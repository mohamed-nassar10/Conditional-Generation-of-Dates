# %%
import datetime

import copy

import random


from dateutil.relativedelta import relativedelta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('seaborn')
# plt.style.use(['dark_background', 'ggplot'])

import seaborn as sns
# sns.set()

# import scipy
# import scipy.stats as stats


# # sympy = symbolic math in Python
# import sympy as sym
# import sympy.plotting.plot as symplot


# make the equations look nicer

# from IPython.display import display
# display.set_matplotlib_formats('svg') # Deprecated since version 7.23

# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


# %config InlineBackend.set_matplotlib_formats = ["svg"]
# %config InlineBackend.figure_formats = ["svg"]

# %%
import sklearn


from sklearn.model_selection import train_test_split


# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler     # <------------ (-1.0, 1.0)
# from sklearn.preprocessing import MinMaxScaler


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from imblearn.over_sampling import SMOTE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset, DataLoader





torch.__version__
# Out:
# '1.12.0+cu113'

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def print_score(shape, yHat, y, yHat_test, yy):
    
    
    n, p = shape
    
    R2 = r2_score(y.detach().numpy(), yHat.detach().numpy())
    
    Adj_r2 = 1 - (1 - R2)  *  (n - 1) / (n - p - 1)
    
    print(f'Adjusted R-Squared(y, yHat): {Adj_r2:0.4f}\n\n')
    # r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
    #  R^2 score is not well-defined with less than two samples
    
    
    print(f'mean_absolute_error(y, yHat):',
          f'{mean_absolute_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_absolute_error(yy, yHat_test):',
          f'{mean_absolute_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_error(y, yHat):',
          f'{mean_squared_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_error(yy, yHat_test):',
          f'{mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_log_error(y, yHat):',
          f'{mean_squared_log_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_log_error(yy, yHat_test):',
          f'{mean_squared_log_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    
    print(f'RMSE(y, yHat):',
          f'{np.sqrt( mean_squared_error(y.detach().numpy(), yHat.detach().numpy()) ):0.4f}\n')
    print(f'RMSE(yy, yHat_test):',
          f'{np.sqrt( mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()) ):0.4f}\n\n')

# %%
# date = np.datetime64("2000-01-01")
# date_strings = date.astype(str).split('-'). 
# # >> ['2000', '01', '01']

# year_int = int(date_strings[0])

# %%
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Out:
# --2022-08-05 12:26:47--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5230713 (5.0M) [text/plain]
# Saving to: ‘data.txt’
#
# data.txt            100%[===================>]   4.99M  --.-KB/s    in 0.02s
#
# 2022-08-05 12:26:47 (242 MB/s) - ‘data.txt’ saved [5230713/5230713]
#
# --2022-08-05 12:26:47--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37732 (37K) [text/plain]
# Saving to: ‘example_input.txt’
#
# example_input.txt   100%[===================>]  36.85K  --.-KB/s    in 0.002s
#
# 2022-08-05 12:26:47 (20.2 MB/s) - ‘example_input.txt’ saved [37732/37732]

# %%
# !ls
# Out:
# data.txt  example_input.txt  sample_data

# %% [markdown]
# 'text.txt'

# %% [markdown]
# [ 1-1-1800 to 31-12-2200 ]

# %% [markdown]
# [day condition] [month condition] [leap year condition] [decade condition] date

# %% [markdown]
# [MON] [DEC] [False] [196] 3-12-1962
# [THU] [DEC] [True] [204] 3-12-2048
# [WED] [JAN] [False] [181] 10-1-1810

# %%
# data = np.loadtxt(open('text.txt','r'),delimiter=' ')
# ori = pd.read_csv('../../data/data.txt', sep=' ', header=None)

ori = pd.read_csv('data.txt', sep=' ', header=None)

# %%
ori.columns = ['day', 'month', 'leap_year', 'decade', 'date']

# %%
ori
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
# data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)
# # pd.to_datetime(data.date, infer_datetime_format=False)

# %%
ori.dtypes
# Out:
# day          object
# month        object
# leap_year    object
# decade       object
# date         object
# dtype: object

# %%
# data_backup = copy.deepcopy(ori)
data = copy.deepcopy(ori)

# %%
data
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
data.date
# Out:
# 0           1-1-1800
# 1           1-1-1801
# 2           1-1-1802
# 3           1-1-1803
# 4           1-1-1804
#              ...
# 146457    31-12-2196
# 146458    31-12-2197
# 146459    31-12-2198
# 146460    31-12-2199
# 146461    31-12-2200
# Name: date, Length: 146462, dtype: object

# %%
# # data['date'] = pd.date_range('3-12-2048', periods=10)
# # data['date'] = pd.date_range('12-3-1962', periods=10)

# # 1-1-1800 to 31-12-2200
# data['date'] = pd.date_range(start='1-1-1800',end='12-31-2200')


data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)

# # data.date = data.date.dt.strftime('%d-%m-%Y')
# # data.date = pd.to_datetime(data.date.dt.strftime('%d-%m-%Y'), format='%d-%m-%Y', infer_datetime_format=False)

# %%
data.dtypes
# Out:
# day                  object
# month                object
# leap_year            object
# decade               object
# date         datetime64[ns]
# dtype: object

# %%
data
# Out:
#           day  month leap_year decade       date
# 0       [WED]  [JAN]   [False]  [180] 1800-01-01
# 1       [THU]  [JAN]   [False]  [180] 1801-01-01
# 2       [FRI]  [JAN]   [False]  [180] 1802-01-01
# 3       [SAT]  [JAN]   [False]  [180] 1803-01-01
# 4       [SUN]  [JAN]    [True]  [180] 1804-01-01
# ...       ...    ...       ...    ...        ...
# 146457  [SAT]  [DEC]    [True]  [219] 2196-12-31
# 146458  [SUN]  [DEC]   [False]  [219] 2197-12-31
# 146459  [MON]  [DEC]   [False]  [219] 2198-12-31
# 146460  [TUE]  [DEC]   [False]  [219] 2199-12-31
# 146461  [WED]  [DEC]   [False]  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %%
map_leap_year = {'[False]': int(0), '[True]' : int(1)}

data.leap_year = data.leap_year.map(map_leap_year)

# data.leap_year = data.leap_year.astype(np.float64)

# %%
data
# Out:
#           day  month  leap_year decade       date
# 0       [WED]  [JAN]          0  [180] 1800-01-01
# 1       [THU]  [JAN]          0  [180] 1801-01-01
# 2       [FRI]  [JAN]          0  [180] 1802-01-01
# 3       [SAT]  [JAN]          0  [180] 1803-01-01
# 4       [SUN]  [JAN]          1  [180] 1804-01-01
# ...       ...    ...        ...    ...        ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31
# 146459  [MON]  [DEC]          0  [219] 2198-12-31
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31
# 146461  [WED]  [DEC]          0  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %% [markdown]
# date -> timestamp

# %%
data.date.iloc[0]
# Out:
# Timestamp('1800-01-01 00:00:00')

# %%
data['date_int'] = data['date'].dt.strftime("%Y%m%d").astype(np.int64)

# data['date_str'] = data['date'].dt.strftime("%Y%m%d")

# %%
# data['date_int'].map(str)
# data['date_int'].astype(str)

# %%
# date_max = data.date_int.max()
# data['date_normalized'] = data.date_int / date_max

# %%
data
# Out:
#           day  month  leap_year decade       date  date_int
# 0       [WED]  [JAN]          0  [180] 1800-01-01  18000101
# 1       [THU]  [JAN]          0  [180] 1801-01-01  18010101
# 2       [FRI]  [JAN]          0  [180] 1802-01-01  18020101
# 3       [SAT]  [JAN]          0  [180] 1803-01-01  18030101
# 4       [SUN]  [JAN]          1  [180] 1804-01-01  18040101
# ...       ...    ...        ...    ...        ...       ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31  21961231
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31  21971231
# 146459  [MON]  [DEC]          0  [219] 2198-12-31  21981231
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31  21991231
# 146461  [WED]  [DEC]          0  [220] 2200-12-31  22001231
#
# [146462 rows x 6 columns]

# %%
x = data.decade.iloc[0]
x
# Out:
# '[180]'

# %%
x.strip('[]')
# Out:
# '180'

# %%
data.decade = data.decade.apply(lambda x: x.strip('[]')).astype('int64')

# %%
# data.day = data.day.apply(lambda x: x.strip('[]'))
# data.month = data.month.apply(lambda x: x.strip('[]'))

# %%
map_day = {'[SAT]': int(0),
           '[SUN]': int(1),
           '[MON]': int(2),
           '[TUE]': int(3),
           '[WED]': int(4),
           '[THU]': int(5),
           '[FRI]': int(6)}

# %%
data['day_code'] = data.day.map(map_day)

# %%
scaler_day = RobustScaler()

x = data.day_code.values.reshape(-1, 1)

data['day_scaled'] = scaler_day.fit_transform(x).flatten()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled
# 0             0.25
# 1             0.50
# 2             0.75
# 3            -0.75
# 4            -0.50
# ...            ...
# 146457       -0.75
# 146458       -0.50
# 146459       -0.25
# 146460        0.00
# 146461        0.25
#
# [146462 rows x 8 columns]

# %%
data['day_sin'] = np.sin(data['day_code'] * (2 * np.pi / 7))
data['day_cos'] = np.cos(data['day_code'] * (2 * np.pi / 7))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos
# 0             0.25 -0.433884 -0.900969
# 1             0.50 -0.974928 -0.222521
# 2             0.75 -0.781831  0.623490
# 3            -0.75  0.000000  1.000000
# 4            -0.50  0.781831  0.623490
# ...            ...       ...       ...
# 146457       -0.75  0.000000  1.000000
# 146458       -0.50  0.781831  0.623490
# 146459       -0.25  0.974928 -0.222521
# 146460        0.00  0.433884 -0.900969
# 146461        0.25 -0.433884 -0.900969
#
# [146462 rows x 10 columns]

# %%
map_month = {'[JAN]' : 0,
             '[FEB]' : 1,
             '[MAR]' : 2,
             '[APR]' : 3,
             '[MAY]' : 4,
             '[JUN]' : 5,
             '[JUL]' : 6,
             '[AUG]' : 7,
             '[SEP]' : 8,
             '[OCT]' : 9,
             '[NOV]' : 10,
             '[DEC]' : 11}

# %%
data['month_code'] = data.month.map(map_month)

# %%
scaler_month = RobustScaler()

x = data.month_code.values.reshape(-1, 1)

data['month_scaled'] = scaler_month.fit_transform(x).flatten()

# %%
data['month_sin'] = np.sin(data['month_code'] * (2 * np.pi / 12))
data['month_cos'] = np.cos(data['month_code'] * (2 * np.pi / 12))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ...           ...
# 146457   0.866025
# 146458   0.866025
# 146459   0.866025
# 146460   0.866025
# 146461   0.866025
#
# [146462 rows x 14 columns]

# %%
scaler_decade = RobustScaler()

x = data.decade.values.reshape(-1, 1)

data['decade_scaled'] = scaler_decade.fit_transform(x).flatten()

# %%
# alpha = len(data.decade.unique())
alpha = (data.decade.iloc[-1] - data.decade.iloc[0]) + 1

data['decade_sin'] = np.sin(data['decade'] * (2 * np.pi / alpha))
data['decade_cos'] = np.cos(data['decade'] * (2 * np.pi / alpha))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %%
# data.date_normalized.min(), data.date_normalized.max()

# %%
# round(data.date_normalized.min()), round(data.date_normalized.max())

# %%
round(data.day_scaled.min()), round(data.day_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_sin.min()), round(data.day_sin.max())
# Out:
# (-1, 1)

# %%
round(data.day_cos.min()), round(data.day_cos.max())
# Out:
# (-1, 1)

# %%
round(data.month_scaled.min()), round(data.month_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.month_sin.min()), round(data.month_sin.max())
# Out:
# (-1, 1)

# %%
round(data.month_cos.min()), round(data.month_cos.max())
# Out:
# (-1, 1)

# %%
data.leap_year.min(), data.leap_year.max()
# Out:
# (0, 1)

# %%
round(data.decade_scaled.min()), round(data.decade_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.decade_sin.min()), round(data.decade_sin.max())
# Out:
# (-1, 1)

# %%
round(data.decade_cos.min()), round(data.decade_cos.max())
# Out:
# (-1, 1)

# %% [markdown]
# Boxplot

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.day.value_counts().plot(kind="bar")

# %%
data.month.value_counts().plot(kind="bar")

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
data.decade.value_counts().plot(kind="bar")

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %% [markdown]
# ['day_sin', 'day_cos', 'month_sin', 'month_cos', 'leap_year', 'decade_scaled']
# ['date_timestamp_scaled']

# %%
X = data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
          'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 0.25      , -0.43388374, -0.90096887, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.5       , -0.97492791, -0.22252093, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.75      , -0.78183148,  0.6234898 , ..., -1.        ,
#          0.63624244, -0.77148918],
#        ...,
#        [-0.25      ,  0.97492791, -0.22252093, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.        ,  0.43388374, -0.90096887, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.25      , -0.43388374, -0.90096887, ...,  1.        ,
#          0.74655322, -0.6653257 ]])

# %%
len(X)
# Out:
# 146462

# %%
X.shape
# Out:
# (146462, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()


ls = []

for s in data['date_int'].astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(data['date_int'])), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y = ll.values / 9

Y
# Out:
# array([[0.11111111, 0.88888889, 0.        , ..., 0.11111111, 0.        ,
#         0.11111111],
#        [0.11111111, 0.88888889, 0.        , ..., 0.11111111, 0.        ,
#         0.11111111],
#        [0.11111111, 0.88888889, 0.        , ..., 0.11111111, 0.        ,
#         0.11111111],
#        ...,
#        [0.22222222, 0.11111111, 1.        , ..., 0.22222222, 0.33333333,
#         0.11111111],
#        [0.22222222, 0.11111111, 1.        , ..., 0.22222222, 0.33333333,
#         0.11111111],
#        [0.22222222, 0.22222222, 0.        , ..., 0.22222222, 0.33333333,
#         0.11111111]])

# %%
len(Y)
# Out:
# 146462

# %%
Y.shape
# Out:
# (146462, 8)

# %%
# # leap = np.where(~X['leap_year'] == 1)[0]
# leap = np.where(X['leap_year'] == 1)[0]

# leap

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64


train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (146462, 10)
#
# Y: (146462, 8)
#
# Train data:   (102523, 10)
#
# Train labels: (102523, 8)
#
# Test data:    (43939, 10)
#
# Test labels:  (43939, 8)

# %%
102523 % 32, 102523 % 64
# Out:
# (27, 59)

# %%
class Model(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.input = nn.Linear(10, 32)

        self.fc1 = nn.Linear(32, 128)
        self.bnorm1 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 512)
        self.bnorm2 = nn.BatchNorm1d(512)

        self.fc3 = nn.Linear(512, 64)
        self.bnorm3 = nn.BatchNorm1d(64)

        self.fc4 = nn.Linear(64, 32)
        self.bnorm4 = nn.BatchNorm1d(32)


        self.output = nn.Linear(32, 8)



    def forward(self, x):


        # print(f'training={self.training}')

        x = F.relu( self.input(x) )

        x = F.relu(self.bnorm1(self.fc1(x)))
        x = F.dropout(x, p=0.25, training=self.training)

        x = F.relu(self.bnorm2(self.fc2(x)))
        x = F.dropout(x, p=0.4, training=self.training)

        x = F.relu(self.bnorm3(self.fc3(x)))
        x = F.dropout(x, p=0.1, training=self.training)

        x = F.relu(self.bnorm4(self.fc4(x)))
        x = F.dropout(x, p=0.05, training=self.training)


        x = F.relu(self.output(x))
        # x = self.output(x)
        


        return x

# %%
# test_x, test_y = next(iter(train_loader))

# print(f'X: {X.shape}\n')
# print(f'Y: {Y.shape}\n')

# %%
def train(model, numepochs):

    numepochs = numepochs

    model = model
    
    
    
    # lossfun = nn.MSELoss()
    lossfun = nn.L1Loss()


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0002, betas=(0.5, 0.999), weight_decay=1e-5)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.5, 0.999), weight_decay=1e-1)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=1e-9)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
    
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    
    
    
    trainLoss = torch.zeros(numepochs)
    testLoss  = torch.zeros(numepochs)
    trainAcc  = torch.zeros(numepochs)
    # testAcc   = torch.zeros(numepochs)


    for epochi in range(numepochs):

        model.train() # switch to train mode

        batchLoss = []
        batchAcc  = []

        for X,y in train_loader:

            X = X.to(device)
            y = y.to(device)

            yHat = model(X)
            loss = lossfun(yHat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())
            # batchAcc.append( torch.mean(( yHat == y).float() ).item() )
            # batchAcc.append( torch.mean( (torch.abs(yHat - y) < 1).float() ).item() ) # <1 for rounding
            batchAcc.append( r2_score(y.detach().cpu().numpy(), yHat.detach().cpu().numpy()) )
            




        trainLoss[epochi] = np.mean(batchLoss)
        # trainAcc[epochi]  = 100*np.mean(batchAcc)
        trainAcc[epochi]  = np.mean(batchAcc)
        



        model.eval() # switch to test mode

        XX,yy = next(iter(test_loader))

        XX = XX.to(device)
        yy = yy.to(device)

        # forward pass and loss
        with torch.no_grad():
            yHat_test = model(XX)
            loss = lossfun(yHat_test, yy)


        testLoss[epochi] = loss.item()
        # testAcc[epochi]  = 100*torch.mean( (yHat_test == yy).float() ).item()
        # testAcc[epochi]  = 100*torch.mean( (torch.abs(yHat_test - yy) < 1).float() ).item()
        # testAcc[epochi]  = 100*r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
        


        # if (epochi + 1) % 5 == 0:
        print(f'Epoch {epochi+1}/{numepochs}, Train Loss: {loss.item():0.6f}, Test Loss: {loss.item():0.6f}')


        
    return trainLoss.cpu(), testLoss.cpu(), trainAcc.cpu(), yHat.cpu(), y.cpu(), yHat_test.cpu(), yy.cpu()

# %%
model = Model().to(device)

# test_hat = model(torch.randn(32,6))
# test_hat = model(test_x)

# print(test_hat.shape)

# %%
# for p in list(model.named_parameters()):
#     if 'weight' in p[0] and 'bnorm' not in p[0]:
#         nn.init.xavier_normal_(p[1].data)
#         print(p[0])
#         print(p[1].data.shape)

# %%
numepochs = 120

trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model, numepochs)
# Out:
# Epoch 1/120, Train Loss: 0.114097, Test Loss: 0.114097
# Epoch 2/120, Train Loss: 0.099699, Test Loss: 0.099699
# Epoch 3/120, Train Loss: 0.102954, Test Loss: 0.102954
# Epoch 4/120, Train Loss: 0.099554, Test Loss: 0.099554
# Epoch 5/120, Train Loss: 0.108312, Test Loss: 0.108312
# Epoch 6/120, Train Loss: 0.104846, Test Loss: 0.104846
# Epoch 7/120, Train Loss: 0.099367, Test Loss: 0.099367
# Epoch 8/120, Train Loss: 0.105774, Test Loss: 0.105774
# Epoch 9/120, Train Loss: 0.103005, Test Loss: 0.103005
# Epoch 10/120, Train Loss: 0.104730, Test Loss: 0.104730
# Epoch 11/120, Train Loss: 0.111724, Test Loss: 0.111724
# Epoch 12/120, Train Loss: 0.105868, Test Loss: 0.105868
# Epoch 13/120, Train Loss: 0.094782, Test Loss: 0.094782
# Epoch 14/120, Train Loss: 0.105455, Test Loss: 0.105455
# Epoch 15/120, Train Loss: 0.095786, Test Loss: 0.095786
# Epoch 16/120, Train Loss: 0.109285, Test Loss: 0.109285
# Epoch 17/120, Train Loss: 0.103616, Test Loss: 0.103616
# Epoch 18/120, Train Loss: 0.098875, Test Loss: 0.098875
# Epoch 19/120, Train Loss: 0.095613, Test Loss: 0.095613
# Epoch 20/120, Train Loss: 0.105687, Test Loss: 0.105687
# Epoch 21/120, Train Loss: 0.098013, Test Loss: 0.098013
# Epoch 22/120, Train Loss: 0.100096, Test Loss: 0.100096
# Epoch 23/120, Train Loss: 0.105483, Test Loss: 0.105483
# Epoch 24/120, Train Loss: 0.098903, Test Loss: 0.098903
# Epoch 25/120, Train Loss: 0.101556, Test Loss: 0.101556
# Epoch 26/120, Train Loss: 0.094239, Test Loss: 0.094239
# Epoch 27/120, Train Loss: 0.103710, Test Loss: 0.103710
# Epoch 28/120, Train Loss: 0.105130, Test Loss: 0.105130
# Epoch 29/120, Train Loss: 0.108938, Test Loss: 0.108938
# Epoch 30/120, Train Loss: 0.095734, Test Loss: 0.095734
# Epoch 31/120, Train Loss: 0.097495, Test Loss: 0.097495
# Epoch 32/120, Train Loss: 0.099583, Test Loss: 0.099583
# Epoch 33/120, Train Loss: 0.109693, Test Loss: 0.109693
# Epoch 34/120, Train Loss: 0.101610, Test Loss: 0.101610
# Epoch 35/120, Train Loss: 0.107244, Test Loss: 0.107244
# Epoch 36/120, Train Loss: 0.104249, Test Loss: 0.104249
# Epoch 37/120, Train Loss: 0.099741, Test Loss: 0.099741
# Epoch 38/120, Train Loss: 0.098397, Test Loss: 0.098397
# Epoch 39/120, Train Loss: 0.109033, Test Loss: 0.109033
# Epoch 40/120, Train Loss: 0.108176, Test Loss: 0.108176
# Epoch 41/120, Train Loss: 0.102124, Test Loss: 0.102124
# Epoch 42/120, Train Loss: 0.101880, Test Loss: 0.101880
# Epoch 43/120, Train Loss: 0.108446, Test Loss: 0.108446
# Epoch 44/120, Train Loss: 0.098015, Test Loss: 0.098015
# Epoch 45/120, Train Loss: 0.105579, Test Loss: 0.105579
# Epoch 46/120, Train Loss: 0.110737, Test Loss: 0.110737
# Epoch 47/120, Train Loss: 0.096355, Test Loss: 0.096355
# Epoch 48/120, Train Loss: 0.099066, Test Loss: 0.099066
# Epoch 49/120, Train Loss: 0.101695, Test Loss: 0.101695
# Epoch 50/120, Train Loss: 0.098328, Test Loss: 0.098328
# Epoch 51/120, Train Loss: 0.110482, Test Loss: 0.110482
# Epoch 52/120, Train Loss: 0.102732, Test Loss: 0.102732
# Epoch 53/120, Train Loss: 0.108098, Test Loss: 0.108098
# Epoch 54/120, Train Loss: 0.103976, Test Loss: 0.103976
# Epoch 55/120, Train Loss: 0.097624, Test Loss: 0.097624
# Epoch 56/120, Train Loss: 0.100174, Test Loss: 0.100174
# Epoch 57/120, Train Loss: 0.110087, Test Loss: 0.110087
# Epoch 58/120, Train Loss: 0.102706, Test Loss: 0.102706
# Epoch 59/120, Train Loss: 0.103075, Test Loss: 0.103075
# Epoch 60/120, Train Loss: 0.099679, Test Loss: 0.099679
# Epoch 61/120, Train Loss: 0.099996, Test Loss: 0.099996
# Epoch 62/120, Train Loss: 0.105279, Test Loss: 0.105279
# Epoch 63/120, Train Loss: 0.099376, Test Loss: 0.099376
# Epoch 64/120, Train Loss: 0.100913, Test Loss: 0.100913
# Epoch 65/120, Train Loss: 0.107850, Test Loss: 0.107850
# Epoch 66/120, Train Loss: 0.105425, Test Loss: 0.105425
# Epoch 67/120, Train Loss: 0.101900, Test Loss: 0.101900
# Epoch 68/120, Train Loss: 0.100305, Test Loss: 0.100305
# Epoch 69/120, Train Loss: 0.101785, Test Loss: 0.101785
# Epoch 70/120, Train Loss: 0.098915, Test Loss: 0.098915
# Epoch 71/120, Train Loss: 0.103581, Test Loss: 0.103581
# Epoch 72/120, Train Loss: 0.102904, Test Loss: 0.102904
# Epoch 73/120, Train Loss: 0.100888, Test Loss: 0.100888
# Epoch 74/120, Train Loss: 0.096388, Test Loss: 0.096388
# Epoch 75/120, Train Loss: 0.104831, Test Loss: 0.104831
# Epoch 76/120, Train Loss: 0.111229, Test Loss: 0.111229
# Epoch 77/120, Train Loss: 0.098823, Test Loss: 0.098823
# Epoch 78/120, Train Loss: 0.100229, Test Loss: 0.100229
# Epoch 79/120, Train Loss: 0.100432, Test Loss: 0.100432
# Epoch 80/120, Train Loss: 0.095844, Test Loss: 0.095844
# Epoch 81/120, Train Loss: 0.094364, Test Loss: 0.094364
# Epoch 82/120, Train Loss: 0.098355, Test Loss: 0.098355
# Epoch 83/120, Train Loss: 0.104826, Test Loss: 0.104826
# Epoch 84/120, Train Loss: 0.101328, Test Loss: 0.101328
# Epoch 85/120, Train Loss: 0.101746, Test Loss: 0.101746
# Epoch 86/120, Train Loss: 0.098437, Test Loss: 0.098437
# Epoch 87/120, Train Loss: 0.102065, Test Loss: 0.102065
# Epoch 88/120, Train Loss: 0.098254, Test Loss: 0.098254
# Epoch 89/120, Train Loss: 0.093496, Test Loss: 0.093496
# Epoch 90/120, Train Loss: 0.107708, Test Loss: 0.107708
# Epoch 91/120, Train Loss: 0.108150, Test Loss: 0.108150
# Epoch 92/120, Train Loss: 0.107703, Test Loss: 0.107703
# Epoch 93/120, Train Loss: 0.104414, Test Loss: 0.104414
# Epoch 94/120, Train Loss: 0.102804, Test Loss: 0.102804
# Epoch 95/120, Train Loss: 0.099548, Test Loss: 0.099548
# Epoch 96/120, Train Loss: 0.111575, Test Loss: 0.111575
# Epoch 97/120, Train Loss: 0.092964, Test Loss: 0.092964
# Epoch 98/120, Train Loss: 0.110982, Test Loss: 0.110982
# Epoch 99/120, Train Loss: 0.101130, Test Loss: 0.101130
# Epoch 100/120, Train Loss: 0.103104, Test Loss: 0.103104
# Epoch 101/120, Train Loss: 0.097920, Test Loss: 0.097920
# Epoch 102/120, Train Loss: 0.099947, Test Loss: 0.099947
# Epoch 103/120, Train Loss: 0.105498, Test Loss: 0.105498
# Epoch 104/120, Train Loss: 0.107222, Test Loss: 0.107222
# Epoch 105/120, Train Loss: 0.105880, Test Loss: 0.105880
# Epoch 106/120, Train Loss: 0.106243, Test Loss: 0.106243
# Epoch 107/120, Train Loss: 0.100791, Test Loss: 0.100791
# Epoch 108/120, Train Loss: 0.127516, Test Loss: 0.127516
# Epoch 109/120, Train Loss: 0.092868, Test Loss: 0.092868
# Epoch 110/120, Train Loss: 0.096300, Test Loss: 0.096300
# Epoch 111/120, Train Loss: 0.101696, Test Loss: 0.101696
# Epoch 112/120, Train Loss: 0.105845, Test Loss: 0.105845
# Epoch 113/120, Train Loss: 0.102681, Test Loss: 0.102681
# Epoch 114/120, Train Loss: 0.099496, Test Loss: 0.099496
# Epoch 115/120, Train Loss: 0.099276, Test Loss: 0.099276
# Epoch 116/120, Train Loss: 0.099329, Test Loss: 0.099329
# Epoch 117/120, Train Loss: 0.104488, Test Loss: 0.104488
# Epoch 118/120, Train Loss: 0.100665, Test Loss: 0.100665
# Epoch 119/120, Train Loss: 0.113077, Test Loss: 0.113077
# Epoch 120/120, Train Loss: 0.102014, Test Loss: 0.102014

# %%
# r2_score(y.detach().numpy(), yHat.detach().numpy())
# type(r2_score(y.detach(), yHat.detach()))

# %%
# torch.mean( r2_score(y.detach().numpy(), yHat.detach().numpy()) ).item()

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([0.1305, 0.1186, 0.1173, 0.1169, 0.1166, 0.1164, 0.1163, 0.1162, 0.1160,
#          0.1160, 0.1161, 0.1159, 0.1158, 0.1158, 0.1158, 0.1160, 0.1160, 0.1160,
#          0.1161, 0.1160, 0.1161, 0.1161, 0.1161, 0.1161, 0.1160, 0.1159, 0.1160,
#          0.1162, 0.1159, 0.1160, 0.1160, 0.1160, 0.1159, 0.1160, 0.1161, 0.1159,
#          0.1160, 0.1160, 0.1159, 0.1159, 0.1160, 0.1158, 0.1158, 0.1159, 0.1157,
#          0.1158, 0.1158, 0.1159, 0.1157, 0.1157, 0.1156, 0.1157, 0.1158, 0.1158,
#          0.1159, 0.1159, 0.1157, 0.1157, 0.1157, 0.1157, 0.1158, 0.1157, 0.1158,
#          0.1157, 0.1159, 0.1158, 0.1156, 0.1157, 0.1157, 0.1159, 0.1160, 0.1158,
#          0.1160, 0.1158, 0.1158, 0.1157, 0.1158, 0.1158, 0.1159, 0.1157, 0.1158,
#          0.1158, 0.1157, 0.1158, 0.1157, 0.1159, 0.1157, 0.1157, 0.1158, 0.1158,
#          0.1157, 0.1158, 0.1157, 0.1157, 0.1157, 0.1157, 0.1158, 0.1158, 0.1159,
#          0.1159, 0.1160, 0.1158, 0.1158, 0.1159, 0.1160, 0.1158, 0.1159, 0.1160,
#          0.1157, 0.1158, 0.1159, 0.1159, 0.1160, 0.1158, 0.1159, 0.1159, 0.1160,
#          0.1158, 0.1159, 0.1160]),
#  tensor([0.1141, 0.0997, 0.1030, 0.0996, 0.1083, 0.1048, 0.0994, 0.1058, 0.1030,
#          0.1047, 0.1117, 0.1059, 0.0948, 0.1055, 0.0958, 0.1093, 0.1036, 0.0989,
#          0.0956, 0.1057, 0.0980, 0.1001, 0.1055, 0.0989, 0.1016, 0.0942, 0.1037,
#          0.1051, 0.1089, 0.0957, 0.0975, 0.0996, 0.1097, 0.1016, 0.1072, 0.1042,
#          0.0997, 0.0984, 0.1090, 0.1082, 0.1021, 0.1019, 0.1084, 0.0980, 0.1056,
#          0.1107, 0.0964, 0.0991, 0.1017, 0.0983, 0.1105, 0.1027, 0.1081, 0.1040,
#          0.0976, 0.1002, 0.1101, 0.1027, 0.1031, 0.0997, 0.1000, 0.1053, 0.0994,
#          0.1009, 0.1078, 0.1054, 0.1019, 0.1003, 0.1018, 0.0989, 0.1036, 0.1029,
#          0.1009, 0.0964, 0.1048, 0.1112, 0.0988, 0.1002, 0.1004, 0.0958, 0.0944,
#          0.0984, 0.1048, 0.1013, 0.1017, 0.0984, 0.1021, 0.0983, 0.0935, 0.1077,
#          0.1081, 0.1077, 0.1044, 0.1028, 0.0995, 0.1116, 0.0930, 0.1110, 0.1011,
#          0.1031, 0.0979, 0.0999, 0.1055, 0.1072, 0.1059, 0.1062, 0.1008, 0.1275,
#          0.0929, 0.0963, 0.1017, 0.1058, 0.1027, 0.0995, 0.0993, 0.0993, 0.1045,
#          0.1007, 0.1131, 0.1020]),
#  tensor([0.3605, 0.4944, 0.4985, 0.5017, 0.5030, 0.5042, 0.5036, 0.5035, 0.5042,
#          0.5045, 0.5041, 0.5044, 0.5056, 0.5054, 0.5054, 0.5045, 0.5037, 0.5035,
#          0.5036, 0.5040, 0.5032, 0.5047, 0.5035, 0.5043, 0.5038, 0.5044, 0.5035,
#          0.5035, 0.5040, 0.5042, 0.5040, 0.5035, 0.5051, 0.5032, 0.5030, 0.5040,
#          0.5029, 0.5017, 0.5035, 0.5039, 0.5037, 0.5054, 0.5049, 0.5035, 0.5053,
#          0.5044, 0.5063, 0.5036, 0.5048, 0.5052, 0.5055, 0.5047, 0.5034, 0.5042,
#          0.5033, 0.5038, 0.5044, 0.5045, 0.5044, 0.5050, 0.5045, 0.5042, 0.5053,
#          0.5045, 0.5029, 0.5042, 0.5061, 0.5054, 0.5043, 0.5029, 0.5030, 0.5044,
#          0.5040, 0.5042, 0.5033, 0.5045, 0.5038, 0.5050, 0.5032, 0.5048, 0.5046,
#          0.5044, 0.5046, 0.5034, 0.5050, 0.5040, 0.5051, 0.5047, 0.5047, 0.5046,
#          0.5047, 0.5028, 0.5045, 0.5046, 0.5038, 0.5038, 0.5027, 0.5042, 0.5040,
#          0.5042, 0.5030, 0.5043, 0.5044, 0.5029, 0.5037, 0.5049, 0.5042, 0.5031,
#          0.5041, 0.5030, 0.5029, 0.5024, 0.5028, 0.5048, 0.5042, 0.5049, 0.5035,
#          0.5042, 0.5033, 0.5037]))

# %%
# batchLoss

# %%
# batchAcc

# %%
# yHat.shape, y.shape

# %%
# yHat_test.shape, yy.shape

# %%
y.T.shape
# Out:
# torch.Size([8, 32])

# %%
yHat.flatten(), y.flatten()
# Out:
# (tensor([0.2234, 0.1538, 0.8984, 0.4189, 0.0000, 0.3695, 0.1110, 0.4532, 0.2261,
#          0.0000, 0.8046, 0.4577, 0.0000, 0.1837, 0.1117, 0.4918, 0.2257, 0.0191,
#          0.4716, 0.4293, 0.0000, 0.3035, 0.1104, 0.4487, 0.2222, 0.1349, 0.3597,
#          0.4350, 0.0000, 0.6996, 0.1101, 0.4477, 0.2242, 0.1353, 0.8893, 0.4514,
#          0.0000, 0.7717, 0.1114, 0.4849, 0.0824, 1.0791, 0.5322, 0.4560, 0.0278,
#          0.1844, 0.1140, 0.4759, 0.1022, 0.9566, 0.1361, 0.4599, 0.0000, 0.3051,
#          0.1125, 0.4661, 0.2236, 0.0457, 0.7476, 0.4526, 0.0877, 0.1464, 0.1108,
#          0.4814, 0.0896, 1.0596, 0.7349, 0.4891, 0.0967, 0.3026, 0.1148, 0.5155,
#          0.1120, 0.9023, 0.2146, 0.4668, 0.0000, 0.6722, 0.1126, 0.4748, 0.2226,
#          0.1398, 0.6137, 0.4454, 0.0000, 0.9189, 0.1108, 0.4646, 0.2244, 0.1232,
#          0.8918, 0.4365, 0.0000, 0.3115, 0.1113, 0.4715, 0.2278, 0.0000, 0.6848,
#          0.4525, 0.0000, 0.3721, 0.1119, 0.4798, 0.2270, 0.0000, 0.9126, 0.4817,
#          0.0000, 0.1097, 0.1120, 0.5213, 0.0958, 1.0057, 0.3979, 0.4701, 0.0000,
#          0.6740, 0.1133, 0.4833, 0.1042, 0.9591, 0.1307, 0.5029, 0.0000, 0.8658,
#          0.1126, 0.5084, 0.0921, 1.0196, 0.2857, 0.4527, 0.0000, 0.4984, 0.1135,
#          0.4624, 0.2235, 0.1032, 0.6684, 0.4353, 0.0189, 0.0907, 0.1107, 0.4610,
#          0.2254, 0.1301, 0.6054, 0.4508, 0.1323, 0.0000, 0.1113, 0.4714, 0.2261,
#          0.0229, 0.5855, 0.4418, 0.1404, 0.1778, 0.1112, 0.4639, 0.1118, 0.8948,
#          0.5624, 0.4609, 0.1195, 0.1283, 0.1141, 0.4797, 0.0986, 0.9831, 0.2967,
#          0.4646, 0.0000, 0.6426, 0.1129, 0.4737, 0.1017, 0.9760, 0.1254, 0.5065,
#          0.0000, 0.8691, 0.1127, 0.5120, 0.0986, 0.9739, 0.1977, 0.4519, 0.0000,
#          0.2360, 0.1126, 0.4590, 0.0973, 1.0032, 0.7163, 0.4646, 0.0000, 0.5457,
#          0.1141, 0.4896, 0.0971, 1.0008, 0.5015, 0.4485, 0.0000, 0.1760, 0.1138,
#          0.4657, 0.2231, 0.1021, 0.0829, 0.4646, 0.0000, 0.6074, 0.1093, 0.4705,
#          0.1070, 0.9316, 0.5823, 0.4492, 0.0000, 0.4579, 0.1136, 0.4727, 0.2062,
#          0.1969, 0.1193, 0.4859, 0.0000, 0.8380, 0.1101, 0.4927, 0.2230, 0.0974,
#          0.1776, 0.4826, 0.1245, 0.0000, 0.1096, 0.4912, 0.0972, 1.0008, 0.4429,
#          0.4773, 0.0000, 0.9218, 0.1135, 0.4909, 0.2248, 0.0000, 0.3417, 0.4627,
#          0.0246, 0.5574, 0.1105, 0.4767], grad_fn=<ReshapeAliasBackward0>),
#  tensor([0.2222, 0.1111, 0.8889, 0.5556, 0.0000, 0.3333, 0.1111, 0.8889, 0.2222,
#          0.0000, 0.8889, 1.0000, 0.0000, 0.2222, 0.2222, 0.4444, 0.2222, 0.0000,
#          0.5556, 0.8889, 0.0000, 0.3333, 0.2222, 1.0000, 0.2222, 0.1111, 0.4444,
#          0.2222, 0.0000, 0.7778, 0.0000, 0.3333, 0.2222, 0.1111, 1.0000, 0.0000,
#          0.0000, 0.8889, 0.0000, 0.6667, 0.1111, 1.0000, 0.5556, 0.7778, 0.0000,
#          0.1111, 0.0000, 0.3333, 0.1111, 0.8889, 0.0000, 0.2222, 0.0000, 0.3333,
#          0.1111, 0.4444, 0.2222, 0.0000, 1.0000, 0.3333, 0.1111, 0.1111, 0.1111,
#          0.8889, 0.1111, 1.0000, 0.6667, 0.4444, 0.1111, 0.2222, 0.1111, 0.0000,
#          0.1111, 1.0000, 0.0000, 0.4444, 0.0000, 0.7778, 0.0000, 0.3333, 0.2222,
#          0.1111, 0.6667, 0.4444, 0.0000, 0.8889, 0.1111, 0.7778, 0.2222, 0.1111,
#          0.8889, 0.8889, 0.0000, 0.2222, 0.2222, 0.0000, 0.2222, 0.0000, 0.8889,
#          0.6667, 0.0000, 0.4444, 0.0000, 0.5556, 0.2222, 0.0000, 0.8889, 0.8889,
#          0.0000, 0.1111, 0.1111, 1.0000, 0.1111, 1.0000, 0.0000, 0.1111, 0.0000,
#          0.7778, 0.2222, 0.4444, 0.1111, 0.8889, 0.0000, 0.6667, 0.0000, 1.0000,
#          0.1111, 0.0000, 0.1111, 1.0000, 0.3333, 0.1111, 0.0000, 0.6667, 0.1111,
#          0.0000, 0.2222, 0.1111, 0.5556, 0.1111, 0.0000, 0.1111, 0.2222, 0.1111,
#          0.2222, 0.1111, 0.6667, 0.0000, 0.1111, 0.0000, 0.1111, 0.3333, 0.2222,
#          0.0000, 1.0000, 0.7778, 0.1111, 0.2222, 0.2222, 0.8889, 0.1111, 1.0000,
#          0.7778, 1.0000, 0.1111, 0.1111, 0.1111, 0.5556, 0.1111, 1.0000, 0.1111,
#          1.0000, 0.0000, 0.7778, 0.1111, 1.0000, 0.1111, 0.8889, 0.0000, 0.1111,
#          0.0000, 0.8889, 0.2222, 0.3333, 0.1111, 0.8889, 0.0000, 0.1111, 0.0000,
#          0.2222, 0.1111, 0.3333, 0.1111, 0.8889, 1.0000, 0.4444, 0.0000, 0.6667,
#          0.0000, 0.3333, 0.1111, 0.8889, 1.0000, 0.0000, 0.0000, 0.2222, 0.2222,
#          0.7778, 0.2222, 0.1111, 0.2222, 0.5556, 0.0000, 0.7778, 0.2222, 0.6667,
#          0.1111, 1.0000, 0.4444, 0.2222, 0.0000, 0.5556, 0.1111, 0.1111, 0.2222,
#          0.0000, 0.0000, 0.1111, 0.0000, 0.8889, 0.0000, 1.0000, 0.2222, 0.1111,
#          0.2222, 0.6667, 0.1111, 0.0000, 0.2222, 0.5556, 0.1111, 0.8889, 0.5556,
#          0.4444, 0.0000, 0.8889, 0.1111, 0.8889, 0.2222, 0.0000, 0.4444, 0.0000,
#          0.0000, 0.5556, 0.2222, 0.6667]))

# %%
yHat_test, yy
# Out:
# (tensor([[0.1164, 0.8729, 0.1592, 0.4661, 0.0000, 0.5919, 0.1108, 0.4717]]),
#  tensor([[0.1111, 0.8889, 0.1111, 0.6667, 0.0000, 0.6667, 0.0000, 0.1111]]))

# %%
(yy * 9).round()
# Out:
# tensor([[1., 8., 1., 6., 0., 6., 0., 1.]])

# %%
(yHat_test * 9).round()
# Out:
# tensor([[1., 8., 1., 4., 0., 5., 1., 4.]])

# %%
(yHat * 9).round(), (y * 9).round()
# Out:
# (tensor([[ 2.,  1.,  8.,  4.,  0.,  3.,  1.,  4.],
#          [ 2.,  0.,  7.,  4.,  0.,  2.,  1.,  4.],
#          [ 2.,  0.,  4.,  4.,  0.,  3.,  1.,  4.],
#          [ 2.,  1.,  3.,  4.,  0.,  6.,  1.,  4.],
#          [ 2.,  1.,  8.,  4.,  0.,  7.,  1.,  4.],
#          [ 1., 10.,  5.,  4.,  0.,  2.,  1.,  4.],
#          [ 1.,  9.,  1.,  4.,  0.,  3.,  1.,  4.],
#          [ 2.,  0.,  7.,  4.,  1.,  1.,  1.,  4.],
#          [ 1., 10.,  7.,  4.,  1.,  3.,  1.,  5.],
#          [ 1.,  8.,  2.,  4.,  0.,  6.,  1.,  4.],
#          [ 2.,  1.,  6.,  4.,  0.,  8.,  1.,  4.],
#          [ 2.,  1.,  8.,  4.,  0.,  3.,  1.,  4.],
#          [ 2.,  0.,  6.,  4.,  0.,  3.,  1.,  4.],
#          [ 2.,  0.,  8.,  4.,  0.,  1.,  1.,  5.],
#          [ 1.,  9.,  4.,  4.,  0.,  6.,  1.,  4.],
#          [ 1.,  9.,  1.,  5.,  0.,  8.,  1.,  5.],
#          [ 1.,  9.,  3.,  4.,  0.,  4.,  1.,  4.],
#          [ 2.,  1.,  6.,  4.,  0.,  1.,  1.,  4.],
#          [ 2.,  1.,  5.,  4.,  1.,  0.,  1.,  4.],
#          [ 2.,  0.,  5.,  4.,  1.,  2.,  1.,  4.],
#          [ 1.,  8.,  5.,  4.,  1.,  1.,  1.,  4.],
#          [ 1.,  9.,  3.,  4.,  0.,  6.,  1.,  4.],
#          [ 1.,  9.,  1.,  5.,  0.,  8.,  1.,  5.],
#          [ 1.,  9.,  2.,  4.,  0.,  2.,  1.,  4.],
#          [ 1.,  9.,  6.,  4.,  0.,  5.,  1.,  4.],
#          [ 1.,  9.,  5.,  4.,  0.,  2.,  1.,  4.],
#          [ 2.,  1.,  1.,  4.,  0.,  5.,  1.,  4.],
#          [ 1.,  8.,  5.,  4.,  0.,  4.,  1.,  4.],
#          [ 2.,  2.,  1.,  4.,  0.,  8.,  1.,  4.],
#          [ 2.,  1.,  2.,  4.,  1.,  0.,  1.,  4.],
#          [ 1.,  9.,  4.,  4.,  0.,  8.,  1.,  4.],
#          [ 2.,  0.,  3.,  4.,  0.,  5.,  1.,  4.]], grad_fn=<RoundBackward0>),
#  tensor([[2., 1., 8., 5., 0., 3., 1., 8.],
#          [2., 0., 8., 9., 0., 2., 2., 4.],
#          [2., 0., 5., 8., 0., 3., 2., 9.],
#          [2., 1., 4., 2., 0., 7., 0., 3.],
#          [2., 1., 9., 0., 0., 8., 0., 6.],
#          [1., 9., 5., 7., 0., 1., 0., 3.],
#          [1., 8., 0., 2., 0., 3., 1., 4.],
#          [2., 0., 9., 3., 1., 1., 1., 8.],
#          [1., 9., 6., 4., 1., 2., 1., 0.],
#          [1., 9., 0., 4., 0., 7., 0., 3.],
#          [2., 1., 6., 4., 0., 8., 1., 7.],
#          [2., 1., 8., 8., 0., 2., 2., 0.],
#          [2., 0., 8., 6., 0., 4., 0., 5.],
#          [2., 0., 8., 8., 0., 1., 1., 9.],
#          [1., 9., 0., 1., 0., 7., 2., 4.],
#          [1., 8., 0., 6., 0., 9., 1., 0.],
#          [1., 9., 3., 1., 0., 6., 1., 0.],
#          [2., 1., 5., 1., 0., 1., 2., 1.],
#          [2., 1., 6., 0., 1., 0., 1., 3.],
#          [2., 0., 9., 7., 1., 2., 2., 8.],
#          [1., 9., 7., 9., 1., 1., 1., 5.],
#          [1., 9., 1., 9., 0., 7., 1., 9.],
#          [1., 8., 0., 1., 0., 8., 2., 3.],
#          [1., 8., 0., 1., 0., 2., 1., 3.],
#          [1., 8., 9., 4., 0., 6., 0., 3.],
#          [1., 8., 9., 0., 0., 2., 2., 7.],
#          [2., 1., 2., 5., 0., 7., 2., 6.],
#          [1., 9., 4., 2., 0., 5., 1., 1.],
#          [2., 0., 0., 1., 0., 8., 0., 9.],
#          [2., 1., 2., 6., 1., 0., 2., 5.],
#          [1., 8., 5., 4., 0., 8., 1., 8.],
#          [2., 0., 4., 0., 0., 5., 2., 6.]]))

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.5599
#
#
# mean_absolute_error(y, yHat): 0.1127
#
# mean_absolute_error(yy, yHat_test): 0.1020
#
#
# mean_squared_error(y, yHat): 0.0340
#
# mean_squared_error(yy, yHat_test): 0.0238
#
#
# mean_squared_log_error(y, yHat): 0.0165
#
# mean_squared_log_error(yy, yHat_test): 0.0138
#
#
# RMSE(y, yHat): 0.1843
#
# RMSE(yy, yHat_test): 0.1544

# %%
# create a 1D smoothing filter
def smooth(x, k=15):
    return np.convolve(x, np.ones(k)/k, mode='same')

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss1.jpg", format='svg', bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.detach().T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc1.jpg", format='svg', bbox_inches='tight')


plt.show()

# %%
data.leap_year.value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
resampler = SMOTE(k_neighbors=20, random_state=0)

# %%
X_res, y_res = resampler.fit_resample(data[['day_code', 'month_code', 'decade', 'date_int']], data['leap_year'])

# %%
y_res.value_counts()
# Out:
# 0    110960
# 1    110960
# Name: leap_year, dtype: int64

# %%
data['leap_year'].value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 221915    1
# 221916    1
# 221917    1
# 221918    1
# 221919    1
# Name: leap_year, Length: 221920, dtype: int64

# %%
X_res
# Out:
#         day_code  month_code  decade  date_int
# 0              4           0     180  18000101
# 1              5           0     180  18010101
# 2              6           0     180  18020101
# 3              0           0     180  18030101
# 4              1           0     180  18040101
# ...          ...         ...     ...       ...
# 221915         0           5     188  18880618
# 221916         2           6     188  18840705
# 221917         5           2     218  21800323
# 221918         1           5     199  19960602
# 221919         1           4     219  21960520
#
# [221920 rows x 4 columns]

# %%
X_smote = X_res.assign(leap_year=y_res)

# %%
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221915         0           5     188  18880618          1
# 221916         2           6     188  18840705          1
# 221917         5           2     218  21800323          1
# 221918         1           5     199  19960602          1
# 221919         1           4     219  21960520          1
#
# [221920 rows x 5 columns]

# %% [markdown]
# Drop 220 decade

# %%
# data.decade.value_counts().plot(kind="bar")
X_smote.decade.value_counts().plot(kind="bar")

# %%
# data.decade.value_counts()[-5:]
X_smote.decade.value_counts()[-5:]
# Out:
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# 220     365
# Name: decade, dtype: int64

# %%
X_smote = X_smote.drop(X_smote.index[X_smote['decade'] == 220]).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221550         0           5     188  18880618          1
# 221551         2           6     188  18840705          1
# 221552         5           2     218  21800323          1
# 221553         1           5     199  19960602          1
# 221554         1           4     219  21960520          1
#
# [221555 rows x 5 columns]

# %%
X_smote.decade.value_counts().plot(kind="bar")

# %%
X_smote.decade.value_counts()[-5:]
# Out:
# 209    5174
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# Name: decade, dtype: int64

# %% [markdown]
# code is required to only work for dates in the range  [ 1-1-1800 to 31-12-2200 ]

# %%
X_smote.date_int.max()
# Out:
# 21991231

# %%
datetime.datetime.strptime(str(X_smote.date_int.max()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '31-12-2199'

# %%
X_smote.date_int.min()
# Out:
# 18000101

# %%
datetime.datetime.strptime(str(X_smote.date_int.min()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '01-01-1800'

# %%
Y_smote = X_smote['date_int']
Y_smote
# Out:
# 0         18000101
# 1         18010101
# 2         18020101
# 3         18030101
# 4         18040101
#             ...
# 221550    18880618
# 221551    18840705
# 221552    21800323
# 221553    19960602
# 221554    21960520
# Name: date_int, Length: 221555, dtype: int64

# %%
X_smote = X_smote.drop('date_int', axis=1).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  leap_year
# 0              4           0     180          0
# 1              5           0     180          0
# 2              6           0     180          0
# 3              0           0     180          0
# 4              1           0     180          1
# ...          ...         ...     ...        ...
# 221550         0           5     188          1
# 221551         2           6     188          1
# 221552         5           2     218          1
# 221553         1           5     199          1
# 221554         1           4     219          1
#
# [221555 rows x 4 columns]

# %%
Y_smote = Y_smote.reset_index(drop=True)

ls = []

for s in Y_smote.astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(Y_smote)), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y_smote = ll.values / 9

Y_smote
# Out:
# array([[0.11111111, 0.88888889, 0.        , ..., 0.11111111, 0.        ,
#         0.11111111],
#        [0.11111111, 0.88888889, 0.        , ..., 0.11111111, 0.        ,
#         0.11111111],
#        [0.11111111, 0.88888889, 0.        , ..., 0.11111111, 0.        ,
#         0.11111111],
#        ...,
#        [0.22222222, 0.11111111, 0.88888889, ..., 0.33333333, 0.22222222,
#         0.33333333],
#        [0.11111111, 1.        , 1.        , ..., 0.66666667, 0.        ,
#         0.22222222],
#        [0.22222222, 0.11111111, 1.        , ..., 0.55555556, 0.22222222,
#         0.        ]])

# %%
# data.index[data['leap_year'] == 1].tolist()
# data.index[data['leap_year'] == 1]

# %%
# for i,idx in enumerate(data['leap_year'].tolist()):
#     print(i, idx)

# %% [markdown]
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1 <---
# 5 0
# 6 0
# 7 0
# 8 1 <---
# 9 0
# 10 0
# 11 0
# 12 1 <---
# 13 0
# 14 0
# 15 0
# 16 1 <---
# 17 0
# 18 0
# 19 0
# 20 1 <---
# 21 0
# 22 0
# 23 0
# 24 1 <---
# 25 0
# 26 0
# 27 0
# 28 1 <---
# 29 0
# 30 0

# %%
scaler_day_smote = RobustScaler()

x = X_smote.day_code.values.reshape(-1, 1)

X_smote['day_scaled'] = scaler_day_smote.fit_transform(x).flatten()

# %%
X_smote['day_sin'] = np.sin(X_smote['day_code'] * (2 * np.pi / 7))
X_smote['day_cos'] = np.cos(X_smote['day_code'] * (2 * np.pi / 7))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos
# 0      -0.900969
# 1      -0.222521
# 2       0.623490
# 3       1.000000
# 4       0.623490
# ...          ...
# 221550  1.000000
# 221551 -0.222521
# 221552 -0.222521
# 221553  0.623490
# 221554  0.623490
#
# [221555 rows x 7 columns]

# %%
scaler_month_smote = RobustScaler()

x = X_smote.month_code.values.reshape(-1, 1)

X_smote['month_scaled'] = scaler_month_smote.fit_transform(x).flatten()

# %%
X_smote['month_sin'] = np.sin(X_smote['month_code'] * (2 * np.pi / 12))
X_smote['month_cos'] = np.cos(X_smote['month_code'] * (2 * np.pi / 12))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos
# 0      -0.900969     -1.000000  0.000000e+00   1.000000
# 1      -0.222521     -1.000000  0.000000e+00   1.000000
# 2       0.623490     -1.000000  0.000000e+00   1.000000
# 3       1.000000     -1.000000  0.000000e+00   1.000000
# 4       0.623490     -1.000000  0.000000e+00   1.000000
# ...          ...           ...           ...        ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000
#
# [221555 rows x 10 columns]

# %%
scaler_decade_smote = RobustScaler()

x = X_smote.decade.values.reshape(-1, 1)

X_smote['decade_scaled'] = scaler_decade_smote.fit_transform(x).flatten()

# %%
# alpha_smote = len(X_smote.decade.unique())
alpha_smote = (X_smote.decade.iloc[-1] - X_smote.decade.iloc[0]) + 1

X_smote['decade_sin'] = np.sin(X_smote['decade'] * (2 * np.pi / alpha_smote))
X_smote['decade_cos'] = np.cos(X_smote['decade'] * (2 * np.pi / alpha_smote))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos  decade_scaled  \
# 0      -0.900969     -1.000000  0.000000e+00   1.000000      -1.052632
# 1      -0.222521     -1.000000  0.000000e+00   1.000000      -1.052632
# 2       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# 3       1.000000     -1.000000  0.000000e+00   1.000000      -1.052632
# 4       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# ...          ...           ...           ...        ...            ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025      -0.631579
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000      -0.631579
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000       0.947368
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025      -0.052632
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000       1.000000
#
#           decade_sin  decade_cos
# 0       1.102182e-15   -1.000000
# 1       1.102182e-15   -1.000000
# 2       1.102182e-15   -1.000000
# 3       1.102182e-15   -1.000000
# 4       1.102182e-15   -1.000000
# ...              ...         ...
# 221550 -9.510565e-01   -0.309017
# 221551 -9.510565e-01   -0.309017
# 221552  3.090170e-01   -0.951057
# 221553 -1.564345e-01    0.987688
# 221554  1.564345e-01   -0.987688
#
# [221555 rows x 13 columns]

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
X = X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 3.33333333e-01, -4.33883739e-01, -9.00968868e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 1.00000000e+00, -7.81831482e-01,  6.23489802e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        ...,
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#          9.47368421e-01,  3.09016994e-01, -9.51056516e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#         -5.26315789e-02, -1.56434465e-01,  9.87688341e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#          1.00000000e+00,  1.56434465e-01, -9.87688341e-01]])

# %%
X.shape
# Out:
# (221555, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()
# Y = data['date_normalized'].values.reshape(-1, 1)
Y = Y_smote


Y
# Out:
# array([[0.11111111, 0.88888889, 0.        , ..., 0.11111111, 0.        ,
#         0.11111111],
#        [0.11111111, 0.88888889, 0.        , ..., 0.11111111, 0.        ,
#         0.11111111],
#        [0.11111111, 0.88888889, 0.        , ..., 0.11111111, 0.        ,
#         0.11111111],
#        ...,
#        [0.22222222, 0.11111111, 0.88888889, ..., 0.33333333, 0.22222222,
#         0.33333333],
#        [0.11111111, 1.        , 1.        , ..., 0.66666667, 0.        ,
#         0.22222222],
#        [0.22222222, 0.11111111, 1.        , ..., 0.55555556, 0.22222222,
#         0.        ]])

# %%
Y.shape
# Out:
# (221555, 8)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64

train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (221555, 10)
#
# Y: (221555, 8)
#
# Train data:   (155088, 10)
#
# Train labels: (155088, 8)
#
# Test data:    (66467, 10)
#
# Test labels:  (66467, 8)

# %%
model_smote = Model().to(device)

# %%
numepochs = 120

trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model_smote, numepochs)
# Out:
# Epoch 1/120, Train Loss: 0.149914, Test Loss: 0.149914
# Epoch 2/120, Train Loss: 0.140546, Test Loss: 0.140546
# Epoch 3/120, Train Loss: 0.134377, Test Loss: 0.134377
# Epoch 4/120, Train Loss: 0.140379, Test Loss: 0.140379
# Epoch 5/120, Train Loss: 0.133322, Test Loss: 0.133322
# Epoch 6/120, Train Loss: 0.149382, Test Loss: 0.149382
# Epoch 7/120, Train Loss: 0.141045, Test Loss: 0.141045
# Epoch 8/120, Train Loss: 0.142109, Test Loss: 0.142109
# Epoch 9/120, Train Loss: 0.151387, Test Loss: 0.151387
# Epoch 10/120, Train Loss: 0.151704, Test Loss: 0.151704
# Epoch 11/120, Train Loss: 0.148363, Test Loss: 0.148363
# Epoch 12/120, Train Loss: 0.140873, Test Loss: 0.140873
# Epoch 13/120, Train Loss: 0.138007, Test Loss: 0.138007
# Epoch 14/120, Train Loss: 0.128750, Test Loss: 0.128750
# Epoch 15/120, Train Loss: 0.141371, Test Loss: 0.141371
# Epoch 16/120, Train Loss: 0.141189, Test Loss: 0.141189
# Epoch 17/120, Train Loss: 0.154296, Test Loss: 0.154296
# Epoch 18/120, Train Loss: 0.141765, Test Loss: 0.141765
# Epoch 19/120, Train Loss: 0.128823, Test Loss: 0.128823
# Epoch 20/120, Train Loss: 0.156797, Test Loss: 0.156797
# Epoch 21/120, Train Loss: 0.142228, Test Loss: 0.142228
# Epoch 22/120, Train Loss: 0.138823, Test Loss: 0.138823
# Epoch 23/120, Train Loss: 0.138897, Test Loss: 0.138897
# Epoch 24/120, Train Loss: 0.136885, Test Loss: 0.136885
# Epoch 25/120, Train Loss: 0.145750, Test Loss: 0.145750
# Epoch 26/120, Train Loss: 0.148708, Test Loss: 0.148708
# Epoch 27/120, Train Loss: 0.134557, Test Loss: 0.134557
# Epoch 28/120, Train Loss: 0.137934, Test Loss: 0.137934
# Epoch 29/120, Train Loss: 0.135316, Test Loss: 0.135316
# Epoch 30/120, Train Loss: 0.138992, Test Loss: 0.138992
# Epoch 31/120, Train Loss: 0.144779, Test Loss: 0.144779
# Epoch 32/120, Train Loss: 0.158042, Test Loss: 0.158042
# Epoch 33/120, Train Loss: 0.139071, Test Loss: 0.139071
# Epoch 34/120, Train Loss: 0.135604, Test Loss: 0.135604
# Epoch 35/120, Train Loss: 0.132715, Test Loss: 0.132715
# Epoch 36/120, Train Loss: 0.144846, Test Loss: 0.144846
# Epoch 37/120, Train Loss: 0.143002, Test Loss: 0.143002
# Epoch 38/120, Train Loss: 0.140697, Test Loss: 0.140697
# Epoch 39/120, Train Loss: 0.136452, Test Loss: 0.136452
# Epoch 40/120, Train Loss: 0.130118, Test Loss: 0.130118
# Epoch 41/120, Train Loss: 0.133656, Test Loss: 0.133656
# Epoch 42/120, Train Loss: 0.134420, Test Loss: 0.134420
# Epoch 43/120, Train Loss: 0.134727, Test Loss: 0.134727
# Epoch 44/120, Train Loss: 0.138124, Test Loss: 0.138124
# Epoch 45/120, Train Loss: 0.145368, Test Loss: 0.145368
# Epoch 46/120, Train Loss: 0.146720, Test Loss: 0.146720
# Epoch 47/120, Train Loss: 0.142590, Test Loss: 0.142590
# Epoch 48/120, Train Loss: 0.143532, Test Loss: 0.143532
# Epoch 49/120, Train Loss: 0.144778, Test Loss: 0.144778
# Epoch 50/120, Train Loss: 0.153759, Test Loss: 0.153759
# Epoch 51/120, Train Loss: 0.143065, Test Loss: 0.143065
# Epoch 52/120, Train Loss: 0.140974, Test Loss: 0.140974
# Epoch 53/120, Train Loss: 0.138024, Test Loss: 0.138024
# Epoch 54/120, Train Loss: 0.145649, Test Loss: 0.145649
# Epoch 55/120, Train Loss: 0.134723, Test Loss: 0.134723
# Epoch 56/120, Train Loss: 0.134004, Test Loss: 0.134004
# Epoch 57/120, Train Loss: 0.139064, Test Loss: 0.139064
# Epoch 58/120, Train Loss: 0.136315, Test Loss: 0.136315
# Epoch 59/120, Train Loss: 0.152246, Test Loss: 0.152246
# Epoch 60/120, Train Loss: 0.139249, Test Loss: 0.139249
# Epoch 61/120, Train Loss: 0.146559, Test Loss: 0.146559
# Epoch 62/120, Train Loss: 0.144219, Test Loss: 0.144219
# Epoch 63/120, Train Loss: 0.155560, Test Loss: 0.155560
# Epoch 64/120, Train Loss: 0.160306, Test Loss: 0.160306
# Epoch 65/120, Train Loss: 0.148812, Test Loss: 0.148812
# Epoch 66/120, Train Loss: 0.156905, Test Loss: 0.156905
# Epoch 67/120, Train Loss: 0.141125, Test Loss: 0.141125
# Epoch 68/120, Train Loss: 0.134006, Test Loss: 0.134006
# Epoch 69/120, Train Loss: 0.142416, Test Loss: 0.142416
# Epoch 70/120, Train Loss: 0.126419, Test Loss: 0.126419
# Epoch 71/120, Train Loss: 0.129719, Test Loss: 0.129719
# Epoch 72/120, Train Loss: 0.143714, Test Loss: 0.143714
# Epoch 73/120, Train Loss: 0.152191, Test Loss: 0.152191
# Epoch 74/120, Train Loss: 0.137787, Test Loss: 0.137787
# Epoch 75/120, Train Loss: 0.148231, Test Loss: 0.148231
# Epoch 76/120, Train Loss: 0.137986, Test Loss: 0.137986
# Epoch 77/120, Train Loss: 0.141131, Test Loss: 0.141131
# Epoch 78/120, Train Loss: 0.143642, Test Loss: 0.143642
# Epoch 79/120, Train Loss: 0.126247, Test Loss: 0.126247
# Epoch 80/120, Train Loss: 0.155709, Test Loss: 0.155709
# Epoch 81/120, Train Loss: 0.144700, Test Loss: 0.144700
# Epoch 82/120, Train Loss: 0.161998, Test Loss: 0.161998
# Epoch 83/120, Train Loss: 0.138396, Test Loss: 0.138396
# Epoch 84/120, Train Loss: 0.134938, Test Loss: 0.134938
# Epoch 85/120, Train Loss: 0.132979, Test Loss: 0.132979
# Epoch 86/120, Train Loss: 0.163681, Test Loss: 0.163681
# Epoch 87/120, Train Loss: 0.138389, Test Loss: 0.138389
# Epoch 88/120, Train Loss: 0.154643, Test Loss: 0.154643
# Epoch 89/120, Train Loss: 0.145286, Test Loss: 0.145286
# Epoch 90/120, Train Loss: 0.144789, Test Loss: 0.144789
# Epoch 91/120, Train Loss: 0.131082, Test Loss: 0.131082
# Epoch 92/120, Train Loss: 0.145678, Test Loss: 0.145678
# Epoch 93/120, Train Loss: 0.156193, Test Loss: 0.156193
# Epoch 94/120, Train Loss: 0.142036, Test Loss: 0.142036
# Epoch 95/120, Train Loss: 0.137736, Test Loss: 0.137736
# Epoch 96/120, Train Loss: 0.151377, Test Loss: 0.151377
# Epoch 97/120, Train Loss: 0.130320, Test Loss: 0.130320
# Epoch 98/120, Train Loss: 0.152469, Test Loss: 0.152469
# Epoch 99/120, Train Loss: 0.165036, Test Loss: 0.165036
# Epoch 100/120, Train Loss: 0.147175, Test Loss: 0.147175
# Epoch 101/120, Train Loss: 0.147827, Test Loss: 0.147827
# Epoch 102/120, Train Loss: 0.154323, Test Loss: 0.154323
# Epoch 103/120, Train Loss: 0.148368, Test Loss: 0.148368
# Epoch 104/120, Train Loss: 0.157078, Test Loss: 0.157078
# Epoch 105/120, Train Loss: 0.135940, Test Loss: 0.135940
# Epoch 106/120, Train Loss: 0.138351, Test Loss: 0.138351
# Epoch 107/120, Train Loss: 0.151211, Test Loss: 0.151211
# Epoch 108/120, Train Loss: 0.136947, Test Loss: 0.136947
# Epoch 109/120, Train Loss: 0.147910, Test Loss: 0.147910
# Epoch 110/120, Train Loss: 0.137042, Test Loss: 0.137042
# Epoch 111/120, Train Loss: 0.144579, Test Loss: 0.144579
# Epoch 112/120, Train Loss: 0.139093, Test Loss: 0.139093
# Epoch 113/120, Train Loss: 0.148293, Test Loss: 0.148293
# Epoch 114/120, Train Loss: 0.137328, Test Loss: 0.137328
# Epoch 115/120, Train Loss: 0.148086, Test Loss: 0.148086
# Epoch 116/120, Train Loss: 0.137059, Test Loss: 0.137059
# Epoch 117/120, Train Loss: 0.130918, Test Loss: 0.130918
# Epoch 118/120, Train Loss: 0.136765, Test Loss: 0.136765
# Epoch 119/120, Train Loss: 0.140129, Test Loss: 0.140129
# Epoch 120/120, Train Loss: 0.152096, Test Loss: 0.152096

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([0.1240, 0.1143, 0.1140, 0.1137, 0.1137, 0.1136, 0.1137, 0.1136, 0.1136,
#          0.1138, 0.1137, 0.1137, 0.1136, 0.1136, 0.1137, 0.1137, 0.1138, 0.1137,
#          0.1137, 0.1138, 0.1139, 0.1137, 0.1138, 0.1139, 0.1139, 0.1140, 0.1140,
#          0.1139, 0.1140, 0.1140, 0.1139, 0.1140, 0.1139, 0.1139, 0.1141, 0.1140,
#          0.1140, 0.1141, 0.1141, 0.1140, 0.1140, 0.1141, 0.1141, 0.1141, 0.1140,
#          0.1141, 0.1141, 0.1140, 0.1141, 0.1141, 0.1141, 0.1141, 0.1139, 0.1140,
#          0.1140, 0.1142, 0.1141, 0.1142, 0.1141, 0.1141, 0.1141, 0.1142, 0.1141,
#          0.1142, 0.1141, 0.1142, 0.1141, 0.1142, 0.1141, 0.1141, 0.1142, 0.1142,
#          0.1141, 0.1141, 0.1140, 0.1141, 0.1141, 0.1142, 0.1141, 0.1141, 0.1142,
#          0.1143, 0.1143, 0.1142, 0.1143, 0.1142, 0.1143, 0.1142, 0.1143, 0.1142,
#          0.1143, 0.1142, 0.1142, 0.1144, 0.1142, 0.1143, 0.1143, 0.1143, 0.1143,
#          0.1144, 0.1143, 0.1143, 0.1143, 0.1144, 0.1144, 0.1142, 0.1143, 0.1142,
#          0.1144, 0.1143, 0.1143, 0.1144, 0.1143, 0.1144, 0.1144, 0.1143, 0.1143,
#          0.1143, 0.1144, 0.1144]),
#  tensor([0.1499, 0.1405, 0.1344, 0.1404, 0.1333, 0.1494, 0.1410, 0.1421, 0.1514,
#          0.1517, 0.1484, 0.1409, 0.1380, 0.1288, 0.1414, 0.1412, 0.1543, 0.1418,
#          0.1288, 0.1568, 0.1422, 0.1388, 0.1389, 0.1369, 0.1457, 0.1487, 0.1346,
#          0.1379, 0.1353, 0.1390, 0.1448, 0.1580, 0.1391, 0.1356, 0.1327, 0.1448,
#          0.1430, 0.1407, 0.1365, 0.1301, 0.1337, 0.1344, 0.1347, 0.1381, 0.1454,
#          0.1467, 0.1426, 0.1435, 0.1448, 0.1538, 0.1431, 0.1410, 0.1380, 0.1456,
#          0.1347, 0.1340, 0.1391, 0.1363, 0.1522, 0.1392, 0.1466, 0.1442, 0.1556,
#          0.1603, 0.1488, 0.1569, 0.1411, 0.1340, 0.1424, 0.1264, 0.1297, 0.1437,
#          0.1522, 0.1378, 0.1482, 0.1380, 0.1411, 0.1436, 0.1262, 0.1557, 0.1447,
#          0.1620, 0.1384, 0.1349, 0.1330, 0.1637, 0.1384, 0.1546, 0.1453, 0.1448,
#          0.1311, 0.1457, 0.1562, 0.1420, 0.1377, 0.1514, 0.1303, 0.1525, 0.1650,
#          0.1472, 0.1478, 0.1543, 0.1484, 0.1571, 0.1359, 0.1384, 0.1512, 0.1369,
#          0.1479, 0.1370, 0.1446, 0.1391, 0.1483, 0.1373, 0.1481, 0.1371, 0.1309,
#          0.1368, 0.1401, 0.1521]),
#  tensor([0.4034, 0.5076, 0.5101, 0.5106, 0.5108, 0.5117, 0.5111, 0.5114, 0.5115,
#          0.5102, 0.5116, 0.5119, 0.5122, 0.5119, 0.5118, 0.5118, 0.5114, 0.5120,
#          0.5113, 0.5111, 0.5107, 0.5111, 0.5106, 0.5108, 0.5104, 0.5102, 0.5102,
#          0.5100, 0.5102, 0.5101, 0.5104, 0.5107, 0.5104, 0.5103, 0.5091, 0.5099,
#          0.5090, 0.5089, 0.5094, 0.5096, 0.5102, 0.5095, 0.5092, 0.5096, 0.5098,
#          0.5089, 0.5083, 0.5091, 0.5094, 0.5091, 0.5089, 0.5092, 0.5106, 0.5095,
#          0.5102, 0.5083, 0.5086, 0.5089, 0.5103, 0.5092, 0.5086, 0.5089, 0.5086,
#          0.5089, 0.5092, 0.5086, 0.5093, 0.5082, 0.5090, 0.5094, 0.5088, 0.5079,
#          0.5091, 0.5097, 0.5098, 0.5094, 0.5103, 0.5090, 0.5092, 0.5091, 0.5082,
#          0.5080, 0.5086, 0.5083, 0.5080, 0.5093, 0.5076, 0.5083, 0.5083, 0.5082,
#          0.5075, 0.5098, 0.5094, 0.5082, 0.5091, 0.5076, 0.5079, 0.5082, 0.5076,
#          0.5067, 0.5066, 0.5087, 0.5085, 0.5076, 0.5070, 0.5086, 0.5081, 0.5092,
#          0.5079, 0.5093, 0.5079, 0.5076, 0.5073, 0.5069, 0.5072, 0.5088, 0.5072,
#          0.5085, 0.5075, 0.5066]))

# %%
# (yy * data['date_int'].max()).round()

# %%
# (yHat_test * data['date_int'].max()).round()

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.5416
#
#
# mean_absolute_error(y, yHat): 0.1107
#
# mean_absolute_error(yy, yHat_test): 0.1521
#
#
# mean_squared_error(y, yHat): 0.0302
#
# mean_squared_error(yy, yHat_test): 0.0498
#
#
# mean_squared_log_error(y, yHat): 0.0137
#
# mean_squared_log_error(yy, yHat_test): 0.0268
#
#
# RMSE(y, yHat): 0.1738
#
# RMSE(yy, yHat_test): 0.2232

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss2.jpg", format='svg', bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.detach().T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc2.jpg", format='svg', bbox_inches='tight')


plt.show()

# %%
['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']
# Out:
# ['day_scaled',
#  'day_sin',
#  'day_cos',
#  'month_scaled',
#  'month_sin',
#  'month_cos',
#  'leap_year',
#  'decade_scaled',
#  'decade_sin',
#  'decade_cos']

# %%
def result_to_date(result):
    
    result = str(result)
    
    day   = int(result[6:]) - 1
    month = int(result[4:6]) - 1

    ss = str(f'{result[:4]}0101')
    
    ds = datetime.datetime.strptime(ss, '%Y%m%d')
    
    ds = ds + relativedelta(months=month, days=day)

    result = ds.strftime('%d-%m-%Y')
    
    
    return result

# %%
# (16830739, 17848869)
result_to_date(16830739), result_to_date(17848869)
# Out:
# ('08-08-1683', '08-06-1791')

# %%
def test_model(input_list):
    

    X       = np.zeros((1, 10))
    X_smote = np.zeros((1, 10))



    day       = np.array(map_day[input_list[0]])
    month     = np.array(map_month[input_list[1]])
    leap_year = map_leap_year[input_list[2]]
    decade    = np.array(input_list[3].strip('[]')).astype('int64')


    X[0, 0] = scaler_day.transform(day.reshape(-1, 1)).flatten()
    X[0, 1] = np.sin(day * (2 * np.pi / 7))
    X[0, 2] = np.cos(day * (2 * np.pi / 7))

    X[0, 3] = scaler_month.transform(month.reshape(-1, 1)).flatten()
    X[0, 4] = np.sin(month * (2 * np.pi / 12))
    X[0, 5] = np.cos(month * (2 * np.pi / 12))

    X[0, 6] = leap_year

    X[0, 7] = scaler_decade.transform(decade.reshape(-1, 1)).flatten()
    X[0, 8] = np.sin(decade * (2 * np.pi / alpha))
    X[0, 9] = np.cos(decade * (2 * np.pi / alpha))

    # ---

    X_smote[0, 0] = scaler_day_smote.transform(day.reshape(-1, 1)).flatten()
    X_smote[0, 1] = X[0, 1]
    X_smote[0, 2] = X[0, 2]

    X_smote[0, 3] = scaler_month_smote.transform(month.reshape(-1, 1)).flatten()
    X_smote[0, 4] = X[0, 4]
    X_smote[0, 5] = X[0, 5]

    X_smote[0, 6] = leap_year

    X_smote[0, 7] = scaler_decade_smote.transform(decade.reshape(-1, 1)).flatten()
    X_smote[0, 8] = np.sin(decade * (2 * np.pi / alpha_smote))
    X_smote[0, 9] = np.cos(decade * (2 * np.pi / alpha_smote))


    # ---

    result       = model(torch.tensor(X).to(device).float()) * 9
    result_smote = model_smote(torch.tensor(X_smote).to(device).float()) * 9


    # ---


    result       = ''.join(result.detach().cpu().numpy().round().astype(int).astype(str).flatten())
    result_smote = ''.join(result_smote.detach().cpu().numpy().round().astype(int).astype(str).flatten())


    
    return result_to_date(result), result_to_date(result_smote)

# %%
input_test1 = ['[MON]', '[DEC]', '[False]', '[196]']
output_test1 = '3-12-1962'

input_test2 = ['[THU]', '[DEC]', '[True]', '[204]']
output_test2 = '3-12-2048'

input_test3 = ['[WED]', '[JAN]', '[False]', '[181]']
output_test3 = '10-1-1810'


input_test4 = ['[WED]', '[JUN]', '[False]', '[209]']

# %%
test_model(input_test1), test_model(input_test2), test_model(input_test3), test_model(input_test4)
# Out:
# (('14-12-1964', '15-12-1864'),
#  ('14-12-2054', '14-12-2054'),
#  ('14-01-1824', '14-01-1814'),
#  ('14-06-2074', '14-06-2074'))

# %%
output_test1, output_test2, output_test3
# Out:
# ('3-12-1962', '3-12-2048', '10-1-1810')

# %%
# example_input = pd.read_csv('../../data/example_input.txt', sep=' ', header=None)
example_input = pd.read_csv('example_input.txt', sep=' ', header=None)


example_input.columns = ['day', 'month', 'leap_year', 'decade']

# %%
example_input
# Out:
#         day  month leap_year decade
# 0     [WED]  [JAN]   [False]  [180]
# 1     [MON]  [JAN]   [False]  [190]
# 2     [SAT]  [JAN]    [True]  [200]
# 3     [FRI]  [JAN]   [False]  [210]
# 4     [WED]  [JAN]   [False]  [220]
# ...     ...    ...       ...    ...
# 1460  [MON]  [OCT]    [True]  [214]
# 1461  [TUE]  [DEC]   [False]  [183]
# 1462  [SUN]  [DEC]   [False]  [193]
# 1463  [SAT]  [DEC]   [False]  [203]
# 1464  [THU]  [DEC]   [False]  [213]
#
# [1465 rows x 4 columns]

# %%
R       = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result'])
R_smote = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result_smote'])

# %%
example_input.iloc[0].tolist()
# Out:
# ['[WED]', '[JAN]', '[False]', '[180]']

# %%
for i in range(len(example_input)):
    R.iloc[i], R_smote.iloc[i] = test_model(example_input.iloc[i].tolist())

# %%
R
# Out:
#           result
# 0     14-01-1824
# 1     14-01-1824
# 2     14-01-2024
# 3     14-01-2124
# 4     14-01-2194
# ...          ...
# 1460  14-10-2144
# 1461  14-12-1834
# 1462  14-12-1834
# 1463  14-12-2034
# 1464  14-12-2134
#
# [1465 rows x 1 columns]

# %%
final = pd.concat([example_input, R], axis=1)
final
# Out:
#         day  month leap_year decade      result
# 0     [WED]  [JAN]   [False]  [180]  14-01-1824
# 1     [MON]  [JAN]   [False]  [190]  14-01-1824
# 2     [SAT]  [JAN]    [True]  [200]  14-01-2024
# 3     [FRI]  [JAN]   [False]  [210]  14-01-2124
# 4     [WED]  [JAN]   [False]  [220]  14-01-2194
# ...     ...    ...       ...    ...         ...
# 1460  [MON]  [OCT]    [True]  [214]  14-10-2144
# 1461  [TUE]  [DEC]   [False]  [183]  14-12-1834
# 1462  [SUN]  [DEC]   [False]  [193]  14-12-1834
# 1463  [SAT]  [DEC]   [False]  [203]  14-12-2034
# 1464  [THU]  [DEC]   [False]  [213]  14-12-2134
#
# [1465 rows x 5 columns]

# %%
final_smote = pd.concat([example_input, R_smote], axis=1)
final_smote
# Out:
#         day  month leap_year decade result_smote
# 0     [WED]  [JAN]   [False]  [180]   15-01-1814
# 1     [MON]  [JAN]   [False]  [190]   15-01-1814
# 2     [SAT]  [JAN]    [True]  [200]   14-01-2024
# 3     [FRI]  [JAN]   [False]  [210]   14-01-2114
# 4     [WED]  [JAN]   [False]  [220]   14-01-2184
# ...     ...    ...       ...    ...          ...
# 1460  [MON]  [OCT]    [True]  [214]   14-10-2144
# 1461  [TUE]  [DEC]   [False]  [183]   14-12-1834
# 1462  [SUN]  [DEC]   [False]  [193]   14-12-1824
# 1463  [SAT]  [DEC]   [False]  [203]   14-12-2044
# 1464  [THU]  [DEC]   [False]  [213]   14-12-2144
#
# [1465 rows x 5 columns]

# %%
final.to_csv('output_file.txt', sep=' ', header=None, index=False)

# %%
final_smote.to_csv('output_file_smote.txt', sep=' ', header=None, index=False)

# %% [markdown]
# Out-liers

# %% [markdown]
# Saving

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              'model_smote_state_dict': model_smote.state_dict(),
              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              'scaler_day_smote' : scaler_day_smote,
              'scaler_month_smote' : scaler_month_smote,
              'scaler_decade_smote' : scaler_decade_smote}


torch.save(checkpoint, 'checkpoint.pth.tar')

# %%
# checkpoint = torch.load('checkpoint.pth.tar')

# %%
# model       = Model()
# model_smote = Model()


# model.load_state_dict(checkpoint['model_state_dict'])
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
