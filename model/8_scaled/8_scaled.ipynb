# %%
import datetime

import copy

import random


from dateutil.relativedelta import relativedelta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('seaborn')
# plt.style.use(['dark_background', 'ggplot'])

import seaborn as sns
# sns.set()

# import scipy
# import scipy.stats as stats


# # sympy = symbolic math in Python
# import sympy as sym
# import sympy.plotting.plot as symplot


# make the equations look nicer

# from IPython.display import display
# display.set_matplotlib_formats('svg') # Deprecated since version 7.23

# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


# %config InlineBackend.set_matplotlib_formats = ["svg"]
# %config InlineBackend.figure_formats = ["svg"]

# %%
import sklearn


from sklearn.model_selection import train_test_split


# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler     # <------------ (-1.0, 1.0)
# from sklearn.preprocessing import MinMaxScaler


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from imblearn.over_sampling import SMOTE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset, DataLoader





torch.__version__
# Out:
# '1.12.0+cu113'

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def print_score(shape, yHat, y, yHat_test, yy):
    
    
    n, p = shape
    
    R2 = r2_score(y, yHat)
    
    Adj_r2 = 1 - (1 - R2)  *  (n - 1) / (n - p - 1)
    
    print(f'Adjusted R-Squared(y, yHat): {Adj_r2:0.4f}\n\n')
    # r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
    #  R^2 score is not well-defined with less than two samples
    
    
    print(f'mean_absolute_error(y, yHat):',
          f'{mean_absolute_error(y, yHat):0.4f}\n')
    print(f'mean_absolute_error(yy, yHat_test):',
          f'{mean_absolute_error(yy, yHat_test):0.4f}\n\n')
    
    
    print(f'mean_squared_error(y, yHat):',
          f'{mean_squared_error(y, yHat):0.4f}\n')
    print(f'mean_squared_error(yy, yHat_test):',
          f'{mean_squared_error(yy, yHat_test):0.4f}\n\n')
    
    
    print(f'mean_squared_log_error(y, yHat):',
          f'{mean_squared_log_error(y, yHat):0.4f}\n')
    print(f'mean_squared_log_error(yy, yHat_test):',
          f'{mean_squared_log_error(yy, yHat_test):0.4f}\n\n')
    
    
    
    print(f'RMSE(y, yHat):',
          f'{np.sqrt( mean_squared_error(y, yHat) ):0.4f}\n')
    print(f'RMSE(yy, yHat_test):',
          f'{np.sqrt( mean_squared_error(yy, yHat_test) ):0.4f}\n\n')

# %%
# date = np.datetime64("2000-01-01")
# date_strings = date.astype(str).split('-'). 
# # >> ['2000', '01', '01']

# year_int = int(date_strings[0])

# %%
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Out:
# --2022-08-05 13:57:21--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5230713 (5.0M) [text/plain]
# Saving to: ‘data.txt’
#
# data.txt            100%[===================>]   4.99M  --.-KB/s    in 0.1s
#
# 2022-08-05 13:57:21 (35.7 MB/s) - ‘data.txt’ saved [5230713/5230713]
#
# --2022-08-05 13:57:21--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37732 (37K) [text/plain]
# Saving to: ‘example_input.txt’
#
# example_input.txt   100%[===================>]  36.85K  --.-KB/s    in 0.007s
#
# 2022-08-05 13:57:21 (4.80 MB/s) - ‘example_input.txt’ saved [37732/37732]

# %%
# !ls
# Out:
# data.txt  example_input.txt  sample_data

# %% [markdown]
# 'text.txt'

# %% [markdown]
# [ 1-1-1800 to 31-12-2200 ]

# %% [markdown]
# [day condition] [month condition] [leap year condition] [decade condition] date

# %% [markdown]
# [MON] [DEC] [False] [196] 3-12-1962
# [THU] [DEC] [True] [204] 3-12-2048
# [WED] [JAN] [False] [181] 10-1-1810

# %%
# data = np.loadtxt(open('text.txt','r'),delimiter=' ')
# ori = pd.read_csv('../../data/data.txt', sep=' ', header=None)

ori = pd.read_csv('data.txt', sep=' ', header=None)

# %%
ori.columns = ['day', 'month', 'leap_year', 'decade', 'date']

# %%
ori
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
# data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)
# # pd.to_datetime(data.date, infer_datetime_format=False)

# %%
ori.dtypes
# Out:
# day          object
# month        object
# leap_year    object
# decade       object
# date         object
# dtype: object

# %%
# data_backup = copy.deepcopy(ori)
data = copy.deepcopy(ori)

# %%
data
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
data.date
# Out:
# 0           1-1-1800
# 1           1-1-1801
# 2           1-1-1802
# 3           1-1-1803
# 4           1-1-1804
#              ...
# 146457    31-12-2196
# 146458    31-12-2197
# 146459    31-12-2198
# 146460    31-12-2199
# 146461    31-12-2200
# Name: date, Length: 146462, dtype: object

# %%
# # data['date'] = pd.date_range('3-12-2048', periods=10)
# # data['date'] = pd.date_range('12-3-1962', periods=10)

# # 1-1-1800 to 31-12-2200
# data['date'] = pd.date_range(start='1-1-1800',end='12-31-2200')


data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)

# # data.date = data.date.dt.strftime('%d-%m-%Y')
# # data.date = pd.to_datetime(data.date.dt.strftime('%d-%m-%Y'), format='%d-%m-%Y', infer_datetime_format=False)

# %%
data.dtypes
# Out:
# day                  object
# month                object
# leap_year            object
# decade               object
# date         datetime64[ns]
# dtype: object

# %%
data
# Out:
#           day  month leap_year decade       date
# 0       [WED]  [JAN]   [False]  [180] 1800-01-01
# 1       [THU]  [JAN]   [False]  [180] 1801-01-01
# 2       [FRI]  [JAN]   [False]  [180] 1802-01-01
# 3       [SAT]  [JAN]   [False]  [180] 1803-01-01
# 4       [SUN]  [JAN]    [True]  [180] 1804-01-01
# ...       ...    ...       ...    ...        ...
# 146457  [SAT]  [DEC]    [True]  [219] 2196-12-31
# 146458  [SUN]  [DEC]   [False]  [219] 2197-12-31
# 146459  [MON]  [DEC]   [False]  [219] 2198-12-31
# 146460  [TUE]  [DEC]   [False]  [219] 2199-12-31
# 146461  [WED]  [DEC]   [False]  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %%
map_leap_year = {'[False]': int(0), '[True]' : int(1)}

data.leap_year = data.leap_year.map(map_leap_year)

# data.leap_year = data.leap_year.astype(np.float64)

# %%
data
# Out:
#           day  month  leap_year decade       date
# 0       [WED]  [JAN]          0  [180] 1800-01-01
# 1       [THU]  [JAN]          0  [180] 1801-01-01
# 2       [FRI]  [JAN]          0  [180] 1802-01-01
# 3       [SAT]  [JAN]          0  [180] 1803-01-01
# 4       [SUN]  [JAN]          1  [180] 1804-01-01
# ...       ...    ...        ...    ...        ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31
# 146459  [MON]  [DEC]          0  [219] 2198-12-31
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31
# 146461  [WED]  [DEC]          0  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %% [markdown]
# date -> timestamp

# %%
data.date.iloc[0]
# Out:
# Timestamp('1800-01-01 00:00:00')

# %%
data['date_int'] = data['date'].dt.strftime("%Y%m%d").astype(np.int64)

# data['date_str'] = data['date'].dt.strftime("%Y%m%d")

# %%
# data['date_int'].map(str)
# data['date_int'].astype(str)

# %%
# date_max = data.date_int.max()
# data['date_normalized'] = data.date_int / date_max

# %%
data
# Out:
#           day  month  leap_year decade       date  date_int
# 0       [WED]  [JAN]          0  [180] 1800-01-01  18000101
# 1       [THU]  [JAN]          0  [180] 1801-01-01  18010101
# 2       [FRI]  [JAN]          0  [180] 1802-01-01  18020101
# 3       [SAT]  [JAN]          0  [180] 1803-01-01  18030101
# 4       [SUN]  [JAN]          1  [180] 1804-01-01  18040101
# ...       ...    ...        ...    ...        ...       ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31  21961231
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31  21971231
# 146459  [MON]  [DEC]          0  [219] 2198-12-31  21981231
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31  21991231
# 146461  [WED]  [DEC]          0  [220] 2200-12-31  22001231
#
# [146462 rows x 6 columns]

# %%
x = data.decade.iloc[0]
x
# Out:
# '[180]'

# %%
x.strip('[]')
# Out:
# '180'

# %%
data.decade = data.decade.apply(lambda x: x.strip('[]')).astype('int64')

# %%
# data.day = data.day.apply(lambda x: x.strip('[]'))
# data.month = data.month.apply(lambda x: x.strip('[]'))

# %%
map_day = {'[SAT]': int(0),
           '[SUN]': int(1),
           '[MON]': int(2),
           '[TUE]': int(3),
           '[WED]': int(4),
           '[THU]': int(5),
           '[FRI]': int(6)}

# %%
data['day_code'] = data.day.map(map_day)

# %%
scaler_day = RobustScaler()

x = data.day_code.values.reshape(-1, 1)

data['day_scaled'] = scaler_day.fit_transform(x).flatten()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled
# 0             0.25
# 1             0.50
# 2             0.75
# 3            -0.75
# 4            -0.50
# ...            ...
# 146457       -0.75
# 146458       -0.50
# 146459       -0.25
# 146460        0.00
# 146461        0.25
#
# [146462 rows x 8 columns]

# %%
data['day_sin'] = np.sin(data['day_code'] * (2 * np.pi / 7))
data['day_cos'] = np.cos(data['day_code'] * (2 * np.pi / 7))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos
# 0             0.25 -0.433884 -0.900969
# 1             0.50 -0.974928 -0.222521
# 2             0.75 -0.781831  0.623490
# 3            -0.75  0.000000  1.000000
# 4            -0.50  0.781831  0.623490
# ...            ...       ...       ...
# 146457       -0.75  0.000000  1.000000
# 146458       -0.50  0.781831  0.623490
# 146459       -0.25  0.974928 -0.222521
# 146460        0.00  0.433884 -0.900969
# 146461        0.25 -0.433884 -0.900969
#
# [146462 rows x 10 columns]

# %%
map_month = {'[JAN]' : 0,
             '[FEB]' : 1,
             '[MAR]' : 2,
             '[APR]' : 3,
             '[MAY]' : 4,
             '[JUN]' : 5,
             '[JUL]' : 6,
             '[AUG]' : 7,
             '[SEP]' : 8,
             '[OCT]' : 9,
             '[NOV]' : 10,
             '[DEC]' : 11}

# %%
data['month_code'] = data.month.map(map_month)

# %%
scaler_month = RobustScaler()

x = data.month_code.values.reshape(-1, 1)

data['month_scaled'] = scaler_month.fit_transform(x).flatten()

# %%
data['month_sin'] = np.sin(data['month_code'] * (2 * np.pi / 12))
data['month_cos'] = np.cos(data['month_code'] * (2 * np.pi / 12))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ...           ...
# 146457   0.866025
# 146458   0.866025
# 146459   0.866025
# 146460   0.866025
# 146461   0.866025
#
# [146462 rows x 14 columns]

# %%
scaler_decade = RobustScaler()

x = data.decade.values.reshape(-1, 1)

data['decade_scaled'] = scaler_decade.fit_transform(x).flatten()

# %%
# alpha = len(data.decade.unique())
alpha = (data.decade.iloc[-1] - data.decade.iloc[0]) + 1

data['decade_sin'] = np.sin(data['decade'] * (2 * np.pi / alpha))
data['decade_cos'] = np.cos(data['decade'] * (2 * np.pi / alpha))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %%
# data.date_normalized.min(), data.date_normalized.max()

# %%
# round(data.date_normalized.min()), round(data.date_normalized.max())

# %%
round(data.day_scaled.min()), round(data.day_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_sin.min()), round(data.day_sin.max())
# Out:
# (-1, 1)

# %%
round(data.day_cos.min()), round(data.day_cos.max())
# Out:
# (-1, 1)

# %%
round(data.month_scaled.min()), round(data.month_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.month_sin.min()), round(data.month_sin.max())
# Out:
# (-1, 1)

# %%
round(data.month_cos.min()), round(data.month_cos.max())
# Out:
# (-1, 1)

# %%
data.leap_year.min(), data.leap_year.max()
# Out:
# (0, 1)

# %%
round(data.decade_scaled.min()), round(data.decade_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.decade_sin.min()), round(data.decade_sin.max())
# Out:
# (-1, 1)

# %%
round(data.decade_cos.min()), round(data.decade_cos.max())
# Out:
# (-1, 1)

# %% [markdown]
# Boxplot

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.day.value_counts().plot(kind="bar")

# %%
data.month.value_counts().plot(kind="bar")

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
data.decade.value_counts().plot(kind="bar")

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %% [markdown]
# ['day_sin', 'day_cos', 'month_sin', 'month_cos', 'leap_year', 'decade_scaled']
# ['date_timestamp_scaled']

# %%
X = data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
          'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 0.25      , -0.43388374, -0.90096887, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.5       , -0.97492791, -0.22252093, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.75      , -0.78183148,  0.6234898 , ..., -1.        ,
#          0.63624244, -0.77148918],
#        ...,
#        [-0.25      ,  0.97492791, -0.22252093, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.        ,  0.43388374, -0.90096887, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.25      , -0.43388374, -0.90096887, ...,  1.        ,
#          0.74655322, -0.6653257 ]])

# %%
len(X)
# Out:
# 146462

# %%
X.shape
# Out:
# (146462, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()


ls = []

for s in data['date_int'].astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(data['date_int'])), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


date_scaler = RobustScaler()

Y = date_scaler.fit_transform(ll.values)

Y
# Out:
# array([[-1.        ,  0.85714286, -0.8       , ..., -0.5       ,
#         -0.5       , -0.6       ],
#        [-1.        ,  0.85714286, -0.8       , ..., -0.5       ,
#         -0.5       , -0.6       ],
#        [-1.        ,  0.85714286, -0.8       , ..., -0.5       ,
#         -0.5       , -0.6       ],
#        ...,
#        [ 0.        , -0.14285714,  1.        , ..., -0.33333333,
#          1.        , -0.6       ],
#        [ 0.        , -0.14285714,  1.        , ..., -0.33333333,
#          1.        , -0.6       ],
#        [ 0.        ,  0.        , -0.8       , ..., -0.33333333,
#          1.        , -0.6       ]])

# %%
len(Y)
# Out:
# 146462

# %%
Y.shape
# Out:
# (146462, 8)

# %%
# # leap = np.where(~X['leap_year'] == 1)[0]
# leap = np.where(X['leap_year'] == 1)[0]

# leap

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64


train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (146462, 10)
#
# Y: (146462, 8)
#
# Train data:   (102523, 10)
#
# Train labels: (102523, 8)
#
# Test data:    (43939, 10)
#
# Test labels:  (43939, 8)

# %%
102523 % 32, 102523 % 64
# Out:
# (27, 59)

# %%
class Model(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.input = nn.Linear(10, 32)

        self.fc1 = nn.Linear(32, 128)
        self.bnorm1 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 512)
        self.bnorm2 = nn.BatchNorm1d(512)

        self.fc3 = nn.Linear(512, 64)
        self.bnorm3 = nn.BatchNorm1d(64)

        self.fc4 = nn.Linear(64, 32)
        self.bnorm4 = nn.BatchNorm1d(32)


        self.output = nn.Linear(32, 8)



    def forward(self, x):


        # print(f'training={self.training}')

        x = F.leaky_relu( self.input(x) )

        x = F.leaky_relu(self.bnorm1(self.fc1(x)))
        x = F.dropout(x, p=0.25, training=self.training)

        x = F.leaky_relu(self.bnorm2(self.fc2(x)))
        x = F.dropout(x, p=0.4, training=self.training)

        x = F.leaky_relu(self.bnorm3(self.fc3(x)))
        x = F.dropout(x, p=0.1, training=self.training)

        x = F.leaky_relu(self.bnorm4(self.fc4(x)))
        x = F.dropout(x, p=0.05, training=self.training)


        x = torch.tanh(self.output(x))
        # x = self.output(x)
        


        return x

# %%
# test_x, test_y = next(iter(train_loader))

# print(f'X: {X.shape}\n')
# print(f'Y: {Y.shape}\n')

# %%
def train(model, numepochs):

    numepochs = numepochs

    model = model
    
    
    
    # lossfun = nn.MSELoss()
    lossfun = nn.L1Loss()


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0002, betas=(0.5, 0.999), weight_decay=1e-5)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.5, 0.999), weight_decay=1e-1)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=1e-9)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
    
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    
    
    
    trainLoss = torch.zeros(numepochs)
    testLoss  = torch.zeros(numepochs)
    trainAcc  = torch.zeros(numepochs)
    # testAcc   = torch.zeros(numepochs)


    for epochi in range(numepochs):

        model.train() # switch to train mode

        batchLoss = []
        batchAcc  = []

        for X,y in train_loader:

            X = X.to(device)
            y = y.to(device)

            yHat = model(X)
            loss = lossfun(yHat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())
            # batchAcc.append( torch.mean(( yHat == y).float() ).item() )
            # batchAcc.append( torch.mean( (torch.abs(yHat - y) < 1).float() ).item() ) # <1 for rounding
            batchAcc.append( r2_score(y.detach().cpu().numpy(), yHat.detach().cpu().numpy()) )
            




        trainLoss[epochi] = np.mean(batchLoss)
        # trainAcc[epochi]  = 100*np.mean(batchAcc)
        trainAcc[epochi]  = np.mean(batchAcc)
        



        model.eval() # switch to test mode

        XX,yy = next(iter(test_loader))

        XX = XX.to(device)
        yy = yy.to(device)

        # forward pass and loss
        with torch.no_grad():
            yHat_test = model(XX)
            loss = lossfun(yHat_test, yy)


        testLoss[epochi] = loss.item()
        # testAcc[epochi]  = 100*torch.mean( (yHat_test == yy).float() ).item()
        # testAcc[epochi]  = 100*torch.mean( (torch.abs(yHat_test - yy) < 1).float() ).item()
        # testAcc[epochi]  = 100*r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
        


        # if (epochi + 1) % 5 == 0:
        print(f'Epoch {epochi+1}/{numepochs}, Train Loss: {loss.item():0.6f}, Test Loss: {loss.item():0.6f}')


        
    return trainLoss.cpu(), testLoss.cpu(), trainAcc.cpu(), yHat.cpu(), y.cpu(), yHat_test.cpu(), yy.cpu()

# %%
model = Model().to(device)

# test_hat = model(torch.randn(32,6))
# test_hat = model(test_x)

# print(test_hat.shape)

# %%
# for p in list(model.named_parameters()):
#     if 'weight' in p[0] and 'bnorm' not in p[0]:
#         nn.init.xavier_normal_(p[1].data)
#         print(p[0])
#         print(p[1].data.shape)

# %%
numepochs = 120

trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model, numepochs)
# Out:
# Epoch 1/120, Train Loss: 0.241222, Test Loss: 0.241222
# Epoch 2/120, Train Loss: 0.243508, Test Loss: 0.243508
# Epoch 3/120, Train Loss: 0.220512, Test Loss: 0.220512
# Epoch 4/120, Train Loss: 0.224331, Test Loss: 0.224331
# Epoch 5/120, Train Loss: 0.242425, Test Loss: 0.242425
# Epoch 6/120, Train Loss: 0.217782, Test Loss: 0.217782
# Epoch 7/120, Train Loss: 0.213118, Test Loss: 0.213118
# Epoch 8/120, Train Loss: 0.218139, Test Loss: 0.218139
# Epoch 9/120, Train Loss: 0.234682, Test Loss: 0.234682
# Epoch 10/120, Train Loss: 0.210119, Test Loss: 0.210119
# Epoch 11/120, Train Loss: 0.223383, Test Loss: 0.223383
# Epoch 12/120, Train Loss: 0.241405, Test Loss: 0.241405
# Epoch 13/120, Train Loss: 0.227707, Test Loss: 0.227707
# Epoch 14/120, Train Loss: 0.213471, Test Loss: 0.213471
# Epoch 15/120, Train Loss: 0.222357, Test Loss: 0.222357
# Epoch 16/120, Train Loss: 0.210598, Test Loss: 0.210598
# Epoch 17/120, Train Loss: 0.214784, Test Loss: 0.214784
# Epoch 18/120, Train Loss: 0.227885, Test Loss: 0.227885
# Epoch 19/120, Train Loss: 0.236638, Test Loss: 0.236638
# Epoch 20/120, Train Loss: 0.223172, Test Loss: 0.223172
# Epoch 21/120, Train Loss: 0.221585, Test Loss: 0.221585
# Epoch 22/120, Train Loss: 0.219595, Test Loss: 0.219595
# Epoch 23/120, Train Loss: 0.243173, Test Loss: 0.243173
# Epoch 24/120, Train Loss: 0.213154, Test Loss: 0.213154
# Epoch 25/120, Train Loss: 0.239101, Test Loss: 0.239101
# Epoch 26/120, Train Loss: 0.230406, Test Loss: 0.230406
# Epoch 27/120, Train Loss: 0.226734, Test Loss: 0.226734
# Epoch 28/120, Train Loss: 0.222772, Test Loss: 0.222772
# Epoch 29/120, Train Loss: 0.229488, Test Loss: 0.229488
# Epoch 30/120, Train Loss: 0.221052, Test Loss: 0.221052
# Epoch 31/120, Train Loss: 0.218128, Test Loss: 0.218128
# Epoch 32/120, Train Loss: 0.227275, Test Loss: 0.227275
# Epoch 33/120, Train Loss: 0.210477, Test Loss: 0.210477
# Epoch 34/120, Train Loss: 0.215119, Test Loss: 0.215119
# Epoch 35/120, Train Loss: 0.234420, Test Loss: 0.234420
# Epoch 36/120, Train Loss: 0.210216, Test Loss: 0.210216
# Epoch 37/120, Train Loss: 0.218910, Test Loss: 0.218910
# Epoch 38/120, Train Loss: 0.240746, Test Loss: 0.240746
# Epoch 39/120, Train Loss: 0.231256, Test Loss: 0.231256
# Epoch 40/120, Train Loss: 0.218697, Test Loss: 0.218697
# Epoch 41/120, Train Loss: 0.216203, Test Loss: 0.216203
# Epoch 42/120, Train Loss: 0.204670, Test Loss: 0.204670
# Epoch 43/120, Train Loss: 0.214983, Test Loss: 0.214983
# Epoch 44/120, Train Loss: 0.230120, Test Loss: 0.230120
# Epoch 45/120, Train Loss: 0.217648, Test Loss: 0.217648
# Epoch 46/120, Train Loss: 0.211768, Test Loss: 0.211768
# Epoch 47/120, Train Loss: 0.216670, Test Loss: 0.216670
# Epoch 48/120, Train Loss: 0.217077, Test Loss: 0.217077
# Epoch 49/120, Train Loss: 0.227006, Test Loss: 0.227006
# Epoch 50/120, Train Loss: 0.219873, Test Loss: 0.219873
# Epoch 51/120, Train Loss: 0.202450, Test Loss: 0.202450
# Epoch 52/120, Train Loss: 0.218458, Test Loss: 0.218458
# Epoch 53/120, Train Loss: 0.245845, Test Loss: 0.245845
# Epoch 54/120, Train Loss: 0.221070, Test Loss: 0.221070
# Epoch 55/120, Train Loss: 0.220553, Test Loss: 0.220553
# Epoch 56/120, Train Loss: 0.239737, Test Loss: 0.239737
# Epoch 57/120, Train Loss: 0.221025, Test Loss: 0.221025
# Epoch 58/120, Train Loss: 0.208518, Test Loss: 0.208518
# Epoch 59/120, Train Loss: 0.216082, Test Loss: 0.216082
# Epoch 60/120, Train Loss: 0.219354, Test Loss: 0.219354
# Epoch 61/120, Train Loss: 0.234205, Test Loss: 0.234205
# Epoch 62/120, Train Loss: 0.229537, Test Loss: 0.229537
# Epoch 63/120, Train Loss: 0.222220, Test Loss: 0.222220
# Epoch 64/120, Train Loss: 0.217880, Test Loss: 0.217880
# Epoch 65/120, Train Loss: 0.234941, Test Loss: 0.234941
# Epoch 66/120, Train Loss: 0.233939, Test Loss: 0.233939
# Epoch 67/120, Train Loss: 0.227485, Test Loss: 0.227485
# Epoch 68/120, Train Loss: 0.219303, Test Loss: 0.219303
# Epoch 69/120, Train Loss: 0.206412, Test Loss: 0.206412
# Epoch 70/120, Train Loss: 0.224633, Test Loss: 0.224633
# Epoch 71/120, Train Loss: 0.221381, Test Loss: 0.221381
# Epoch 72/120, Train Loss: 0.220134, Test Loss: 0.220134
# Epoch 73/120, Train Loss: 0.214538, Test Loss: 0.214538
# Epoch 74/120, Train Loss: 0.211983, Test Loss: 0.211983
# Epoch 75/120, Train Loss: 0.217134, Test Loss: 0.217134
# Epoch 76/120, Train Loss: 0.222822, Test Loss: 0.222822
# Epoch 77/120, Train Loss: 0.229332, Test Loss: 0.229332
# Epoch 78/120, Train Loss: 0.222304, Test Loss: 0.222304
# Epoch 79/120, Train Loss: 0.219027, Test Loss: 0.219027
# Epoch 80/120, Train Loss: 0.219789, Test Loss: 0.219789
# Epoch 81/120, Train Loss: 0.227668, Test Loss: 0.227668
# Epoch 82/120, Train Loss: 0.213293, Test Loss: 0.213293
# Epoch 83/120, Train Loss: 0.220440, Test Loss: 0.220440
# Epoch 84/120, Train Loss: 0.217696, Test Loss: 0.217696
# Epoch 85/120, Train Loss: 0.209809, Test Loss: 0.209809
# Epoch 86/120, Train Loss: 0.232525, Test Loss: 0.232525
# Epoch 87/120, Train Loss: 0.218688, Test Loss: 0.218688
# Epoch 88/120, Train Loss: 0.217346, Test Loss: 0.217346
# Epoch 89/120, Train Loss: 0.237300, Test Loss: 0.237300
# Epoch 90/120, Train Loss: 0.221667, Test Loss: 0.221667
# Epoch 91/120, Train Loss: 0.217971, Test Loss: 0.217971
# Epoch 92/120, Train Loss: 0.217842, Test Loss: 0.217842
# Epoch 93/120, Train Loss: 0.219043, Test Loss: 0.219043
# Epoch 94/120, Train Loss: 0.215726, Test Loss: 0.215726
# Epoch 95/120, Train Loss: 0.225811, Test Loss: 0.225811
# Epoch 96/120, Train Loss: 0.219402, Test Loss: 0.219402
# Epoch 97/120, Train Loss: 0.212070, Test Loss: 0.212070
# Epoch 98/120, Train Loss: 0.211951, Test Loss: 0.211951
# Epoch 99/120, Train Loss: 0.229996, Test Loss: 0.229996
# Epoch 100/120, Train Loss: 0.232064, Test Loss: 0.232064
# Epoch 101/120, Train Loss: 0.199742, Test Loss: 0.199742
# Epoch 102/120, Train Loss: 0.226521, Test Loss: 0.226521
# Epoch 103/120, Train Loss: 0.235761, Test Loss: 0.235761
# Epoch 104/120, Train Loss: 0.209325, Test Loss: 0.209325
# Epoch 105/120, Train Loss: 0.219920, Test Loss: 0.219920
# Epoch 106/120, Train Loss: 0.235554, Test Loss: 0.235554
# Epoch 107/120, Train Loss: 0.217339, Test Loss: 0.217339
# Epoch 108/120, Train Loss: 0.206928, Test Loss: 0.206928
# Epoch 109/120, Train Loss: 0.226737, Test Loss: 0.226737
# Epoch 110/120, Train Loss: 0.227234, Test Loss: 0.227234
# Epoch 111/120, Train Loss: 0.232876, Test Loss: 0.232876
# Epoch 112/120, Train Loss: 0.220801, Test Loss: 0.220801
# Epoch 113/120, Train Loss: 0.208006, Test Loss: 0.208006
# Epoch 114/120, Train Loss: 0.220414, Test Loss: 0.220414
# Epoch 115/120, Train Loss: 0.228741, Test Loss: 0.228741
# Epoch 116/120, Train Loss: 0.223668, Test Loss: 0.223668
# Epoch 117/120, Train Loss: 0.243109, Test Loss: 0.243109
# Epoch 118/120, Train Loss: 0.242619, Test Loss: 0.242619
# Epoch 119/120, Train Loss: 0.221230, Test Loss: 0.221230
# Epoch 120/120, Train Loss: 0.229144, Test Loss: 0.229144

# %%
# r2_score(y.detach().numpy(), yHat.detach().numpy())
# type(r2_score(y.detach(), yHat.detach()))

# %%
# torch.mean( r2_score(y.detach().numpy(), yHat.detach().numpy()) ).item()

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([0.2531, 0.2329, 0.2301, 0.2282, 0.2278, 0.2274, 0.2275, 0.2271, 0.2271,
#          0.2272, 0.2271, 0.2273, 0.2272, 0.2271, 0.2271, 0.2270, 0.2271, 0.2269,
#          0.2269, 0.2269, 0.2269, 0.2269, 0.2268, 0.2266, 0.2266, 0.2268, 0.2271,
#          0.2272, 0.2268, 0.2271, 0.2269, 0.2270, 0.2268, 0.2272, 0.2269, 0.2271,
#          0.2271, 0.2272, 0.2271, 0.2269, 0.2268, 0.2271, 0.2270, 0.2272, 0.2269,
#          0.2270, 0.2270, 0.2270, 0.2272, 0.2270, 0.2272, 0.2272, 0.2269, 0.2271,
#          0.2270, 0.2268, 0.2269, 0.2270, 0.2269, 0.2270, 0.2271, 0.2273, 0.2271,
#          0.2270, 0.2271, 0.2271, 0.2274, 0.2269, 0.2273, 0.2272, 0.2273, 0.2269,
#          0.2272, 0.2269, 0.2273, 0.2270, 0.2275, 0.2272, 0.2273, 0.2272, 0.2273,
#          0.2276, 0.2271, 0.2274, 0.2273, 0.2273, 0.2274, 0.2272, 0.2273, 0.2274,
#          0.2271, 0.2273, 0.2273, 0.2276, 0.2272, 0.2275, 0.2275, 0.2276, 0.2273,
#          0.2276, 0.2275, 0.2272, 0.2276, 0.2276, 0.2274, 0.2274, 0.2275, 0.2272,
#          0.2272, 0.2274, 0.2272, 0.2271, 0.2274, 0.2274, 0.2276, 0.2274, 0.2273,
#          0.2275, 0.2273, 0.2274]),
#  tensor([0.2412, 0.2435, 0.2205, 0.2243, 0.2424, 0.2178, 0.2131, 0.2181, 0.2347,
#          0.2101, 0.2234, 0.2414, 0.2277, 0.2135, 0.2224, 0.2106, 0.2148, 0.2279,
#          0.2366, 0.2232, 0.2216, 0.2196, 0.2432, 0.2132, 0.2391, 0.2304, 0.2267,
#          0.2228, 0.2295, 0.2211, 0.2181, 0.2273, 0.2105, 0.2151, 0.2344, 0.2102,
#          0.2189, 0.2407, 0.2313, 0.2187, 0.2162, 0.2047, 0.2150, 0.2301, 0.2176,
#          0.2118, 0.2167, 0.2171, 0.2270, 0.2199, 0.2024, 0.2185, 0.2458, 0.2211,
#          0.2206, 0.2397, 0.2210, 0.2085, 0.2161, 0.2194, 0.2342, 0.2295, 0.2222,
#          0.2179, 0.2349, 0.2339, 0.2275, 0.2193, 0.2064, 0.2246, 0.2214, 0.2201,
#          0.2145, 0.2120, 0.2171, 0.2228, 0.2293, 0.2223, 0.2190, 0.2198, 0.2277,
#          0.2133, 0.2204, 0.2177, 0.2098, 0.2325, 0.2187, 0.2173, 0.2373, 0.2217,
#          0.2180, 0.2178, 0.2190, 0.2157, 0.2258, 0.2194, 0.2121, 0.2120, 0.2300,
#          0.2321, 0.1997, 0.2265, 0.2358, 0.2093, 0.2199, 0.2356, 0.2173, 0.2069,
#          0.2267, 0.2272, 0.2329, 0.2208, 0.2080, 0.2204, 0.2287, 0.2237, 0.2431,
#          0.2426, 0.2212, 0.2291]),
#  tensor([0.4795, 0.5306, 0.5370, 0.5407, 0.5411, 0.5423, 0.5414, 0.5428, 0.5431,
#          0.5428, 0.5433, 0.5429, 0.5425, 0.5432, 0.5435, 0.5439, 0.5433, 0.5440,
#          0.5442, 0.5442, 0.5439, 0.5443, 0.5443, 0.5451, 0.5455, 0.5447, 0.5440,
#          0.5435, 0.5451, 0.5441, 0.5448, 0.5440, 0.5449, 0.5438, 0.5446, 0.5441,
#          0.5440, 0.5432, 0.5440, 0.5445, 0.5445, 0.5441, 0.5442, 0.5436, 0.5444,
#          0.5444, 0.5442, 0.5439, 0.5435, 0.5440, 0.5435, 0.5434, 0.5447, 0.5436,
#          0.5437, 0.5446, 0.5443, 0.5438, 0.5446, 0.5442, 0.5438, 0.5431, 0.5438,
#          0.5449, 0.5446, 0.5446, 0.5429, 0.5447, 0.5439, 0.5438, 0.5436, 0.5446,
#          0.5436, 0.5447, 0.5437, 0.5437, 0.5431, 0.5442, 0.5437, 0.5436, 0.5434,
#          0.5426, 0.5444, 0.5434, 0.5434, 0.5436, 0.5431, 0.5440, 0.5440, 0.5431,
#          0.5442, 0.5437, 0.5435, 0.5431, 0.5439, 0.5430, 0.5436, 0.5425, 0.5433,
#          0.5422, 0.5433, 0.5435, 0.5428, 0.5430, 0.5434, 0.5431, 0.5434, 0.5439,
#          0.5439, 0.5438, 0.5437, 0.5441, 0.5436, 0.5431, 0.5430, 0.5437, 0.5436,
#          0.5427, 0.5436, 0.5439]))

# %%
# batchLoss

# %%
# batchAcc

# %%
# yHat.shape, y.shape

# %%
# yHat_test.shape, yy.shape

# %%
y.T.shape
# Out:
# torch.Size([8, 32])

# %%
yHat.flatten(), y.flatten()
# Out:
# (tensor([-6.6644e-04, -1.3947e-01,  7.3059e-01,  9.1770e-04, -1.3831e-03,
#          -3.8885e-02,  1.6153e-05,  2.3830e-02,  1.4216e-03, -2.8793e-01,
#           4.1697e-01,  3.2626e-02, -2.6839e-04, -3.2113e-01,  1.8372e-03,
#           3.0030e-02,  2.5741e-04, -2.1829e-01,  2.3017e-01,  2.9085e-02,
#          -2.1089e-04, -2.2897e-01,  1.3599e-03,  2.5849e-02, -7.1968e-04,
#          -1.3900e-01, -1.7646e-01,  1.7244e-02, -2.4976e-04,  2.7555e-01,
#          -5.9606e-04,  2.9255e-02, -6.5808e-01,  4.8925e-01,  7.2111e-01,
#           1.6136e-02, -2.4410e-03,  6.0848e-01, -6.2485e-04,  3.9531e-02,
#          -9.7222e-01,  9.3320e-01,  1.5999e-02,  1.1762e-01, -2.1752e-03,
#          -5.0605e-01,  2.9545e-03,  4.7246e-02, -7.6526e-01,  6.0662e-01,
#          -7.0830e-01,  7.0217e-02, -1.4392e-03, -7.8859e-02, -1.2288e-03,
#           5.7125e-02, -1.8784e-03, -2.5199e-01, -7.8763e-02,  6.0790e-02,
#           9.5778e-01, -4.8473e-01, -8.4938e-04,  7.3137e-02, -9.8444e-01,
#           9.5860e-01,  5.5648e-01,  1.3363e-01,  9.6732e-01, -4.6843e-01,
#           1.8008e-04,  8.9861e-02, -9.6517e-01,  9.1943e-01,  1.8266e-01,
#           7.3416e-02, -2.8731e-03,  4.8344e-01, -9.6898e-04,  5.2660e-02,
#          -1.2558e-03, -1.4373e-01,  2.6112e-01,  5.3294e-03, -9.8681e-04,
#           3.8840e-01, -1.9228e-04,  2.5560e-02, -3.3363e-04, -1.4058e-01,
#           8.0512e-01,  1.3592e-02, -2.2478e-03, -3.9810e-01,  1.4028e-03,
#           2.8476e-02,  1.4354e-03, -2.8714e-01,  7.9755e-01,  3.6015e-03,
#           1.5623e-03, -9.8335e-03,  1.9706e-04,  2.8217e-02, -1.5020e-03,
#          -1.3926e-01,  5.9945e-01,  1.4898e-02,  1.3879e-01, -1.8334e-01,
#           5.5259e-04,  2.8606e-02, -9.4813e-01,  8.8000e-01, -5.3497e-01,
#           8.5393e-02, -1.3992e-03,  5.3528e-01, -1.2978e-03,  5.7472e-02,
#          -8.7548e-01,  7.6821e-01,  2.6829e-03,  6.4241e-02, -1.8945e-04,
#           3.2037e-01,  9.7984e-04,  3.7375e-02, -9.8638e-01,  9.6334e-01,
#          -6.9903e-02,  1.0547e-01, -8.9675e-04,  1.7921e-01,  1.8516e-03,
#           4.4164e-02, -1.0206e-03, -1.3889e-01,  1.2750e-01,  4.0403e-02,
#          -9.9779e-04, -4.9164e-01,  2.0736e-03,  2.7166e-02, -3.6140e-03,
#          -1.3749e-01,  2.2803e-01,  4.4863e-02,  8.4495e-01, -4.3765e-01,
#          -6.7616e-04,  5.2203e-02, -3.9629e-03, -2.8071e-01,  7.1056e-01,
#           3.9240e-02,  9.3492e-01, -3.8047e-01,  3.0113e-04,  7.0673e-02,
#          -9.8014e-01,  9.4911e-01,  7.0184e-01,  1.2819e-01,  9.5957e-01,
#          -5.0385e-01,  6.3676e-04,  9.0607e-02, -9.3259e-01,  8.6017e-01,
#          -6.0298e-01,  7.0133e-02, -2.1694e-03,  6.3654e-01, -1.7575e-03,
#           6.3079e-02, -9.1683e-01,  8.3321e-01, -5.0916e-01,  6.8112e-02,
#          -2.7910e-03,  6.6043e-01, -1.0166e-03,  5.9269e-02, -9.3530e-01,
#           8.5067e-01, -3.8386e-01,  9.8683e-02, -8.8330e-04, -2.4500e-01,
#           1.9346e-03,  4.9499e-02, -9.6237e-01,  9.0869e-01,  6.8429e-01,
#           5.5931e-02, -2.8299e-03,  4.8210e-01,  9.9269e-04,  4.7609e-02,
#          -9.6612e-01,  9.2073e-01,  2.7744e-01,  9.4532e-02, -1.9966e-03,
#          -1.4671e-01,  2.8337e-03,  4.2262e-02, -6.8412e-04, -1.3914e-01,
#          -3.2553e-01,  1.2921e-02, -9.6487e-04,  5.3711e-01, -1.6017e-03,
#           3.7115e-02, -9.1607e-01,  8.3282e-01,  4.2261e-01,  6.2059e-02,
#          -9.7749e-04,  6.7347e-02,  1.8814e-03,  3.4493e-02,  1.4160e-03,
#          -2.9184e-01, -5.0747e-01,  3.0097e-02,  1.7522e-05,  3.6850e-01,
#          -1.5963e-03,  4.5196e-02, -4.1194e-03, -1.4872e-01, -2.9627e-01,
#           7.4184e-02,  9.4465e-01, -6.4318e-01, -5.5568e-04,  7.4738e-02,
#          -9.7097e-01,  9.3088e-01, -2.6288e-02,  8.5219e-02, -2.2372e-03,
#           5.8246e-01,  2.6650e-04,  4.6058e-02,  8.1872e-04, -2.6956e-01,
#           1.7926e-01,  2.2927e-02,  1.0805e-03, -8.0675e-03,  4.3622e-04,
#           2.4700e-02], grad_fn=<ReshapeAliasBackward0>),
#  tensor([ 0.0000, -0.1429,  0.8000,  0.2000,  0.0000, -0.1667,  0.0000,  0.8000,
#           0.0000, -0.2857,  0.8000,  1.0000,  0.0000, -0.3333,  0.5000,  0.0000,
#           0.0000, -0.2857,  0.2000,  0.8000,  0.0000, -0.1667,  0.5000,  1.0000,
#           0.0000, -0.1429,  0.0000, -0.4000,  0.0000,  0.5000, -0.5000, -0.2000,
#           0.0000, -0.1429,  1.0000, -0.8000,  0.0000,  0.6667, -0.5000,  0.4000,
#          -1.0000,  1.0000,  0.2000,  0.6000,  0.0000, -0.5000, -0.5000, -0.2000,
#          -1.0000,  0.8571, -0.8000, -0.4000,  0.0000, -0.1667,  0.0000,  0.0000,
#           0.0000, -0.2857,  1.0000, -0.2000,  1.0000, -0.5000,  0.0000,  0.8000,
#          -1.0000,  1.0000,  0.4000,  0.0000,  1.0000, -0.3333,  0.0000, -0.8000,
#          -1.0000,  1.0000, -0.8000,  0.0000,  0.0000,  0.5000, -0.5000, -0.2000,
#           0.0000, -0.1429,  0.4000,  0.0000,  0.0000,  0.6667,  0.0000,  0.6000,
#           0.0000, -0.1429,  0.8000,  0.8000,  0.0000, -0.3333,  0.5000, -0.8000,
#           0.0000, -0.2857,  0.8000,  0.4000,  0.0000,  0.0000, -0.5000,  0.2000,
#           0.0000, -0.2857,  0.8000,  0.8000,  0.0000, -0.5000,  0.0000,  1.0000,
#          -1.0000,  1.0000, -0.8000, -0.6000,  0.0000,  0.5000,  0.5000,  0.0000,
#          -1.0000,  0.8571, -0.8000,  0.4000,  0.0000,  0.8333,  0.0000, -0.8000,
#          -1.0000,  1.0000, -0.2000, -0.6000,  0.0000,  0.3333,  0.0000, -0.8000,
#           0.0000, -0.1429,  0.2000, -0.6000,  0.0000, -0.5000,  0.5000, -0.6000,
#           0.0000, -0.1429,  0.4000, -0.8000,  1.0000, -0.6667,  0.0000, -0.2000,
#           0.0000, -0.2857,  1.0000,  0.6000,  1.0000, -0.3333,  0.5000,  0.8000,
#          -1.0000,  1.0000,  0.6000,  1.0000,  1.0000, -0.5000,  0.0000,  0.2000,
#          -1.0000,  1.0000, -0.6000,  1.0000,  0.0000,  0.5000,  0.0000,  1.0000,
#          -1.0000,  0.8571, -0.8000, -0.6000,  0.0000,  0.6667,  0.5000, -0.2000,
#          -1.0000,  0.8571, -0.8000, -0.6000,  0.0000, -0.3333,  0.0000, -0.2000,
#          -1.0000,  0.8571,  1.0000,  0.0000,  0.0000,  0.3333, -0.5000, -0.2000,
#          -1.0000,  0.8571,  1.0000, -0.8000,  0.0000, -0.3333,  0.5000,  0.6000,
#           0.0000, -0.1429, -0.4000,  0.2000,  0.0000,  0.5000,  0.5000,  0.4000,
#          -1.0000,  1.0000,  0.0000, -0.4000,  0.0000,  0.1667,  0.0000, -0.6000,
#           0.0000, -0.2857, -0.8000, -0.6000,  0.0000,  0.6667, -0.5000,  1.0000,
#           0.0000, -0.1429, -0.4000,  0.4000,  1.0000, -0.6667,  0.5000,  0.2000,
#          -1.0000,  0.8571,  0.2000,  0.0000,  0.0000,  0.6667,  0.0000,  0.8000,
#           0.0000, -0.2857,  0.0000, -0.8000,  0.0000,  0.1667,  0.5000,  0.4000]))

# %%
yHat_test, yy
# Out:
# (tensor([[-0.9200,  0.8390, -0.4103,  0.0744, -0.0019,  0.4000, -0.0019,  0.0529]]),
#  tensor([[-1.0000,  0.8571, -0.6000,  0.4000,  0.0000,  0.3333, -0.5000, -0.6000]]))

# %%
date_scaler.inverse_transform(yy).round()
# Out:
# array([[1., 8., 1., 6., 0., 6., 0., 1.]])

# %%
date_scaler.inverse_transform(yHat_test).round()
# Out:
# array([[ 1.,  8.,  2.,  4., -0.,  6.,  1.,  4.]])

# %%
date_scaler.inverse_transform(yHat.detach().numpy()).round(), date_scaler.inverse_transform(y.detach().numpy()).round()
# Out:
# (array([[ 2.,  1.,  8.,  4., -0.,  4.,  1.,  4.],
#         [ 2., -0.,  6.,  4., -0.,  2.,  1.,  4.],
#         [ 2.,  0.,  5.,  4., -0.,  3.,  1.,  4.],
#         [ 2.,  1.,  3.,  4., -0.,  6.,  1.,  4.],
#         [ 1.,  5.,  8.,  4., -0.,  8.,  1.,  4.],
#         [ 1.,  9.,  4.,  5., -0.,  1.,  1.,  4.],
#         [ 1.,  6.,  0.,  4., -0.,  4.,  1.,  4.],
#         [ 2.,  0.,  4.,  4.,  1.,  1.,  1.,  4.],
#         [ 1.,  9.,  7.,  5.,  1.,  1.,  1.,  4.],
#         [ 1.,  8.,  5.,  4., -0.,  7.,  1.,  4.],
#         [ 2.,  1.,  5.,  4., -0.,  6.,  1.,  4.],
#         [ 2.,  1.,  8.,  4., -0.,  2.,  1.,  4.],
#         [ 2., -0.,  8.,  4.,  0.,  4.,  1.,  4.],
#         [ 2.,  1.,  7.,  4.,  0.,  3.,  1.,  4.],
#         [ 1.,  8.,  1.,  4., -0.,  7.,  1.,  4.],
#         [ 1.,  7.,  4.,  4., -0.,  6.,  1.,  4.],
#         [ 1.,  9.,  4.,  5., -0.,  5.,  1.,  4.],
#         [ 2.,  1.,  5.,  4., -0.,  1.,  1.,  4.],
#         [ 2.,  1.,  5.,  4.,  1.,  1.,  1.,  4.],
#         [ 2.,  0.,  8.,  4.,  1.,  2.,  1.,  4.],
#         [ 1.,  9.,  8.,  5.,  1.,  1.,  1.,  4.],
#         [ 1.,  8.,  1.,  4., -0.,  8.,  1.,  4.],
#         [ 1.,  8.,  1.,  4., -0.,  8.,  1.,  4.],
#         [ 1.,  8.,  2.,  4., -0.,  3.,  1.,  4.],
#         [ 1.,  8.,  7.,  4., -0.,  7.,  1.,  4.],
#         [ 1.,  8.,  5.,  4., -0.,  3.,  1.,  4.],
#         [ 2.,  1.,  2.,  4., -0.,  7.,  1.,  4.],
#         [ 1.,  8.,  6.,  4., -0.,  4.,  1.,  4.],
#         [ 2., -0.,  1.,  4.,  0.,  6.,  1.,  4.],
#         [ 2.,  1.,  3.,  4.,  1.,  0.,  1.,  4.],
#         [ 1.,  9.,  4.,  4., -0.,  7.,  1.,  4.],
#         [ 2.,  0.,  5.,  4.,  0.,  4.,  1.,  4.]], dtype=float32),
#  array([[2., 1., 8., 5., 0., 3., 1., 8.],
#         [2., 0., 8., 9., 0., 2., 2., 4.],
#         [2., 0., 5., 8., 0., 3., 2., 9.],
#         [2., 1., 4., 2., 0., 7., 0., 3.],
#         [2., 1., 9., 0., 0., 8., 0., 6.],
#         [1., 9., 5., 7., 0., 1., 0., 3.],
#         [1., 8., 0., 2., 0., 3., 1., 4.],
#         [2., 0., 9., 3., 1., 1., 1., 8.],
#         [1., 9., 6., 4., 1., 2., 1., 0.],
#         [1., 9., 0., 4., 0., 7., 0., 3.],
#         [2., 1., 6., 4., 0., 8., 1., 7.],
#         [2., 1., 8., 8., 0., 2., 2., 0.],
#         [2., 0., 8., 6., 0., 4., 0., 5.],
#         [2., 0., 8., 8., 0., 1., 1., 9.],
#         [1., 9., 0., 1., 0., 7., 2., 4.],
#         [1., 8., 0., 6., 0., 9., 1., 0.],
#         [1., 9., 3., 1., 0., 6., 1., 0.],
#         [2., 1., 5., 1., 0., 1., 2., 1.],
#         [2., 1., 6., 0., 1., 0., 1., 3.],
#         [2., 0., 9., 7., 1., 2., 2., 8.],
#         [1., 9., 7., 9., 1., 1., 1., 5.],
#         [1., 9., 1., 9., 0., 7., 1., 9.],
#         [1., 8., 0., 1., 0., 8., 2., 3.],
#         [1., 8., 0., 1., 0., 2., 1., 3.],
#         [1., 8., 9., 4., 0., 6., 0., 3.],
#         [1., 8., 9., 0., 0., 2., 2., 7.],
#         [2., 1., 2., 5., 0., 7., 2., 6.],
#         [1., 9., 4., 2., 0., 5., 1., 1.],
#         [2., 0., 0., 1., 0., 8., 0., 9.],
#         [2., 1., 2., 6., 1., 0., 2., 5.],
#         [1., 8., 5., 4., 0., 8., 1., 8.],
#         [2., 0., 4., 0., 0., 5., 2., 6.]], dtype=float32))

# %%
yHat      = date_scaler.inverse_transform(yHat.detach().numpy()).flatten()
y         = date_scaler.inverse_transform(y.detach().numpy()).flatten()
yHat_test = date_scaler.inverse_transform(yHat_test.detach().numpy()).flatten()
yy        = date_scaler.inverse_transform(yy.detach().numpy()).flatten()

# %%
yHat      = yHat.round()
yHat_test = yHat_test.round()

# %%
print_score(X.shape, yHat.round(), y, yHat_test.round(), yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.6913
#
#
# mean_absolute_error(y, yHat): 1.0078
#
# mean_absolute_error(yy, yHat_test): 0.8750
#
#
# mean_squared_error(y, yHat): 2.9688
#
# mean_squared_error(yy, yHat_test): 1.8750
#
#
# mean_squared_log_error(y, yHat): 0.2146
#
# mean_squared_log_error(yy, yHat_test): 0.1997
#
#
# RMSE(y, yHat): 1.7230
#
# RMSE(yy, yHat_test): 1.3693

# %%
# create a 1D smoothing filter
def smooth(x, k=15):
    return np.convolve(x, np.ones(k)/k, mode='same')

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss1.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc1.jpg", bbox_inches='tight')


plt.show()

# %%
data.leap_year.value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
resampler = SMOTE(k_neighbors=20, random_state=0)

# %%
X_res, y_res = resampler.fit_resample(data[['day_code', 'month_code', 'decade', 'date_int']], data['leap_year'])

# %%
y_res.value_counts()
# Out:
# 0    110960
# 1    110960
# Name: leap_year, dtype: int64

# %%
data['leap_year'].value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 221915    1
# 221916    1
# 221917    1
# 221918    1
# 221919    1
# Name: leap_year, Length: 221920, dtype: int64

# %%
X_res
# Out:
#         day_code  month_code  decade  date_int
# 0              4           0     180  18000101
# 1              5           0     180  18010101
# 2              6           0     180  18020101
# 3              0           0     180  18030101
# 4              1           0     180  18040101
# ...          ...         ...     ...       ...
# 221915         0           5     188  18880618
# 221916         2           6     188  18840705
# 221917         5           2     218  21800323
# 221918         1           5     199  19960602
# 221919         1           4     219  21960520
#
# [221920 rows x 4 columns]

# %%
X_smote = X_res.assign(leap_year=y_res)

# %%
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221915         0           5     188  18880618          1
# 221916         2           6     188  18840705          1
# 221917         5           2     218  21800323          1
# 221918         1           5     199  19960602          1
# 221919         1           4     219  21960520          1
#
# [221920 rows x 5 columns]

# %% [markdown]
# Drop 220 decade

# %%
# data.decade.value_counts().plot(kind="bar")
X_smote.decade.value_counts().plot(kind="bar")

# %%
# data.decade.value_counts()[-5:]
X_smote.decade.value_counts()[-5:]
# Out:
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# 220     365
# Name: decade, dtype: int64

# %%
X_smote = X_smote.drop(X_smote.index[X_smote['decade'] == 220]).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221550         0           5     188  18880618          1
# 221551         2           6     188  18840705          1
# 221552         5           2     218  21800323          1
# 221553         1           5     199  19960602          1
# 221554         1           4     219  21960520          1
#
# [221555 rows x 5 columns]

# %%
X_smote.decade.value_counts().plot(kind="bar")

# %%
X_smote.decade.value_counts()[-5:]
# Out:
# 209    5174
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# Name: decade, dtype: int64

# %% [markdown]
# code is required to only work for dates in the range  [ 1-1-1800 to 31-12-2200 ]

# %%
X_smote.date_int.max()
# Out:
# 21991231

# %%
datetime.datetime.strptime(str(X_smote.date_int.max()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '31-12-2199'

# %%
X_smote.date_int.min()
# Out:
# 18000101

# %%
datetime.datetime.strptime(str(X_smote.date_int.min()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '01-01-1800'

# %%
Y_smote = X_smote['date_int']
Y_smote
# Out:
# 0         18000101
# 1         18010101
# 2         18020101
# 3         18030101
# 4         18040101
#             ...
# 221550    18880618
# 221551    18840705
# 221552    21800323
# 221553    19960602
# 221554    21960520
# Name: date_int, Length: 221555, dtype: int64

# %%
X_smote = X_smote.drop('date_int', axis=1).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  leap_year
# 0              4           0     180          0
# 1              5           0     180          0
# 2              6           0     180          0
# 3              0           0     180          0
# 4              1           0     180          1
# ...          ...         ...     ...        ...
# 221550         0           5     188          1
# 221551         2           6     188          1
# 221552         5           2     218          1
# 221553         1           5     199          1
# 221554         1           4     219          1
#
# [221555 rows x 4 columns]

# %%
Y_smote = Y_smote.reset_index(drop=True)

ls = []

for s in Y_smote.astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(Y_smote)), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


date_scaler_smote = RobustScaler()

Y_smote = date_scaler_smote.fit_transform(ll.values)


Y_smote
# Out:
# array([[-1.        ,  0.875     , -0.8       , ..., -0.5       ,
#         -0.5       , -0.6       ],
#        [-1.        ,  0.875     , -0.8       , ..., -0.5       ,
#         -0.5       , -0.6       ],
#        [-1.        ,  0.875     , -0.8       , ..., -0.5       ,
#         -0.5       , -0.6       ],
#        ...,
#        [ 0.        ,  0.        ,  0.8       , ..., -0.16666667,
#          0.5       , -0.2       ],
#        [-1.        ,  1.        ,  1.        , ...,  0.33333333,
#         -0.5       , -0.4       ],
#        [ 0.        ,  0.        ,  1.        , ...,  0.16666667,
#          0.5       , -0.8       ]])

# %%
# data.index[data['leap_year'] == 1].tolist()
# data.index[data['leap_year'] == 1]

# %%
# for i,idx in enumerate(data['leap_year'].tolist()):
#     print(i, idx)

# %% [markdown]
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1 <---
# 5 0
# 6 0
# 7 0
# 8 1 <---
# 9 0
# 10 0
# 11 0
# 12 1 <---
# 13 0
# 14 0
# 15 0
# 16 1 <---
# 17 0
# 18 0
# 19 0
# 20 1 <---
# 21 0
# 22 0
# 23 0
# 24 1 <---
# 25 0
# 26 0
# 27 0
# 28 1 <---
# 29 0
# 30 0

# %%
scaler_day_smote = RobustScaler()

x = X_smote.day_code.values.reshape(-1, 1)

X_smote['day_scaled'] = scaler_day_smote.fit_transform(x).flatten()

# %%
X_smote['day_sin'] = np.sin(X_smote['day_code'] * (2 * np.pi / 7))
X_smote['day_cos'] = np.cos(X_smote['day_code'] * (2 * np.pi / 7))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos
# 0      -0.900969
# 1      -0.222521
# 2       0.623490
# 3       1.000000
# 4       0.623490
# ...          ...
# 221550  1.000000
# 221551 -0.222521
# 221552 -0.222521
# 221553  0.623490
# 221554  0.623490
#
# [221555 rows x 7 columns]

# %%
scaler_month_smote = RobustScaler()

x = X_smote.month_code.values.reshape(-1, 1)

X_smote['month_scaled'] = scaler_month_smote.fit_transform(x).flatten()

# %%
X_smote['month_sin'] = np.sin(X_smote['month_code'] * (2 * np.pi / 12))
X_smote['month_cos'] = np.cos(X_smote['month_code'] * (2 * np.pi / 12))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos
# 0      -0.900969     -1.000000  0.000000e+00   1.000000
# 1      -0.222521     -1.000000  0.000000e+00   1.000000
# 2       0.623490     -1.000000  0.000000e+00   1.000000
# 3       1.000000     -1.000000  0.000000e+00   1.000000
# 4       0.623490     -1.000000  0.000000e+00   1.000000
# ...          ...           ...           ...        ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000
#
# [221555 rows x 10 columns]

# %%
scaler_decade_smote = RobustScaler()

x = X_smote.decade.values.reshape(-1, 1)

X_smote['decade_scaled'] = scaler_decade_smote.fit_transform(x).flatten()

# %%
# alpha_smote = len(X_smote.decade.unique())
alpha_smote = (X_smote.decade.iloc[-1] - X_smote.decade.iloc[0]) + 1

X_smote['decade_sin'] = np.sin(X_smote['decade'] * (2 * np.pi / alpha_smote))
X_smote['decade_cos'] = np.cos(X_smote['decade'] * (2 * np.pi / alpha_smote))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos  decade_scaled  \
# 0      -0.900969     -1.000000  0.000000e+00   1.000000      -1.052632
# 1      -0.222521     -1.000000  0.000000e+00   1.000000      -1.052632
# 2       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# 3       1.000000     -1.000000  0.000000e+00   1.000000      -1.052632
# 4       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# ...          ...           ...           ...        ...            ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025      -0.631579
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000      -0.631579
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000       0.947368
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025      -0.052632
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000       1.000000
#
#           decade_sin  decade_cos
# 0       1.102182e-15   -1.000000
# 1       1.102182e-15   -1.000000
# 2       1.102182e-15   -1.000000
# 3       1.102182e-15   -1.000000
# 4       1.102182e-15   -1.000000
# ...              ...         ...
# 221550 -9.510565e-01   -0.309017
# 221551 -9.510565e-01   -0.309017
# 221552  3.090170e-01   -0.951057
# 221553 -1.564345e-01    0.987688
# 221554  1.564345e-01   -0.987688
#
# [221555 rows x 13 columns]

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
X = X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 3.33333333e-01, -4.33883739e-01, -9.00968868e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 1.00000000e+00, -7.81831482e-01,  6.23489802e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        ...,
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#          9.47368421e-01,  3.09016994e-01, -9.51056516e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#         -5.26315789e-02, -1.56434465e-01,  9.87688341e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#          1.00000000e+00,  1.56434465e-01, -9.87688341e-01]])

# %%
X.shape
# Out:
# (221555, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()
# Y = data['date_normalized'].values.reshape(-1, 1)
Y = Y_smote


Y
# Out:
# array([[-1.        ,  0.875     , -0.8       , ..., -0.5       ,
#         -0.5       , -0.6       ],
#        [-1.        ,  0.875     , -0.8       , ..., -0.5       ,
#         -0.5       , -0.6       ],
#        [-1.        ,  0.875     , -0.8       , ..., -0.5       ,
#         -0.5       , -0.6       ],
#        ...,
#        [ 0.        ,  0.        ,  0.8       , ..., -0.16666667,
#          0.5       , -0.2       ],
#        [-1.        ,  1.        ,  1.        , ...,  0.33333333,
#         -0.5       , -0.4       ],
#        [ 0.        ,  0.        ,  1.        , ...,  0.16666667,
#          0.5       , -0.8       ]])

# %%
Y.shape
# Out:
# (221555, 8)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64

train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (221555, 10)
#
# Y: (221555, 8)
#
# Train data:   (155088, 10)
#
# Train labels: (155088, 8)
#
# Test data:    (66467, 10)
#
# Test labels:  (66467, 8)

# %%
model_smote = Model().to(device)

# %%
numepochs = 120

trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model_smote, numepochs)
# Out:
# Epoch 1/120, Train Loss: 0.290867, Test Loss: 0.290867
# Epoch 2/120, Train Loss: 0.287861, Test Loss: 0.287861
# Epoch 3/120, Train Loss: 0.277697, Test Loss: 0.277697
# Epoch 4/120, Train Loss: 0.283452, Test Loss: 0.283452
# Epoch 5/120, Train Loss: 0.276842, Test Loss: 0.276842
# Epoch 6/120, Train Loss: 0.291874, Test Loss: 0.291874
# Epoch 7/120, Train Loss: 0.272721, Test Loss: 0.272721
# Epoch 8/120, Train Loss: 0.275648, Test Loss: 0.275648
# Epoch 9/120, Train Loss: 0.284944, Test Loss: 0.284944
# Epoch 10/120, Train Loss: 0.279438, Test Loss: 0.279438
# Epoch 11/120, Train Loss: 0.281910, Test Loss: 0.281910
# Epoch 12/120, Train Loss: 0.283209, Test Loss: 0.283209
# Epoch 13/120, Train Loss: 0.285917, Test Loss: 0.285917
# Epoch 14/120, Train Loss: 0.272769, Test Loss: 0.272769
# Epoch 15/120, Train Loss: 0.274113, Test Loss: 0.274113
# Epoch 16/120, Train Loss: 0.284029, Test Loss: 0.284029
# Epoch 17/120, Train Loss: 0.290672, Test Loss: 0.290672
# Epoch 18/120, Train Loss: 0.290047, Test Loss: 0.290047
# Epoch 19/120, Train Loss: 0.274064, Test Loss: 0.274064
# Epoch 20/120, Train Loss: 0.275184, Test Loss: 0.275184
# Epoch 21/120, Train Loss: 0.273482, Test Loss: 0.273482
# Epoch 22/120, Train Loss: 0.285685, Test Loss: 0.285685
# Epoch 23/120, Train Loss: 0.289492, Test Loss: 0.289492
# Epoch 24/120, Train Loss: 0.298846, Test Loss: 0.298846
# Epoch 25/120, Train Loss: 0.280328, Test Loss: 0.280328
# Epoch 26/120, Train Loss: 0.287182, Test Loss: 0.287182
# Epoch 27/120, Train Loss: 0.289980, Test Loss: 0.289980
# Epoch 28/120, Train Loss: 0.294108, Test Loss: 0.294108
# Epoch 29/120, Train Loss: 0.294398, Test Loss: 0.294398
# Epoch 30/120, Train Loss: 0.280885, Test Loss: 0.280885
# Epoch 31/120, Train Loss: 0.280135, Test Loss: 0.280135
# Epoch 32/120, Train Loss: 0.289295, Test Loss: 0.289295
# Epoch 33/120, Train Loss: 0.282947, Test Loss: 0.282947
# Epoch 34/120, Train Loss: 0.289186, Test Loss: 0.289186
# Epoch 35/120, Train Loss: 0.277175, Test Loss: 0.277175
# Epoch 36/120, Train Loss: 0.303269, Test Loss: 0.303269
# Epoch 37/120, Train Loss: 0.279172, Test Loss: 0.279172
# Epoch 38/120, Train Loss: 0.296843, Test Loss: 0.296843
# Epoch 39/120, Train Loss: 0.284047, Test Loss: 0.284047
# Epoch 40/120, Train Loss: 0.266733, Test Loss: 0.266733
# Epoch 41/120, Train Loss: 0.284291, Test Loss: 0.284291
# Epoch 42/120, Train Loss: 0.281344, Test Loss: 0.281344
# Epoch 43/120, Train Loss: 0.299349, Test Loss: 0.299349
# Epoch 44/120, Train Loss: 0.295660, Test Loss: 0.295660
# Epoch 45/120, Train Loss: 0.290054, Test Loss: 0.290054
# Epoch 46/120, Train Loss: 0.285149, Test Loss: 0.285149
# Epoch 47/120, Train Loss: 0.304202, Test Loss: 0.304202
# Epoch 48/120, Train Loss: 0.287890, Test Loss: 0.287890
# Epoch 49/120, Train Loss: 0.273495, Test Loss: 0.273495
# Epoch 50/120, Train Loss: 0.280800, Test Loss: 0.280800
# Epoch 51/120, Train Loss: 0.287262, Test Loss: 0.287262
# Epoch 52/120, Train Loss: 0.295530, Test Loss: 0.295530
# Epoch 53/120, Train Loss: 0.285009, Test Loss: 0.285009
# Epoch 54/120, Train Loss: 0.272411, Test Loss: 0.272411
# Epoch 55/120, Train Loss: 0.279729, Test Loss: 0.279729
# Epoch 56/120, Train Loss: 0.288156, Test Loss: 0.288156
# Epoch 57/120, Train Loss: 0.291434, Test Loss: 0.291434
# Epoch 58/120, Train Loss: 0.282167, Test Loss: 0.282167
# Epoch 59/120, Train Loss: 0.300933, Test Loss: 0.300933
# Epoch 60/120, Train Loss: 0.279619, Test Loss: 0.279619
# Epoch 61/120, Train Loss: 0.288017, Test Loss: 0.288017
# Epoch 62/120, Train Loss: 0.273299, Test Loss: 0.273299
# Epoch 63/120, Train Loss: 0.272255, Test Loss: 0.272255
# Epoch 64/120, Train Loss: 0.284328, Test Loss: 0.284328
# Epoch 65/120, Train Loss: 0.287014, Test Loss: 0.287014
# Epoch 66/120, Train Loss: 0.280478, Test Loss: 0.280478
# Epoch 67/120, Train Loss: 0.264052, Test Loss: 0.264052
# Epoch 68/120, Train Loss: 0.294668, Test Loss: 0.294668
# Epoch 69/120, Train Loss: 0.277013, Test Loss: 0.277013
# Epoch 70/120, Train Loss: 0.291822, Test Loss: 0.291822
# Epoch 71/120, Train Loss: 0.282458, Test Loss: 0.282458
# Epoch 72/120, Train Loss: 0.287585, Test Loss: 0.287585
# Epoch 73/120, Train Loss: 0.278609, Test Loss: 0.278609
# Epoch 74/120, Train Loss: 0.289240, Test Loss: 0.289240
# Epoch 75/120, Train Loss: 0.268009, Test Loss: 0.268009
# Epoch 76/120, Train Loss: 0.278778, Test Loss: 0.278778
# Epoch 77/120, Train Loss: 0.283920, Test Loss: 0.283920
# Epoch 78/120, Train Loss: 0.276092, Test Loss: 0.276092
# Epoch 79/120, Train Loss: 0.292863, Test Loss: 0.292863
# Epoch 80/120, Train Loss: 0.295872, Test Loss: 0.295872
# Epoch 81/120, Train Loss: 0.274536, Test Loss: 0.274536
# Epoch 82/120, Train Loss: 0.276752, Test Loss: 0.276752
# Epoch 83/120, Train Loss: 0.287217, Test Loss: 0.287217
# Epoch 84/120, Train Loss: 0.295644, Test Loss: 0.295644
# Epoch 85/120, Train Loss: 0.297922, Test Loss: 0.297922
# Epoch 86/120, Train Loss: 0.288525, Test Loss: 0.288525
# Epoch 87/120, Train Loss: 0.276980, Test Loss: 0.276980
# Epoch 88/120, Train Loss: 0.291375, Test Loss: 0.291375
# Epoch 89/120, Train Loss: 0.263980, Test Loss: 0.263980
# Epoch 90/120, Train Loss: 0.269308, Test Loss: 0.269308
# Epoch 91/120, Train Loss: 0.284850, Test Loss: 0.284850
# Epoch 92/120, Train Loss: 0.282346, Test Loss: 0.282346
# Epoch 93/120, Train Loss: 0.274480, Test Loss: 0.274480
# Epoch 94/120, Train Loss: 0.286243, Test Loss: 0.286243
# Epoch 95/120, Train Loss: 0.282284, Test Loss: 0.282284
# Epoch 96/120, Train Loss: 0.290835, Test Loss: 0.290835
# Epoch 97/120, Train Loss: 0.298106, Test Loss: 0.298106
# Epoch 98/120, Train Loss: 0.294457, Test Loss: 0.294457
# Epoch 99/120, Train Loss: 0.292902, Test Loss: 0.292902
# Epoch 100/120, Train Loss: 0.278136, Test Loss: 0.278136
# Epoch 101/120, Train Loss: 0.287566, Test Loss: 0.287566
# Epoch 102/120, Train Loss: 0.283219, Test Loss: 0.283219
# Epoch 103/120, Train Loss: 0.293037, Test Loss: 0.293037
# Epoch 104/120, Train Loss: 0.274979, Test Loss: 0.274979
# Epoch 105/120, Train Loss: 0.289721, Test Loss: 0.289721
# Epoch 106/120, Train Loss: 0.299143, Test Loss: 0.299143
# Epoch 107/120, Train Loss: 0.284302, Test Loss: 0.284302
# Epoch 108/120, Train Loss: 0.294600, Test Loss: 0.294600
# Epoch 109/120, Train Loss: 0.278690, Test Loss: 0.278690
# Epoch 110/120, Train Loss: 0.294462, Test Loss: 0.294462
# Epoch 111/120, Train Loss: 0.290575, Test Loss: 0.290575
# Epoch 112/120, Train Loss: 0.262632, Test Loss: 0.262632
# Epoch 113/120, Train Loss: 0.280989, Test Loss: 0.280989
# Epoch 114/120, Train Loss: 0.288205, Test Loss: 0.288205
# Epoch 115/120, Train Loss: 0.297866, Test Loss: 0.297866
# Epoch 116/120, Train Loss: 0.285875, Test Loss: 0.285875
# Epoch 117/120, Train Loss: 0.295503, Test Loss: 0.295503
# Epoch 118/120, Train Loss: 0.296267, Test Loss: 0.296267
# Epoch 119/120, Train Loss: 0.290314, Test Loss: 0.290314
# Epoch 120/120, Train Loss: 0.281066, Test Loss: 0.281066

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([0.2411, 0.2227, 0.2214, 0.2209, 0.2212, 0.2211, 0.2209, 0.2209, 0.2212,
#          0.2211, 0.2213, 0.2214, 0.2214, 0.2214, 0.2215, 0.2216, 0.2214, 0.2215,
#          0.2214, 0.2217, 0.2216, 0.2217, 0.2217, 0.2216, 0.2215, 0.2215, 0.2217,
#          0.2218, 0.2217, 0.2217, 0.2215, 0.2217, 0.2216, 0.2217, 0.2218, 0.2219,
#          0.2215, 0.2217, 0.2216, 0.2217, 0.2219, 0.2217, 0.2217, 0.2218, 0.2218,
#          0.2217, 0.2219, 0.2220, 0.2218, 0.2219, 0.2218, 0.2219, 0.2217, 0.2219,
#          0.2220, 0.2221, 0.2221, 0.2221, 0.2219, 0.2218, 0.2219, 0.2218, 0.2218,
#          0.2220, 0.2220, 0.2220, 0.2218, 0.2221, 0.2219, 0.2219, 0.2218, 0.2220,
#          0.2220, 0.2219, 0.2222, 0.2222, 0.2222, 0.2221, 0.2220, 0.2221, 0.2221,
#          0.2221, 0.2220, 0.2222, 0.2219, 0.2221, 0.2223, 0.2224, 0.2222, 0.2222,
#          0.2222, 0.2221, 0.2222, 0.2223, 0.2220, 0.2221, 0.2225, 0.2223, 0.2220,
#          0.2223, 0.2224, 0.2221, 0.2222, 0.2223, 0.2222, 0.2223, 0.2220, 0.2222,
#          0.2224, 0.2222, 0.2223, 0.2222, 0.2225, 0.2224, 0.2222, 0.2223, 0.2224,
#          0.2223, 0.2223, 0.2226]),
#  tensor([0.2909, 0.2879, 0.2777, 0.2835, 0.2768, 0.2919, 0.2727, 0.2756, 0.2849,
#          0.2794, 0.2819, 0.2832, 0.2859, 0.2728, 0.2741, 0.2840, 0.2907, 0.2900,
#          0.2741, 0.2752, 0.2735, 0.2857, 0.2895, 0.2988, 0.2803, 0.2872, 0.2900,
#          0.2941, 0.2944, 0.2809, 0.2801, 0.2893, 0.2829, 0.2892, 0.2772, 0.3033,
#          0.2792, 0.2968, 0.2840, 0.2667, 0.2843, 0.2813, 0.2993, 0.2957, 0.2901,
#          0.2851, 0.3042, 0.2879, 0.2735, 0.2808, 0.2873, 0.2955, 0.2850, 0.2724,
#          0.2797, 0.2882, 0.2914, 0.2822, 0.3009, 0.2796, 0.2880, 0.2733, 0.2723,
#          0.2843, 0.2870, 0.2805, 0.2641, 0.2947, 0.2770, 0.2918, 0.2825, 0.2876,
#          0.2786, 0.2892, 0.2680, 0.2788, 0.2839, 0.2761, 0.2929, 0.2959, 0.2745,
#          0.2768, 0.2872, 0.2956, 0.2979, 0.2885, 0.2770, 0.2914, 0.2640, 0.2693,
#          0.2849, 0.2823, 0.2745, 0.2862, 0.2823, 0.2908, 0.2981, 0.2945, 0.2929,
#          0.2781, 0.2876, 0.2832, 0.2930, 0.2750, 0.2897, 0.2991, 0.2843, 0.2946,
#          0.2787, 0.2945, 0.2906, 0.2626, 0.2810, 0.2882, 0.2979, 0.2859, 0.2955,
#          0.2963, 0.2903, 0.2811]),
#  tensor([0.4967, 0.5443, 0.5472, 0.5481, 0.5479, 0.5479, 0.5487, 0.5483, 0.5472,
#          0.5473, 0.5472, 0.5471, 0.5472, 0.5467, 0.5470, 0.5467, 0.5470, 0.5465,
#          0.5468, 0.5462, 0.5467, 0.5461, 0.5458, 0.5461, 0.5465, 0.5463, 0.5461,
#          0.5458, 0.5458, 0.5462, 0.5468, 0.5462, 0.5460, 0.5459, 0.5458, 0.5453,
#          0.5467, 0.5456, 0.5461, 0.5458, 0.5459, 0.5466, 0.5464, 0.5456, 0.5458,
#          0.5462, 0.5458, 0.5451, 0.5453, 0.5455, 0.5462, 0.5457, 0.5462, 0.5458,
#          0.5454, 0.5448, 0.5449, 0.5453, 0.5454, 0.5457, 0.5457, 0.5459, 0.5461,
#          0.5454, 0.5457, 0.5457, 0.5457, 0.5449, 0.5454, 0.5450, 0.5461, 0.5453,
#          0.5453, 0.5454, 0.5449, 0.5455, 0.5449, 0.5445, 0.5456, 0.5454, 0.5453,
#          0.5452, 0.5455, 0.5444, 0.5457, 0.5449, 0.5444, 0.5443, 0.5451, 0.5452,
#          0.5448, 0.5453, 0.5450, 0.5447, 0.5456, 0.5455, 0.5443, 0.5445, 0.5451,
#          0.5447, 0.5442, 0.5446, 0.5449, 0.5448, 0.5450, 0.5448, 0.5456, 0.5452,
#          0.5445, 0.5448, 0.5446, 0.5448, 0.5441, 0.5440, 0.5448, 0.5446, 0.5443,
#          0.5446, 0.5444, 0.5440]))

# %%
# (yy * data['date_int'].max()).round()

# %%
# (yHat_test * data['date_int'].max()).round()

# %%
yHat      = date_scaler.inverse_transform(yHat.detach().numpy().round()).flatten()
y         = date_scaler.inverse_transform(y.detach().numpy().round()).flatten()
yHat_test = date_scaler.inverse_transform(yHat_test.detach().numpy().round()).flatten()
yy        = date_scaler.inverse_transform(yy.detach().numpy().round()).flatten()

# %%
y[y < 0]                 = 0
yHat_test[yHat_test < 0] = 0
yy[yy < 0]               = 0
yHat_test[yHat_test < 0] = 0

# %%
yHat[yHat < 0], y[y < 0]
# Out:
# (array([], dtype=float32), array([], dtype=float32))

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.5853
#
#
# mean_absolute_error(y, yHat): 0.9023
#
# mean_absolute_error(yy, yHat_test): 1.1250
#
#
# mean_squared_error(y, yHat): 4.3320
#
# mean_squared_error(yy, yHat_test): 5.1250
#
#
# mean_squared_log_error(y, yHat): 0.2513
#
# mean_squared_log_error(yy, yHat_test): 0.3838
#
#
# RMSE(y, yHat): 2.0814
#
# RMSE(yy, yHat_test): 2.2638

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss2.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc2.jpg", bbox_inches='tight')


plt.show()

# %%
['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']
# Out:
# ['day_scaled',
#  'day_sin',
#  'day_cos',
#  'month_scaled',
#  'month_sin',
#  'month_cos',
#  'leap_year',
#  'decade_scaled',
#  'decade_sin',
#  'decade_cos']

# %%
def result_to_date(result):
    
    result = str(result)
    
    day   = int(result[6:]) - 1
    month = int(result[4:6]) - 1

    ss = str(f'{result[:4]}0101')
    
    ds = datetime.datetime.strptime(ss, '%Y%m%d')
    
    ds = ds + relativedelta(months=month, days=day)

    result = ds.strftime('%d-%m-%Y')
    
    
    return result

# %%
# (16830739, 17848869)
result_to_date(16830739), result_to_date(17848869)
# Out:
# ('08-08-1683', '08-06-1791')

# %%
def test_model(input_list):
    

    X       = np.zeros((1, 10))
    X_smote = np.zeros((1, 10))



    day       = np.array(map_day[input_list[0]])
    month     = np.array(map_month[input_list[1]])
    leap_year = map_leap_year[input_list[2]]
    decade    = np.array(input_list[3].strip('[]')).astype('int64')


    X[0, 0] = scaler_day.transform(day.reshape(-1, 1)).flatten()
    X[0, 1] = np.sin(day * (2 * np.pi / 7))
    X[0, 2] = np.cos(day * (2 * np.pi / 7))

    X[0, 3] = scaler_month.transform(month.reshape(-1, 1)).flatten()
    X[0, 4] = np.sin(month * (2 * np.pi / 12))
    X[0, 5] = np.cos(month * (2 * np.pi / 12))

    X[0, 6] = leap_year

    X[0, 7] = scaler_decade.transform(decade.reshape(-1, 1)).flatten()
    X[0, 8] = np.sin(decade * (2 * np.pi / alpha))
    X[0, 9] = np.cos(decade * (2 * np.pi / alpha))

    # ---

    X_smote[0, 0] = scaler_day_smote.transform(day.reshape(-1, 1)).flatten()
    X_smote[0, 1] = X[0, 1]
    X_smote[0, 2] = X[0, 2]

    X_smote[0, 3] = scaler_month_smote.transform(month.reshape(-1, 1)).flatten()
    X_smote[0, 4] = X[0, 4]
    X_smote[0, 5] = X[0, 5]

    X_smote[0, 6] = leap_year

    X_smote[0, 7] = scaler_decade_smote.transform(decade.reshape(-1, 1)).flatten()
    X_smote[0, 8] = np.sin(decade * (2 * np.pi / alpha_smote))
    X_smote[0, 9] = np.cos(decade * (2 * np.pi / alpha_smote))


    # ---

    result       = model(torch.tensor(X).to(device).float())
    result_smote = model_smote(torch.tensor(X_smote).to(device).float())


    # ---

    result       = date_scaler.inverse_transform(result.detach().cpu().numpy()).round()
    result_smote = date_scaler_smote.inverse_transform(result_smote.detach().cpu().numpy()).round()
    

    result       = ''.join(result.round().astype(int).astype(str).flatten())
    result_smote = ''.join(result_smote.round().astype(int).astype(str).flatten())


    
    return result_to_date(result), result_to_date(result_smote)

# %%
input_test1 = ['[MON]', '[DEC]', '[False]', '[196]']
output_test1 = '3-12-1962'

input_test2 = ['[THU]', '[DEC]', '[True]', '[204]']
output_test2 = '3-12-2048'

input_test3 = ['[WED]', '[JAN]', '[False]', '[181]']
output_test3 = '10-1-1810'


input_test4 = ['[WED]', '[JUN]', '[False]', '[209]']

# %%
test_model(input_test1), test_model(input_test2), test_model(input_test3), test_model(input_test4)
# Out:
# (('14-12-1865', '14-12-1854'),
#  ('14-12-2054', '14-12-2034'),
#  ('14-02-1824', '14-02-1824'),
#  ('14-06-2084', '14-06-2074'))

# %%
output_test1, output_test2, output_test3
# Out:
# ('3-12-1962', '3-12-2048', '10-1-1810')

# %%
# example_input = pd.read_csv('../../data/example_input.txt', sep=' ', header=None)
example_input = pd.read_csv('example_input.txt', sep=' ', header=None)


example_input.columns = ['day', 'month', 'leap_year', 'decade']

# %%
example_input
# Out:
#         day  month leap_year decade
# 0     [WED]  [JAN]   [False]  [180]
# 1     [MON]  [JAN]   [False]  [190]
# 2     [SAT]  [JAN]    [True]  [200]
# 3     [FRI]  [JAN]   [False]  [210]
# 4     [WED]  [JAN]   [False]  [220]
# ...     ...    ...       ...    ...
# 1460  [MON]  [OCT]    [True]  [214]
# 1461  [TUE]  [DEC]   [False]  [183]
# 1462  [SUN]  [DEC]   [False]  [193]
# 1463  [SAT]  [DEC]   [False]  [203]
# 1464  [THU]  [DEC]   [False]  [213]
#
# [1465 rows x 4 columns]

# %%
R       = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result'])
R_smote = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result_smote'])

# %%
example_input.iloc[0].tolist()
# Out:
# ['[WED]', '[JAN]', '[False]', '[180]']

# %%
for i in range(len(example_input)):
    R.iloc[i], R_smote.iloc[i] = test_model(example_input.iloc[i].tolist())

# %%
R
# Out:
#           result
# 0     14-02-1814
# 1     14-02-1825
# 2     14-01-2014
# 3     14-02-2114
# 4     14-01-2184
# ...          ...
# 1460  14-11-2144
# 1461  14-12-1845
# 1462  14-12-1835
# 1463  14-12-2034
# 1464  14-12-2144
#
# [1465 rows x 1 columns]

# %%
final = pd.concat([example_input, R], axis=1)
final
# Out:
#         day  month leap_year decade      result
# 0     [WED]  [JAN]   [False]  [180]  14-02-1814
# 1     [MON]  [JAN]   [False]  [190]  14-02-1825
# 2     [SAT]  [JAN]    [True]  [200]  14-01-2014
# 3     [FRI]  [JAN]   [False]  [210]  14-02-2114
# 4     [WED]  [JAN]   [False]  [220]  14-01-2184
# ...     ...    ...       ...    ...         ...
# 1460  [MON]  [OCT]    [True]  [214]  14-11-2144
# 1461  [TUE]  [DEC]   [False]  [183]  14-12-1845
# 1462  [SUN]  [DEC]   [False]  [193]  14-12-1835
# 1463  [SAT]  [DEC]   [False]  [203]  14-12-2034
# 1464  [THU]  [DEC]   [False]  [213]  14-12-2144
#
# [1465 rows x 5 columns]

# %%
final_smote = pd.concat([example_input, R_smote], axis=1)
final_smote
# Out:
#         day  month leap_year decade result_smote
# 0     [WED]  [JAN]   [False]  [180]   14-02-1814
# 1     [MON]  [JAN]   [False]  [190]   14-02-1814
# 2     [SAT]  [JAN]    [True]  [200]   14-02-2014
# 3     [FRI]  [JAN]   [False]  [210]   14-01-2114
# 4     [WED]  [JAN]   [False]  [220]   14-02-2184
# ...     ...    ...       ...    ...          ...
# 1460  [MON]  [OCT]    [True]  [214]   14-10-2134
# 1461  [TUE]  [DEC]   [False]  [183]   14-12-1824
# 1462  [SUN]  [DEC]   [False]  [193]   14-12-1824
# 1463  [SAT]  [DEC]   [False]  [203]   14-12-2024
# 1464  [THU]  [DEC]   [False]  [213]   14-12-2124
#
# [1465 rows x 5 columns]

# %%
final.to_csv('output_file.txt', sep=' ', header=None, index=False)

# %%
final_smote.to_csv('output_file_smote.txt', sep=' ', header=None, index=False)

# %% [markdown]
# Out-liers

# %% [markdown]
# Saving

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              'model_smote_state_dict': model_smote.state_dict(),
              
              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              'scaler_day_smote' : scaler_day_smote,
              'scaler_month_smote' : scaler_month_smote,
              'scaler_decade_smote' : scaler_decade_smote}


torch.save(checkpoint, 'checkpoint.pth.tar')

# %%
# checkpoint = torch.load('checkpoint.pth.tar')

# %%
# model       = Model()
# model_smote = Model()


# model.load_state_dict(checkpoint['model_state_dict'])
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
