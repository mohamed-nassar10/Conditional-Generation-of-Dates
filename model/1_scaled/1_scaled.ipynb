# %%
import datetime

import copy

import random


from dateutil.relativedelta import relativedelta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('seaborn')
# plt.style.use(['dark_background', 'ggplot'])

import seaborn as sns
# sns.set()

# import scipy
# import scipy.stats as stats


# # sympy = symbolic math in Python
# import sympy as sym
# import sympy.plotting.plot as symplot


# make the equations look nicer

# from IPython.display import display
# display.set_matplotlib_formats('svg') # Deprecated since version 7.23

# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


# %config InlineBackend.set_matplotlib_formats = ["svg"]
# %config InlineBackend.figure_formats = ["svg"]

# %%
import sklearn


from sklearn.model_selection import train_test_split


# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler     # <------------ (-1.0, 1.0)
# from sklearn.preprocessing import MinMaxScaler


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from imblearn.over_sampling import SMOTE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset, DataLoader





torch.__version__
# Out:
# '1.12.0+cu113'

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def print_score(shape, yHat, y, yHat_test, yy):
    
    
    n, p = shape
    
    R2 = r2_score(y, yHat)
    
    Adj_r2 = 1 - (1 - R2)  *  (n - 1) / (n - p - 1)
    
    print(f'Adjusted R-Squared(y, yHat): {Adj_r2:0.4f}\n\n')
    # r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
    #  R^2 score is not well-defined with less than two samples
    
    
    print(f'mean_absolute_error(y, yHat):',
          f'{mean_absolute_error(y, yHat):0.4f}\n')
    print(f'mean_absolute_error(yy, yHat_test):',
          f'{mean_absolute_error(yy, yHat_test):0.4f}\n\n')
    
    
    print(f'mean_squared_error(y, yHat):',
          f'{mean_squared_error(y, yHat):0.4f}\n')
    print(f'mean_squared_error(yy, yHat_test):',
          f'{mean_squared_error(yy, yHat_test):0.4f}\n\n')
    
    
    print(f'mean_squared_log_error(y, yHat):',
          f'{mean_squared_log_error(y, yHat):0.4f}\n')
    print(f'mean_squared_log_error(yy, yHat_test):',
          f'{mean_squared_log_error(yy, yHat_test):0.4f}\n\n')
    
    
    
    print(f'RMSE(y, yHat):',
          f'{np.sqrt( mean_squared_error(y, yHat) ):0.4f}\n')
    print(f'RMSE(yy, yHat_test):',
          f'{np.sqrt( mean_squared_error(yy, yHat_test) ):0.4f}\n\n')

# %%
# date = np.datetime64("2000-01-01")
# date_strings = date.astype(str).split('-'). 
# # >> ['2000', '01', '01']

# year_int = int(date_strings[0])

# %%
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Out:
# --2022-08-05 08:20:32--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5230713 (5.0M) [text/plain]
# Saving to: ‘data.txt’
#
# data.txt            100%[===================>]   4.99M  --.-KB/s    in 0.02s
#
# 2022-08-05 08:20:32 (202 MB/s) - ‘data.txt’ saved [5230713/5230713]
#
# --2022-08-05 08:20:32--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37732 (37K) [text/plain]
# Saving to: ‘example_input.txt’
#
# example_input.txt   100%[===================>]  36.85K  --.-KB/s    in 0.001s
#
# 2022-08-05 08:20:33 (40.8 MB/s) - ‘example_input.txt’ saved [37732/37732]

# %%
# !ls
# Out:
# data.txt  example_input.txt  sample_data

# %% [markdown]
# 'text.txt'

# %% [markdown]
# [ 1-1-1800 to 31-12-2200 ]

# %% [markdown]
# [day condition] [month condition] [leap year condition] [decade condition] date

# %% [markdown]
# [MON] [DEC] [False] [196] 3-12-1962
# [THU] [DEC] [True] [204] 3-12-2048
# [WED] [JAN] [False] [181] 10-1-1810

# %%
# data = np.loadtxt(open('text.txt','r'),delimiter=' ')
# ori = pd.read_csv('./data/data.txt', sep=' ', header=None)

ori = pd.read_csv('data.txt', sep=' ', header=None)

# %%
ori.columns = ['day', 'month', 'leap_year', 'decade', 'date']

# %%
ori
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
# data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)
# # pd.to_datetime(data.date, infer_datetime_format=False)

# %%
ori.dtypes
# Out:
# day          object
# month        object
# leap_year    object
# decade       object
# date         object
# dtype: object

# %%
# data_backup = copy.deepcopy(ori)
data = copy.deepcopy(ori)

# %%
data
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
data.date
# Out:
# 0           1-1-1800
# 1           1-1-1801
# 2           1-1-1802
# 3           1-1-1803
# 4           1-1-1804
#              ...
# 146457    31-12-2196
# 146458    31-12-2197
# 146459    31-12-2198
# 146460    31-12-2199
# 146461    31-12-2200
# Name: date, Length: 146462, dtype: object

# %%
# # data['date'] = pd.date_range('3-12-2048', periods=10)
# # data['date'] = pd.date_range('12-3-1962', periods=10)

# # 1-1-1800 to 31-12-2200
# data['date'] = pd.date_range(start='1-1-1800',end='12-31-2200')


data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)

# # data.date = data.date.dt.strftime('%d-%m-%Y')
# # data.date = pd.to_datetime(data.date.dt.strftime('%d-%m-%Y'), format='%d-%m-%Y', infer_datetime_format=False)

# %%
data.dtypes
# Out:
# day                  object
# month                object
# leap_year            object
# decade               object
# date         datetime64[ns]
# dtype: object

# %%
data
# Out:
#           day  month leap_year decade       date
# 0       [WED]  [JAN]   [False]  [180] 1800-01-01
# 1       [THU]  [JAN]   [False]  [180] 1801-01-01
# 2       [FRI]  [JAN]   [False]  [180] 1802-01-01
# 3       [SAT]  [JAN]   [False]  [180] 1803-01-01
# 4       [SUN]  [JAN]    [True]  [180] 1804-01-01
# ...       ...    ...       ...    ...        ...
# 146457  [SAT]  [DEC]    [True]  [219] 2196-12-31
# 146458  [SUN]  [DEC]   [False]  [219] 2197-12-31
# 146459  [MON]  [DEC]   [False]  [219] 2198-12-31
# 146460  [TUE]  [DEC]   [False]  [219] 2199-12-31
# 146461  [WED]  [DEC]   [False]  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %%
map_leap_year = {'[False]': int(0), '[True]' : int(1)}

data.leap_year = data.leap_year.map(map_leap_year)

# data.leap_year = data.leap_year.astype(np.float64)

# %%
data
# Out:
#           day  month  leap_year decade       date
# 0       [WED]  [JAN]          0  [180] 1800-01-01
# 1       [THU]  [JAN]          0  [180] 1801-01-01
# 2       [FRI]  [JAN]          0  [180] 1802-01-01
# 3       [SAT]  [JAN]          0  [180] 1803-01-01
# 4       [SUN]  [JAN]          1  [180] 1804-01-01
# ...       ...    ...        ...    ...        ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31
# 146459  [MON]  [DEC]          0  [219] 2198-12-31
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31
# 146461  [WED]  [DEC]          0  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %% [markdown]
# date -> timestamp

# %%
data.date.iloc[0]
# Out:
# Timestamp('1800-01-01 00:00:00')

# %%
data['date_int'] = data['date'].dt.strftime("%Y%m%d").astype(np.int64)

# %%
# date_max = data.date_int.max()
# data['date_normalized'] = data.date_int / date_max

date_scaler = RobustScaler()
data['date_scaled'] = date_scaler.fit_transform(data.date_int.values.reshape(-1, 1)).flatten()

# %%
data
# Out:
#           day  month  leap_year decade       date  date_int  date_scaled
# 0       [WED]  [JAN]          0  [180] 1800-01-01  18000101    -1.000010
# 1       [THU]  [JAN]          0  [180] 1801-01-01  18010101    -0.995011
# 2       [FRI]  [JAN]          0  [180] 1802-01-01  18020101    -0.990013
# 3       [SAT]  [JAN]          0  [180] 1803-01-01  18030101    -0.985014
# 4       [SUN]  [JAN]          1  [180] 1804-01-01  18040101    -0.980016
# ...       ...    ...        ...    ...        ...       ...          ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31  21961231     0.979980
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31  21971231     0.984979
# 146459  [MON]  [DEC]          0  [219] 2198-12-31  21981231     0.989977
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31  21991231     0.994976
# 146461  [WED]  [DEC]          0  [220] 2200-12-31  22001231     0.999974
#
# [146462 rows x 7 columns]

# %%
x = data.decade.iloc[0]
x
# Out:
# '[180]'

# %%
x.strip('[]')
# Out:
# '180'

# %%
data.decade = data.decade.apply(lambda x: x.strip('[]')).astype('int64')

# %%
# data.day = data.day.apply(lambda x: x.strip('[]'))
# data.month = data.month.apply(lambda x: x.strip('[]'))

# %%
map_day = {'[SAT]': int(0),
           '[SUN]': int(1),
           '[MON]': int(2),
           '[TUE]': int(3),
           '[WED]': int(4),
           '[THU]': int(5),
           '[FRI]': int(6)}

# %%
data['day_code'] = data.day.map(map_day)

# %%
scaler_day = RobustScaler()

x = data.day_code.values.reshape(-1, 1)

data['day_scaled'] = scaler_day.fit_transform(x).flatten()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  date_scaled  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101    -1.000010
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101    -0.995011
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101    -0.990013
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101    -0.985014
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101    -0.980016
# ...       ...    ...        ...     ...        ...       ...          ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231     0.979980
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231     0.984979
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231     0.989977
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231     0.994976
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231     0.999974
#
#         day_code  day_scaled
# 0              4        0.25
# 1              5        0.50
# 2              6        0.75
# 3              0       -0.75
# 4              1       -0.50
# ...          ...         ...
# 146457         0       -0.75
# 146458         1       -0.50
# 146459         2       -0.25
# 146460         3        0.00
# 146461         4        0.25
#
# [146462 rows x 9 columns]

# %%
data['day_sin'] = np.sin(data['day_code'] * (2 * np.pi / 7))
data['day_cos'] = np.cos(data['day_code'] * (2 * np.pi / 7))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  date_scaled  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101    -1.000010
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101    -0.995011
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101    -0.990013
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101    -0.985014
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101    -0.980016
# ...       ...    ...        ...     ...        ...       ...          ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231     0.979980
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231     0.984979
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231     0.989977
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231     0.994976
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231     0.999974
#
#         day_code  day_scaled   day_sin   day_cos
# 0              4        0.25 -0.433884 -0.900969
# 1              5        0.50 -0.974928 -0.222521
# 2              6        0.75 -0.781831  0.623490
# 3              0       -0.75  0.000000  1.000000
# 4              1       -0.50  0.781831  0.623490
# ...          ...         ...       ...       ...
# 146457         0       -0.75  0.000000  1.000000
# 146458         1       -0.50  0.781831  0.623490
# 146459         2       -0.25  0.974928 -0.222521
# 146460         3        0.00  0.433884 -0.900969
# 146461         4        0.25 -0.433884 -0.900969
#
# [146462 rows x 11 columns]

# %%
map_month = {'[JAN]' : 0,
             '[FEB]' : 1,
             '[MAR]' : 2,
             '[APR]' : 3,
             '[MAY]' : 4,
             '[JUN]' : 5,
             '[JUL]' : 6,
             '[AUG]' : 7,
             '[SEP]' : 8,
             '[OCT]' : 9,
             '[NOV]' : 10,
             '[DEC]' : 11}

# %%
data['month_code'] = data.month.map(map_month)

# %%
scaler_month = RobustScaler()

x = data.month_code.values.reshape(-1, 1)

data['month_scaled'] = scaler_month.fit_transform(x).flatten()

# %%
data['month_sin'] = np.sin(data['month_code'] * (2 * np.pi / 12))
data['month_cos'] = np.cos(data['month_code'] * (2 * np.pi / 12))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  date_scaled  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101    -1.000010
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101    -0.995011
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101    -0.990013
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101    -0.985014
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101    -0.980016
# ...       ...    ...        ...     ...        ...       ...          ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231     0.979980
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231     0.984979
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231     0.989977
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231     0.994976
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231     0.999974
#
#         day_code  day_scaled   day_sin   day_cos  month_code  month_scaled  \
# 0              4        0.25 -0.433884 -0.900969           0     -1.000000
# 1              5        0.50 -0.974928 -0.222521           0     -1.000000
# 2              6        0.75 -0.781831  0.623490           0     -1.000000
# 3              0       -0.75  0.000000  1.000000           0     -1.000000
# 4              1       -0.50  0.781831  0.623490           0     -1.000000
# ...          ...         ...       ...       ...         ...           ...
# 146457         0       -0.75  0.000000  1.000000          11      0.833333
# 146458         1       -0.50  0.781831  0.623490          11      0.833333
# 146459         2       -0.25  0.974928 -0.222521          11      0.833333
# 146460         3        0.00  0.433884 -0.900969          11      0.833333
# 146461         4        0.25 -0.433884 -0.900969          11      0.833333
#
#         month_sin  month_cos
# 0             0.0   1.000000
# 1             0.0   1.000000
# 2             0.0   1.000000
# 3             0.0   1.000000
# 4             0.0   1.000000
# ...           ...        ...
# 146457       -0.5   0.866025
# 146458       -0.5   0.866025
# 146459       -0.5   0.866025
# 146460       -0.5   0.866025
# 146461       -0.5   0.866025
#
# [146462 rows x 15 columns]

# %%
scaler_decade = RobustScaler()

x = data.decade.values.reshape(-1, 1)

data['decade_scaled'] = scaler_decade.fit_transform(x).flatten()

# %%
# alpha = len(data.decade.unique())
alpha = (data.decade.iloc[-1] - data.decade.iloc[0]) + 1

data['decade_sin'] = np.sin(data['decade'] * (2 * np.pi / alpha))
data['decade_cos'] = np.cos(data['decade'] * (2 * np.pi / alpha))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  date_scaled  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101    -1.000010
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101    -0.995011
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101    -0.990013
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101    -0.985014
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101    -0.980016
# ...       ...    ...        ...     ...        ...       ...          ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231     0.979980
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231     0.984979
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231     0.989977
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231     0.994976
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231     0.999974
#
#         day_code  day_scaled   day_sin   day_cos  month_code  month_scaled  \
# 0              4        0.25 -0.433884 -0.900969           0     -1.000000
# 1              5        0.50 -0.974928 -0.222521           0     -1.000000
# 2              6        0.75 -0.781831  0.623490           0     -1.000000
# 3              0       -0.75  0.000000  1.000000           0     -1.000000
# 4              1       -0.50  0.781831  0.623490           0     -1.000000
# ...          ...         ...       ...       ...         ...           ...
# 146457         0       -0.75  0.000000  1.000000          11      0.833333
# 146458         1       -0.50  0.781831  0.623490          11      0.833333
# 146459         2       -0.25  0.974928 -0.222521          11      0.833333
# 146460         3        0.00  0.433884 -0.900969          11      0.833333
# 146461         4        0.25 -0.433884 -0.900969          11      0.833333
#
#         month_sin  month_cos  decade_scaled  decade_sin  decade_cos
# 0             0.0   1.000000          -1.00    0.636242   -0.771489
# 1             0.0   1.000000          -1.00    0.636242   -0.771489
# 2             0.0   1.000000          -1.00    0.636242   -0.771489
# 3             0.0   1.000000          -1.00    0.636242   -0.771489
# 4             0.0   1.000000          -1.00    0.636242   -0.771489
# ...           ...        ...            ...         ...         ...
# 146457       -0.5   0.866025           0.95    0.839365   -0.543568
# 146458       -0.5   0.866025           0.95    0.839365   -0.543568
# 146459       -0.5   0.866025           0.95    0.839365   -0.543568
# 146460       -0.5   0.866025           0.95    0.839365   -0.543568
# 146461       -0.5   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 18 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# date_scaled             float64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %%
data.date_scaled.min(), data.date_scaled.max()
# Out:
# (-1.0000097471684475, 0.9999742574782026)

# %%
round(data.date_scaled.min()), round(data.date_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_scaled.min()), round(data.day_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_sin.min()), round(data.day_sin.max())
# Out:
# (-1, 1)

# %%
round(data.day_cos.min()), round(data.day_cos.max())
# Out:
# (-1, 1)

# %%
round(data.month_scaled.min()), round(data.month_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.month_sin.min()), round(data.month_sin.max())
# Out:
# (-1, 1)

# %%
round(data.month_cos.min()), round(data.month_cos.max())
# Out:
# (-1, 1)

# %%
data.leap_year.min(), data.leap_year.max()
# Out:
# (0, 1)

# %%
round(data.decade_scaled.min()), round(data.decade_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.decade_sin.min()), round(data.decade_sin.max())
# Out:
# (-1, 1)

# %%
round(data.decade_cos.min()), round(data.decade_cos.max())
# Out:
# (-1, 1)

# %% [markdown]
# Boxplot

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)

# plt.savefig("boxplot1.jpg", formate='svg', bbox_inches='tight')

# plt.show()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  date_scaled  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101    -1.000010
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101    -0.995011
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101    -0.990013
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101    -0.985014
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101    -0.980016
# ...       ...    ...        ...     ...        ...       ...          ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231     0.979980
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231     0.984979
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231     0.989977
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231     0.994976
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231     0.999974
#
#         day_code  day_scaled   day_sin   day_cos  month_code  month_scaled  \
# 0              4        0.25 -0.433884 -0.900969           0     -1.000000
# 1              5        0.50 -0.974928 -0.222521           0     -1.000000
# 2              6        0.75 -0.781831  0.623490           0     -1.000000
# 3              0       -0.75  0.000000  1.000000           0     -1.000000
# 4              1       -0.50  0.781831  0.623490           0     -1.000000
# ...          ...         ...       ...       ...         ...           ...
# 146457         0       -0.75  0.000000  1.000000          11      0.833333
# 146458         1       -0.50  0.781831  0.623490          11      0.833333
# 146459         2       -0.25  0.974928 -0.222521          11      0.833333
# 146460         3        0.00  0.433884 -0.900969          11      0.833333
# 146461         4        0.25 -0.433884 -0.900969          11      0.833333
#
#         month_sin  month_cos  decade_scaled  decade_sin  decade_cos
# 0             0.0   1.000000          -1.00    0.636242   -0.771489
# 1             0.0   1.000000          -1.00    0.636242   -0.771489
# 2             0.0   1.000000          -1.00    0.636242   -0.771489
# 3             0.0   1.000000          -1.00    0.636242   -0.771489
# 4             0.0   1.000000          -1.00    0.636242   -0.771489
# ...           ...        ...            ...         ...         ...
# 146457       -0.5   0.866025           0.95    0.839365   -0.543568
# 146458       -0.5   0.866025           0.95    0.839365   -0.543568
# 146459       -0.5   0.866025           0.95    0.839365   -0.543568
# 146460       -0.5   0.866025           0.95    0.839365   -0.543568
# 146461       -0.5   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 18 columns]

# %%
data.day.value_counts().plot(kind="bar")
plt.savefig("day1.jpg", formate='svg', bbox_inches='tight')

# %%
data.month.value_counts().plot(kind="bar")
plt.savefig("month1.jpg", formate='svg', bbox_inches='tight')

# %%
data.leap_year.value_counts().plot(kind="bar")
plt.savefig("leap_year1.jpg", formate='svg', bbox_inches='tight')

# %%
data.decade.value_counts().plot(kind="bar")
plt.savefig("decade1.jpg", formate='svg', bbox_inches='tight')

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  date_scaled  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101    -1.000010
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101    -0.995011
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101    -0.990013
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101    -0.985014
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101    -0.980016
# ...       ...    ...        ...     ...        ...       ...          ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231     0.979980
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231     0.984979
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231     0.989977
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231     0.994976
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231     0.999974
#
#         day_code  day_scaled   day_sin   day_cos  month_code  month_scaled  \
# 0              4        0.25 -0.433884 -0.900969           0     -1.000000
# 1              5        0.50 -0.974928 -0.222521           0     -1.000000
# 2              6        0.75 -0.781831  0.623490           0     -1.000000
# 3              0       -0.75  0.000000  1.000000           0     -1.000000
# 4              1       -0.50  0.781831  0.623490           0     -1.000000
# ...          ...         ...       ...       ...         ...           ...
# 146457         0       -0.75  0.000000  1.000000          11      0.833333
# 146458         1       -0.50  0.781831  0.623490          11      0.833333
# 146459         2       -0.25  0.974928 -0.222521          11      0.833333
# 146460         3        0.00  0.433884 -0.900969          11      0.833333
# 146461         4        0.25 -0.433884 -0.900969          11      0.833333
#
#         month_sin  month_cos  decade_scaled  decade_sin  decade_cos
# 0             0.0   1.000000          -1.00    0.636242   -0.771489
# 1             0.0   1.000000          -1.00    0.636242   -0.771489
# 2             0.0   1.000000          -1.00    0.636242   -0.771489
# 3             0.0   1.000000          -1.00    0.636242   -0.771489
# 4             0.0   1.000000          -1.00    0.636242   -0.771489
# ...           ...        ...            ...         ...         ...
# 146457       -0.5   0.866025           0.95    0.839365   -0.543568
# 146458       -0.5   0.866025           0.95    0.839365   -0.543568
# 146459       -0.5   0.866025           0.95    0.839365   -0.543568
# 146460       -0.5   0.866025           0.95    0.839365   -0.543568
# 146461       -0.5   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 18 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# date_scaled             float64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %% [markdown]
# ['day_sin', 'day_cos', 'month_sin', 'month_cos', 'leap_year', 'decade_scaled']
# ['date_timestamp_scaled']

# %%
X = data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
          'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 0.25      , -0.43388374, -0.90096887, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.5       , -0.97492791, -0.22252093, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.75      , -0.78183148,  0.6234898 , ..., -1.        ,
#          0.63624244, -0.77148918],
#        ...,
#        [-0.25      ,  0.97492791, -0.22252093, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.        ,  0.43388374, -0.90096887, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.25      , -0.43388374, -0.90096887, ...,  1.        ,
#          0.74655322, -0.6653257 ]])

# %%
len(X)
# Out:
# 146462

# %%
X.shape
# Out:
# (146462, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()

Y = data['date_scaled'].values.reshape(-1, 1)


Y
# Out:
# array([[-1.00000975],
#        [-0.9950112 ],
#        [-0.99001265],
#        ...,
#        [ 0.98997716],
#        [ 0.99497571],
#        [ 0.99997426]])

# %%
len(Y)
# Out:
# 146462

# %%
Y.shape
# Out:
# (146462, 1)

# %%
# # leap = np.where(~X['leap_year'] == 1)[0]
# leap = np.where(X['leap_year'] == 1)[0]

# leap

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64


train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (146462, 10)
#
# Y: (146462, 1)
#
# Train data:   (102523, 10)
#
# Train labels: (102523, 1)
#
# Test data:    (43939, 10)
#
# Test labels:  (43939, 1)

# %%
102523 % 32, 102523 % 64
# Out:
# (27, 59)

# %%
class Model(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.input = nn.Linear(10, 32)

        self.fc1 = nn.Linear(32, 128)
        self.bnorm1 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 512)
        self.bnorm2 = nn.BatchNorm1d(512)

        self.fc3 = nn.Linear(512, 64)
        self.bnorm3 = nn.BatchNorm1d(64)

        self.fc4 = nn.Linear(64, 10)
        self.bnorm4 = nn.BatchNorm1d(10)


        self.output = nn.Linear(10, 1)



    def forward(self, x):


        # print(f'training={self.training}')

        x = F.leaky_relu( self.input(x) )

        x = F.leaky_relu(self.bnorm1(self.fc1(x)))
        x = F.dropout(x, p=0.25, training=self.training)

        x = F.leaky_relu(self.bnorm2(self.fc2(x)))
        x = F.dropout(x, p=0.4, training=self.training)

        x = F.leaky_relu(self.bnorm3(self.fc3(x)))
        x = F.dropout(x, p=0.1, training=self.training)

        x = F.leaky_relu(self.bnorm4(self.fc4(x)))
        x = F.dropout(x, p=0.05, training=self.training)


        x = torch.tanh(self.output(x))
#         x = self.output(x)
        


        return x

# %%
# test_x, test_y = next(iter(train_loader))

# print(f'X: {X.shape}\n')
# print(f'Y: {Y.shape}\n')

# %%
def train(model, numepochs):

    numepochs = numepochs

    model = model
    
    
    
    # lossfun = nn.MSELoss()
    lossfun = nn.L1Loss()


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0002, betas=(0.5, 0.999), weight_decay=1e-5)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.5, 0.999), weight_decay=1e-1)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=1e-9)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
    
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    
    
    
    trainLoss = torch.zeros(numepochs)
    testLoss  = torch.zeros(numepochs)
    trainAcc  = torch.zeros(numepochs)
    # testAcc   = torch.zeros(numepochs)


    for epochi in range(numepochs):

        model.train() # switch to train mode

        batchLoss = []
        batchAcc  = []

        for X,y in train_loader:

            X = X.to(device)
            y = y.to(device)

            yHat = model(X)
            loss = lossfun(yHat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())
            # batchAcc.append( torch.mean(( yHat == y).float() ).item() )
            # batchAcc.append( torch.mean( (torch.abs(yHat - y) < 1).float() ).item() ) # <1 for rounding
            batchAcc.append( r2_score(y.detach().cpu().numpy(), yHat.detach().cpu().numpy()) )
            




        trainLoss[epochi] = np.mean(batchLoss)
        # trainAcc[epochi]  = 100*np.mean(batchAcc)
        trainAcc[epochi]  = np.mean(batchAcc)
        



        model.eval() # switch to test mode

        XX,yy = next(iter(test_loader))

        XX = XX.to(device)
        yy = yy.to(device)

        # forward pass and loss
        with torch.no_grad():
            yHat_test = model(XX)
            loss = lossfun(yHat_test, yy)


        testLoss[epochi] = loss.item()
        # testAcc[epochi]  = 100*torch.mean( (yHat_test == yy).float() ).item()
        # testAcc[epochi]  = 100*torch.mean( (torch.abs(yHat_test - yy) < 1).float() ).item()
        # testAcc[epochi]  = 100*r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
        


        # if (epochi + 1) % 5 == 0:
        print(f'Epoch {epochi+1}/{numepochs}, Train Loss: {loss.item():0.6f}, Test Loss: {loss.item():0.6f}')


        
    return trainLoss.cpu(), testLoss.cpu(), trainAcc.cpu(), yHat.cpu(), y.cpu(), yHat_test.cpu(), yy.cpu()

# %%
model = Model().to(device)

# test_hat = model(torch.randn(32,6))
# test_hat = model(test_x)

# print(test_hat.shape)

# %%
# for p in list(model.named_parameters()):
#     if 'weight' in p[0] and 'bnorm' not in p[0]:
#         nn.init.xavier_normal_(p[1].data)
#         print(p[0])
#         print(p[1].data.shape)

# %%
numepochs = 120

trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model, numepochs)
# Out:
# Epoch 1/120, Train Loss: 0.066770, Test Loss: 0.066770
# Epoch 2/120, Train Loss: 0.035803, Test Loss: 0.035803
# Epoch 3/120, Train Loss: 0.011473, Test Loss: 0.011473
# Epoch 4/120, Train Loss: 0.016274, Test Loss: 0.016274
# Epoch 5/120, Train Loss: 0.004198, Test Loss: 0.004198
# Epoch 6/120, Train Loss: 0.027022, Test Loss: 0.027022
# Epoch 7/120, Train Loss: 0.036346, Test Loss: 0.036346
# Epoch 8/120, Train Loss: 0.039415, Test Loss: 0.039415
# Epoch 9/120, Train Loss: 0.086504, Test Loss: 0.086504
# Epoch 10/120, Train Loss: 0.137284, Test Loss: 0.137284
# Epoch 11/120, Train Loss: 0.006451, Test Loss: 0.006451
# Epoch 12/120, Train Loss: 0.015296, Test Loss: 0.015296
# Epoch 13/120, Train Loss: 0.004853, Test Loss: 0.004853
# Epoch 14/120, Train Loss: 0.044376, Test Loss: 0.044376
# Epoch 15/120, Train Loss: 0.008843, Test Loss: 0.008843
# Epoch 16/120, Train Loss: 0.072431, Test Loss: 0.072431
# Epoch 17/120, Train Loss: 0.010931, Test Loss: 0.010931
# Epoch 18/120, Train Loss: 0.034526, Test Loss: 0.034526
# Epoch 19/120, Train Loss: 0.039945, Test Loss: 0.039945
# Epoch 20/120, Train Loss: 0.054760, Test Loss: 0.054760
# Epoch 21/120, Train Loss: 0.019139, Test Loss: 0.019139
# Epoch 22/120, Train Loss: 0.030528, Test Loss: 0.030528
# Epoch 23/120, Train Loss: 0.005747, Test Loss: 0.005747
# Epoch 24/120, Train Loss: 0.011062, Test Loss: 0.011062
# Epoch 25/120, Train Loss: 0.042994, Test Loss: 0.042994
# Epoch 26/120, Train Loss: 0.041213, Test Loss: 0.041213
# Epoch 27/120, Train Loss: 0.016346, Test Loss: 0.016346
# Epoch 28/120, Train Loss: 0.011748, Test Loss: 0.011748
# Epoch 29/120, Train Loss: 0.005241, Test Loss: 0.005241
# Epoch 30/120, Train Loss: 0.027153, Test Loss: 0.027153
# Epoch 31/120, Train Loss: 0.007630, Test Loss: 0.007630
# Epoch 32/120, Train Loss: 0.094583, Test Loss: 0.094583
# Epoch 33/120, Train Loss: 0.004668, Test Loss: 0.004668
# Epoch 34/120, Train Loss: 0.016922, Test Loss: 0.016922
# Epoch 35/120, Train Loss: 0.006164, Test Loss: 0.006164
# Epoch 36/120, Train Loss: 0.031316, Test Loss: 0.031316
# Epoch 37/120, Train Loss: 0.003588, Test Loss: 0.003588
# Epoch 38/120, Train Loss: 0.078607, Test Loss: 0.078607
# Epoch 39/120, Train Loss: 0.011207, Test Loss: 0.011207
# Epoch 40/120, Train Loss: 0.046347, Test Loss: 0.046347
# Epoch 41/120, Train Loss: 0.019503, Test Loss: 0.019503
# Epoch 42/120, Train Loss: 0.019401, Test Loss: 0.019401
# Epoch 43/120, Train Loss: 0.000069, Test Loss: 0.000069
# Epoch 44/120, Train Loss: 0.003974, Test Loss: 0.003974
# Epoch 45/120, Train Loss: 0.012633, Test Loss: 0.012633
# Epoch 46/120, Train Loss: 0.052154, Test Loss: 0.052154
# Epoch 47/120, Train Loss: 0.030585, Test Loss: 0.030585
# Epoch 48/120, Train Loss: 0.031142, Test Loss: 0.031142
# Epoch 49/120, Train Loss: 0.004670, Test Loss: 0.004670
# Epoch 50/120, Train Loss: 0.005271, Test Loss: 0.005271
# Epoch 51/120, Train Loss: 0.028103, Test Loss: 0.028103
# Epoch 52/120, Train Loss: 0.041225, Test Loss: 0.041225
# Epoch 53/120, Train Loss: 0.004327, Test Loss: 0.004327
# Epoch 54/120, Train Loss: 0.009707, Test Loss: 0.009707
# Epoch 55/120, Train Loss: 0.026437, Test Loss: 0.026437
# Epoch 56/120, Train Loss: 0.010566, Test Loss: 0.010566
# Epoch 57/120, Train Loss: 0.025390, Test Loss: 0.025390
# Epoch 58/120, Train Loss: 0.024418, Test Loss: 0.024418
# Epoch 59/120, Train Loss: 0.041911, Test Loss: 0.041911
# Epoch 60/120, Train Loss: 0.068110, Test Loss: 0.068110
# Epoch 61/120, Train Loss: 0.002061, Test Loss: 0.002061
# Epoch 62/120, Train Loss: 0.004481, Test Loss: 0.004481
# Epoch 63/120, Train Loss: 0.033485, Test Loss: 0.033485
# Epoch 64/120, Train Loss: 0.011886, Test Loss: 0.011886
# Epoch 65/120, Train Loss: 0.015746, Test Loss: 0.015746
# Epoch 66/120, Train Loss: 0.002973, Test Loss: 0.002973
# Epoch 67/120, Train Loss: 0.018984, Test Loss: 0.018984
# Epoch 68/120, Train Loss: 0.009269, Test Loss: 0.009269
# Epoch 69/120, Train Loss: 0.036450, Test Loss: 0.036450
# Epoch 70/120, Train Loss: 0.001175, Test Loss: 0.001175
# Epoch 71/120, Train Loss: 0.013015, Test Loss: 0.013015
# Epoch 72/120, Train Loss: 0.007236, Test Loss: 0.007236
# Epoch 73/120, Train Loss: 0.033182, Test Loss: 0.033182
# Epoch 74/120, Train Loss: 0.091176, Test Loss: 0.091176
# Epoch 75/120, Train Loss: 0.017747, Test Loss: 0.017747
# Epoch 76/120, Train Loss: 0.028742, Test Loss: 0.028742
# Epoch 77/120, Train Loss: 0.008796, Test Loss: 0.008796
# Epoch 78/120, Train Loss: 0.019321, Test Loss: 0.019321
# Epoch 79/120, Train Loss: 0.052206, Test Loss: 0.052206
# Epoch 80/120, Train Loss: 0.024197, Test Loss: 0.024197
# Epoch 81/120, Train Loss: 0.006903, Test Loss: 0.006903
# Epoch 82/120, Train Loss: 0.008098, Test Loss: 0.008098
# Epoch 83/120, Train Loss: 0.032122, Test Loss: 0.032122
# Epoch 84/120, Train Loss: 0.037479, Test Loss: 0.037479
# Epoch 85/120, Train Loss: 0.006555, Test Loss: 0.006555
# Epoch 86/120, Train Loss: 0.037749, Test Loss: 0.037749
# Epoch 87/120, Train Loss: 0.014149, Test Loss: 0.014149
# Epoch 88/120, Train Loss: 0.003245, Test Loss: 0.003245
# Epoch 89/120, Train Loss: 0.020146, Test Loss: 0.020146
# Epoch 90/120, Train Loss: 0.003585, Test Loss: 0.003585
# Epoch 91/120, Train Loss: 0.007482, Test Loss: 0.007482
# Epoch 92/120, Train Loss: 0.028828, Test Loss: 0.028828
# Epoch 93/120, Train Loss: 0.001297, Test Loss: 0.001297
# Epoch 94/120, Train Loss: 0.018533, Test Loss: 0.018533
# Epoch 95/120, Train Loss: 0.055859, Test Loss: 0.055859
# Epoch 96/120, Train Loss: 0.037549, Test Loss: 0.037549
# Epoch 97/120, Train Loss: 0.033107, Test Loss: 0.033107
# Epoch 98/120, Train Loss: 0.022454, Test Loss: 0.022454
# Epoch 99/120, Train Loss: 0.009310, Test Loss: 0.009310
# Epoch 100/120, Train Loss: 0.023354, Test Loss: 0.023354
# Epoch 101/120, Train Loss: 0.002713, Test Loss: 0.002713
# Epoch 102/120, Train Loss: 0.014537, Test Loss: 0.014537
# Epoch 103/120, Train Loss: 0.013188, Test Loss: 0.013188
# Epoch 104/120, Train Loss: 0.024921, Test Loss: 0.024921
# Epoch 105/120, Train Loss: 0.000991, Test Loss: 0.000991
# Epoch 106/120, Train Loss: 0.029470, Test Loss: 0.029470
# Epoch 107/120, Train Loss: 0.010572, Test Loss: 0.010572
# Epoch 108/120, Train Loss: 0.003561, Test Loss: 0.003561
# Epoch 109/120, Train Loss: 0.009061, Test Loss: 0.009061
# Epoch 110/120, Train Loss: 0.017366, Test Loss: 0.017366
# Epoch 111/120, Train Loss: 0.017962, Test Loss: 0.017962
# Epoch 112/120, Train Loss: 0.013725, Test Loss: 0.013725
# Epoch 113/120, Train Loss: 0.036166, Test Loss: 0.036166
# Epoch 114/120, Train Loss: 0.052234, Test Loss: 0.052234
# Epoch 115/120, Train Loss: 0.058249, Test Loss: 0.058249
# Epoch 116/120, Train Loss: 0.014199, Test Loss: 0.014199
# Epoch 117/120, Train Loss: 0.027668, Test Loss: 0.027668
# Epoch 118/120, Train Loss: 0.019532, Test Loss: 0.019532
# Epoch 119/120, Train Loss: 0.021030, Test Loss: 0.021030
# Epoch 120/120, Train Loss: 0.013516, Test Loss: 0.013516

# %%
# r2_score(y.detach().numpy(), yHat.detach().numpy())
# type(r2_score(y.detach(), yHat.detach()))

# %%
# torch.mean( r2_score(y.detach().numpy(), yHat.detach().numpy()) ).item()

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([0.0793, 0.0695, 0.0672, 0.0664, 0.0662, 0.0666, 0.0660, 0.0660, 0.0662,
#          0.0663, 0.0662, 0.0664, 0.0667, 0.0667, 0.0665, 0.0663, 0.0666, 0.0668,
#          0.0667, 0.0669, 0.0662, 0.0670, 0.0670, 0.0667, 0.0670, 0.0666, 0.0671,
#          0.0668, 0.0667, 0.0671, 0.0667, 0.0668, 0.0666, 0.0666, 0.0673, 0.0668,
#          0.0665, 0.0667, 0.0671, 0.0673, 0.0670, 0.0667, 0.0671, 0.0665, 0.0666,
#          0.0668, 0.0668, 0.0669, 0.0666, 0.0668, 0.0671, 0.0670, 0.0670, 0.0665,
#          0.0664, 0.0671, 0.0667, 0.0671, 0.0668, 0.0670, 0.0668, 0.0670, 0.0669,
#          0.0667, 0.0670, 0.0674, 0.0671, 0.0672, 0.0670, 0.0669, 0.0670, 0.0672,
#          0.0670, 0.0671, 0.0674, 0.0673, 0.0674, 0.0673, 0.0673, 0.0676, 0.0669,
#          0.0675, 0.0675, 0.0669, 0.0671, 0.0676, 0.0673, 0.0672, 0.0669, 0.0668,
#          0.0668, 0.0671, 0.0669, 0.0671, 0.0667, 0.0670, 0.0667, 0.0670, 0.0671,
#          0.0672, 0.0668, 0.0672, 0.0668, 0.0670, 0.0670, 0.0672, 0.0671, 0.0668,
#          0.0671, 0.0668, 0.0668, 0.0672, 0.0676, 0.0672, 0.0674, 0.0673, 0.0670,
#          0.0672, 0.0677, 0.0669]),
#  tensor([6.6770e-02, 3.5803e-02, 1.1473e-02, 1.6274e-02, 4.1976e-03, 2.7022e-02,
#          3.6346e-02, 3.9415e-02, 8.6504e-02, 1.3728e-01, 6.4507e-03, 1.5296e-02,
#          4.8530e-03, 4.4376e-02, 8.8432e-03, 7.2431e-02, 1.0931e-02, 3.4526e-02,
#          3.9945e-02, 5.4760e-02, 1.9139e-02, 3.0528e-02, 5.7470e-03, 1.1062e-02,
#          4.2994e-02, 4.1213e-02, 1.6346e-02, 1.1748e-02, 5.2406e-03, 2.7153e-02,
#          7.6303e-03, 9.4583e-02, 4.6682e-03, 1.6922e-02, 6.1644e-03, 3.1316e-02,
#          3.5878e-03, 7.8607e-02, 1.1207e-02, 4.6347e-02, 1.9503e-02, 1.9401e-02,
#          6.8903e-05, 3.9738e-03, 1.2633e-02, 5.2154e-02, 3.0585e-02, 3.1142e-02,
#          4.6698e-03, 5.2706e-03, 2.8103e-02, 4.1225e-02, 4.3267e-03, 9.7069e-03,
#          2.6437e-02, 1.0566e-02, 2.5390e-02, 2.4418e-02, 4.1911e-02, 6.8110e-02,
#          2.0610e-03, 4.4811e-03, 3.3485e-02, 1.1886e-02, 1.5746e-02, 2.9725e-03,
#          1.8984e-02, 9.2693e-03, 3.6450e-02, 1.1750e-03, 1.3015e-02, 7.2364e-03,
#          3.3182e-02, 9.1176e-02, 1.7747e-02, 2.8742e-02, 8.7959e-03, 1.9321e-02,
#          5.2206e-02, 2.4197e-02, 6.9034e-03, 8.0977e-03, 3.2122e-02, 3.7479e-02,
#          6.5546e-03, 3.7749e-02, 1.4149e-02, 3.2449e-03, 2.0146e-02, 3.5845e-03,
#          7.4824e-03, 2.8828e-02, 1.2970e-03, 1.8533e-02, 5.5859e-02, 3.7549e-02,
#          3.3107e-02, 2.2454e-02, 9.3104e-03, 2.3354e-02, 2.7128e-03, 1.4537e-02,
#          1.3188e-02, 2.4921e-02, 9.9128e-04, 2.9470e-02, 1.0572e-02, 3.5614e-03,
#          9.0608e-03, 1.7366e-02, 1.7962e-02, 1.3725e-02, 3.6166e-02, 5.2234e-02,
#          5.8249e-02, 1.4199e-02, 2.7668e-02, 1.9532e-02, 2.1030e-02, 1.3516e-02]),
#  tensor([0.9632, 0.9732, 0.9750, 0.9756, 0.9757, 0.9754, 0.9758, 0.9757, 0.9757,
#          0.9757, 0.9756, 0.9754, 0.9753, 0.9753, 0.9755, 0.9755, 0.9754, 0.9753,
#          0.9753, 0.9752, 0.9756, 0.9751, 0.9752, 0.9752, 0.9750, 0.9753, 0.9751,
#          0.9752, 0.9751, 0.9750, 0.9752, 0.9753, 0.9753, 0.9755, 0.9748, 0.9752,
#          0.9754, 0.9752, 0.9750, 0.9749, 0.9751, 0.9753, 0.9750, 0.9755, 0.9753,
#          0.9753, 0.9752, 0.9753, 0.9755, 0.9752, 0.9749, 0.9751, 0.9750, 0.9753,
#          0.9755, 0.9748, 0.9753, 0.9751, 0.9752, 0.9752, 0.9752, 0.9752, 0.9750,
#          0.9752, 0.9750, 0.9747, 0.9751, 0.9748, 0.9751, 0.9750, 0.9752, 0.9750,
#          0.9752, 0.9749, 0.9749, 0.9749, 0.9749, 0.9746, 0.9749, 0.9746, 0.9751,
#          0.9748, 0.9746, 0.9751, 0.9750, 0.9746, 0.9747, 0.9750, 0.9751, 0.9752,
#          0.9751, 0.9749, 0.9753, 0.9748, 0.9751, 0.9751, 0.9752, 0.9751, 0.9749,
#          0.9748, 0.9752, 0.9749, 0.9751, 0.9751, 0.9751, 0.9750, 0.9751, 0.9752,
#          0.9750, 0.9751, 0.9752, 0.9749, 0.9747, 0.9751, 0.9749, 0.9749, 0.9750,
#          0.9749, 0.9744, 0.9751]))

# %%
# batchLoss

# %%
# batchAcc

# %%
# yHat.shape, y.shape

# %%
# yHat_test.shape, yy.shape

# %%
yHat.flatten(), y.flatten()
# Out:
# (tensor([ 0.9212,  0.3281,  0.1698,  0.6751,  0.8692, -0.2511, -0.9682,  0.4905,
#          -0.1907, -0.2792,  0.8949,  0.8607,  0.4144,  0.3748, -0.4435, -0.9301,
#          -0.3473,  0.8035,  0.7401,  0.4263, -0.1105, -0.4372, -0.9589, -0.9063,
#          -0.5101, -0.5006,  0.5452, -0.2680, -0.0240,  0.5404, -0.6674,  0.1673],
#         grad_fn=<ReshapeAliasBackward0>),
#  tensor([ 0.9245,  0.4446,  0.2897,  0.7098,  0.9498, -0.2152, -0.9899,  0.4651,
#          -0.1797, -0.4799,  0.8198,  0.9395,  0.4297,  0.4396, -0.4948, -0.9696,
#          -0.3449,  0.7545,  0.7999,  0.4851, -0.1048, -0.4049, -0.9947, -0.9950,
#          -0.5299, -0.5501,  0.6248, -0.2900,  0.0051,  0.6300, -0.7297,  0.1999]))

# %%
yHat_test, yy
# Out:
# (tensor([[-0.9333]]), tensor([[-0.9198]]))

# %%
Y
date_scaler.inverse_transform(torch.tensor(Y))
# Out:
# array([[18000101.],
#        [18010101.],
#        [18020101.],
#        ...,
#        [21981231.],
#        [21991231.],
#        [22001231.]])

# %%
# (yy * data['date_int'].max()).round()
date_scaler.inverse_transform(yy).round()
# Out:
# array([[18160601.]])

# %%
# (yHat_test * data['date_int'].max()).round()
date_scaler.inverse_transform(yHat_test).round()
# Out:
# array([[18133562.]])

# %%
# (yHat.flatten() * data['date_int'].max()).round(), (y.flatten() * data['date_int'].max()).round()
date_scaler.inverse_transform(yHat.detach().numpy()).flatten(), date_scaler.inverse_transform(y.detach().numpy()).flatten()
# Out:
# (array([21843580., 20657186., 20340378., 21351272., 21739602., 19498422.,
#         18063712., 20981928., 19619140., 19442196., 21791092., 21722654.,
#         20829838., 20750484., 19113508., 18139946., 19305820., 21608082.,
#         21481246., 20853532., 19779566., 19126000., 18082332., 18187538.,
#         18980300., 18999296., 21091424., 19464480., 19952626., 21081868.,
#         18665434., 20335406.], dtype=float32),
#  array([21850318., 20890224., 20580328., 21420704., 21900806., 19570104.,
#         18020314., 20931118., 19641210., 19040704., 21640816., 21880220.,
#         20860404., 20880120., 19010724., 18060910., 19310610., 21510120.,
#         21601012., 20971228., 19791116., 19190720., 18010824., 18010212.,
#         18940604., 18900228., 21250726., 19420512., 20010808., 21261024.,
#         18540818., 20400526.], dtype=float32))

# %%
yHat      = date_scaler.inverse_transform(yHat.detach().numpy()).flatten()
y         = date_scaler.inverse_transform(y.detach().numpy()).flatten()
yHat_test = date_scaler.inverse_transform(yHat_test.detach().numpy()).flatten()
yy        = date_scaler.inverse_transform(yy.detach().numpy()).flatten()

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.9889
#
#
# mean_absolute_error(y, yHat): 105753.2500
#
# mean_absolute_error(yy, yHat_test): 27038.0000
#
#
# mean_squared_error(y, yHat): 17769713664.0000
#
# mean_squared_error(yy, yHat_test): 731053440.0000
#
#
# mean_squared_log_error(y, yHat): 0.0000
#
# mean_squared_log_error(yy, yHat_test): 0.0000
#
#
# RMSE(y, yHat): 133303.0938
#
# RMSE(yy, yHat_test): 27038.0000

# %%
# create a 1D smoothing filter
def smooth(x, k=15):
    return np.convolve(x, np.ones(k)/k, mode='same')

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss1.jpg", formate='svg', bbox_inches='tight')




plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc1.jpg", formate='svg', bbox_inches='tight')



plt.show()

# %%
data.leap_year.value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
resampler = SMOTE(k_neighbors=20, random_state=0)

# %%
X_res, y_res = resampler.fit_resample(data[['day_code', 'month_code', 'decade', 'date_int']], data['leap_year'])

# %%
y_res.value_counts()
# Out:
# 0    110960
# 1    110960
# Name: leap_year, dtype: int64

# %%
data['leap_year'].value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  date_scaled  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101    -1.000010
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101    -0.995011
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101    -0.990013
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101    -0.985014
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101    -0.980016
# ...       ...    ...        ...     ...        ...       ...          ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231     0.979980
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231     0.984979
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231     0.989977
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231     0.994976
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231     0.999974
#
#         day_code  day_scaled   day_sin   day_cos  month_code  month_scaled  \
# 0              4        0.25 -0.433884 -0.900969           0     -1.000000
# 1              5        0.50 -0.974928 -0.222521           0     -1.000000
# 2              6        0.75 -0.781831  0.623490           0     -1.000000
# 3              0       -0.75  0.000000  1.000000           0     -1.000000
# 4              1       -0.50  0.781831  0.623490           0     -1.000000
# ...          ...         ...       ...       ...         ...           ...
# 146457         0       -0.75  0.000000  1.000000          11      0.833333
# 146458         1       -0.50  0.781831  0.623490          11      0.833333
# 146459         2       -0.25  0.974928 -0.222521          11      0.833333
# 146460         3        0.00  0.433884 -0.900969          11      0.833333
# 146461         4        0.25 -0.433884 -0.900969          11      0.833333
#
#         month_sin  month_cos  decade_scaled  decade_sin  decade_cos
# 0             0.0   1.000000          -1.00    0.636242   -0.771489
# 1             0.0   1.000000          -1.00    0.636242   -0.771489
# 2             0.0   1.000000          -1.00    0.636242   -0.771489
# 3             0.0   1.000000          -1.00    0.636242   -0.771489
# 4             0.0   1.000000          -1.00    0.636242   -0.771489
# ...           ...        ...            ...         ...         ...
# 146457       -0.5   0.866025           0.95    0.839365   -0.543568
# 146458       -0.5   0.866025           0.95    0.839365   -0.543568
# 146459       -0.5   0.866025           0.95    0.839365   -0.543568
# 146460       -0.5   0.866025           0.95    0.839365   -0.543568
# 146461       -0.5   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 18 columns]

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 221915    1
# 221916    1
# 221917    1
# 221918    1
# 221919    1
# Name: leap_year, Length: 221920, dtype: int64

# %%
X_res
# Out:
#         day_code  month_code  decade  date_int
# 0              4           0     180  18000101
# 1              5           0     180  18010101
# 2              6           0     180  18020101
# 3              0           0     180  18030101
# 4              1           0     180  18040101
# ...          ...         ...     ...       ...
# 221915         0           5     188  18880618
# 221916         2           6     188  18840705
# 221917         5           2     218  21800323
# 221918         1           5     199  19960602
# 221919         1           4     219  21960520
#
# [221920 rows x 4 columns]

# %%
X_smote = X_res.assign(leap_year=y_res)

# %%
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221915         0           5     188  18880618          1
# 221916         2           6     188  18840705          1
# 221917         5           2     218  21800323          1
# 221918         1           5     199  19960602          1
# 221919         1           4     219  21960520          1
#
# [221920 rows x 5 columns]

# %% [markdown]
# Drop 220 decade

# %%
# data.decade.value_counts().plot(kind="bar")
X_smote.decade.value_counts().plot(kind="bar")
plt.savefig("decade2.jpg", formate='svg', bbox_inches='tight')

# %%
# data.decade.value_counts()[-5:]
X_smote.decade.value_counts()[-5:]
# Out:
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# 220     365
# Name: decade, dtype: int64

# %%
X_smote = X_smote.drop(X_smote.index[X_smote['decade'] == 220]).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221550         0           5     188  18880618          1
# 221551         2           6     188  18840705          1
# 221552         5           2     218  21800323          1
# 221553         1           5     199  19960602          1
# 221554         1           4     219  21960520          1
#
# [221555 rows x 5 columns]

# %%
X_smote.decade.value_counts().plot(kind="bar")
plt.savefig("decade3.jpg", formate='svg', bbox_inches='tight')

# %%
X_smote.decade.value_counts()[-5:]
# Out:
# 209    5174
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# Name: decade, dtype: int64

# %% [markdown]
# code is required to only work for dates in the range  [ 1-1-1800 to 31-12-2200 ]

# %%
X_smote.date_int.max()
# Out:
# 21991231

# %%
datetime.datetime.strptime(str(X_smote.date_int.max()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '31-12-2199'

# %%
X_smote.date_int.min()
# Out:
# 18000101

# %%
datetime.datetime.strptime(str(X_smote.date_int.min()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '01-01-1800'

# %%
Y_smote = X_smote['date_int']
Y_smote
# Out:
# 0         18000101
# 1         18010101
# 2         18020101
# 3         18030101
# 4         18040101
#             ...
# 221550    18880618
# 221551    18840705
# 221552    21800323
# 221553    19960602
# 221554    21960520
# Name: date_int, Length: 221555, dtype: int64

# %%
X_smote = X_smote.drop('date_int', axis=1).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  leap_year
# 0              4           0     180          0
# 1              5           0     180          0
# 2              6           0     180          0
# 3              0           0     180          0
# 4              1           0     180          1
# ...          ...         ...     ...        ...
# 221550         0           5     188          1
# 221551         2           6     188          1
# 221552         5           2     218          1
# 221553         1           5     199          1
# 221554         1           4     219          1
#
# [221555 rows x 4 columns]

# %%
Y_smote = Y_smote.reset_index(drop=True)

date_scaler_smote = RobustScaler()

Y_smote = date_scaler_smote.fit_transform(Y_smote.values.reshape(-1, 1))

Y_smote
# Out:
# array([[-1.00529172],
#        [-1.00026635],
#        [-0.99524097],
#        ...,
#        [ 0.90446354],
#        [-0.02006583],
#        [ 0.98496859]])

# %%
# data.index[data['leap_year'] == 1].tolist()
# data.index[data['leap_year'] == 1]

# %%
# for i,idx in enumerate(data['leap_year'].tolist()):
#     print(i, idx)

# %% [markdown]
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1 <---
# 5 0
# 6 0
# 7 0
# 8 1 <---
# 9 0
# 10 0
# 11 0
# 12 1 <---
# 13 0
# 14 0
# 15 0
# 16 1 <---
# 17 0
# 18 0
# 19 0
# 20 1 <---
# 21 0
# 22 0
# 23 0
# 24 1 <---
# 25 0
# 26 0
# 27 0
# 28 1 <---
# 29 0
# 30 0

# %%
scaler_day_smote = RobustScaler()

x = X_smote.day_code.values.reshape(-1, 1)

X_smote['day_scaled'] = scaler_day_smote.fit_transform(x).flatten()

# %%
X_smote['day_sin'] = np.sin(X_smote['day_code'] * (2 * np.pi / 7))
X_smote['day_cos'] = np.cos(X_smote['day_code'] * (2 * np.pi / 7))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos
# 0      -0.900969
# 1      -0.222521
# 2       0.623490
# 3       1.000000
# 4       0.623490
# ...          ...
# 221550  1.000000
# 221551 -0.222521
# 221552 -0.222521
# 221553  0.623490
# 221554  0.623490
#
# [221555 rows x 7 columns]

# %%
scaler_month_smote = RobustScaler()

x = X_smote.month_code.values.reshape(-1, 1)

X_smote['month_scaled'] = scaler_month_smote.fit_transform(x).flatten()

# %%
X_smote['month_sin'] = np.sin(X_smote['month_code'] * (2 * np.pi / 12))
X_smote['month_cos'] = np.cos(X_smote['month_code'] * (2 * np.pi / 12))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos
# 0      -0.900969     -1.000000  0.000000e+00   1.000000
# 1      -0.222521     -1.000000  0.000000e+00   1.000000
# 2       0.623490     -1.000000  0.000000e+00   1.000000
# 3       1.000000     -1.000000  0.000000e+00   1.000000
# 4       0.623490     -1.000000  0.000000e+00   1.000000
# ...          ...           ...           ...        ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000
#
# [221555 rows x 10 columns]

# %%
scaler_decade_smote = RobustScaler()

x = X_smote.decade.values.reshape(-1, 1)

X_smote['decade_scaled'] = scaler_decade_smote.fit_transform(x).flatten()

# %%
# alpha_smote = len(X_smote.decade.unique())
alpha_smote = (X_smote.decade.iloc[-1] - X_smote.decade.iloc[0]) + 1

X_smote['decade_sin'] = np.sin(X_smote['decade'] * (2 * np.pi / alpha_smote))
X_smote['decade_cos'] = np.cos(X_smote['decade'] * (2 * np.pi / alpha_smote))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos  decade_scaled  \
# 0      -0.900969     -1.000000  0.000000e+00   1.000000      -1.052632
# 1      -0.222521     -1.000000  0.000000e+00   1.000000      -1.052632
# 2       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# 3       1.000000     -1.000000  0.000000e+00   1.000000      -1.052632
# 4       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# ...          ...           ...           ...        ...            ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025      -0.631579
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000      -0.631579
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000       0.947368
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025      -0.052632
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000       1.000000
#
#           decade_sin  decade_cos
# 0       1.102182e-15   -1.000000
# 1       1.102182e-15   -1.000000
# 2       1.102182e-15   -1.000000
# 3       1.102182e-15   -1.000000
# 4       1.102182e-15   -1.000000
# ...              ...         ...
# 221550 -9.510565e-01   -0.309017
# 221551 -9.510565e-01   -0.309017
# 221552  3.090170e-01   -0.951057
# 221553 -1.564345e-01    0.987688
# 221554  1.564345e-01   -0.987688
#
# [221555 rows x 13 columns]

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)

# plt.savefig("boxplot2.jpg", formate='svg', bbox_inches='tight')

# plt.show()

# %%
X = X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 3.33333333e-01, -4.33883739e-01, -9.00968868e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 1.00000000e+00, -7.81831482e-01,  6.23489802e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        ...,
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#          9.47368421e-01,  3.09016994e-01, -9.51056516e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#         -5.26315789e-02, -1.56434465e-01,  9.87688341e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#          1.00000000e+00,  1.56434465e-01, -9.87688341e-01]])

# %%
X.shape
# Out:
# (221555, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()
# Y = data['date_normalized'].values.reshape(-1, 1)
Y = Y_smote


Y
# Out:
# array([[-1.00529172],
#        [-1.00026635],
#        [-0.99524097],
#        ...,
#        [ 0.90446354],
#        [-0.02006583],
#        [ 0.98496859]])

# %%
Y.shape
# Out:
# (221555, 1)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64

train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (221555, 10)
#
# Y: (221555, 1)
#
# Train data:   (155088, 10)
#
# Train labels: (155088, 1)
#
# Test data:    (66467, 10)
#
# Test labels:  (66467, 1)

# %%
model_smote = Model().to(device)

# %%
numepochs = 120

trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model_smote, numepochs)
# Out:
# Epoch 1/120, Train Loss: 0.012445, Test Loss: 0.012445
# Epoch 2/120, Train Loss: 0.005833, Test Loss: 0.005833
# Epoch 3/120, Train Loss: 0.029790, Test Loss: 0.029790
# Epoch 4/120, Train Loss: 0.056163, Test Loss: 0.056163
# Epoch 5/120, Train Loss: 0.072239, Test Loss: 0.072239
# Epoch 6/120, Train Loss: 0.030108, Test Loss: 0.030108
# Epoch 7/120, Train Loss: 0.046982, Test Loss: 0.046982
# Epoch 8/120, Train Loss: 0.034065, Test Loss: 0.034065
# Epoch 9/120, Train Loss: 0.018995, Test Loss: 0.018995
# Epoch 10/120, Train Loss: 0.024921, Test Loss: 0.024921
# Epoch 11/120, Train Loss: 0.026974, Test Loss: 0.026974
# Epoch 12/120, Train Loss: 0.024859, Test Loss: 0.024859
# Epoch 13/120, Train Loss: 0.020708, Test Loss: 0.020708
# Epoch 14/120, Train Loss: 0.069751, Test Loss: 0.069751
# Epoch 15/120, Train Loss: 0.048718, Test Loss: 0.048718
# Epoch 16/120, Train Loss: 0.030983, Test Loss: 0.030983
# Epoch 17/120, Train Loss: 0.007384, Test Loss: 0.007384
# Epoch 18/120, Train Loss: 0.039869, Test Loss: 0.039869
# Epoch 19/120, Train Loss: 0.010399, Test Loss: 0.010399
# Epoch 20/120, Train Loss: 0.000816, Test Loss: 0.000816
# Epoch 21/120, Train Loss: 0.017382, Test Loss: 0.017382
# Epoch 22/120, Train Loss: 0.043039, Test Loss: 0.043039
# Epoch 23/120, Train Loss: 0.008377, Test Loss: 0.008377
# Epoch 24/120, Train Loss: 0.040045, Test Loss: 0.040045
# Epoch 25/120, Train Loss: 0.004055, Test Loss: 0.004055
# Epoch 26/120, Train Loss: 0.026978, Test Loss: 0.026978
# Epoch 27/120, Train Loss: 0.020594, Test Loss: 0.020594
# Epoch 28/120, Train Loss: 0.008996, Test Loss: 0.008996
# Epoch 29/120, Train Loss: 0.019327, Test Loss: 0.019327
# Epoch 30/120, Train Loss: 0.021523, Test Loss: 0.021523
# Epoch 31/120, Train Loss: 0.031578, Test Loss: 0.031578
# Epoch 32/120, Train Loss: 0.001142, Test Loss: 0.001142
# Epoch 33/120, Train Loss: 0.087833, Test Loss: 0.087833
# Epoch 34/120, Train Loss: 0.015598, Test Loss: 0.015598
# Epoch 35/120, Train Loss: 0.052999, Test Loss: 0.052999
# Epoch 36/120, Train Loss: 0.043627, Test Loss: 0.043627
# Epoch 37/120, Train Loss: 0.010575, Test Loss: 0.010575
# Epoch 38/120, Train Loss: 0.003124, Test Loss: 0.003124
# Epoch 39/120, Train Loss: 0.025241, Test Loss: 0.025241
# Epoch 40/120, Train Loss: 0.018842, Test Loss: 0.018842
# Epoch 41/120, Train Loss: 0.001254, Test Loss: 0.001254
# Epoch 42/120, Train Loss: 0.006204, Test Loss: 0.006204
# Epoch 43/120, Train Loss: 0.060538, Test Loss: 0.060538
# Epoch 44/120, Train Loss: 0.033060, Test Loss: 0.033060
# Epoch 45/120, Train Loss: 0.045440, Test Loss: 0.045440
# Epoch 46/120, Train Loss: 0.002234, Test Loss: 0.002234
# Epoch 47/120, Train Loss: 0.001349, Test Loss: 0.001349
# Epoch 48/120, Train Loss: 0.024476, Test Loss: 0.024476
# Epoch 49/120, Train Loss: 0.023339, Test Loss: 0.023339
# Epoch 50/120, Train Loss: 0.023114, Test Loss: 0.023114
# Epoch 51/120, Train Loss: 0.024790, Test Loss: 0.024790
# Epoch 52/120, Train Loss: 0.036331, Test Loss: 0.036331
# Epoch 53/120, Train Loss: 0.013782, Test Loss: 0.013782
# Epoch 54/120, Train Loss: 0.011752, Test Loss: 0.011752
# Epoch 55/120, Train Loss: 0.008479, Test Loss: 0.008479
# Epoch 56/120, Train Loss: 0.057680, Test Loss: 0.057680
# Epoch 57/120, Train Loss: 0.012823, Test Loss: 0.012823
# Epoch 58/120, Train Loss: 0.039355, Test Loss: 0.039355
# Epoch 59/120, Train Loss: 0.020451, Test Loss: 0.020451
# Epoch 60/120, Train Loss: 0.007174, Test Loss: 0.007174
# Epoch 61/120, Train Loss: 0.042238, Test Loss: 0.042238
# Epoch 62/120, Train Loss: 0.011515, Test Loss: 0.011515
# Epoch 63/120, Train Loss: 0.034596, Test Loss: 0.034596
# Epoch 64/120, Train Loss: 0.052204, Test Loss: 0.052204
# Epoch 65/120, Train Loss: 0.035816, Test Loss: 0.035816
# Epoch 66/120, Train Loss: 0.029984, Test Loss: 0.029984
# Epoch 67/120, Train Loss: 0.033186, Test Loss: 0.033186
# Epoch 68/120, Train Loss: 0.044546, Test Loss: 0.044546
# Epoch 69/120, Train Loss: 0.045914, Test Loss: 0.045914
# Epoch 70/120, Train Loss: 0.044271, Test Loss: 0.044271
# Epoch 71/120, Train Loss: 0.037677, Test Loss: 0.037677
# Epoch 72/120, Train Loss: 0.040105, Test Loss: 0.040105
# Epoch 73/120, Train Loss: 0.036774, Test Loss: 0.036774
# Epoch 74/120, Train Loss: 0.005296, Test Loss: 0.005296
# Epoch 75/120, Train Loss: 0.049952, Test Loss: 0.049952
# Epoch 76/120, Train Loss: 0.029145, Test Loss: 0.029145
# Epoch 77/120, Train Loss: 0.043914, Test Loss: 0.043914
# Epoch 78/120, Train Loss: 0.016025, Test Loss: 0.016025
# Epoch 79/120, Train Loss: 0.013517, Test Loss: 0.013517
# Epoch 80/120, Train Loss: 0.011248, Test Loss: 0.011248
# Epoch 81/120, Train Loss: 0.040682, Test Loss: 0.040682
# Epoch 82/120, Train Loss: 0.028425, Test Loss: 0.028425
# Epoch 83/120, Train Loss: 0.030589, Test Loss: 0.030589
# Epoch 84/120, Train Loss: 0.032983, Test Loss: 0.032983
# Epoch 85/120, Train Loss: 0.002751, Test Loss: 0.002751
# Epoch 86/120, Train Loss: 0.034287, Test Loss: 0.034287
# Epoch 87/120, Train Loss: 0.069001, Test Loss: 0.069001
# Epoch 88/120, Train Loss: 0.005315, Test Loss: 0.005315
# Epoch 89/120, Train Loss: 0.037061, Test Loss: 0.037061
# Epoch 90/120, Train Loss: 0.054048, Test Loss: 0.054048
# Epoch 91/120, Train Loss: 0.015007, Test Loss: 0.015007
# Epoch 92/120, Train Loss: 0.000575, Test Loss: 0.000575
# Epoch 93/120, Train Loss: 0.003786, Test Loss: 0.003786
# Epoch 94/120, Train Loss: 0.054568, Test Loss: 0.054568
# Epoch 95/120, Train Loss: 0.000183, Test Loss: 0.000183
# Epoch 96/120, Train Loss: 0.041881, Test Loss: 0.041881
# Epoch 97/120, Train Loss: 0.004860, Test Loss: 0.004860
# Epoch 98/120, Train Loss: 0.051072, Test Loss: 0.051072
# Epoch 99/120, Train Loss: 0.010590, Test Loss: 0.010590
# Epoch 100/120, Train Loss: 0.041063, Test Loss: 0.041063
# Epoch 101/120, Train Loss: 0.017471, Test Loss: 0.017471
# Epoch 102/120, Train Loss: 0.047832, Test Loss: 0.047832
# Epoch 103/120, Train Loss: 0.033727, Test Loss: 0.033727
# Epoch 104/120, Train Loss: 0.049563, Test Loss: 0.049563
# Epoch 105/120, Train Loss: 0.027104, Test Loss: 0.027104
# Epoch 106/120, Train Loss: 0.008404, Test Loss: 0.008404
# Epoch 107/120, Train Loss: 0.000761, Test Loss: 0.000761
# Epoch 108/120, Train Loss: 0.012227, Test Loss: 0.012227
# Epoch 109/120, Train Loss: 0.028205, Test Loss: 0.028205
# Epoch 110/120, Train Loss: 0.011619, Test Loss: 0.011619
# Epoch 111/120, Train Loss: 0.005049, Test Loss: 0.005049
# Epoch 112/120, Train Loss: 0.067479, Test Loss: 0.067479
# Epoch 113/120, Train Loss: 0.066279, Test Loss: 0.066279
# Epoch 114/120, Train Loss: 0.027302, Test Loss: 0.027302
# Epoch 115/120, Train Loss: 0.057153, Test Loss: 0.057153
# Epoch 116/120, Train Loss: 0.015722, Test Loss: 0.015722
# Epoch 117/120, Train Loss: 0.027858, Test Loss: 0.027858
# Epoch 118/120, Train Loss: 0.021546, Test Loss: 0.021546
# Epoch 119/120, Train Loss: 0.061931, Test Loss: 0.061931
# Epoch 120/120, Train Loss: 0.019428, Test Loss: 0.019428

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([0.0768, 0.0678, 0.0667, 0.0668, 0.0669, 0.0673, 0.0673, 0.0668, 0.0666,
#          0.0671, 0.0668, 0.0670, 0.0672, 0.0670, 0.0671, 0.0675, 0.0675, 0.0678,
#          0.0677, 0.0673, 0.0675, 0.0679, 0.0677, 0.0677, 0.0677, 0.0675, 0.0674,
#          0.0675, 0.0679, 0.0674, 0.0675, 0.0674, 0.0675, 0.0681, 0.0675, 0.0675,
#          0.0678, 0.0676, 0.0673, 0.0678, 0.0677, 0.0678, 0.0677, 0.0679, 0.0677,
#          0.0677, 0.0678, 0.0678, 0.0678, 0.0680, 0.0676, 0.0677, 0.0678, 0.0680,
#          0.0680, 0.0678, 0.0683, 0.0678, 0.0675, 0.0676, 0.0676, 0.0676, 0.0674,
#          0.0675, 0.0673, 0.0676, 0.0677, 0.0677, 0.0677, 0.0681, 0.0681, 0.0674,
#          0.0679, 0.0678, 0.0682, 0.0676, 0.0682, 0.0678, 0.0680, 0.0680, 0.0679,
#          0.0677, 0.0678, 0.0676, 0.0678, 0.0674, 0.0674, 0.0677, 0.0677, 0.0675,
#          0.0678, 0.0677, 0.0679, 0.0684, 0.0679, 0.0682, 0.0681, 0.0678, 0.0677,
#          0.0682, 0.0676, 0.0680, 0.0676, 0.0678, 0.0678, 0.0677, 0.0678, 0.0683,
#          0.0684, 0.0679, 0.0678, 0.0679, 0.0677, 0.0678, 0.0677, 0.0674, 0.0679,
#          0.0677, 0.0676, 0.0677]),
#  tensor([0.0124, 0.0058, 0.0298, 0.0562, 0.0722, 0.0301, 0.0470, 0.0341, 0.0190,
#          0.0249, 0.0270, 0.0249, 0.0207, 0.0698, 0.0487, 0.0310, 0.0074, 0.0399,
#          0.0104, 0.0008, 0.0174, 0.0430, 0.0084, 0.0400, 0.0041, 0.0270, 0.0206,
#          0.0090, 0.0193, 0.0215, 0.0316, 0.0011, 0.0878, 0.0156, 0.0530, 0.0436,
#          0.0106, 0.0031, 0.0252, 0.0188, 0.0013, 0.0062, 0.0605, 0.0331, 0.0454,
#          0.0022, 0.0013, 0.0245, 0.0233, 0.0231, 0.0248, 0.0363, 0.0138, 0.0118,
#          0.0085, 0.0577, 0.0128, 0.0394, 0.0205, 0.0072, 0.0422, 0.0115, 0.0346,
#          0.0522, 0.0358, 0.0300, 0.0332, 0.0445, 0.0459, 0.0443, 0.0377, 0.0401,
#          0.0368, 0.0053, 0.0500, 0.0291, 0.0439, 0.0160, 0.0135, 0.0112, 0.0407,
#          0.0284, 0.0306, 0.0330, 0.0028, 0.0343, 0.0690, 0.0053, 0.0371, 0.0540,
#          0.0150, 0.0006, 0.0038, 0.0546, 0.0002, 0.0419, 0.0049, 0.0511, 0.0106,
#          0.0411, 0.0175, 0.0478, 0.0337, 0.0496, 0.0271, 0.0084, 0.0008, 0.0122,
#          0.0282, 0.0116, 0.0050, 0.0675, 0.0663, 0.0273, 0.0572, 0.0157, 0.0279,
#          0.0215, 0.0619, 0.0194]),
#  tensor([0.9654, 0.9740, 0.9746, 0.9747, 0.9746, 0.9743, 0.9742, 0.9746, 0.9746,
#          0.9744, 0.9745, 0.9746, 0.9744, 0.9744, 0.9745, 0.9740, 0.9742, 0.9739,
#          0.9740, 0.9743, 0.9742, 0.9737, 0.9741, 0.9740, 0.9739, 0.9741, 0.9741,
#          0.9741, 0.9736, 0.9742, 0.9740, 0.9743, 0.9742, 0.9736, 0.9740, 0.9743,
#          0.9738, 0.9740, 0.9743, 0.9739, 0.9740, 0.9738, 0.9738, 0.9739, 0.9739,
#          0.9740, 0.9738, 0.9739, 0.9738, 0.9737, 0.9740, 0.9738, 0.9737, 0.9737,
#          0.9737, 0.9738, 0.9735, 0.9738, 0.9741, 0.9741, 0.9739, 0.9740, 0.9742,
#          0.9740, 0.9743, 0.9740, 0.9740, 0.9738, 0.9739, 0.9735, 0.9737, 0.9740,
#          0.9737, 0.9740, 0.9736, 0.9739, 0.9736, 0.9738, 0.9736, 0.9736, 0.9738,
#          0.9741, 0.9737, 0.9740, 0.9737, 0.9741, 0.9741, 0.9737, 0.9740, 0.9740,
#          0.9737, 0.9741, 0.9738, 0.9734, 0.9738, 0.9737, 0.9738, 0.9739, 0.9739,
#          0.9737, 0.9742, 0.9737, 0.9740, 0.9739, 0.9739, 0.9740, 0.9739, 0.9736,
#          0.9734, 0.9739, 0.9739, 0.9739, 0.9740, 0.9741, 0.9739, 0.9742, 0.9739,
#          0.9739, 0.9740, 0.9741]))

# %%
date_scaler_smote.inverse_transform(yy)
# Out:
# array([[19100827.98528647]])

# %%
date_scaler_smote.inverse_transform(yHat_test)
# Out:
# array([[19139487.08020425]])

# %%
yHat      = date_scaler.inverse_transform(yHat.detach().numpy()).flatten()
y         = date_scaler.inverse_transform(y.detach().numpy()).flatten()
yHat_test = date_scaler.inverse_transform(yHat_test.detach().numpy()).flatten()
yy        = date_scaler.inverse_transform(yy.detach().numpy()).flatten()

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.9872
#
#
# mean_absolute_error(y, yHat): 105606.9375
#
# mean_absolute_error(yy, yHat_test): 38866.0000
#
#
# mean_squared_error(y, yHat): 20003803136.0000
#
# mean_squared_error(yy, yHat_test): 1510566016.0000
#
#
# mean_squared_log_error(y, yHat): 0.0000
#
# mean_squared_log_error(yy, yHat_test): 0.0000
#
#
# RMSE(y, yHat): 141434.7969
#
# RMSE(yy, yHat_test): 38866.0000

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points

plt.savefig("loss2.jpg", formate='svg', bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc2.jpg", formate='svg', bbox_inches='tight')


plt.show()

# %%
['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']
# Out:
# ['day_scaled',
#  'day_sin',
#  'day_cos',
#  'month_scaled',
#  'month_sin',
#  'month_cos',
#  'leap_year',
#  'decade_scaled',
#  'decade_sin',
#  'decade_cos']

# %%
def result_to_date(result):
    
    result = str(round(result))
    
    day   = int(result[6:]) - 1
    month = int(result[4:6]) - 1

    ss = str(f'{result[:4]}0101')
    
    ds = datetime.datetime.strptime(ss, '%Y%m%d')
    
    ds = ds + relativedelta(months=month, days=day)

    result = ds.strftime('%d-%m-%Y')
    
    
    return result

# %%
# (16830739, 17848869)
result_to_date(16830739), result_to_date(17848869)
# Out:
# ('08-08-1683', '08-06-1791')

# %%
def test_model(input_list):
    

    X       = np.zeros((1, 10))
    X_smote = np.zeros((1, 10))



    day       = np.array(map_day[input_list[0]])
    month     = np.array(map_month[input_list[1]])
    leap_year = map_leap_year[input_list[2]]
    decade    = np.array(input_list[3].strip('[]')).astype('int64')


    X[0, 0] = scaler_day.transform(day.reshape(-1, 1)).flatten()
    X[0, 1] = np.sin(day * (2 * np.pi / 7))
    X[0, 2] = np.cos(day * (2 * np.pi / 7))

    X[0, 3] = scaler_month.transform(month.reshape(-1, 1)).flatten()
    X[0, 4] = np.sin(month * (2 * np.pi / 12))
    X[0, 5] = np.cos(month * (2 * np.pi / 12))

    X[0, 6] = leap_year

    X[0, 7] = scaler_decade.transform(decade.reshape(-1, 1)).flatten()
    X[0, 8] = np.sin(decade * (2 * np.pi / alpha))
    X[0, 9] = np.cos(decade * (2 * np.pi / alpha))

    # ---

    X_smote[0, 0] = scaler_day_smote.transform(day.reshape(-1, 1)).flatten()
    X_smote[0, 1] = X[0, 1]
    X_smote[0, 2] = X[0, 2]

    X_smote[0, 3] = scaler_month_smote.transform(month.reshape(-1, 1)).flatten()
    X_smote[0, 4] = X[0, 4]
    X_smote[0, 5] = X[0, 5]

    X_smote[0, 6] = leap_year

    X_smote[0, 7] = scaler_decade_smote.transform(decade.reshape(-1, 1)).flatten()
    X_smote[0, 8] = np.sin(decade * (2 * np.pi / alpha_smote))
    X_smote[0, 9] = np.cos(decade * (2 * np.pi / alpha_smote))


    # ---

    result       = model(torch.tensor(X).to(device).float())
    result_smote = model_smote(torch.tensor(X_smote).to(device).float())


    # ---

    result       = date_scaler.inverse_transform(result.detach().cpu().numpy().reshape(-1, 1)).round()[0, 0]

    result_smote = date_scaler_smote.inverse_transform(result_smote.detach().cpu().numpy().reshape(-1, 1)).round()[0, 0]

    
    return result_to_date(result), result_to_date(result_smote)

# %%
input_test1 = ['[MON]', '[DEC]', '[False]', '[196]']
output_test1 = '3-12-1962'

input_test2 = ['[THU]', '[DEC]', '[True]', '[204]']
output_test2 = '3-12-2048'

input_test3 = ['[WED]', '[JAN]', '[False]', '[181]']
output_test3 = '10-1-1810'


input_test4 = ['[WED]', '[JUN]', '[False]', '[209]']

# %%
test_model(input_test1), test_model(input_test2), test_model(input_test3), test_model(input_test4)
# Out:
# (('04-12-1965', '06-05-1967'),
#  ('19-11-2047', '04-06-2056'),
#  ('07-01-1811', '01-07-1810'),
#  ('30-06-2095', '04-01-2079'))

# %%
output_test1, output_test2, output_test3
# Out:
# ('3-12-1962', '3-12-2048', '10-1-1810')

# %%
# example_input = pd.read_csv('./data/example_input.txt', sep=' ', header=None)
example_input = pd.read_csv('example_input.txt', sep=' ', header=None)


example_input.columns = ['day', 'month', 'leap_year', 'decade']

# %%
example_input
# Out:
#         day  month leap_year decade
# 0     [WED]  [JAN]   [False]  [180]
# 1     [MON]  [JAN]   [False]  [190]
# 2     [SAT]  [JAN]    [True]  [200]
# 3     [FRI]  [JAN]   [False]  [210]
# 4     [WED]  [JAN]   [False]  [220]
# ...     ...    ...       ...    ...
# 1460  [MON]  [OCT]    [True]  [214]
# 1461  [TUE]  [DEC]   [False]  [183]
# 1462  [SUN]  [DEC]   [False]  [193]
# 1463  [SAT]  [DEC]   [False]  [203]
# 1464  [THU]  [DEC]   [False]  [213]
#
# [1465 rows x 4 columns]

# %%
R       = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result'])
R_smote = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result_smote'])

# %%
example_input.iloc[0].tolist()
# Out:
# ['[WED]', '[JAN]', '[False]', '[180]']

# %%
for i in range(len(example_input)):
    R.iloc[i], R_smote.iloc[i] = test_model(example_input.iloc[i].tolist())

# %%
R
# Out:
#           result
# 0     02-12-1809
# 1     25-12-1920
# 2     21-08-2019
# 3     05-10-2103
# 4     25-09-2200
# ...          ...
# 1460  03-11-2142
# 1461  28-08-1850
# 1462  27-06-1931
# 1463  29-04-2042
# 1464  06-04-2122
#
# [1465 rows x 1 columns]

# %%
final = pd.concat([example_input, R], axis=1)
final
# Out:
#         day  month leap_year decade      result
# 0     [WED]  [JAN]   [False]  [180]  02-12-1809
# 1     [MON]  [JAN]   [False]  [190]  25-12-1920
# 2     [SAT]  [JAN]    [True]  [200]  21-08-2019
# 3     [FRI]  [JAN]   [False]  [210]  05-10-2103
# 4     [WED]  [JAN]   [False]  [220]  25-09-2200
# ...     ...    ...       ...    ...         ...
# 1460  [MON]  [OCT]    [True]  [214]  03-11-2142
# 1461  [TUE]  [DEC]   [False]  [183]  28-08-1850
# 1462  [SUN]  [DEC]   [False]  [193]  27-06-1931
# 1463  [SAT]  [DEC]   [False]  [203]  29-04-2042
# 1464  [THU]  [DEC]   [False]  [213]  06-04-2122
#
# [1465 rows x 5 columns]

# %%
final_smote = pd.concat([example_input, R_smote], axis=1)
final_smote
# Out:
#         day  month leap_year decade result_smote
# 0     [WED]  [JAN]   [False]  [180]   23-11-1806
# 1     [MON]  [JAN]   [False]  [190]   01-02-1899
# 2     [SAT]  [JAN]    [True]  [200]   18-07-2007
# 3     [FRI]  [JAN]   [False]  [210]   28-11-2086
# 4     [WED]  [JAN]   [False]  [220]   09-12-2176
# ...     ...    ...       ...    ...          ...
# 1460  [MON]  [OCT]    [True]  [214]   18-12-2145
# 1461  [TUE]  [DEC]   [False]  [183]   26-09-1820
# 1462  [SUN]  [DEC]   [False]  [193]   11-12-1922
# 1463  [SAT]  [DEC]   [False]  [203]   26-11-2037
# 1464  [THU]  [DEC]   [False]  [213]   24-03-2133
#
# [1465 rows x 5 columns]

# %%
final.to_csv('output_file.txt', sep=' ', header=None, index=False)

# %%
final_smote.to_csv('output_file_smote.txt', sep=' ', header=None, index=False)

# %% [markdown]
# Out-liers

# %% [markdown]
# Saving

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              'model_smote_state_dict': model_smote.state_dict()}


torch.save(checkpoint, 'checkpoint.pth.tar')

# %%
# checkpoint = torch.load('checkpoint.pth.tar')

# %%
# model       = Model()
# model_smote = Model()


# model.load_state_dict(checkpoint['model_state_dict'])
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
