# %%
import datetime

import copy

import random


from dateutil.relativedelta import relativedelta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('seaborn')
# plt.style.use(['dark_background', 'ggplot'])

import seaborn as sns
# sns.set()

# import scipy
# import scipy.stats as stats


# # sympy = symbolic math in Python
# import sympy as sym
# import sympy.plotting.plot as symplot


# make the equations look nicer

# from IPython.display import display
# display.set_matplotlib_formats('svg') # Deprecated since version 7.23

# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


# %config InlineBackend.set_matplotlib_formats = ["svg"]
# %config InlineBackend.figure_formats = ["svg"]

# %%
import sklearn


from sklearn.model_selection import train_test_split


# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler     # <------------ (-1.0, 1.0)
# from sklearn.preprocessing import MinMaxScaler


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from imblearn.over_sampling import SMOTE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset, DataLoader





torch.__version__
# Out:
# '1.12.0+cu113'

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def print_score(shape, yHat, y, yHat_test, yy):
    
    
    n, p = shape
    
    R2 = r2_score(y.detach().numpy(), yHat.detach().numpy())
    
    Adj_r2 = 1 - (1 - R2)  *  (n - 1) / (n - p - 1)
    
    print(f'Adjusted R-Squared(y, yHat): {Adj_r2:0.4f}\n\n')
    # r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
    #  R^2 score is not well-defined with less than two samples
    
    
    print(f'mean_absolute_error(y, yHat):',
          f'{mean_absolute_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_absolute_error(yy, yHat_test):',
          f'{mean_absolute_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_error(y, yHat):',
          f'{mean_squared_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_error(yy, yHat_test):',
          f'{mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_log_error(y, yHat):',
          f'{mean_squared_log_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_log_error(yy, yHat_test):',
          f'{mean_squared_log_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    
    print(f'RMSE(y, yHat):',
          f'{np.sqrt( mean_squared_error(y.detach().numpy(), yHat.detach().numpy()) ):0.4f}\n')
    print(f'RMSE(yy, yHat_test):',
          f'{np.sqrt( mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()) ):0.4f}\n\n')

# %%
# date = np.datetime64("2000-01-01")
# date_strings = date.astype(str).split('-'). 
# # >> ['2000', '01', '01']

# year_int = int(date_strings[0])

# %%
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Out:
# File ‘data.txt’ already there; not retrieving.
#
# File ‘example_input.txt’ already there; not retrieving.

# %%
# !ls
# Out:
# data.txt  example_input.txt  sample_data

# %% [markdown]
# 'text.txt'

# %% [markdown]
# [ 1-1-1800 to 31-12-2200 ]

# %% [markdown]
# [day condition] [month condition] [leap year condition] [decade condition] date

# %% [markdown]
# [MON] [DEC] [False] [196] 3-12-1962
# [THU] [DEC] [True] [204] 3-12-2048
# [WED] [JAN] [False] [181] 10-1-1810

# %%
# data = np.loadtxt(open('text.txt','r'),delimiter=' ')
# ori = pd.read_csv('./data/data.txt', sep=' ', header=None)

ori = pd.read_csv('data.txt', sep=' ', header=None)

# %%
ori.columns = ['day', 'month', 'leap_year', 'decade', 'date']

# %%
ori
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
# data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)
# # pd.to_datetime(data.date, infer_datetime_format=False)

# %%
ori.dtypes
# Out:
# day          object
# month        object
# leap_year    object
# decade       object
# date         object
# dtype: object

# %%
# data_backup = copy.deepcopy(ori)
data = copy.deepcopy(ori)

# %%
data
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
data.date
# Out:
# 0           1-1-1800
# 1           1-1-1801
# 2           1-1-1802
# 3           1-1-1803
# 4           1-1-1804
#              ...
# 146457    31-12-2196
# 146458    31-12-2197
# 146459    31-12-2198
# 146460    31-12-2199
# 146461    31-12-2200
# Name: date, Length: 146462, dtype: object

# %%
# # data['date'] = pd.date_range('3-12-2048', periods=10)
# # data['date'] = pd.date_range('12-3-1962', periods=10)

# # 1-1-1800 to 31-12-2200
# data['date'] = pd.date_range(start='1-1-1800',end='12-31-2200')


data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)

# # data.date = data.date.dt.strftime('%d-%m-%Y')
# # data.date = pd.to_datetime(data.date.dt.strftime('%d-%m-%Y'), format='%d-%m-%Y', infer_datetime_format=False)

# %%
data.dtypes
# Out:
# day                  object
# month                object
# leap_year            object
# decade               object
# date         datetime64[ns]
# dtype: object

# %%
data
# Out:
#           day  month leap_year decade       date
# 0       [WED]  [JAN]   [False]  [180] 1800-01-01
# 1       [THU]  [JAN]   [False]  [180] 1801-01-01
# 2       [FRI]  [JAN]   [False]  [180] 1802-01-01
# 3       [SAT]  [JAN]   [False]  [180] 1803-01-01
# 4       [SUN]  [JAN]    [True]  [180] 1804-01-01
# ...       ...    ...       ...    ...        ...
# 146457  [SAT]  [DEC]    [True]  [219] 2196-12-31
# 146458  [SUN]  [DEC]   [False]  [219] 2197-12-31
# 146459  [MON]  [DEC]   [False]  [219] 2198-12-31
# 146460  [TUE]  [DEC]   [False]  [219] 2199-12-31
# 146461  [WED]  [DEC]   [False]  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %%
map_leap_year = {'[False]': int(0), '[True]' : int(1)}

data.leap_year = data.leap_year.map(map_leap_year)

# data.leap_year = data.leap_year.astype(np.float64)

# %%
data
# Out:
#           day  month  leap_year decade       date
# 0       [WED]  [JAN]          0  [180] 1800-01-01
# 1       [THU]  [JAN]          0  [180] 1801-01-01
# 2       [FRI]  [JAN]          0  [180] 1802-01-01
# 3       [SAT]  [JAN]          0  [180] 1803-01-01
# 4       [SUN]  [JAN]          1  [180] 1804-01-01
# ...       ...    ...        ...    ...        ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31
# 146459  [MON]  [DEC]          0  [219] 2198-12-31
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31
# 146461  [WED]  [DEC]          0  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %% [markdown]
# date -> timestamp

# %%
data.date.iloc[0]
# Out:
# Timestamp('1800-01-01 00:00:00')

# %%
data['date_int'] = data['date'].dt.strftime("%Y%m%d").astype(np.int64)

# data['date_str'] = data['date'].dt.strftime("%Y%m%d")

# %%
# data['date_int'].map(str)
# data['date_int'].astype(str)

# %%
# date_max = data.date_int.max()
# data['date_normalized'] = data.date_int / date_max

# %%
data
# Out:
#           day  month  leap_year decade       date  date_int
# 0       [WED]  [JAN]          0  [180] 1800-01-01  18000101
# 1       [THU]  [JAN]          0  [180] 1801-01-01  18010101
# 2       [FRI]  [JAN]          0  [180] 1802-01-01  18020101
# 3       [SAT]  [JAN]          0  [180] 1803-01-01  18030101
# 4       [SUN]  [JAN]          1  [180] 1804-01-01  18040101
# ...       ...    ...        ...    ...        ...       ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31  21961231
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31  21971231
# 146459  [MON]  [DEC]          0  [219] 2198-12-31  21981231
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31  21991231
# 146461  [WED]  [DEC]          0  [220] 2200-12-31  22001231
#
# [146462 rows x 6 columns]

# %%
x = data.decade.iloc[0]
x
# Out:
# '[180]'

# %%
x.strip('[]')
# Out:
# '180'

# %%
data.decade = data.decade.apply(lambda x: x.strip('[]')).astype('int64')

# %%
# data.day = data.day.apply(lambda x: x.strip('[]'))
# data.month = data.month.apply(lambda x: x.strip('[]'))

# %%
map_day = {'[SAT]': int(0),
           '[SUN]': int(1),
           '[MON]': int(2),
           '[TUE]': int(3),
           '[WED]': int(4),
           '[THU]': int(5),
           '[FRI]': int(6)}

# %%
data['day_code'] = data.day.map(map_day)

# %%
scaler_day = RobustScaler()

x = data.day_code.values.reshape(-1, 1)

data['day_scaled'] = scaler_day.fit_transform(x).flatten()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled
# 0             0.25
# 1             0.50
# 2             0.75
# 3            -0.75
# 4            -0.50
# ...            ...
# 146457       -0.75
# 146458       -0.50
# 146459       -0.25
# 146460        0.00
# 146461        0.25
#
# [146462 rows x 8 columns]

# %%
data['day_sin'] = np.sin(data['day_code'] * (2 * np.pi / 7))
data['day_cos'] = np.cos(data['day_code'] * (2 * np.pi / 7))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos
# 0             0.25 -0.433884 -0.900969
# 1             0.50 -0.974928 -0.222521
# 2             0.75 -0.781831  0.623490
# 3            -0.75  0.000000  1.000000
# 4            -0.50  0.781831  0.623490
# ...            ...       ...       ...
# 146457       -0.75  0.000000  1.000000
# 146458       -0.50  0.781831  0.623490
# 146459       -0.25  0.974928 -0.222521
# 146460        0.00  0.433884 -0.900969
# 146461        0.25 -0.433884 -0.900969
#
# [146462 rows x 10 columns]

# %%
map_month = {'[JAN]' : 0,
             '[FEB]' : 1,
             '[MAR]' : 2,
             '[APR]' : 3,
             '[MAY]' : 4,
             '[JUN]' : 5,
             '[JUL]' : 6,
             '[AUG]' : 7,
             '[SEP]' : 8,
             '[OCT]' : 9,
             '[NOV]' : 10,
             '[DEC]' : 11}

# %%
data['month_code'] = data.month.map(map_month)

# %%
scaler_month = RobustScaler()

x = data.month_code.values.reshape(-1, 1)

data['month_scaled'] = scaler_month.fit_transform(x).flatten()

# %%
data['month_sin'] = np.sin(data['month_code'] * (2 * np.pi / 12))
data['month_cos'] = np.cos(data['month_code'] * (2 * np.pi / 12))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ...           ...
# 146457   0.866025
# 146458   0.866025
# 146459   0.866025
# 146460   0.866025
# 146461   0.866025
#
# [146462 rows x 14 columns]

# %%
scaler_decade = RobustScaler()

x = data.decade.values.reshape(-1, 1)

data['decade_scaled'] = scaler_decade.fit_transform(x).flatten()

# %%
# alpha = len(data.decade.unique())
alpha = (data.decade.iloc[-1] - data.decade.iloc[0]) + 1

data['decade_sin'] = np.sin(data['decade'] * (2 * np.pi / alpha))
data['decade_cos'] = np.cos(data['decade'] * (2 * np.pi / alpha))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %%
# data.date_normalized.min(), data.date_normalized.max()

# %%
# round(data.date_normalized.min()), round(data.date_normalized.max())

# %%
round(data.day_scaled.min()), round(data.day_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_sin.min()), round(data.day_sin.max())
# Out:
# (-1, 1)

# %%
round(data.day_cos.min()), round(data.day_cos.max())
# Out:
# (-1, 1)

# %%
round(data.month_scaled.min()), round(data.month_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.month_sin.min()), round(data.month_sin.max())
# Out:
# (-1, 1)

# %%
round(data.month_cos.min()), round(data.month_cos.max())
# Out:
# (-1, 1)

# %%
data.leap_year.min(), data.leap_year.max()
# Out:
# (0, 1)

# %%
round(data.decade_scaled.min()), round(data.decade_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.decade_sin.min()), round(data.decade_sin.max())
# Out:
# (-1, 1)

# %%
round(data.decade_cos.min()), round(data.decade_cos.max())
# Out:
# (-1, 1)

# %% [markdown]
# Boxplot

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.day.value_counts().plot(kind="bar")

# %%
data.month.value_counts().plot(kind="bar")

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
data.decade.value_counts().plot(kind="bar")

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %% [markdown]
# ['day_sin', 'day_cos', 'month_sin', 'month_cos', 'leap_year', 'decade_scaled']
# ['date_timestamp_scaled']

# %%
X = data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
          'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 0.25      , -0.43388374, -0.90096887, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.5       , -0.97492791, -0.22252093, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.75      , -0.78183148,  0.6234898 , ..., -1.        ,
#          0.63624244, -0.77148918],
#        ...,
#        [-0.25      ,  0.97492791, -0.22252093, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.        ,  0.43388374, -0.90096887, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.25      , -0.43388374, -0.90096887, ...,  1.        ,
#          0.74655322, -0.6653257 ]])

# %%
len(X)
# Out:
# 146462

# %%
X.shape
# Out:
# (146462, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()


ls = []

for s in data['date_int'].astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(data['date_int'])), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y = ll.values

Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 2, 0, ..., 2, 3, 1]])

# %%
len(Y)
# Out:
# 146462

# %%
Y.shape
# Out:
# (146462, 8)

# %%
# # leap = np.where(~X['leap_year'] == 1)[0]
# leap = np.where(X['leap_year'] == 1)[0]

# leap

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64


train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (146462, 10)
#
# Y: (146462, 8)
#
# Train data:   (102523, 10)
#
# Train labels: (102523, 8)
#
# Test data:    (43939, 10)
#
# Test labels:  (43939, 8)

# %%
102523 % 32, 102523 % 64
# Out:
# (27, 59)

# %%
class Model(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.input = nn.Linear(10, 32)

        self.fc1 = nn.Linear(32, 128)
        self.bnorm1 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 512)
        self.bnorm2 = nn.BatchNorm1d(512)

        self.fc3 = nn.Linear(512, 64)
        self.bnorm3 = nn.BatchNorm1d(64)

        self.fc4 = nn.Linear(64, 32)
        self.bnorm4 = nn.BatchNorm1d(32)


        self.output = nn.Linear(32, 8)



    def forward(self, x):


        # print(f'training={self.training}')

        x = F.relu( self.input(x) )

        x = F.relu(self.bnorm1(self.fc1(x)))
        x = F.dropout(x, p=0.25, training=self.training)

        x = F.relu(self.bnorm2(self.fc2(x)))
        x = F.dropout(x, p=0.4, training=self.training)

        x = F.relu(self.bnorm3(self.fc3(x)))
        x = F.dropout(x, p=0.1, training=self.training)

        x = F.relu(self.bnorm4(self.fc4(x)))
        x = F.dropout(x, p=0.05, training=self.training)


        x = F.relu(self.output(x))
        # x = self.output(x)
        


        return x

# %%
# test_x, test_y = next(iter(train_loader))

# print(f'X: {X.shape}\n')
# print(f'Y: {Y.shape}\n')

# %%
def train(model, numepochs):

    numepochs = numepochs

    model = model
    
    
    
    # lossfun = nn.MSELoss()
    lossfun = nn.L1Loss()


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0002, betas=(0.5, 0.999), weight_decay=1e-5)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.5, 0.999), weight_decay=1e-1)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=1e-9)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
    
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    
    
    
    trainLoss = torch.zeros(numepochs)
    testLoss  = torch.zeros(numepochs)
    trainAcc  = torch.zeros(numepochs)
    # testAcc   = torch.zeros(numepochs)


    for epochi in range(numepochs):

        model.train() # switch to train mode

        batchLoss = []
        batchAcc  = []

        for X,y in train_loader:

            X = X.to(device)
            y = y.to(device)

            yHat = model(X)
            loss = lossfun(yHat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())
            # batchAcc.append( torch.mean(( yHat == y).float() ).item() )
            # batchAcc.append( torch.mean( (torch.abs(yHat - y) < 1).float() ).item() ) # <1 for rounding
            batchAcc.append( r2_score(y.detach().cpu().numpy(), yHat.detach().cpu().numpy()) )
            




        trainLoss[epochi] = np.mean(batchLoss)
        # trainAcc[epochi]  = 100*np.mean(batchAcc)
        trainAcc[epochi]  = np.mean(batchAcc)
        



        model.eval() # switch to test mode

        XX,yy = next(iter(test_loader))

        XX = XX.to(device)
        yy = yy.to(device)

        # forward pass and loss
        with torch.no_grad():
            yHat_test = model(XX)
            loss = lossfun(yHat_test, yy)


        testLoss[epochi] = loss.item()
        # testAcc[epochi]  = 100*torch.mean( (yHat_test == yy).float() ).item()
        # testAcc[epochi]  = 100*torch.mean( (torch.abs(yHat_test - yy) < 1).float() ).item()
        # testAcc[epochi]  = 100*r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
        


        # if (epochi + 1) % 5 == 0:
        print(f'Epoch {epochi+1}/{numepochs}, Train Loss: {loss.item():0.6f}, Test Loss: {loss.item():0.6f}')


        
    return trainLoss.cpu(), testLoss.cpu(), trainAcc.cpu(), yHat.cpu(), y.cpu(), yHat_test.cpu(), yy.cpu()

# %%
model = Model().to(device)

# test_hat = model(torch.randn(32,6))
# test_hat = model(test_x)

# print(test_hat.shape)

# %%
# for p in list(model.named_parameters()):
#     if 'weight' in p[0] and 'bnorm' not in p[0]:
#         nn.init.xavier_normal_(p[1].data)
#         print(p[0])
#         print(p[1].data.shape)

# %%
numepochs = 120

trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model, numepochs)
# Out:
# Epoch 1/120, Train Loss: 0.992075, Test Loss: 0.992075
# Epoch 2/120, Train Loss: 0.919872, Test Loss: 0.919872
# Epoch 3/120, Train Loss: 0.929783, Test Loss: 0.929783
# Epoch 4/120, Train Loss: 1.002836, Test Loss: 1.002836
# Epoch 5/120, Train Loss: 0.942873, Test Loss: 0.942873
# Epoch 6/120, Train Loss: 0.871579, Test Loss: 0.871579
# Epoch 7/120, Train Loss: 0.870624, Test Loss: 0.870624
# Epoch 8/120, Train Loss: 1.003895, Test Loss: 1.003895
# Epoch 9/120, Train Loss: 0.820669, Test Loss: 0.820669
# Epoch 10/120, Train Loss: 0.939413, Test Loss: 0.939413
# Epoch 11/120, Train Loss: 0.883833, Test Loss: 0.883833
# Epoch 12/120, Train Loss: 0.833575, Test Loss: 0.833575
# Epoch 13/120, Train Loss: 0.919244, Test Loss: 0.919244
# Epoch 14/120, Train Loss: 0.875129, Test Loss: 0.875129
# Epoch 15/120, Train Loss: 0.870932, Test Loss: 0.870932
# Epoch 16/120, Train Loss: 0.852847, Test Loss: 0.852847
# Epoch 17/120, Train Loss: 0.889994, Test Loss: 0.889994
# Epoch 18/120, Train Loss: 0.937598, Test Loss: 0.937598
# Epoch 19/120, Train Loss: 0.939522, Test Loss: 0.939522
# Epoch 20/120, Train Loss: 0.792184, Test Loss: 0.792184
# Epoch 21/120, Train Loss: 0.978165, Test Loss: 0.978165
# Epoch 22/120, Train Loss: 0.789988, Test Loss: 0.789988
# Epoch 23/120, Train Loss: 1.065655, Test Loss: 1.065655
# Epoch 24/120, Train Loss: 0.909598, Test Loss: 0.909598
# Epoch 25/120, Train Loss: 0.902358, Test Loss: 0.902358
# Epoch 26/120, Train Loss: 0.889386, Test Loss: 0.889386
# Epoch 27/120, Train Loss: 0.842597, Test Loss: 0.842597
# Epoch 28/120, Train Loss: 0.965821, Test Loss: 0.965821
# Epoch 29/120, Train Loss: 0.888337, Test Loss: 0.888337
# Epoch 30/120, Train Loss: 0.918788, Test Loss: 0.918788
# Epoch 31/120, Train Loss: 0.908325, Test Loss: 0.908325
# Epoch 32/120, Train Loss: 0.933392, Test Loss: 0.933392
# Epoch 33/120, Train Loss: 0.824535, Test Loss: 0.824535
# Epoch 34/120, Train Loss: 0.921322, Test Loss: 0.921322
# Epoch 35/120, Train Loss: 0.873001, Test Loss: 0.873001
# Epoch 36/120, Train Loss: 0.939057, Test Loss: 0.939057
# Epoch 37/120, Train Loss: 0.864651, Test Loss: 0.864651
# Epoch 38/120, Train Loss: 0.826662, Test Loss: 0.826662
# Epoch 39/120, Train Loss: 0.859155, Test Loss: 0.859155
# Epoch 40/120, Train Loss: 0.898109, Test Loss: 0.898109
# Epoch 41/120, Train Loss: 0.879605, Test Loss: 0.879605
# Epoch 42/120, Train Loss: 0.908056, Test Loss: 0.908056
# Epoch 43/120, Train Loss: 0.903257, Test Loss: 0.903257
# Epoch 44/120, Train Loss: 0.900629, Test Loss: 0.900629
# Epoch 45/120, Train Loss: 0.854371, Test Loss: 0.854371
# Epoch 46/120, Train Loss: 0.820249, Test Loss: 0.820249
# Epoch 47/120, Train Loss: 0.818190, Test Loss: 0.818190
# Epoch 48/120, Train Loss: 0.857368, Test Loss: 0.857368
# Epoch 49/120, Train Loss: 0.858192, Test Loss: 0.858192
# Epoch 50/120, Train Loss: 0.904710, Test Loss: 0.904710
# Epoch 51/120, Train Loss: 0.858911, Test Loss: 0.858911
# Epoch 52/120, Train Loss: 0.896092, Test Loss: 0.896092
# Epoch 53/120, Train Loss: 0.941463, Test Loss: 0.941463
# Epoch 54/120, Train Loss: 0.869734, Test Loss: 0.869734
# Epoch 55/120, Train Loss: 0.845525, Test Loss: 0.845525
# Epoch 56/120, Train Loss: 0.898252, Test Loss: 0.898252
# Epoch 57/120, Train Loss: 0.949944, Test Loss: 0.949944
# Epoch 58/120, Train Loss: 0.882499, Test Loss: 0.882499
# Epoch 59/120, Train Loss: 0.914788, Test Loss: 0.914788
# Epoch 60/120, Train Loss: 0.810840, Test Loss: 0.810840
# Epoch 61/120, Train Loss: 0.933432, Test Loss: 0.933432
# Epoch 62/120, Train Loss: 0.803618, Test Loss: 0.803618
# Epoch 63/120, Train Loss: 0.877158, Test Loss: 0.877158
# Epoch 64/120, Train Loss: 0.918550, Test Loss: 0.918550
# Epoch 65/120, Train Loss: 0.798587, Test Loss: 0.798587
# Epoch 66/120, Train Loss: 0.878656, Test Loss: 0.878656
# Epoch 67/120, Train Loss: 0.950105, Test Loss: 0.950105
# Epoch 68/120, Train Loss: 0.857575, Test Loss: 0.857575
# Epoch 69/120, Train Loss: 0.928732, Test Loss: 0.928732
# Epoch 70/120, Train Loss: 0.854551, Test Loss: 0.854551
# Epoch 71/120, Train Loss: 0.815407, Test Loss: 0.815407
# Epoch 72/120, Train Loss: 0.830819, Test Loss: 0.830819
# Epoch 73/120, Train Loss: 0.914695, Test Loss: 0.914695
# Epoch 74/120, Train Loss: 0.853547, Test Loss: 0.853547
# Epoch 75/120, Train Loss: 0.927006, Test Loss: 0.927006
# Epoch 76/120, Train Loss: 0.856224, Test Loss: 0.856224
# Epoch 77/120, Train Loss: 0.831847, Test Loss: 0.831847
# Epoch 78/120, Train Loss: 0.883411, Test Loss: 0.883411
# Epoch 79/120, Train Loss: 0.793030, Test Loss: 0.793030
# Epoch 80/120, Train Loss: 0.988480, Test Loss: 0.988480
# Epoch 81/120, Train Loss: 0.967881, Test Loss: 0.967881
# Epoch 82/120, Train Loss: 0.867907, Test Loss: 0.867907
# Epoch 83/120, Train Loss: 0.843508, Test Loss: 0.843508
# Epoch 84/120, Train Loss: 0.883294, Test Loss: 0.883294
# Epoch 85/120, Train Loss: 0.868440, Test Loss: 0.868440
# Epoch 86/120, Train Loss: 0.874698, Test Loss: 0.874698
# Epoch 87/120, Train Loss: 0.819483, Test Loss: 0.819483
# Epoch 88/120, Train Loss: 0.890279, Test Loss: 0.890279
# Epoch 89/120, Train Loss: 0.769836, Test Loss: 0.769836
# Epoch 90/120, Train Loss: 0.839802, Test Loss: 0.839802
# Epoch 91/120, Train Loss: 0.885621, Test Loss: 0.885621
# Epoch 92/120, Train Loss: 0.868514, Test Loss: 0.868514
# Epoch 93/120, Train Loss: 0.908402, Test Loss: 0.908402
# Epoch 94/120, Train Loss: 0.874953, Test Loss: 0.874953
# Epoch 95/120, Train Loss: 0.927619, Test Loss: 0.927619
# Epoch 96/120, Train Loss: 0.894593, Test Loss: 0.894593
# Epoch 97/120, Train Loss: 0.875929, Test Loss: 0.875929
# Epoch 98/120, Train Loss: 0.837701, Test Loss: 0.837701
# Epoch 99/120, Train Loss: 0.861288, Test Loss: 0.861288
# Epoch 100/120, Train Loss: 0.799802, Test Loss: 0.799802
# Epoch 101/120, Train Loss: 0.896833, Test Loss: 0.896833
# Epoch 102/120, Train Loss: 0.823066, Test Loss: 0.823066
# Epoch 103/120, Train Loss: 0.926542, Test Loss: 0.926542
# Epoch 104/120, Train Loss: 0.856269, Test Loss: 0.856269
# Epoch 105/120, Train Loss: 0.832973, Test Loss: 0.832973
# Epoch 106/120, Train Loss: 0.903250, Test Loss: 0.903250
# Epoch 107/120, Train Loss: 0.791830, Test Loss: 0.791830
# Epoch 108/120, Train Loss: 0.801791, Test Loss: 0.801791
# Epoch 109/120, Train Loss: 0.892352, Test Loss: 0.892352
# Epoch 110/120, Train Loss: 0.922295, Test Loss: 0.922295
# Epoch 111/120, Train Loss: 0.777990, Test Loss: 0.777990
# Epoch 112/120, Train Loss: 0.913785, Test Loss: 0.913785
# Epoch 113/120, Train Loss: 0.935449, Test Loss: 0.935449
# Epoch 114/120, Train Loss: 0.918194, Test Loss: 0.918194
# Epoch 115/120, Train Loss: 0.847938, Test Loss: 0.847938
# Epoch 116/120, Train Loss: 0.970259, Test Loss: 0.970259
# Epoch 117/120, Train Loss: 0.864331, Test Loss: 0.864331
# Epoch 118/120, Train Loss: 0.835370, Test Loss: 0.835370
# Epoch 119/120, Train Loss: 0.864181, Test Loss: 0.864181
# Epoch 120/120, Train Loss: 0.808228, Test Loss: 0.808228

# %%
# r2_score(y.detach().numpy(), yHat.detach().numpy())
# type(r2_score(y.detach(), yHat.detach()))

# %%
# torch.mean( r2_score(y.detach().numpy(), yHat.detach().numpy()) ).item()

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([1.1627, 1.0004, 0.9896, 0.9869, 0.9854, 0.9850, 0.9852, 0.9847, 0.9844,
#          0.9842, 0.9839, 0.9843, 0.9841, 0.9841, 0.9846, 0.9841, 0.9839, 0.9849,
#          0.9846, 0.9842, 0.9833, 0.9838, 0.9837, 0.9844, 0.9850, 0.9843, 0.9849,
#          0.9851, 0.9852, 0.9842, 0.9851, 0.9846, 0.9851, 0.9841, 0.9840, 0.9847,
#          0.9836, 0.9831, 0.9833, 0.9834, 0.9827, 0.9832, 0.9838, 0.9828, 0.9832,
#          0.9837, 0.9840, 0.9838, 0.9835, 0.9837, 0.9837, 0.9839, 0.9838, 0.9835,
#          0.9837, 0.9831, 0.9844, 0.9829, 0.9835, 0.9838, 0.9843, 0.9837, 0.9844,
#          0.9835, 0.9838, 0.9841, 0.9837, 0.9833, 0.9840, 0.9845, 0.9840, 0.9822,
#          0.9838, 0.9836, 0.9828, 0.9827, 0.9840, 0.9830, 0.9840, 0.9835, 0.9829,
#          0.9835, 0.9838, 0.9837, 0.9841, 0.9839, 0.9831, 0.9830, 0.9840, 0.9838,
#          0.9830, 0.9841, 0.9835, 0.9834, 0.9854, 0.9837, 0.9831, 0.9842, 0.9835,
#          0.9835, 0.9831, 0.9847, 0.9835, 0.9840, 0.9833, 0.9831, 0.9833, 0.9829,
#          0.9840, 0.9844, 0.9840, 0.9835, 0.9832, 0.9836, 0.9842, 0.9834, 0.9841,
#          0.9830, 0.9839, 0.9839]),
#  tensor([0.9921, 0.9199, 0.9298, 1.0028, 0.9429, 0.8716, 0.8706, 1.0039, 0.8207,
#          0.9394, 0.8838, 0.8336, 0.9192, 0.8751, 0.8709, 0.8528, 0.8900, 0.9376,
#          0.9395, 0.7922, 0.9782, 0.7900, 1.0657, 0.9096, 0.9024, 0.8894, 0.8426,
#          0.9658, 0.8883, 0.9188, 0.9083, 0.9334, 0.8245, 0.9213, 0.8730, 0.9391,
#          0.8647, 0.8267, 0.8592, 0.8981, 0.8796, 0.9081, 0.9033, 0.9006, 0.8544,
#          0.8202, 0.8182, 0.8574, 0.8582, 0.9047, 0.8589, 0.8961, 0.9415, 0.8697,
#          0.8455, 0.8983, 0.9499, 0.8825, 0.9148, 0.8108, 0.9334, 0.8036, 0.8772,
#          0.9186, 0.7986, 0.8787, 0.9501, 0.8576, 0.9287, 0.8546, 0.8154, 0.8308,
#          0.9147, 0.8535, 0.9270, 0.8562, 0.8318, 0.8834, 0.7930, 0.9885, 0.9679,
#          0.8679, 0.8435, 0.8833, 0.8684, 0.8747, 0.8195, 0.8903, 0.7698, 0.8398,
#          0.8856, 0.8685, 0.9084, 0.8750, 0.9276, 0.8946, 0.8759, 0.8377, 0.8613,
#          0.7998, 0.8968, 0.8231, 0.9265, 0.8563, 0.8330, 0.9033, 0.7918, 0.8018,
#          0.8924, 0.9223, 0.7780, 0.9138, 0.9354, 0.9182, 0.8479, 0.9703, 0.8643,
#          0.8354, 0.8642, 0.8082]),
#  tensor([0.4065, 0.5328, 0.5372, 0.5384, 0.5392, 0.5391, 0.5396, 0.5388, 0.5393,
#          0.5389, 0.5397, 0.5396, 0.5390, 0.5397, 0.5398, 0.5400, 0.5394, 0.5387,
#          0.5395, 0.5398, 0.5401, 0.5398, 0.5399, 0.5396, 0.5388, 0.5394, 0.5392,
#          0.5393, 0.5393, 0.5393, 0.5388, 0.5392, 0.5388, 0.5390, 0.5387, 0.5387,
#          0.5389, 0.5392, 0.5390, 0.5389, 0.5395, 0.5392, 0.5385, 0.5393, 0.5392,
#          0.5379, 0.5383, 0.5386, 0.5385, 0.5386, 0.5386, 0.5385, 0.5391, 0.5385,
#          0.5384, 0.5388, 0.5383, 0.5390, 0.5391, 0.5390, 0.5379, 0.5387, 0.5388,
#          0.5387, 0.5383, 0.5386, 0.5387, 0.5383, 0.5380, 0.5388, 0.5381, 0.5392,
#          0.5379, 0.5388, 0.5390, 0.5392, 0.5382, 0.5393, 0.5385, 0.5390, 0.5397,
#          0.5387, 0.5382, 0.5386, 0.5383, 0.5386, 0.5394, 0.5390, 0.5386, 0.5387,
#          0.5383, 0.5388, 0.5390, 0.5391, 0.5385, 0.5389, 0.5391, 0.5384, 0.5389,
#          0.5384, 0.5384, 0.5386, 0.5390, 0.5383, 0.5384, 0.5383, 0.5384, 0.5388,
#          0.5382, 0.5383, 0.5386, 0.5384, 0.5388, 0.5392, 0.5387, 0.5396, 0.5389,
#          0.5388, 0.5387, 0.5389]))

# %%
# batchLoss

# %%
# batchAcc

# %%
# yHat.shape, y.shape

# %%
# yHat_test.shape, yy.shape

# %%
yHat.flatten(), y.flatten()
# Out:
# (tensor([ 1.9176,  1.2228,  7.3779,  4.1273,  0.0000,  3.2840,  1.0191,  4.1904,
#           1.8106,  0.0000,  6.9162,  3.6344,  0.4619,  1.6201,  0.8989,  3.6968,
#           2.0615,  0.0000,  4.6503,  4.2148,  0.0000,  3.1826,  1.0502,  4.2453,
#           1.8118,  0.8625,  3.4993,  3.6825,  0.0000,  6.9741,  0.9234,  3.7707,
#           1.8923,  1.2045,  7.6416,  4.1943,  0.0000,  6.9067,  1.0287,  4.2998,
#           1.0598,  7.1476,  4.7130,  4.0005,  0.0000,  1.2290,  0.9805,  3.8988,
#           0.9734,  8.7982,  0.0572,  4.5429,  0.0487,  4.1579,  1.0637,  4.4116,
#           1.8468,  0.0926,  7.2324,  3.9378,  1.0021,  1.5783,  0.9739,  3.9724,
#           1.0104, 10.0169,  6.0965,  4.9158,  1.1070,  1.9847,  1.1333,  4.7641,
#           0.9822,  9.9279,  0.6828,  4.9869,  0.0000,  7.5015,  1.1441,  4.8692,
#           1.8682,  0.9244,  4.7662,  3.8326,  0.0000,  7.2682,  0.9819,  3.9202,
#           1.8462,  1.2021,  7.2244,  3.9260,  0.1282,  1.7051,  0.9759,  3.9729,
#           2.1371,  0.0000,  7.4205,  4.4243,  0.0000,  4.1082,  1.0663,  4.5006,
#           1.9377,  0.0654,  7.4361,  4.1423,  0.0000,  1.2149,  1.0121,  4.1841,
#           0.8063,  7.7318,  2.1935,  3.8840,  0.0000,  5.1490,  0.9460,  3.8075,
#           1.0265,  8.8489,  0.8455,  4.7531,  0.0000,  8.3538,  1.1111,  4.6706,
#           1.1381,  7.5853,  3.9346,  4.3324,  0.0000,  5.1893,  1.0570,  4.2625,
#           1.9040,  0.5737,  5.9564,  3.9033,  0.7798,  0.9985,  0.9624,  3.9007,
#           1.9250,  0.5298,  5.2320,  3.9648,  0.9570,  0.0000,  0.9769,  3.9688,
#           1.8282,  0.0000,  7.4497,  3.8299,  0.9711,  1.9623,  0.9518,  3.8628,
#           1.0201,  9.7980,  5.8274,  4.8844,  1.1067,  1.1755,  1.1236,  4.7291,
#           1.0626,  8.6338,  1.3795,  4.5490,  0.0000,  5.5161,  1.0674,  4.4314,
#           0.9568,  8.6939,  0.9829,  4.4531,  0.0000,  6.7436,  1.0573,  4.3723,
#           0.9882,  8.9178,  1.1558,  4.4784,  0.0000,  2.1355,  1.0619,  4.3276,
#           0.9819,  8.2051,  8.3112,  4.4697,  0.0000,  5.4719,  1.0471,  4.4228,
#           0.8866,  7.5190,  5.9291,  3.8780,  0.3703,  1.2238,  0.9341,  3.7450,
#           1.8094,  1.9472,  2.3007,  4.0032,  0.0000,  6.6957,  1.0104,  4.0489,
#           1.0016,  9.1914,  3.7514,  4.5786,  0.0000,  4.5673,  1.0863,  4.4693,
#           1.6991,  0.9927,  1.0076,  3.8521,  0.0000,  7.3767,  0.9760,  3.8949,
#           1.8057,  0.5826,  2.4243,  3.8408,  1.0684,  0.0000,  0.9666,  3.8201,
#           0.9975,  8.4594,  4.3496,  4.3759,  0.0000,  6.2631,  1.0455,  4.3033,
#           2.1579,  0.0000,  3.8564,  4.3532,  0.0000,  5.1644,  1.0742,  4.3978],
#         grad_fn=<ReshapeAliasBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
yHat_test, yy
# Out:
# (tensor([[0.9657, 7.9861, 1.0041, 4.1673, 0.0000, 5.4956, 1.0032, 4.0733]]),
#  tensor([[1., 8., 1., 6., 0., 6., 0., 1.]]))

# %%
(yy * data['date_int'].max()).round()
# Out:
# tensor([[2.2001e+07, 1.7601e+08, 2.2001e+07, 1.3201e+08, 0.0000e+00, 1.3201e+08,
#          0.0000e+00, 2.2001e+07]])

# %%
(yHat_test * data['date_int'].max()).round()
# Out:
# tensor([[2.1247e+07, 1.7570e+08, 2.2091e+07, 9.1685e+07, 0.0000e+00, 1.2091e+08,
#          2.2071e+07, 8.9617e+07]])

# %%
(yHat.flatten() * data['date_int'].max()).round(), (y.flatten() * data['date_int'].max()).round()
# Out:
# (tensor([4.2190e+07, 2.6903e+07, 1.6232e+08, 9.0806e+07, 0.0000e+00, 7.2252e+07,
#          2.2422e+07, 9.2195e+07, 3.9835e+07, 0.0000e+00, 1.5216e+08, 7.9962e+07,
#          1.0163e+07, 3.5645e+07, 1.9776e+07, 8.1333e+07, 4.5356e+07, 0.0000e+00,
#          1.0231e+08, 9.2731e+07, 0.0000e+00, 7.0021e+07, 2.3105e+07, 9.3401e+07,
#          3.9862e+07, 1.8976e+07, 7.6988e+07, 8.1021e+07, 0.0000e+00, 1.5344e+08,
#          2.0316e+07, 8.2960e+07, 4.1633e+07, 2.6501e+07, 1.6812e+08, 9.2281e+07,
#          0.0000e+00, 1.5196e+08, 2.2633e+07, 9.4602e+07, 2.3316e+07, 1.5726e+08,
#          1.0369e+08, 8.8016e+07, 0.0000e+00, 2.7039e+07, 2.1572e+07, 8.5779e+07,
#          2.1415e+07, 1.9357e+08, 1.2586e+06, 9.9949e+07, 1.0706e+06, 9.1480e+07,
#          2.3403e+07, 9.7061e+07, 4.0631e+07, 2.0384e+06, 1.5912e+08, 8.6635e+07,
#          2.2046e+07, 3.4723e+07, 2.1427e+07, 8.7397e+07, 2.2231e+07, 2.2038e+08,
#          1.3413e+08, 1.0815e+08, 2.4356e+07, 4.3666e+07, 2.4935e+07, 1.0482e+08,
#          2.1609e+07, 2.1843e+08, 1.5021e+07, 1.0972e+08, 0.0000e+00, 1.6504e+08,
#          2.5173e+07, 1.0713e+08, 4.1103e+07, 2.0337e+07, 1.0486e+08, 8.4322e+07,
#          0.0000e+00, 1.5991e+08, 2.1603e+07, 8.6249e+07, 4.0618e+07, 2.6447e+07,
#          1.5895e+08, 8.6376e+07, 2.8202e+06, 3.7513e+07, 2.1470e+07, 8.7409e+07,
#          4.7018e+07, 0.0000e+00, 1.6326e+08, 9.7340e+07, 0.0000e+00, 9.0385e+07,
#          2.3459e+07, 9.9018e+07, 4.2632e+07, 1.4380e+06, 1.6360e+08, 9.1136e+07,
#          0.0000e+00, 2.6730e+07, 2.2268e+07, 9.2055e+07, 1.7740e+07, 1.7011e+08,
#          4.8260e+07, 8.5453e+07, 0.0000e+00, 1.1328e+08, 2.0813e+07, 8.3770e+07,
#          2.2584e+07, 1.9469e+08, 1.8601e+07, 1.0457e+08, 0.0000e+00, 1.8379e+08,
#          2.4446e+07, 1.0276e+08, 2.5039e+07, 1.6689e+08, 8.6566e+07, 9.5318e+07,
#          0.0000e+00, 1.1417e+08, 2.3255e+07, 9.3781e+07, 4.1890e+07, 1.2622e+07,
#          1.3105e+08, 8.5876e+07, 1.7156e+07, 2.1969e+07, 2.1175e+07, 8.5820e+07,
#          4.2352e+07, 1.1656e+07, 1.1511e+08, 8.7230e+07, 2.1056e+07, 0.0000e+00,
#          2.1493e+07, 8.7317e+07, 4.0223e+07, 0.0000e+00, 1.6390e+08, 8.4263e+07,
#          2.1365e+07, 4.3172e+07, 2.0940e+07, 8.4986e+07, 2.2444e+07, 2.1557e+08,
#          1.2821e+08, 1.0746e+08, 2.4349e+07, 2.5863e+07, 2.4721e+07, 1.0405e+08,
#          2.3379e+07, 1.8996e+08, 3.0352e+07, 1.0008e+08, 0.0000e+00, 1.2136e+08,
#          2.3484e+07, 9.7497e+07, 2.1050e+07, 1.9128e+08, 2.1626e+07, 9.7974e+07,
#          0.0000e+00, 1.4837e+08, 2.3261e+07, 9.6197e+07, 2.1742e+07, 1.9620e+08,
#          2.5429e+07, 9.8531e+07, 0.0000e+00, 4.6985e+07, 2.3364e+07, 9.5213e+07,
#          2.1603e+07, 1.8052e+08, 1.8286e+08, 9.8339e+07, 0.0000e+00, 1.2039e+08,
#          2.3037e+07, 9.7308e+07, 1.9507e+07, 1.6543e+08, 1.3045e+08, 8.5321e+07,
#          8.1467e+06, 2.6926e+07, 2.0552e+07, 8.2394e+07, 3.9808e+07, 4.2841e+07,
#          5.0618e+07, 8.8076e+07, 0.0000e+00, 1.4731e+08, 2.2230e+07, 8.9080e+07,
#          2.2037e+07, 2.0222e+08, 8.2536e+07, 1.0073e+08, 0.0000e+00, 1.0049e+08,
#          2.3901e+07, 9.8330e+07, 3.7382e+07, 2.1842e+07, 2.2168e+07, 8.4751e+07,
#          0.0000e+00, 1.6230e+08, 2.1474e+07, 8.5694e+07, 3.9727e+07, 1.2817e+07,
#          5.3337e+07, 8.4502e+07, 2.3507e+07, 0.0000e+00, 2.1267e+07, 8.4047e+07,
#          2.1946e+07, 1.8612e+08, 9.5698e+07, 9.6274e+07, 0.0000e+00, 1.3780e+08,
#          2.3002e+07, 9.4679e+07, 4.7478e+07, 0.0000e+00, 8.4845e+07, 9.5775e+07,
#          0.0000e+00, 1.1362e+08, 2.3633e+07, 9.6757e+07],
#         grad_fn=<RoundBackward0>),
#  tensor([4.4002e+07, 2.2001e+07, 1.7601e+08, 1.1001e+08, 0.0000e+00, 6.6004e+07,
#          2.2001e+07, 1.7601e+08, 4.4002e+07, 0.0000e+00, 1.7601e+08, 1.9801e+08,
#          0.0000e+00, 4.4002e+07, 4.4002e+07, 8.8005e+07, 4.4002e+07, 0.0000e+00,
#          1.1001e+08, 1.7601e+08, 0.0000e+00, 6.6004e+07, 4.4002e+07, 1.9801e+08,
#          4.4002e+07, 2.2001e+07, 8.8005e+07, 4.4002e+07, 0.0000e+00, 1.5401e+08,
#          0.0000e+00, 6.6004e+07, 4.4002e+07, 2.2001e+07, 1.9801e+08, 0.0000e+00,
#          0.0000e+00, 1.7601e+08, 0.0000e+00, 1.3201e+08, 2.2001e+07, 1.9801e+08,
#          1.1001e+08, 1.5401e+08, 0.0000e+00, 2.2001e+07, 0.0000e+00, 6.6004e+07,
#          2.2001e+07, 1.7601e+08, 0.0000e+00, 4.4002e+07, 0.0000e+00, 6.6004e+07,
#          2.2001e+07, 8.8005e+07, 4.4002e+07, 0.0000e+00, 1.9801e+08, 6.6004e+07,
#          2.2001e+07, 2.2001e+07, 2.2001e+07, 1.7601e+08, 2.2001e+07, 1.9801e+08,
#          1.3201e+08, 8.8005e+07, 2.2001e+07, 4.4002e+07, 2.2001e+07, 0.0000e+00,
#          2.2001e+07, 1.9801e+08, 0.0000e+00, 8.8005e+07, 0.0000e+00, 1.5401e+08,
#          0.0000e+00, 6.6004e+07, 4.4002e+07, 2.2001e+07, 1.3201e+08, 8.8005e+07,
#          0.0000e+00, 1.7601e+08, 2.2001e+07, 1.5401e+08, 4.4002e+07, 2.2001e+07,
#          1.7601e+08, 1.7601e+08, 0.0000e+00, 4.4002e+07, 4.4002e+07, 0.0000e+00,
#          4.4002e+07, 0.0000e+00, 1.7601e+08, 1.3201e+08, 0.0000e+00, 8.8005e+07,
#          0.0000e+00, 1.1001e+08, 4.4002e+07, 0.0000e+00, 1.7601e+08, 1.7601e+08,
#          0.0000e+00, 2.2001e+07, 2.2001e+07, 1.9801e+08, 2.2001e+07, 1.9801e+08,
#          0.0000e+00, 2.2001e+07, 0.0000e+00, 1.5401e+08, 4.4002e+07, 8.8005e+07,
#          2.2001e+07, 1.7601e+08, 0.0000e+00, 1.3201e+08, 0.0000e+00, 1.9801e+08,
#          2.2001e+07, 0.0000e+00, 2.2001e+07, 1.9801e+08, 6.6004e+07, 2.2001e+07,
#          0.0000e+00, 1.3201e+08, 2.2001e+07, 0.0000e+00, 4.4002e+07, 2.2001e+07,
#          1.1001e+08, 2.2001e+07, 0.0000e+00, 2.2001e+07, 4.4002e+07, 2.2001e+07,
#          4.4002e+07, 2.2001e+07, 1.3201e+08, 0.0000e+00, 2.2001e+07, 0.0000e+00,
#          2.2001e+07, 6.6004e+07, 4.4002e+07, 0.0000e+00, 1.9801e+08, 1.5401e+08,
#          2.2001e+07, 4.4002e+07, 4.4002e+07, 1.7601e+08, 2.2001e+07, 1.9801e+08,
#          1.5401e+08, 1.9801e+08, 2.2001e+07, 2.2001e+07, 2.2001e+07, 1.1001e+08,
#          2.2001e+07, 1.9801e+08, 2.2001e+07, 1.9801e+08, 0.0000e+00, 1.5401e+08,
#          2.2001e+07, 1.9801e+08, 2.2001e+07, 1.7601e+08, 0.0000e+00, 2.2001e+07,
#          0.0000e+00, 1.7601e+08, 4.4002e+07, 6.6004e+07, 2.2001e+07, 1.7601e+08,
#          0.0000e+00, 2.2001e+07, 0.0000e+00, 4.4002e+07, 2.2001e+07, 6.6004e+07,
#          2.2001e+07, 1.7601e+08, 1.9801e+08, 8.8005e+07, 0.0000e+00, 1.3201e+08,
#          0.0000e+00, 6.6004e+07, 2.2001e+07, 1.7601e+08, 1.9801e+08, 0.0000e+00,
#          0.0000e+00, 4.4002e+07, 4.4002e+07, 1.5401e+08, 4.4002e+07, 2.2001e+07,
#          4.4002e+07, 1.1001e+08, 0.0000e+00, 1.5401e+08, 4.4002e+07, 1.3201e+08,
#          2.2001e+07, 1.9801e+08, 8.8005e+07, 4.4002e+07, 0.0000e+00, 1.1001e+08,
#          2.2001e+07, 2.2001e+07, 4.4002e+07, 0.0000e+00, 0.0000e+00, 2.2001e+07,
#          0.0000e+00, 1.7601e+08, 0.0000e+00, 1.9801e+08, 4.4002e+07, 2.2001e+07,
#          4.4002e+07, 1.3201e+08, 2.2001e+07, 0.0000e+00, 4.4002e+07, 1.1001e+08,
#          2.2001e+07, 1.7601e+08, 1.1001e+08, 8.8005e+07, 0.0000e+00, 1.7601e+08,
#          2.2001e+07, 1.7601e+08, 4.4002e+07, 0.0000e+00, 8.8005e+07, 0.0000e+00,
#          0.0000e+00, 1.1001e+08, 4.4002e+07, 1.3201e+08]))

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.5449
#
#
# mean_absolute_error(y, yHat): 0.9839
#
# mean_absolute_error(yy, yHat_test): 0.8082
#
#
# mean_squared_error(y, yHat): 2.6257
#
# mean_squared_error(yy, yHat_test): 1.7583
#
#
# mean_squared_log_error(y, yHat): 0.1925
#
# mean_squared_log_error(yy, yHat_test): 0.1809
#
#
# RMSE(y, yHat): 1.6204
#
# RMSE(yy, yHat_test): 1.3260

# %%
# create a 1D smoothing filter
def smooth(x, k=15):
    return np.convolve(x, np.ones(k)/k, mode='same')

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss1.jpg", format='svg', bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.detach().T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc1.jpg", format='svg', bbox_inches='tight')


plt.show()

# %%
data.leap_year.value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
resampler = SMOTE(k_neighbors=20, random_state=0)

# %%
X_res, y_res = resampler.fit_resample(data[['day_code', 'month_code', 'decade', 'date_int']], data['leap_year'])

# %%
y_res.value_counts()
# Out:
# 0    110960
# 1    110960
# Name: leap_year, dtype: int64

# %%
data['leap_year'].value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 221915    1
# 221916    1
# 221917    1
# 221918    1
# 221919    1
# Name: leap_year, Length: 221920, dtype: int64

# %%
X_res
# Out:
#         day_code  month_code  decade  date_int
# 0              4           0     180  18000101
# 1              5           0     180  18010101
# 2              6           0     180  18020101
# 3              0           0     180  18030101
# 4              1           0     180  18040101
# ...          ...         ...     ...       ...
# 221915         0           5     188  18880618
# 221916         2           6     188  18840705
# 221917         5           2     218  21800323
# 221918         1           5     199  19960602
# 221919         1           4     219  21960520
#
# [221920 rows x 4 columns]

# %%
X_smote = X_res.assign(leap_year=y_res)

# %%
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221915         0           5     188  18880618          1
# 221916         2           6     188  18840705          1
# 221917         5           2     218  21800323          1
# 221918         1           5     199  19960602          1
# 221919         1           4     219  21960520          1
#
# [221920 rows x 5 columns]

# %% [markdown]
# Drop 220 decade

# %%
# data.decade.value_counts().plot(kind="bar")
X_smote.decade.value_counts().plot(kind="bar")

# %%
# data.decade.value_counts()[-5:]
X_smote.decade.value_counts()[-5:]
# Out:
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# 220     365
# Name: decade, dtype: int64

# %%
X_smote = X_smote.drop(X_smote.index[X_smote['decade'] == 220]).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221550         0           5     188  18880618          1
# 221551         2           6     188  18840705          1
# 221552         5           2     218  21800323          1
# 221553         1           5     199  19960602          1
# 221554         1           4     219  21960520          1
#
# [221555 rows x 5 columns]

# %%
X_smote.decade.value_counts().plot(kind="bar")

# %%
X_smote.decade.value_counts()[-5:]
# Out:
# 209    5174
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# Name: decade, dtype: int64

# %% [markdown]
# code is required to only work for dates in the range  [ 1-1-1800 to 31-12-2200 ]

# %%
X_smote.date_int.max()
# Out:
# 21991231

# %%
datetime.datetime.strptime(str(X_smote.date_int.max()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '31-12-2199'

# %%
X_smote.date_int.min()
# Out:
# 18000101

# %%
datetime.datetime.strptime(str(X_smote.date_int.min()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '01-01-1800'

# %%
Y_smote = X_smote['date_int']
Y_smote
# Out:
# 0         18000101
# 1         18010101
# 2         18020101
# 3         18030101
# 4         18040101
#             ...
# 221550    18880618
# 221551    18840705
# 221552    21800323
# 221553    19960602
# 221554    21960520
# Name: date_int, Length: 221555, dtype: int64

# %%
X_smote = X_smote.drop('date_int', axis=1).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  leap_year
# 0              4           0     180          0
# 1              5           0     180          0
# 2              6           0     180          0
# 3              0           0     180          0
# 4              1           0     180          1
# ...          ...         ...     ...        ...
# 221550         0           5     188          1
# 221551         2           6     188          1
# 221552         5           2     218          1
# 221553         1           5     199          1
# 221554         1           4     219          1
#
# [221555 rows x 4 columns]

# %%
Y_smote = Y_smote.reset_index(drop=True)

ls = []

for s in Y_smote.astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(Y_smote)), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y_smote = ll.values

Y_smote
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
# data.index[data['leap_year'] == 1].tolist()
# data.index[data['leap_year'] == 1]

# %%
# for i,idx in enumerate(data['leap_year'].tolist()):
#     print(i, idx)

# %% [markdown]
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1 <---
# 5 0
# 6 0
# 7 0
# 8 1 <---
# 9 0
# 10 0
# 11 0
# 12 1 <---
# 13 0
# 14 0
# 15 0
# 16 1 <---
# 17 0
# 18 0
# 19 0
# 20 1 <---
# 21 0
# 22 0
# 23 0
# 24 1 <---
# 25 0
# 26 0
# 27 0
# 28 1 <---
# 29 0
# 30 0

# %%
scaler_day_smote = RobustScaler()

x = X_smote.day_code.values.reshape(-1, 1)

X_smote['day_scaled'] = scaler_day_smote.fit_transform(x).flatten()

# %%
X_smote['day_sin'] = np.sin(X_smote['day_code'] * (2 * np.pi / 7))
X_smote['day_cos'] = np.cos(X_smote['day_code'] * (2 * np.pi / 7))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos
# 0      -0.900969
# 1      -0.222521
# 2       0.623490
# 3       1.000000
# 4       0.623490
# ...          ...
# 221550  1.000000
# 221551 -0.222521
# 221552 -0.222521
# 221553  0.623490
# 221554  0.623490
#
# [221555 rows x 7 columns]

# %%
scaler_month_smote = RobustScaler()

x = X_smote.month_code.values.reshape(-1, 1)

X_smote['month_scaled'] = scaler_month_smote.fit_transform(x).flatten()

# %%
X_smote['month_sin'] = np.sin(X_smote['month_code'] * (2 * np.pi / 12))
X_smote['month_cos'] = np.cos(X_smote['month_code'] * (2 * np.pi / 12))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos
# 0      -0.900969     -1.000000  0.000000e+00   1.000000
# 1      -0.222521     -1.000000  0.000000e+00   1.000000
# 2       0.623490     -1.000000  0.000000e+00   1.000000
# 3       1.000000     -1.000000  0.000000e+00   1.000000
# 4       0.623490     -1.000000  0.000000e+00   1.000000
# ...          ...           ...           ...        ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000
#
# [221555 rows x 10 columns]

# %%
scaler_decade_smote = RobustScaler()

x = X_smote.decade.values.reshape(-1, 1)

X_smote['decade_scaled'] = scaler_decade_smote.fit_transform(x).flatten()

# %%
# alpha_smote = len(X_smote.decade.unique())
alpha_smote = (X_smote.decade.iloc[-1] - X_smote.decade.iloc[0]) + 1

X_smote['decade_sin'] = np.sin(X_smote['decade'] * (2 * np.pi / alpha_smote))
X_smote['decade_cos'] = np.cos(X_smote['decade'] * (2 * np.pi / alpha_smote))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos  decade_scaled  \
# 0      -0.900969     -1.000000  0.000000e+00   1.000000      -1.052632
# 1      -0.222521     -1.000000  0.000000e+00   1.000000      -1.052632
# 2       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# 3       1.000000     -1.000000  0.000000e+00   1.000000      -1.052632
# 4       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# ...          ...           ...           ...        ...            ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025      -0.631579
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000      -0.631579
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000       0.947368
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025      -0.052632
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000       1.000000
#
#           decade_sin  decade_cos
# 0       1.102182e-15   -1.000000
# 1       1.102182e-15   -1.000000
# 2       1.102182e-15   -1.000000
# 3       1.102182e-15   -1.000000
# 4       1.102182e-15   -1.000000
# ...              ...         ...
# 221550 -9.510565e-01   -0.309017
# 221551 -9.510565e-01   -0.309017
# 221552  3.090170e-01   -0.951057
# 221553 -1.564345e-01    0.987688
# 221554  1.564345e-01   -0.987688
#
# [221555 rows x 13 columns]

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
X = X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 3.33333333e-01, -4.33883739e-01, -9.00968868e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 1.00000000e+00, -7.81831482e-01,  6.23489802e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        ...,
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#          9.47368421e-01,  3.09016994e-01, -9.51056516e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#         -5.26315789e-02, -1.56434465e-01,  9.87688341e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#          1.00000000e+00,  1.56434465e-01, -9.87688341e-01]])

# %%
X.shape
# Out:
# (221555, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()
# Y = data['date_normalized'].values.reshape(-1, 1)
Y = Y_smote


Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
Y.shape
# Out:
# (221555, 8)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64

train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (221555, 10)
#
# Y: (221555, 8)
#
# Train data:   (155088, 10)
#
# Train labels: (155088, 8)
#
# Test data:    (66467, 10)
#
# Test labels:  (66467, 8)

# %%
model_smote = Model().to(device)

# %%
numepochs = 120

trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model_smote, numepochs)
# Out:
# Epoch 1/120, Train Loss: 1.264076, Test Loss: 1.264076
# Epoch 2/120, Train Loss: 1.431250, Test Loss: 1.431250
# Epoch 3/120, Train Loss: 1.354538, Test Loss: 1.354538
# Epoch 4/120, Train Loss: 1.185532, Test Loss: 1.185532
# Epoch 5/120, Train Loss: 1.269103, Test Loss: 1.269103
# Epoch 6/120, Train Loss: 1.245341, Test Loss: 1.245341
# Epoch 7/120, Train Loss: 1.291949, Test Loss: 1.291949
# Epoch 8/120, Train Loss: 1.245790, Test Loss: 1.245790
# Epoch 9/120, Train Loss: 1.253546, Test Loss: 1.253546
# Epoch 10/120, Train Loss: 1.318267, Test Loss: 1.318267
# Epoch 11/120, Train Loss: 1.297624, Test Loss: 1.297624
# Epoch 12/120, Train Loss: 1.251698, Test Loss: 1.251698
# Epoch 13/120, Train Loss: 1.344595, Test Loss: 1.344595
# Epoch 14/120, Train Loss: 1.221789, Test Loss: 1.221789
# Epoch 15/120, Train Loss: 1.344811, Test Loss: 1.344811
# Epoch 16/120, Train Loss: 1.230948, Test Loss: 1.230948
# Epoch 17/120, Train Loss: 1.265941, Test Loss: 1.265941
# Epoch 18/120, Train Loss: 1.252442, Test Loss: 1.252442
# Epoch 19/120, Train Loss: 1.217989, Test Loss: 1.217989
# Epoch 20/120, Train Loss: 1.184767, Test Loss: 1.184767
# Epoch 21/120, Train Loss: 1.330692, Test Loss: 1.330692
# Epoch 22/120, Train Loss: 1.289122, Test Loss: 1.289122
# Epoch 23/120, Train Loss: 1.174821, Test Loss: 1.174821
# Epoch 24/120, Train Loss: 1.288321, Test Loss: 1.288321
# Epoch 25/120, Train Loss: 1.370138, Test Loss: 1.370138
# Epoch 26/120, Train Loss: 1.316959, Test Loss: 1.316959
# Epoch 27/120, Train Loss: 1.271593, Test Loss: 1.271593
# Epoch 28/120, Train Loss: 1.199636, Test Loss: 1.199636
# Epoch 29/120, Train Loss: 1.307807, Test Loss: 1.307807
# Epoch 30/120, Train Loss: 1.225034, Test Loss: 1.225034
# Epoch 31/120, Train Loss: 1.251081, Test Loss: 1.251081
# Epoch 32/120, Train Loss: 1.278332, Test Loss: 1.278332
# Epoch 33/120, Train Loss: 1.274931, Test Loss: 1.274931
# Epoch 34/120, Train Loss: 1.289062, Test Loss: 1.289062
# Epoch 35/120, Train Loss: 1.190071, Test Loss: 1.190071
# Epoch 36/120, Train Loss: 1.266083, Test Loss: 1.266083
# Epoch 37/120, Train Loss: 1.245564, Test Loss: 1.245564
# Epoch 38/120, Train Loss: 1.307044, Test Loss: 1.307044
# Epoch 39/120, Train Loss: 1.275287, Test Loss: 1.275287
# Epoch 40/120, Train Loss: 1.364700, Test Loss: 1.364700
# Epoch 41/120, Train Loss: 1.198542, Test Loss: 1.198542
# Epoch 42/120, Train Loss: 1.265492, Test Loss: 1.265492
# Epoch 43/120, Train Loss: 1.312939, Test Loss: 1.312939
# Epoch 44/120, Train Loss: 1.202410, Test Loss: 1.202410
# Epoch 45/120, Train Loss: 1.306813, Test Loss: 1.306813
# Epoch 46/120, Train Loss: 1.309524, Test Loss: 1.309524
# Epoch 47/120, Train Loss: 1.303947, Test Loss: 1.303947
# Epoch 48/120, Train Loss: 1.235631, Test Loss: 1.235631
# Epoch 49/120, Train Loss: 1.317829, Test Loss: 1.317829
# Epoch 50/120, Train Loss: 1.284834, Test Loss: 1.284834
# Epoch 51/120, Train Loss: 1.260497, Test Loss: 1.260497
# Epoch 52/120, Train Loss: 1.302879, Test Loss: 1.302879
# Epoch 53/120, Train Loss: 1.295324, Test Loss: 1.295324
# Epoch 54/120, Train Loss: 1.235903, Test Loss: 1.235903
# Epoch 55/120, Train Loss: 1.291510, Test Loss: 1.291510
# Epoch 56/120, Train Loss: 1.220432, Test Loss: 1.220432
# Epoch 57/120, Train Loss: 1.312960, Test Loss: 1.312960
# Epoch 58/120, Train Loss: 1.261205, Test Loss: 1.261205
# Epoch 59/120, Train Loss: 1.252046, Test Loss: 1.252046
# Epoch 60/120, Train Loss: 1.220955, Test Loss: 1.220955
# Epoch 61/120, Train Loss: 1.292736, Test Loss: 1.292736
# Epoch 62/120, Train Loss: 1.336225, Test Loss: 1.336225
# Epoch 63/120, Train Loss: 1.299033, Test Loss: 1.299033
# Epoch 64/120, Train Loss: 1.250795, Test Loss: 1.250795
# Epoch 65/120, Train Loss: 1.295317, Test Loss: 1.295317
# Epoch 66/120, Train Loss: 1.272358, Test Loss: 1.272358
# Epoch 67/120, Train Loss: 1.298917, Test Loss: 1.298917
# Epoch 68/120, Train Loss: 1.318050, Test Loss: 1.318050
# Epoch 69/120, Train Loss: 1.268429, Test Loss: 1.268429
# Epoch 70/120, Train Loss: 1.280014, Test Loss: 1.280014
# Epoch 71/120, Train Loss: 1.354806, Test Loss: 1.354806
# Epoch 72/120, Train Loss: 1.283293, Test Loss: 1.283293
# Epoch 73/120, Train Loss: 1.308894, Test Loss: 1.308894
# Epoch 74/120, Train Loss: 1.268776, Test Loss: 1.268776
# Epoch 75/120, Train Loss: 1.192364, Test Loss: 1.192364
# Epoch 76/120, Train Loss: 1.360652, Test Loss: 1.360652
# Epoch 77/120, Train Loss: 1.273835, Test Loss: 1.273835
# Epoch 78/120, Train Loss: 1.268004, Test Loss: 1.268004
# Epoch 79/120, Train Loss: 1.188504, Test Loss: 1.188504
# Epoch 80/120, Train Loss: 1.328353, Test Loss: 1.328353
# Epoch 81/120, Train Loss: 1.269106, Test Loss: 1.269106
# Epoch 82/120, Train Loss: 1.322367, Test Loss: 1.322367
# Epoch 83/120, Train Loss: 1.283044, Test Loss: 1.283044
# Epoch 84/120, Train Loss: 1.397364, Test Loss: 1.397364
# Epoch 85/120, Train Loss: 1.239191, Test Loss: 1.239191
# Epoch 86/120, Train Loss: 1.339595, Test Loss: 1.339595
# Epoch 87/120, Train Loss: 1.341404, Test Loss: 1.341404
# Epoch 88/120, Train Loss: 1.374616, Test Loss: 1.374616
# Epoch 89/120, Train Loss: 1.314850, Test Loss: 1.314850
# Epoch 90/120, Train Loss: 1.173010, Test Loss: 1.173010
# Epoch 91/120, Train Loss: 1.344220, Test Loss: 1.344220
# Epoch 92/120, Train Loss: 1.350899, Test Loss: 1.350899
# Epoch 93/120, Train Loss: 1.229288, Test Loss: 1.229288
# Epoch 94/120, Train Loss: 1.331752, Test Loss: 1.331752
# Epoch 95/120, Train Loss: 1.294689, Test Loss: 1.294689
# Epoch 96/120, Train Loss: 1.341845, Test Loss: 1.341845
# Epoch 97/120, Train Loss: 1.399862, Test Loss: 1.399862
# Epoch 98/120, Train Loss: 1.298847, Test Loss: 1.298847
# Epoch 99/120, Train Loss: 1.281127, Test Loss: 1.281127
# Epoch 100/120, Train Loss: 1.238668, Test Loss: 1.238668
# Epoch 101/120, Train Loss: 1.309336, Test Loss: 1.309336
# Epoch 102/120, Train Loss: 1.327825, Test Loss: 1.327825
# Epoch 103/120, Train Loss: 1.255383, Test Loss: 1.255383
# Epoch 104/120, Train Loss: 1.309831, Test Loss: 1.309831
# Epoch 105/120, Train Loss: 1.244737, Test Loss: 1.244737
# Epoch 106/120, Train Loss: 1.338845, Test Loss: 1.338845
# Epoch 107/120, Train Loss: 1.338672, Test Loss: 1.338672
# Epoch 108/120, Train Loss: 1.252103, Test Loss: 1.252103
# Epoch 109/120, Train Loss: 1.276076, Test Loss: 1.276076
# Epoch 110/120, Train Loss: 1.289158, Test Loss: 1.289158
# Epoch 111/120, Train Loss: 1.239969, Test Loss: 1.239969
# Epoch 112/120, Train Loss: 1.277475, Test Loss: 1.277475
# Epoch 113/120, Train Loss: 1.288777, Test Loss: 1.288777
# Epoch 114/120, Train Loss: 1.261237, Test Loss: 1.261237
# Epoch 115/120, Train Loss: 1.207431, Test Loss: 1.207431
# Epoch 116/120, Train Loss: 1.353180, Test Loss: 1.353180
# Epoch 117/120, Train Loss: 1.183200, Test Loss: 1.183200
# Epoch 118/120, Train Loss: 1.253618, Test Loss: 1.253618
# Epoch 119/120, Train Loss: 1.278632, Test Loss: 1.278632
# Epoch 120/120, Train Loss: 1.243466, Test Loss: 1.243466

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([1.0898, 0.9737, 0.9669, 0.9640, 0.9635, 0.9632, 0.9631, 0.9629, 0.9617,
#          0.9620, 0.9619, 0.9621, 0.9619, 0.9625, 0.9616, 0.9616, 0.9622, 0.9621,
#          0.9620, 0.9624, 0.9623, 0.9626, 0.9623, 0.9622, 0.9619, 0.9621, 0.9620,
#          0.9631, 0.9625, 0.9634, 0.9625, 0.9626, 0.9624, 0.9626, 0.9625, 0.9629,
#          0.9628, 0.9624, 0.9628, 0.9627, 0.9625, 0.9617, 0.9619, 0.9617, 0.9614,
#          0.9606, 0.9611, 0.9618, 0.9608, 0.9611, 0.9610, 0.9617, 0.9614, 0.9614,
#          0.9604, 0.9613, 0.9605, 0.9614, 0.9611, 0.9612, 0.9612, 0.9604, 0.9612,
#          0.9616, 0.9610, 0.9606, 0.9607, 0.9608, 0.9608, 0.9621, 0.9613, 0.9613,
#          0.9616, 0.9621, 0.9610, 0.9611, 0.9613, 0.9618, 0.9615, 0.9613, 0.9615,
#          0.9622, 0.9609, 0.9610, 0.9616, 0.9610, 0.9614, 0.9607, 0.9618, 0.9613,
#          0.9616, 0.9611, 0.9615, 0.9610, 0.9618, 0.9606, 0.9621, 0.9607, 0.9609,
#          0.9607, 0.9618, 0.9612, 0.9609, 0.9610, 0.9619, 0.9623, 0.9619, 0.9621,
#          0.9615, 0.9620, 0.9615, 0.9616, 0.9625, 0.9615, 0.9623, 0.9615, 0.9612,
#          0.9622, 0.9614, 0.9614]),
#  tensor([1.2641, 1.4312, 1.3545, 1.1855, 1.2691, 1.2453, 1.2919, 1.2458, 1.2535,
#          1.3183, 1.2976, 1.2517, 1.3446, 1.2218, 1.3448, 1.2309, 1.2659, 1.2524,
#          1.2180, 1.1848, 1.3307, 1.2891, 1.1748, 1.2883, 1.3701, 1.3170, 1.2716,
#          1.1996, 1.3078, 1.2250, 1.2511, 1.2783, 1.2749, 1.2891, 1.1901, 1.2661,
#          1.2456, 1.3070, 1.2753, 1.3647, 1.1985, 1.2655, 1.3129, 1.2024, 1.3068,
#          1.3095, 1.3039, 1.2356, 1.3178, 1.2848, 1.2605, 1.3029, 1.2953, 1.2359,
#          1.2915, 1.2204, 1.3130, 1.2612, 1.2520, 1.2210, 1.2927, 1.3362, 1.2990,
#          1.2508, 1.2953, 1.2724, 1.2989, 1.3181, 1.2684, 1.2800, 1.3548, 1.2833,
#          1.3089, 1.2688, 1.1924, 1.3607, 1.2738, 1.2680, 1.1885, 1.3284, 1.2691,
#          1.3224, 1.2830, 1.3974, 1.2392, 1.3396, 1.3414, 1.3746, 1.3148, 1.1730,
#          1.3442, 1.3509, 1.2293, 1.3318, 1.2947, 1.3418, 1.3999, 1.2988, 1.2811,
#          1.2387, 1.3093, 1.3278, 1.2554, 1.3098, 1.2447, 1.3388, 1.3387, 1.2521,
#          1.2761, 1.2892, 1.2400, 1.2775, 1.2888, 1.2612, 1.2074, 1.3532, 1.1832,
#          1.2536, 1.2786, 1.2435]),
#  tensor([0.4289, 0.5385, 0.5413, 0.5425, 0.5424, 0.5422, 0.5416, 0.5419, 0.5425,
#          0.5419, 0.5424, 0.5416, 0.5422, 0.5419, 0.5426, 0.5423, 0.5420, 0.5423,
#          0.5422, 0.5419, 0.5419, 0.5421, 0.5418, 0.5421, 0.5426, 0.5422, 0.5422,
#          0.5421, 0.5418, 0.5411, 0.5421, 0.5415, 0.5419, 0.5419, 0.5421, 0.5419,
#          0.5416, 0.5415, 0.5413, 0.5416, 0.5421, 0.5423, 0.5418, 0.5419, 0.5421,
#          0.5426, 0.5425, 0.5419, 0.5428, 0.5425, 0.5423, 0.5426, 0.5426, 0.5424,
#          0.5435, 0.5430, 0.5431, 0.5424, 0.5430, 0.5427, 0.5422, 0.5433, 0.5428,
#          0.5425, 0.5424, 0.5427, 0.5428, 0.5429, 0.5428, 0.5419, 0.5424, 0.5432,
#          0.5426, 0.5424, 0.5432, 0.5431, 0.5428, 0.5426, 0.5425, 0.5432, 0.5424,
#          0.5419, 0.5430, 0.5426, 0.5425, 0.5431, 0.5427, 0.5427, 0.5420, 0.5427,
#          0.5424, 0.5426, 0.5425, 0.5427, 0.5421, 0.5427, 0.5421, 0.5428, 0.5425,
#          0.5431, 0.5423, 0.5424, 0.5427, 0.5428, 0.5422, 0.5419, 0.5423, 0.5421,
#          0.5429, 0.5426, 0.5425, 0.5425, 0.5419, 0.5434, 0.5424, 0.5430, 0.5429,
#          0.5418, 0.5425, 0.5427]))

# %%
# (yy * data['date_int'].max()).round()

# %%
# (yHat_test * data['date_int'].max()).round()

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.5561
#
#
# mean_absolute_error(y, yHat): 0.9269
#
# mean_absolute_error(yy, yHat_test): 1.2435
#
#
# mean_squared_error(y, yHat): 2.2626
#
# mean_squared_error(yy, yHat_test): 3.9621
#
#
# mean_squared_log_error(y, yHat): 0.1102
#
# mean_squared_log_error(yy, yHat_test): 0.3944
#
#
# RMSE(y, yHat): 1.5042
#
# RMSE(yy, yHat_test): 1.9905

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss2.jpg", format='svg', bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.detach().T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc2.jpg", format='svg', bbox_inches='tight')


plt.show()

# %%
['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']
# Out:
# ['day_scaled',
#  'day_sin',
#  'day_cos',
#  'month_scaled',
#  'month_sin',
#  'month_cos',
#  'leap_year',
#  'decade_scaled',
#  'decade_sin',
#  'decade_cos']

# %%
def result_to_date(result):
    
    result = str(result)
    
    day   = int(result[6:]) - 1
    month = int(result[4:6]) - 1

    ss = str(f'{result[:4]}0101')
    
    ds = datetime.datetime.strptime(ss, '%Y%m%d')
    
    ds = ds + relativedelta(months=month, days=day)

    result = ds.strftime('%d-%m-%Y')
    
    
    return result

# %%
# (16830739, 17848869)
result_to_date(16830739), result_to_date(17848869)
# Out:
# ('08-08-1683', '08-06-1791')

# %%
def test_model(input_list):
    

    X       = np.zeros((1, 10))
    X_smote = np.zeros((1, 10))



    day       = np.array(map_day[input_list[0]])
    month     = np.array(map_month[input_list[1]])
    leap_year = map_leap_year[input_list[2]]
    decade    = np.array(input_list[3].strip('[]')).astype('int64')


    X[0, 0] = scaler_day.transform(day.reshape(-1, 1)).flatten()
    X[0, 1] = np.sin(day * (2 * np.pi / 7))
    X[0, 2] = np.cos(day * (2 * np.pi / 7))

    X[0, 3] = scaler_month.transform(month.reshape(-1, 1)).flatten()
    X[0, 4] = np.sin(month * (2 * np.pi / 12))
    X[0, 5] = np.cos(month * (2 * np.pi / 12))

    X[0, 6] = leap_year

    X[0, 7] = scaler_decade.transform(decade.reshape(-1, 1)).flatten()
    X[0, 8] = np.sin(decade * (2 * np.pi / alpha))
    X[0, 9] = np.cos(decade * (2 * np.pi / alpha))

    # ---

    X_smote[0, 0] = scaler_day_smote.transform(day.reshape(-1, 1)).flatten()
    X_smote[0, 1] = X[0, 1]
    X_smote[0, 2] = X[0, 2]

    X_smote[0, 3] = scaler_month_smote.transform(month.reshape(-1, 1)).flatten()
    X_smote[0, 4] = X[0, 4]
    X_smote[0, 5] = X[0, 5]

    X_smote[0, 6] = leap_year

    X_smote[0, 7] = scaler_decade_smote.transform(decade.reshape(-1, 1)).flatten()
    X_smote[0, 8] = np.sin(decade * (2 * np.pi / alpha_smote))
    X_smote[0, 9] = np.cos(decade * (2 * np.pi / alpha_smote))


    # ---

    result       = model(torch.tensor(X).to(device).float())
    result_smote = model_smote(torch.tensor(X_smote).to(device).float())


    # ---


    result       = ''.join(result.detach().cpu().numpy().round().astype(int).astype(str).flatten())
    result_smote = ''.join(result_smote.detach().cpu().numpy().round().astype(int).astype(str).flatten())


    
    return result_to_date(result), result_to_date(result_smote)

# %%
input_test1 = ['[MON]', '[DEC]', '[False]', '[196]']
output_test1 = '3-12-1962'

input_test2 = ['[THU]', '[DEC]', '[True]', '[204]']
output_test2 = '3-12-2048'

input_test3 = ['[WED]', '[JAN]', '[False]', '[181]']
output_test3 = '10-1-1810'


input_test4 = ['[WED]', '[JUN]', '[False]', '[209]']

# %%
test_model(input_test1), test_model(input_test2), test_model(input_test3), test_model(input_test4)
# Out:
# (('14-12-1964', '14-12-1964'),
#  ('14-12-2054', '14-12-2044'),
#  ('14-01-1824', '14-01-1804'),
#  ('14-06-2084', '14-06-2074'))

# %%
output_test1, output_test2, output_test3
# Out:
# ('3-12-1962', '3-12-2048', '10-1-1810')

# %%
# example_input = pd.read_csv('./data/example_input.txt', sep=' ', header=None)
example_input = pd.read_csv('example_input.txt', sep=' ', header=None)


example_input.columns = ['day', 'month', 'leap_year', 'decade']

# %%
example_input
# Out:
#         day  month leap_year decade
# 0     [WED]  [JAN]   [False]  [180]
# 1     [MON]  [JAN]   [False]  [190]
# 2     [SAT]  [JAN]    [True]  [200]
# 3     [FRI]  [JAN]   [False]  [210]
# 4     [WED]  [JAN]   [False]  [220]
# ...     ...    ...       ...    ...
# 1460  [MON]  [OCT]    [True]  [214]
# 1461  [TUE]  [DEC]   [False]  [183]
# 1462  [SUN]  [DEC]   [False]  [193]
# 1463  [SAT]  [DEC]   [False]  [203]
# 1464  [THU]  [DEC]   [False]  [213]
#
# [1465 rows x 4 columns]

# %%
R       = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result'])
R_smote = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result_smote'])

# %%
example_input.iloc[0].tolist()
# Out:
# ['[WED]', '[JAN]', '[False]', '[180]']

# %%
for i in range(len(example_input)):
    R.iloc[i], R_smote.iloc[i] = test_model(example_input.iloc[i].tolist())

# %%
R
# Out:
#           result
# 0     14-01-1814
# 1     14-01-1914
# 2     14-01-2014
# 3     14-01-2114
# 4     14-01-2184
# ...          ...
# 1460  14-10-2154
# 1461  14-12-1834
# 1462  14-12-1934
# 1463  14-12-2034
# 1464  14-12-2134
#
# [1465 rows x 1 columns]

# %%
final = pd.concat([example_input, R], axis=1)
final
# Out:
#         day  month leap_year decade      result
# 0     [WED]  [JAN]   [False]  [180]  14-01-1814
# 1     [MON]  [JAN]   [False]  [190]  14-01-1914
# 2     [SAT]  [JAN]    [True]  [200]  14-01-2014
# 3     [FRI]  [JAN]   [False]  [210]  14-01-2114
# 4     [WED]  [JAN]   [False]  [220]  14-01-2184
# ...     ...    ...       ...    ...         ...
# 1460  [MON]  [OCT]    [True]  [214]  14-10-2154
# 1461  [TUE]  [DEC]   [False]  [183]  14-12-1834
# 1462  [SUN]  [DEC]   [False]  [193]  14-12-1934
# 1463  [SAT]  [DEC]   [False]  [203]  14-12-2034
# 1464  [THU]  [DEC]   [False]  [213]  14-12-2134
#
# [1465 rows x 5 columns]

# %%
final_smote = pd.concat([example_input, R_smote], axis=1)
final_smote
# Out:
#         day  month leap_year decade result_smote
# 0     [WED]  [JAN]   [False]  [180]   14-01-1804
# 1     [MON]  [JAN]   [False]  [190]   14-01-1904
# 2     [SAT]  [JAN]    [True]  [200]   14-01-2004
# 3     [FRI]  [JAN]   [False]  [210]   14-01-2104
# 4     [WED]  [JAN]   [False]  [220]   14-01-2184
# ...     ...    ...       ...    ...          ...
# 1460  [MON]  [OCT]    [True]  [214]   14-10-2144
# 1461  [TUE]  [DEC]   [False]  [183]   14-12-1834
# 1462  [SUN]  [DEC]   [False]  [193]   14-12-1944
# 1463  [SAT]  [DEC]   [False]  [203]   14-12-2034
# 1464  [THU]  [DEC]   [False]  [213]   14-12-2134
#
# [1465 rows x 5 columns]

# %%
final.to_csv('output_file.txt', sep=' ', header=None, index=False)

# %%
final_smote.to_csv('output_file_smote.txt', sep=' ', header=None, index=False)

# %% [markdown]
# Out-liers

# %% [markdown]
# Saving

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              'model_smote_state_dict': model_smote.state_dict()}


torch.save(checkpoint, 'checkpoint.pth.tar')

# %%
# checkpoint = torch.load('checkpoint.pth.tar')

# %%
# model       = Model()
# model_smote = Model()


# model.load_state_dict(checkpoint['model_state_dict'])
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
