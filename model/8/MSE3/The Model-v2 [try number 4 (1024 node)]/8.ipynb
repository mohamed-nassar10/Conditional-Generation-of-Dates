# %%
import datetime

import copy

import random


from dateutil.relativedelta import relativedelta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('seaborn')
# plt.style.use(['dark_background', 'ggplot'])

import seaborn as sns
# sns.set()

# import scipy
# import scipy.stats as stats


# # sympy = symbolic math in Python
# import sympy as sym
# import sympy.plotting.plot as symplot


# make the equations look nicer

# from IPython.display import display
# display.set_matplotlib_formats('svg') # Deprecated since version 7.23

# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


# %config InlineBackend.set_matplotlib_formats = ["svg"]
# %config InlineBackend.figure_formats = ["svg"]

# %%
import sklearn


from sklearn.model_selection import train_test_split


# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler     # <------------ (-1.0, 1.0)
# from sklearn.preprocessing import MinMaxScaler


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from imblearn.over_sampling import SMOTE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset, DataLoader





torch.__version__
# Out:
# '1.12.1+cu113'

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def print_score(shape, yHat, y, yHat_test, yy):
    
    
    n, p = shape
    
    R2 = r2_score(y.detach().numpy(), yHat.detach().numpy())
    
    Adj_r2 = 1 - (1 - R2)  *  (n - 1) / (n - p - 1)
    
    print(f'Adjusted R-Squared(y, yHat): {Adj_r2:0.4f}\n\n')
    # r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
    #  R^2 score is not well-defined with less than two samples
    
    
    print(f'mean_absolute_error(y, yHat):',
          f'{mean_absolute_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_absolute_error(yy, yHat_test):',
          f'{mean_absolute_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_error(y, yHat):',
          f'{mean_squared_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_error(yy, yHat_test):',
          f'{mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_log_error(y, yHat):',
          f'{mean_squared_log_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_log_error(yy, yHat_test):',
          f'{mean_squared_log_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    
    print(f'RMSE(y, yHat):',
          f'{np.sqrt( mean_squared_error(y.detach().numpy(), yHat.detach().numpy()) ):0.4f}\n')
    print(f'RMSE(yy, yHat_test):',
          f'{np.sqrt( mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()) ):0.4f}\n\n')

# %%
# date = np.datetime64("2000-01-01")
# date_strings = date.astype(str).split('-'). 
# # >> ['2000', '01', '01']

# year_int = int(date_strings[0])

# %%
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Out:
# --2022-08-18 14:09:08--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5230713 (5.0M) [text/plain]
# Saving to: ‘data.txt’
#
# data.txt            100%[===================>]   4.99M  --.-KB/s    in 0.1s
#
# 2022-08-18 14:09:09 (42.4 MB/s) - ‘data.txt’ saved [5230713/5230713]
#
# --2022-08-18 14:09:09--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37732 (37K) [text/plain]
# Saving to: ‘example_input.txt’
#
# example_input.txt   100%[===================>]  36.85K  --.-KB/s    in 0s
#
# 2022-08-18 14:09:09 (137 MB/s) - ‘example_input.txt’ saved [37732/37732]

# %%
# !ls
# Out:
# data.txt  example_input.txt  sample_data

# %% [markdown]
# 'text.txt'

# %% [markdown]
# [ 1-1-1800 to 31-12-2200 ]

# %% [markdown]
# [day condition] [month condition] [leap year condition] [decade condition] date

# %% [markdown]
# [MON] [DEC] [False] [196] 3-12-1962
# [THU] [DEC] [True] [204] 3-12-2048
# [WED] [JAN] [False] [181] 10-1-1810

# %%
# data = np.loadtxt(open('text.txt','r'),delimiter=' ')
# ori = pd.read_csv('./data/data.txt', sep=' ', header=None)

ori = pd.read_csv('data.txt', sep=' ', header=None)

# %%
ori.columns = ['day', 'month', 'leap_year', 'decade', 'date']

# %%
ori
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
# data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)
# # pd.to_datetime(data.date, infer_datetime_format=False)

# %%
ori.dtypes
# Out:
# day          object
# month        object
# leap_year    object
# decade       object
# date         object
# dtype: object

# %%
# data_backup = copy.deepcopy(ori)
data = copy.deepcopy(ori)

# %%
data
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
data.date
# Out:
# 0           1-1-1800
# 1           1-1-1801
# 2           1-1-1802
# 3           1-1-1803
# 4           1-1-1804
#              ...
# 146457    31-12-2196
# 146458    31-12-2197
# 146459    31-12-2198
# 146460    31-12-2199
# 146461    31-12-2200
# Name: date, Length: 146462, dtype: object

# %%
# # data['date'] = pd.date_range('3-12-2048', periods=10)
# # data['date'] = pd.date_range('12-3-1962', periods=10)

# # 1-1-1800 to 31-12-2200
# data['date'] = pd.date_range(start='1-1-1800',end='12-31-2200')


data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)

# # data.date = data.date.dt.strftime('%d-%m-%Y')
# # data.date = pd.to_datetime(data.date.dt.strftime('%d-%m-%Y'), format='%d-%m-%Y', infer_datetime_format=False)

# %%
data.dtypes
# Out:
# day                  object
# month                object
# leap_year            object
# decade               object
# date         datetime64[ns]
# dtype: object

# %%
data
# Out:
#           day  month leap_year decade       date
# 0       [WED]  [JAN]   [False]  [180] 1800-01-01
# 1       [THU]  [JAN]   [False]  [180] 1801-01-01
# 2       [FRI]  [JAN]   [False]  [180] 1802-01-01
# 3       [SAT]  [JAN]   [False]  [180] 1803-01-01
# 4       [SUN]  [JAN]    [True]  [180] 1804-01-01
# ...       ...    ...       ...    ...        ...
# 146457  [SAT]  [DEC]    [True]  [219] 2196-12-31
# 146458  [SUN]  [DEC]   [False]  [219] 2197-12-31
# 146459  [MON]  [DEC]   [False]  [219] 2198-12-31
# 146460  [TUE]  [DEC]   [False]  [219] 2199-12-31
# 146461  [WED]  [DEC]   [False]  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %%
map_leap_year = {'[False]': int(0), '[True]' : int(1)}

data.leap_year = data.leap_year.map(map_leap_year)

# data.leap_year = data.leap_year.astype(np.float64)

# %%
data
# Out:
#           day  month  leap_year decade       date
# 0       [WED]  [JAN]          0  [180] 1800-01-01
# 1       [THU]  [JAN]          0  [180] 1801-01-01
# 2       [FRI]  [JAN]          0  [180] 1802-01-01
# 3       [SAT]  [JAN]          0  [180] 1803-01-01
# 4       [SUN]  [JAN]          1  [180] 1804-01-01
# ...       ...    ...        ...    ...        ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31
# 146459  [MON]  [DEC]          0  [219] 2198-12-31
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31
# 146461  [WED]  [DEC]          0  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %% [markdown]
# date -> timestamp

# %%
data.date.iloc[0]
# Out:
# Timestamp('1800-01-01 00:00:00')

# %%
data['date_int'] = data['date'].dt.strftime("%Y%m%d").astype(np.int64)

# data['date_str'] = data['date'].dt.strftime("%Y%m%d")

# %%
# data['date_int'].map(str)
# data['date_int'].astype(str)

# %%
# date_max = data.date_int.max()
# data['date_normalized'] = data.date_int / date_max

# %%
data
# Out:
#           day  month  leap_year decade       date  date_int
# 0       [WED]  [JAN]          0  [180] 1800-01-01  18000101
# 1       [THU]  [JAN]          0  [180] 1801-01-01  18010101
# 2       [FRI]  [JAN]          0  [180] 1802-01-01  18020101
# 3       [SAT]  [JAN]          0  [180] 1803-01-01  18030101
# 4       [SUN]  [JAN]          1  [180] 1804-01-01  18040101
# ...       ...    ...        ...    ...        ...       ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31  21961231
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31  21971231
# 146459  [MON]  [DEC]          0  [219] 2198-12-31  21981231
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31  21991231
# 146461  [WED]  [DEC]          0  [220] 2200-12-31  22001231
#
# [146462 rows x 6 columns]

# %%
x = data.decade.iloc[0]
x
# Out:
# '[180]'

# %%
x.strip('[]')
# Out:
# '180'

# %%
data.decade = data.decade.apply(lambda x: x.strip('[]')).astype('int64')

# %%
# data.day = data.day.apply(lambda x: x.strip('[]'))
# data.month = data.month.apply(lambda x: x.strip('[]'))

# %%
map_day = {'[SAT]': int(0),
           '[SUN]': int(1),
           '[MON]': int(2),
           '[TUE]': int(3),
           '[WED]': int(4),
           '[THU]': int(5),
           '[FRI]': int(6)}

# %%
data['day_code'] = data.day.map(map_day)

# %%
scaler_day = RobustScaler()

x = data.day_code.values.reshape(-1, 1)

data['day_scaled'] = scaler_day.fit_transform(x).flatten()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled
# 0             0.25
# 1             0.50
# 2             0.75
# 3            -0.75
# 4            -0.50
# ...            ...
# 146457       -0.75
# 146458       -0.50
# 146459       -0.25
# 146460        0.00
# 146461        0.25
#
# [146462 rows x 8 columns]

# %%
data['day_sin'] = np.sin(data['day_code'] * (2 * np.pi / 7))
data['day_cos'] = np.cos(data['day_code'] * (2 * np.pi / 7))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos
# 0             0.25 -0.433884 -0.900969
# 1             0.50 -0.974928 -0.222521
# 2             0.75 -0.781831  0.623490
# 3            -0.75  0.000000  1.000000
# 4            -0.50  0.781831  0.623490
# ...            ...       ...       ...
# 146457       -0.75  0.000000  1.000000
# 146458       -0.50  0.781831  0.623490
# 146459       -0.25  0.974928 -0.222521
# 146460        0.00  0.433884 -0.900969
# 146461        0.25 -0.433884 -0.900969
#
# [146462 rows x 10 columns]

# %%
map_month = {'[JAN]': int(0),
             '[FEB]': int(1),
             '[MAR]': int(2),
             '[APR]': int(3),
             '[MAY]': int(4),
             '[JUN]': int(5),
             '[JUL]': int(6),
             '[AUG]': int(7),
             '[SEP]': int(8),
             '[OCT]': int(9),
             '[NOV]': int(10),
             '[DEC]': int(11)}

# %%
data['month_code'] = data.month.map(map_month)

# %%
scaler_month = RobustScaler()

x = data.month_code.values.reshape(-1, 1)

data['month_scaled'] = scaler_month.fit_transform(x).flatten()

# %%
data['month_sin'] = np.sin(data['month_code'] * (2 * np.pi / 12))
data['month_cos'] = np.cos(data['month_code'] * (2 * np.pi / 12))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ...           ...
# 146457   0.866025
# 146458   0.866025
# 146459   0.866025
# 146460   0.866025
# 146461   0.866025
#
# [146462 rows x 14 columns]

# %%
scaler_decade = RobustScaler()

x = data.decade.values.reshape(-1, 1)

data['decade_scaled'] = scaler_decade.fit_transform(x).flatten()

# %%
# alpha = len(data.decade.unique())
alpha = (data.decade.iloc[-1] - data.decade.iloc[0]) + 1

data['decade_sin'] = np.sin(data['decade'] * (2 * np.pi / alpha))
data['decade_cos'] = np.cos(data['decade'] * (2 * np.pi / alpha))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %%
# data.date_normalized.min(), data.date_normalized.max()

# %%
# round(data.date_normalized.min()), round(data.date_normalized.max())

# %%
round(data.day_scaled.min()), round(data.day_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_sin.min()), round(data.day_sin.max())
# Out:
# (-1, 1)

# %%
round(data.day_cos.min()), round(data.day_cos.max())
# Out:
# (-1, 1)

# %%
round(data.month_scaled.min()), round(data.month_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.month_sin.min()), round(data.month_sin.max())
# Out:
# (-1, 1)

# %%
round(data.month_cos.min()), round(data.month_cos.max())
# Out:
# (-1, 1)

# %%
data.leap_year.min(), data.leap_year.max()
# Out:
# (0, 1)

# %%
round(data.decade_scaled.min()), round(data.decade_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.decade_sin.min()), round(data.decade_sin.max())
# Out:
# (-1, 1)

# %%
round(data.decade_cos.min()), round(data.decade_cos.max())
# Out:
# (-1, 1)

# %% [markdown]
# Boxplot

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.day.value_counts().plot(kind="bar")

# %%
data.month.value_counts().plot(kind="bar")

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
data.decade.value_counts().plot(kind="bar")

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %% [markdown]
# ['day_sin', 'day_cos', 'month_sin', 'month_cos', 'leap_year', 'decade_scaled']
# ['date_timestamp_scaled']

# %%
X = data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
          'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 0.25      , -0.43388374, -0.90096887, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.5       , -0.97492791, -0.22252093, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.75      , -0.78183148,  0.6234898 , ..., -1.        ,
#          0.63624244, -0.77148918],
#        ...,
#        [-0.25      ,  0.97492791, -0.22252093, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.        ,  0.43388374, -0.90096887, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.25      , -0.43388374, -0.90096887, ...,  1.        ,
#          0.74655322, -0.6653257 ]])

# %%
len(X)
# Out:
# 146462

# %%
X.shape
# Out:
# (146462, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()


ls = []

for s in data['date_int'].astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(data['date_int'])), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y = ll.values

Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 2, 0, ..., 2, 3, 1]])

# %%
len(Y)
# Out:
# 146462

# %%
Y.shape
# Out:
# (146462, 8)

# %%
# # leap = np.where(~X['leap_year'] == 1)[0]
# leap = np.where(X['leap_year'] == 1)[0]

# leap

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64


train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (146462, 10)
#
# Y: (146462, 8)
#
# Train data:   (102523, 10)
#
# Train labels: (102523, 8)
#
# Test data:    (43939, 10)
#
# Test labels:  (43939, 8)

# %%
102523 % 32, 102523 % 64
# Out:
# (27, 59)

# %%
class Model(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.input = nn.Linear(10, 64)

        self.fc1 = nn.Linear(64, 128)
        self.bnorm1 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 512)
        self.bnorm2 = nn.BatchNorm1d(512)

        self.fc3 = nn.Linear(512, 1024)
        self.bnorm3 = nn.BatchNorm1d(1024)

        self.fc4 = nn.Linear(1024, 512)
        self.bnorm4 = nn.BatchNorm1d(512)

        self.fc5 = nn.Linear(512, 128)
        self.bnorm5 = nn.BatchNorm1d(128)

        self.fc6 = nn.Linear(128, 64)
        self.bnorm6 = nn.BatchNorm1d(64)


        self.output = nn.Linear(64, 8)



    def forward(self, x):


        # print(f'training={self.training}')

        x = F.relu( self.input(x) ) # 64

        x = F.relu(self.bnorm1(self.fc1(x))) # 128
        x = F.dropout(x, p=0.07, training=self.training)

        x = F.relu(self.bnorm2(self.fc2(x))) # 512
        x = F.dropout(x, p=0.12, training=self.training)

        x = F.relu(self.bnorm3(self.fc3(x))) # 1024
        x = F.dropout(x, p=0.25, training=self.training)

        x = F.relu(self.bnorm4(self.fc4(x))) # 512
        x = F.dropout(x, p=0.12, training=self.training)

        x = F.relu(self.bnorm5(self.fc5(x))) # 128
        x = F.dropout(x, p=0.07, training=self.training)

        x = F.relu(self.bnorm6(self.fc6(x))) # 64
        # x = F.dropout(x, p=0.05, training=self.training)

        x = F.relu(self.output(x)) # 8
        # x = self.output(x)
        


        return x

# %%
# test_x, test_y = next(iter(train_loader))

# print(f'test_x: {test_x.shape}\n')
# print(f'test_y: {test_y.shape}\n')

# %%
def train(model, numepochs):

    numepochs = numepochs

    model = model
    
    
    
    lossfun = nn.MSELoss()
    # lossfun = nn.L1Loss()


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0002, betas=(0.5, 0.999), weight_decay=1e-5)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.5, 0.999), weight_decay=1e-1)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=1e-9)


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
    
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    
    
    
    trainLoss = torch.zeros(numepochs)
    testLoss  = torch.zeros(numepochs)
    trainAcc  = torch.zeros(numepochs)
    # testAcc   = torch.zeros(numepochs)


    for epochi in range(numepochs):

        model.train() # switch to train mode

        batchLoss = []
        batchAcc  = []

        for X,y in train_loader:

            X = X.to(device)
            y = y.to(device)

            yHat = model(X)
            loss = lossfun(yHat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())
            # batchAcc.append( torch.mean(( yHat == y).float() ).item() )
            # batchAcc.append( torch.mean( (torch.abs(yHat - y) < 1).float() ).item() ) # <1 for rounding
            batchAcc.append( r2_score(y.detach().cpu().numpy(), yHat.detach().cpu().numpy()) )
            




        trainLoss[epochi] = np.mean(batchLoss)
        # trainAcc[epochi]  = 100*np.mean(batchAcc)
        trainAcc[epochi]  = np.mean(batchAcc)
        



        model.eval() # switch to test mode

        XX,yy = next(iter(test_loader))

        XX = XX.to(device)
        yy = yy.to(device)

        # forward pass and loss
        with torch.no_grad():
            yHat_test = model(XX)
            loss_test = lossfun(yHat_test, yy)


        testLoss[epochi] = loss_test.item()
        # testAcc[epochi]  = 100*torch.mean( (yHat_test == yy).float() ).item()
        # testAcc[epochi]  = 100*torch.mean( (torch.abs(yHat_test - yy) < 1).float() ).item()
        # testAcc[epochi]  = 100*r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
        


        # if (epochi + 1) % 5 == 0:
        print(f'Epoch {epochi+1}/{numepochs}, Train Loss: {loss.item():0.6f}, Test Loss: {loss_test.item():0.6f}')


        
    return trainLoss.cpu(), testLoss.cpu(), trainAcc.cpu(), yHat.cpu(), y.cpu(), yHat_test.cpu(), yy.cpu()

# %%
model = Model().to(device)

# test_hat = model(torch.randn(32,6))
# test_hat = model(test_x)

# print(test_hat.shape)


# # checkpoint = torch.load('checkpoint.pth.tar', map_location=torch.device('cpu'))
# checkpoint = torch.load('checkpoint_half.pth.tar', map_location=torch.device('cpu'))

# model.load_state_dict(checkpoint['model_state_dict'])

# %%
# for p in list(model.named_parameters()):
#     if 'weight' in p[0] and 'bnorm' not in p[0]:
#         nn.init.xavier_normal_(p[1].data)
#         print(p[0])
#         print(p[1].data.shape)

# %%
numepochs = 120
# numepochs = 300
# numepochs = 500



trainLoss1, testLoss1, trainAcc1, yHat1, y1, yHat_test1, yy1 = train(model, numepochs)
# Out:
# Epoch 1/120, Train Loss: 2.566577, Test Loss: 2.283629
# Epoch 2/120, Train Loss: 2.409548, Test Loss: 2.113798
# Epoch 3/120, Train Loss: 2.354638, Test Loss: 2.052906
# Epoch 4/120, Train Loss: 2.311755, Test Loss: 1.987182
# Epoch 5/120, Train Loss: 2.321741, Test Loss: 1.999209
# Epoch 6/120, Train Loss: 2.305456, Test Loss: 2.059774
# Epoch 7/120, Train Loss: 2.305014, Test Loss: 2.016999
# Epoch 8/120, Train Loss: 2.289014, Test Loss: 2.012779
# Epoch 9/120, Train Loss: 2.307162, Test Loss: 1.989085
# Epoch 10/120, Train Loss: 2.630750, Test Loss: 1.973859
# Epoch 11/120, Train Loss: 2.290622, Test Loss: 2.016614
# Epoch 12/120, Train Loss: 2.299384, Test Loss: 2.008053
# Epoch 13/120, Train Loss: 2.280721, Test Loss: 2.024579
# Epoch 14/120, Train Loss: 2.298119, Test Loss: 2.009871
# Epoch 15/120, Train Loss: 2.277549, Test Loss: 2.005093
# Epoch 16/120, Train Loss: 2.285017, Test Loss: 1.992948
# Epoch 17/120, Train Loss: 2.271575, Test Loss: 1.987739
# Epoch 18/120, Train Loss: 2.289104, Test Loss: 1.996283
# Epoch 19/120, Train Loss: 2.275636, Test Loss: 1.980657
# Epoch 20/120, Train Loss: 2.300952, Test Loss: 1.980812
# Epoch 21/120, Train Loss: 2.295972, Test Loss: 1.956495
# Epoch 22/120, Train Loss: 2.276147, Test Loss: 1.959468
# Epoch 23/120, Train Loss: 2.286081, Test Loss: 1.947129
# Epoch 24/120, Train Loss: 2.274827, Test Loss: 1.950033
# Epoch 25/120, Train Loss: 2.282405, Test Loss: 1.929622
# Epoch 26/120, Train Loss: 2.281050, Test Loss: 1.930030
# Epoch 27/120, Train Loss: 2.305075, Test Loss: 1.938103
# Epoch 28/120, Train Loss: 2.282474, Test Loss: 1.933676
# Epoch 29/120, Train Loss: 2.268046, Test Loss: 1.977808
# Epoch 30/120, Train Loss: 2.289470, Test Loss: 1.927680
# Epoch 31/120, Train Loss: 2.286474, Test Loss: 1.939034
# Epoch 32/120, Train Loss: 2.327727, Test Loss: 1.943855
# Epoch 33/120, Train Loss: 2.308694, Test Loss: 1.947710
# Epoch 34/120, Train Loss: 2.300586, Test Loss: 1.945796
# Epoch 35/120, Train Loss: 2.290838, Test Loss: 1.943834
# Epoch 36/120, Train Loss: 2.306314, Test Loss: 1.962195
# Epoch 37/120, Train Loss: 2.287780, Test Loss: 1.931006
# Epoch 38/120, Train Loss: 2.348529, Test Loss: 1.943729
# Epoch 39/120, Train Loss: 2.280584, Test Loss: 1.954846
# Epoch 40/120, Train Loss: 2.271788, Test Loss: 1.958707
# Epoch 41/120, Train Loss: 2.269279, Test Loss: 1.945527
# Epoch 42/120, Train Loss: 2.287572, Test Loss: 1.979016
# Epoch 43/120, Train Loss: 2.326098, Test Loss: 1.962701
# Epoch 44/120, Train Loss: 2.273868, Test Loss: 1.958464
# Epoch 45/120, Train Loss: 2.271174, Test Loss: 1.948113
# Epoch 46/120, Train Loss: 2.329920, Test Loss: 1.955302
# Epoch 47/120, Train Loss: 2.270999, Test Loss: 1.947046
# Epoch 48/120, Train Loss: 2.302325, Test Loss: 1.942180
# Epoch 49/120, Train Loss: 2.294689, Test Loss: 1.946549
# Epoch 50/120, Train Loss: 2.306825, Test Loss: 1.956140
# Epoch 51/120, Train Loss: 2.310755, Test Loss: 1.964964
# Epoch 52/120, Train Loss: 2.284528, Test Loss: 1.978840
# Epoch 53/120, Train Loss: 2.266711, Test Loss: 1.948637
# Epoch 54/120, Train Loss: 2.357371, Test Loss: 2.002526
# Epoch 55/120, Train Loss: 2.312797, Test Loss: 2.009831
# Epoch 56/120, Train Loss: 2.279074, Test Loss: 2.003758
# Epoch 57/120, Train Loss: 2.305303, Test Loss: 1.988138
# Epoch 58/120, Train Loss: 2.308438, Test Loss: 1.970209
# Epoch 59/120, Train Loss: 2.291753, Test Loss: 2.024154
# Epoch 60/120, Train Loss: 2.291444, Test Loss: 2.036973
# Epoch 61/120, Train Loss: 2.318976, Test Loss: 2.020406
# Epoch 62/120, Train Loss: 2.262791, Test Loss: 1.988048
# Epoch 63/120, Train Loss: 2.298167, Test Loss: 1.976638
# Epoch 64/120, Train Loss: 2.295159, Test Loss: 2.003138
# Epoch 65/120, Train Loss: 2.300281, Test Loss: 1.977993
# Epoch 66/120, Train Loss: 2.389042, Test Loss: 1.974804
# Epoch 67/120, Train Loss: 2.323083, Test Loss: 2.033428
# Epoch 68/120, Train Loss: 2.287663, Test Loss: 2.035252
# Epoch 69/120, Train Loss: 2.348998, Test Loss: 2.101357
# Epoch 70/120, Train Loss: 2.335637, Test Loss: 2.057583
# Epoch 71/120, Train Loss: 2.307037, Test Loss: 2.087672
# Epoch 72/120, Train Loss: 2.282693, Test Loss: 2.043123
# Epoch 73/120, Train Loss: 2.208435, Test Loss: 2.022260
# Epoch 74/120, Train Loss: 2.304912, Test Loss: 2.059728
# Epoch 75/120, Train Loss: 2.341345, Test Loss: 2.023238
# Epoch 76/120, Train Loss: 2.292169, Test Loss: 2.105706
# Epoch 77/120, Train Loss: 2.378943, Test Loss: 2.052352
# Epoch 78/120, Train Loss: 2.172797, Test Loss: 2.133366
# Epoch 79/120, Train Loss: 2.318238, Test Loss: 2.100260
# Epoch 80/120, Train Loss: 2.256370, Test Loss: 2.152352
# Epoch 81/120, Train Loss: 2.188854, Test Loss: 2.069261
# Epoch 82/120, Train Loss: 2.290939, Test Loss: 2.164756
# Epoch 83/120, Train Loss: 2.232930, Test Loss: 2.168544
# Epoch 84/120, Train Loss: 2.260126, Test Loss: 2.131864
# Epoch 85/120, Train Loss: 2.205644, Test Loss: 2.152873
# Epoch 86/120, Train Loss: 2.188939, Test Loss: 2.146600
# Epoch 87/120, Train Loss: 2.308621, Test Loss: 2.118276
# Epoch 88/120, Train Loss: 2.321985, Test Loss: 2.118037
# Epoch 89/120, Train Loss: 2.261959, Test Loss: 2.136986
# Epoch 90/120, Train Loss: 2.391801, Test Loss: 2.029223
# Epoch 91/120, Train Loss: 2.363246, Test Loss: 2.039102
# Epoch 92/120, Train Loss: 2.263759, Test Loss: 1.898040
# Epoch 93/120, Train Loss: 2.242131, Test Loss: 2.230825
# Epoch 94/120, Train Loss: 2.346944, Test Loss: 1.958080
# Epoch 95/120, Train Loss: 2.199144, Test Loss: 1.973517
# Epoch 96/120, Train Loss: 2.256522, Test Loss: 1.825582
# Epoch 97/120, Train Loss: 2.259359, Test Loss: 2.046744
# Epoch 98/120, Train Loss: 2.257435, Test Loss: 1.815038
# Epoch 99/120, Train Loss: 2.429358, Test Loss: 2.012228
# Epoch 100/120, Train Loss: 2.366362, Test Loss: 1.841001
# Epoch 101/120, Train Loss: 2.342333, Test Loss: 2.102810
# Epoch 102/120, Train Loss: 2.254036, Test Loss: 1.776468
# Epoch 103/120, Train Loss: 2.215255, Test Loss: 1.982057
# Epoch 104/120, Train Loss: 2.159197, Test Loss: 1.781226
# Epoch 105/120, Train Loss: 2.234762, Test Loss: 1.876651
# Epoch 106/120, Train Loss: 2.315377, Test Loss: 2.052818
# Epoch 107/120, Train Loss: 2.184723, Test Loss: 2.160114
# Epoch 108/120, Train Loss: 2.180689, Test Loss: 2.082639
# Epoch 109/120, Train Loss: 2.212292, Test Loss: 2.147226
# Epoch 110/120, Train Loss: 2.199840, Test Loss: 2.336130
# Epoch 111/120, Train Loss: 2.278867, Test Loss: 2.267746
# Epoch 112/120, Train Loss: 2.481426, Test Loss: 1.902916
# Epoch 113/120, Train Loss: 2.504136, Test Loss: 2.063911
# Epoch 114/120, Train Loss: 2.247619, Test Loss: 1.978932
# Epoch 115/120, Train Loss: 2.268579, Test Loss: 2.185011
# Epoch 116/120, Train Loss: 2.108732, Test Loss: 1.998105
# Epoch 117/120, Train Loss: 2.349375, Test Loss: 1.935589
# Epoch 118/120, Train Loss: 2.256110, Test Loss: 2.020142
# Epoch 119/120, Train Loss: 2.075357, Test Loss: 2.236387
# Epoch 120/120, Train Loss: 2.245692, Test Loss: 2.332911

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              #'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              #'scaler_day_smote' : scaler_day_smote,
              #'scaler_month_smote' : scaler_month_smote,
              #'scaler_decade_smote' : scaler_decade_smote,
              
              'alpha': alpha,
              #'alpha_smote': alpha_smote
              }



torch.save(checkpoint, 'checkpoint_half.pth.tar')

# %%
# r2_score(y.detach().numpy(), yHat.detach().numpy())
# type(r2_score(y.detach(), yHat.detach()))

# %%
# torch.mean( r2_score(y.detach().numpy(), yHat.detach().numpy()) ).item()

# %%
trainLoss1, testLoss1, trainAcc1
# Out:
# (tensor([2.7962, 2.4087, 2.3330, 2.3001, 2.2767, 2.2479, 2.2198, 2.2369, 2.2411,
#          2.2223, 2.2123, 2.2186, 2.2058, 2.2043, 2.2032, 2.2050, 2.1990, 2.1864,
#          2.1969, 2.1997, 2.1985, 2.1941, 2.1918, 2.1936, 2.1877, 2.1945, 2.1790,
#          2.1859, 2.1864, 2.1849, 2.1788, 2.1852, 2.1787, 2.1912, 2.1759, 2.1793,
#          2.1770, 2.1787, 2.1797, 2.1747, 2.1782, 2.1846, 2.1736, 2.1764, 2.1746,
#          2.1735, 2.1745, 2.1713, 2.1767, 2.1696, 2.1716, 2.1707, 2.1700, 2.1683,
#          2.1712, 2.1664, 2.1670, 2.1671, 2.1656, 2.1654, 2.1671, 2.1635, 2.1650,
#          2.1624, 2.1609, 2.1600, 2.1606, 2.1573, 2.1564, 2.1567, 2.1547, 2.1540,
#          2.1525, 2.1515, 2.1520, 2.1481, 2.1474, 2.1464, 2.1448, 2.1436, 2.1405,
#          2.1398, 2.1389, 2.1369, 2.1357, 2.1329, 2.1322, 2.1312, 2.1289, 2.1274,
#          2.1270, 2.1215, 2.1226, 2.1185, 2.1177, 2.1163, 2.1125, 2.1104, 2.1098,
#          2.1063, 2.1044, 2.1046, 2.1009, 2.0972, 2.0972, 2.0928, 2.0922, 2.0889,
#          2.0874, 2.0840, 2.0862, 2.0810, 2.0789, 2.0757, 2.0737, 2.0712, 2.0677,
#          2.0686, 2.0629, 2.0615]),
#  tensor([2.2836, 2.1138, 2.0529, 1.9872, 1.9992, 2.0598, 2.0170, 2.0128, 1.9891,
#          1.9739, 2.0166, 2.0081, 2.0246, 2.0099, 2.0051, 1.9929, 1.9877, 1.9963,
#          1.9807, 1.9808, 1.9565, 1.9595, 1.9471, 1.9500, 1.9296, 1.9300, 1.9381,
#          1.9337, 1.9778, 1.9277, 1.9390, 1.9439, 1.9477, 1.9458, 1.9438, 1.9622,
#          1.9310, 1.9437, 1.9548, 1.9587, 1.9455, 1.9790, 1.9627, 1.9585, 1.9481,
#          1.9553, 1.9470, 1.9422, 1.9465, 1.9561, 1.9650, 1.9788, 1.9486, 2.0025,
#          2.0098, 2.0038, 1.9881, 1.9702, 2.0242, 2.0370, 2.0204, 1.9880, 1.9766,
#          2.0031, 1.9780, 1.9748, 2.0334, 2.0353, 2.1014, 2.0576, 2.0877, 2.0431,
#          2.0223, 2.0597, 2.0232, 2.1057, 2.0524, 2.1334, 2.1003, 2.1524, 2.0693,
#          2.1648, 2.1685, 2.1319, 2.1529, 2.1466, 2.1183, 2.1180, 2.1370, 2.0292,
#          2.0391, 1.8980, 2.2308, 1.9581, 1.9735, 1.8256, 2.0467, 1.8150, 2.0122,
#          1.8410, 2.1028, 1.7765, 1.9821, 1.7812, 1.8767, 2.0528, 2.1601, 2.0826,
#          2.1472, 2.3361, 2.2677, 1.9029, 2.0639, 1.9789, 2.1850, 1.9981, 1.9356,
#          2.0201, 2.2364, 2.3329]),
#  tensor([0.4517, 0.5131, 0.5275, 0.5483, 0.5866, 0.5952, 0.5986, 0.5972, 0.5978,
#          0.6011, 0.6022, 0.6013, 0.6039, 0.6037, 0.6035, 0.6034, 0.6040, 0.6061,
#          0.6051, 0.6046, 0.6049, 0.6060, 0.6056, 0.6055, 0.6059, 0.6054, 0.6074,
#          0.6068, 0.6067, 0.6068, 0.6072, 0.6069, 0.6079, 0.6062, 0.6082, 0.6079,
#          0.6081, 0.6075, 0.6077, 0.6082, 0.6077, 0.6061, 0.6081, 0.6073, 0.6077,
#          0.6080, 0.6083, 0.6090, 0.6079, 0.6092, 0.6086, 0.6090, 0.6092, 0.6091,
#          0.6088, 0.6098, 0.6095, 0.6095, 0.6095, 0.6096, 0.6094, 0.6099, 0.6095,
#          0.6098, 0.6101, 0.6095, 0.6099, 0.6102, 0.6104, 0.6100, 0.6099, 0.6103,
#          0.6107, 0.6107, 0.6102, 0.6106, 0.6112, 0.6108, 0.6109, 0.6109, 0.6115,
#          0.6116, 0.6111, 0.6110, 0.6117, 0.6122, 0.6123, 0.6121, 0.6122, 0.6126,
#          0.6124, 0.6135, 0.6128, 0.6126, 0.6122, 0.6128, 0.6130, 0.6133, 0.6133,
#          0.6135, 0.6146, 0.6140, 0.6147, 0.6153, 0.6144, 0.6154, 0.6154, 0.6154,
#          0.6160, 0.6156, 0.6153, 0.6169, 0.6165, 0.6168, 0.6174, 0.6168, 0.6172,
#          0.6169, 0.6179, 0.6172]))

# %%
# batchLoss

# %%
# batchAcc

# %%
# yHat.shape, y.shape

# %%
# yHat_test.shape, yy.shape

# %%
yHat1.flatten(), y1.flatten()
# Out:
# (tensor([1.9415, 0.8581, 7.9466, 6.2628, 0.0000, 2.8079, 1.1682, 4.0434, 2.0002,
#          0.0000, 8.1285, 5.9202, 0.0000, 1.9159, 1.1059, 4.5850, 1.9780, 0.0000,
#          5.0716, 7.6078, 0.0000, 3.3376, 1.1638, 4.3474, 1.9521, 0.9138, 3.9136,
#          6.0595, 0.0000, 7.1776, 1.1632, 4.0384, 1.9730, 1.0997, 8.5797, 4.0864,
#          0.0000, 7.6425, 1.1712, 3.7797, 1.0077, 8.9773, 5.2568, 4.3288, 0.0000,
#          1.0780, 1.0786, 4.6228, 0.9645, 8.0070, 0.0000, 4.6690, 0.0000, 2.8975,
#          1.1432, 3.9957, 2.0387, 0.0000, 8.8600, 4.7047, 1.0352, 0.7901, 1.1346,
#          4.4584, 0.9993, 8.9500, 6.6461, 4.5221, 1.0274, 1.9417, 1.0906, 4.1791,
#          0.9998, 8.9949, 0.0000, 4.5329, 0.0000, 6.6847, 1.1185, 4.1348, 1.9366,
#          0.8783, 6.1632, 4.8435, 0.0000, 7.9214, 1.1363, 4.2209, 1.9264, 0.8819,
#          7.5798, 5.7600, 0.0000, 1.4498, 1.0609, 5.1388, 1.9961, 0.0000, 7.7648,
#          4.4272, 0.0000, 4.0418, 1.1602, 4.0684, 2.0439, 0.0000, 8.2883, 4.4454,
#          0.0000, 0.7709, 1.1424, 4.7960, 0.9989, 8.9909, 0.0000, 4.2400, 0.0000,
#          6.6648, 1.0511, 4.7691, 0.9420, 8.0275, 0.3273, 4.1361, 0.0000, 9.0239,
#          0.9750, 5.6824, 1.0076, 8.9996, 2.5877, 4.0904, 0.0000, 5.9717, 1.0428,
#          5.1573, 1.9676, 0.9417, 5.1243, 5.4264, 0.0000, 1.1841, 1.0890, 4.6562,
#          1.9627, 1.0362, 6.1178, 3.0086, 1.0103, 0.0000, 1.1930, 4.2580, 2.0046,
#          0.0000, 8.8861, 3.2007, 1.0440, 1.5729, 1.1137, 4.2814, 1.0013, 8.9609,
#          7.2091, 4.6394, 1.0022, 0.9298, 1.1319, 4.0558, 1.0021, 8.9714, 0.7633,
#          4.1738, 0.0000, 6.9564, 1.0373, 4.9827, 0.9385, 8.0146, 0.0000, 4.4333,
#          0.0000, 8.2705, 1.0449, 5.0898, 0.9657, 8.0164, 0.0000, 4.4011, 0.0000,
#          1.9934, 1.0366, 4.8349, 0.9439, 7.9970, 8.6997, 3.9467, 0.0000, 6.1213,
#          1.0161, 5.3441, 0.9530, 7.9947, 8.8907, 4.7349, 0.0000, 1.5369, 1.0829,
#          4.6262, 1.9049, 1.0056, 2.0282, 4.0220, 0.0000, 6.8160, 1.1514, 4.1903,
#          0.9999, 8.9674, 4.3884, 4.4810, 0.0000, 5.0256, 1.1578, 3.9571, 2.0174,
#          0.0000, 0.0000, 3.2898, 0.0000, 7.9416, 0.9518, 6.0313, 1.9841, 0.9498,
#          1.5569, 5.4533, 1.0513, 0.0000, 1.1545, 4.8398, 0.9404, 7.9451, 4.9085,
#          5.1372, 0.0000, 7.5569, 1.2070, 3.7094, 1.9619, 0.0000, 3.9503, 2.2461,
#          0.0000, 4.8600, 1.1457, 4.1875], grad_fn=<ReshapeAliasBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
yHat_test1, yy1
# Out:
# (tensor([[0.9581, 8.0220, 0.9992, 4.3207, 0.0000, 5.9517, 1.0767, 4.8314]]),
#  tensor([[1., 8., 1., 6., 0., 6., 0., 1.]]))

# %%
yy1
# Out:
# tensor([[1., 8., 1., 6., 0., 6., 0., 1.]])

# %%
(yHat_test1).round()
# Out:
# tensor([[1., 8., 1., 4., 0., 6., 1., 5.]])

# %%
(yHat1.flatten()).round(), (y1.flatten()).round()
# Out:
# (tensor([2., 1., 8., 6., 0., 3., 1., 4., 2., 0., 8., 6., 0., 2., 1., 5., 2., 0.,
#          5., 8., 0., 3., 1., 4., 2., 1., 4., 6., 0., 7., 1., 4., 2., 1., 9., 4.,
#          0., 8., 1., 4., 1., 9., 5., 4., 0., 1., 1., 5., 1., 8., 0., 5., 0., 3.,
#          1., 4., 2., 0., 9., 5., 1., 1., 1., 4., 1., 9., 7., 5., 1., 2., 1., 4.,
#          1., 9., 0., 5., 0., 7., 1., 4., 2., 1., 6., 5., 0., 8., 1., 4., 2., 1.,
#          8., 6., 0., 1., 1., 5., 2., 0., 8., 4., 0., 4., 1., 4., 2., 0., 8., 4.,
#          0., 1., 1., 5., 1., 9., 0., 4., 0., 7., 1., 5., 1., 8., 0., 4., 0., 9.,
#          1., 6., 1., 9., 3., 4., 0., 6., 1., 5., 2., 1., 5., 5., 0., 1., 1., 5.,
#          2., 1., 6., 3., 1., 0., 1., 4., 2., 0., 9., 3., 1., 2., 1., 4., 1., 9.,
#          7., 5., 1., 1., 1., 4., 1., 9., 1., 4., 0., 7., 1., 5., 1., 8., 0., 4.,
#          0., 8., 1., 5., 1., 8., 0., 4., 0., 2., 1., 5., 1., 8., 9., 4., 0., 6.,
#          1., 5., 1., 8., 9., 5., 0., 2., 1., 5., 2., 1., 2., 4., 0., 7., 1., 4.,
#          1., 9., 4., 4., 0., 5., 1., 4., 2., 0., 0., 3., 0., 8., 1., 6., 2., 1.,
#          2., 5., 1., 0., 1., 5., 1., 8., 5., 5., 0., 8., 1., 4., 2., 0., 4., 2.,
#          0., 5., 1., 4.], grad_fn=<RoundBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
print_score(X.shape, yHat1, y1, yHat_test1, yy1)
# Out:
# Adjusted R-Squared(y, yHat): 0.6234
#
#
# mean_absolute_error(y, yHat): 0.7648
#
# mean_absolute_error(yy, yHat_test): 0.8375
#
#
# mean_squared_error(y, yHat): 2.2457
#
# mean_squared_error(yy, yHat_test): 2.3329
#
#
# mean_squared_log_error(y, yHat): 0.1674
#
# mean_squared_log_error(yy, yHat_test): 0.2194
#
#
# RMSE(y, yHat): 1.4986
#
# RMSE(yy, yHat_test): 1.5274

# %%
# create a 1D smoothing filter
def smooth(x, k=15):
    return np.convolve(x, np.ones(k)/k, mode='same')

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Train loss')
ax[0].legend()



ax[1].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Test loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss1.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc1, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat1.detach().T, y1.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc1.jpg", bbox_inches='tight')


plt.show()

# %%
data.leap_year.value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
resampler = SMOTE(k_neighbors=20, random_state=0)

# %%
X_res, y_res = resampler.fit_resample(data[['day_code', 'month_code', 'decade', 'date_int']], data['leap_year'])

# %%
y_res.value_counts()
# Out:
# 0    110960
# 1    110960
# Name: leap_year, dtype: int64

# %%
data['leap_year'].value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 221915    1
# 221916    1
# 221917    1
# 221918    1
# 221919    1
# Name: leap_year, Length: 221920, dtype: int64

# %%
X_res
# Out:
#         day_code  month_code  decade  date_int
# 0              4           0     180  18000101
# 1              5           0     180  18010101
# 2              6           0     180  18020101
# 3              0           0     180  18030101
# 4              1           0     180  18040101
# ...          ...         ...     ...       ...
# 221915         0           5     188  18880618
# 221916         2           6     188  18840705
# 221917         5           2     218  21800323
# 221918         1           5     199  19960602
# 221919         1           4     219  21960520
#
# [221920 rows x 4 columns]

# %%
X_smote = X_res.assign(leap_year=y_res)

# %%
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221915         0           5     188  18880618          1
# 221916         2           6     188  18840705          1
# 221917         5           2     218  21800323          1
# 221918         1           5     199  19960602          1
# 221919         1           4     219  21960520          1
#
# [221920 rows x 5 columns]

# %% [markdown]
# Drop 220 decade

# %%
# data.decade.value_counts().plot(kind="bar")
X_smote.decade.value_counts().plot(kind="bar")

# %%
# data.decade.value_counts()[-5:]
X_smote.decade.value_counts()[-5:]
# Out:
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# 220     365
# Name: decade, dtype: int64

# %%
X_smote = X_smote.drop(X_smote.index[X_smote['decade'] == 220]).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221550         0           5     188  18880618          1
# 221551         2           6     188  18840705          1
# 221552         5           2     218  21800323          1
# 221553         1           5     199  19960602          1
# 221554         1           4     219  21960520          1
#
# [221555 rows x 5 columns]

# %%
X_smote.decade.value_counts().plot(kind="bar")

# %%
X_smote.decade.value_counts()[-5:]
# Out:
# 209    5174
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# Name: decade, dtype: int64

# %% [markdown]
# code is required to only work for dates in the range  [ 1-1-1800 to 31-12-2200 ]

# %%
X_smote.date_int.max()
# Out:
# 21991231

# %%
datetime.datetime.strptime(str(X_smote.date_int.max()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '31-12-2199'

# %%
X_smote.date_int.min()
# Out:
# 18000101

# %%
datetime.datetime.strptime(str(X_smote.date_int.min()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '01-01-1800'

# %%
Y_smote = X_smote['date_int']
Y_smote
# Out:
# 0         18000101
# 1         18010101
# 2         18020101
# 3         18030101
# 4         18040101
#             ...
# 221550    18880618
# 221551    18840705
# 221552    21800323
# 221553    19960602
# 221554    21960520
# Name: date_int, Length: 221555, dtype: int64

# %%
X_smote = X_smote.drop('date_int', axis=1).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  leap_year
# 0              4           0     180          0
# 1              5           0     180          0
# 2              6           0     180          0
# 3              0           0     180          0
# 4              1           0     180          1
# ...          ...         ...     ...        ...
# 221550         0           5     188          1
# 221551         2           6     188          1
# 221552         5           2     218          1
# 221553         1           5     199          1
# 221554         1           4     219          1
#
# [221555 rows x 4 columns]

# %%
Y_smote = Y_smote.reset_index(drop=True)

ls = []

for s in Y_smote.astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(Y_smote)), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y_smote = ll.values

Y_smote
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
# data.index[data['leap_year'] == 1].tolist()
# data.index[data['leap_year'] == 1]

# %%
# for i,idx in enumerate(data['leap_year'].tolist()):
#     print(i, idx)

# %% [markdown]
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1 <---
# 5 0
# 6 0
# 7 0
# 8 1 <---
# 9 0
# 10 0
# 11 0
# 12 1 <---
# 13 0
# 14 0
# 15 0
# 16 1 <---
# 17 0
# 18 0
# 19 0
# 20 1 <---
# 21 0
# 22 0
# 23 0
# 24 1 <---
# 25 0
# 26 0
# 27 0
# 28 1 <---
# 29 0
# 30 0

# %%
scaler_day_smote = RobustScaler()

x = X_smote.day_code.values.reshape(-1, 1)

X_smote['day_scaled'] = scaler_day_smote.fit_transform(x).flatten()

# %%
X_smote['day_sin'] = np.sin(X_smote['day_code'] * (2 * np.pi / 7))
X_smote['day_cos'] = np.cos(X_smote['day_code'] * (2 * np.pi / 7))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos
# 0      -0.900969
# 1      -0.222521
# 2       0.623490
# 3       1.000000
# 4       0.623490
# ...          ...
# 221550  1.000000
# 221551 -0.222521
# 221552 -0.222521
# 221553  0.623490
# 221554  0.623490
#
# [221555 rows x 7 columns]

# %%
scaler_month_smote = RobustScaler()

x = X_smote.month_code.values.reshape(-1, 1)

X_smote['month_scaled'] = scaler_month_smote.fit_transform(x).flatten()

# %%
X_smote['month_sin'] = np.sin(X_smote['month_code'] * (2 * np.pi / 12))
X_smote['month_cos'] = np.cos(X_smote['month_code'] * (2 * np.pi / 12))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos
# 0      -0.900969     -1.000000  0.000000e+00   1.000000
# 1      -0.222521     -1.000000  0.000000e+00   1.000000
# 2       0.623490     -1.000000  0.000000e+00   1.000000
# 3       1.000000     -1.000000  0.000000e+00   1.000000
# 4       0.623490     -1.000000  0.000000e+00   1.000000
# ...          ...           ...           ...        ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000
#
# [221555 rows x 10 columns]

# %%
scaler_decade_smote = RobustScaler()

x = X_smote.decade.values.reshape(-1, 1)

X_smote['decade_scaled'] = scaler_decade_smote.fit_transform(x).flatten()

# %%
# alpha_smote = len(X_smote.decade.unique())
alpha_smote = (X_smote.decade.iloc[-1] - X_smote.decade.iloc[0]) + 1

X_smote['decade_sin'] = np.sin(X_smote['decade'] * (2 * np.pi / alpha_smote))
X_smote['decade_cos'] = np.cos(X_smote['decade'] * (2 * np.pi / alpha_smote))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos  decade_scaled  \
# 0      -0.900969     -1.000000  0.000000e+00   1.000000      -1.052632
# 1      -0.222521     -1.000000  0.000000e+00   1.000000      -1.052632
# 2       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# 3       1.000000     -1.000000  0.000000e+00   1.000000      -1.052632
# 4       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# ...          ...           ...           ...        ...            ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025      -0.631579
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000      -0.631579
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000       0.947368
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025      -0.052632
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000       1.000000
#
#           decade_sin  decade_cos
# 0       1.102182e-15   -1.000000
# 1       1.102182e-15   -1.000000
# 2       1.102182e-15   -1.000000
# 3       1.102182e-15   -1.000000
# 4       1.102182e-15   -1.000000
# ...              ...         ...
# 221550 -9.510565e-01   -0.309017
# 221551 -9.510565e-01   -0.309017
# 221552  3.090170e-01   -0.951057
# 221553 -1.564345e-01    0.987688
# 221554  1.564345e-01   -0.987688
#
# [221555 rows x 13 columns]

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
X = X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 3.33333333e-01, -4.33883739e-01, -9.00968868e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 1.00000000e+00, -7.81831482e-01,  6.23489802e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        ...,
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#          9.47368421e-01,  3.09016994e-01, -9.51056516e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#         -5.26315789e-02, -1.56434465e-01,  9.87688341e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#          1.00000000e+00,  1.56434465e-01, -9.87688341e-01]])

# %%
X.shape
# Out:
# (221555, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()
# Y = data['date_normalized'].values.reshape(-1, 1)
Y = Y_smote


Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
Y.shape
# Out:
# (221555, 8)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64

train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (221555, 10)
#
# Y: (221555, 8)
#
# Train data:   (155088, 10)
#
# Train labels: (155088, 8)
#
# Test data:    (66467, 10)
#
# Test labels:  (66467, 8)

# %%
model_smote = Model().to(device)


# checkpoint = torch.load('checkpoint.pth.tar', map_location=torch.device('cpu'))
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])

# %%
numepochs = 120
# numepochs = 300
# numepochs = 500



trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model_smote, numepochs)
# Out:
# Epoch 1/120, Train Loss: 1.995427, Test Loss: 4.424641
# Epoch 2/120, Train Loss: 1.963583, Test Loss: 4.143343
# Epoch 3/120, Train Loss: 1.906710, Test Loss: 4.120914
# Epoch 4/120, Train Loss: 1.892833, Test Loss: 4.069780
# Epoch 5/120, Train Loss: 2.291105, Test Loss: 4.113356
# Epoch 6/120, Train Loss: 1.875629, Test Loss: 4.033902
# Epoch 7/120, Train Loss: 1.875660, Test Loss: 4.035581
# Epoch 8/120, Train Loss: 1.868377, Test Loss: 3.928389
# Epoch 9/120, Train Loss: 1.900240, Test Loss: 3.905266
# Epoch 10/120, Train Loss: 1.889242, Test Loss: 3.926502
# Epoch 11/120, Train Loss: 1.876867, Test Loss: 3.949828
# Epoch 12/120, Train Loss: 1.890712, Test Loss: 3.893947
# Epoch 13/120, Train Loss: 1.874999, Test Loss: 4.001898
# Epoch 14/120, Train Loss: 1.879093, Test Loss: 3.932482
# Epoch 15/120, Train Loss: 1.874154, Test Loss: 3.875666
# Epoch 16/120, Train Loss: 1.891102, Test Loss: 3.847079
# Epoch 17/120, Train Loss: 1.875852, Test Loss: 3.852035
# Epoch 18/120, Train Loss: 1.907288, Test Loss: 3.972026
# Epoch 19/120, Train Loss: 1.909746, Test Loss: 3.980076
# Epoch 20/120, Train Loss: 1.886236, Test Loss: 3.737036
# Epoch 21/120, Train Loss: 1.897834, Test Loss: 4.242141
# Epoch 22/120, Train Loss: 1.905672, Test Loss: 4.167511
# Epoch 23/120, Train Loss: 1.909184, Test Loss: 4.348037
# Epoch 24/120, Train Loss: 1.873165, Test Loss: 4.390982
# Epoch 25/120, Train Loss: 1.893722, Test Loss: 4.211610
# Epoch 26/120, Train Loss: 1.936563, Test Loss: 4.204038
# Epoch 27/120, Train Loss: 1.912127, Test Loss: 4.301781
# Epoch 28/120, Train Loss: 1.881465, Test Loss: 4.409282
# Epoch 29/120, Train Loss: 1.864675, Test Loss: 4.402135
# Epoch 30/120, Train Loss: 1.885122, Test Loss: 4.364417
# Epoch 31/120, Train Loss: 1.866892, Test Loss: 4.402090
# Epoch 32/120, Train Loss: 1.884753, Test Loss: 4.308409
# Epoch 33/120, Train Loss: 1.881070, Test Loss: 4.365818
# Epoch 34/120, Train Loss: 1.882499, Test Loss: 4.466315
# Epoch 35/120, Train Loss: 1.899341, Test Loss: 4.542608
# Epoch 36/120, Train Loss: 1.870526, Test Loss: 4.367707
# Epoch 37/120, Train Loss: 1.872904, Test Loss: 4.269026
# Epoch 38/120, Train Loss: 1.905869, Test Loss: 4.306300
# Epoch 39/120, Train Loss: 1.895862, Test Loss: 4.260710
# Epoch 40/120, Train Loss: 1.876838, Test Loss: 4.243571
# Epoch 41/120, Train Loss: 1.889428, Test Loss: 4.462853
# Epoch 42/120, Train Loss: 1.916975, Test Loss: 4.318635
# Epoch 43/120, Train Loss: 1.882938, Test Loss: 4.445674
# Epoch 44/120, Train Loss: 1.917472, Test Loss: 4.349773
# Epoch 45/120, Train Loss: 1.888552, Test Loss: 4.441023
# Epoch 46/120, Train Loss: 1.883270, Test Loss: 4.451784
# Epoch 47/120, Train Loss: 1.890928, Test Loss: 4.564314
# Epoch 48/120, Train Loss: 1.890072, Test Loss: 4.628469
# Epoch 49/120, Train Loss: 1.871177, Test Loss: 4.213252
# Epoch 50/120, Train Loss: 1.879791, Test Loss: 4.417977
# Epoch 51/120, Train Loss: 1.890502, Test Loss: 4.559718
# Epoch 52/120, Train Loss: 1.880137, Test Loss: 4.429865
# Epoch 53/120, Train Loss: 1.911061, Test Loss: 4.284218
# Epoch 54/120, Train Loss: 1.868134, Test Loss: 4.438363
# Epoch 55/120, Train Loss: 1.883360, Test Loss: 4.449076
# Epoch 56/120, Train Loss: 1.884282, Test Loss: 4.722739
# Epoch 57/120, Train Loss: 1.938520, Test Loss: 4.450720
# Epoch 58/120, Train Loss: 1.896856, Test Loss: 4.532622
# Epoch 59/120, Train Loss: 1.867693, Test Loss: 4.508163
# Epoch 60/120, Train Loss: 1.870824, Test Loss: 4.626464
# Epoch 61/120, Train Loss: 1.849269, Test Loss: 4.654782
# Epoch 62/120, Train Loss: 1.849504, Test Loss: 4.776233
# Epoch 63/120, Train Loss: 1.843954, Test Loss: 4.652912
# Epoch 64/120, Train Loss: 1.880039, Test Loss: 4.674595
# Epoch 65/120, Train Loss: 1.881721, Test Loss: 4.848890
# Epoch 66/120, Train Loss: 1.866714, Test Loss: 4.871019
# Epoch 67/120, Train Loss: 1.886790, Test Loss: 4.449563
# Epoch 68/120, Train Loss: 1.909609, Test Loss: 4.631892
# Epoch 69/120, Train Loss: 1.871682, Test Loss: 4.627685
# Epoch 70/120, Train Loss: 1.902575, Test Loss: 4.744343
# Epoch 71/120, Train Loss: 1.878360, Test Loss: 4.591190
# Epoch 72/120, Train Loss: 1.883852, Test Loss: 4.668923
# Epoch 73/120, Train Loss: 1.851838, Test Loss: 4.943533
# Epoch 74/120, Train Loss: 1.864267, Test Loss: 4.868384
# Epoch 75/120, Train Loss: 1.881808, Test Loss: 4.480975
# Epoch 76/120, Train Loss: 1.891425, Test Loss: 4.691367
# Epoch 77/120, Train Loss: 1.897824, Test Loss: 4.808228
# Epoch 78/120, Train Loss: 1.883601, Test Loss: 4.782403
# Epoch 79/120, Train Loss: 1.897108, Test Loss: 5.054070
# Epoch 80/120, Train Loss: 1.854517, Test Loss: 4.896114
# Epoch 81/120, Train Loss: 1.905321, Test Loss: 4.677416
# Epoch 82/120, Train Loss: 1.887931, Test Loss: 4.762593
# Epoch 83/120, Train Loss: 1.864111, Test Loss: 4.985957
# Epoch 84/120, Train Loss: 1.870069, Test Loss: 4.680434
# Epoch 85/120, Train Loss: 1.857103, Test Loss: 5.092120
# Epoch 86/120, Train Loss: 1.886622, Test Loss: 5.176617
# Epoch 87/120, Train Loss: 1.879433, Test Loss: 5.336073
# Epoch 88/120, Train Loss: 1.884780, Test Loss: 5.107572
# Epoch 89/120, Train Loss: 1.864506, Test Loss: 4.970794
# Epoch 90/120, Train Loss: 1.892818, Test Loss: 4.938591
# Epoch 91/120, Train Loss: 1.885332, Test Loss: 5.115381
# Epoch 92/120, Train Loss: 1.857578, Test Loss: 5.220735
# Epoch 93/120, Train Loss: 1.870379, Test Loss: 5.047231
# Epoch 94/120, Train Loss: 1.890498, Test Loss: 5.062382
# Epoch 95/120, Train Loss: 1.915175, Test Loss: 4.832723
# Epoch 96/120, Train Loss: 1.888478, Test Loss: 5.016226
# Epoch 97/120, Train Loss: 1.943236, Test Loss: 5.037418
# Epoch 98/120, Train Loss: 1.861165, Test Loss: 5.273562
# Epoch 99/120, Train Loss: 1.977362, Test Loss: 5.073981
# Epoch 100/120, Train Loss: 1.937900, Test Loss: 5.381717
# Epoch 101/120, Train Loss: 1.836452, Test Loss: 5.458182
# Epoch 102/120, Train Loss: 1.851962, Test Loss: 5.897765
# Epoch 103/120, Train Loss: 1.871342, Test Loss: 5.456419
# Epoch 104/120, Train Loss: 1.880458, Test Loss: 5.186228
# Epoch 105/120, Train Loss: 1.839123, Test Loss: 5.918742
# Epoch 106/120, Train Loss: 1.792995, Test Loss: 5.749903
# Epoch 107/120, Train Loss: 1.866508, Test Loss: 5.614927
# Epoch 108/120, Train Loss: 1.830194, Test Loss: 5.843792
# Epoch 109/120, Train Loss: 1.954257, Test Loss: 5.870994
# Epoch 110/120, Train Loss: 1.885259, Test Loss: 5.602676
# Epoch 111/120, Train Loss: 1.792994, Test Loss: 5.953429
# Epoch 112/120, Train Loss: 1.850547, Test Loss: 6.129241
# Epoch 113/120, Train Loss: 1.795571, Test Loss: 6.178620
# Epoch 114/120, Train Loss: 1.808898, Test Loss: 5.481145
# Epoch 115/120, Train Loss: 1.847344, Test Loss: 5.822903
# Epoch 116/120, Train Loss: 1.834809, Test Loss: 5.858102
# Epoch 117/120, Train Loss: 1.800019, Test Loss: 6.125783
# Epoch 118/120, Train Loss: 1.932296, Test Loss: 6.129912
# Epoch 119/120, Train Loss: 1.996506, Test Loss: 5.517944
# Epoch 120/120, Train Loss: 1.864785, Test Loss: 6.194355

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([2.5160, 2.2498, 2.2174, 2.1898, 2.1710, 2.1600, 2.1643, 2.1579, 2.1548,
#          2.1507, 2.1489, 2.1456, 2.1429, 2.1427, 2.1432, 2.1399, 2.1385, 2.1379,
#          2.1341, 2.1343, 2.1289, 2.1272, 2.1267, 2.1248, 2.1222, 2.1265, 2.1430,
#          2.1221, 2.1204, 2.1215, 2.1194, 2.1184, 2.1185, 2.1185, 2.1181, 2.1164,
#          2.1182, 2.1168, 2.1166, 2.1160, 2.1163, 2.1153, 2.1156, 2.1143, 2.1154,
#          2.1143, 2.1143, 2.1132, 2.1132, 2.1131, 2.1124, 2.1126, 2.1119, 2.1110,
#          2.1118, 2.1114, 2.1107, 2.1105, 2.1105, 2.1096, 2.1091, 2.1089, 2.1078,
#          2.1071, 2.1070, 2.1075, 2.1065, 2.1062, 2.1052, 2.1049, 2.1039, 2.1040,
#          2.1033, 2.1031, 2.1015, 2.1016, 2.1010, 2.0996, 2.0994, 2.0986, 2.0970,
#          2.0968, 2.0968, 2.0958, 2.0934, 2.0938, 2.0912, 2.0911, 2.0910, 2.0898,
#          2.0889, 2.0879, 2.0864, 2.0865, 2.0841, 2.0833, 2.0830, 2.0808, 2.0801,
#          2.0795, 2.0772, 2.0753, 2.0758, 2.0755, 2.0727, 2.0714, 2.0696, 2.0692,
#          2.0675, 2.0660, 2.0649, 2.0643, 2.0615, 2.0621, 2.0590, 2.0586, 2.0558,
#          2.0562, 2.0533, 2.0513]),
#  tensor([4.4246, 4.1433, 4.1209, 4.0698, 4.1134, 4.0339, 4.0356, 3.9284, 3.9053,
#          3.9265, 3.9498, 3.8939, 4.0019, 3.9325, 3.8757, 3.8471, 3.8520, 3.9720,
#          3.9801, 3.7370, 4.2421, 4.1675, 4.3480, 4.3910, 4.2116, 4.2040, 4.3018,
#          4.4093, 4.4021, 4.3644, 4.4021, 4.3084, 4.3658, 4.4663, 4.5426, 4.3677,
#          4.2690, 4.3063, 4.2607, 4.2436, 4.4629, 4.3186, 4.4457, 4.3498, 4.4410,
#          4.4518, 4.5643, 4.6285, 4.2133, 4.4180, 4.5597, 4.4299, 4.2842, 4.4384,
#          4.4491, 4.7227, 4.4507, 4.5326, 4.5082, 4.6265, 4.6548, 4.7762, 4.6529,
#          4.6746, 4.8489, 4.8710, 4.4496, 4.6319, 4.6277, 4.7443, 4.5912, 4.6689,
#          4.9435, 4.8684, 4.4810, 4.6914, 4.8082, 4.7824, 5.0541, 4.8961, 4.6774,
#          4.7626, 4.9860, 4.6804, 5.0921, 5.1766, 5.3361, 5.1076, 4.9708, 4.9386,
#          5.1154, 5.2207, 5.0472, 5.0624, 4.8327, 5.0162, 5.0374, 5.2736, 5.0740,
#          5.3817, 5.4582, 5.8978, 5.4564, 5.1862, 5.9187, 5.7499, 5.6149, 5.8438,
#          5.8710, 5.6027, 5.9534, 6.1292, 6.1786, 5.4811, 5.8229, 5.8581, 6.1258,
#          6.1299, 5.5179, 6.1944]),
#  tensor([0.4825, 0.5316, 0.5417, 0.5883, 0.5996, 0.6024, 0.6017, 0.6035, 0.6038,
#          0.6047, 0.6051, 0.6059, 0.6061, 0.6058, 0.6062, 0.6065, 0.6071, 0.6069,
#          0.6075, 0.6074, 0.6082, 0.6084, 0.6086, 0.6088, 0.6093, 0.6089, 0.6063,
#          0.6081, 0.6086, 0.6085, 0.6088, 0.6091, 0.6092, 0.6091, 0.6090, 0.6096,
#          0.6092, 0.6092, 0.6095, 0.6097, 0.6093, 0.6097, 0.6095, 0.6098, 0.6094,
#          0.6097, 0.6094, 0.6098, 0.6096, 0.6095, 0.6096, 0.6095, 0.6098, 0.6097,
#          0.6097, 0.6097, 0.6099, 0.6098, 0.6099, 0.6096, 0.6097, 0.6098, 0.6098,
#          0.6101, 0.6100, 0.6099, 0.6099, 0.6099, 0.6102, 0.6100, 0.6101, 0.6102,
#          0.6102, 0.6102, 0.6101, 0.6103, 0.6101, 0.6103, 0.6105, 0.6105, 0.6106,
#          0.6106, 0.6104, 0.6103, 0.6107, 0.6102, 0.6106, 0.6109, 0.6107, 0.6110,
#          0.6108, 0.6111, 0.6110, 0.6105, 0.6109, 0.6109, 0.6111, 0.6112, 0.6114,
#          0.6113, 0.6117, 0.6118, 0.6117, 0.6120, 0.6120, 0.6121, 0.6123, 0.6118,
#          0.6124, 0.6121, 0.6124, 0.6128, 0.6129, 0.6126, 0.6129, 0.6131, 0.6131,
#          0.6133, 0.6134, 0.6138]))

# %%
# (yy * data['date_int'].max()).round()

# %%
# (yHat_test * data['date_int'].max()).round()

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.6031
#
#
# mean_absolute_error(y, yHat): 0.7075
#
# mean_absolute_error(yy, yHat_test): 1.3374
#
#
# mean_squared_error(y, yHat): 1.8648
#
# mean_squared_error(yy, yHat_test): 6.1944
#
#
# mean_squared_log_error(y, yHat): 0.1004
#
# mean_squared_log_error(yy, yHat_test): 0.5249
#
#
# RMSE(y, yHat): 1.3656
#
# RMSE(yy, yHat_test): 2.4888

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Train loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Test loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss2.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.detach().T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc2.jpg", bbox_inches='tight')


plt.show()

# %%
['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']
# Out:
# ['day_scaled',
#  'day_sin',
#  'day_cos',
#  'month_scaled',
#  'month_sin',
#  'month_cos',
#  'leap_year',
#  'decade_scaled',
#  'decade_sin',
#  'decade_cos']

# %%
def result_to_date(result):
    
    result = str(result)
    
    day   = int(result[6:]) - 1
    month = int(result[4:6]) - 1

    ss = str(f'{result[:4]}0101')
    
    ds = datetime.datetime.strptime(ss, '%Y%m%d')
    
    ds = ds + relativedelta(months=month, days=day)

    result = ds.strftime('%d-%m-%Y')
    
    
    return result

# %%
# (16830739, 17848869)
result_to_date(16830739), result_to_date(17848869)
# Out:
# ('08-08-1683', '08-06-1791')

# %%
def test_model(input_list):
    

    X       = np.zeros((1, 10))
    X_smote = np.zeros((1, 10))



    day       = np.array(map_day[input_list[0]])
    month     = np.array(map_month[input_list[1]])
    leap_year = map_leap_year[input_list[2]]
    decade    = np.array(input_list[3].strip('[]')).astype('int64')


    X[0, 0] = scaler_day.transform(day.reshape(-1, 1)).flatten()
    X[0, 1] = np.sin(day * (2 * np.pi / 7))
    X[0, 2] = np.cos(day * (2 * np.pi / 7))

    X[0, 3] = scaler_month.transform(month.reshape(-1, 1)).flatten()
    X[0, 4] = np.sin(month * (2 * np.pi / 12))
    X[0, 5] = np.cos(month * (2 * np.pi / 12))

    X[0, 6] = leap_year

    X[0, 7] = scaler_decade.transform(decade.reshape(-1, 1)).flatten()
    X[0, 8] = np.sin(decade * (2 * np.pi / alpha))
    X[0, 9] = np.cos(decade * (2 * np.pi / alpha))

    # ---

    X_smote[0, 0] = scaler_day_smote.transform(day.reshape(-1, 1)).flatten()
    X_smote[0, 1] = X[0, 1]
    X_smote[0, 2] = X[0, 2]

    X_smote[0, 3] = scaler_month_smote.transform(month.reshape(-1, 1)).flatten()
    X_smote[0, 4] = X[0, 4]
    X_smote[0, 5] = X[0, 5]

    X_smote[0, 6] = leap_year

    X_smote[0, 7] = scaler_decade_smote.transform(decade.reshape(-1, 1)).flatten()
    X_smote[0, 8] = np.sin(decade * (2 * np.pi / alpha_smote))
    X_smote[0, 9] = np.cos(decade * (2 * np.pi / alpha_smote))



    flag = [model.training, model_smote.training]

    # ---

    model.eval()
    model_smote.eval()


    result       = model(torch.tensor(X).to(device).float())
    result_smote = model_smote(torch.tensor(X_smote).to(device).float())



    # if all(flag):
    #   model.train()
    #   model_smote.train()


    if flag[0]:
      model.train()

    if flag[1]:
      model_smote.train()


    # ---


    result       = ''.join(result.detach().cpu().numpy().round().astype(int).astype(str).flatten())
    result_smote = ''.join(result_smote.detach().cpu().numpy().round().astype(int).astype(str).flatten())

    
    
    return result_to_date(result), result_to_date(result_smote)

# %%
input_test1 = ['[MON]', '[DEC]', '[False]', '[196]']
output_test1 = '3-12-1962'

input_test2 = ['[THU]', '[DEC]', '[True]', '[204]']
output_test2 = '3-12-2048'

input_test3 = ['[WED]', '[JAN]', '[False]', '[181]']
output_test3 = '10-1-1810'


input_test4 = ['[WED]', '[JUN]', '[False]', '[209]']

# %%
test_model(input_test1), test_model(input_test2), test_model(input_test3), test_model(input_test4)
# Out:
# (('14-12-1965', '15-12-1964'),
#  ('14-12-2046', '15-12-2044'),
#  ('14-01-1814', '15-01-1815'),
#  ('15-06-2095', '15-06-2095'))

# %%
output_test1, output_test2, output_test3
# Out:
# ('3-12-1962', '3-12-2048', '10-1-1810')

# %%
# example_input = pd.read_csv('./data/example_input.txt', sep=' ', header=None)
example_input = pd.read_csv('example_input.txt', sep=' ', header=None)


example_input.columns = ['day', 'month', 'leap_year', 'decade']

# %%
example_input
# Out:
#         day  month leap_year decade
# 0     [WED]  [JAN]   [False]  [180]
# 1     [MON]  [JAN]   [False]  [190]
# 2     [SAT]  [JAN]    [True]  [200]
# 3     [FRI]  [JAN]   [False]  [210]
# 4     [WED]  [JAN]   [False]  [220]
# ...     ...    ...       ...    ...
# 1460  [MON]  [OCT]    [True]  [214]
# 1461  [TUE]  [DEC]   [False]  [183]
# 1462  [SUN]  [DEC]   [False]  [193]
# 1463  [SAT]  [DEC]   [False]  [203]
# 1464  [THU]  [DEC]   [False]  [213]
#
# [1465 rows x 4 columns]

# %%
R       = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result'])
R_smote = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result_smote'])

# %%
example_input.iloc[0].tolist()
# Out:
# ['[WED]', '[JAN]', '[False]', '[180]']

# %%
for i in range(len(example_input)):
    R.iloc[i], R_smote.iloc[i] = test_model(example_input.iloc[i].tolist())

# %%
R
# Out:
#           result
# 0     15-01-1804
# 1     15-01-1904
# 2     15-01-2004
# 3     15-01-2103
# 4     17-12-1499
# ...          ...
# 1460  14-10-2145
# 1461  14-12-1835
# 1462  14-12-1935
# 1463  14-12-2036
# 1464  14-12-2135
#
# [1465 rows x 1 columns]

# %%
final = pd.concat([example_input, R], axis=1)
final
# Out:
#         day  month leap_year decade      result
# 0     [WED]  [JAN]   [False]  [180]  15-01-1804
# 1     [MON]  [JAN]   [False]  [190]  15-01-1904
# 2     [SAT]  [JAN]    [True]  [200]  15-01-2004
# 3     [FRI]  [JAN]   [False]  [210]  15-01-2103
# 4     [WED]  [JAN]   [False]  [220]  17-12-1499
# ...     ...    ...       ...    ...         ...
# 1460  [MON]  [OCT]    [True]  [214]  14-10-2145
# 1461  [TUE]  [DEC]   [False]  [183]  14-12-1835
# 1462  [SUN]  [DEC]   [False]  [193]  14-12-1935
# 1463  [SAT]  [DEC]   [False]  [203]  14-12-2036
# 1464  [THU]  [DEC]   [False]  [213]  14-12-2135
#
# [1465 rows x 5 columns]

# %%
final_smote = pd.concat([example_input, R_smote], axis=1)
final_smote
# Out:
#         day  month leap_year decade result_smote
# 0     [WED]  [JAN]   [False]  [180]   15-01-1804
# 1     [MON]  [JAN]   [False]  [190]   15-01-1904
# 2     [SAT]  [JAN]    [True]  [200]   15-01-2004
# 3     [FRI]  [JAN]   [False]  [210]   15-01-2105
# 4     [WED]  [JAN]   [False]  [220]   14-01-2195
# ...     ...    ...       ...    ...          ...
# 1460  [MON]  [OCT]    [True]  [214]   15-10-2144
# 1461  [TUE]  [DEC]   [False]  [183]   14-12-1834
# 1462  [SUN]  [DEC]   [False]  [193]   15-12-1935
# 1463  [SAT]  [DEC]   [False]  [203]   14-12-2034
# 1464  [THU]  [DEC]   [False]  [213]   14-12-2135
#
# [1465 rows x 5 columns]

# %%
final.to_csv('output_file.txt', sep=' ', header=None, index=False)

# %%
final_smote.to_csv('output_file_smote.txt', sep=' ', header=None, index=False)

# %% [markdown]
# Out-liers

# %% [markdown]
# Saving

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              'scaler_day_smote' : scaler_day_smote,
              'scaler_month_smote' : scaler_month_smote,
              'scaler_decade_smote' : scaler_decade_smote,
              
              'alpha': alpha,
              'alpha_smote': alpha_smote}



torch.save(checkpoint, 'checkpoint.pth.tar')

# %%
# checkpoint = torch.load('checkpoint.pth.tar')

# %%
# model       = Model()
# model_smote = Model()


# model.load_state_dict(checkpoint['model_state_dict'])
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
