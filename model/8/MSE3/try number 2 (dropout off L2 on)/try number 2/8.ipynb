# %%
import datetime

import copy

import random


from dateutil.relativedelta import relativedelta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('seaborn')
# plt.style.use(['dark_background', 'ggplot'])

import seaborn as sns
# sns.set()

# import scipy
# import scipy.stats as stats


# # sympy = symbolic math in Python
# import sympy as sym
# import sympy.plotting.plot as symplot


# make the equations look nicer

# from IPython.display import display
# display.set_matplotlib_formats('svg') # Deprecated since version 7.23

# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


# %config InlineBackend.set_matplotlib_formats = ["svg"]
# %config InlineBackend.figure_formats = ["svg"]

# %%
import sklearn


from sklearn.model_selection import train_test_split


# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler     # <------------ (-1.0, 1.0)
# from sklearn.preprocessing import MinMaxScaler


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from imblearn.over_sampling import SMOTE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset, DataLoader





torch.__version__
# Out:
# '1.12.1+cu113'

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def print_score(shape, yHat, y, yHat_test, yy):
    
    
    n, p = shape
    
    R2 = r2_score(y.detach().numpy(), yHat.detach().numpy())
    
    Adj_r2 = 1 - (1 - R2)  *  (n - 1) / (n - p - 1)
    
    print(f'Adjusted R-Squared(y, yHat): {Adj_r2:0.4f}\n\n')
    # r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
    #  R^2 score is not well-defined with less than two samples
    
    
    print(f'mean_absolute_error(y, yHat):',
          f'{mean_absolute_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_absolute_error(yy, yHat_test):',
          f'{mean_absolute_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_error(y, yHat):',
          f'{mean_squared_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_error(yy, yHat_test):',
          f'{mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_log_error(y, yHat):',
          f'{mean_squared_log_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_log_error(yy, yHat_test):',
          f'{mean_squared_log_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    
    print(f'RMSE(y, yHat):',
          f'{np.sqrt( mean_squared_error(y.detach().numpy(), yHat.detach().numpy()) ):0.4f}\n')
    print(f'RMSE(yy, yHat_test):',
          f'{np.sqrt( mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()) ):0.4f}\n\n')

# %%
# date = np.datetime64("2000-01-01")
# date_strings = date.astype(str).split('-'). 
# # >> ['2000', '01', '01']

# year_int = int(date_strings[0])

# %%
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Out:
# --2022-08-15 12:01:30--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5230713 (5.0M) [text/plain]
# Saving to: ‘data.txt’
#
# data.txt            100%[===================>]   4.99M  --.-KB/s    in 0.08s
#
# 2022-08-15 12:01:31 (61.5 MB/s) - ‘data.txt’ saved [5230713/5230713]
#
# --2022-08-15 12:01:31--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37732 (37K) [text/plain]
# Saving to: ‘example_input.txt’
#
# example_input.txt   100%[===================>]  36.85K  --.-KB/s    in 0.004s
#
# 2022-08-15 12:01:31 (9.88 MB/s) - ‘example_input.txt’ saved [37732/37732]

# %%
# !ls
# Out:
# data.txt  example_input.txt  sample_data

# %% [markdown]
# 'text.txt'

# %% [markdown]
# [ 1-1-1800 to 31-12-2200 ]

# %% [markdown]
# [day condition] [month condition] [leap year condition] [decade condition] date

# %% [markdown]
# [MON] [DEC] [False] [196] 3-12-1962
# [THU] [DEC] [True] [204] 3-12-2048
# [WED] [JAN] [False] [181] 10-1-1810

# %%
# data = np.loadtxt(open('text.txt','r'),delimiter=' ')
# ori = pd.read_csv('./data/data.txt', sep=' ', header=None)

ori = pd.read_csv('data.txt', sep=' ', header=None)

# %%
ori.columns = ['day', 'month', 'leap_year', 'decade', 'date']

# %%
ori
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
# data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)
# # pd.to_datetime(data.date, infer_datetime_format=False)

# %%
ori.dtypes
# Out:
# day          object
# month        object
# leap_year    object
# decade       object
# date         object
# dtype: object

# %%
# data_backup = copy.deepcopy(ori)
data = copy.deepcopy(ori)

# %%
data
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
data.date
# Out:
# 0           1-1-1800
# 1           1-1-1801
# 2           1-1-1802
# 3           1-1-1803
# 4           1-1-1804
#              ...
# 146457    31-12-2196
# 146458    31-12-2197
# 146459    31-12-2198
# 146460    31-12-2199
# 146461    31-12-2200
# Name: date, Length: 146462, dtype: object

# %%
# # data['date'] = pd.date_range('3-12-2048', periods=10)
# # data['date'] = pd.date_range('12-3-1962', periods=10)

# # 1-1-1800 to 31-12-2200
# data['date'] = pd.date_range(start='1-1-1800',end='12-31-2200')


data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)

# # data.date = data.date.dt.strftime('%d-%m-%Y')
# # data.date = pd.to_datetime(data.date.dt.strftime('%d-%m-%Y'), format='%d-%m-%Y', infer_datetime_format=False)

# %%
data.dtypes
# Out:
# day                  object
# month                object
# leap_year            object
# decade               object
# date         datetime64[ns]
# dtype: object

# %%
data
# Out:
#           day  month leap_year decade       date
# 0       [WED]  [JAN]   [False]  [180] 1800-01-01
# 1       [THU]  [JAN]   [False]  [180] 1801-01-01
# 2       [FRI]  [JAN]   [False]  [180] 1802-01-01
# 3       [SAT]  [JAN]   [False]  [180] 1803-01-01
# 4       [SUN]  [JAN]    [True]  [180] 1804-01-01
# ...       ...    ...       ...    ...        ...
# 146457  [SAT]  [DEC]    [True]  [219] 2196-12-31
# 146458  [SUN]  [DEC]   [False]  [219] 2197-12-31
# 146459  [MON]  [DEC]   [False]  [219] 2198-12-31
# 146460  [TUE]  [DEC]   [False]  [219] 2199-12-31
# 146461  [WED]  [DEC]   [False]  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %%
map_leap_year = {'[False]': int(0), '[True]' : int(1)}

data.leap_year = data.leap_year.map(map_leap_year)

# data.leap_year = data.leap_year.astype(np.float64)

# %%
data
# Out:
#           day  month  leap_year decade       date
# 0       [WED]  [JAN]          0  [180] 1800-01-01
# 1       [THU]  [JAN]          0  [180] 1801-01-01
# 2       [FRI]  [JAN]          0  [180] 1802-01-01
# 3       [SAT]  [JAN]          0  [180] 1803-01-01
# 4       [SUN]  [JAN]          1  [180] 1804-01-01
# ...       ...    ...        ...    ...        ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31
# 146459  [MON]  [DEC]          0  [219] 2198-12-31
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31
# 146461  [WED]  [DEC]          0  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %% [markdown]
# date -> timestamp

# %%
data.date.iloc[0]
# Out:
# Timestamp('1800-01-01 00:00:00')

# %%
data['date_int'] = data['date'].dt.strftime("%Y%m%d").astype(np.int64)

# data['date_str'] = data['date'].dt.strftime("%Y%m%d")

# %%
# data['date_int'].map(str)
# data['date_int'].astype(str)

# %%
# date_max = data.date_int.max()
# data['date_normalized'] = data.date_int / date_max

# %%
data
# Out:
#           day  month  leap_year decade       date  date_int
# 0       [WED]  [JAN]          0  [180] 1800-01-01  18000101
# 1       [THU]  [JAN]          0  [180] 1801-01-01  18010101
# 2       [FRI]  [JAN]          0  [180] 1802-01-01  18020101
# 3       [SAT]  [JAN]          0  [180] 1803-01-01  18030101
# 4       [SUN]  [JAN]          1  [180] 1804-01-01  18040101
# ...       ...    ...        ...    ...        ...       ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31  21961231
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31  21971231
# 146459  [MON]  [DEC]          0  [219] 2198-12-31  21981231
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31  21991231
# 146461  [WED]  [DEC]          0  [220] 2200-12-31  22001231
#
# [146462 rows x 6 columns]

# %%
x = data.decade.iloc[0]
x
# Out:
# '[180]'

# %%
x.strip('[]')
# Out:
# '180'

# %%
data.decade = data.decade.apply(lambda x: x.strip('[]')).astype('int64')

# %%
# data.day = data.day.apply(lambda x: x.strip('[]'))
# data.month = data.month.apply(lambda x: x.strip('[]'))

# %%
map_day = {'[SAT]': int(0),
           '[SUN]': int(1),
           '[MON]': int(2),
           '[TUE]': int(3),
           '[WED]': int(4),
           '[THU]': int(5),
           '[FRI]': int(6)}

# %%
data['day_code'] = data.day.map(map_day)

# %%
scaler_day = RobustScaler()

x = data.day_code.values.reshape(-1, 1)

data['day_scaled'] = scaler_day.fit_transform(x).flatten()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled
# 0             0.25
# 1             0.50
# 2             0.75
# 3            -0.75
# 4            -0.50
# ...            ...
# 146457       -0.75
# 146458       -0.50
# 146459       -0.25
# 146460        0.00
# 146461        0.25
#
# [146462 rows x 8 columns]

# %%
data['day_sin'] = np.sin(data['day_code'] * (2 * np.pi / 7))
data['day_cos'] = np.cos(data['day_code'] * (2 * np.pi / 7))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos
# 0             0.25 -0.433884 -0.900969
# 1             0.50 -0.974928 -0.222521
# 2             0.75 -0.781831  0.623490
# 3            -0.75  0.000000  1.000000
# 4            -0.50  0.781831  0.623490
# ...            ...       ...       ...
# 146457       -0.75  0.000000  1.000000
# 146458       -0.50  0.781831  0.623490
# 146459       -0.25  0.974928 -0.222521
# 146460        0.00  0.433884 -0.900969
# 146461        0.25 -0.433884 -0.900969
#
# [146462 rows x 10 columns]

# %%
map_month = {'[JAN]': int(0),
             '[FEB]': int(1),
             '[MAR]': int(2),
             '[APR]': int(3),
             '[MAY]': int(4),
             '[JUN]': int(5),
             '[JUL]': int(6),
             '[AUG]': int(7),
             '[SEP]': int(8),
             '[OCT]': int(9),
             '[NOV]': int(10),
             '[DEC]': int(11)}

# %%
data['month_code'] = data.month.map(map_month)

# %%
scaler_month = RobustScaler()

x = data.month_code.values.reshape(-1, 1)

data['month_scaled'] = scaler_month.fit_transform(x).flatten()

# %%
data['month_sin'] = np.sin(data['month_code'] * (2 * np.pi / 12))
data['month_cos'] = np.cos(data['month_code'] * (2 * np.pi / 12))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ...           ...
# 146457   0.866025
# 146458   0.866025
# 146459   0.866025
# 146460   0.866025
# 146461   0.866025
#
# [146462 rows x 14 columns]

# %%
scaler_decade = RobustScaler()

x = data.decade.values.reshape(-1, 1)

data['decade_scaled'] = scaler_decade.fit_transform(x).flatten()

# %%
# alpha = len(data.decade.unique())
alpha = (data.decade.iloc[-1] - data.decade.iloc[0]) + 1

data['decade_sin'] = np.sin(data['decade'] * (2 * np.pi / alpha))
data['decade_cos'] = np.cos(data['decade'] * (2 * np.pi / alpha))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %%
# data.date_normalized.min(), data.date_normalized.max()

# %%
# round(data.date_normalized.min()), round(data.date_normalized.max())

# %%
round(data.day_scaled.min()), round(data.day_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_sin.min()), round(data.day_sin.max())
# Out:
# (-1, 1)

# %%
round(data.day_cos.min()), round(data.day_cos.max())
# Out:
# (-1, 1)

# %%
round(data.month_scaled.min()), round(data.month_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.month_sin.min()), round(data.month_sin.max())
# Out:
# (-1, 1)

# %%
round(data.month_cos.min()), round(data.month_cos.max())
# Out:
# (-1, 1)

# %%
data.leap_year.min(), data.leap_year.max()
# Out:
# (0, 1)

# %%
round(data.decade_scaled.min()), round(data.decade_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.decade_sin.min()), round(data.decade_sin.max())
# Out:
# (-1, 1)

# %%
round(data.decade_cos.min()), round(data.decade_cos.max())
# Out:
# (-1, 1)

# %% [markdown]
# Boxplot

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.day.value_counts().plot(kind="bar")

# %%
data.month.value_counts().plot(kind="bar")

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
data.decade.value_counts().plot(kind="bar")

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %% [markdown]
# ['day_sin', 'day_cos', 'month_sin', 'month_cos', 'leap_year', 'decade_scaled']
# ['date_timestamp_scaled']

# %%
X = data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
          'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 0.25      , -0.43388374, -0.90096887, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.5       , -0.97492791, -0.22252093, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.75      , -0.78183148,  0.6234898 , ..., -1.        ,
#          0.63624244, -0.77148918],
#        ...,
#        [-0.25      ,  0.97492791, -0.22252093, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.        ,  0.43388374, -0.90096887, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.25      , -0.43388374, -0.90096887, ...,  1.        ,
#          0.74655322, -0.6653257 ]])

# %%
len(X)
# Out:
# 146462

# %%
X.shape
# Out:
# (146462, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()


ls = []

for s in data['date_int'].astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(data['date_int'])), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y = ll.values

Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 2, 0, ..., 2, 3, 1]])

# %%
len(Y)
# Out:
# 146462

# %%
Y.shape
# Out:
# (146462, 8)

# %%
# # leap = np.where(~X['leap_year'] == 1)[0]
# leap = np.where(X['leap_year'] == 1)[0]

# leap

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64


train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (146462, 10)
#
# Y: (146462, 8)
#
# Train data:   (102523, 10)
#
# Train labels: (102523, 8)
#
# Test data:    (43939, 10)
#
# Test labels:  (43939, 8)

# %%
102523 % 32, 102523 % 64
# Out:
# (27, 59)

# %%
class Model(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.input = nn.Linear(10, 32)

        self.fc1 = nn.Linear(32, 128)
        self.bnorm1 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 512)
        self.bnorm2 = nn.BatchNorm1d(512)

        self.fc3 = nn.Linear(512, 64)
        self.bnorm3 = nn.BatchNorm1d(64)

        self.fc4 = nn.Linear(64, 32)
        self.bnorm4 = nn.BatchNorm1d(32)


        self.output = nn.Linear(32, 8)



    def forward(self, x):


        # print(f'training={self.training}')

        x = F.relu( self.input(x) )

        x = F.relu(self.bnorm1(self.fc1(x)))
        # x = F.dropout(x, p=0.25, training=self.training)

        x = F.relu(self.bnorm2(self.fc2(x)))
        # x = F.dropout(x, p=0.4, training=self.training)

        x = F.relu(self.bnorm3(self.fc3(x)))
        # x = F.dropout(x, p=0.1, training=self.training)

        x = F.relu(self.bnorm4(self.fc4(x)))
        # x = F.dropout(x, p=0.05, training=self.training)


        x = F.relu(self.output(x))
        # x = self.output(x)
        


        return x

# %%
# test_x, test_y = next(iter(train_loader))

# print(f'test_x: {test_x.shape}\n')
# print(f'test_y: {test_y.shape}\n')

# %%
def train(model, numepochs):

    numepochs = numepochs

    model = model
    
    
    
    lossfun = nn.MSELoss()
    # lossfun = nn.L1Loss()


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0002, betas=(0.5, 0.999), weight_decay=1e-5)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.5, 0.999), weight_decay=1e-1)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=1e-3)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=1e-9)


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
    
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    
    
    
    trainLoss = torch.zeros(numepochs)
    testLoss  = torch.zeros(numepochs)
    trainAcc  = torch.zeros(numepochs)
    # testAcc   = torch.zeros(numepochs)


    for epochi in range(numepochs):

        model.train() # switch to train mode

        batchLoss = []
        batchAcc  = []

        for X,y in train_loader:

            X = X.to(device)
            y = y.to(device)

            yHat = model(X)
            loss = lossfun(yHat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())
            # batchAcc.append( torch.mean(( yHat == y).float() ).item() )
            # batchAcc.append( torch.mean( (torch.abs(yHat - y) < 1).float() ).item() ) # <1 for rounding
            batchAcc.append( r2_score(y.detach().cpu().numpy(), yHat.detach().cpu().numpy()) )
            




        trainLoss[epochi] = np.mean(batchLoss)
        # trainAcc[epochi]  = 100*np.mean(batchAcc)
        trainAcc[epochi]  = np.mean(batchAcc)
        



        model.eval() # switch to test mode

        XX,yy = next(iter(test_loader))

        XX = XX.to(device)
        yy = yy.to(device)

        # forward pass and loss
        with torch.no_grad():
            yHat_test = model(XX)
            loss_test = lossfun(yHat_test, yy)


        testLoss[epochi] = loss_test.item()
        # testAcc[epochi]  = 100*torch.mean( (yHat_test == yy).float() ).item()
        # testAcc[epochi]  = 100*torch.mean( (torch.abs(yHat_test - yy) < 1).float() ).item()
        # testAcc[epochi]  = 100*r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
        


        # if (epochi + 1) % 5 == 0:
        print(f'Epoch {epochi+1}/{numepochs}, Train Loss: {loss.item():0.6f}, Test Loss: {loss_test.item():0.6f}')


        
    return trainLoss.cpu(), testLoss.cpu(), trainAcc.cpu(), yHat.cpu(), y.cpu(), yHat_test.cpu(), yy.cpu()

# %%
model = Model().to(device)

# test_hat = model(torch.randn(32,6))
# test_hat = model(test_x)

# print(test_hat.shape)


checkpoint = torch.load('checkpoint.pth.tar', map_location=torch.device('cpu'))
# checkpoint = torch.load('checkpoint_half.pth.tar', map_location=torch.device('cpu'))

model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
# for p in list(model.named_parameters()):
#     if 'weight' in p[0] and 'bnorm' not in p[0]:
#         nn.init.xavier_normal_(p[1].data)
#         print(p[0])
#         print(p[1].data.shape)

# %%
# numepochs = 120
numepochs = 300


trainLoss1, testLoss1, trainAcc1, yHat1, y1, yHat_test1, yy1 = train(model, numepochs)
# Out:
# Epoch 1/300, Train Loss: 2.371483, Test Loss: 2.110981
# Epoch 2/300, Train Loss: 2.414873, Test Loss: 2.308448
# Epoch 3/300, Train Loss: 2.393262, Test Loss: 2.237902
# Epoch 4/300, Train Loss: 2.410958, Test Loss: 2.250879
# Epoch 5/300, Train Loss: 2.386981, Test Loss: 2.089281
# Epoch 6/300, Train Loss: 2.378144, Test Loss: 2.122737
# Epoch 7/300, Train Loss: 2.421437, Test Loss: 2.077718
# Epoch 8/300, Train Loss: 2.401868, Test Loss: 2.311727
# Epoch 9/300, Train Loss: 2.380319, Test Loss: 2.155493
# Epoch 10/300, Train Loss: 2.417398, Test Loss: 2.078417
# Epoch 11/300, Train Loss: 2.374336, Test Loss: 2.064965
# Epoch 12/300, Train Loss: 2.399503, Test Loss: 2.179276
# Epoch 13/300, Train Loss: 2.375166, Test Loss: 2.119890
# Epoch 14/300, Train Loss: 2.376148, Test Loss: 2.107021
# Epoch 15/300, Train Loss: 2.393877, Test Loss: 2.087719
# Epoch 16/300, Train Loss: 2.357584, Test Loss: 2.049622
# Epoch 17/300, Train Loss: 2.398553, Test Loss: 2.095428
# Epoch 18/300, Train Loss: 2.396058, Test Loss: 2.128583
# Epoch 19/300, Train Loss: 2.410858, Test Loss: 2.414152
# Epoch 20/300, Train Loss: 2.571109, Test Loss: 2.265777
# Epoch 21/300, Train Loss: 2.381090, Test Loss: 2.162996
# Epoch 22/300, Train Loss: 2.392002, Test Loss: 2.157391
# Epoch 23/300, Train Loss: 2.382193, Test Loss: 2.342806
# Epoch 24/300, Train Loss: 2.389832, Test Loss: 2.180027
# Epoch 25/300, Train Loss: 2.396257, Test Loss: 2.177546
# Epoch 26/300, Train Loss: 3.008336, Test Loss: 2.145736
# Epoch 27/300, Train Loss: 2.390210, Test Loss: 2.118186
# Epoch 28/300, Train Loss: 2.404099, Test Loss: 2.130451
# Epoch 29/300, Train Loss: 2.372518, Test Loss: 2.090069
# Epoch 30/300, Train Loss: 2.380423, Test Loss: 2.127466
# Epoch 31/300, Train Loss: 2.439337, Test Loss: 2.537070
# Epoch 32/300, Train Loss: 2.454275, Test Loss: 2.149758
# Epoch 33/300, Train Loss: 2.397086, Test Loss: 2.210957
# Epoch 34/300, Train Loss: 2.565813, Test Loss: 2.236405
# Epoch 35/300, Train Loss: 2.386164, Test Loss: 2.072335
# Epoch 36/300, Train Loss: 2.377340, Test Loss: 2.160548
# Epoch 37/300, Train Loss: 2.370432, Test Loss: 2.069451
# Epoch 38/300, Train Loss: 2.586661, Test Loss: 2.126550
# Epoch 39/300, Train Loss: 2.389687, Test Loss: 2.227975
# Epoch 40/300, Train Loss: 2.430285, Test Loss: 2.383575
# Epoch 41/300, Train Loss: 2.397287, Test Loss: 2.065996
# Epoch 42/300, Train Loss: 2.380395, Test Loss: 2.211603
# Epoch 43/300, Train Loss: 2.375256, Test Loss: 2.052163
# Epoch 44/300, Train Loss: 2.526799, Test Loss: 2.811797
# Epoch 45/300, Train Loss: 2.362295, Test Loss: 2.129666
# Epoch 46/300, Train Loss: 2.372361, Test Loss: 2.052948
# Epoch 47/300, Train Loss: 2.386650, Test Loss: 2.150444
# Epoch 48/300, Train Loss: 2.377754, Test Loss: 2.119320
# Epoch 49/300, Train Loss: 2.360594, Test Loss: 2.083847
# Epoch 50/300, Train Loss: 2.380882, Test Loss: 2.077304
# Epoch 51/300, Train Loss: 2.401105, Test Loss: 2.169793
# Epoch 52/300, Train Loss: 2.375654, Test Loss: 2.123975
# Epoch 53/300, Train Loss: 2.401831, Test Loss: 2.270217
# Epoch 54/300, Train Loss: 2.408520, Test Loss: 2.140163
# Epoch 55/300, Train Loss: 2.366329, Test Loss: 2.111610
# Epoch 56/300, Train Loss: 2.499325, Test Loss: 2.357700
# Epoch 57/300, Train Loss: 2.387156, Test Loss: 2.106485
# Epoch 58/300, Train Loss: 2.373504, Test Loss: 2.281813
# Epoch 59/300, Train Loss: 2.447749, Test Loss: 2.188007
# Epoch 60/300, Train Loss: 2.425413, Test Loss: 2.272424
# Epoch 61/300, Train Loss: 2.400545, Test Loss: 2.357623
# Epoch 62/300, Train Loss: 2.404319, Test Loss: 2.077000
# Epoch 63/300, Train Loss: 2.387750, Test Loss: 2.110903
# Epoch 64/300, Train Loss: 2.379821, Test Loss: 2.078506
# Epoch 65/300, Train Loss: 2.401305, Test Loss: 2.053398
# Epoch 66/300, Train Loss: 2.382175, Test Loss: 2.062337
# Epoch 67/300, Train Loss: 2.407886, Test Loss: 2.173117
# Epoch 68/300, Train Loss: 2.450328, Test Loss: 2.763546
# Epoch 69/300, Train Loss: 2.396551, Test Loss: 2.263595
# Epoch 70/300, Train Loss: 3.099137, Test Loss: 2.154123
# Epoch 71/300, Train Loss: 2.384156, Test Loss: 2.072202
# Epoch 72/300, Train Loss: 2.420141, Test Loss: 2.163041
# Epoch 73/300, Train Loss: 2.378721, Test Loss: 2.158732
# Epoch 74/300, Train Loss: 2.381302, Test Loss: 2.089605
# Epoch 75/300, Train Loss: 2.409730, Test Loss: 2.081397
# Epoch 76/300, Train Loss: 2.392905, Test Loss: 2.040713
# Epoch 77/300, Train Loss: 2.386125, Test Loss: 2.245019
# Epoch 78/300, Train Loss: 2.394553, Test Loss: 2.670341
# Epoch 79/300, Train Loss: 2.470664, Test Loss: 2.085344
# Epoch 80/300, Train Loss: 2.397140, Test Loss: 2.300994
# Epoch 81/300, Train Loss: 2.458452, Test Loss: 2.312243
# Epoch 82/300, Train Loss: 2.388766, Test Loss: 2.109386
# Epoch 83/300, Train Loss: 2.365888, Test Loss: 2.066013
# Epoch 84/300, Train Loss: 2.405573, Test Loss: 2.080143
# Epoch 85/300, Train Loss: 2.434809, Test Loss: 2.195218
# Epoch 86/300, Train Loss: 2.391975, Test Loss: 2.012064
# Epoch 87/300, Train Loss: 2.381595, Test Loss: 2.137311
# Epoch 88/300, Train Loss: 2.381539, Test Loss: 2.109816
# Epoch 89/300, Train Loss: 2.806687, Test Loss: 2.310854
# Epoch 90/300, Train Loss: 2.366555, Test Loss: 2.010766
# Epoch 91/300, Train Loss: 2.719107, Test Loss: 2.182071
# Epoch 92/300, Train Loss: 2.371633, Test Loss: 2.056206
# Epoch 93/300, Train Loss: 2.368065, Test Loss: 2.080500
# Epoch 94/300, Train Loss: 2.372878, Test Loss: 2.067059
# Epoch 95/300, Train Loss: 2.391654, Test Loss: 2.065354
# Epoch 96/300, Train Loss: 2.385887, Test Loss: 2.012906
# Epoch 97/300, Train Loss: 2.365083, Test Loss: 2.060771
# Epoch 98/300, Train Loss: 2.436976, Test Loss: 2.062803
# Epoch 99/300, Train Loss: 2.588006, Test Loss: 2.026159
# Epoch 100/300, Train Loss: 2.372828, Test Loss: 2.267566
# Epoch 101/300, Train Loss: 2.383516, Test Loss: 2.019655
# Epoch 102/300, Train Loss: 2.361299, Test Loss: 2.040090
# Epoch 103/300, Train Loss: 2.375340, Test Loss: 2.077523
# Epoch 104/300, Train Loss: 2.383101, Test Loss: 2.064103
# Epoch 105/300, Train Loss: 2.357549, Test Loss: 2.034354
# Epoch 106/300, Train Loss: 2.354425, Test Loss: 2.022509
# Epoch 107/300, Train Loss: 2.364275, Test Loss: 2.020231
# Epoch 108/300, Train Loss: 2.396405, Test Loss: 2.126745
# Epoch 109/300, Train Loss: 2.546873, Test Loss: 2.092464
# Epoch 110/300, Train Loss: 2.946632, Test Loss: 2.187391
# Epoch 111/300, Train Loss: 2.391800, Test Loss: 2.034976
# Epoch 112/300, Train Loss: 2.441088, Test Loss: 2.022474
# Epoch 113/300, Train Loss: 2.375242, Test Loss: 2.123504
# Epoch 114/300, Train Loss: 2.361637, Test Loss: 2.059653
# Epoch 115/300, Train Loss: 2.365637, Test Loss: 2.085184
# Epoch 116/300, Train Loss: 2.368455, Test Loss: 2.041725
# Epoch 117/300, Train Loss: 2.726700, Test Loss: 2.137491
# Epoch 118/300, Train Loss: 2.372878, Test Loss: 2.041075
# Epoch 119/300, Train Loss: 2.364881, Test Loss: 2.096010
# Epoch 120/300, Train Loss: 2.373995, Test Loss: 2.042617
# Epoch 121/300, Train Loss: 2.374330, Test Loss: 2.015478
# Epoch 122/300, Train Loss: 2.369380, Test Loss: 2.074866
# Epoch 123/300, Train Loss: 2.376037, Test Loss: 2.127219
# Epoch 124/300, Train Loss: 2.377496, Test Loss: 2.081059
# Epoch 125/300, Train Loss: 2.388596, Test Loss: 2.031984
# Epoch 126/300, Train Loss: 2.368834, Test Loss: 2.052994
# Epoch 127/300, Train Loss: 2.369272, Test Loss: 2.053308
# Epoch 128/300, Train Loss: 2.371679, Test Loss: 2.109099
# Epoch 129/300, Train Loss: 2.372506, Test Loss: 2.026713
# Epoch 130/300, Train Loss: 2.416956, Test Loss: 2.456911
# Epoch 131/300, Train Loss: 2.381710, Test Loss: 2.053883
# Epoch 132/300, Train Loss: 2.539164, Test Loss: 2.161569
# Epoch 133/300, Train Loss: 2.420990, Test Loss: 2.108071
# Epoch 134/300, Train Loss: 2.369560, Test Loss: 2.055919
# Epoch 135/300, Train Loss: 2.482429, Test Loss: 2.019047
# Epoch 136/300, Train Loss: 2.392564, Test Loss: 2.326993
# Epoch 137/300, Train Loss: 2.502414, Test Loss: 2.174940
# Epoch 138/300, Train Loss: 2.389152, Test Loss: 2.033232
# Epoch 139/300, Train Loss: 2.471938, Test Loss: 2.091107
# Epoch 140/300, Train Loss: 2.364850, Test Loss: 2.124966
# Epoch 141/300, Train Loss: 2.358547, Test Loss: 2.058674
# Epoch 142/300, Train Loss: 2.375948, Test Loss: 2.051467
# Epoch 143/300, Train Loss: 2.375536, Test Loss: 2.076736
# Epoch 144/300, Train Loss: 2.419416, Test Loss: 2.020001
# Epoch 145/300, Train Loss: 2.479144, Test Loss: 2.840680
# Epoch 146/300, Train Loss: 2.379789, Test Loss: 2.035911
# Epoch 147/300, Train Loss: 2.372795, Test Loss: 2.026414
# Epoch 148/300, Train Loss: 2.359939, Test Loss: 2.036225
# Epoch 149/300, Train Loss: 2.434695, Test Loss: 2.047395
# Epoch 150/300, Train Loss: 2.378442, Test Loss: 2.033459
# Epoch 151/300, Train Loss: 2.364907, Test Loss: 2.150951
# Epoch 152/300, Train Loss: 2.377590, Test Loss: 2.129522
# Epoch 153/300, Train Loss: 2.366022, Test Loss: 2.062775
# Epoch 154/300, Train Loss: 2.490768, Test Loss: 2.228512
# Epoch 155/300, Train Loss: 2.393356, Test Loss: 2.018121
# Epoch 156/300, Train Loss: 2.362278, Test Loss: 2.102635
# Epoch 157/300, Train Loss: 2.384826, Test Loss: 2.092154
# Epoch 158/300, Train Loss: 2.373964, Test Loss: 2.093403
# Epoch 159/300, Train Loss: 2.345361, Test Loss: 2.063200
# Epoch 160/300, Train Loss: 2.348245, Test Loss: 2.037931
# Epoch 161/300, Train Loss: 2.365963, Test Loss: 2.036589
# Epoch 162/300, Train Loss: 2.365393, Test Loss: 2.064474
# Epoch 163/300, Train Loss: 2.390985, Test Loss: 2.438212
# Epoch 164/300, Train Loss: 2.350966, Test Loss: 2.108951
# Epoch 165/300, Train Loss: 2.674612, Test Loss: 1.987175
# Epoch 166/300, Train Loss: 2.359668, Test Loss: 2.030733
# Epoch 167/300, Train Loss: 2.386725, Test Loss: 2.271880
# Epoch 168/300, Train Loss: 2.379956, Test Loss: 2.019323
# Epoch 169/300, Train Loss: 2.410707, Test Loss: 2.079492
# Epoch 170/300, Train Loss: 2.354436, Test Loss: 2.042954
# Epoch 171/300, Train Loss: 2.357809, Test Loss: 2.062244
# Epoch 172/300, Train Loss: 2.332985, Test Loss: 2.005130
# Epoch 173/300, Train Loss: 2.548405, Test Loss: 2.229135
# Epoch 174/300, Train Loss: 2.364424, Test Loss: 2.115863
# Epoch 175/300, Train Loss: 2.355930, Test Loss: 2.055995
# Epoch 176/300, Train Loss: 2.453114, Test Loss: 2.138098
# Epoch 177/300, Train Loss: 2.426993, Test Loss: 2.115782
# Epoch 178/300, Train Loss: 2.354265, Test Loss: 2.104475
# Epoch 179/300, Train Loss: 2.343849, Test Loss: 2.103715
# Epoch 180/300, Train Loss: 2.384824, Test Loss: 2.129230
# Epoch 181/300, Train Loss: 2.341550, Test Loss: 2.047199
# Epoch 182/300, Train Loss: 2.364830, Test Loss: 2.043774
# Epoch 183/300, Train Loss: 2.404803, Test Loss: 2.195855
# Epoch 184/300, Train Loss: 2.668172, Test Loss: 2.257087
# Epoch 185/300, Train Loss: 2.391745, Test Loss: 2.088730
# Epoch 186/300, Train Loss: 2.354340, Test Loss: 2.067227
# Epoch 187/300, Train Loss: 2.356690, Test Loss: 2.044609
# Epoch 188/300, Train Loss: 2.355113, Test Loss: 2.064731
# Epoch 189/300, Train Loss: 2.358894, Test Loss: 2.122452
# Epoch 190/300, Train Loss: 2.385376, Test Loss: 2.030792
# Epoch 191/300, Train Loss: 2.365949, Test Loss: 2.074333
# Epoch 192/300, Train Loss: 2.390184, Test Loss: 2.238115
# Epoch 193/300, Train Loss: 2.614091, Test Loss: 2.647623
# Epoch 194/300, Train Loss: 2.359735, Test Loss: 2.118503
# Epoch 195/300, Train Loss: 2.361841, Test Loss: 2.069910
# Epoch 196/300, Train Loss: 2.366989, Test Loss: 2.037411
# Epoch 197/300, Train Loss: 2.378103, Test Loss: 2.158014
# Epoch 198/300, Train Loss: 2.423059, Test Loss: 2.129640
# Epoch 199/300, Train Loss: 2.490392, Test Loss: 2.668592
# Epoch 200/300, Train Loss: 2.346816, Test Loss: 2.063283
# Epoch 201/300, Train Loss: 2.355095, Test Loss: 2.079132
# Epoch 202/300, Train Loss: 2.356990, Test Loss: 2.044391
# Epoch 203/300, Train Loss: 2.372635, Test Loss: 2.098421
# Epoch 204/300, Train Loss: 2.358334, Test Loss: 2.044604
# Epoch 205/300, Train Loss: 2.358200, Test Loss: 2.049579
# Epoch 206/300, Train Loss: 2.347523, Test Loss: 2.089197
# Epoch 207/300, Train Loss: 2.482223, Test Loss: 2.035630
# Epoch 208/300, Train Loss: 2.385031, Test Loss: 2.044681
# Epoch 209/300, Train Loss: 2.538215, Test Loss: 2.020922
# Epoch 210/300, Train Loss: 2.343272, Test Loss: 2.032521
# Epoch 211/300, Train Loss: 2.351887, Test Loss: 2.104606
# Epoch 212/300, Train Loss: 2.350112, Test Loss: 2.126375
# Epoch 213/300, Train Loss: 2.385851, Test Loss: 2.176618
# Epoch 214/300, Train Loss: 2.466682, Test Loss: 2.185164
# Epoch 215/300, Train Loss: 2.344257, Test Loss: 2.082928
# Epoch 216/300, Train Loss: 2.403244, Test Loss: 2.094434
# Epoch 217/300, Train Loss: 2.343392, Test Loss: 2.062695
# Epoch 218/300, Train Loss: 2.349269, Test Loss: 2.252760
# Epoch 219/300, Train Loss: 2.366800, Test Loss: 2.102833
# Epoch 220/300, Train Loss: 2.356279, Test Loss: 2.074891
# Epoch 221/300, Train Loss: 2.651886, Test Loss: 2.136781
# Epoch 222/300, Train Loss: 2.357459, Test Loss: 2.112363
# Epoch 223/300, Train Loss: 2.510449, Test Loss: 2.030047
# Epoch 224/300, Train Loss: 2.358358, Test Loss: 2.064339
# Epoch 225/300, Train Loss: 2.343302, Test Loss: 2.048347
# Epoch 226/300, Train Loss: 2.336988, Test Loss: 2.063792
# Epoch 227/300, Train Loss: 2.341251, Test Loss: 2.033209
# Epoch 228/300, Train Loss: 2.354959, Test Loss: 2.055813
# Epoch 229/300, Train Loss: 2.350681, Test Loss: 2.024885
# Epoch 230/300, Train Loss: 2.370622, Test Loss: 2.095285
# Epoch 231/300, Train Loss: 2.383582, Test Loss: 2.091010
# Epoch 232/300, Train Loss: 2.451707, Test Loss: 2.330829
# Epoch 233/300, Train Loss: 2.350614, Test Loss: 2.000224
# Epoch 234/300, Train Loss: 2.505953, Test Loss: 2.060489
# Epoch 235/300, Train Loss: 2.366694, Test Loss: 2.030972
# Epoch 236/300, Train Loss: 2.356436, Test Loss: 1.999798
# Epoch 237/300, Train Loss: 2.455618, Test Loss: 2.025724
# Epoch 238/300, Train Loss: 2.364718, Test Loss: 2.098446
# Epoch 239/300, Train Loss: 2.752925, Test Loss: 2.022694
# Epoch 240/300, Train Loss: 2.380429, Test Loss: 2.054632
# Epoch 241/300, Train Loss: 2.497756, Test Loss: 2.062850
# Epoch 242/300, Train Loss: 2.406530, Test Loss: 2.088480
# Epoch 243/300, Train Loss: 2.358435, Test Loss: 2.007406
# Epoch 244/300, Train Loss: 2.330735, Test Loss: 2.078665
# Epoch 245/300, Train Loss: 2.372571, Test Loss: 2.174546
# Epoch 246/300, Train Loss: 2.343581, Test Loss: 2.027499
# Epoch 247/300, Train Loss: 2.384391, Test Loss: 2.064137
# Epoch 248/300, Train Loss: 2.435402, Test Loss: 2.207367
# Epoch 249/300, Train Loss: 2.344175, Test Loss: 2.048089
# Epoch 250/300, Train Loss: 2.380159, Test Loss: 2.087105
# Epoch 251/300, Train Loss: 2.362941, Test Loss: 2.072623
# Epoch 252/300, Train Loss: 2.369706, Test Loss: 2.064581
# Epoch 253/300, Train Loss: 2.369993, Test Loss: 2.084367
# Epoch 254/300, Train Loss: 2.384302, Test Loss: 2.130918
# Epoch 255/300, Train Loss: 2.351172, Test Loss: 2.070605
# Epoch 256/300, Train Loss: 2.403311, Test Loss: 2.048170
# Epoch 257/300, Train Loss: 2.387665, Test Loss: 2.117473
# Epoch 258/300, Train Loss: 2.387496, Test Loss: 2.171902
# Epoch 259/300, Train Loss: 2.381504, Test Loss: 2.068320
# Epoch 260/300, Train Loss: 2.405524, Test Loss: 2.002234
# Epoch 261/300, Train Loss: 2.365957, Test Loss: 2.042258
# Epoch 262/300, Train Loss: 2.395371, Test Loss: 2.093495
# Epoch 263/300, Train Loss: 2.357930, Test Loss: 2.050787
# Epoch 264/300, Train Loss: 2.373621, Test Loss: 2.048380
# Epoch 265/300, Train Loss: 2.359751, Test Loss: 2.047526
# Epoch 266/300, Train Loss: 2.358272, Test Loss: 2.002334
# Epoch 267/300, Train Loss: 2.348946, Test Loss: 2.032320
# Epoch 268/300, Train Loss: 2.486696, Test Loss: 2.396863
# Epoch 269/300, Train Loss: 2.361135, Test Loss: 2.041245
# Epoch 270/300, Train Loss: 2.362247, Test Loss: 2.038022
# Epoch 271/300, Train Loss: 2.330399, Test Loss: 2.064599
# Epoch 272/300, Train Loss: 2.364274, Test Loss: 2.119798
# Epoch 273/300, Train Loss: 2.446859, Test Loss: 2.149726
# Epoch 274/300, Train Loss: 2.353844, Test Loss: 2.006454
# Epoch 275/300, Train Loss: 2.358589, Test Loss: 2.016690
# Epoch 276/300, Train Loss: 3.074737, Test Loss: 2.076745
# Epoch 277/300, Train Loss: 2.371962, Test Loss: 2.099338
# Epoch 278/300, Train Loss: 2.347569, Test Loss: 2.084192
# Epoch 279/300, Train Loss: 2.548659, Test Loss: 2.117557
# Epoch 280/300, Train Loss: 2.381570, Test Loss: 2.259070
# Epoch 281/300, Train Loss: 2.354687, Test Loss: 2.004721
# Epoch 282/300, Train Loss: 2.357102, Test Loss: 2.042206
# Epoch 283/300, Train Loss: 2.356058, Test Loss: 2.044189
# Epoch 284/300, Train Loss: 2.366462, Test Loss: 2.161125
# Epoch 285/300, Train Loss: 2.401617, Test Loss: 2.088762
# Epoch 286/300, Train Loss: 2.368282, Test Loss: 2.085934
# Epoch 287/300, Train Loss: 2.397192, Test Loss: 2.026189
# Epoch 288/300, Train Loss: 2.344468, Test Loss: 2.048766
# Epoch 289/300, Train Loss: 2.354288, Test Loss: 2.040159
# Epoch 290/300, Train Loss: 2.403252, Test Loss: 2.235232
# Epoch 291/300, Train Loss: 2.740011, Test Loss: 2.065453
# Epoch 292/300, Train Loss: 2.368229, Test Loss: 2.171889
# Epoch 293/300, Train Loss: 2.368837, Test Loss: 1.995690
# Epoch 294/300, Train Loss: 2.379594, Test Loss: 2.049066
# Epoch 295/300, Train Loss: 2.335297, Test Loss: 2.018410
# Epoch 296/300, Train Loss: 2.399958, Test Loss: 2.188386
# Epoch 297/300, Train Loss: 2.369632, Test Loss: 2.060839
# Epoch 298/300, Train Loss: 2.377579, Test Loss: 2.211773
# Epoch 299/300, Train Loss: 2.354881, Test Loss: 2.065159
# Epoch 300/300, Train Loss: 2.379858, Test Loss: 2.132817

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              #'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              #'scaler_day_smote' : scaler_day_smote,
              #'scaler_month_smote' : scaler_month_smote,
              #'scaler_decade_smote' : scaler_decade_smote,
              
              'alpha': alpha,
              #'alpha_smote': alpha_smote
              }



torch.save(checkpoint, 'checkpoint_half.pth.tar')

# %%
# r2_score(y.detach().numpy(), yHat.detach().numpy())
# type(r2_score(y.detach(), yHat.detach()))

# %%
# torch.mean( r2_score(y.detach().numpy(), yHat.detach().numpy()) ).item()

# %%
trainLoss1, testLoss1, trainAcc1
# Out:
# (tensor([2.3262, 2.3244, 2.3181, 2.3213, 2.3195, 2.3254, 2.3137, 2.3243, 2.3270,
#          2.3072, 2.2968, 2.2983, 2.3043, 2.3051, 2.3039, 2.3020, 2.2973, 2.3097,
#          2.3014, 2.3029, 2.3005, 2.3053, 2.2991, 2.3053, 2.2985, 2.2954, 2.3075,
#          2.3033, 2.3024, 2.2987, 2.3062, 2.3037, 2.3050, 2.2956, 2.3103, 2.3001,
#          2.2935, 2.3069, 2.2931, 2.3023, 2.2937, 2.2980, 2.3080, 2.2987, 2.3017,
#          2.3070, 2.3077, 2.3037, 2.2985, 2.3015, 2.3067, 2.2994, 2.2957, 2.3062,
#          2.3012, 2.2978, 2.3132, 2.2988, 2.3037, 2.2952, 2.2988, 2.2949, 2.3065,
#          2.3023, 2.3002, 2.2991, 2.3001, 2.3051, 2.2965, 2.3078, 2.3008, 2.2982,
#          2.3025, 2.2976, 2.2994, 2.3010, 2.2972, 2.2936, 2.2981, 2.3062, 2.3014,
#          2.2960, 2.2964, 2.3051, 2.2918, 2.3112, 2.3020, 2.2934, 2.2971, 2.2957,
#          2.3014, 2.2992, 2.2972, 2.2965, 2.3041, 2.2934, 2.3108, 2.3295, 2.2984,
#          2.2923, 2.2953, 2.3105, 2.2952, 2.2911, 2.2949, 2.2963, 2.2929, 2.2904,
#          2.3016, 2.3160, 2.3052, 2.2914, 2.2933, 2.2972, 2.2949, 2.2958, 2.2957,
#          2.3004, 2.2937, 2.2894, 2.2940, 2.2986, 2.3002, 2.2996, 2.2965, 2.2924,
#          2.2989, 2.2939, 2.2967, 2.2933, 2.2999, 2.2921, 2.2981, 2.3009, 2.2989,
#          2.2960, 2.3056, 2.3008, 2.3053, 2.3005, 2.2990, 2.2968, 2.3021, 2.2994,
#          2.2914, 2.2918, 2.2945, 2.2909, 2.2980, 2.2971, 2.2887, 2.3055, 2.2967,
#          2.3091, 2.2993, 2.2955, 2.2892, 2.3105, 2.2984, 2.2964, 2.2939, 2.2882,
#          2.2946, 2.2942, 2.2923, 2.2974, 2.3051, 2.3026, 2.2850, 2.3011, 2.2965,
#          2.3082, 2.2957, 2.2916, 2.2998, 2.2894, 2.2962, 2.2964, 2.2888, 2.2943,
#          2.2883, 2.3034, 2.2928, 2.2931, 2.2909, 2.2976, 2.2908, 2.2926, 2.2938,
#          2.2991, 2.3004, 2.2955, 2.3020, 2.2910, 2.2990, 2.3008, 2.2977, 2.2968,
#          2.2933, 2.2942, 2.2994, 2.2947, 2.3014, 2.2996, 2.2996, 2.2972, 2.2973,
#          2.2960, 2.2994, 2.2994, 2.2898, 2.2953, 2.2948, 2.2911, 2.3050, 2.2927,
#          2.2959, 2.2937, 2.3026, 2.2961, 2.2952, 2.2895, 2.2952, 2.3007, 2.2952,
#          2.2938, 2.2937, 2.3006, 2.2939, 2.3043, 2.3032, 2.3039, 2.3008, 2.2961,
#          2.2918, 2.2840, 2.3118, 2.2858, 2.3028, 2.2940, 2.2940, 2.3077, 2.2820,
#          2.3084, 2.2988, 2.3078, 2.2968, 2.2995, 2.2891, 2.2979, 2.3028, 2.2878,
#          2.2950, 2.3035, 2.2986, 2.2998, 2.3016, 2.2895, 2.3039, 2.2994, 2.3053,
#          2.2946, 2.2938, 2.3014, 2.2949, 2.3022, 2.2946, 2.2924, 2.2915, 2.3008,
#          2.3039, 2.3024, 2.3140, 2.3015, 2.2961, 2.3093, 2.3057, 2.3020, 2.2905,
#          2.2987, 2.2933, 2.2997, 2.2919, 2.2916, 2.2939, 2.2912, 2.2925, 2.3073,
#          2.2842, 2.2979, 2.2981, 2.2933, 2.3014, 2.2878, 2.2982, 2.3004, 2.2906,
#          2.3066, 2.2993, 2.2871]),
#  tensor([2.1110, 2.3084, 2.2379, 2.2509, 2.0893, 2.1227, 2.0777, 2.3117, 2.1555,
#          2.0784, 2.0650, 2.1793, 2.1199, 2.1070, 2.0877, 2.0496, 2.0954, 2.1286,
#          2.4142, 2.2658, 2.1630, 2.1574, 2.3428, 2.1800, 2.1775, 2.1457, 2.1182,
#          2.1305, 2.0901, 2.1275, 2.5371, 2.1498, 2.2110, 2.2364, 2.0723, 2.1605,
#          2.0695, 2.1265, 2.2280, 2.3836, 2.0660, 2.2116, 2.0522, 2.8118, 2.1297,
#          2.0529, 2.1504, 2.1193, 2.0838, 2.0773, 2.1698, 2.1240, 2.2702, 2.1402,
#          2.1116, 2.3577, 2.1065, 2.2818, 2.1880, 2.2724, 2.3576, 2.0770, 2.1109,
#          2.0785, 2.0534, 2.0623, 2.1731, 2.7635, 2.2636, 2.1541, 2.0722, 2.1630,
#          2.1587, 2.0896, 2.0814, 2.0407, 2.2450, 2.6703, 2.0853, 2.3010, 2.3122,
#          2.1094, 2.0660, 2.0801, 2.1952, 2.0121, 2.1373, 2.1098, 2.3109, 2.0108,
#          2.1821, 2.0562, 2.0805, 2.0671, 2.0654, 2.0129, 2.0608, 2.0628, 2.0262,
#          2.2676, 2.0197, 2.0401, 2.0775, 2.0641, 2.0344, 2.0225, 2.0202, 2.1267,
#          2.0925, 2.1874, 2.0350, 2.0225, 2.1235, 2.0597, 2.0852, 2.0417, 2.1375,
#          2.0411, 2.0960, 2.0426, 2.0155, 2.0749, 2.1272, 2.0811, 2.0320, 2.0530,
#          2.0533, 2.1091, 2.0267, 2.4569, 2.0539, 2.1616, 2.1081, 2.0559, 2.0190,
#          2.3270, 2.1749, 2.0332, 2.0911, 2.1250, 2.0587, 2.0515, 2.0767, 2.0200,
#          2.8407, 2.0359, 2.0264, 2.0362, 2.0474, 2.0335, 2.1510, 2.1295, 2.0628,
#          2.2285, 2.0181, 2.1026, 2.0922, 2.0934, 2.0632, 2.0379, 2.0366, 2.0645,
#          2.4382, 2.1090, 1.9872, 2.0307, 2.2719, 2.0193, 2.0795, 2.0430, 2.0622,
#          2.0051, 2.2291, 2.1159, 2.0560, 2.1381, 2.1158, 2.1045, 2.1037, 2.1292,
#          2.0472, 2.0438, 2.1959, 2.2571, 2.0887, 2.0672, 2.0446, 2.0647, 2.1225,
#          2.0308, 2.0743, 2.2381, 2.6476, 2.1185, 2.0699, 2.0374, 2.1580, 2.1296,
#          2.6686, 2.0633, 2.0791, 2.0444, 2.0984, 2.0446, 2.0496, 2.0892, 2.0356,
#          2.0447, 2.0209, 2.0325, 2.1046, 2.1264, 2.1766, 2.1852, 2.0829, 2.0944,
#          2.0627, 2.2528, 2.1028, 2.0749, 2.1368, 2.1124, 2.0300, 2.0643, 2.0483,
#          2.0638, 2.0332, 2.0558, 2.0249, 2.0953, 2.0910, 2.3308, 2.0002, 2.0605,
#          2.0310, 1.9998, 2.0257, 2.0984, 2.0227, 2.0546, 2.0628, 2.0885, 2.0074,
#          2.0787, 2.1745, 2.0275, 2.0641, 2.2074, 2.0481, 2.0871, 2.0726, 2.0646,
#          2.0844, 2.1309, 2.0706, 2.0482, 2.1175, 2.1719, 2.0683, 2.0022, 2.0423,
#          2.0935, 2.0508, 2.0484, 2.0475, 2.0023, 2.0323, 2.3969, 2.0412, 2.0380,
#          2.0646, 2.1198, 2.1497, 2.0065, 2.0167, 2.0767, 2.0993, 2.0842, 2.1176,
#          2.2591, 2.0047, 2.0422, 2.0442, 2.1611, 2.0888, 2.0859, 2.0262, 2.0488,
#          2.0402, 2.2352, 2.0655, 2.1719, 1.9957, 2.0491, 2.0184, 2.1884, 2.0608,
#          2.2118, 2.0652, 2.1328]),
#  tensor([0.5254, 0.5255, 0.5260, 0.5256, 0.5259, 0.5249, 0.5267, 0.5252, 0.5251,
#          0.5277, 0.5290, 0.5286, 0.5277, 0.5274, 0.5279, 0.5283, 0.5286, 0.5271,
#          0.5283, 0.5281, 0.5283, 0.5278, 0.5291, 0.5280, 0.5289, 0.5296, 0.5279,
#          0.5280, 0.5284, 0.5289, 0.5278, 0.5280, 0.5282, 0.5295, 0.5279, 0.5290,
#          0.5296, 0.5275, 0.5297, 0.5286, 0.5299, 0.5293, 0.5280, 0.5289, 0.5286,
#          0.5282, 0.5275, 0.5283, 0.5287, 0.5287, 0.5278, 0.5289, 0.5296, 0.5280,
#          0.5287, 0.5292, 0.5271, 0.5291, 0.5283, 0.5296, 0.5289, 0.5294, 0.5279,
#          0.5282, 0.5287, 0.5285, 0.5289, 0.5283, 0.5292, 0.5279, 0.5286, 0.5292,
#          0.5283, 0.5289, 0.5286, 0.5286, 0.5291, 0.5295, 0.5292, 0.5280, 0.5289,
#          0.5295, 0.5292, 0.5280, 0.5302, 0.5273, 0.5285, 0.5296, 0.5293, 0.5293,
#          0.5284, 0.5287, 0.5291, 0.5292, 0.5282, 0.5298, 0.5273, 0.5253, 0.5288,
#          0.5297, 0.5296, 0.5272, 0.5294, 0.5298, 0.5293, 0.5292, 0.5297, 0.5300,
#          0.5288, 0.5273, 0.5280, 0.5299, 0.5295, 0.5288, 0.5295, 0.5296, 0.5293,
#          0.5284, 0.5293, 0.5302, 0.5295, 0.5290, 0.5290, 0.5289, 0.5291, 0.5297,
#          0.5286, 0.5295, 0.5288, 0.5297, 0.5288, 0.5298, 0.5294, 0.5284, 0.5289,
#          0.5295, 0.5279, 0.5284, 0.5276, 0.5284, 0.5292, 0.5292, 0.5286, 0.5289,
#          0.5298, 0.5297, 0.5293, 0.5297, 0.5292, 0.5292, 0.5304, 0.5282, 0.5293,
#          0.5276, 0.5291, 0.5291, 0.5300, 0.5270, 0.5284, 0.5291, 0.5297, 0.5303,
#          0.5294, 0.5295, 0.5298, 0.5291, 0.5280, 0.5282, 0.5307, 0.5285, 0.5292,
#          0.5278, 0.5296, 0.5298, 0.5287, 0.5299, 0.5293, 0.5295, 0.5303, 0.5292,
#          0.5305, 0.5281, 0.5295, 0.5295, 0.5298, 0.5291, 0.5298, 0.5295, 0.5298,
#          0.5288, 0.5284, 0.5294, 0.5283, 0.5301, 0.5289, 0.5288, 0.5290, 0.5296,
#          0.5293, 0.5296, 0.5286, 0.5298, 0.5286, 0.5287, 0.5291, 0.5291, 0.5294,
#          0.5291, 0.5289, 0.5288, 0.5301, 0.5296, 0.5293, 0.5301, 0.5282, 0.5295,
#          0.5293, 0.5295, 0.5280, 0.5292, 0.5295, 0.5298, 0.5292, 0.5285, 0.5294,
#          0.5293, 0.5293, 0.5284, 0.5295, 0.5282, 0.5284, 0.5281, 0.5282, 0.5287,
#          0.5295, 0.5311, 0.5273, 0.5308, 0.5282, 0.5295, 0.5295, 0.5279, 0.5310,
#          0.5272, 0.5287, 0.5277, 0.5293, 0.5289, 0.5303, 0.5290, 0.5284, 0.5303,
#          0.5293, 0.5283, 0.5284, 0.5290, 0.5285, 0.5302, 0.5280, 0.5291, 0.5281,
#          0.5293, 0.5294, 0.5282, 0.5297, 0.5285, 0.5295, 0.5296, 0.5298, 0.5283,
#          0.5284, 0.5284, 0.5269, 0.5290, 0.5292, 0.5275, 0.5277, 0.5282, 0.5301,
#          0.5291, 0.5295, 0.5286, 0.5296, 0.5295, 0.5293, 0.5298, 0.5297, 0.5279,
#          0.5309, 0.5287, 0.5289, 0.5298, 0.5285, 0.5303, 0.5291, 0.5286, 0.5297,
#          0.5278, 0.5283, 0.5305]))

# %%
# batchLoss

# %%
# batchAcc

# %%
# yHat.shape, y.shape

# %%
# yHat_test.shape, yy.shape

# %%
yHat1.flatten(), y1.flatten()
# Out:
# (tensor([1.9863, 0.6040, 7.5246, 4.5669, 0.0104, 3.0897, 1.1534, 4.5059, 1.9808,
#          0.0000, 7.4396, 4.6058, 0.3068, 2.1120, 1.1836, 4.5696, 1.9943, 0.0000,
#          5.1185, 4.7561, 0.0189, 3.0405, 1.1662, 4.6199, 1.9894, 0.6101, 3.4960,
#          4.7211, 0.0000, 6.8947, 1.1654, 4.6368, 1.9938, 0.7096, 7.7759, 4.5181,
#          0.0000, 7.7768, 1.1860, 4.5109, 0.9905, 9.1918, 4.6818, 4.6173, 0.6732,
#          1.0301, 1.1689, 4.5250, 0.9926, 8.1381, 0.9696, 4.6453, 0.0333, 3.0236,
#          1.1329, 4.6065, 1.9822, 0.0000, 8.0688, 4.5674, 0.8305, 0.4074, 1.2166,
#          4.6196, 0.9794, 9.0764, 6.3000, 4.5648, 0.4066, 1.8890, 1.1564, 4.4312,
#          0.9428, 9.0932, 0.0000, 4.6771, 0.0000, 6.4785, 1.1500, 4.7604, 1.9863,
#          0.6638, 5.8322, 4.6612, 0.0000, 8.0120, 1.1685, 4.5340, 1.9751, 0.6939,
#          7.8255, 4.5447, 0.2807, 2.2117, 1.1679, 4.5273, 2.0295, 0.0000, 7.2633,
#          4.6246, 0.0000, 3.9882, 1.1686, 4.5575, 1.9804, 0.0000, 7.6936, 4.5930,
#          0.7172, 0.7718, 1.2069, 4.6109, 0.9443, 9.0770, 0.0000, 4.6771, 0.0000,
#          6.3897, 1.1495, 4.7564, 1.0326, 8.2045, 1.2502, 4.5923, 0.0000, 8.8779,
#          1.1401, 4.5899, 0.9778, 9.0504, 2.5680, 4.6483, 0.0000, 5.3262, 1.1560,
#          4.5624, 1.9601, 0.7483, 4.2125, 4.7205, 0.6825, 0.8768, 1.1724, 4.6675,
#          1.9503, 0.8733, 5.5693, 4.6874, 1.0540, 0.0000, 1.1851, 4.6399, 1.9880,
#          0.0000, 8.2376, 4.5540, 0.4536, 1.6463, 1.2010, 4.5820, 0.9842, 9.1440,
#          7.5773, 4.4619, 0.8159, 0.5790, 1.1837, 4.4415, 0.9632, 9.0512, 0.0000,
#          4.6593, 0.0000, 6.5090, 1.1522, 4.6740, 1.0274, 8.2017, 1.2009, 4.6041,
#          0.0000, 8.0189, 1.1396, 4.5964, 1.0073, 8.1339, 1.2960, 4.6357, 0.2901,
#          2.1805, 1.1423, 4.6153, 1.0147, 7.9261, 8.1451, 4.3777, 0.0000, 5.4503,
#          1.1566, 4.3943, 0.9983, 8.0748, 8.1973, 4.3892, 0.2318, 2.4105, 1.1612,
#          4.3981, 1.9815, 0.6159, 1.5069, 4.7456, 0.0000, 6.9645, 1.1651, 4.7106,
#          0.9796, 9.0303, 3.6253, 4.6474, 0.0000, 4.5892, 1.1563, 4.5302, 1.9926,
#          0.0000, 0.3258, 4.7789, 0.0000, 8.1163, 1.1838, 4.7944, 1.9557, 0.9007,
#          1.5671, 4.7380, 1.1018, 0.0000, 1.1866, 4.7921, 1.0453, 8.0981, 5.3986,
#          4.5417, 0.0000, 7.8100, 1.1382, 4.4390, 2.0206, 0.0000, 3.8763, 4.7916,
#          0.0000, 4.8765, 1.1912, 4.6909], grad_fn=<ReshapeAliasBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
yHat_test1, yy1
# Out:
# (tensor([[1.0401, 8.1471, 2.0487, 4.5979, 0.0000, 6.0865, 1.1235, 4.5642]]),
#  tensor([[1., 8., 1., 6., 0., 6., 0., 1.]]))

# %%
yy1
# Out:
# tensor([[1., 8., 1., 6., 0., 6., 0., 1.]])

# %%
(yHat_test1).round()
# Out:
# tensor([[1., 8., 2., 5., 0., 6., 1., 5.]])

# %%
(yHat1.flatten()).round(), (y1.flatten()).round()
# Out:
# (tensor([2., 1., 8., 5., 0., 3., 1., 5., 2., 0., 7., 5., 0., 2., 1., 5., 2., 0.,
#          5., 5., 0., 3., 1., 5., 2., 1., 3., 5., 0., 7., 1., 5., 2., 1., 8., 5.,
#          0., 8., 1., 5., 1., 9., 5., 5., 1., 1., 1., 5., 1., 8., 1., 5., 0., 3.,
#          1., 5., 2., 0., 8., 5., 1., 0., 1., 5., 1., 9., 6., 5., 0., 2., 1., 4.,
#          1., 9., 0., 5., 0., 6., 1., 5., 2., 1., 6., 5., 0., 8., 1., 5., 2., 1.,
#          8., 5., 0., 2., 1., 5., 2., 0., 7., 5., 0., 4., 1., 5., 2., 0., 8., 5.,
#          1., 1., 1., 5., 1., 9., 0., 5., 0., 6., 1., 5., 1., 8., 1., 5., 0., 9.,
#          1., 5., 1., 9., 3., 5., 0., 5., 1., 5., 2., 1., 4., 5., 1., 1., 1., 5.,
#          2., 1., 6., 5., 1., 0., 1., 5., 2., 0., 8., 5., 0., 2., 1., 5., 1., 9.,
#          8., 4., 1., 1., 1., 4., 1., 9., 0., 5., 0., 7., 1., 5., 1., 8., 1., 5.,
#          0., 8., 1., 5., 1., 8., 1., 5., 0., 2., 1., 5., 1., 8., 8., 4., 0., 5.,
#          1., 4., 1., 8., 8., 4., 0., 2., 1., 4., 2., 1., 2., 5., 0., 7., 1., 5.,
#          1., 9., 4., 5., 0., 5., 1., 5., 2., 0., 0., 5., 0., 8., 1., 5., 2., 1.,
#          2., 5., 1., 0., 1., 5., 1., 8., 5., 5., 0., 8., 1., 4., 2., 0., 4., 5.,
#          0., 5., 1., 5.], grad_fn=<RoundBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
print_score(X.shape, yHat1, y1, yHat_test1, yy1)
# Out:
# Adjusted R-Squared(y, yHat): 0.5483
#
#
# mean_absolute_error(y, yHat): 0.8618
#
# mean_absolute_error(yy, yHat_test): 0.9265
#
#
# mean_squared_error(y, yHat): 2.3799
#
# mean_squared_error(yy, yHat_test): 2.1328
#
#
# mean_squared_log_error(y, yHat): 0.1940
#
# mean_squared_log_error(yy, yHat_test): 0.2303
#
#
# RMSE(y, yHat): 1.5427
#
# RMSE(yy, yHat_test): 1.4604

# %%
# create a 1D smoothing filter
def smooth(x, k=15):
    return np.convolve(x, np.ones(k)/k, mode='same')

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Train loss')
ax[0].legend()



ax[1].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Test loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss1.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc1, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat1.detach().T, y1.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc1.jpg", bbox_inches='tight')


plt.show()

# %%
data.leap_year.value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
resampler = SMOTE(k_neighbors=20, random_state=0)

# %%
X_res, y_res = resampler.fit_resample(data[['day_code', 'month_code', 'decade', 'date_int']], data['leap_year'])

# %%
y_res.value_counts()
# Out:
# 0    110960
# 1    110960
# Name: leap_year, dtype: int64

# %%
data['leap_year'].value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 221915    1
# 221916    1
# 221917    1
# 221918    1
# 221919    1
# Name: leap_year, Length: 221920, dtype: int64

# %%
X_res
# Out:
#         day_code  month_code  decade  date_int
# 0              4           0     180  18000101
# 1              5           0     180  18010101
# 2              6           0     180  18020101
# 3              0           0     180  18030101
# 4              1           0     180  18040101
# ...          ...         ...     ...       ...
# 221915         0           5     188  18880618
# 221916         2           6     188  18840705
# 221917         5           2     218  21800323
# 221918         1           5     199  19960602
# 221919         1           4     219  21960520
#
# [221920 rows x 4 columns]

# %%
X_smote = X_res.assign(leap_year=y_res)

# %%
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221915         0           5     188  18880618          1
# 221916         2           6     188  18840705          1
# 221917         5           2     218  21800323          1
# 221918         1           5     199  19960602          1
# 221919         1           4     219  21960520          1
#
# [221920 rows x 5 columns]

# %% [markdown]
# Drop 220 decade

# %%
# data.decade.value_counts().plot(kind="bar")
X_smote.decade.value_counts().plot(kind="bar")

# %%
# data.decade.value_counts()[-5:]
X_smote.decade.value_counts()[-5:]
# Out:
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# 220     365
# Name: decade, dtype: int64

# %%
X_smote = X_smote.drop(X_smote.index[X_smote['decade'] == 220]).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221550         0           5     188  18880618          1
# 221551         2           6     188  18840705          1
# 221552         5           2     218  21800323          1
# 221553         1           5     199  19960602          1
# 221554         1           4     219  21960520          1
#
# [221555 rows x 5 columns]

# %%
X_smote.decade.value_counts().plot(kind="bar")

# %%
X_smote.decade.value_counts()[-5:]
# Out:
# 209    5174
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# Name: decade, dtype: int64

# %% [markdown]
# code is required to only work for dates in the range  [ 1-1-1800 to 31-12-2200 ]

# %%
X_smote.date_int.max()
# Out:
# 21991231

# %%
datetime.datetime.strptime(str(X_smote.date_int.max()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '31-12-2199'

# %%
X_smote.date_int.min()
# Out:
# 18000101

# %%
datetime.datetime.strptime(str(X_smote.date_int.min()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '01-01-1800'

# %%
Y_smote = X_smote['date_int']
Y_smote
# Out:
# 0         18000101
# 1         18010101
# 2         18020101
# 3         18030101
# 4         18040101
#             ...
# 221550    18880618
# 221551    18840705
# 221552    21800323
# 221553    19960602
# 221554    21960520
# Name: date_int, Length: 221555, dtype: int64

# %%
X_smote = X_smote.drop('date_int', axis=1).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  leap_year
# 0              4           0     180          0
# 1              5           0     180          0
# 2              6           0     180          0
# 3              0           0     180          0
# 4              1           0     180          1
# ...          ...         ...     ...        ...
# 221550         0           5     188          1
# 221551         2           6     188          1
# 221552         5           2     218          1
# 221553         1           5     199          1
# 221554         1           4     219          1
#
# [221555 rows x 4 columns]

# %%
Y_smote = Y_smote.reset_index(drop=True)

ls = []

for s in Y_smote.astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(Y_smote)), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y_smote = ll.values

Y_smote
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
# data.index[data['leap_year'] == 1].tolist()
# data.index[data['leap_year'] == 1]

# %%
# for i,idx in enumerate(data['leap_year'].tolist()):
#     print(i, idx)

# %% [markdown]
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1 <---
# 5 0
# 6 0
# 7 0
# 8 1 <---
# 9 0
# 10 0
# 11 0
# 12 1 <---
# 13 0
# 14 0
# 15 0
# 16 1 <---
# 17 0
# 18 0
# 19 0
# 20 1 <---
# 21 0
# 22 0
# 23 0
# 24 1 <---
# 25 0
# 26 0
# 27 0
# 28 1 <---
# 29 0
# 30 0

# %%
scaler_day_smote = RobustScaler()

x = X_smote.day_code.values.reshape(-1, 1)

X_smote['day_scaled'] = scaler_day_smote.fit_transform(x).flatten()

# %%
X_smote['day_sin'] = np.sin(X_smote['day_code'] * (2 * np.pi / 7))
X_smote['day_cos'] = np.cos(X_smote['day_code'] * (2 * np.pi / 7))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos
# 0      -0.900969
# 1      -0.222521
# 2       0.623490
# 3       1.000000
# 4       0.623490
# ...          ...
# 221550  1.000000
# 221551 -0.222521
# 221552 -0.222521
# 221553  0.623490
# 221554  0.623490
#
# [221555 rows x 7 columns]

# %%
scaler_month_smote = RobustScaler()

x = X_smote.month_code.values.reshape(-1, 1)

X_smote['month_scaled'] = scaler_month_smote.fit_transform(x).flatten()

# %%
X_smote['month_sin'] = np.sin(X_smote['month_code'] * (2 * np.pi / 12))
X_smote['month_cos'] = np.cos(X_smote['month_code'] * (2 * np.pi / 12))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos
# 0      -0.900969     -1.000000  0.000000e+00   1.000000
# 1      -0.222521     -1.000000  0.000000e+00   1.000000
# 2       0.623490     -1.000000  0.000000e+00   1.000000
# 3       1.000000     -1.000000  0.000000e+00   1.000000
# 4       0.623490     -1.000000  0.000000e+00   1.000000
# ...          ...           ...           ...        ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000
#
# [221555 rows x 10 columns]

# %%
scaler_decade_smote = RobustScaler()

x = X_smote.decade.values.reshape(-1, 1)

X_smote['decade_scaled'] = scaler_decade_smote.fit_transform(x).flatten()

# %%
# alpha_smote = len(X_smote.decade.unique())
alpha_smote = (X_smote.decade.iloc[-1] - X_smote.decade.iloc[0]) + 1

X_smote['decade_sin'] = np.sin(X_smote['decade'] * (2 * np.pi / alpha_smote))
X_smote['decade_cos'] = np.cos(X_smote['decade'] * (2 * np.pi / alpha_smote))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos  decade_scaled  \
# 0      -0.900969     -1.000000  0.000000e+00   1.000000      -1.052632
# 1      -0.222521     -1.000000  0.000000e+00   1.000000      -1.052632
# 2       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# 3       1.000000     -1.000000  0.000000e+00   1.000000      -1.052632
# 4       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# ...          ...           ...           ...        ...            ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025      -0.631579
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000      -0.631579
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000       0.947368
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025      -0.052632
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000       1.000000
#
#           decade_sin  decade_cos
# 0       1.102182e-15   -1.000000
# 1       1.102182e-15   -1.000000
# 2       1.102182e-15   -1.000000
# 3       1.102182e-15   -1.000000
# 4       1.102182e-15   -1.000000
# ...              ...         ...
# 221550 -9.510565e-01   -0.309017
# 221551 -9.510565e-01   -0.309017
# 221552  3.090170e-01   -0.951057
# 221553 -1.564345e-01    0.987688
# 221554  1.564345e-01   -0.987688
#
# [221555 rows x 13 columns]

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
X = X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 3.33333333e-01, -4.33883739e-01, -9.00968868e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 1.00000000e+00, -7.81831482e-01,  6.23489802e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        ...,
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#          9.47368421e-01,  3.09016994e-01, -9.51056516e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#         -5.26315789e-02, -1.56434465e-01,  9.87688341e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#          1.00000000e+00,  1.56434465e-01, -9.87688341e-01]])

# %%
X.shape
# Out:
# (221555, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()
# Y = data['date_normalized'].values.reshape(-1, 1)
Y = Y_smote


Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
Y.shape
# Out:
# (221555, 8)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64

train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (221555, 10)
#
# Y: (221555, 8)
#
# Train data:   (155088, 10)
#
# Train labels: (155088, 8)
#
# Test data:    (66467, 10)
#
# Test labels:  (66467, 8)

# %%
model_smote = Model().to(device)


checkpoint = torch.load('checkpoint.pth.tar', map_location=torch.device('cpu'))

model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
# Out:
# <All keys matched successfully>

# %%
# numepochs = 120
numepochs = 300


trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model_smote, numepochs)
# Out:
# Epoch 1/300, Train Loss: 1.934235, Test Loss: 4.315057
# Epoch 2/300, Train Loss: 1.938152, Test Loss: 4.123538
# Epoch 3/300, Train Loss: 1.950913, Test Loss: 4.167860
# Epoch 4/300, Train Loss: 2.000391, Test Loss: 4.189663
# Epoch 5/300, Train Loss: 1.963698, Test Loss: 4.153986
# Epoch 6/300, Train Loss: 1.969789, Test Loss: 4.226395
# Epoch 7/300, Train Loss: 1.941373, Test Loss: 4.141820
# Epoch 8/300, Train Loss: 1.941219, Test Loss: 4.129520
# Epoch 9/300, Train Loss: 1.927571, Test Loss: 4.309091
# Epoch 10/300, Train Loss: 1.933017, Test Loss: 4.122548
# Epoch 11/300, Train Loss: 1.948731, Test Loss: 4.260571
# Epoch 12/300, Train Loss: 1.932671, Test Loss: 4.235303
# Epoch 13/300, Train Loss: 1.985273, Test Loss: 4.130060
# Epoch 14/300, Train Loss: 2.004684, Test Loss: 4.565996
# Epoch 15/300, Train Loss: 1.950844, Test Loss: 4.137524
# Epoch 16/300, Train Loss: 1.941761, Test Loss: 4.233981
# Epoch 17/300, Train Loss: 2.010612, Test Loss: 4.205883
# Epoch 18/300, Train Loss: 1.949777, Test Loss: 4.276497
# Epoch 19/300, Train Loss: 1.944240, Test Loss: 4.416866
# Epoch 20/300, Train Loss: 1.979538, Test Loss: 4.581082
# Epoch 21/300, Train Loss: 1.951620, Test Loss: 4.167274
# Epoch 22/300, Train Loss: 1.940462, Test Loss: 4.324319
# Epoch 23/300, Train Loss: 1.953789, Test Loss: 4.189823
# Epoch 24/300, Train Loss: 2.031352, Test Loss: 4.355088
# Epoch 25/300, Train Loss: 1.979873, Test Loss: 4.140134
# Epoch 26/300, Train Loss: 1.980559, Test Loss: 4.290954
# Epoch 27/300, Train Loss: 2.117959, Test Loss: 4.199951
# Epoch 28/300, Train Loss: 1.991634, Test Loss: 4.104665
# Epoch 29/300, Train Loss: 1.993495, Test Loss: 4.314914
# Epoch 30/300, Train Loss: 1.942606, Test Loss: 4.364533
# Epoch 31/300, Train Loss: 1.946025, Test Loss: 4.166582
# Epoch 32/300, Train Loss: 1.942667, Test Loss: 4.274548
# Epoch 33/300, Train Loss: 1.934885, Test Loss: 4.131398
# Epoch 34/300, Train Loss: 1.970895, Test Loss: 4.463147
# Epoch 35/300, Train Loss: 1.948278, Test Loss: 4.496148
# Epoch 36/300, Train Loss: 1.992678, Test Loss: 4.342130
# Epoch 37/300, Train Loss: 1.947773, Test Loss: 4.235996
# Epoch 38/300, Train Loss: 1.939511, Test Loss: 4.286090
# Epoch 39/300, Train Loss: 1.935392, Test Loss: 4.457297
# Epoch 40/300, Train Loss: 1.946712, Test Loss: 4.312360
# Epoch 41/300, Train Loss: 1.952645, Test Loss: 4.290482
# Epoch 42/300, Train Loss: 1.971052, Test Loss: 4.136119
# Epoch 43/300, Train Loss: 1.952983, Test Loss: 4.188962
# Epoch 44/300, Train Loss: 1.937429, Test Loss: 4.220263
# Epoch 45/300, Train Loss: 1.931045, Test Loss: 4.367093
# Epoch 46/300, Train Loss: 1.926890, Test Loss: 4.161168
# Epoch 47/300, Train Loss: 1.938202, Test Loss: 4.316652
# Epoch 48/300, Train Loss: 1.949533, Test Loss: 4.146361
# Epoch 49/300, Train Loss: 1.941504, Test Loss: 4.208189
# Epoch 50/300, Train Loss: 1.928838, Test Loss: 4.252245
# Epoch 51/300, Train Loss: 1.945171, Test Loss: 4.340532
# Epoch 52/300, Train Loss: 1.962525, Test Loss: 4.164552
# Epoch 53/300, Train Loss: 1.959120, Test Loss: 4.176557
# Epoch 54/300, Train Loss: 1.937371, Test Loss: 4.548166
# Epoch 55/300, Train Loss: 1.942891, Test Loss: 4.302147
# Epoch 56/300, Train Loss: 1.955812, Test Loss: 4.208943
# Epoch 57/300, Train Loss: 1.924068, Test Loss: 4.189545
# Epoch 58/300, Train Loss: 1.927649, Test Loss: 4.278489
# Epoch 59/300, Train Loss: 1.972488, Test Loss: 4.130314
# Epoch 60/300, Train Loss: 1.955868, Test Loss: 4.235175
# Epoch 61/300, Train Loss: 1.946457, Test Loss: 4.135075
# Epoch 62/300, Train Loss: 1.979687, Test Loss: 4.113118
# Epoch 63/300, Train Loss: 1.960683, Test Loss: 4.242467
# Epoch 64/300, Train Loss: 1.936219, Test Loss: 4.113446
# Epoch 65/300, Train Loss: 1.942745, Test Loss: 4.112340
# Epoch 66/300, Train Loss: 1.951480, Test Loss: 4.341563
# Epoch 67/300, Train Loss: 1.926924, Test Loss: 4.305826
# Epoch 68/300, Train Loss: 1.931569, Test Loss: 4.195660
# Epoch 69/300, Train Loss: 1.983795, Test Loss: 4.108088
# Epoch 70/300, Train Loss: 1.945745, Test Loss: 4.412663
# Epoch 71/300, Train Loss: 1.938375, Test Loss: 4.303117
# Epoch 72/300, Train Loss: 1.933676, Test Loss: 4.109381
# Epoch 73/300, Train Loss: 1.921018, Test Loss: 4.352924
# Epoch 74/300, Train Loss: 1.957725, Test Loss: 4.172178
# Epoch 75/300, Train Loss: 1.945498, Test Loss: 4.176620
# Epoch 76/300, Train Loss: 1.966208, Test Loss: 4.031487
# Epoch 77/300, Train Loss: 1.952656, Test Loss: 4.114851
# Epoch 78/300, Train Loss: 1.939804, Test Loss: 4.505609
# Epoch 79/300, Train Loss: 1.956141, Test Loss: 4.347369
# Epoch 80/300, Train Loss: 1.952436, Test Loss: 4.137532
# Epoch 81/300, Train Loss: 1.941680, Test Loss: 4.210767
# Epoch 82/300, Train Loss: 1.955425, Test Loss: 4.106006
# Epoch 83/300, Train Loss: 1.959412, Test Loss: 4.121616
# Epoch 84/300, Train Loss: 1.935789, Test Loss: 4.443213
# Epoch 85/300, Train Loss: 1.958992, Test Loss: 4.356363
# Epoch 86/300, Train Loss: 1.955367, Test Loss: 4.386531
# Epoch 87/300, Train Loss: 2.014544, Test Loss: 4.202502
# Epoch 88/300, Train Loss: 1.944859, Test Loss: 4.402705
# Epoch 89/300, Train Loss: 1.975833, Test Loss: 4.175165
# Epoch 90/300, Train Loss: 1.945694, Test Loss: 4.134904
# Epoch 91/300, Train Loss: 1.948699, Test Loss: 4.175243
# Epoch 92/300, Train Loss: 1.938630, Test Loss: 4.140306
# Epoch 93/300, Train Loss: 1.940831, Test Loss: 4.204474
# Epoch 94/300, Train Loss: 1.952619, Test Loss: 4.443390
# Epoch 95/300, Train Loss: 1.957348, Test Loss: 4.396081
# Epoch 96/300, Train Loss: 1.953179, Test Loss: 4.185264
# Epoch 97/300, Train Loss: 1.942617, Test Loss: 4.141287
# Epoch 98/300, Train Loss: 1.946180, Test Loss: 4.176200
# Epoch 99/300, Train Loss: 1.953452, Test Loss: 4.587068
# Epoch 100/300, Train Loss: 1.924382, Test Loss: 4.145003
# Epoch 101/300, Train Loss: 1.940597, Test Loss: 4.145352
# Epoch 102/300, Train Loss: 1.961771, Test Loss: 4.186489
# Epoch 103/300, Train Loss: 1.946585, Test Loss: 4.185860
# Epoch 104/300, Train Loss: 1.955325, Test Loss: 4.181907
# Epoch 105/300, Train Loss: 1.941989, Test Loss: 4.209940
# Epoch 106/300, Train Loss: 1.940188, Test Loss: 4.229246
# Epoch 107/300, Train Loss: 1.953118, Test Loss: 4.109495
# Epoch 108/300, Train Loss: 1.948148, Test Loss: 4.131650
# Epoch 109/300, Train Loss: 1.942587, Test Loss: 4.384082
# Epoch 110/300, Train Loss: 1.938968, Test Loss: 4.508060
# Epoch 111/300, Train Loss: 1.924440, Test Loss: 4.126891
# Epoch 112/300, Train Loss: 1.914902, Test Loss: 4.098998
# Epoch 113/300, Train Loss: 1.931917, Test Loss: 4.200901
# Epoch 114/300, Train Loss: 1.955897, Test Loss: 4.087300
# Epoch 115/300, Train Loss: 1.935956, Test Loss: 4.132861
# Epoch 116/300, Train Loss: 1.924436, Test Loss: 4.318745
# Epoch 117/300, Train Loss: 1.928988, Test Loss: 4.148718
# Epoch 118/300, Train Loss: 1.913248, Test Loss: 4.109518
# Epoch 119/300, Train Loss: 2.004186, Test Loss: 4.180184
# Epoch 120/300, Train Loss: 1.999247, Test Loss: 4.801521
# Epoch 121/300, Train Loss: 1.941803, Test Loss: 4.327220
# Epoch 122/300, Train Loss: 1.957983, Test Loss: 4.395545
# Epoch 123/300, Train Loss: 2.012894, Test Loss: 4.190242
# Epoch 124/300, Train Loss: 1.941973, Test Loss: 4.193069
# Epoch 125/300, Train Loss: 1.926179, Test Loss: 4.163244
# Epoch 126/300, Train Loss: 1.917144, Test Loss: 4.181509
# Epoch 127/300, Train Loss: 1.953647, Test Loss: 4.354674
# Epoch 128/300, Train Loss: 1.940091, Test Loss: 4.406359
# Epoch 129/300, Train Loss: 1.917684, Test Loss: 4.222085
# Epoch 130/300, Train Loss: 1.950778, Test Loss: 4.529598
# Epoch 131/300, Train Loss: 1.939268, Test Loss: 4.473734
# Epoch 132/300, Train Loss: 1.922047, Test Loss: 4.206453
# Epoch 133/300, Train Loss: 1.957673, Test Loss: 4.173817
# Epoch 134/300, Train Loss: 1.970883, Test Loss: 4.360093
# Epoch 135/300, Train Loss: 1.911260, Test Loss: 4.213389
# Epoch 136/300, Train Loss: 1.938836, Test Loss: 4.162035
# Epoch 137/300, Train Loss: 1.941656, Test Loss: 4.177076
# Epoch 138/300, Train Loss: 1.934107, Test Loss: 4.447769
# Epoch 139/300, Train Loss: 1.939135, Test Loss: 4.251061
# Epoch 140/300, Train Loss: 1.936861, Test Loss: 4.472434
# Epoch 141/300, Train Loss: 1.948084, Test Loss: 4.148881
# Epoch 142/300, Train Loss: 1.924943, Test Loss: 4.103003
# Epoch 143/300, Train Loss: 1.950769, Test Loss: 4.404148
# Epoch 144/300, Train Loss: 2.181486, Test Loss: 5.056933
# Epoch 145/300, Train Loss: 1.960190, Test Loss: 4.129976
# Epoch 146/300, Train Loss: 1.932774, Test Loss: 4.177772
# Epoch 147/300, Train Loss: 1.910607, Test Loss: 4.125108
# Epoch 148/300, Train Loss: 1.909985, Test Loss: 4.133384
# Epoch 149/300, Train Loss: 1.953525, Test Loss: 4.212299
# Epoch 150/300, Train Loss: 1.927525, Test Loss: 4.131360
# Epoch 151/300, Train Loss: 1.949829, Test Loss: 4.134274
# Epoch 152/300, Train Loss: 1.924423, Test Loss: 4.171175
# Epoch 153/300, Train Loss: 1.980309, Test Loss: 4.313339
# Epoch 154/300, Train Loss: 1.937705, Test Loss: 4.288947
# Epoch 155/300, Train Loss: 1.941417, Test Loss: 4.237237
# Epoch 156/300, Train Loss: 1.928689, Test Loss: 4.113735
# Epoch 157/300, Train Loss: 1.926324, Test Loss: 4.155177
# Epoch 158/300, Train Loss: 1.963266, Test Loss: 4.344557
# Epoch 159/300, Train Loss: 1.934171, Test Loss: 4.115419
# Epoch 160/300, Train Loss: 2.005339, Test Loss: 4.231895
# Epoch 161/300, Train Loss: 1.933738, Test Loss: 4.408986
# Epoch 162/300, Train Loss: 1.939585, Test Loss: 4.129757
# Epoch 163/300, Train Loss: 1.933818, Test Loss: 4.094497
# Epoch 164/300, Train Loss: 1.932059, Test Loss: 4.279026
# Epoch 165/300, Train Loss: 1.941992, Test Loss: 4.209024
# Epoch 166/300, Train Loss: 1.930318, Test Loss: 4.116205
# Epoch 167/300, Train Loss: 1.922102, Test Loss: 4.139755
# Epoch 168/300, Train Loss: 1.920899, Test Loss: 4.338897
# Epoch 169/300, Train Loss: 1.928257, Test Loss: 4.138749
# Epoch 170/300, Train Loss: 2.009191, Test Loss: 4.396507
# Epoch 171/300, Train Loss: 1.981530, Test Loss: 4.145802
# Epoch 172/300, Train Loss: 1.914666, Test Loss: 4.564613
# Epoch 173/300, Train Loss: 1.932076, Test Loss: 4.127078
# Epoch 174/300, Train Loss: 1.925755, Test Loss: 4.148491
# Epoch 175/300, Train Loss: 1.935861, Test Loss: 4.134395
# Epoch 176/300, Train Loss: 2.029351, Test Loss: 4.129056
# Epoch 177/300, Train Loss: 1.944633, Test Loss: 4.167100
# Epoch 178/300, Train Loss: 2.010516, Test Loss: 4.181326
# Epoch 179/300, Train Loss: 1.904732, Test Loss: 4.146422
# Epoch 180/300, Train Loss: 1.964756, Test Loss: 4.153088
# Epoch 181/300, Train Loss: 1.940345, Test Loss: 4.116380
# Epoch 182/300, Train Loss: 1.922831, Test Loss: 4.174417
# Epoch 183/300, Train Loss: 1.968719, Test Loss: 4.509685
# Epoch 184/300, Train Loss: 1.917199, Test Loss: 4.259064
# Epoch 185/300, Train Loss: 2.003986, Test Loss: 4.157412
# Epoch 186/300, Train Loss: 1.953201, Test Loss: 4.136751
# Epoch 187/300, Train Loss: 1.937019, Test Loss: 4.150552
# Epoch 188/300, Train Loss: 1.944232, Test Loss: 4.212109
# Epoch 189/300, Train Loss: 1.937626, Test Loss: 4.203761
# Epoch 190/300, Train Loss: 1.952363, Test Loss: 4.188787
# Epoch 191/300, Train Loss: 1.954981, Test Loss: 4.532603
# Epoch 192/300, Train Loss: 1.925535, Test Loss: 4.106710
# Epoch 193/300, Train Loss: 1.944034, Test Loss: 4.084881
# Epoch 194/300, Train Loss: 1.929012, Test Loss: 4.364036
# Epoch 195/300, Train Loss: 1.910421, Test Loss: 4.111165
# Epoch 196/300, Train Loss: 2.037302, Test Loss: 4.113947
# Epoch 197/300, Train Loss: 1.971083, Test Loss: 4.155252
# Epoch 198/300, Train Loss: 2.109884, Test Loss: 4.780540
# Epoch 199/300, Train Loss: 1.971239, Test Loss: 4.320199
# Epoch 200/300, Train Loss: 1.925844, Test Loss: 4.172475
# Epoch 201/300, Train Loss: 1.941502, Test Loss: 4.194067
# Epoch 202/300, Train Loss: 1.943894, Test Loss: 4.093839
# Epoch 203/300, Train Loss: 1.930122, Test Loss: 4.397311
# Epoch 204/300, Train Loss: 1.933813, Test Loss: 4.157024
# Epoch 205/300, Train Loss: 1.929854, Test Loss: 4.200670
# Epoch 206/300, Train Loss: 2.004014, Test Loss: 4.674902
# Epoch 207/300, Train Loss: 1.979524, Test Loss: 4.191891
# Epoch 208/300, Train Loss: 1.934973, Test Loss: 4.128205
# Epoch 209/300, Train Loss: 1.939568, Test Loss: 4.211499
# Epoch 210/300, Train Loss: 2.197720, Test Loss: 4.648440
# Epoch 211/300, Train Loss: 1.939556, Test Loss: 4.105529
# Epoch 212/300, Train Loss: 1.932341, Test Loss: 4.154015
# Epoch 213/300, Train Loss: 2.115311, Test Loss: 4.722510
# Epoch 214/300, Train Loss: 1.962105, Test Loss: 4.053225
# Epoch 215/300, Train Loss: 2.305016, Test Loss: 4.272662
# Epoch 216/300, Train Loss: 1.925435, Test Loss: 4.048249
# Epoch 217/300, Train Loss: 1.937451, Test Loss: 4.069373
# Epoch 218/300, Train Loss: 1.929067, Test Loss: 4.090811
# Epoch 219/300, Train Loss: 1.936033, Test Loss: 4.123697
# Epoch 220/300, Train Loss: 1.929963, Test Loss: 4.082637
# Epoch 221/300, Train Loss: 1.939283, Test Loss: 4.136502
# Epoch 222/300, Train Loss: 1.948342, Test Loss: 4.249022
# Epoch 223/300, Train Loss: 1.938499, Test Loss: 4.259012
# Epoch 224/300, Train Loss: 2.068723, Test Loss: 4.365267
# Epoch 225/300, Train Loss: 2.024452, Test Loss: 4.215042
# Epoch 226/300, Train Loss: 1.952834, Test Loss: 4.330964
# Epoch 227/300, Train Loss: 1.958982, Test Loss: 4.560985
# Epoch 228/300, Train Loss: 1.984920, Test Loss: 4.372487
# Epoch 229/300, Train Loss: 1.938732, Test Loss: 4.140421
# Epoch 230/300, Train Loss: 1.941403, Test Loss: 4.132496
# Epoch 231/300, Train Loss: 1.961219, Test Loss: 4.092698
# Epoch 232/300, Train Loss: 1.938902, Test Loss: 4.165724
# Epoch 233/300, Train Loss: 1.940331, Test Loss: 4.083864
# Epoch 234/300, Train Loss: 1.922499, Test Loss: 4.262532
# Epoch 235/300, Train Loss: 2.007790, Test Loss: 4.076257
# Epoch 236/300, Train Loss: 1.992356, Test Loss: 4.330500
# Epoch 237/300, Train Loss: 1.930611, Test Loss: 4.088860
# Epoch 238/300, Train Loss: 1.958791, Test Loss: 4.609773
# Epoch 239/300, Train Loss: 1.947052, Test Loss: 4.309576
# Epoch 240/300, Train Loss: 2.523009, Test Loss: 4.723630
# Epoch 241/300, Train Loss: 1.938737, Test Loss: 4.110635
# Epoch 242/300, Train Loss: 2.194036, Test Loss: 4.188700
# Epoch 243/300, Train Loss: 1.955857, Test Loss: 4.123236
# Epoch 244/300, Train Loss: 1.926031, Test Loss: 4.078194
# Epoch 245/300, Train Loss: 1.925369, Test Loss: 4.168715
# Epoch 246/300, Train Loss: 1.929576, Test Loss: 4.239920
# Epoch 247/300, Train Loss: 1.937175, Test Loss: 4.075141
# Epoch 248/300, Train Loss: 1.986815, Test Loss: 4.204823
# Epoch 249/300, Train Loss: 1.951891, Test Loss: 4.120366
# Epoch 250/300, Train Loss: 1.936712, Test Loss: 4.320229
# Epoch 251/300, Train Loss: 1.933528, Test Loss: 4.124704
# Epoch 252/300, Train Loss: 1.932268, Test Loss: 4.132666
# Epoch 253/300, Train Loss: 2.105503, Test Loss: 4.197828
# Epoch 254/300, Train Loss: 1.973213, Test Loss: 4.555721
# Epoch 255/300, Train Loss: 1.962376, Test Loss: 4.392074
# Epoch 256/300, Train Loss: 1.945628, Test Loss: 4.192496
# Epoch 257/300, Train Loss: 1.926729, Test Loss: 4.159631
# Epoch 258/300, Train Loss: 1.918802, Test Loss: 4.166531
# Epoch 259/300, Train Loss: 1.952037, Test Loss: 4.201910
# Epoch 260/300, Train Loss: 1.939934, Test Loss: 4.213796
# Epoch 261/300, Train Loss: 1.943318, Test Loss: 4.158479
# Epoch 262/300, Train Loss: 1.936638, Test Loss: 4.139697
# Epoch 263/300, Train Loss: 1.943161, Test Loss: 4.167572
# Epoch 264/300, Train Loss: 1.946550, Test Loss: 4.351976
# Epoch 265/300, Train Loss: 1.967738, Test Loss: 4.052252
# Epoch 266/300, Train Loss: 1.935946, Test Loss: 4.153330
# Epoch 267/300, Train Loss: 1.937197, Test Loss: 4.113454
# Epoch 268/300, Train Loss: 1.947633, Test Loss: 4.155112
# Epoch 269/300, Train Loss: 1.936979, Test Loss: 4.169249
# Epoch 270/300, Train Loss: 1.952842, Test Loss: 4.161577
# Epoch 271/300, Train Loss: 1.938982, Test Loss: 4.166157
# Epoch 272/300, Train Loss: 1.925888, Test Loss: 4.052296
# Epoch 273/300, Train Loss: 1.925322, Test Loss: 4.104420
# Epoch 274/300, Train Loss: 1.930469, Test Loss: 4.107471
# Epoch 275/300, Train Loss: 1.929538, Test Loss: 4.230606
# Epoch 276/300, Train Loss: 1.928653, Test Loss: 4.180345
# Epoch 277/300, Train Loss: 1.928811, Test Loss: 4.176820
# Epoch 278/300, Train Loss: 1.973103, Test Loss: 4.221283
# Epoch 279/300, Train Loss: 1.922725, Test Loss: 4.384062
# Epoch 280/300, Train Loss: 1.935029, Test Loss: 4.052546
# Epoch 281/300, Train Loss: 1.942034, Test Loss: 4.390188
# Epoch 282/300, Train Loss: 1.965191, Test Loss: 4.097426
# Epoch 283/300, Train Loss: 1.931697, Test Loss: 4.259817
# Epoch 284/300, Train Loss: 1.931525, Test Loss: 4.349670
# Epoch 285/300, Train Loss: 1.927376, Test Loss: 4.163227
# Epoch 286/300, Train Loss: 1.937139, Test Loss: 4.161483
# Epoch 287/300, Train Loss: 1.937229, Test Loss: 4.303676
# Epoch 288/300, Train Loss: 1.951123, Test Loss: 4.099110
# Epoch 289/300, Train Loss: 2.015001, Test Loss: 4.163378
# Epoch 290/300, Train Loss: 1.932333, Test Loss: 4.110457
# Epoch 291/300, Train Loss: 1.950315, Test Loss: 4.164085
# Epoch 292/300, Train Loss: 1.955404, Test Loss: 4.280519
# Epoch 293/300, Train Loss: 1.941106, Test Loss: 4.243507
# Epoch 294/300, Train Loss: 1.933683, Test Loss: 4.487433
# Epoch 295/300, Train Loss: 1.923686, Test Loss: 4.090483
# Epoch 296/300, Train Loss: 1.921611, Test Loss: 4.159240
# Epoch 297/300, Train Loss: 1.915954, Test Loss: 4.163211
# Epoch 298/300, Train Loss: 1.917948, Test Loss: 4.338063
# Epoch 299/300, Train Loss: 1.955085, Test Loss: 4.089924
# Epoch 300/300, Train Loss: 1.983982, Test Loss: 4.336867

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([2.2549, 2.2552, 2.2523, 2.2531, 2.2496, 2.2517, 2.2510, 2.2545, 2.2498,
#          2.2514, 2.2486, 2.2525, 2.2474, 2.2484, 2.2481, 2.2500, 2.2523, 2.2506,
#          2.2524, 2.2539, 2.2539, 2.2536, 2.2512, 2.2504, 2.2478, 2.2575, 2.2545,
#          2.2533, 2.2535, 2.2517, 2.2518, 2.2484, 2.2533, 2.2538, 2.2440, 2.2559,
#          2.2466, 2.2451, 2.2490, 2.2602, 2.2491, 2.2472, 2.2496, 2.2514, 2.2523,
#          2.2509, 2.2491, 2.2448, 2.2489, 2.2482, 2.2504, 2.2498, 2.2483, 2.2467,
#          2.2439, 2.2505, 2.2456, 2.2456, 2.2473, 2.2488, 2.2493, 2.2437, 2.2425,
#          2.2384, 2.2483, 2.2522, 2.2424, 2.2473, 2.2472, 2.2394, 2.2468, 2.2480,
#          2.2486, 2.2485, 2.2437, 2.2443, 2.2417, 2.2489, 2.2464, 2.2402, 2.2532,
#          2.2399, 2.2547, 2.2418, 2.2430, 2.2439, 2.2517, 2.2448, 2.2502, 2.2446,
#          2.2468, 2.2416, 2.2455, 2.2532, 2.2422, 2.2514, 2.2482, 2.2477, 2.2412,
#          2.2474, 2.2452, 2.2468, 2.2558, 2.2478, 2.2510, 2.2495, 2.2475, 2.2431,
#          2.2422, 2.2397, 2.2408, 2.2406, 2.2376, 2.2466, 2.2404, 2.2392, 2.2394,
#          2.2438, 2.2447, 2.2429, 2.2365, 2.2434, 2.2421, 2.2395, 2.2422, 2.2471,
#          2.2450, 2.2488, 2.2480, 2.2405, 2.2555, 2.2418, 2.2432, 2.2447, 2.2421,
#          2.2391, 2.2449, 2.2447, 2.2372, 2.2400, 2.2553, 2.2421, 2.2430, 2.2427,
#          2.2414, 2.2432, 2.2380, 2.2400, 2.2465, 2.2385, 2.2461, 2.2407, 2.2420,
#          2.2393, 2.2337, 2.2400, 2.2458, 2.2378, 2.2422, 2.2396, 2.2429, 2.2466,
#          2.2376, 2.2410, 2.2366, 2.2406, 2.2417, 2.2382, 2.2416, 2.2410, 2.2342,
#          2.2412, 2.2352, 2.2378, 2.2459, 2.2342, 2.2385, 2.2396, 2.2329, 2.2461,
#          2.2473, 2.2404, 2.2455, 2.2358, 2.2479, 2.2421, 2.2359, 2.2410, 2.2437,
#          2.2402, 2.2383, 2.2387, 2.2370, 2.2427, 2.2383, 2.2426, 2.2408, 2.2385,
#          2.2471, 2.2424, 2.2365, 2.2456, 2.2448, 2.2393, 2.2410, 2.2413, 2.2351,
#          2.2377, 2.2470, 2.2432, 2.2451, 2.2405, 2.2481, 2.2456, 2.2406, 2.2405,
#          2.2409, 2.2419, 2.2531, 2.2419, 2.2408, 2.2469, 2.2422, 2.2460, 2.2388,
#          2.2443, 2.2417, 2.2416, 2.2410, 2.2427, 2.2445, 2.2363, 2.2455, 2.2450,
#          2.2412, 2.2480, 2.2475, 2.2467, 2.2429, 2.2470, 2.2423, 2.2431, 2.2396,
#          2.2381, 2.2452, 2.2394, 2.2434, 2.2376, 2.2479, 2.2412, 2.2436, 2.2432,
#          2.2430, 2.2475, 2.2408, 2.2427, 2.2445, 2.2437, 2.2342, 2.2407, 2.2454,
#          2.2456, 2.2418, 2.2434, 2.2479, 2.2429, 2.2456, 2.2443, 2.2422, 2.2444,
#          2.2407, 2.2429, 2.2419, 2.2454, 2.2401, 2.2451, 2.2422, 2.2443, 2.2418,
#          2.2355, 2.2475, 2.2481, 2.2382, 2.2436, 2.2379, 2.2426, 2.2423, 2.2451,
#          2.2434, 2.2389, 2.2344, 2.2447, 2.2438, 2.2442, 2.2398, 2.2478, 2.2441,
#          2.2437, 2.2394, 2.2426]),
#  tensor([4.3151, 4.1235, 4.1679, 4.1897, 4.1540, 4.2264, 4.1418, 4.1295, 4.3091,
#          4.1225, 4.2606, 4.2353, 4.1301, 4.5660, 4.1375, 4.2340, 4.2059, 4.2765,
#          4.4169, 4.5811, 4.1673, 4.3243, 4.1898, 4.3551, 4.1401, 4.2910, 4.2000,
#          4.1047, 4.3149, 4.3645, 4.1666, 4.2745, 4.1314, 4.4631, 4.4961, 4.3421,
#          4.2360, 4.2861, 4.4573, 4.3124, 4.2905, 4.1361, 4.1890, 4.2203, 4.3671,
#          4.1612, 4.3167, 4.1464, 4.2082, 4.2522, 4.3405, 4.1646, 4.1766, 4.5482,
#          4.3021, 4.2089, 4.1895, 4.2785, 4.1303, 4.2352, 4.1351, 4.1131, 4.2425,
#          4.1134, 4.1123, 4.3416, 4.3058, 4.1957, 4.1081, 4.4127, 4.3031, 4.1094,
#          4.3529, 4.1722, 4.1766, 4.0315, 4.1149, 4.5056, 4.3474, 4.1375, 4.2108,
#          4.1060, 4.1216, 4.4432, 4.3564, 4.3865, 4.2025, 4.4027, 4.1752, 4.1349,
#          4.1752, 4.1403, 4.2045, 4.4434, 4.3961, 4.1853, 4.1413, 4.1762, 4.5871,
#          4.1450, 4.1454, 4.1865, 4.1859, 4.1819, 4.2099, 4.2292, 4.1095, 4.1317,
#          4.3841, 4.5081, 4.1269, 4.0990, 4.2009, 4.0873, 4.1329, 4.3187, 4.1487,
#          4.1095, 4.1802, 4.8015, 4.3272, 4.3955, 4.1902, 4.1931, 4.1632, 4.1815,
#          4.3547, 4.4064, 4.2221, 4.5296, 4.4737, 4.2065, 4.1738, 4.3601, 4.2134,
#          4.1620, 4.1771, 4.4478, 4.2511, 4.4724, 4.1489, 4.1030, 4.4041, 5.0569,
#          4.1300, 4.1778, 4.1251, 4.1334, 4.2123, 4.1314, 4.1343, 4.1712, 4.3133,
#          4.2889, 4.2372, 4.1137, 4.1552, 4.3446, 4.1154, 4.2319, 4.4090, 4.1298,
#          4.0945, 4.2790, 4.2090, 4.1162, 4.1398, 4.3389, 4.1387, 4.3965, 4.1458,
#          4.5646, 4.1271, 4.1485, 4.1344, 4.1291, 4.1671, 4.1813, 4.1464, 4.1531,
#          4.1164, 4.1744, 4.5097, 4.2591, 4.1574, 4.1368, 4.1506, 4.2121, 4.2038,
#          4.1888, 4.5326, 4.1067, 4.0849, 4.3640, 4.1112, 4.1139, 4.1553, 4.7805,
#          4.3202, 4.1725, 4.1941, 4.0938, 4.3973, 4.1570, 4.2007, 4.6749, 4.1919,
#          4.1282, 4.2115, 4.6484, 4.1055, 4.1540, 4.7225, 4.0532, 4.2727, 4.0482,
#          4.0694, 4.0908, 4.1237, 4.0826, 4.1365, 4.2490, 4.2590, 4.3653, 4.2150,
#          4.3310, 4.5610, 4.3725, 4.1404, 4.1325, 4.0927, 4.1657, 4.0839, 4.2625,
#          4.0763, 4.3305, 4.0889, 4.6098, 4.3096, 4.7236, 4.1106, 4.1887, 4.1232,
#          4.0782, 4.1687, 4.2399, 4.0751, 4.2048, 4.1204, 4.3202, 4.1247, 4.1327,
#          4.1978, 4.5557, 4.3921, 4.1925, 4.1596, 4.1665, 4.2019, 4.2138, 4.1585,
#          4.1397, 4.1676, 4.3520, 4.0523, 4.1533, 4.1135, 4.1551, 4.1692, 4.1616,
#          4.1662, 4.0523, 4.1044, 4.1075, 4.2306, 4.1803, 4.1768, 4.2213, 4.3841,
#          4.0525, 4.3902, 4.0974, 4.2598, 4.3497, 4.1632, 4.1615, 4.3037, 4.0991,
#          4.1634, 4.1105, 4.1641, 4.2805, 4.2435, 4.4874, 4.0905, 4.1592, 4.1632,
#          4.3381, 4.0899, 4.3369]),
#  tensor([0.5214, 0.5208, 0.5213, 0.5208, 0.5213, 0.5210, 0.5214, 0.5209, 0.5217,
#          0.5209, 0.5213, 0.5206, 0.5215, 0.5208, 0.5209, 0.5213, 0.5208, 0.5205,
#          0.5210, 0.5210, 0.5210, 0.5211, 0.5208, 0.5214, 0.5217, 0.5204, 0.5207,
#          0.5209, 0.5210, 0.5210, 0.5208, 0.5217, 0.5212, 0.5211, 0.5222, 0.5187,
#          0.5199, 0.5198, 0.5204, 0.5207, 0.5221, 0.5217, 0.5213, 0.5215, 0.5211,
#          0.5216, 0.5238, 0.5276, 0.5277, 0.5279, 0.5276, 0.5273, 0.5278, 0.5281,
#          0.5287, 0.5275, 0.5280, 0.5282, 0.5277, 0.5276, 0.5278, 0.5285, 0.5289,
#          0.5294, 0.5282, 0.5274, 0.5291, 0.5284, 0.5283, 0.5293, 0.5285, 0.5283,
#          0.5283, 0.5279, 0.5286, 0.5285, 0.5290, 0.5284, 0.5284, 0.5297, 0.5274,
#          0.5294, 0.5276, 0.5292, 0.5288, 0.5285, 0.5281, 0.5285, 0.5278, 0.5288,
#          0.5289, 0.5291, 0.5287, 0.5277, 0.5293, 0.5280, 0.5281, 0.5282, 0.5289,
#          0.5281, 0.5284, 0.5285, 0.5273, 0.5283, 0.5277, 0.5281, 0.5280, 0.5284,
#          0.5283, 0.5291, 0.5287, 0.5291, 0.5291, 0.5279, 0.5288, 0.5292, 0.5291,
#          0.5287, 0.5283, 0.5285, 0.5294, 0.5286, 0.5290, 0.5291, 0.5280, 0.5275,
#          0.5278, 0.5272, 0.5274, 0.5290, 0.5273, 0.5289, 0.5291, 0.5295, 0.5303,
#          0.5305, 0.5299, 0.5299, 0.5307, 0.5305, 0.5283, 0.5300, 0.5301, 0.5302,
#          0.5303, 0.5303, 0.5306, 0.5305, 0.5293, 0.5304, 0.5294, 0.5302, 0.5304,
#          0.5300, 0.5315, 0.5302, 0.5297, 0.5306, 0.5302, 0.5302, 0.5299, 0.5300,
#          0.5308, 0.5301, 0.5310, 0.5316, 0.5312, 0.5320, 0.5314, 0.5319, 0.5325,
#          0.5317, 0.5323, 0.5322, 0.5308, 0.5324, 0.5318, 0.5320, 0.5329, 0.5313,
#          0.5312, 0.5320, 0.5315, 0.5321, 0.5307, 0.5314, 0.5324, 0.5317, 0.5312,
#          0.5318, 0.5321, 0.5320, 0.5311, 0.5300, 0.5306, 0.5302, 0.5299, 0.5304,
#          0.5295, 0.5299, 0.5307, 0.5295, 0.5293, 0.5305, 0.5302, 0.5302, 0.5309,
#          0.5305, 0.5293, 0.5298, 0.5293, 0.5297, 0.5291, 0.5294, 0.5300, 0.5302,
#          0.5304, 0.5301, 0.5283, 0.5297, 0.5302, 0.5291, 0.5296, 0.5293, 0.5302,
#          0.5293, 0.5296, 0.5298, 0.5298, 0.5299, 0.5294, 0.5306, 0.5293, 0.5294,
#          0.5299, 0.5292, 0.5290, 0.5293, 0.5298, 0.5294, 0.5295, 0.5295, 0.5303,
#          0.5301, 0.5293, 0.5301, 0.5297, 0.5305, 0.5291, 0.5298, 0.5292, 0.5297,
#          0.5297, 0.5291, 0.5300, 0.5299, 0.5295, 0.5297, 0.5307, 0.5296, 0.5292,
#          0.5292, 0.5298, 0.5297, 0.5293, 0.5296, 0.5293, 0.5294, 0.5298, 0.5295,
#          0.5300, 0.5297, 0.5299, 0.5296, 0.5300, 0.5293, 0.5297, 0.5295, 0.5300,
#          0.5306, 0.5292, 0.5291, 0.5301, 0.5299, 0.5302, 0.5298, 0.5298, 0.5295,
#          0.5301, 0.5304, 0.5309, 0.5300, 0.5301, 0.5297, 0.5302, 0.5293, 0.5298,
#          0.5297, 0.5303, 0.5295]))

# %%
# (yy * data['date_int'].max()).round()

# %%
# (yHat_test * data['date_int'].max()).round()

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.5582
#
#
# mean_absolute_error(y, yHat): 0.7932
#
# mean_absolute_error(yy, yHat_test): 1.2685
#
#
# mean_squared_error(y, yHat): 1.9840
#
# mean_squared_error(yy, yHat_test): 4.3369
#
#
# mean_squared_log_error(y, yHat): 0.1102
#
# mean_squared_log_error(yy, yHat_test): 0.4281
#
#
# RMSE(y, yHat): 1.4085
#
# RMSE(yy, yHat_test): 2.0825

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Train loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Test loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss2.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.detach().T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc2.jpg", bbox_inches='tight')


plt.show()

# %%
['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']
# Out:
# ['day_scaled',
#  'day_sin',
#  'day_cos',
#  'month_scaled',
#  'month_sin',
#  'month_cos',
#  'leap_year',
#  'decade_scaled',
#  'decade_sin',
#  'decade_cos']

# %%
def result_to_date(result):
    
    result = str(result)
    
    day   = int(result[6:]) - 1
    month = int(result[4:6]) - 1

    ss = str(f'{result[:4]}0101')
    
    ds = datetime.datetime.strptime(ss, '%Y%m%d')
    
    ds = ds + relativedelta(months=month, days=day)

    result = ds.strftime('%d-%m-%Y')
    
    
    return result

# %%
# (16830739, 17848869)
result_to_date(16830739), result_to_date(17848869)
# Out:
# ('08-08-1683', '08-06-1791')

# %%
def test_model(input_list):
    

    X       = np.zeros((1, 10))
    X_smote = np.zeros((1, 10))



    day       = np.array(map_day[input_list[0]])
    month     = np.array(map_month[input_list[1]])
    leap_year = map_leap_year[input_list[2]]
    decade    = np.array(input_list[3].strip('[]')).astype('int64')


    X[0, 0] = scaler_day.transform(day.reshape(-1, 1)).flatten()
    X[0, 1] = np.sin(day * (2 * np.pi / 7))
    X[0, 2] = np.cos(day * (2 * np.pi / 7))

    X[0, 3] = scaler_month.transform(month.reshape(-1, 1)).flatten()
    X[0, 4] = np.sin(month * (2 * np.pi / 12))
    X[0, 5] = np.cos(month * (2 * np.pi / 12))

    X[0, 6] = leap_year

    X[0, 7] = scaler_decade.transform(decade.reshape(-1, 1)).flatten()
    X[0, 8] = np.sin(decade * (2 * np.pi / alpha))
    X[0, 9] = np.cos(decade * (2 * np.pi / alpha))

    # ---

    X_smote[0, 0] = scaler_day_smote.transform(day.reshape(-1, 1)).flatten()
    X_smote[0, 1] = X[0, 1]
    X_smote[0, 2] = X[0, 2]

    X_smote[0, 3] = scaler_month_smote.transform(month.reshape(-1, 1)).flatten()
    X_smote[0, 4] = X[0, 4]
    X_smote[0, 5] = X[0, 5]

    X_smote[0, 6] = leap_year

    X_smote[0, 7] = scaler_decade_smote.transform(decade.reshape(-1, 1)).flatten()
    X_smote[0, 8] = np.sin(decade * (2 * np.pi / alpha_smote))
    X_smote[0, 9] = np.cos(decade * (2 * np.pi / alpha_smote))


    model.eval()
    model_smote.eval()


    # ---

    result       = model(torch.tensor(X).to(device).float())
    result_smote = model_smote(torch.tensor(X_smote).to(device).float())


    # ---


    result       = ''.join(result.detach().cpu().numpy().round().astype(int).astype(str).flatten())
    result_smote = ''.join(result_smote.detach().cpu().numpy().round().astype(int).astype(str).flatten())


    model.train()
    model_smote.train()

    
    return result_to_date(result), result_to_date(result_smote)

# %%
input_test1 = ['[MON]', '[DEC]', '[False]', '[196]']
output_test1 = '3-12-1962'

input_test2 = ['[THU]', '[DEC]', '[True]', '[204]']
output_test2 = '3-12-2048'

input_test3 = ['[WED]', '[JAN]', '[False]', '[181]']
output_test3 = '10-1-1810'


input_test4 = ['[WED]', '[JUN]', '[False]', '[209]']

# %%
test_model(input_test1), test_model(input_test2), test_model(input_test3), test_model(input_test4)
# Out:
# (('14-02-1965', '15-02-1964'),
#  ('15-02-2045', '15-02-2055'),
#  ('15-11-1825', '15-11-1825'),
#  ('15-06-2085', '14-07-2084'))

# %%
output_test1, output_test2, output_test3
# Out:
# ('3-12-1962', '3-12-2048', '10-1-1810')

# %%
# example_input = pd.read_csv('./data/example_input.txt', sep=' ', header=None)
example_input = pd.read_csv('example_input.txt', sep=' ', header=None)


example_input.columns = ['day', 'month', 'leap_year', 'decade']

# %%
example_input
# Out:
#         day  month leap_year decade
# 0     [WED]  [JAN]   [False]  [180]
# 1     [MON]  [JAN]   [False]  [190]
# 2     [SAT]  [JAN]    [True]  [200]
# 3     [FRI]  [JAN]   [False]  [210]
# 4     [WED]  [JAN]   [False]  [220]
# ...     ...    ...       ...    ...
# 1460  [MON]  [OCT]    [True]  [214]
# 1461  [TUE]  [DEC]   [False]  [183]
# 1462  [SUN]  [DEC]   [False]  [193]
# 1463  [SAT]  [DEC]   [False]  [203]
# 1464  [THU]  [DEC]   [False]  [213]
#
# [1465 rows x 4 columns]

# %%
R       = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result'])
R_smote = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result_smote'])

# %%
example_input.iloc[0].tolist()
# Out:
# ['[WED]', '[JAN]', '[False]', '[180]']

# %%
for i in range(len(example_input)):
    R.iloc[i], R_smote.iloc[i] = test_model(example_input.iloc[i].tolist())

# %%
R
# Out:
#           result
# 0     15-11-1815
# 1     15-11-1905
# 2     15-11-2005
# 3     15-11-2105
# 4     15-11-2105
# ...          ...
# 1460  15-10-2145
# 1461  15-02-1835
# 1462  15-02-1935
# 1463  15-02-2035
# 1464  15-02-2135
#
# [1465 rows x 1 columns]

# %%
final = pd.concat([example_input, R], axis=1)
final
# Out:
#         day  month leap_year decade      result
# 0     [WED]  [JAN]   [False]  [180]  15-11-1815
# 1     [MON]  [JAN]   [False]  [190]  15-11-1905
# 2     [SAT]  [JAN]    [True]  [200]  15-11-2005
# 3     [FRI]  [JAN]   [False]  [210]  15-11-2105
# 4     [WED]  [JAN]   [False]  [220]  15-11-2105
# ...     ...    ...       ...    ...         ...
# 1460  [MON]  [OCT]    [True]  [214]  15-10-2145
# 1461  [TUE]  [DEC]   [False]  [183]  15-02-1835
# 1462  [SUN]  [DEC]   [False]  [193]  15-02-1935
# 1463  [SAT]  [DEC]   [False]  [203]  15-02-2035
# 1464  [THU]  [DEC]   [False]  [213]  15-02-2135
#
# [1465 rows x 5 columns]

# %%
final_smote = pd.concat([example_input, R_smote], axis=1)
final_smote
# Out:
#         day  month leap_year decade result_smote
# 0     [WED]  [JAN]   [False]  [180]   15-11-1815
# 1     [MON]  [JAN]   [False]  [190]   15-11-1915
# 2     [SAT]  [JAN]    [True]  [200]   15-11-2015
# 3     [FRI]  [JAN]   [False]  [210]   15-11-2115
# 4     [WED]  [JAN]   [False]  [220]   14-11-2194
# ...     ...    ...       ...    ...          ...
# 1460  [MON]  [OCT]    [True]  [214]   15-10-2155
# 1461  [TUE]  [DEC]   [False]  [183]   15-02-1844
# 1462  [SUN]  [DEC]   [False]  [193]   15-02-1944
# 1463  [SAT]  [DEC]   [False]  [203]   15-02-2045
# 1464  [THU]  [DEC]   [False]  [213]   15-02-2145
#
# [1465 rows x 5 columns]

# %%
final.to_csv('output_file.txt', sep=' ', header=None, index=False)

# %%
final_smote.to_csv('output_file_smote.txt', sep=' ', header=None, index=False)

# %% [markdown]
# Out-liers

# %% [markdown]
# Saving

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              'scaler_day_smote' : scaler_day_smote,
              'scaler_month_smote' : scaler_month_smote,
              'scaler_decade_smote' : scaler_decade_smote,
              
              'alpha': alpha,
              'alpha_smote': alpha_smote}



torch.save(checkpoint, 'checkpoint.pth.tar')

# %%
# checkpoint = torch.load('checkpoint.pth.tar')

# %%
# model       = Model()
# model_smote = Model()


# model.load_state_dict(checkpoint['model_state_dict'])
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
