# %%
import datetime

import copy

import random


from dateutil.relativedelta import relativedelta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('seaborn')
# plt.style.use(['dark_background', 'ggplot'])

import seaborn as sns
# sns.set()

# import scipy
# import scipy.stats as stats


# # sympy = symbolic math in Python
# import sympy as sym
# import sympy.plotting.plot as symplot


# make the equations look nicer

# from IPython.display import display
# display.set_matplotlib_formats('svg') # Deprecated since version 7.23

# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


# %config InlineBackend.set_matplotlib_formats = ["svg"]
# %config InlineBackend.figure_formats = ["svg"]

# %%
import sklearn


from sklearn.model_selection import train_test_split


# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler     # <------------ (-1.0, 1.0)
# from sklearn.preprocessing import MinMaxScaler


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from imblearn.over_sampling import SMOTE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset, DataLoader





torch.__version__
# Out:
# '1.12.1+cu113'

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def print_score(shape, yHat, y, yHat_test, yy):
    
    
    n, p = shape
    
    R2 = r2_score(y.detach().numpy(), yHat.detach().numpy())
    
    Adj_r2 = 1 - (1 - R2)  *  (n - 1) / (n - p - 1)
    
    print(f'Adjusted R-Squared(y, yHat): {Adj_r2:0.4f}\n\n')
    # r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
    #  R^2 score is not well-defined with less than two samples
    
    
    print(f'mean_absolute_error(y, yHat):',
          f'{mean_absolute_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_absolute_error(yy, yHat_test):',
          f'{mean_absolute_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_error(y, yHat):',
          f'{mean_squared_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_error(yy, yHat_test):',
          f'{mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_log_error(y, yHat):',
          f'{mean_squared_log_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_log_error(yy, yHat_test):',
          f'{mean_squared_log_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    
    print(f'RMSE(y, yHat):',
          f'{np.sqrt( mean_squared_error(y.detach().numpy(), yHat.detach().numpy()) ):0.4f}\n')
    print(f'RMSE(yy, yHat_test):',
          f'{np.sqrt( mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()) ):0.4f}\n\n')

# %%
# date = np.datetime64("2000-01-01")
# date_strings = date.astype(str).split('-'). 
# # >> ['2000', '01', '01']

# year_int = int(date_strings[0])

# %%
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Out:
# --2022-08-18 10:26:15--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5230713 (5.0M) [text/plain]
# Saving to: ‘data.txt’
#
# data.txt            100%[===================>]   4.99M  --.-KB/s    in 0.03s
#
# 2022-08-18 10:26:16 (152 MB/s) - ‘data.txt’ saved [5230713/5230713]
#
# --2022-08-18 10:26:16--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37732 (37K) [text/plain]
# Saving to: ‘example_input.txt’
#
# example_input.txt   100%[===================>]  36.85K  --.-KB/s    in 0s
#
# 2022-08-18 10:26:16 (96.6 MB/s) - ‘example_input.txt’ saved [37732/37732]

# %%
# !ls
# Out:
# data.txt  example_input.txt  sample_data

# %% [markdown]
# 'text.txt'

# %% [markdown]
# [ 1-1-1800 to 31-12-2200 ]

# %% [markdown]
# [day condition] [month condition] [leap year condition] [decade condition] date

# %% [markdown]
# [MON] [DEC] [False] [196] 3-12-1962
# [THU] [DEC] [True] [204] 3-12-2048
# [WED] [JAN] [False] [181] 10-1-1810

# %%
# data = np.loadtxt(open('text.txt','r'),delimiter=' ')
# ori = pd.read_csv('./data/data.txt', sep=' ', header=None)

ori = pd.read_csv('data.txt', sep=' ', header=None)

# %%
ori.columns = ['day', 'month', 'leap_year', 'decade', 'date']

# %%
ori
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
# data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)
# # pd.to_datetime(data.date, infer_datetime_format=False)

# %%
ori.dtypes
# Out:
# day          object
# month        object
# leap_year    object
# decade       object
# date         object
# dtype: object

# %%
# data_backup = copy.deepcopy(ori)
data = copy.deepcopy(ori)

# %%
data
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
data.date
# Out:
# 0           1-1-1800
# 1           1-1-1801
# 2           1-1-1802
# 3           1-1-1803
# 4           1-1-1804
#              ...
# 146457    31-12-2196
# 146458    31-12-2197
# 146459    31-12-2198
# 146460    31-12-2199
# 146461    31-12-2200
# Name: date, Length: 146462, dtype: object

# %%
# # data['date'] = pd.date_range('3-12-2048', periods=10)
# # data['date'] = pd.date_range('12-3-1962', periods=10)

# # 1-1-1800 to 31-12-2200
# data['date'] = pd.date_range(start='1-1-1800',end='12-31-2200')


data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)

# # data.date = data.date.dt.strftime('%d-%m-%Y')
# # data.date = pd.to_datetime(data.date.dt.strftime('%d-%m-%Y'), format='%d-%m-%Y', infer_datetime_format=False)

# %%
data.dtypes
# Out:
# day                  object
# month                object
# leap_year            object
# decade               object
# date         datetime64[ns]
# dtype: object

# %%
data
# Out:
#           day  month leap_year decade       date
# 0       [WED]  [JAN]   [False]  [180] 1800-01-01
# 1       [THU]  [JAN]   [False]  [180] 1801-01-01
# 2       [FRI]  [JAN]   [False]  [180] 1802-01-01
# 3       [SAT]  [JAN]   [False]  [180] 1803-01-01
# 4       [SUN]  [JAN]    [True]  [180] 1804-01-01
# ...       ...    ...       ...    ...        ...
# 146457  [SAT]  [DEC]    [True]  [219] 2196-12-31
# 146458  [SUN]  [DEC]   [False]  [219] 2197-12-31
# 146459  [MON]  [DEC]   [False]  [219] 2198-12-31
# 146460  [TUE]  [DEC]   [False]  [219] 2199-12-31
# 146461  [WED]  [DEC]   [False]  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %%
map_leap_year = {'[False]': int(0), '[True]' : int(1)}

data.leap_year = data.leap_year.map(map_leap_year)

# data.leap_year = data.leap_year.astype(np.float64)

# %%
data
# Out:
#           day  month  leap_year decade       date
# 0       [WED]  [JAN]          0  [180] 1800-01-01
# 1       [THU]  [JAN]          0  [180] 1801-01-01
# 2       [FRI]  [JAN]          0  [180] 1802-01-01
# 3       [SAT]  [JAN]          0  [180] 1803-01-01
# 4       [SUN]  [JAN]          1  [180] 1804-01-01
# ...       ...    ...        ...    ...        ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31
# 146459  [MON]  [DEC]          0  [219] 2198-12-31
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31
# 146461  [WED]  [DEC]          0  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %% [markdown]
# date -> timestamp

# %%
data.date.iloc[0]
# Out:
# Timestamp('1800-01-01 00:00:00')

# %%
data['date_int'] = data['date'].dt.strftime("%Y%m%d").astype(np.int64)

# data['date_str'] = data['date'].dt.strftime("%Y%m%d")

# %%
# data['date_int'].map(str)
# data['date_int'].astype(str)

# %%
# date_max = data.date_int.max()
# data['date_normalized'] = data.date_int / date_max

# %%
data
# Out:
#           day  month  leap_year decade       date  date_int
# 0       [WED]  [JAN]          0  [180] 1800-01-01  18000101
# 1       [THU]  [JAN]          0  [180] 1801-01-01  18010101
# 2       [FRI]  [JAN]          0  [180] 1802-01-01  18020101
# 3       [SAT]  [JAN]          0  [180] 1803-01-01  18030101
# 4       [SUN]  [JAN]          1  [180] 1804-01-01  18040101
# ...       ...    ...        ...    ...        ...       ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31  21961231
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31  21971231
# 146459  [MON]  [DEC]          0  [219] 2198-12-31  21981231
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31  21991231
# 146461  [WED]  [DEC]          0  [220] 2200-12-31  22001231
#
# [146462 rows x 6 columns]

# %%
x = data.decade.iloc[0]
x
# Out:
# '[180]'

# %%
x.strip('[]')
# Out:
# '180'

# %%
data.decade = data.decade.apply(lambda x: x.strip('[]')).astype('int64')

# %%
# data.day = data.day.apply(lambda x: x.strip('[]'))
# data.month = data.month.apply(lambda x: x.strip('[]'))

# %%
map_day = {'[SAT]': int(0),
           '[SUN]': int(1),
           '[MON]': int(2),
           '[TUE]': int(3),
           '[WED]': int(4),
           '[THU]': int(5),
           '[FRI]': int(6)}

# %%
data['day_code'] = data.day.map(map_day)

# %%
scaler_day = RobustScaler()

x = data.day_code.values.reshape(-1, 1)

data['day_scaled'] = scaler_day.fit_transform(x).flatten()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled
# 0             0.25
# 1             0.50
# 2             0.75
# 3            -0.75
# 4            -0.50
# ...            ...
# 146457       -0.75
# 146458       -0.50
# 146459       -0.25
# 146460        0.00
# 146461        0.25
#
# [146462 rows x 8 columns]

# %%
data['day_sin'] = np.sin(data['day_code'] * (2 * np.pi / 7))
data['day_cos'] = np.cos(data['day_code'] * (2 * np.pi / 7))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos
# 0             0.25 -0.433884 -0.900969
# 1             0.50 -0.974928 -0.222521
# 2             0.75 -0.781831  0.623490
# 3            -0.75  0.000000  1.000000
# 4            -0.50  0.781831  0.623490
# ...            ...       ...       ...
# 146457       -0.75  0.000000  1.000000
# 146458       -0.50  0.781831  0.623490
# 146459       -0.25  0.974928 -0.222521
# 146460        0.00  0.433884 -0.900969
# 146461        0.25 -0.433884 -0.900969
#
# [146462 rows x 10 columns]

# %%
map_month = {'[JAN]': int(0),
             '[FEB]': int(1),
             '[MAR]': int(2),
             '[APR]': int(3),
             '[MAY]': int(4),
             '[JUN]': int(5),
             '[JUL]': int(6),
             '[AUG]': int(7),
             '[SEP]': int(8),
             '[OCT]': int(9),
             '[NOV]': int(10),
             '[DEC]': int(11)}

# %%
data['month_code'] = data.month.map(map_month)

# %%
scaler_month = RobustScaler()

x = data.month_code.values.reshape(-1, 1)

data['month_scaled'] = scaler_month.fit_transform(x).flatten()

# %%
data['month_sin'] = np.sin(data['month_code'] * (2 * np.pi / 12))
data['month_cos'] = np.cos(data['month_code'] * (2 * np.pi / 12))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ...           ...
# 146457   0.866025
# 146458   0.866025
# 146459   0.866025
# 146460   0.866025
# 146461   0.866025
#
# [146462 rows x 14 columns]

# %%
scaler_decade = RobustScaler()

x = data.decade.values.reshape(-1, 1)

data['decade_scaled'] = scaler_decade.fit_transform(x).flatten()

# %%
# alpha = len(data.decade.unique())
alpha = (data.decade.iloc[-1] - data.decade.iloc[0]) + 1

data['decade_sin'] = np.sin(data['decade'] * (2 * np.pi / alpha))
data['decade_cos'] = np.cos(data['decade'] * (2 * np.pi / alpha))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %%
# data.date_normalized.min(), data.date_normalized.max()

# %%
# round(data.date_normalized.min()), round(data.date_normalized.max())

# %%
round(data.day_scaled.min()), round(data.day_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_sin.min()), round(data.day_sin.max())
# Out:
# (-1, 1)

# %%
round(data.day_cos.min()), round(data.day_cos.max())
# Out:
# (-1, 1)

# %%
round(data.month_scaled.min()), round(data.month_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.month_sin.min()), round(data.month_sin.max())
# Out:
# (-1, 1)

# %%
round(data.month_cos.min()), round(data.month_cos.max())
# Out:
# (-1, 1)

# %%
data.leap_year.min(), data.leap_year.max()
# Out:
# (0, 1)

# %%
round(data.decade_scaled.min()), round(data.decade_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.decade_sin.min()), round(data.decade_sin.max())
# Out:
# (-1, 1)

# %%
round(data.decade_cos.min()), round(data.decade_cos.max())
# Out:
# (-1, 1)

# %% [markdown]
# Boxplot

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.day.value_counts().plot(kind="bar")

# %%
data.month.value_counts().plot(kind="bar")

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
data.decade.value_counts().plot(kind="bar")

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %% [markdown]
# ['day_sin', 'day_cos', 'month_sin', 'month_cos', 'leap_year', 'decade_scaled']
# ['date_timestamp_scaled']

# %%
X = data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
          'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 0.25      , -0.43388374, -0.90096887, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.5       , -0.97492791, -0.22252093, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.75      , -0.78183148,  0.6234898 , ..., -1.        ,
#          0.63624244, -0.77148918],
#        ...,
#        [-0.25      ,  0.97492791, -0.22252093, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.        ,  0.43388374, -0.90096887, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.25      , -0.43388374, -0.90096887, ...,  1.        ,
#          0.74655322, -0.6653257 ]])

# %%
len(X)
# Out:
# 146462

# %%
X.shape
# Out:
# (146462, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()


ls = []

for s in data['date_int'].astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(data['date_int'])), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y = ll.values

Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 2, 0, ..., 2, 3, 1]])

# %%
len(Y)
# Out:
# 146462

# %%
Y.shape
# Out:
# (146462, 8)

# %%
# # leap = np.where(~X['leap_year'] == 1)[0]
# leap = np.where(X['leap_year'] == 1)[0]

# leap

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64


train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (146462, 10)
#
# Y: (146462, 8)
#
# Train data:   (102523, 10)
#
# Train labels: (102523, 8)
#
# Test data:    (43939, 10)
#
# Test labels:  (43939, 8)

# %%
102523 % 32, 102523 % 64
# Out:
# (27, 59)

# %%
class Model(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.input = nn.Linear(10, 32)

        self.fc1 = nn.Linear(32, 128)
        self.bnorm1 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 512)
        self.bnorm2 = nn.BatchNorm1d(512)

        self.fc3 = nn.Linear(512, 64)
        self.bnorm3 = nn.BatchNorm1d(64)

        self.fc4 = nn.Linear(64, 32)
        self.bnorm4 = nn.BatchNorm1d(32)


        self.output = nn.Linear(32, 8)



    def forward(self, x):


        # print(f'training={self.training}')

        x = F.relu( self.input(x) )

        x = F.relu(self.bnorm1(self.fc1(x)))
        # x = F.dropout(x, p=0.25, training=self.training)

        x = F.relu(self.bnorm2(self.fc2(x)))
        # x = F.dropout(x, p=0.4, training=self.training)

        x = F.relu(self.bnorm3(self.fc3(x)))
        # x = F.dropout(x, p=0.1, training=self.training)

        x = F.relu(self.bnorm4(self.fc4(x)))
        # x = F.dropout(x, p=0.05, training=self.training)


        x = F.relu(self.output(x))
        # x = self.output(x)
        


        return x

# %%
# test_x, test_y = next(iter(train_loader))

# print(f'test_x: {test_x.shape}\n')
# print(f'test_y: {test_y.shape}\n')

# %%
def train(model, numepochs):

    numepochs = numepochs

    model = model
    
    
    
    lossfun = nn.MSELoss()
    # lossfun = nn.L1Loss()


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0002, betas=(0.5, 0.999), weight_decay=1e-5)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.5, 0.999), weight_decay=1e-1)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=1e-9)


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
    
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    
    
    
    trainLoss = torch.zeros(numepochs)
    testLoss  = torch.zeros(numepochs)
    trainAcc  = torch.zeros(numepochs)
    # testAcc   = torch.zeros(numepochs)


    for epochi in range(numepochs):

        model.train() # switch to train mode

        batchLoss = []
        batchAcc  = []

        for X,y in train_loader:

            X = X.to(device)
            y = y.to(device)

            yHat = model(X)
            loss = lossfun(yHat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())
            # batchAcc.append( torch.mean(( yHat == y).float() ).item() )
            # batchAcc.append( torch.mean( (torch.abs(yHat - y) < 1).float() ).item() ) # <1 for rounding
            batchAcc.append( r2_score(y.detach().cpu().numpy(), yHat.detach().cpu().numpy()) )
            




        trainLoss[epochi] = np.mean(batchLoss)
        # trainAcc[epochi]  = 100*np.mean(batchAcc)
        trainAcc[epochi]  = np.mean(batchAcc)
        



        model.eval() # switch to test mode

        XX,yy = next(iter(test_loader))

        XX = XX.to(device)
        yy = yy.to(device)

        # forward pass and loss
        with torch.no_grad():
            yHat_test = model(XX)
            loss_test = lossfun(yHat_test, yy)


        testLoss[epochi] = loss_test.item()
        # testAcc[epochi]  = 100*torch.mean( (yHat_test == yy).float() ).item()
        # testAcc[epochi]  = 100*torch.mean( (torch.abs(yHat_test - yy) < 1).float() ).item()
        # testAcc[epochi]  = 100*r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
        


        # if (epochi + 1) % 5 == 0:
        print(f'Epoch {epochi+1}/{numepochs}, Train Loss: {loss.item():0.6f}, Test Loss: {loss_test.item():0.6f}')


        
    return trainLoss.cpu(), testLoss.cpu(), trainAcc.cpu(), yHat.cpu(), y.cpu(), yHat_test.cpu(), yy.cpu()

# %%
model = Model().to(device)

# test_hat = model(torch.randn(32,6))
# test_hat = model(test_x)

# print(test_hat.shape)


# checkpoint = torch.load('checkpoint.pth.tar', map_location=torch.device('cpu'))
checkpoint = torch.load('checkpoint_half.pth.tar', map_location=torch.device('cpu'))

model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
# for p in list(model.named_parameters()):
#     if 'weight' in p[0] and 'bnorm' not in p[0]:
#         nn.init.xavier_normal_(p[1].data)
#         print(p[0])
#         print(p[1].data.shape)

# %%
# numepochs = 120
# numepochs = 300
numepochs = 500



trainLoss1, testLoss1, trainAcc1, yHat1, y1, yHat_test1, yy1 = train(model, numepochs)
# Out:
# Epoch 1/500, Train Loss: 2.139656, Test Loss: 2.321436
# Epoch 2/500, Train Loss: 2.162840, Test Loss: 2.296906
# Epoch 3/500, Train Loss: 2.117620, Test Loss: 2.288357
# Epoch 4/500, Train Loss: 2.126652, Test Loss: 2.322620
# Epoch 5/500, Train Loss: 2.152585, Test Loss: 2.341775
# Epoch 6/500, Train Loss: 2.144576, Test Loss: 2.303783
# Epoch 7/500, Train Loss: 2.106343, Test Loss: 2.306672
# Epoch 8/500, Train Loss: 2.138390, Test Loss: 2.296307
# Epoch 9/500, Train Loss: 2.149665, Test Loss: 2.319027
# Epoch 10/500, Train Loss: 2.179275, Test Loss: 2.310927
# Epoch 11/500, Train Loss: 2.188195, Test Loss: 2.294809
# Epoch 12/500, Train Loss: 2.167036, Test Loss: 2.258169
# Epoch 13/500, Train Loss: 2.152658, Test Loss: 2.317067
# Epoch 14/500, Train Loss: 2.144122, Test Loss: 2.258963
# Epoch 15/500, Train Loss: 2.154352, Test Loss: 2.295038
# Epoch 16/500, Train Loss: 2.148484, Test Loss: 2.325215
# Epoch 17/500, Train Loss: 2.108504, Test Loss: 2.300855
# Epoch 18/500, Train Loss: 2.159415, Test Loss: 2.292703
# Epoch 19/500, Train Loss: 2.111348, Test Loss: 2.291603
# Epoch 20/500, Train Loss: 2.156215, Test Loss: 2.350592
# Epoch 21/500, Train Loss: 2.167122, Test Loss: 2.302946
# Epoch 22/500, Train Loss: 2.135214, Test Loss: 2.297617
# Epoch 23/500, Train Loss: 2.140563, Test Loss: 2.347202
# Epoch 24/500, Train Loss: 2.133788, Test Loss: 2.354983
# Epoch 25/500, Train Loss: 2.147856, Test Loss: 2.350691
# Epoch 26/500, Train Loss: 2.207070, Test Loss: 2.340325
# Epoch 27/500, Train Loss: 2.167319, Test Loss: 2.356588
# Epoch 28/500, Train Loss: 2.181225, Test Loss: 2.362751
# Epoch 29/500, Train Loss: 2.126264, Test Loss: 2.352602
# Epoch 30/500, Train Loss: 2.145269, Test Loss: 2.353531
# Epoch 31/500, Train Loss: 2.130209, Test Loss: 2.324921
# Epoch 32/500, Train Loss: 2.152144, Test Loss: 2.304143
# Epoch 33/500, Train Loss: 2.121635, Test Loss: 2.345110
# Epoch 34/500, Train Loss: 2.149057, Test Loss: 2.349830
# Epoch 35/500, Train Loss: 2.118796, Test Loss: 2.350858
# Epoch 36/500, Train Loss: 2.151835, Test Loss: 2.353595
# Epoch 37/500, Train Loss: 2.127842, Test Loss: 2.343601
# Epoch 38/500, Train Loss: 2.088348, Test Loss: 2.311065
# Epoch 39/500, Train Loss: 2.136048, Test Loss: 2.326028
# Epoch 40/500, Train Loss: 2.181762, Test Loss: 2.319011
# Epoch 41/500, Train Loss: 2.121344, Test Loss: 2.285185
# Epoch 42/500, Train Loss: 2.097916, Test Loss: 2.281485
# Epoch 43/500, Train Loss: 2.144202, Test Loss: 2.317821
# Epoch 44/500, Train Loss: 2.232705, Test Loss: 2.307636
# Epoch 45/500, Train Loss: 2.103095, Test Loss: 2.319291
# Epoch 46/500, Train Loss: 2.107547, Test Loss: 2.322126
# Epoch 47/500, Train Loss: 2.140459, Test Loss: 2.329696
# Epoch 48/500, Train Loss: 2.114609, Test Loss: 2.317947
# Epoch 49/500, Train Loss: 2.069137, Test Loss: 2.329824
# Epoch 50/500, Train Loss: 2.105072, Test Loss: 2.265223
# Epoch 51/500, Train Loss: 2.131021, Test Loss: 2.273244
# Epoch 52/500, Train Loss: 2.124409, Test Loss: 2.274638
# Epoch 53/500, Train Loss: 2.069690, Test Loss: 2.253351
# Epoch 54/500, Train Loss: 2.233327, Test Loss: 2.257862
# Epoch 55/500, Train Loss: 2.125573, Test Loss: 2.307039
# Epoch 56/500, Train Loss: 2.138618, Test Loss: 2.277443
# Epoch 57/500, Train Loss: 2.133247, Test Loss: 2.268931
# Epoch 58/500, Train Loss: 2.153496, Test Loss: 2.298975
# Epoch 59/500, Train Loss: 2.100720, Test Loss: 2.317426
# Epoch 60/500, Train Loss: 2.168530, Test Loss: 2.326239
# Epoch 61/500, Train Loss: 2.139416, Test Loss: 2.319221
# Epoch 62/500, Train Loss: 2.144448, Test Loss: 2.307171
# Epoch 63/500, Train Loss: 2.158032, Test Loss: 2.340763
# Epoch 64/500, Train Loss: 2.150720, Test Loss: 2.289693
# Epoch 65/500, Train Loss: 2.144794, Test Loss: 2.302735
# Epoch 66/500, Train Loss: 2.132237, Test Loss: 2.347643
# Epoch 67/500, Train Loss: 2.176056, Test Loss: 2.305267
# Epoch 68/500, Train Loss: 2.148130, Test Loss: 2.279282
# Epoch 69/500, Train Loss: 2.143776, Test Loss: 2.315348
# Epoch 70/500, Train Loss: 2.154039, Test Loss: 2.269968
# Epoch 71/500, Train Loss: 2.186745, Test Loss: 2.280595
# Epoch 72/500, Train Loss: 2.143226, Test Loss: 2.258140
# Epoch 73/500, Train Loss: 2.175586, Test Loss: 2.233492
# Epoch 74/500, Train Loss: 2.143522, Test Loss: 2.269177
# Epoch 75/500, Train Loss: 2.137413, Test Loss: 2.276496
# Epoch 76/500, Train Loss: 2.134231, Test Loss: 2.300086
# Epoch 77/500, Train Loss: 2.151493, Test Loss: 2.280604
# Epoch 78/500, Train Loss: 2.085783, Test Loss: 2.301824
# Epoch 79/500, Train Loss: 2.173064, Test Loss: 2.296840
# Epoch 80/500, Train Loss: 2.148827, Test Loss: 2.289073
# Epoch 81/500, Train Loss: 2.153154, Test Loss: 2.317866
# Epoch 82/500, Train Loss: 2.115900, Test Loss: 2.286262
# Epoch 83/500, Train Loss: 2.124425, Test Loss: 2.280862
# Epoch 84/500, Train Loss: 2.163366, Test Loss: 2.331708
# Epoch 85/500, Train Loss: 2.131090, Test Loss: 2.309917
# Epoch 86/500, Train Loss: 2.157537, Test Loss: 2.284081
# Epoch 87/500, Train Loss: 2.110415, Test Loss: 2.284703
# Epoch 88/500, Train Loss: 2.172627, Test Loss: 2.255501
# Epoch 89/500, Train Loss: 2.083010, Test Loss: 2.277464
# Epoch 90/500, Train Loss: 2.163981, Test Loss: 2.294974
# Epoch 91/500, Train Loss: 2.086608, Test Loss: 2.211872
# Epoch 92/500, Train Loss: 2.192603, Test Loss: 2.300747
# Epoch 93/500, Train Loss: 2.106595, Test Loss: 2.270589
# Epoch 94/500, Train Loss: 2.187428, Test Loss: 2.286061
# Epoch 95/500, Train Loss: 2.111452, Test Loss: 2.265676
# Epoch 96/500, Train Loss: 2.124727, Test Loss: 2.312841
# Epoch 97/500, Train Loss: 2.150893, Test Loss: 2.282082
# Epoch 98/500, Train Loss: 2.142406, Test Loss: 2.235043
# Epoch 99/500, Train Loss: 2.153758, Test Loss: 2.318049
# Epoch 100/500, Train Loss: 2.161841, Test Loss: 2.256670
# Epoch 101/500, Train Loss: 2.203467, Test Loss: 2.300233
# Epoch 102/500, Train Loss: 2.104984, Test Loss: 2.256102
# Epoch 103/500, Train Loss: 2.153815, Test Loss: 2.261251
# Epoch 104/500, Train Loss: 2.155579, Test Loss: 2.283587
# Epoch 105/500, Train Loss: 2.099103, Test Loss: 2.261956
# Epoch 106/500, Train Loss: 2.114894, Test Loss: 2.242901
# Epoch 107/500, Train Loss: 2.124247, Test Loss: 2.244135
# Epoch 108/500, Train Loss: 2.142821, Test Loss: 2.267962
# Epoch 109/500, Train Loss: 2.115344, Test Loss: 2.286461
# Epoch 110/500, Train Loss: 2.125019, Test Loss: 2.244010
# Epoch 111/500, Train Loss: 2.144949, Test Loss: 2.226141
# Epoch 112/500, Train Loss: 2.111907, Test Loss: 2.247643
# Epoch 113/500, Train Loss: 2.157056, Test Loss: 2.288699
# Epoch 114/500, Train Loss: 2.165663, Test Loss: 2.283495
# Epoch 115/500, Train Loss: 2.138672, Test Loss: 2.209188
# Epoch 116/500, Train Loss: 2.158888, Test Loss: 2.267403
# Epoch 117/500, Train Loss: 2.112850, Test Loss: 2.252381
# Epoch 118/500, Train Loss: 2.109250, Test Loss: 2.309711
# Epoch 119/500, Train Loss: 2.135343, Test Loss: 2.289862
# Epoch 120/500, Train Loss: 2.096781, Test Loss: 2.288160
# Epoch 121/500, Train Loss: 2.111619, Test Loss: 2.262600
# Epoch 122/500, Train Loss: 2.138494, Test Loss: 2.242727
# Epoch 123/500, Train Loss: 2.124942, Test Loss: 2.284903
# Epoch 124/500, Train Loss: 2.091059, Test Loss: 2.268472
# Epoch 125/500, Train Loss: 2.083763, Test Loss: 2.276821
# Epoch 126/500, Train Loss: 2.145936, Test Loss: 2.301069
# Epoch 127/500, Train Loss: 2.139929, Test Loss: 2.276837
# Epoch 128/500, Train Loss: 2.069481, Test Loss: 2.309866
# Epoch 129/500, Train Loss: 2.130856, Test Loss: 2.297899
# Epoch 130/500, Train Loss: 2.103884, Test Loss: 2.290966
# Epoch 131/500, Train Loss: 2.116799, Test Loss: 2.288432
# Epoch 132/500, Train Loss: 2.133668, Test Loss: 2.259476
# Epoch 133/500, Train Loss: 2.135356, Test Loss: 2.334801
# Epoch 134/500, Train Loss: 2.147507, Test Loss: 2.305590
# Epoch 135/500, Train Loss: 2.122544, Test Loss: 2.265393
# Epoch 136/500, Train Loss: 2.128024, Test Loss: 2.298567
# Epoch 137/500, Train Loss: 2.174045, Test Loss: 2.270942
# Epoch 138/500, Train Loss: 2.119525, Test Loss: 2.315614
# Epoch 139/500, Train Loss: 2.098448, Test Loss: 2.284370
# Epoch 140/500, Train Loss: 2.104436, Test Loss: 2.315318
# Epoch 141/500, Train Loss: 2.124418, Test Loss: 2.267040
# Epoch 142/500, Train Loss: 2.084805, Test Loss: 2.259867
# Epoch 143/500, Train Loss: 2.115811, Test Loss: 2.247231
# Epoch 144/500, Train Loss: 2.156096, Test Loss: 2.274473
# Epoch 145/500, Train Loss: 2.162654, Test Loss: 2.250657
# Epoch 146/500, Train Loss: 2.102624, Test Loss: 2.278884
# Epoch 147/500, Train Loss: 2.120746, Test Loss: 2.267289
# Epoch 148/500, Train Loss: 2.177158, Test Loss: 2.281455
# Epoch 149/500, Train Loss: 2.139305, Test Loss: 2.262082
# Epoch 150/500, Train Loss: 2.149397, Test Loss: 2.282749
# Epoch 151/500, Train Loss: 2.152077, Test Loss: 2.303442
# Epoch 152/500, Train Loss: 2.115042, Test Loss: 2.237469
# Epoch 153/500, Train Loss: 2.159764, Test Loss: 2.258022
# Epoch 154/500, Train Loss: 2.162537, Test Loss: 2.233415
# Epoch 155/500, Train Loss: 2.134955, Test Loss: 2.287076
# Epoch 156/500, Train Loss: 2.151365, Test Loss: 2.248163
# Epoch 157/500, Train Loss: 2.048654, Test Loss: 2.248549
# Epoch 158/500, Train Loss: 2.058983, Test Loss: 2.255277
# Epoch 159/500, Train Loss: 2.167027, Test Loss: 2.271669
# Epoch 160/500, Train Loss: 2.210220, Test Loss: 2.255343
# Epoch 161/500, Train Loss: 2.190393, Test Loss: 2.252743
# Epoch 162/500, Train Loss: 2.120333, Test Loss: 2.243836
# Epoch 163/500, Train Loss: 2.191232, Test Loss: 2.254059
# Epoch 164/500, Train Loss: 2.159640, Test Loss: 2.251111
# Epoch 165/500, Train Loss: 2.113168, Test Loss: 2.260625
# Epoch 166/500, Train Loss: 2.140545, Test Loss: 2.252399
# Epoch 167/500, Train Loss: 2.119345, Test Loss: 2.266387
# Epoch 168/500, Train Loss: 2.131867, Test Loss: 2.228353
# Epoch 169/500, Train Loss: 2.125941, Test Loss: 2.256768
# Epoch 170/500, Train Loss: 2.071550, Test Loss: 2.265985
# Epoch 171/500, Train Loss: 2.102201, Test Loss: 2.262910
# Epoch 172/500, Train Loss: 2.165813, Test Loss: 2.269513
# Epoch 173/500, Train Loss: 2.178165, Test Loss: 2.264039
# Epoch 174/500, Train Loss: 2.170975, Test Loss: 2.287434
# Epoch 175/500, Train Loss: 2.105070, Test Loss: 2.256739
# Epoch 176/500, Train Loss: 2.121436, Test Loss: 2.239865
# Epoch 177/500, Train Loss: 2.145657, Test Loss: 2.267288
# Epoch 178/500, Train Loss: 2.069957, Test Loss: 2.268006
# Epoch 179/500, Train Loss: 2.123147, Test Loss: 2.252117
# Epoch 180/500, Train Loss: 2.134495, Test Loss: 2.317791
# Epoch 181/500, Train Loss: 2.189054, Test Loss: 2.293660
# Epoch 182/500, Train Loss: 2.174140, Test Loss: 2.296494
# Epoch 183/500, Train Loss: 2.139324, Test Loss: 2.256516
# Epoch 184/500, Train Loss: 2.148148, Test Loss: 2.280879
# Epoch 185/500, Train Loss: 2.135015, Test Loss: 2.279616
# Epoch 186/500, Train Loss: 2.153573, Test Loss: 2.261953
# Epoch 187/500, Train Loss: 2.156463, Test Loss: 2.281107
# Epoch 188/500, Train Loss: 2.224109, Test Loss: 2.214172
# Epoch 189/500, Train Loss: 2.158778, Test Loss: 2.281843
# Epoch 190/500, Train Loss: 2.120044, Test Loss: 2.266629
# Epoch 191/500, Train Loss: 2.077873, Test Loss: 2.222699
# Epoch 192/500, Train Loss: 2.181236, Test Loss: 2.290594
# Epoch 193/500, Train Loss: 2.165490, Test Loss: 2.262851
# Epoch 194/500, Train Loss: 2.180180, Test Loss: 2.248037
# Epoch 195/500, Train Loss: 2.090664, Test Loss: 2.225752
# Epoch 196/500, Train Loss: 2.174203, Test Loss: 2.269013
# Epoch 197/500, Train Loss: 2.131828, Test Loss: 2.264594
# Epoch 198/500, Train Loss: 2.206521, Test Loss: 2.245225
# Epoch 199/500, Train Loss: 2.133269, Test Loss: 2.247027
# Epoch 200/500, Train Loss: 2.097799, Test Loss: 2.270948
# Epoch 201/500, Train Loss: 2.143434, Test Loss: 2.246536
# Epoch 202/500, Train Loss: 2.108451, Test Loss: 2.272372
# Epoch 203/500, Train Loss: 2.168011, Test Loss: 2.191471
# Epoch 204/500, Train Loss: 2.109112, Test Loss: 2.244158
# Epoch 205/500, Train Loss: 2.198494, Test Loss: 2.246747
# Epoch 206/500, Train Loss: 2.104375, Test Loss: 2.227250
# Epoch 207/500, Train Loss: 2.104162, Test Loss: 2.248650
# Epoch 208/500, Train Loss: 2.175098, Test Loss: 2.268607
# Epoch 209/500, Train Loss: 2.128398, Test Loss: 2.254192
# Epoch 210/500, Train Loss: 2.163134, Test Loss: 2.240279
# Epoch 211/500, Train Loss: 2.100884, Test Loss: 2.239023
# Epoch 212/500, Train Loss: 2.104430, Test Loss: 2.267444
# Epoch 213/500, Train Loss: 2.173155, Test Loss: 2.265067
# Epoch 214/500, Train Loss: 2.154699, Test Loss: 2.263995
# Epoch 215/500, Train Loss: 2.068126, Test Loss: 2.193346
# Epoch 216/500, Train Loss: 2.153833, Test Loss: 2.190085
# Epoch 217/500, Train Loss: 2.136683, Test Loss: 2.254270
# Epoch 218/500, Train Loss: 2.091922, Test Loss: 2.232840
# Epoch 219/500, Train Loss: 2.178690, Test Loss: 2.283231
# Epoch 220/500, Train Loss: 2.150512, Test Loss: 2.248459
# Epoch 221/500, Train Loss: 2.172434, Test Loss: 2.272356
# Epoch 222/500, Train Loss: 2.161104, Test Loss: 2.236643
# Epoch 223/500, Train Loss: 2.148708, Test Loss: 2.286380
# Epoch 224/500, Train Loss: 2.050319, Test Loss: 2.226877
# Epoch 225/500, Train Loss: 2.119375, Test Loss: 2.242320
# Epoch 226/500, Train Loss: 2.134499, Test Loss: 2.266591
# Epoch 227/500, Train Loss: 2.142946, Test Loss: 2.258917
# Epoch 228/500, Train Loss: 2.121059, Test Loss: 2.241312
# Epoch 229/500, Train Loss: 2.126973, Test Loss: 2.259984
# Epoch 230/500, Train Loss: 2.113761, Test Loss: 2.253579
# Epoch 231/500, Train Loss: 2.123534, Test Loss: 2.266351
# Epoch 232/500, Train Loss: 2.075666, Test Loss: 2.261873
# Epoch 233/500, Train Loss: 2.070238, Test Loss: 2.267256
# Epoch 234/500, Train Loss: 2.108213, Test Loss: 2.228751
# Epoch 235/500, Train Loss: 2.196617, Test Loss: 2.272314
# Epoch 236/500, Train Loss: 2.109003, Test Loss: 2.266660
# Epoch 237/500, Train Loss: 2.163927, Test Loss: 2.191086
# Epoch 238/500, Train Loss: 2.143914, Test Loss: 2.282942
# Epoch 239/500, Train Loss: 2.160239, Test Loss: 2.256196
# Epoch 240/500, Train Loss: 2.224562, Test Loss: 2.215825
# Epoch 241/500, Train Loss: 2.110248, Test Loss: 2.245378
# Epoch 242/500, Train Loss: 2.092212, Test Loss: 2.242739
# Epoch 243/500, Train Loss: 2.114325, Test Loss: 2.236433
# Epoch 244/500, Train Loss: 2.130420, Test Loss: 2.215852
# Epoch 245/500, Train Loss: 2.147240, Test Loss: 2.229747
# Epoch 246/500, Train Loss: 2.173304, Test Loss: 2.237072
# Epoch 247/500, Train Loss: 2.113894, Test Loss: 2.237711
# Epoch 248/500, Train Loss: 2.091178, Test Loss: 2.200531
# Epoch 249/500, Train Loss: 2.127985, Test Loss: 2.187535
# Epoch 250/500, Train Loss: 2.089988, Test Loss: 2.201791
# Epoch 251/500, Train Loss: 2.130569, Test Loss: 2.236297
# Epoch 252/500, Train Loss: 2.089392, Test Loss: 2.262381
# Epoch 253/500, Train Loss: 2.108097, Test Loss: 2.229362
# Epoch 254/500, Train Loss: 2.085217, Test Loss: 2.195019
# Epoch 255/500, Train Loss: 2.181398, Test Loss: 2.232721
# Epoch 256/500, Train Loss: 2.100754, Test Loss: 2.246259
# Epoch 257/500, Train Loss: 2.093502, Test Loss: 2.220634
# Epoch 258/500, Train Loss: 2.147161, Test Loss: 2.260871
# Epoch 259/500, Train Loss: 2.133534, Test Loss: 2.243587
# Epoch 260/500, Train Loss: 2.116633, Test Loss: 2.218483
# Epoch 261/500, Train Loss: 2.110966, Test Loss: 2.255505
# Epoch 262/500, Train Loss: 2.149899, Test Loss: 2.248885
# Epoch 263/500, Train Loss: 2.118523, Test Loss: 2.279288
# Epoch 264/500, Train Loss: 2.078276, Test Loss: 2.253199
# Epoch 265/500, Train Loss: 2.201650, Test Loss: 2.240115
# Epoch 266/500, Train Loss: 2.228680, Test Loss: 2.202290
# Epoch 267/500, Train Loss: 2.129423, Test Loss: 2.232010
# Epoch 268/500, Train Loss: 2.081138, Test Loss: 2.240608
# Epoch 269/500, Train Loss: 2.095396, Test Loss: 2.220480
# Epoch 270/500, Train Loss: 2.147342, Test Loss: 2.247591
# Epoch 271/500, Train Loss: 2.147790, Test Loss: 2.256042
# Epoch 272/500, Train Loss: 2.156117, Test Loss: 2.235297
# Epoch 273/500, Train Loss: 2.118544, Test Loss: 2.244432
# Epoch 274/500, Train Loss: 2.153433, Test Loss: 2.232120
# Epoch 275/500, Train Loss: 2.117797, Test Loss: 2.265172
# Epoch 276/500, Train Loss: 2.158082, Test Loss: 2.222030
# Epoch 277/500, Train Loss: 2.107984, Test Loss: 2.219203
# Epoch 278/500, Train Loss: 2.109727, Test Loss: 2.264330
# Epoch 279/500, Train Loss: 2.182761, Test Loss: 2.254192
# Epoch 280/500, Train Loss: 2.104810, Test Loss: 2.240748
# Epoch 281/500, Train Loss: 2.076543, Test Loss: 2.216440
# Epoch 282/500, Train Loss: 2.173652, Test Loss: 2.249308
# Epoch 283/500, Train Loss: 2.163414, Test Loss: 2.243154
# Epoch 284/500, Train Loss: 2.164383, Test Loss: 2.260875
# Epoch 285/500, Train Loss: 2.101012, Test Loss: 2.252579
# Epoch 286/500, Train Loss: 2.130298, Test Loss: 2.254880
# Epoch 287/500, Train Loss: 2.157012, Test Loss: 2.262599
# Epoch 288/500, Train Loss: 2.129960, Test Loss: 2.245436
# Epoch 289/500, Train Loss: 2.162858, Test Loss: 2.220986
# Epoch 290/500, Train Loss: 2.151906, Test Loss: 2.219452
# Epoch 291/500, Train Loss: 2.121695, Test Loss: 2.269719
# Epoch 292/500, Train Loss: 2.175213, Test Loss: 2.220657
# Epoch 293/500, Train Loss: 2.108679, Test Loss: 2.261271
# Epoch 294/500, Train Loss: 2.180608, Test Loss: 2.249238
# Epoch 295/500, Train Loss: 2.142742, Test Loss: 2.251404
# Epoch 296/500, Train Loss: 2.168905, Test Loss: 2.239612
# Epoch 297/500, Train Loss: 2.137193, Test Loss: 2.285172
# Epoch 298/500, Train Loss: 2.126231, Test Loss: 2.272781
# Epoch 299/500, Train Loss: 2.135673, Test Loss: 2.271706
# Epoch 300/500, Train Loss: 2.121054, Test Loss: 2.234604
# Epoch 301/500, Train Loss: 2.132592, Test Loss: 2.255382
# Epoch 302/500, Train Loss: 2.152755, Test Loss: 2.247566
# Epoch 303/500, Train Loss: 2.132451, Test Loss: 2.264147
# Epoch 304/500, Train Loss: 2.139298, Test Loss: 2.195364
# Epoch 305/500, Train Loss: 2.147803, Test Loss: 2.256913
# Epoch 306/500, Train Loss: 2.129628, Test Loss: 2.211227
# Epoch 307/500, Train Loss: 2.146012, Test Loss: 2.251555
# Epoch 308/500, Train Loss: 2.150782, Test Loss: 2.253032
# Epoch 309/500, Train Loss: 2.119449, Test Loss: 2.260364
# Epoch 310/500, Train Loss: 2.142517, Test Loss: 2.214328
# Epoch 311/500, Train Loss: 2.144839, Test Loss: 2.271110
# Epoch 312/500, Train Loss: 2.152848, Test Loss: 2.223712
# Epoch 313/500, Train Loss: 2.203958, Test Loss: 2.245107
# Epoch 314/500, Train Loss: 2.132892, Test Loss: 2.206968
# Epoch 315/500, Train Loss: 2.127354, Test Loss: 2.263811
# Epoch 316/500, Train Loss: 2.140340, Test Loss: 2.239679
# Epoch 317/500, Train Loss: 2.134717, Test Loss: 2.266380
# Epoch 318/500, Train Loss: 2.150227, Test Loss: 2.218671
# Epoch 319/500, Train Loss: 2.147200, Test Loss: 2.212021
# Epoch 320/500, Train Loss: 2.114557, Test Loss: 2.254384
# Epoch 321/500, Train Loss: 2.132127, Test Loss: 2.246424
# Epoch 322/500, Train Loss: 2.125549, Test Loss: 2.263477
# Epoch 323/500, Train Loss: 2.107726, Test Loss: 2.210191
# Epoch 324/500, Train Loss: 2.137527, Test Loss: 2.235412
# Epoch 325/500, Train Loss: 2.127359, Test Loss: 2.200207
# Epoch 326/500, Train Loss: 2.140904, Test Loss: 2.245756
# Epoch 327/500, Train Loss: 2.122381, Test Loss: 2.235999
# Epoch 328/500, Train Loss: 2.139926, Test Loss: 2.246797
# Epoch 329/500, Train Loss: 2.142185, Test Loss: 2.240862
# Epoch 330/500, Train Loss: 2.159124, Test Loss: 2.220045
# Epoch 331/500, Train Loss: 2.146868, Test Loss: 2.251869
# Epoch 332/500, Train Loss: 2.140290, Test Loss: 2.272501
# Epoch 333/500, Train Loss: 2.139176, Test Loss: 2.283091
# Epoch 334/500, Train Loss: 2.125981, Test Loss: 2.222850
# Epoch 335/500, Train Loss: 2.150832, Test Loss: 2.268185
# Epoch 336/500, Train Loss: 2.144712, Test Loss: 2.226019
# Epoch 337/500, Train Loss: 2.164644, Test Loss: 2.249440
# Epoch 338/500, Train Loss: 2.166829, Test Loss: 2.239619
# Epoch 339/500, Train Loss: 2.127783, Test Loss: 2.213111
# Epoch 340/500, Train Loss: 2.137256, Test Loss: 2.246035
# Epoch 341/500, Train Loss: 2.143713, Test Loss: 2.236026
# Epoch 342/500, Train Loss: 2.171179, Test Loss: 2.223752
# Epoch 343/500, Train Loss: 2.139987, Test Loss: 2.257108
# Epoch 344/500, Train Loss: 2.144143, Test Loss: 2.230037
# Epoch 345/500, Train Loss: 2.158164, Test Loss: 2.244025
# Epoch 346/500, Train Loss: 2.168137, Test Loss: 2.241505
# Epoch 347/500, Train Loss: 2.141188, Test Loss: 2.271945
# Epoch 348/500, Train Loss: 2.156358, Test Loss: 2.237703
# Epoch 349/500, Train Loss: 2.127927, Test Loss: 2.266561
# Epoch 350/500, Train Loss: 2.132091, Test Loss: 2.246888
# Epoch 351/500, Train Loss: 2.154044, Test Loss: 2.254152
# Epoch 352/500, Train Loss: 2.143682, Test Loss: 2.252400
# Epoch 353/500, Train Loss: 2.134786, Test Loss: 2.238784
# Epoch 354/500, Train Loss: 2.151256, Test Loss: 2.235758
# Epoch 355/500, Train Loss: 2.227016, Test Loss: 2.275952
# Epoch 356/500, Train Loss: 2.164950, Test Loss: 2.215950
# Epoch 357/500, Train Loss: 2.158241, Test Loss: 2.232960
# Epoch 358/500, Train Loss: 2.137748, Test Loss: 2.252169
# Epoch 359/500, Train Loss: 2.143497, Test Loss: 2.262010
# Epoch 360/500, Train Loss: 2.149050, Test Loss: 2.275390
# Epoch 361/500, Train Loss: 2.147376, Test Loss: 2.270102
# Epoch 362/500, Train Loss: 2.126718, Test Loss: 2.254522
# Epoch 363/500, Train Loss: 2.140477, Test Loss: 2.223238
# Epoch 364/500, Train Loss: 2.146809, Test Loss: 2.262590
# Epoch 365/500, Train Loss: 2.156277, Test Loss: 2.246793
# Epoch 366/500, Train Loss: 2.161744, Test Loss: 2.228882
# Epoch 367/500, Train Loss: 2.245545, Test Loss: 2.264938
# Epoch 368/500, Train Loss: 2.152522, Test Loss: 2.266377
# Epoch 369/500, Train Loss: 2.147861, Test Loss: 2.237185
# Epoch 370/500, Train Loss: 2.150494, Test Loss: 2.243713
# Epoch 371/500, Train Loss: 2.150528, Test Loss: 2.265283
# Epoch 372/500, Train Loss: 2.153581, Test Loss: 2.231148
# Epoch 373/500, Train Loss: 2.159451, Test Loss: 2.255205
# Epoch 374/500, Train Loss: 2.138150, Test Loss: 2.246173
# Epoch 375/500, Train Loss: 2.142471, Test Loss: 2.227259
# Epoch 376/500, Train Loss: 2.159940, Test Loss: 2.250551
# Epoch 377/500, Train Loss: 2.135962, Test Loss: 2.249822
# Epoch 378/500, Train Loss: 2.139781, Test Loss: 2.222908
# Epoch 379/500, Train Loss: 2.156078, Test Loss: 2.253348
# Epoch 380/500, Train Loss: 2.138293, Test Loss: 2.243138
# Epoch 381/500, Train Loss: 2.148808, Test Loss: 2.259064
# Epoch 382/500, Train Loss: 2.177017, Test Loss: 2.225496
# Epoch 383/500, Train Loss: 2.165975, Test Loss: 2.233993
# Epoch 384/500, Train Loss: 2.158940, Test Loss: 2.245558
# Epoch 385/500, Train Loss: 2.126583, Test Loss: 2.236034
# Epoch 386/500, Train Loss: 2.194272, Test Loss: 2.201180
# Epoch 387/500, Train Loss: 2.189511, Test Loss: 2.180952
# Epoch 388/500, Train Loss: 2.169228, Test Loss: 2.221394
# Epoch 389/500, Train Loss: 2.154486, Test Loss: 2.238728
# Epoch 390/500, Train Loss: 2.168714, Test Loss: 2.202761
# Epoch 391/500, Train Loss: 2.163319, Test Loss: 2.220412
# Epoch 392/500, Train Loss: 2.148030, Test Loss: 2.238146
# Epoch 393/500, Train Loss: 2.161318, Test Loss: 2.233558
# Epoch 394/500, Train Loss: 2.165275, Test Loss: 2.233636
# Epoch 395/500, Train Loss: 2.145884, Test Loss: 2.233234
# Epoch 396/500, Train Loss: 2.132152, Test Loss: 2.220517
# Epoch 397/500, Train Loss: 2.156811, Test Loss: 2.235302
# Epoch 398/500, Train Loss: 2.170734, Test Loss: 2.243433
# Epoch 399/500, Train Loss: 2.180986, Test Loss: 2.217987
# Epoch 400/500, Train Loss: 2.167079, Test Loss: 2.224973
# Epoch 401/500, Train Loss: 2.170424, Test Loss: 2.262679
# Epoch 402/500, Train Loss: 2.182507, Test Loss: 2.210703
# Epoch 403/500, Train Loss: 2.181110, Test Loss: 2.262068
# Epoch 404/500, Train Loss: 2.218489, Test Loss: 2.257916
# Epoch 405/500, Train Loss: 2.156892, Test Loss: 2.240726
# Epoch 406/500, Train Loss: 2.172740, Test Loss: 2.254604
# Epoch 407/500, Train Loss: 2.213281, Test Loss: 2.239787
# Epoch 408/500, Train Loss: 2.157591, Test Loss: 2.254342
# Epoch 409/500, Train Loss: 2.180573, Test Loss: 2.254949
# Epoch 410/500, Train Loss: 2.182626, Test Loss: 2.218097
# Epoch 411/500, Train Loss: 2.187731, Test Loss: 2.230346
# Epoch 412/500, Train Loss: 2.169585, Test Loss: 2.259694
# Epoch 413/500, Train Loss: 2.186494, Test Loss: 2.275188
# Epoch 414/500, Train Loss: 2.167605, Test Loss: 2.248830
# Epoch 415/500, Train Loss: 2.154799, Test Loss: 2.252611
# Epoch 416/500, Train Loss: 2.189608, Test Loss: 2.250875
# Epoch 417/500, Train Loss: 2.146001, Test Loss: 2.276177
# Epoch 418/500, Train Loss: 2.163022, Test Loss: 2.252026
# Epoch 419/500, Train Loss: 2.190496, Test Loss: 2.222790
# Epoch 420/500, Train Loss: 2.169594, Test Loss: 2.233842
# Epoch 421/500, Train Loss: 2.183909, Test Loss: 2.238233
# Epoch 422/500, Train Loss: 2.171299, Test Loss: 2.246700
# Epoch 423/500, Train Loss: 2.196782, Test Loss: 2.240487
# Epoch 424/500, Train Loss: 2.175153, Test Loss: 2.260792
# Epoch 425/500, Train Loss: 2.161356, Test Loss: 2.242305
# Epoch 426/500, Train Loss: 2.167875, Test Loss: 2.252125
# Epoch 427/500, Train Loss: 2.181126, Test Loss: 2.239034
# Epoch 428/500, Train Loss: 2.184812, Test Loss: 2.246113
# Epoch 429/500, Train Loss: 2.176809, Test Loss: 2.252193
# Epoch 430/500, Train Loss: 2.162519, Test Loss: 2.245754
# Epoch 431/500, Train Loss: 2.167438, Test Loss: 2.239949
# Epoch 432/500, Train Loss: 2.172822, Test Loss: 2.246403
# Epoch 433/500, Train Loss: 2.183198, Test Loss: 2.250807
# Epoch 434/500, Train Loss: 2.142265, Test Loss: 2.231305
# Epoch 435/500, Train Loss: 2.155820, Test Loss: 2.231948
# Epoch 436/500, Train Loss: 2.170829, Test Loss: 2.236487
# Epoch 437/500, Train Loss: 2.152076, Test Loss: 2.239839
# Epoch 438/500, Train Loss: 2.176126, Test Loss: 2.256047
# Epoch 439/500, Train Loss: 2.156515, Test Loss: 2.227264
# Epoch 440/500, Train Loss: 2.194167, Test Loss: 2.246979
# Epoch 441/500, Train Loss: 2.189660, Test Loss: 2.242405
# Epoch 442/500, Train Loss: 2.123948, Test Loss: 2.239082
# Epoch 443/500, Train Loss: 2.171849, Test Loss: 2.262508
# Epoch 444/500, Train Loss: 2.193176, Test Loss: 2.220995
# Epoch 445/500, Train Loss: 2.217141, Test Loss: 2.255979
# Epoch 446/500, Train Loss: 2.161961, Test Loss: 2.256372
# Epoch 447/500, Train Loss: 2.176027, Test Loss: 2.247787
# Epoch 448/500, Train Loss: 2.152233, Test Loss: 2.257672
# Epoch 449/500, Train Loss: 2.181072, Test Loss: 2.235157
# Epoch 450/500, Train Loss: 2.187663, Test Loss: 2.226240
# Epoch 451/500, Train Loss: 2.151623, Test Loss: 2.252969
# Epoch 452/500, Train Loss: 2.181086, Test Loss: 2.244534
# Epoch 453/500, Train Loss: 2.165002, Test Loss: 2.225410
# Epoch 454/500, Train Loss: 2.180533, Test Loss: 2.241291
# Epoch 455/500, Train Loss: 2.177929, Test Loss: 2.272512
# Epoch 456/500, Train Loss: 2.180202, Test Loss: 2.233555
# Epoch 457/500, Train Loss: 2.173155, Test Loss: 2.253746
# Epoch 458/500, Train Loss: 2.157727, Test Loss: 2.261992
# Epoch 459/500, Train Loss: 2.153516, Test Loss: 2.274813
# Epoch 460/500, Train Loss: 2.158743, Test Loss: 2.260788
# Epoch 461/500, Train Loss: 2.144238, Test Loss: 2.250820
# Epoch 462/500, Train Loss: 2.128290, Test Loss: 2.273481
# Epoch 463/500, Train Loss: 2.142023, Test Loss: 2.266862
# Epoch 464/500, Train Loss: 2.173585, Test Loss: 2.272350
# Epoch 465/500, Train Loss: 2.191779, Test Loss: 2.217793
# Epoch 466/500, Train Loss: 2.140215, Test Loss: 2.264559
# Epoch 467/500, Train Loss: 2.181598, Test Loss: 2.270787
# Epoch 468/500, Train Loss: 2.183191, Test Loss: 2.250536
# Epoch 469/500, Train Loss: 2.190730, Test Loss: 2.271883
# Epoch 470/500, Train Loss: 2.202041, Test Loss: 2.252095
# Epoch 471/500, Train Loss: 2.205315, Test Loss: 2.266522
# Epoch 472/500, Train Loss: 2.152697, Test Loss: 2.273761
# Epoch 473/500, Train Loss: 2.159239, Test Loss: 2.256900
# Epoch 474/500, Train Loss: 2.156803, Test Loss: 2.258371
# Epoch 475/500, Train Loss: 2.188899, Test Loss: 2.306544
# Epoch 476/500, Train Loss: 2.145495, Test Loss: 2.265863
# Epoch 477/500, Train Loss: 2.172420, Test Loss: 2.244583
# Epoch 478/500, Train Loss: 2.155154, Test Loss: 2.256475
# Epoch 479/500, Train Loss: 2.165270, Test Loss: 2.248603
# Epoch 480/500, Train Loss: 2.150336, Test Loss: 2.251984
# Epoch 481/500, Train Loss: 2.169363, Test Loss: 2.227066
# Epoch 482/500, Train Loss: 2.157722, Test Loss: 2.276748
# Epoch 483/500, Train Loss: 2.176027, Test Loss: 2.241585
# Epoch 484/500, Train Loss: 2.177012, Test Loss: 2.265528
# Epoch 485/500, Train Loss: 2.191858, Test Loss: 2.258788
# Epoch 486/500, Train Loss: 2.174104, Test Loss: 2.270758
# Epoch 487/500, Train Loss: 2.164653, Test Loss: 2.257811
# Epoch 488/500, Train Loss: 2.206556, Test Loss: 2.248496
# Epoch 489/500, Train Loss: 2.219118, Test Loss: 2.248219
# Epoch 490/500, Train Loss: 2.158528, Test Loss: 2.246050
# Epoch 491/500, Train Loss: 2.190799, Test Loss: 2.247041
# Epoch 492/500, Train Loss: 2.194492, Test Loss: 2.259611
# Epoch 493/500, Train Loss: 2.180834, Test Loss: 2.263459
# Epoch 494/500, Train Loss: 2.170599, Test Loss: 2.239790
# Epoch 495/500, Train Loss: 2.147093, Test Loss: 2.232229
# Epoch 496/500, Train Loss: 2.210350, Test Loss: 2.264963
# Epoch 497/500, Train Loss: 2.154518, Test Loss: 2.252125
# Epoch 498/500, Train Loss: 2.187605, Test Loss: 2.232865
# Epoch 499/500, Train Loss: 2.170036, Test Loss: 2.268067
# Epoch 500/500, Train Loss: 2.218815, Test Loss: 2.249544

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              #'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              #'scaler_day_smote' : scaler_day_smote,
              #'scaler_month_smote' : scaler_month_smote,
              #'scaler_decade_smote' : scaler_decade_smote,
              
              'alpha': alpha,
              #'alpha_smote': alpha_smote
              }



torch.save(checkpoint, 'checkpoint_half.pth.tar')

# %%
# r2_score(y.detach().numpy(), yHat.detach().numpy())
# type(r2_score(y.detach(), yHat.detach()))

# %%
# torch.mean( r2_score(y.detach().numpy(), yHat.detach().numpy()) ).item()

# %%
trainLoss1, testLoss1, trainAcc1
# Out:
# (tensor([2.0625, 2.0620, 2.0615, 2.0617, 2.0606, 2.0609, 2.0613, 2.0606, 2.0622,
#          2.0603, 2.0602, 2.0606, 2.0619, 2.0627, 2.0622, 2.0603, 2.0588, 2.0603,
#          2.0640, 2.0580, 2.0603, 2.0583, 2.0592, 2.0634, 2.0579, 2.0589, 2.0584,
#          2.0617, 2.0581, 2.0586, 2.0603, 2.0567, 2.0580, 2.0576, 2.0560, 2.0589,
#          2.0564, 2.0578, 2.0583, 2.0571, 2.0578, 2.0563, 2.0561, 2.0556, 2.0643,
#          2.0555, 2.0590, 2.0549, 2.0572, 2.0554, 2.0573, 2.0554, 2.0564, 2.0558,
#          2.0570, 2.0551, 2.0540, 2.0551, 2.0553, 2.0543, 2.0533, 2.0539, 2.0541,
#          2.0541, 2.0525, 2.0531, 2.0554, 2.0527, 2.0532, 2.0558, 2.0540, 2.0545,
#          2.0523, 2.0549, 2.0517, 2.0541, 2.0521, 2.0516, 2.0523, 2.0513, 2.0518,
#          2.0539, 2.0520, 2.0524, 2.0533, 2.0510, 2.0499, 2.0519, 2.0517, 2.0513,
#          2.0517, 2.0510, 2.0500, 2.0498, 2.0512, 2.0489, 2.0499, 2.0502, 2.0488,
#          2.0515, 2.0490, 2.0491, 2.0493, 2.0504, 2.0487, 2.0487, 2.0490, 2.0489,
#          2.0477, 2.0485, 2.0497, 2.0485, 2.0477, 2.0476, 2.0484, 2.0463, 2.0473,
#          2.0504, 2.0471, 2.0460, 2.0470, 2.0465, 2.0459, 2.0461, 2.0458, 2.0451,
#          2.0466, 2.0450, 2.0460, 2.0439, 2.0451, 2.0460, 2.0456, 2.0447, 2.0460,
#          2.0440, 2.0436, 2.0435, 2.0432, 2.0449, 2.0436, 2.0436, 2.0471, 2.0429,
#          2.0448, 2.0428, 2.0474, 2.0446, 2.0423, 2.0424, 2.0434, 2.0417, 2.0421,
#          2.0453, 2.0416, 2.0441, 2.0445, 2.0427, 2.0415, 2.0445, 2.0412, 2.0410,
#          2.0406, 2.0407, 2.0434, 2.0413, 2.0407, 2.0400, 2.0414, 2.0405, 2.0400,
#          2.0400, 2.0389, 2.0395, 2.0401, 2.0413, 2.0411, 2.0449, 2.0429, 2.0401,
#          2.0407, 2.0444, 2.0405, 2.0399, 2.0388, 2.0398, 2.0388, 2.0386, 2.0379,
#          2.0385, 2.0393, 2.0376, 2.0382, 2.0382, 2.0374, 2.0371, 2.0388, 2.0369,
#          2.0363, 2.0372, 2.0370, 2.0372, 2.0382, 2.0386, 2.0354, 2.0367, 2.0356,
#          2.0380, 2.0351, 2.0356, 2.0354, 2.0349, 2.0356, 2.0347, 2.0361, 2.0366,
#          2.0378, 2.0360, 2.0338, 2.0364, 2.0349, 2.0338, 2.0340, 2.0360, 2.0334,
#          2.0346, 2.0341, 2.0324, 2.0339, 2.0342, 2.0341, 2.0328, 2.0327, 2.0326,
#          2.0334, 2.0329, 2.0324, 2.0335, 2.0335, 2.0332, 2.0344, 2.0320, 2.0319,
#          2.0342, 2.0309, 2.0322, 2.0319, 2.0311, 2.0308, 2.0323, 2.0338, 2.0312,
#          2.0306, 2.0317, 2.0341, 2.0309, 2.0358, 2.0303, 2.0334, 2.0296, 2.0319,
#          2.0321, 2.0345, 2.0346, 2.0304, 2.0301, 2.0313, 2.0294, 2.0303, 2.0314,
#          2.0313, 2.0276, 2.0289, 2.0292, 2.0305, 2.0292, 2.0281, 2.0286, 2.0281,
#          2.0304, 2.0277, 2.0283, 2.0290, 2.0269, 2.0279, 2.0313, 2.0284, 2.0271,
#          2.0257, 2.0278, 2.0272, 2.0267, 2.0264, 2.0268, 2.0260, 2.0259, 2.0259,
#          2.0280, 2.0264, 2.0259, 2.0239, 2.0252, 2.0290, 2.0275, 2.0242, 2.0260,
#          2.0227, 2.0253, 2.0268, 2.0241, 2.0284, 2.0242, 2.0235, 2.0234, 2.0215,
#          2.0243, 2.0230, 2.0226, 2.0233, 2.0234, 2.0225, 2.0232, 2.0256, 2.0234,
#          2.0215, 2.0219, 2.0247, 2.0213, 2.0225, 2.0218, 2.0232, 2.0212, 2.0230,
#          2.0215, 2.0212, 2.0235, 2.0204, 2.0220, 2.0200, 2.0203, 2.0227, 2.0214,
#          2.0205, 2.0208, 2.0233, 2.0195, 2.0194, 2.0192, 2.0257, 2.0193, 2.0185,
#          2.0195, 2.0186, 2.0186, 2.0239, 2.0177, 2.0202, 2.0173, 2.0214, 2.0189,
#          2.0175, 2.0184, 2.0199, 2.0186, 2.0173, 2.0171, 2.0190, 2.0229, 2.0173,
#          2.0174, 2.0198, 2.0198, 2.0159, 2.0168, 2.0172, 2.0163, 2.0178, 2.0156,
#          2.0184, 2.0153, 2.0182, 2.0152, 2.0177, 2.0161, 2.0148, 2.0172, 2.0224,
#          2.0177, 2.0152, 2.0183, 2.0145, 2.0145, 2.0151, 2.0156, 2.0152, 2.0152,
#          2.0161, 2.0158, 2.0157, 2.0159, 2.0168, 2.0177, 2.0159, 2.0171, 2.0157,
#          2.0152, 2.0180, 2.0156, 2.0139, 2.0177, 2.0141, 2.0132, 2.0118, 2.0133,
#          2.0133, 2.0156, 2.0147, 2.0135, 2.0130, 2.0140, 2.0133, 2.0127, 2.0149,
#          2.0143, 2.0125, 2.0125, 2.0122, 2.0125, 2.0133, 2.0129, 2.0120, 2.0126,
#          2.0116, 2.0113, 2.0144, 2.0105, 2.0133, 2.0117, 2.0126, 2.0115, 2.0120,
#          2.0119, 2.0130, 2.0099, 2.0112, 2.0111, 2.0107, 2.0104, 2.0108, 2.0131,
#          2.0086, 2.0105, 2.0113, 2.0105, 2.0131, 2.0095, 2.0101, 2.0119, 2.0092,
#          2.0089, 2.0091, 2.0091, 2.0089, 2.0098, 2.0128, 2.0108, 2.0084, 2.0130,
#          2.0095, 2.0113, 2.0083, 2.0090, 2.0116, 2.0077, 2.0084, 2.0099, 2.0079,
#          2.0080, 2.0084, 2.0077, 2.0066, 2.0067, 2.0074, 2.0080, 2.0073, 2.0078,
#          2.0081, 2.0083, 2.0061, 2.0072, 2.0102, 2.0094, 2.0063, 2.0074, 2.0094,
#          2.0084, 2.0055, 2.0123, 2.0077, 2.0067]),
#  tensor([2.3214, 2.2969, 2.2884, 2.3226, 2.3418, 2.3038, 2.3067, 2.2963, 2.3190,
#          2.3109, 2.2948, 2.2582, 2.3171, 2.2590, 2.2950, 2.3252, 2.3009, 2.2927,
#          2.2916, 2.3506, 2.3029, 2.2976, 2.3472, 2.3550, 2.3507, 2.3403, 2.3566,
#          2.3628, 2.3526, 2.3535, 2.3249, 2.3041, 2.3451, 2.3498, 2.3509, 2.3536,
#          2.3436, 2.3111, 2.3260, 2.3190, 2.2852, 2.2815, 2.3178, 2.3076, 2.3193,
#          2.3221, 2.3297, 2.3179, 2.3298, 2.2652, 2.2732, 2.2746, 2.2534, 2.2579,
#          2.3070, 2.2774, 2.2689, 2.2990, 2.3174, 2.3262, 2.3192, 2.3072, 2.3408,
#          2.2897, 2.3027, 2.3476, 2.3053, 2.2793, 2.3153, 2.2700, 2.2806, 2.2581,
#          2.2335, 2.2692, 2.2765, 2.3001, 2.2806, 2.3018, 2.2968, 2.2891, 2.3179,
#          2.2863, 2.2809, 2.3317, 2.3099, 2.2841, 2.2847, 2.2555, 2.2775, 2.2950,
#          2.2119, 2.3007, 2.2706, 2.2861, 2.2657, 2.3128, 2.2821, 2.2350, 2.3180,
#          2.2567, 2.3002, 2.2561, 2.2613, 2.2836, 2.2620, 2.2429, 2.2441, 2.2680,
#          2.2865, 2.2440, 2.2261, 2.2476, 2.2887, 2.2835, 2.2092, 2.2674, 2.2524,
#          2.3097, 2.2899, 2.2882, 2.2626, 2.2427, 2.2849, 2.2685, 2.2768, 2.3011,
#          2.2768, 2.3099, 2.2979, 2.2910, 2.2884, 2.2595, 2.3348, 2.3056, 2.2654,
#          2.2986, 2.2709, 2.3156, 2.2844, 2.3153, 2.2670, 2.2599, 2.2472, 2.2745,
#          2.2507, 2.2789, 2.2673, 2.2815, 2.2621, 2.2827, 2.3034, 2.2375, 2.2580,
#          2.2334, 2.2871, 2.2482, 2.2485, 2.2553, 2.2717, 2.2553, 2.2527, 2.2438,
#          2.2541, 2.2511, 2.2606, 2.2524, 2.2664, 2.2284, 2.2568, 2.2660, 2.2629,
#          2.2695, 2.2640, 2.2874, 2.2567, 2.2399, 2.2673, 2.2680, 2.2521, 2.3178,
#          2.2937, 2.2965, 2.2565, 2.2809, 2.2796, 2.2620, 2.2811, 2.2142, 2.2818,
#          2.2666, 2.2227, 2.2906, 2.2629, 2.2480, 2.2258, 2.2690, 2.2646, 2.2452,
#          2.2470, 2.2709, 2.2465, 2.2724, 2.1915, 2.2442, 2.2467, 2.2273, 2.2486,
#          2.2686, 2.2542, 2.2403, 2.2390, 2.2674, 2.2651, 2.2640, 2.1933, 2.1901,
#          2.2543, 2.2328, 2.2832, 2.2485, 2.2724, 2.2366, 2.2864, 2.2269, 2.2423,
#          2.2666, 2.2589, 2.2413, 2.2600, 2.2536, 2.2664, 2.2619, 2.2673, 2.2288,
#          2.2723, 2.2667, 2.1911, 2.2829, 2.2562, 2.2158, 2.2454, 2.2427, 2.2364,
#          2.2159, 2.2297, 2.2371, 2.2377, 2.2005, 2.1875, 2.2018, 2.2363, 2.2624,
#          2.2294, 2.1950, 2.2327, 2.2463, 2.2206, 2.2609, 2.2436, 2.2185, 2.2555,
#          2.2489, 2.2793, 2.2532, 2.2401, 2.2023, 2.2320, 2.2406, 2.2205, 2.2476,
#          2.2560, 2.2353, 2.2444, 2.2321, 2.2652, 2.2220, 2.2192, 2.2643, 2.2542,
#          2.2407, 2.2164, 2.2493, 2.2432, 2.2609, 2.2526, 2.2549, 2.2626, 2.2454,
#          2.2210, 2.2195, 2.2697, 2.2207, 2.2613, 2.2492, 2.2514, 2.2396, 2.2852,
#          2.2728, 2.2717, 2.2346, 2.2554, 2.2476, 2.2641, 2.1954, 2.2569, 2.2112,
#          2.2516, 2.2530, 2.2604, 2.2143, 2.2711, 2.2237, 2.2451, 2.2070, 2.2638,
#          2.2397, 2.2664, 2.2187, 2.2120, 2.2544, 2.2464, 2.2635, 2.2102, 2.2354,
#          2.2002, 2.2458, 2.2360, 2.2468, 2.2409, 2.2200, 2.2519, 2.2725, 2.2831,
#          2.2228, 2.2682, 2.2260, 2.2494, 2.2396, 2.2131, 2.2460, 2.2360, 2.2238,
#          2.2571, 2.2300, 2.2440, 2.2415, 2.2719, 2.2377, 2.2666, 2.2469, 2.2542,
#          2.2524, 2.2388, 2.2358, 2.2760, 2.2159, 2.2330, 2.2522, 2.2620, 2.2754,
#          2.2701, 2.2545, 2.2232, 2.2626, 2.2468, 2.2289, 2.2649, 2.2664, 2.2372,
#          2.2437, 2.2653, 2.2311, 2.2552, 2.2462, 2.2273, 2.2506, 2.2498, 2.2229,
#          2.2533, 2.2431, 2.2591, 2.2255, 2.2340, 2.2456, 2.2360, 2.2012, 2.1810,
#          2.2214, 2.2387, 2.2028, 2.2204, 2.2381, 2.2336, 2.2336, 2.2332, 2.2205,
#          2.2353, 2.2434, 2.2180, 2.2250, 2.2627, 2.2107, 2.2621, 2.2579, 2.2407,
#          2.2546, 2.2398, 2.2543, 2.2549, 2.2181, 2.2303, 2.2597, 2.2752, 2.2488,
#          2.2526, 2.2509, 2.2762, 2.2520, 2.2228, 2.2338, 2.2382, 2.2467, 2.2405,
#          2.2608, 2.2423, 2.2521, 2.2390, 2.2461, 2.2522, 2.2458, 2.2399, 2.2464,
#          2.2508, 2.2313, 2.2319, 2.2365, 2.2398, 2.2560, 2.2273, 2.2470, 2.2424,
#          2.2391, 2.2625, 2.2210, 2.2560, 2.2564, 2.2478, 2.2577, 2.2352, 2.2262,
#          2.2530, 2.2445, 2.2254, 2.2413, 2.2725, 2.2336, 2.2537, 2.2620, 2.2748,
#          2.2608, 2.2508, 2.2735, 2.2669, 2.2723, 2.2178, 2.2646, 2.2708, 2.2505,
#          2.2719, 2.2521, 2.2665, 2.2738, 2.2569, 2.2584, 2.3065, 2.2659, 2.2446,
#          2.2565, 2.2486, 2.2520, 2.2271, 2.2767, 2.2416, 2.2655, 2.2588, 2.2708,
#          2.2578, 2.2485, 2.2482, 2.2460, 2.2470, 2.2596, 2.2635, 2.2398, 2.2322,
#          2.2650, 2.2521, 2.2329, 2.2681, 2.2495]),
#  tensor([0.6173, 0.6170, 0.6174, 0.6172, 0.6170, 0.6177, 0.6171, 0.6172, 0.6172,
#          0.6172, 0.6177, 0.6170, 0.6165, 0.6167, 0.6165, 0.6171, 0.6167, 0.6173,
#          0.6164, 0.6172, 0.6166, 0.6176, 0.6167, 0.6168, 0.6175, 0.6167, 0.6170,
#          0.6173, 0.6170, 0.6176, 0.6170, 0.6176, 0.6175, 0.6177, 0.6175, 0.6169,
#          0.6172, 0.6169, 0.6168, 0.6176, 0.6176, 0.6174, 0.6174, 0.6178, 0.6165,
#          0.6176, 0.6176, 0.6178, 0.6173, 0.6181, 0.6177, 0.6178, 0.6166, 0.6177,
#          0.6178, 0.6176, 0.6175, 0.6171, 0.6180, 0.6178, 0.6181, 0.6177, 0.6173,
#          0.6178, 0.6175, 0.6173, 0.6170, 0.6180, 0.6174, 0.6176, 0.6177, 0.6178,
#          0.6177, 0.6171, 0.6175, 0.6177, 0.6178, 0.6182, 0.6178, 0.6178, 0.6176,
#          0.6178, 0.6178, 0.6179, 0.6181, 0.6179, 0.6183, 0.6167, 0.6180, 0.6173,
#          0.6174, 0.6181, 0.6182, 0.6179, 0.6182, 0.6186, 0.6178, 0.6176, 0.6180,
#          0.6176, 0.6181, 0.6174, 0.6180, 0.6179, 0.6184, 0.6183, 0.6178, 0.6180,
#          0.6178, 0.6181, 0.6180, 0.6181, 0.6183, 0.6186, 0.6181, 0.6185, 0.6176,
#          0.6177, 0.6183, 0.6186, 0.6179, 0.6183, 0.6182, 0.6180, 0.6185, 0.6180,
#          0.6174, 0.6185, 0.6185, 0.6181, 0.6186, 0.6183, 0.6188, 0.6190, 0.6182,
#          0.6188, 0.6184, 0.6186, 0.6189, 0.6187, 0.6186, 0.6184, 0.6184, 0.6188,
#          0.6181, 0.6189, 0.6180, 0.6187, 0.6185, 0.6182, 0.6186, 0.6186, 0.6183,
#          0.6176, 0.6187, 0.6183, 0.6182, 0.6184, 0.6185, 0.6184, 0.6183, 0.6186,
#          0.6186, 0.6184, 0.6179, 0.6184, 0.6184, 0.6185, 0.6182, 0.6185, 0.6186,
#          0.6182, 0.6187, 0.6191, 0.6186, 0.6189, 0.6186, 0.6182, 0.6187, 0.6192,
#          0.6182, 0.6178, 0.6189, 0.6185, 0.6191, 0.6192, 0.6186, 0.6192, 0.6189,
#          0.6188, 0.6181, 0.6189, 0.6187, 0.6183, 0.6189, 0.6185, 0.6187, 0.6190,
#          0.6190, 0.6189, 0.6190, 0.6189, 0.6187, 0.6191, 0.6191, 0.6190, 0.6185,
#          0.6187, 0.6194, 0.6187, 0.6191, 0.6192, 0.6193, 0.6188, 0.6189, 0.6189,
#          0.6184, 0.6192, 0.6191, 0.6183, 0.6186, 0.6190, 0.6193, 0.6192, 0.6189,
#          0.6193, 0.6197, 0.6193, 0.6192, 0.6194, 0.6194, 0.6196, 0.6194, 0.6190,
#          0.6187, 0.6191, 0.6190, 0.6186, 0.6189, 0.6191, 0.6190, 0.6194, 0.6195,
#          0.6188, 0.6196, 0.6196, 0.6194, 0.6191, 0.6193, 0.6195, 0.6186, 0.6197,
#          0.6195, 0.6187, 0.6188, 0.6191, 0.6188, 0.6193, 0.6194, 0.6194, 0.6196,
#          0.6194, 0.6189, 0.6191, 0.6197, 0.6198, 0.6198, 0.6197, 0.6194, 0.6194,
#          0.6195, 0.6200, 0.6196, 0.6195, 0.6188, 0.6199, 0.6199, 0.6199, 0.6199,
#          0.6196, 0.6199, 0.6199, 0.6197, 0.6199, 0.6201, 0.6193, 0.6203, 0.6200,
#          0.6206, 0.6199, 0.6201, 0.6198, 0.6194, 0.6197, 0.6198, 0.6197, 0.6194,
#          0.6194, 0.6203, 0.6197, 0.6204, 0.6198, 0.6193, 0.6199, 0.6202, 0.6200,
#          0.6203, 0.6197, 0.6198, 0.6198, 0.6200, 0.6199, 0.6206, 0.6204, 0.6203,
#          0.6200, 0.6204, 0.6205, 0.6206, 0.6207, 0.6203, 0.6200, 0.6201, 0.6204,
#          0.6207, 0.6206, 0.6199, 0.6206, 0.6205, 0.6210, 0.6206, 0.6206, 0.6203,
#          0.6206, 0.6205, 0.6203, 0.6207, 0.6205, 0.6211, 0.6206, 0.6203, 0.6206,
#          0.6208, 0.6206, 0.6201, 0.6209, 0.6208, 0.6210, 0.6199, 0.6205, 0.6206,
#          0.6207, 0.6209, 0.6209, 0.6201, 0.6207, 0.6203, 0.6210, 0.6205, 0.6206,
#          0.6211, 0.6205, 0.6205, 0.6205, 0.6211, 0.6208, 0.6209, 0.6208, 0.6211,
#          0.6212, 0.6205, 0.6211, 0.6211, 0.6215, 0.6210, 0.6216, 0.6206, 0.6211,
#          0.6208, 0.6215, 0.6211, 0.6212, 0.6210, 0.6211, 0.6210, 0.6211, 0.6202,
#          0.6208, 0.6209, 0.6209, 0.6214, 0.6214, 0.6211, 0.6207, 0.6212, 0.6211,
#          0.6208, 0.6209, 0.6212, 0.6212, 0.6207, 0.6207, 0.6206, 0.6211, 0.6209,
#          0.6211, 0.6208, 0.6212, 0.6215, 0.6212, 0.6215, 0.6213, 0.6218, 0.6215,
#          0.6215, 0.6207, 0.6211, 0.6211, 0.6214, 0.6213, 0.6211, 0.6218, 0.6209,
#          0.6212, 0.6218, 0.6216, 0.6216, 0.6218, 0.6210, 0.6213, 0.6212, 0.6215,
#          0.6215, 0.6218, 0.6205, 0.6215, 0.6210, 0.6214, 0.6213, 0.6215, 0.6216,
#          0.6213, 0.6211, 0.6220, 0.6215, 0.6214, 0.6215, 0.6217, 0.6220, 0.6210,
#          0.6219, 0.6215, 0.6217, 0.6214, 0.6214, 0.6220, 0.6219, 0.6214, 0.6222,
#          0.6220, 0.6216, 0.6219, 0.6219, 0.6219, 0.6210, 0.6217, 0.6220, 0.6213,
#          0.6220, 0.6216, 0.6223, 0.6214, 0.6214, 0.6222, 0.6220, 0.6221, 0.6222,
#          0.6218, 0.6221, 0.6223, 0.6220, 0.6218, 0.6219, 0.6218, 0.6224, 0.6221,
#          0.6219, 0.6220, 0.6222, 0.6223, 0.6218, 0.6222, 0.6223, 0.6218, 0.6217,
#          0.6222, 0.6225, 0.6219, 0.6223, 0.6225]))

# %%
# batchLoss

# %%
# batchAcc

# %%
# yHat.shape, y.shape

# %%
# yHat_test.shape, yy.shape

# %%
yHat1.flatten(), y1.flatten()
# Out:
# (tensor([1.9715, 1.1684, 7.7402, 4.6340, 0.0000, 3.3240, 1.0605, 5.0713, 2.0491,
#          0.0000, 7.9176, 4.5561, 0.0000, 2.4164, 1.0597, 5.1364, 2.0226, 0.0000,
#          5.1455, 4.6159, 0.0000, 3.3069, 1.0726, 5.1838, 1.9617, 1.1825, 3.4744,
#          4.5646, 0.0000, 6.5495, 1.0600, 4.8448, 1.9587, 1.2453, 8.7864, 3.3297,
#          0.0000, 7.4151, 1.3620, 1.0669, 1.0075, 8.8872, 4.9877, 4.5784, 0.0000,
#          1.5323, 1.0671, 4.8219, 1.0009, 7.9683, 0.0000, 4.7459, 0.0000, 3.0965,
#          1.0191, 5.1539, 2.0020, 0.0000, 8.8231, 4.4086, 0.9264, 1.2073, 1.0680,
#          4.7524, 1.0110, 8.9814, 6.3037, 4.5556, 0.9563, 2.2523, 1.0689, 4.8759,
#          1.0036, 9.0105, 0.0000, 3.9636, 0.0000, 6.5275, 1.1849, 3.0000, 1.9665,
#          1.1661, 6.0892, 4.5571, 0.0000, 7.3782, 1.0508, 4.9924, 1.9691, 1.1918,
#          7.8870, 4.5819, 0.0000, 2.5548, 1.0674, 4.9282, 2.0420, 0.0000, 7.7161,
#          3.9669, 0.0000, 4.1549, 1.2069, 3.5266, 2.0443, 0.0000, 7.7832, 4.5089,
#          0.0000, 1.2265, 1.0789, 5.0574, 1.0036, 9.0011, 0.0000, 4.0145, 0.0000,
#          6.5071, 1.1665, 3.1731, 1.0304, 7.8503, 0.0000, 4.2851, 0.0000, 8.5984,
#          1.1479, 1.9903, 1.0064, 8.9073, 2.7430, 4.5824, 0.0000, 5.9992, 1.0398,
#          4.8926, 1.9640, 1.1800, 5.0266, 4.5968, 0.0000, 1.5377, 1.0883, 4.8146,
#          1.9613, 1.2230, 6.1159, 4.3910, 1.0314, 0.0000, 1.0913, 4.5873, 2.0054,
#          0.0000, 8.8789, 4.4013, 0.9207, 2.3493, 1.0708, 4.7110, 1.0125, 9.1011,
#          6.8199, 4.4762, 0.9511, 1.3806, 1.0687, 4.7627, 1.0049, 8.9763, 0.7920,
#          4.4460, 0.0000, 6.4986, 1.0612, 4.5101, 1.0037, 7.9293, 0.0000, 3.5202,
#          0.0000, 7.4455, 1.3134, 0.9555, 1.0042, 7.9642, 0.0000, 4.8037, 0.0000,
#          2.2819, 1.0043, 5.1953, 1.0123, 7.9873, 8.9250, 4.6425, 0.0000, 6.0192,
#          1.0297, 4.9677, 1.0129, 7.9952, 9.0047, 4.5471, 0.0000, 2.1135, 1.0468,
#          4.6999, 1.9619, 1.1751, 1.5169, 4.5103, 0.0000, 6.6425, 1.0493, 4.7575,
#          1.0066, 8.9933, 3.3824, 4.3390, 0.0000, 5.1202, 1.1110, 4.1231, 1.9584,
#          0.0000, 0.0000, 4.6463, 0.0000, 7.6184, 0.8266, 6.3632, 1.9779, 1.4439,
#          1.1895, 4.3345, 1.0295, 0.0000, 1.0479, 4.5932, 1.0021, 7.9806, 5.0295,
#          4.6988, 0.0000, 7.3647, 1.0333, 5.1044, 2.0253, 0.0000, 3.6009, 4.4768,
#          0.0000, 4.8927, 1.1238, 4.7164], grad_fn=<ReshapeAliasBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
yHat_test1, yy1
# Out:
# (tensor([[1.0039, 7.9717, 1.0403, 4.6387, 0.0000, 5.9889, 1.0396, 4.8807]]),
#  tensor([[1., 8., 1., 6., 0., 6., 0., 1.]]))

# %%
yy1
# Out:
# tensor([[1., 8., 1., 6., 0., 6., 0., 1.]])

# %%
(yHat_test1).round()
# Out:
# tensor([[1., 8., 1., 5., 0., 6., 1., 5.]])

# %%
(yHat1.flatten()).round(), (y1.flatten()).round()
# Out:
# (tensor([2., 1., 8., 5., 0., 3., 1., 5., 2., 0., 8., 5., 0., 2., 1., 5., 2., 0.,
#          5., 5., 0., 3., 1., 5., 2., 1., 3., 5., 0., 7., 1., 5., 2., 1., 9., 3.,
#          0., 7., 1., 1., 1., 9., 5., 5., 0., 2., 1., 5., 1., 8., 0., 5., 0., 3.,
#          1., 5., 2., 0., 9., 4., 1., 1., 1., 5., 1., 9., 6., 5., 1., 2., 1., 5.,
#          1., 9., 0., 4., 0., 7., 1., 3., 2., 1., 6., 5., 0., 7., 1., 5., 2., 1.,
#          8., 5., 0., 3., 1., 5., 2., 0., 8., 4., 0., 4., 1., 4., 2., 0., 8., 5.,
#          0., 1., 1., 5., 1., 9., 0., 4., 0., 7., 1., 3., 1., 8., 0., 4., 0., 9.,
#          1., 2., 1., 9., 3., 5., 0., 6., 1., 5., 2., 1., 5., 5., 0., 2., 1., 5.,
#          2., 1., 6., 4., 1., 0., 1., 5., 2., 0., 9., 4., 1., 2., 1., 5., 1., 9.,
#          7., 4., 1., 1., 1., 5., 1., 9., 1., 4., 0., 6., 1., 5., 1., 8., 0., 4.,
#          0., 7., 1., 1., 1., 8., 0., 5., 0., 2., 1., 5., 1., 8., 9., 5., 0., 6.,
#          1., 5., 1., 8., 9., 5., 0., 2., 1., 5., 2., 1., 2., 5., 0., 7., 1., 5.,
#          1., 9., 3., 4., 0., 5., 1., 4., 2., 0., 0., 5., 0., 8., 1., 6., 2., 1.,
#          1., 4., 1., 0., 1., 5., 1., 8., 5., 5., 0., 7., 1., 5., 2., 0., 4., 4.,
#          0., 5., 1., 5.], grad_fn=<RoundBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
print_score(X.shape, yHat1, y1, yHat_test1, yy1)
# Out:
# Adjusted R-Squared(y, yHat): 0.6256
#
#
# mean_absolute_error(y, yHat): 0.7862
#
# mean_absolute_error(yy, yHat_test): 0.7956
#
#
# mean_squared_error(y, yHat): 2.2188
#
# mean_squared_error(yy, yHat_test): 2.2495
#
#
# mean_squared_log_error(y, yHat): 0.1708
#
# mean_squared_log_error(yy, yHat_test): 0.2148
#
#
# RMSE(y, yHat): 1.4896
#
# RMSE(yy, yHat_test): 1.4998

# %%
# create a 1D smoothing filter
def smooth(x, k=15):
    return np.convolve(x, np.ones(k)/k, mode='same')

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Train loss')
ax[0].legend()



ax[1].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Test loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss1.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc1, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat1.detach().T, y1.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc1.jpg", bbox_inches='tight')


plt.show()

# %%
data.leap_year.value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
resampler = SMOTE(k_neighbors=20, random_state=0)

# %%
X_res, y_res = resampler.fit_resample(data[['day_code', 'month_code', 'decade', 'date_int']], data['leap_year'])

# %%
y_res.value_counts()
# Out:
# 0    110960
# 1    110960
# Name: leap_year, dtype: int64

# %%
data['leap_year'].value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 221915    1
# 221916    1
# 221917    1
# 221918    1
# 221919    1
# Name: leap_year, Length: 221920, dtype: int64

# %%
X_res
# Out:
#         day_code  month_code  decade  date_int
# 0              4           0     180  18000101
# 1              5           0     180  18010101
# 2              6           0     180  18020101
# 3              0           0     180  18030101
# 4              1           0     180  18040101
# ...          ...         ...     ...       ...
# 221915         0           5     188  18880618
# 221916         2           6     188  18840705
# 221917         5           2     218  21800323
# 221918         1           5     199  19960602
# 221919         1           4     219  21960520
#
# [221920 rows x 4 columns]

# %%
X_smote = X_res.assign(leap_year=y_res)

# %%
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221915         0           5     188  18880618          1
# 221916         2           6     188  18840705          1
# 221917         5           2     218  21800323          1
# 221918         1           5     199  19960602          1
# 221919         1           4     219  21960520          1
#
# [221920 rows x 5 columns]

# %% [markdown]
# Drop 220 decade

# %%
# data.decade.value_counts().plot(kind="bar")
X_smote.decade.value_counts().plot(kind="bar")

# %%
# data.decade.value_counts()[-5:]
X_smote.decade.value_counts()[-5:]
# Out:
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# 220     365
# Name: decade, dtype: int64

# %%
X_smote = X_smote.drop(X_smote.index[X_smote['decade'] == 220]).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221550         0           5     188  18880618          1
# 221551         2           6     188  18840705          1
# 221552         5           2     218  21800323          1
# 221553         1           5     199  19960602          1
# 221554         1           4     219  21960520          1
#
# [221555 rows x 5 columns]

# %%
X_smote.decade.value_counts().plot(kind="bar")

# %%
X_smote.decade.value_counts()[-5:]
# Out:
# 209    5174
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# Name: decade, dtype: int64

# %% [markdown]
# code is required to only work for dates in the range  [ 1-1-1800 to 31-12-2200 ]

# %%
X_smote.date_int.max()
# Out:
# 21991231

# %%
datetime.datetime.strptime(str(X_smote.date_int.max()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '31-12-2199'

# %%
X_smote.date_int.min()
# Out:
# 18000101

# %%
datetime.datetime.strptime(str(X_smote.date_int.min()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '01-01-1800'

# %%
Y_smote = X_smote['date_int']
Y_smote
# Out:
# 0         18000101
# 1         18010101
# 2         18020101
# 3         18030101
# 4         18040101
#             ...
# 221550    18880618
# 221551    18840705
# 221552    21800323
# 221553    19960602
# 221554    21960520
# Name: date_int, Length: 221555, dtype: int64

# %%
X_smote = X_smote.drop('date_int', axis=1).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  leap_year
# 0              4           0     180          0
# 1              5           0     180          0
# 2              6           0     180          0
# 3              0           0     180          0
# 4              1           0     180          1
# ...          ...         ...     ...        ...
# 221550         0           5     188          1
# 221551         2           6     188          1
# 221552         5           2     218          1
# 221553         1           5     199          1
# 221554         1           4     219          1
#
# [221555 rows x 4 columns]

# %%
Y_smote = Y_smote.reset_index(drop=True)

ls = []

for s in Y_smote.astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(Y_smote)), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y_smote = ll.values

Y_smote
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
# data.index[data['leap_year'] == 1].tolist()
# data.index[data['leap_year'] == 1]

# %%
# for i,idx in enumerate(data['leap_year'].tolist()):
#     print(i, idx)

# %% [markdown]
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1 <---
# 5 0
# 6 0
# 7 0
# 8 1 <---
# 9 0
# 10 0
# 11 0
# 12 1 <---
# 13 0
# 14 0
# 15 0
# 16 1 <---
# 17 0
# 18 0
# 19 0
# 20 1 <---
# 21 0
# 22 0
# 23 0
# 24 1 <---
# 25 0
# 26 0
# 27 0
# 28 1 <---
# 29 0
# 30 0

# %%
scaler_day_smote = RobustScaler()

x = X_smote.day_code.values.reshape(-1, 1)

X_smote['day_scaled'] = scaler_day_smote.fit_transform(x).flatten()

# %%
X_smote['day_sin'] = np.sin(X_smote['day_code'] * (2 * np.pi / 7))
X_smote['day_cos'] = np.cos(X_smote['day_code'] * (2 * np.pi / 7))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos
# 0      -0.900969
# 1      -0.222521
# 2       0.623490
# 3       1.000000
# 4       0.623490
# ...          ...
# 221550  1.000000
# 221551 -0.222521
# 221552 -0.222521
# 221553  0.623490
# 221554  0.623490
#
# [221555 rows x 7 columns]

# %%
scaler_month_smote = RobustScaler()

x = X_smote.month_code.values.reshape(-1, 1)

X_smote['month_scaled'] = scaler_month_smote.fit_transform(x).flatten()

# %%
X_smote['month_sin'] = np.sin(X_smote['month_code'] * (2 * np.pi / 12))
X_smote['month_cos'] = np.cos(X_smote['month_code'] * (2 * np.pi / 12))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos
# 0      -0.900969     -1.000000  0.000000e+00   1.000000
# 1      -0.222521     -1.000000  0.000000e+00   1.000000
# 2       0.623490     -1.000000  0.000000e+00   1.000000
# 3       1.000000     -1.000000  0.000000e+00   1.000000
# 4       0.623490     -1.000000  0.000000e+00   1.000000
# ...          ...           ...           ...        ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000
#
# [221555 rows x 10 columns]

# %%
scaler_decade_smote = RobustScaler()

x = X_smote.decade.values.reshape(-1, 1)

X_smote['decade_scaled'] = scaler_decade_smote.fit_transform(x).flatten()

# %%
# alpha_smote = len(X_smote.decade.unique())
alpha_smote = (X_smote.decade.iloc[-1] - X_smote.decade.iloc[0]) + 1

X_smote['decade_sin'] = np.sin(X_smote['decade'] * (2 * np.pi / alpha_smote))
X_smote['decade_cos'] = np.cos(X_smote['decade'] * (2 * np.pi / alpha_smote))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos  decade_scaled  \
# 0      -0.900969     -1.000000  0.000000e+00   1.000000      -1.052632
# 1      -0.222521     -1.000000  0.000000e+00   1.000000      -1.052632
# 2       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# 3       1.000000     -1.000000  0.000000e+00   1.000000      -1.052632
# 4       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# ...          ...           ...           ...        ...            ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025      -0.631579
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000      -0.631579
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000       0.947368
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025      -0.052632
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000       1.000000
#
#           decade_sin  decade_cos
# 0       1.102182e-15   -1.000000
# 1       1.102182e-15   -1.000000
# 2       1.102182e-15   -1.000000
# 3       1.102182e-15   -1.000000
# 4       1.102182e-15   -1.000000
# ...              ...         ...
# 221550 -9.510565e-01   -0.309017
# 221551 -9.510565e-01   -0.309017
# 221552  3.090170e-01   -0.951057
# 221553 -1.564345e-01    0.987688
# 221554  1.564345e-01   -0.987688
#
# [221555 rows x 13 columns]

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
X = X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 3.33333333e-01, -4.33883739e-01, -9.00968868e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 1.00000000e+00, -7.81831482e-01,  6.23489802e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        ...,
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#          9.47368421e-01,  3.09016994e-01, -9.51056516e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#         -5.26315789e-02, -1.56434465e-01,  9.87688341e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#          1.00000000e+00,  1.56434465e-01, -9.87688341e-01]])

# %%
X.shape
# Out:
# (221555, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()
# Y = data['date_normalized'].values.reshape(-1, 1)
Y = Y_smote


Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
Y.shape
# Out:
# (221555, 8)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64

train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (221555, 10)
#
# Y: (221555, 8)
#
# Train data:   (155088, 10)
#
# Train labels: (155088, 8)
#
# Test data:    (66467, 10)
#
# Test labels:  (66467, 8)

# %%
model_smote = Model().to(device)


checkpoint = torch.load('checkpoint.pth.tar', map_location=torch.device('cpu'))
model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
# Out:
# <All keys matched successfully>

# %%
# numepochs = 120
# numepochs = 300
numepochs = 500



trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model_smote, numepochs)
# Out:
# Epoch 1/500, Train Loss: 1.692553, Test Loss: 4.490122
# Epoch 2/500, Train Loss: 1.704190, Test Loss: 4.537430
# Epoch 3/500, Train Loss: 1.725570, Test Loss: 4.548097
# Epoch 4/500, Train Loss: 1.695047, Test Loss: 4.435469
# Epoch 5/500, Train Loss: 1.728844, Test Loss: 4.470009
# Epoch 6/500, Train Loss: 1.705480, Test Loss: 4.459423
# Epoch 7/500, Train Loss: 1.720747, Test Loss: 4.442179
# Epoch 8/500, Train Loss: 1.718558, Test Loss: 4.274334
# Epoch 9/500, Train Loss: 1.694707, Test Loss: 4.235757
# Epoch 10/500, Train Loss: 1.688607, Test Loss: 4.041166
# Epoch 11/500, Train Loss: 1.719651, Test Loss: 4.369425
# Epoch 12/500, Train Loss: 1.737678, Test Loss: 4.329165
# Epoch 13/500, Train Loss: 1.729891, Test Loss: 4.361016
# Epoch 14/500, Train Loss: 1.682246, Test Loss: 4.409105
# Epoch 15/500, Train Loss: 1.690676, Test Loss: 4.372879
# Epoch 16/500, Train Loss: 1.708635, Test Loss: 4.358975
# Epoch 17/500, Train Loss: 1.738593, Test Loss: 4.448163
# Epoch 18/500, Train Loss: 1.713185, Test Loss: 4.236937
# Epoch 19/500, Train Loss: 1.707989, Test Loss: 4.236349
# Epoch 20/500, Train Loss: 1.717482, Test Loss: 4.344107
# Epoch 21/500, Train Loss: 1.757760, Test Loss: 4.457526
# Epoch 22/500, Train Loss: 1.721827, Test Loss: 4.464947
# Epoch 23/500, Train Loss: 1.714311, Test Loss: 4.453347
# Epoch 24/500, Train Loss: 1.704467, Test Loss: 4.294526
# Epoch 25/500, Train Loss: 1.710435, Test Loss: 4.693973
# Epoch 26/500, Train Loss: 1.692182, Test Loss: 4.299476
# Epoch 27/500, Train Loss: 1.734249, Test Loss: 4.344682
# Epoch 28/500, Train Loss: 1.697660, Test Loss: 4.405850
# Epoch 29/500, Train Loss: 1.705715, Test Loss: 4.178655
# Epoch 30/500, Train Loss: 1.694957, Test Loss: 4.358541
# Epoch 31/500, Train Loss: 1.694016, Test Loss: 4.476291
# Epoch 32/500, Train Loss: 1.693457, Test Loss: 4.361058
# Epoch 33/500, Train Loss: 1.671667, Test Loss: 4.405708
# Epoch 34/500, Train Loss: 1.719775, Test Loss: 4.272263
# Epoch 35/500, Train Loss: 1.716271, Test Loss: 4.280933
# Epoch 36/500, Train Loss: 1.700275, Test Loss: 4.418276
# Epoch 37/500, Train Loss: 1.686776, Test Loss: 4.502758
# Epoch 38/500, Train Loss: 1.698196, Test Loss: 4.524818
# Epoch 39/500, Train Loss: 1.720518, Test Loss: 4.419685
# Epoch 40/500, Train Loss: 1.700598, Test Loss: 4.505152
# Epoch 41/500, Train Loss: 1.672912, Test Loss: 4.330291
# Epoch 42/500, Train Loss: 1.665966, Test Loss: 4.466439
# Epoch 43/500, Train Loss: 1.703787, Test Loss: 4.581368
# Epoch 44/500, Train Loss: 1.678007, Test Loss: 4.415144
# Epoch 45/500, Train Loss: 1.677785, Test Loss: 4.417405
# Epoch 46/500, Train Loss: 1.704405, Test Loss: 4.470581
# Epoch 47/500, Train Loss: 1.691389, Test Loss: 4.560652
# Epoch 48/500, Train Loss: 1.687335, Test Loss: 4.505270
# Epoch 49/500, Train Loss: 1.681645, Test Loss: 4.626974
# Epoch 50/500, Train Loss: 1.684227, Test Loss: 4.487591
# Epoch 51/500, Train Loss: 1.679614, Test Loss: 4.512139
# Epoch 52/500, Train Loss: 1.681325, Test Loss: 4.528381
# Epoch 53/500, Train Loss: 1.667646, Test Loss: 4.819806
# Epoch 54/500, Train Loss: 1.668127, Test Loss: 4.500166
# Epoch 55/500, Train Loss: 1.690341, Test Loss: 4.711971
# Epoch 56/500, Train Loss: 1.685997, Test Loss: 4.583305
# Epoch 57/500, Train Loss: 1.673675, Test Loss: 4.650679
# Epoch 58/500, Train Loss: 1.674361, Test Loss: 4.502960
# Epoch 59/500, Train Loss: 1.680932, Test Loss: 4.396334
# Epoch 60/500, Train Loss: 1.669736, Test Loss: 4.490904
# Epoch 61/500, Train Loss: 1.658016, Test Loss: 4.641482
# Epoch 62/500, Train Loss: 1.680745, Test Loss: 4.491629
# Epoch 63/500, Train Loss: 1.675650, Test Loss: 4.453982
# Epoch 64/500, Train Loss: 1.695125, Test Loss: 4.489165
# Epoch 65/500, Train Loss: 1.658702, Test Loss: 4.513667
# Epoch 66/500, Train Loss: 1.672068, Test Loss: 4.427114
# Epoch 67/500, Train Loss: 1.668259, Test Loss: 4.530790
# Epoch 68/500, Train Loss: 1.692458, Test Loss: 4.678478
# Epoch 69/500, Train Loss: 1.659027, Test Loss: 4.508206
# Epoch 70/500, Train Loss: 1.680067, Test Loss: 4.751417
# Epoch 71/500, Train Loss: 1.658059, Test Loss: 4.579667
# Epoch 72/500, Train Loss: 1.681928, Test Loss: 4.688635
# Epoch 73/500, Train Loss: 1.674069, Test Loss: 4.411289
# Epoch 74/500, Train Loss: 1.665246, Test Loss: 4.615365
# Epoch 75/500, Train Loss: 1.639580, Test Loss: 4.617337
# Epoch 76/500, Train Loss: 1.656315, Test Loss: 4.653057
# Epoch 77/500, Train Loss: 1.651026, Test Loss: 4.503510
# Epoch 78/500, Train Loss: 1.639798, Test Loss: 4.471076
# Epoch 79/500, Train Loss: 1.658228, Test Loss: 4.505351
# Epoch 80/500, Train Loss: 1.654301, Test Loss: 4.501043
# Epoch 81/500, Train Loss: 1.656579, Test Loss: 4.713928
# Epoch 82/500, Train Loss: 1.651850, Test Loss: 4.691814
# Epoch 83/500, Train Loss: 1.644447, Test Loss: 4.691195
# Epoch 84/500, Train Loss: 1.658397, Test Loss: 4.543744
# Epoch 85/500, Train Loss: 1.651143, Test Loss: 4.821251
# Epoch 86/500, Train Loss: 1.670995, Test Loss: 4.562231
# Epoch 87/500, Train Loss: 1.656001, Test Loss: 4.531169
# Epoch 88/500, Train Loss: 1.656365, Test Loss: 4.493847
# Epoch 89/500, Train Loss: 1.652985, Test Loss: 4.646107
# Epoch 90/500, Train Loss: 1.648261, Test Loss: 4.530889
# Epoch 91/500, Train Loss: 1.650027, Test Loss: 4.696594
# Epoch 92/500, Train Loss: 1.642111, Test Loss: 4.525201
# Epoch 93/500, Train Loss: 1.640582, Test Loss: 4.529477
# Epoch 94/500, Train Loss: 1.649999, Test Loss: 4.428154
# Epoch 95/500, Train Loss: 1.647101, Test Loss: 4.628015
# Epoch 96/500, Train Loss: 1.648213, Test Loss: 4.604967
# Epoch 97/500, Train Loss: 1.643340, Test Loss: 4.654840
# Epoch 98/500, Train Loss: 1.641162, Test Loss: 4.603042
# Epoch 99/500, Train Loss: 1.640005, Test Loss: 4.449754
# Epoch 100/500, Train Loss: 1.629970, Test Loss: 4.493483
# Epoch 101/500, Train Loss: 1.669713, Test Loss: 4.674955
# Epoch 102/500, Train Loss: 1.635145, Test Loss: 4.552330
# Epoch 103/500, Train Loss: 1.653812, Test Loss: 4.588848
# Epoch 104/500, Train Loss: 1.632377, Test Loss: 4.664531
# Epoch 105/500, Train Loss: 1.648087, Test Loss: 4.831066
# Epoch 106/500, Train Loss: 1.654682, Test Loss: 4.553359
# Epoch 107/500, Train Loss: 1.667054, Test Loss: 4.635287
# Epoch 108/500, Train Loss: 1.644368, Test Loss: 4.627532
# Epoch 109/500, Train Loss: 1.656528, Test Loss: 4.423523
# Epoch 110/500, Train Loss: 1.643101, Test Loss: 4.679548
# Epoch 111/500, Train Loss: 1.640949, Test Loss: 4.418301
# Epoch 112/500, Train Loss: 1.633919, Test Loss: 4.652984
# Epoch 113/500, Train Loss: 1.653510, Test Loss: 4.431256
# Epoch 114/500, Train Loss: 1.642968, Test Loss: 4.676579
# Epoch 115/500, Train Loss: 1.627710, Test Loss: 4.711045
# Epoch 116/500, Train Loss: 1.642279, Test Loss: 4.619584
# Epoch 117/500, Train Loss: 1.626112, Test Loss: 4.579600
# Epoch 118/500, Train Loss: 1.645286, Test Loss: 4.475708
# Epoch 119/500, Train Loss: 1.665329, Test Loss: 4.573381
# Epoch 120/500, Train Loss: 1.630842, Test Loss: 4.639107
# Epoch 121/500, Train Loss: 1.638276, Test Loss: 4.643475
# Epoch 122/500, Train Loss: 1.634856, Test Loss: 4.418619
# Epoch 123/500, Train Loss: 1.640701, Test Loss: 4.511149
# Epoch 124/500, Train Loss: 1.642981, Test Loss: 4.739541
# Epoch 125/500, Train Loss: 1.639124, Test Loss: 4.721672
# Epoch 126/500, Train Loss: 1.627593, Test Loss: 4.589292
# Epoch 127/500, Train Loss: 1.633539, Test Loss: 4.523915
# Epoch 128/500, Train Loss: 1.598065, Test Loss: 4.714535
# Epoch 129/500, Train Loss: 1.624472, Test Loss: 4.631568
# Epoch 130/500, Train Loss: 1.633160, Test Loss: 4.736933
# Epoch 131/500, Train Loss: 1.617400, Test Loss: 4.540126
# Epoch 132/500, Train Loss: 1.635675, Test Loss: 4.476017
# Epoch 133/500, Train Loss: 1.619533, Test Loss: 4.653348
# Epoch 134/500, Train Loss: 1.652098, Test Loss: 4.680544
# Epoch 135/500, Train Loss: 1.635037, Test Loss: 4.679326
# Epoch 136/500, Train Loss: 1.626232, Test Loss: 4.487257
# Epoch 137/500, Train Loss: 1.617033, Test Loss: 4.658874
# Epoch 138/500, Train Loss: 1.635718, Test Loss: 4.897795
# Epoch 139/500, Train Loss: 1.610384, Test Loss: 4.618499
# Epoch 140/500, Train Loss: 1.635189, Test Loss: 4.663782
# Epoch 141/500, Train Loss: 1.644678, Test Loss: 4.716589
# Epoch 142/500, Train Loss: 1.612463, Test Loss: 4.693979
# Epoch 143/500, Train Loss: 1.633482, Test Loss: 4.987915
# Epoch 144/500, Train Loss: 1.633083, Test Loss: 4.597457
# Epoch 145/500, Train Loss: 1.627059, Test Loss: 4.621631
# Epoch 146/500, Train Loss: 1.604017, Test Loss: 4.806786
# Epoch 147/500, Train Loss: 1.646949, Test Loss: 4.659357
# Epoch 148/500, Train Loss: 1.614634, Test Loss: 4.739544
# Epoch 149/500, Train Loss: 1.660500, Test Loss: 4.703508
# Epoch 150/500, Train Loss: 1.619585, Test Loss: 4.774217
# Epoch 151/500, Train Loss: 1.627296, Test Loss: 4.516928
# Epoch 152/500, Train Loss: 1.619183, Test Loss: 4.643930
# Epoch 153/500, Train Loss: 1.620796, Test Loss: 4.476845
# Epoch 154/500, Train Loss: 1.620842, Test Loss: 4.766122
# Epoch 155/500, Train Loss: 1.625506, Test Loss: 4.644914
# Epoch 156/500, Train Loss: 1.620068, Test Loss: 4.828303
# Epoch 157/500, Train Loss: 1.640620, Test Loss: 4.677840
# Epoch 158/500, Train Loss: 1.619373, Test Loss: 4.730206
# Epoch 159/500, Train Loss: 1.616218, Test Loss: 4.887073
# Epoch 160/500, Train Loss: 1.643324, Test Loss: 4.836502
# Epoch 161/500, Train Loss: 1.606101, Test Loss: 4.663782
# Epoch 162/500, Train Loss: 1.617632, Test Loss: 4.740617
# Epoch 163/500, Train Loss: 1.623778, Test Loss: 4.786123
# Epoch 164/500, Train Loss: 1.637493, Test Loss: 4.714592
# Epoch 165/500, Train Loss: 1.624733, Test Loss: 4.681406
# Epoch 166/500, Train Loss: 1.613027, Test Loss: 4.639135
# Epoch 167/500, Train Loss: 1.610974, Test Loss: 4.617201
# Epoch 168/500, Train Loss: 1.624194, Test Loss: 4.797060
# Epoch 169/500, Train Loss: 1.598006, Test Loss: 4.533944
# Epoch 170/500, Train Loss: 1.579031, Test Loss: 4.811872
# Epoch 171/500, Train Loss: 1.585670, Test Loss: 4.834024
# Epoch 172/500, Train Loss: 1.628568, Test Loss: 4.772198
# Epoch 173/500, Train Loss: 1.612609, Test Loss: 4.805892
# Epoch 174/500, Train Loss: 1.624326, Test Loss: 4.876318
# Epoch 175/500, Train Loss: 1.607252, Test Loss: 4.985039
# Epoch 176/500, Train Loss: 1.616940, Test Loss: 4.708287
# Epoch 177/500, Train Loss: 1.616381, Test Loss: 4.970903
# Epoch 178/500, Train Loss: 1.622278, Test Loss: 4.755884
# Epoch 179/500, Train Loss: 1.624771, Test Loss: 4.762801
# Epoch 180/500, Train Loss: 1.615843, Test Loss: 4.586432
# Epoch 181/500, Train Loss: 1.618361, Test Loss: 5.126483
# Epoch 182/500, Train Loss: 1.632319, Test Loss: 5.050653
# Epoch 183/500, Train Loss: 1.616693, Test Loss: 5.083280
# Epoch 184/500, Train Loss: 1.596415, Test Loss: 5.122734
# Epoch 185/500, Train Loss: 1.617735, Test Loss: 4.673380
# Epoch 186/500, Train Loss: 1.591777, Test Loss: 5.005261
# Epoch 187/500, Train Loss: 1.614362, Test Loss: 4.793928
# Epoch 188/500, Train Loss: 1.618467, Test Loss: 5.093060
# Epoch 189/500, Train Loss: 1.603671, Test Loss: 4.858407
# Epoch 190/500, Train Loss: 1.628839, Test Loss: 4.769967
# Epoch 191/500, Train Loss: 1.613056, Test Loss: 4.712665
# Epoch 192/500, Train Loss: 1.626116, Test Loss: 5.092103
# Epoch 193/500, Train Loss: 1.618661, Test Loss: 4.909124
# Epoch 194/500, Train Loss: 1.621041, Test Loss: 4.907923
# Epoch 195/500, Train Loss: 1.632694, Test Loss: 5.044122
# Epoch 196/500, Train Loss: 1.616643, Test Loss: 4.863286
# Epoch 197/500, Train Loss: 1.607982, Test Loss: 4.865880
# Epoch 198/500, Train Loss: 1.609837, Test Loss: 4.597807
# Epoch 199/500, Train Loss: 1.611511, Test Loss: 4.962422
# Epoch 200/500, Train Loss: 1.614592, Test Loss: 4.858065
# Epoch 201/500, Train Loss: 1.629194, Test Loss: 4.736314
# Epoch 202/500, Train Loss: 1.626973, Test Loss: 4.967700
# Epoch 203/500, Train Loss: 1.607599, Test Loss: 4.949982
# Epoch 204/500, Train Loss: 1.595216, Test Loss: 5.144870
# Epoch 205/500, Train Loss: 1.605019, Test Loss: 5.028517
# Epoch 206/500, Train Loss: 1.601320, Test Loss: 5.093565
# Epoch 207/500, Train Loss: 1.609103, Test Loss: 5.047041
# Epoch 208/500, Train Loss: 1.629473, Test Loss: 4.718474
# Epoch 209/500, Train Loss: 1.626058, Test Loss: 4.952999
# Epoch 210/500, Train Loss: 1.610739, Test Loss: 4.739153
# Epoch 211/500, Train Loss: 1.613472, Test Loss: 4.856538
# Epoch 212/500, Train Loss: 1.592798, Test Loss: 4.890712
# Epoch 213/500, Train Loss: 1.603894, Test Loss: 4.776639
# Epoch 214/500, Train Loss: 1.608744, Test Loss: 4.833339
# Epoch 215/500, Train Loss: 1.602357, Test Loss: 4.799813
# Epoch 216/500, Train Loss: 1.603909, Test Loss: 4.798668
# Epoch 217/500, Train Loss: 1.608362, Test Loss: 4.786903
# Epoch 218/500, Train Loss: 1.595528, Test Loss: 4.782515
# Epoch 219/500, Train Loss: 1.611033, Test Loss: 4.828274
# Epoch 220/500, Train Loss: 1.595842, Test Loss: 5.097994
# Epoch 221/500, Train Loss: 1.576063, Test Loss: 4.856023
# Epoch 222/500, Train Loss: 1.586303, Test Loss: 4.795370
# Epoch 223/500, Train Loss: 1.576919, Test Loss: 4.753134
# Epoch 224/500, Train Loss: 1.581966, Test Loss: 4.934051
# Epoch 225/500, Train Loss: 1.602085, Test Loss: 4.945588
# Epoch 226/500, Train Loss: 1.594741, Test Loss: 4.790702
# Epoch 227/500, Train Loss: 1.588802, Test Loss: 5.071925
# Epoch 228/500, Train Loss: 1.600397, Test Loss: 4.900998
# Epoch 229/500, Train Loss: 1.596361, Test Loss: 4.964400
# Epoch 230/500, Train Loss: 1.591775, Test Loss: 4.866334
# Epoch 231/500, Train Loss: 1.573850, Test Loss: 4.600322
# Epoch 232/500, Train Loss: 1.597391, Test Loss: 4.741964
# Epoch 233/500, Train Loss: 1.614628, Test Loss: 4.829347
# Epoch 234/500, Train Loss: 1.602261, Test Loss: 4.772521
# Epoch 235/500, Train Loss: 1.577406, Test Loss: 4.688969
# Epoch 236/500, Train Loss: 1.582662, Test Loss: 4.735514
# Epoch 237/500, Train Loss: 1.579931, Test Loss: 4.795575
# Epoch 238/500, Train Loss: 1.605011, Test Loss: 4.675919
# Epoch 239/500, Train Loss: 1.577065, Test Loss: 4.682820
# Epoch 240/500, Train Loss: 1.606239, Test Loss: 4.673559
# Epoch 241/500, Train Loss: 1.584452, Test Loss: 4.677719
# Epoch 242/500, Train Loss: 1.609890, Test Loss: 4.741523
# Epoch 243/500, Train Loss: 1.609000, Test Loss: 4.553545
# Epoch 244/500, Train Loss: 1.576318, Test Loss: 4.600501
# Epoch 245/500, Train Loss: 1.584102, Test Loss: 4.693927
# Epoch 246/500, Train Loss: 1.593206, Test Loss: 4.576773
# Epoch 247/500, Train Loss: 1.603329, Test Loss: 4.719572
# Epoch 248/500, Train Loss: 1.620984, Test Loss: 4.706806
# Epoch 249/500, Train Loss: 1.605939, Test Loss: 4.744088
# Epoch 250/500, Train Loss: 1.606255, Test Loss: 4.720045
# Epoch 251/500, Train Loss: 1.585824, Test Loss: 4.673007
# Epoch 252/500, Train Loss: 1.582385, Test Loss: 4.663251
# Epoch 253/500, Train Loss: 1.601823, Test Loss: 4.739400
# Epoch 254/500, Train Loss: 1.622566, Test Loss: 4.754591
# Epoch 255/500, Train Loss: 1.596237, Test Loss: 4.725565
# Epoch 256/500, Train Loss: 1.618579, Test Loss: 4.729123
# Epoch 257/500, Train Loss: 1.604253, Test Loss: 4.904613
# Epoch 258/500, Train Loss: 1.601416, Test Loss: 4.675365
# Epoch 259/500, Train Loss: 1.624866, Test Loss: 4.839654
# Epoch 260/500, Train Loss: 1.605425, Test Loss: 4.670578
# Epoch 261/500, Train Loss: 1.600171, Test Loss: 4.715914
# Epoch 262/500, Train Loss: 1.614242, Test Loss: 4.566607
# Epoch 263/500, Train Loss: 1.594561, Test Loss: 4.621830
# Epoch 264/500, Train Loss: 1.594269, Test Loss: 4.691046
# Epoch 265/500, Train Loss: 1.595120, Test Loss: 4.720649
# Epoch 266/500, Train Loss: 1.599237, Test Loss: 4.725915
# Epoch 267/500, Train Loss: 1.629777, Test Loss: 4.804955
# Epoch 268/500, Train Loss: 1.604869, Test Loss: 4.852351
# Epoch 269/500, Train Loss: 1.631149, Test Loss: 4.813694
# Epoch 270/500, Train Loss: 1.582387, Test Loss: 4.787201
# Epoch 271/500, Train Loss: 1.637051, Test Loss: 4.811893
# Epoch 272/500, Train Loss: 1.625175, Test Loss: 4.590873
# Epoch 273/500, Train Loss: 1.640028, Test Loss: 4.663645
# Epoch 274/500, Train Loss: 1.594481, Test Loss: 4.680655
# Epoch 275/500, Train Loss: 1.616731, Test Loss: 4.629929
# Epoch 276/500, Train Loss: 1.590704, Test Loss: 4.670725
# Epoch 277/500, Train Loss: 1.630074, Test Loss: 4.637620
# Epoch 278/500, Train Loss: 1.608624, Test Loss: 4.524555
# Epoch 279/500, Train Loss: 1.627934, Test Loss: 4.711163
# Epoch 280/500, Train Loss: 1.637452, Test Loss: 4.623213
# Epoch 281/500, Train Loss: 1.599066, Test Loss: 4.628367
# Epoch 282/500, Train Loss: 1.636719, Test Loss: 4.629989
# Epoch 283/500, Train Loss: 1.604436, Test Loss: 4.526070
# Epoch 284/500, Train Loss: 1.633769, Test Loss: 4.776346
# Epoch 285/500, Train Loss: 1.609367, Test Loss: 4.711119
# Epoch 286/500, Train Loss: 1.613516, Test Loss: 4.846502
# Epoch 287/500, Train Loss: 1.614655, Test Loss: 4.677800
# Epoch 288/500, Train Loss: 1.621254, Test Loss: 4.647126
# Epoch 289/500, Train Loss: 1.590901, Test Loss: 4.902773
# Epoch 290/500, Train Loss: 1.624189, Test Loss: 4.559815
# Epoch 291/500, Train Loss: 1.628370, Test Loss: 4.768175
# Epoch 292/500, Train Loss: 1.626427, Test Loss: 4.837818
# Epoch 293/500, Train Loss: 1.614229, Test Loss: 4.680328
# Epoch 294/500, Train Loss: 1.620916, Test Loss: 4.813453
# Epoch 295/500, Train Loss: 1.630195, Test Loss: 4.826658
# Epoch 296/500, Train Loss: 1.608916, Test Loss: 4.796382
# Epoch 297/500, Train Loss: 1.611770, Test Loss: 4.699845
# Epoch 298/500, Train Loss: 1.621583, Test Loss: 4.673413
# Epoch 299/500, Train Loss: 1.615520, Test Loss: 4.825884
# Epoch 300/500, Train Loss: 1.610919, Test Loss: 5.127187
# Epoch 301/500, Train Loss: 1.653540, Test Loss: 4.942141
# Epoch 302/500, Train Loss: 1.639223, Test Loss: 4.647380
# Epoch 303/500, Train Loss: 1.651100, Test Loss: 4.556277
# Epoch 304/500, Train Loss: 1.622906, Test Loss: 4.694688
# Epoch 305/500, Train Loss: 1.636096, Test Loss: 4.672280
# Epoch 306/500, Train Loss: 1.613292, Test Loss: 4.706079
# Epoch 307/500, Train Loss: 1.620574, Test Loss: 4.531381
# Epoch 308/500, Train Loss: 1.632197, Test Loss: 4.693632
# Epoch 309/500, Train Loss: 1.643385, Test Loss: 4.799890
# Epoch 310/500, Train Loss: 1.617888, Test Loss: 4.708318
# Epoch 311/500, Train Loss: 1.613136, Test Loss: 4.845437
# Epoch 312/500, Train Loss: 1.633103, Test Loss: 4.782135
# Epoch 313/500, Train Loss: 1.639163, Test Loss: 4.858496
# Epoch 314/500, Train Loss: 1.631468, Test Loss: 4.752061
# Epoch 315/500, Train Loss: 1.631738, Test Loss: 4.665726
# Epoch 316/500, Train Loss: 1.606950, Test Loss: 4.750579
# Epoch 317/500, Train Loss: 1.625947, Test Loss: 4.583904
# Epoch 318/500, Train Loss: 1.650241, Test Loss: 4.758611
# Epoch 319/500, Train Loss: 1.648791, Test Loss: 4.811439
# Epoch 320/500, Train Loss: 1.648997, Test Loss: 4.608841
# Epoch 321/500, Train Loss: 1.619381, Test Loss: 4.854945
# Epoch 322/500, Train Loss: 1.633309, Test Loss: 4.737162
# Epoch 323/500, Train Loss: 1.654356, Test Loss: 4.669919
# Epoch 324/500, Train Loss: 1.599526, Test Loss: 4.521604
# Epoch 325/500, Train Loss: 1.607762, Test Loss: 4.813038
# Epoch 326/500, Train Loss: 1.645544, Test Loss: 4.666884
# Epoch 327/500, Train Loss: 1.603717, Test Loss: 4.582924
# Epoch 328/500, Train Loss: 1.625577, Test Loss: 4.786142
# Epoch 329/500, Train Loss: 1.622416, Test Loss: 4.736598
# Epoch 330/500, Train Loss: 1.615590, Test Loss: 4.614370
# Epoch 331/500, Train Loss: 1.599503, Test Loss: 4.688628
# Epoch 332/500, Train Loss: 1.636794, Test Loss: 4.807391
# Epoch 333/500, Train Loss: 1.632012, Test Loss: 4.683385
# Epoch 334/500, Train Loss: 1.653472, Test Loss: 4.697494
# Epoch 335/500, Train Loss: 1.621376, Test Loss: 4.918404
# Epoch 336/500, Train Loss: 1.612165, Test Loss: 4.714927
# Epoch 337/500, Train Loss: 1.618564, Test Loss: 4.579670
# Epoch 338/500, Train Loss: 1.624202, Test Loss: 4.715900
# Epoch 339/500, Train Loss: 1.622501, Test Loss: 4.443018
# Epoch 340/500, Train Loss: 1.636408, Test Loss: 4.664739
# Epoch 341/500, Train Loss: 1.626960, Test Loss: 4.759151
# Epoch 342/500, Train Loss: 1.641987, Test Loss: 4.665563
# Epoch 343/500, Train Loss: 1.639782, Test Loss: 4.717155
# Epoch 344/500, Train Loss: 1.624736, Test Loss: 4.671634
# Epoch 345/500, Train Loss: 1.638047, Test Loss: 4.576750
# Epoch 346/500, Train Loss: 1.652448, Test Loss: 4.674213
# Epoch 347/500, Train Loss: 1.650615, Test Loss: 4.728123
# Epoch 348/500, Train Loss: 1.614894, Test Loss: 4.586057
# Epoch 349/500, Train Loss: 1.623730, Test Loss: 4.637526
# Epoch 350/500, Train Loss: 1.634486, Test Loss: 4.734549
# Epoch 351/500, Train Loss: 1.634575, Test Loss: 4.633077
# Epoch 352/500, Train Loss: 1.640545, Test Loss: 4.691014
# Epoch 353/500, Train Loss: 1.642707, Test Loss: 4.528992
# Epoch 354/500, Train Loss: 1.644097, Test Loss: 4.528295
# Epoch 355/500, Train Loss: 1.661916, Test Loss: 4.525872
# Epoch 356/500, Train Loss: 1.634739, Test Loss: 4.539543
# Epoch 357/500, Train Loss: 1.644123, Test Loss: 4.557138
# Epoch 358/500, Train Loss: 1.637041, Test Loss: 4.505457
# Epoch 359/500, Train Loss: 1.626818, Test Loss: 4.429144
# Epoch 360/500, Train Loss: 1.630943, Test Loss: 4.594736
# Epoch 361/500, Train Loss: 1.629708, Test Loss: 4.620337
# Epoch 362/500, Train Loss: 1.622096, Test Loss: 4.760317
# Epoch 363/500, Train Loss: 1.618643, Test Loss: 4.608986
# Epoch 364/500, Train Loss: 1.655413, Test Loss: 4.741171
# Epoch 365/500, Train Loss: 1.649664, Test Loss: 4.288223
# Epoch 366/500, Train Loss: 1.637480, Test Loss: 4.748548
# Epoch 367/500, Train Loss: 1.653321, Test Loss: 4.594511
# Epoch 368/500, Train Loss: 1.648815, Test Loss: 4.599484
# Epoch 369/500, Train Loss: 1.653909, Test Loss: 4.652118
# Epoch 370/500, Train Loss: 1.648567, Test Loss: 4.738945
# Epoch 371/500, Train Loss: 1.646757, Test Loss: 4.532663
# Epoch 372/500, Train Loss: 1.674646, Test Loss: 4.599103
# Epoch 373/500, Train Loss: 1.654072, Test Loss: 4.551410
# Epoch 374/500, Train Loss: 1.632606, Test Loss: 4.667958
# Epoch 375/500, Train Loss: 1.646957, Test Loss: 4.620381
# Epoch 376/500, Train Loss: 1.606598, Test Loss: 4.520784
# Epoch 377/500, Train Loss: 1.617372, Test Loss: 4.554117
# Epoch 378/500, Train Loss: 1.640295, Test Loss: 4.575093
# Epoch 379/500, Train Loss: 1.642652, Test Loss: 4.878705
# Epoch 380/500, Train Loss: 1.668750, Test Loss: 4.663894
# Epoch 381/500, Train Loss: 1.640856, Test Loss: 4.723735
# Epoch 382/500, Train Loss: 1.641409, Test Loss: 4.550081
# Epoch 383/500, Train Loss: 1.635288, Test Loss: 4.596666
# Epoch 384/500, Train Loss: 1.636719, Test Loss: 4.708443
# Epoch 385/500, Train Loss: 1.627913, Test Loss: 4.751311
# Epoch 386/500, Train Loss: 1.631411, Test Loss: 4.606570
# Epoch 387/500, Train Loss: 1.634197, Test Loss: 4.501199
# Epoch 388/500, Train Loss: 1.628193, Test Loss: 4.473413
# Epoch 389/500, Train Loss: 1.644862, Test Loss: 4.430004
# Epoch 390/500, Train Loss: 1.648842, Test Loss: 4.540451
# Epoch 391/500, Train Loss: 1.602697, Test Loss: 4.528783
# Epoch 392/500, Train Loss: 1.613281, Test Loss: 4.484401
# Epoch 393/500, Train Loss: 1.594893, Test Loss: 4.511305
# Epoch 394/500, Train Loss: 1.612104, Test Loss: 4.556585
# Epoch 395/500, Train Loss: 1.621647, Test Loss: 4.512114
# Epoch 396/500, Train Loss: 1.616544, Test Loss: 4.551114
# Epoch 397/500, Train Loss: 1.656519, Test Loss: 4.605234
# Epoch 398/500, Train Loss: 1.630939, Test Loss: 4.533807
# Epoch 399/500, Train Loss: 1.613312, Test Loss: 4.634476
# Epoch 400/500, Train Loss: 1.620569, Test Loss: 4.581901
# Epoch 401/500, Train Loss: 1.612368, Test Loss: 4.690484
# Epoch 402/500, Train Loss: 1.610326, Test Loss: 4.553807
# Epoch 403/500, Train Loss: 1.598657, Test Loss: 4.513384
# Epoch 404/500, Train Loss: 1.650485, Test Loss: 4.647553
# Epoch 405/500, Train Loss: 1.620780, Test Loss: 4.801977
# Epoch 406/500, Train Loss: 1.629133, Test Loss: 4.660231
# Epoch 407/500, Train Loss: 1.623392, Test Loss: 4.515091
# Epoch 408/500, Train Loss: 1.601935, Test Loss: 4.658615
# Epoch 409/500, Train Loss: 1.628654, Test Loss: 4.546205
# Epoch 410/500, Train Loss: 1.590638, Test Loss: 4.710630
# Epoch 411/500, Train Loss: 1.618005, Test Loss: 4.431993
# Epoch 412/500, Train Loss: 1.612191, Test Loss: 4.541272
# Epoch 413/500, Train Loss: 1.615790, Test Loss: 4.631003
# Epoch 414/500, Train Loss: 1.622075, Test Loss: 4.539370
# Epoch 415/500, Train Loss: 1.606734, Test Loss: 4.644675
# Epoch 416/500, Train Loss: 1.589061, Test Loss: 4.437065
# Epoch 417/500, Train Loss: 1.615003, Test Loss: 4.481034
# Epoch 418/500, Train Loss: 1.613187, Test Loss: 4.610747
# Epoch 419/500, Train Loss: 1.620020, Test Loss: 4.617363
# Epoch 420/500, Train Loss: 1.623267, Test Loss: 4.456509
# Epoch 421/500, Train Loss: 1.654950, Test Loss: 4.437614
# Epoch 422/500, Train Loss: 1.639964, Test Loss: 4.550621
# Epoch 423/500, Train Loss: 1.654888, Test Loss: 4.472129
# Epoch 424/500, Train Loss: 1.670532, Test Loss: 4.634395
# Epoch 425/500, Train Loss: 1.635461, Test Loss: 4.582107
# Epoch 426/500, Train Loss: 1.637497, Test Loss: 4.586182
# Epoch 427/500, Train Loss: 1.639520, Test Loss: 4.629834
# Epoch 428/500, Train Loss: 1.622636, Test Loss: 4.503773
# Epoch 429/500, Train Loss: 1.636922, Test Loss: 4.665426
# Epoch 430/500, Train Loss: 1.616107, Test Loss: 4.467188
# Epoch 431/500, Train Loss: 1.598309, Test Loss: 4.603877
# Epoch 432/500, Train Loss: 1.620005, Test Loss: 4.533850
# Epoch 433/500, Train Loss: 1.640990, Test Loss: 4.576253
# Epoch 434/500, Train Loss: 1.612099, Test Loss: 4.464483
# Epoch 435/500, Train Loss: 1.601868, Test Loss: 4.541058
# Epoch 436/500, Train Loss: 1.642633, Test Loss: 4.415496
# Epoch 437/500, Train Loss: 1.620808, Test Loss: 4.441837
# Epoch 438/500, Train Loss: 1.643289, Test Loss: 4.377232
# Epoch 439/500, Train Loss: 1.652589, Test Loss: 4.577098
# Epoch 440/500, Train Loss: 1.631868, Test Loss: 4.468204
# Epoch 441/500, Train Loss: 1.603420, Test Loss: 4.551209
# Epoch 442/500, Train Loss: 1.632253, Test Loss: 4.511155
# Epoch 443/500, Train Loss: 1.614587, Test Loss: 4.528572
# Epoch 444/500, Train Loss: 1.579638, Test Loss: 4.472566
# Epoch 445/500, Train Loss: 1.682245, Test Loss: 4.820160
# Epoch 446/500, Train Loss: 1.575247, Test Loss: 4.661909
# Epoch 447/500, Train Loss: 1.602217, Test Loss: 4.485677
# Epoch 448/500, Train Loss: 1.605733, Test Loss: 4.436537
# Epoch 449/500, Train Loss: 1.641832, Test Loss: 4.487878
# Epoch 450/500, Train Loss: 1.593909, Test Loss: 4.344731
# Epoch 451/500, Train Loss: 1.604793, Test Loss: 4.513951
# Epoch 452/500, Train Loss: 1.612774, Test Loss: 4.378486
# Epoch 453/500, Train Loss: 1.617330, Test Loss: 4.426103
# Epoch 454/500, Train Loss: 1.587321, Test Loss: 4.347480
# Epoch 455/500, Train Loss: 1.589345, Test Loss: 4.462861
# Epoch 456/500, Train Loss: 1.634437, Test Loss: 4.435839
# Epoch 457/500, Train Loss: 1.599122, Test Loss: 4.324349
# Epoch 458/500, Train Loss: 1.644337, Test Loss: 4.316383
# Epoch 459/500, Train Loss: 1.648823, Test Loss: 4.526069
# Epoch 460/500, Train Loss: 1.630641, Test Loss: 4.422889
# Epoch 461/500, Train Loss: 1.583789, Test Loss: 4.421407
# Epoch 462/500, Train Loss: 1.597414, Test Loss: 4.334122
# Epoch 463/500, Train Loss: 1.591694, Test Loss: 4.478328
# Epoch 464/500, Train Loss: 1.616129, Test Loss: 4.375541
# Epoch 465/500, Train Loss: 1.620347, Test Loss: 4.356807
# Epoch 466/500, Train Loss: 1.608080, Test Loss: 4.519515
# Epoch 467/500, Train Loss: 1.630009, Test Loss: 4.333001
# Epoch 468/500, Train Loss: 1.616222, Test Loss: 4.600035
# Epoch 469/500, Train Loss: 1.599868, Test Loss: 4.325373
# Epoch 470/500, Train Loss: 1.634495, Test Loss: 4.447438
# Epoch 471/500, Train Loss: 1.619753, Test Loss: 4.707546
# Epoch 472/500, Train Loss: 1.658125, Test Loss: 4.525681
# Epoch 473/500, Train Loss: 1.625265, Test Loss: 4.381344
# Epoch 474/500, Train Loss: 1.653491, Test Loss: 4.557169
# Epoch 475/500, Train Loss: 1.600152, Test Loss: 4.596247
# Epoch 476/500, Train Loss: 1.610783, Test Loss: 4.394066
# Epoch 477/500, Train Loss: 1.624938, Test Loss: 4.431910
# Epoch 478/500, Train Loss: 1.626926, Test Loss: 4.430368
# Epoch 479/500, Train Loss: 1.607227, Test Loss: 4.423283
# Epoch 480/500, Train Loss: 1.597713, Test Loss: 4.267832
# Epoch 481/500, Train Loss: 1.602052, Test Loss: 4.269750
# Epoch 482/500, Train Loss: 1.619888, Test Loss: 4.504334
# Epoch 483/500, Train Loss: 1.622299, Test Loss: 4.434878
# Epoch 484/500, Train Loss: 1.609405, Test Loss: 4.343959
# Epoch 485/500, Train Loss: 1.604166, Test Loss: 4.190773
# Epoch 486/500, Train Loss: 1.624182, Test Loss: 4.477453
# Epoch 487/500, Train Loss: 1.635126, Test Loss: 4.250899
# Epoch 488/500, Train Loss: 1.598918, Test Loss: 4.529677
# Epoch 489/500, Train Loss: 1.633276, Test Loss: 4.425365
# Epoch 490/500, Train Loss: 1.619892, Test Loss: 4.392346
# Epoch 491/500, Train Loss: 1.584396, Test Loss: 4.203748
# Epoch 492/500, Train Loss: 1.642628, Test Loss: 4.399819
# Epoch 493/500, Train Loss: 1.614979, Test Loss: 4.175931
# Epoch 494/500, Train Loss: 1.602907, Test Loss: 4.195628
# Epoch 495/500, Train Loss: 1.604387, Test Loss: 4.584386
# Epoch 496/500, Train Loss: 1.626608, Test Loss: 4.418492
# Epoch 497/500, Train Loss: 1.595584, Test Loss: 4.424725
# Epoch 498/500, Train Loss: 1.599390, Test Loss: 4.397092
# Epoch 499/500, Train Loss: 1.606924, Test Loss: 4.224607
# Epoch 500/500, Train Loss: 1.593077, Test Loss: 4.389773

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([1.9986, 1.9973, 1.9965, 1.9971, 1.9961, 1.9966, 1.9965, 1.9966, 1.9964,
#          1.9966, 1.9955, 1.9959, 1.9953, 1.9953, 1.9957, 1.9955, 1.9960, 1.9964,
#          1.9960, 1.9952, 1.9959, 1.9952, 1.9957, 1.9955, 1.9953, 1.9950, 1.9949,
#          1.9951, 1.9942, 1.9945, 1.9951, 1.9950, 1.9943, 1.9948, 1.9949, 1.9946,
#          1.9949, 1.9947, 1.9940, 1.9951, 1.9941, 1.9938, 1.9946, 1.9947, 1.9942,
#          1.9942, 1.9938, 1.9938, 1.9936, 1.9940, 1.9937, 1.9935, 1.9937, 1.9938,
#          1.9937, 1.9935, 1.9936, 1.9931, 1.9931, 1.9934, 1.9931, 1.9926, 1.9930,
#          1.9938, 1.9933, 1.9928, 1.9927, 1.9926, 1.9930, 1.9926, 1.9928, 1.9919,
#          1.9925, 1.9929, 1.9929, 1.9924, 1.9920, 1.9924, 1.9921, 1.9918, 1.9922,
#          1.9921, 1.9920, 1.9913, 1.9924, 1.9920, 1.9921, 1.9921, 1.9923, 1.9911,
#          1.9912, 1.9914, 1.9915, 1.9916, 1.9916, 1.9912, 1.9910, 1.9910, 1.9909,
#          1.9903, 1.9905, 1.9905, 1.9906, 1.9904, 1.9901, 1.9902, 1.9905, 1.9900,
#          1.9900, 1.9890, 1.9903, 1.9900, 1.9903, 1.9903, 1.9898, 1.9893, 1.9894,
#          1.9885, 1.9893, 1.9894, 1.9896, 1.9887, 1.9884, 1.9894, 1.9890, 1.9884,
#          1.9892, 1.9883, 1.9887, 1.9880, 1.9882, 1.9879, 1.9880, 1.9880, 1.9875,
#          1.9877, 1.9879, 1.9877, 1.9876, 1.9876, 1.9870, 1.9877, 1.9870, 1.9877,
#          1.9868, 1.9875, 1.9868, 1.9872, 1.9871, 1.9876, 1.9869, 1.9875, 1.9866,
#          1.9871, 1.9867, 1.9859, 1.9866, 1.9870, 1.9859, 1.9860, 1.9859, 1.9860,
#          1.9859, 1.9861, 1.9866, 1.9863, 1.9859, 1.9853, 1.9852, 1.9861, 1.9862,
#          1.9864, 1.9853, 1.9853, 1.9865, 1.9862, 1.9852, 1.9857, 1.9858, 1.9853,
#          1.9855, 1.9855, 1.9850, 1.9857, 1.9848, 1.9849, 1.9858, 1.9853, 1.9845,
#          1.9845, 1.9847, 1.9842, 1.9843, 1.9847, 1.9838, 1.9838, 1.9840, 1.9844,
#          1.9843, 1.9838, 1.9835, 1.9832, 1.9835, 1.9840, 1.9840, 1.9833, 1.9835,
#          1.9831, 1.9832, 1.9830, 1.9847, 1.9828, 1.9831, 1.9825, 1.9838, 1.9826,
#          1.9830, 1.9824, 1.9836, 1.9833, 1.9826, 1.9828, 1.9826, 1.9828, 1.9828,
#          1.9823, 1.9825, 1.9826, 1.9812, 1.9822, 1.9809, 1.9826, 1.9821, 1.9815,
#          1.9821, 1.9817, 1.9809, 1.9815, 1.9806, 1.9812, 1.9812, 1.9817, 1.9809,
#          1.9810, 1.9810, 1.9802, 1.9806, 1.9815, 1.9810, 1.9806, 1.9802, 1.9805,
#          1.9818, 1.9803, 1.9810, 1.9802, 1.9807, 1.9810, 1.9804, 1.9801, 1.9798,
#          1.9807, 1.9805, 1.9798, 1.9806, 1.9798, 1.9805, 1.9812, 1.9801, 1.9796,
#          1.9799, 1.9816, 1.9804, 1.9798, 1.9790, 1.9794, 1.9801, 1.9797, 1.9800,
#          1.9799, 1.9794, 1.9791, 1.9791, 1.9798, 1.9788, 1.9792, 1.9790, 1.9799,
#          1.9789, 1.9788, 1.9785, 1.9790, 1.9791, 1.9790, 1.9793, 1.9786, 1.9800,
#          1.9793, 1.9784, 1.9787, 1.9786, 1.9784, 1.9792, 1.9785, 1.9781, 1.9790,
#          1.9778, 1.9794, 1.9779, 1.9780, 1.9777, 1.9783, 1.9781, 1.9774, 1.9780,
#          1.9775, 1.9773, 1.9783, 1.9774, 1.9777, 1.9769, 1.9770, 1.9780, 1.9775,
#          1.9781, 1.9778, 1.9776, 1.9773, 1.9774, 1.9775, 1.9774, 1.9773, 1.9774,
#          1.9772, 1.9778, 1.9772, 1.9781, 1.9778, 1.9769, 1.9776, 1.9763, 1.9773,
#          1.9767, 1.9768, 1.9768, 1.9764, 1.9769, 1.9774, 1.9768, 1.9761, 1.9769,
#          1.9770, 1.9770, 1.9762, 1.9765, 1.9764, 1.9758, 1.9767, 1.9772, 1.9766,
#          1.9762, 1.9773, 1.9765, 1.9765, 1.9761, 1.9757, 1.9762, 1.9759, 1.9761,
#          1.9764, 1.9762, 1.9754, 1.9757, 1.9758, 1.9749, 1.9759, 1.9757, 1.9750,
#          1.9760, 1.9751, 1.9755, 1.9753, 1.9757, 1.9758, 1.9755, 1.9750, 1.9758,
#          1.9754, 1.9751, 1.9754, 1.9749, 1.9747, 1.9754, 1.9746, 1.9751, 1.9753,
#          1.9748, 1.9743, 1.9749, 1.9740, 1.9745, 1.9746, 1.9751, 1.9748, 1.9743,
#          1.9738, 1.9751, 1.9736, 1.9746, 1.9738, 1.9751, 1.9748, 1.9742, 1.9747,
#          1.9740, 1.9738, 1.9744, 1.9736, 1.9732, 1.9737, 1.9739, 1.9736, 1.9741,
#          1.9738, 1.9736, 1.9737, 1.9734, 1.9740, 1.9733, 1.9735, 1.9727, 1.9732,
#          1.9734, 1.9732, 1.9737, 1.9731, 1.9735, 1.9736, 1.9731, 1.9737, 1.9731,
#          1.9732, 1.9721, 1.9732, 1.9731, 1.9730, 1.9730, 1.9733, 1.9738, 1.9732,
#          1.9732, 1.9729, 1.9726, 1.9726, 1.9731, 1.9729, 1.9731, 1.9735, 1.9728,
#          1.9726, 1.9734, 1.9723, 1.9727, 1.9731, 1.9734, 1.9728, 1.9735, 1.9740,
#          1.9725, 1.9731, 1.9726, 1.9728, 1.9729, 1.9722, 1.9722, 1.9722, 1.9723,
#          1.9720, 1.9720, 1.9716, 1.9725, 1.9721, 1.9717, 1.9722, 1.9721, 1.9718,
#          1.9713, 1.9711, 1.9716, 1.9711, 1.9716, 1.9718, 1.9709, 1.9715, 1.9720,
#          1.9716, 1.9721, 1.9718, 1.9714, 1.9711]),
#  tensor([4.4901, 4.5374, 4.5481, 4.4355, 4.4700, 4.4594, 4.4422, 4.2743, 4.2358,
#          4.0412, 4.3694, 4.3292, 4.3610, 4.4091, 4.3729, 4.3590, 4.4482, 4.2369,
#          4.2363, 4.3441, 4.4575, 4.4649, 4.4533, 4.2945, 4.6940, 4.2995, 4.3447,
#          4.4059, 4.1787, 4.3585, 4.4763, 4.3611, 4.4057, 4.2723, 4.2809, 4.4183,
#          4.5028, 4.5248, 4.4197, 4.5052, 4.3303, 4.4664, 4.5814, 4.4151, 4.4174,
#          4.4706, 4.5607, 4.5053, 4.6270, 4.4876, 4.5121, 4.5284, 4.8198, 4.5002,
#          4.7120, 4.5833, 4.6507, 4.5030, 4.3963, 4.4909, 4.6415, 4.4916, 4.4540,
#          4.4892, 4.5137, 4.4271, 4.5308, 4.6785, 4.5082, 4.7514, 4.5797, 4.6886,
#          4.4113, 4.6154, 4.6173, 4.6531, 4.5035, 4.4711, 4.5054, 4.5010, 4.7139,
#          4.6918, 4.6912, 4.5437, 4.8213, 4.5622, 4.5312, 4.4938, 4.6461, 4.5309,
#          4.6966, 4.5252, 4.5295, 4.4282, 4.6280, 4.6050, 4.6548, 4.6030, 4.4498,
#          4.4935, 4.6750, 4.5523, 4.5888, 4.6645, 4.8311, 4.5534, 4.6353, 4.6275,
#          4.4235, 4.6795, 4.4183, 4.6530, 4.4313, 4.6766, 4.7110, 4.6196, 4.5796,
#          4.4757, 4.5734, 4.6391, 4.6435, 4.4186, 4.5111, 4.7395, 4.7217, 4.5893,
#          4.5239, 4.7145, 4.6316, 4.7369, 4.5401, 4.4760, 4.6533, 4.6805, 4.6793,
#          4.4873, 4.6589, 4.8978, 4.6185, 4.6638, 4.7166, 4.6940, 4.9879, 4.5975,
#          4.6216, 4.8068, 4.6594, 4.7395, 4.7035, 4.7742, 4.5169, 4.6439, 4.4768,
#          4.7661, 4.6449, 4.8283, 4.6778, 4.7302, 4.8871, 4.8365, 4.6638, 4.7406,
#          4.7861, 4.7146, 4.6814, 4.6391, 4.6172, 4.7971, 4.5339, 4.8119, 4.8340,
#          4.7722, 4.8059, 4.8763, 4.9850, 4.7083, 4.9709, 4.7559, 4.7628, 4.5864,
#          5.1265, 5.0507, 5.0833, 5.1227, 4.6734, 5.0053, 4.7939, 5.0931, 4.8584,
#          4.7700, 4.7127, 5.0921, 4.9091, 4.9079, 5.0441, 4.8633, 4.8659, 4.5978,
#          4.9624, 4.8581, 4.7363, 4.9677, 4.9500, 5.1449, 5.0285, 5.0936, 5.0470,
#          4.7185, 4.9530, 4.7392, 4.8565, 4.8907, 4.7766, 4.8333, 4.7998, 4.7987,
#          4.7869, 4.7825, 4.8283, 5.0980, 4.8560, 4.7954, 4.7531, 4.9341, 4.9456,
#          4.7907, 5.0719, 4.9010, 4.9644, 4.8663, 4.6003, 4.7420, 4.8293, 4.7725,
#          4.6890, 4.7355, 4.7956, 4.6759, 4.6828, 4.6736, 4.6777, 4.7415, 4.5535,
#          4.6005, 4.6939, 4.5768, 4.7196, 4.7068, 4.7441, 4.7200, 4.6730, 4.6633,
#          4.7394, 4.7546, 4.7256, 4.7291, 4.9046, 4.6754, 4.8397, 4.6706, 4.7159,
#          4.5666, 4.6218, 4.6910, 4.7206, 4.7259, 4.8050, 4.8524, 4.8137, 4.7872,
#          4.8119, 4.5909, 4.6636, 4.6807, 4.6299, 4.6707, 4.6376, 4.5246, 4.7112,
#          4.6232, 4.6284, 4.6300, 4.5261, 4.7763, 4.7111, 4.8465, 4.6778, 4.6471,
#          4.9028, 4.5598, 4.7682, 4.8378, 4.6803, 4.8135, 4.8267, 4.7964, 4.6998,
#          4.6734, 4.8259, 5.1272, 4.9421, 4.6474, 4.5563, 4.6947, 4.6723, 4.7061,
#          4.5314, 4.6936, 4.7999, 4.7083, 4.8454, 4.7821, 4.8585, 4.7521, 4.6657,
#          4.7506, 4.5839, 4.7586, 4.8114, 4.6088, 4.8549, 4.7372, 4.6699, 4.5216,
#          4.8130, 4.6669, 4.5829, 4.7861, 4.7366, 4.6144, 4.6886, 4.8074, 4.6834,
#          4.6975, 4.9184, 4.7149, 4.5797, 4.7159, 4.4430, 4.6647, 4.7592, 4.6656,
#          4.7172, 4.6716, 4.5768, 4.6742, 4.7281, 4.5861, 4.6375, 4.7345, 4.6331,
#          4.6910, 4.5290, 4.5283, 4.5259, 4.5395, 4.5571, 4.5055, 4.4291, 4.5947,
#          4.6203, 4.7603, 4.6090, 4.7412, 4.2882, 4.7485, 4.5945, 4.5995, 4.6521,
#          4.7389, 4.5327, 4.5991, 4.5514, 4.6680, 4.6204, 4.5208, 4.5541, 4.5751,
#          4.8787, 4.6639, 4.7237, 4.5501, 4.5967, 4.7084, 4.7513, 4.6066, 4.5012,
#          4.4734, 4.4300, 4.5405, 4.5288, 4.4844, 4.5113, 4.5566, 4.5121, 4.5511,
#          4.6052, 4.5338, 4.6345, 4.5819, 4.6905, 4.5538, 4.5134, 4.6476, 4.8020,
#          4.6602, 4.5151, 4.6586, 4.5462, 4.7106, 4.4320, 4.5413, 4.6310, 4.5394,
#          4.6447, 4.4371, 4.4810, 4.6107, 4.6174, 4.4565, 4.4376, 4.5506, 4.4721,
#          4.6344, 4.5821, 4.5862, 4.6298, 4.5038, 4.6654, 4.4672, 4.6039, 4.5338,
#          4.5763, 4.4645, 4.5411, 4.4155, 4.4418, 4.3772, 4.5771, 4.4682, 4.5512,
#          4.5112, 4.5286, 4.4726, 4.8202, 4.6619, 4.4857, 4.4365, 4.4879, 4.3447,
#          4.5140, 4.3785, 4.4261, 4.3475, 4.4629, 4.4358, 4.3243, 4.3164, 4.5261,
#          4.4229, 4.4214, 4.3341, 4.4783, 4.3755, 4.3568, 4.5195, 4.3330, 4.6000,
#          4.3254, 4.4474, 4.7075, 4.5257, 4.3813, 4.5572, 4.5962, 4.3941, 4.4319,
#          4.4304, 4.4233, 4.2678, 4.2697, 4.5043, 4.4349, 4.3440, 4.1908, 4.4775,
#          4.2509, 4.5297, 4.4254, 4.3923, 4.2037, 4.3998, 4.1759, 4.1956, 4.5844,
#          4.4185, 4.4247, 4.3971, 4.2246, 4.3898]),
#  tensor([0.6218, 0.6220, 0.6219, 0.6218, 0.6221, 0.6222, 0.6221, 0.6220, 0.6220,
#          0.6219, 0.6222, 0.6223, 0.6221, 0.6221, 0.6220, 0.6221, 0.6221, 0.6219,
#          0.6220, 0.6222, 0.6219, 0.6223, 0.6219, 0.6220, 0.6221, 0.6222, 0.6220,
#          0.6221, 0.6223, 0.6221, 0.6221, 0.6222, 0.6221, 0.6222, 0.6221, 0.6221,
#          0.6222, 0.6222, 0.6222, 0.6221, 0.6222, 0.6223, 0.6220, 0.6221, 0.6223,
#          0.6222, 0.6223, 0.6221, 0.6221, 0.6222, 0.6221, 0.6224, 0.6222, 0.6224,
#          0.6221, 0.6223, 0.6222, 0.6223, 0.6223, 0.6221, 0.6220, 0.6224, 0.6224,
#          0.6222, 0.6222, 0.6222, 0.6222, 0.6223, 0.6223, 0.6223, 0.6224, 0.6224,
#          0.6222, 0.6223, 0.6222, 0.6224, 0.6225, 0.6223, 0.6224, 0.6224, 0.6225,
#          0.6224, 0.6222, 0.6224, 0.6224, 0.6223, 0.6224, 0.6225, 0.6225, 0.6224,
#          0.6224, 0.6225, 0.6223, 0.6222, 0.6225, 0.6225, 0.6224, 0.6226, 0.6227,
#          0.6227, 0.6226, 0.6227, 0.6226, 0.6227, 0.6226, 0.6227, 0.6226, 0.6226,
#          0.6228, 0.6227, 0.6225, 0.6228, 0.6227, 0.6225, 0.6227, 0.6228, 0.6227,
#          0.6228, 0.6228, 0.6228, 0.6229, 0.6230, 0.6229, 0.6226, 0.6228, 0.6229,
#          0.6226, 0.6229, 0.6229, 0.6229, 0.6228, 0.6228, 0.6228, 0.6227, 0.6230,
#          0.6230, 0.6231, 0.6229, 0.6231, 0.6230, 0.6230, 0.6230, 0.6230, 0.6229,
#          0.6231, 0.6230, 0.6231, 0.6229, 0.6231, 0.6228, 0.6231, 0.6229, 0.6231,
#          0.6230, 0.6229, 0.6233, 0.6228, 0.6229, 0.6231, 0.6231, 0.6233, 0.6232,
#          0.6232, 0.6232, 0.6231, 0.6229, 0.6232, 0.6232, 0.6230, 0.6231, 0.6232,
#          0.6231, 0.6230, 0.6231, 0.6230, 0.6230, 0.6232, 0.6232, 0.6233, 0.6231,
#          0.6231, 0.6232, 0.6233, 0.6232, 0.6232, 0.6232, 0.6230, 0.6233, 0.6234,
#          0.6234, 0.6233, 0.6233, 0.6234, 0.6231, 0.6233, 0.6234, 0.6232, 0.6233,
#          0.6233, 0.6233, 0.6233, 0.6234, 0.6234, 0.6233, 0.6234, 0.6234, 0.6235,
#          0.6234, 0.6236, 0.6234, 0.6233, 0.6235, 0.6234, 0.6235, 0.6234, 0.6236,
#          0.6235, 0.6234, 0.6234, 0.6234, 0.6234, 0.6236, 0.6234, 0.6236, 0.6237,
#          0.6236, 0.6236, 0.6233, 0.6236, 0.6235, 0.6238, 0.6236, 0.6235, 0.6236,
#          0.6235, 0.6237, 0.6238, 0.6235, 0.6238, 0.6237, 0.6238, 0.6238, 0.6237,
#          0.6238, 0.6238, 0.6239, 0.6238, 0.6237, 0.6236, 0.6237, 0.6238, 0.6239,
#          0.6236, 0.6238, 0.6237, 0.6238, 0.6237, 0.6238, 0.6237, 0.6238, 0.6239,
#          0.6238, 0.6238, 0.6240, 0.6239, 0.6240, 0.6238, 0.6238, 0.6238, 0.6239,
#          0.6240, 0.6237, 0.6239, 0.6239, 0.6240, 0.6239, 0.6239, 0.6238, 0.6239,
#          0.6238, 0.6238, 0.6240, 0.6240, 0.6240, 0.6239, 0.6240, 0.6239, 0.6238,
#          0.6241, 0.6240, 0.6241, 0.6239, 0.6239, 0.6240, 0.6239, 0.6241, 0.6239,
#          0.6239, 0.6240, 0.6240, 0.6240, 0.6240, 0.6240, 0.6242, 0.6242, 0.6240,
#          0.6242, 0.6240, 0.6243, 0.6241, 0.6242, 0.6242, 0.6241, 0.6242, 0.6242,
#          0.6242, 0.6243, 0.6241, 0.6242, 0.6241, 0.6243, 0.6242, 0.6242, 0.6241,
#          0.6242, 0.6242, 0.6241, 0.6243, 0.6243, 0.6241, 0.6242, 0.6242, 0.6243,
#          0.6243, 0.6243, 0.6243, 0.6241, 0.6242, 0.6244, 0.6242, 0.6245, 0.6242,
#          0.6244, 0.6244, 0.6243, 0.6244, 0.6244, 0.6244, 0.6243, 0.6244, 0.6244,
#          0.6243, 0.6244, 0.6244, 0.6245, 0.6246, 0.6246, 0.6245, 0.6244, 0.6243,
#          0.6245, 0.6244, 0.6247, 0.6245, 0.6246, 0.6244, 0.6245, 0.6245, 0.6245,
#          0.6244, 0.6244, 0.6245, 0.6246, 0.6244, 0.6248, 0.6245, 0.6246, 0.6247,
#          0.6246, 0.6246, 0.6246, 0.6246, 0.6246, 0.6245, 0.6246, 0.6248, 0.6247,
#          0.6246, 0.6247, 0.6247, 0.6248, 0.6247, 0.6245, 0.6247, 0.6249, 0.6247,
#          0.6248, 0.6247, 0.6246, 0.6248, 0.6247, 0.6246, 0.6248, 0.6249, 0.6247,
#          0.6250, 0.6247, 0.6250, 0.6248, 0.6249, 0.6247, 0.6248, 0.6247, 0.6246,
#          0.6247, 0.6249, 0.6247, 0.6247, 0.6248, 0.6247, 0.6246, 0.6248, 0.6246,
#          0.6247, 0.6247, 0.6248, 0.6248, 0.6246, 0.6249, 0.6248, 0.6249, 0.6249,
#          0.6249, 0.6248, 0.6249, 0.6250, 0.6248, 0.6247, 0.6248, 0.6249, 0.6249,
#          0.6249, 0.6250, 0.6248, 0.6248, 0.6249, 0.6248, 0.6247, 0.6248, 0.6249,
#          0.6247, 0.6250, 0.6250, 0.6249, 0.6250, 0.6248, 0.6249, 0.6247, 0.6249,
#          0.6249, 0.6248, 0.6250, 0.6250, 0.6249, 0.6247, 0.6247, 0.6247, 0.6248,
#          0.6250, 0.6248, 0.6249, 0.6249, 0.6248, 0.6249, 0.6248, 0.6250, 0.6247,
#          0.6249, 0.6251, 0.6251, 0.6248, 0.6250, 0.6250, 0.6250, 0.6249, 0.6250,
#          0.6250, 0.6252, 0.6249, 0.6252, 0.6251, 0.6251, 0.6252, 0.6250, 0.6251,
#          0.6251, 0.6250, 0.6251, 0.6251, 0.6251]))

# %%
# (yy * data['date_int'].max()).round()

# %%
# (yHat_test * data['date_int'].max()).round()

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.6433
#
#
# mean_absolute_error(y, yHat): 0.6408
#
# mean_absolute_error(yy, yHat_test): 1.2000
#
#
# mean_squared_error(y, yHat): 1.5931
#
# mean_squared_error(yy, yHat_test): 4.3898
#
#
# mean_squared_log_error(y, yHat): 0.0900
#
# mean_squared_log_error(yy, yHat_test): 0.4321
#
#
# RMSE(y, yHat): 1.2622
#
# RMSE(yy, yHat_test): 2.0952

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Train loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Test loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss2.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.detach().T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc2.jpg", bbox_inches='tight')


plt.show()

# %%
['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']
# Out:
# ['day_scaled',
#  'day_sin',
#  'day_cos',
#  'month_scaled',
#  'month_sin',
#  'month_cos',
#  'leap_year',
#  'decade_scaled',
#  'decade_sin',
#  'decade_cos']

# %%
def result_to_date(result):
    
    result = str(result)
    
    day   = int(result[6:]) - 1
    month = int(result[4:6]) - 1

    ss = str(f'{result[:4]}0101')
    
    ds = datetime.datetime.strptime(ss, '%Y%m%d')
    
    ds = ds + relativedelta(months=month, days=day)

    result = ds.strftime('%d-%m-%Y')
    
    
    return result

# %%
# (16830739, 17848869)
result_to_date(16830739), result_to_date(17848869)
# Out:
# ('08-08-1683', '08-06-1791')

# %%
def test_model(input_list):
    

    X       = np.zeros((1, 10))
    X_smote = np.zeros((1, 10))



    day       = np.array(map_day[input_list[0]])
    month     = np.array(map_month[input_list[1]])
    leap_year = map_leap_year[input_list[2]]
    decade    = np.array(input_list[3].strip('[]')).astype('int64')


    X[0, 0] = scaler_day.transform(day.reshape(-1, 1)).flatten()
    X[0, 1] = np.sin(day * (2 * np.pi / 7))
    X[0, 2] = np.cos(day * (2 * np.pi / 7))

    X[0, 3] = scaler_month.transform(month.reshape(-1, 1)).flatten()
    X[0, 4] = np.sin(month * (2 * np.pi / 12))
    X[0, 5] = np.cos(month * (2 * np.pi / 12))

    X[0, 6] = leap_year

    X[0, 7] = scaler_decade.transform(decade.reshape(-1, 1)).flatten()
    X[0, 8] = np.sin(decade * (2 * np.pi / alpha))
    X[0, 9] = np.cos(decade * (2 * np.pi / alpha))

    # ---

    X_smote[0, 0] = scaler_day_smote.transform(day.reshape(-1, 1)).flatten()
    X_smote[0, 1] = X[0, 1]
    X_smote[0, 2] = X[0, 2]

    X_smote[0, 3] = scaler_month_smote.transform(month.reshape(-1, 1)).flatten()
    X_smote[0, 4] = X[0, 4]
    X_smote[0, 5] = X[0, 5]

    X_smote[0, 6] = leap_year

    X_smote[0, 7] = scaler_decade_smote.transform(decade.reshape(-1, 1)).flatten()
    X_smote[0, 8] = np.sin(decade * (2 * np.pi / alpha_smote))
    X_smote[0, 9] = np.cos(decade * (2 * np.pi / alpha_smote))



    flag = [model.training, model_smote.training]

    # ---

    model.eval()
    model_smote.eval()


    result       = model(torch.tensor(X).to(device).float())
    result_smote = model_smote(torch.tensor(X_smote).to(device).float())



    # if all(flag):
    #   model.train()
    #   model_smote.train()


    if flag[0]:
      model.train()

    if flag[1]:
      model_smote.train()


    # ---


    result       = ''.join(result.detach().cpu().numpy().round().astype(int).astype(str).flatten())
    result_smote = ''.join(result_smote.detach().cpu().numpy().round().astype(int).astype(str).flatten())

    
    
    return result_to_date(result), result_to_date(result_smote)

# %%
input_test1 = ['[MON]', '[DEC]', '[False]', '[196]']
output_test1 = '3-12-1962'

input_test2 = ['[THU]', '[DEC]', '[True]', '[204]']
output_test2 = '3-12-2048'

input_test3 = ['[WED]', '[JAN]', '[False]', '[181]']
output_test3 = '10-1-1810'


input_test4 = ['[WED]', '[JUN]', '[False]', '[209]']

# %%
test_model(input_test1), test_model(input_test2), test_model(input_test3), test_model(input_test4)
# Out:
# (('15-12-1965', '15-12-1965'),
#  ('15-12-2044', '15-12-2045'),
#  ('13-01-1814', '15-01-1815'),
#  ('15-06-2095', '14-06-2095'))

# %%
output_test1, output_test2, output_test3
# Out:
# ('3-12-1962', '3-12-2048', '10-1-1810')

# %%
# example_input = pd.read_csv('./data/example_input.txt', sep=' ', header=None)
example_input = pd.read_csv('example_input.txt', sep=' ', header=None)


example_input.columns = ['day', 'month', 'leap_year', 'decade']

# %%
example_input
# Out:
#         day  month leap_year decade
# 0     [WED]  [JAN]   [False]  [180]
# 1     [MON]  [JAN]   [False]  [190]
# 2     [SAT]  [JAN]    [True]  [200]
# 3     [FRI]  [JAN]   [False]  [210]
# 4     [WED]  [JAN]   [False]  [220]
# ...     ...    ...       ...    ...
# 1460  [MON]  [OCT]    [True]  [214]
# 1461  [TUE]  [DEC]   [False]  [183]
# 1462  [SUN]  [DEC]   [False]  [193]
# 1463  [SAT]  [DEC]   [False]  [203]
# 1464  [THU]  [DEC]   [False]  [213]
#
# [1465 rows x 4 columns]

# %%
R       = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result'])
R_smote = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result_smote'])

# %%
example_input.iloc[0].tolist()
# Out:
# ['[WED]', '[JAN]', '[False]', '[180]']

# %%
for i in range(len(example_input)):
    R.iloc[i], R_smote.iloc[i] = test_model(example_input.iloc[i].tolist())

# %%
R
# Out:
#           result
# 0     13-01-1804
# 1     15-01-1905
# 2     15-01-2005
# 3     15-01-2105
# 4     13-02-2200
# ...          ...
# 1460  15-10-2144
# 1461  15-12-1835
# 1462  15-12-1934
# 1463  15-12-2034
# 1464  15-12-2134
#
# [1465 rows x 1 columns]

# %%
final = pd.concat([example_input, R], axis=1)
final
# Out:
#         day  month leap_year decade      result
# 0     [WED]  [JAN]   [False]  [180]  13-01-1804
# 1     [MON]  [JAN]   [False]  [190]  15-01-1905
# 2     [SAT]  [JAN]    [True]  [200]  15-01-2005
# 3     [FRI]  [JAN]   [False]  [210]  15-01-2105
# 4     [WED]  [JAN]   [False]  [220]  13-02-2200
# ...     ...    ...       ...    ...         ...
# 1460  [MON]  [OCT]    [True]  [214]  15-10-2144
# 1461  [TUE]  [DEC]   [False]  [183]  15-12-1835
# 1462  [SUN]  [DEC]   [False]  [193]  15-12-1934
# 1463  [SAT]  [DEC]   [False]  [203]  15-12-2034
# 1464  [THU]  [DEC]   [False]  [213]  15-12-2134
#
# [1465 rows x 5 columns]

# %%
final_smote = pd.concat([example_input, R_smote], axis=1)
final_smote
# Out:
#         day  month leap_year decade result_smote
# 0     [WED]  [JAN]   [False]  [180]   15-01-1803
# 1     [MON]  [JAN]   [False]  [190]   15-01-1904
# 2     [SAT]  [JAN]    [True]  [200]   15-01-2004
# 3     [FRI]  [JAN]   [False]  [210]   15-01-2104
# 4     [WED]  [JAN]   [False]  [220]   14-01-2194
# ...     ...    ...       ...    ...          ...
# 1460  [MON]  [OCT]    [True]  [214]   15-10-2145
# 1461  [TUE]  [DEC]   [False]  [183]   15-12-1834
# 1462  [SUN]  [DEC]   [False]  [193]   15-12-1935
# 1463  [SAT]  [DEC]   [False]  [203]   15-12-2035
# 1464  [THU]  [DEC]   [False]  [213]   15-12-2134
#
# [1465 rows x 5 columns]

# %%
final.to_csv('output_file.txt', sep=' ', header=None, index=False)

# %%
final_smote.to_csv('output_file_smote.txt', sep=' ', header=None, index=False)

# %% [markdown]
# Out-liers

# %% [markdown]
# Saving

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              'scaler_day_smote' : scaler_day_smote,
              'scaler_month_smote' : scaler_month_smote,
              'scaler_decade_smote' : scaler_decade_smote,
              
              'alpha': alpha,
              'alpha_smote': alpha_smote}



torch.save(checkpoint, 'checkpoint.pth.tar')

# %%
# checkpoint = torch.load('checkpoint.pth.tar')

# %%
# model       = Model()
# model_smote = Model()


# model.load_state_dict(checkpoint['model_state_dict'])
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
