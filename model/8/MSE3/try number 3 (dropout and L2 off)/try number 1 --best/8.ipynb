# %%
import datetime

import copy

import random


from dateutil.relativedelta import relativedelta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('seaborn')
# plt.style.use(['dark_background', 'ggplot'])

import seaborn as sns
# sns.set()

# import scipy
# import scipy.stats as stats


# # sympy = symbolic math in Python
# import sympy as sym
# import sympy.plotting.plot as symplot


# make the equations look nicer

# from IPython.display import display
# display.set_matplotlib_formats('svg') # Deprecated since version 7.23

# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


# %config InlineBackend.set_matplotlib_formats = ["svg"]
# %config InlineBackend.figure_formats = ["svg"]

# %%
import sklearn


from sklearn.model_selection import train_test_split


# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler     # <------------ (-1.0, 1.0)
# from sklearn.preprocessing import MinMaxScaler


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from imblearn.over_sampling import SMOTE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset, DataLoader





torch.__version__
# Out:
# '1.12.1+cu113'

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def print_score(shape, yHat, y, yHat_test, yy):
    
    
    n, p = shape
    
    R2 = r2_score(y.detach().numpy(), yHat.detach().numpy())
    
    Adj_r2 = 1 - (1 - R2)  *  (n - 1) / (n - p - 1)
    
    print(f'Adjusted R-Squared(y, yHat): {Adj_r2:0.4f}\n\n')
    # r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
    #  R^2 score is not well-defined with less than two samples
    
    
    print(f'mean_absolute_error(y, yHat):',
          f'{mean_absolute_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_absolute_error(yy, yHat_test):',
          f'{mean_absolute_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_error(y, yHat):',
          f'{mean_squared_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_error(yy, yHat_test):',
          f'{mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_log_error(y, yHat):',
          f'{mean_squared_log_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_log_error(yy, yHat_test):',
          f'{mean_squared_log_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    
    print(f'RMSE(y, yHat):',
          f'{np.sqrt( mean_squared_error(y.detach().numpy(), yHat.detach().numpy()) ):0.4f}\n')
    print(f'RMSE(yy, yHat_test):',
          f'{np.sqrt( mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()) ):0.4f}\n\n')

# %%
# date = np.datetime64("2000-01-01")
# date_strings = date.astype(str).split('-'). 
# # >> ['2000', '01', '01']

# year_int = int(date_strings[0])

# %%
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Out:
# --2022-08-14 13:51:57--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5230713 (5.0M) [text/plain]
# Saving to: ‘data.txt’
#
# data.txt            100%[===================>]   4.99M  --.-KB/s    in 0.02s
#
# 2022-08-14 13:52:20 (287 MB/s) - ‘data.txt’ saved [5230713/5230713]
#
# --2022-08-14 13:52:20--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37732 (37K) [text/plain]
# Saving to: ‘example_input.txt’
#
# example_input.txt   100%[===================>]  36.85K  --.-KB/s    in 0s
#
# 2022-08-14 13:52:20 (135 MB/s) - ‘example_input.txt’ saved [37732/37732]

# %%
# !ls
# Out:
# checkpoint.pth.tar  data.txt  example_input.txt  sample_data

# %% [markdown]
# 'text.txt'

# %% [markdown]
# [ 1-1-1800 to 31-12-2200 ]

# %% [markdown]
# [day condition] [month condition] [leap year condition] [decade condition] date

# %% [markdown]
# [MON] [DEC] [False] [196] 3-12-1962
# [THU] [DEC] [True] [204] 3-12-2048
# [WED] [JAN] [False] [181] 10-1-1810

# %%
# data = np.loadtxt(open('text.txt','r'),delimiter=' ')
# ori = pd.read_csv('./data/data.txt', sep=' ', header=None)

ori = pd.read_csv('data.txt', sep=' ', header=None)

# %%
ori.columns = ['day', 'month', 'leap_year', 'decade', 'date']

# %%
ori
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
# data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)
# # pd.to_datetime(data.date, infer_datetime_format=False)

# %%
ori.dtypes
# Out:
# day          object
# month        object
# leap_year    object
# decade       object
# date         object
# dtype: object

# %%
# data_backup = copy.deepcopy(ori)
data = copy.deepcopy(ori)

# %%
data
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
data.date
# Out:
# 0           1-1-1800
# 1           1-1-1801
# 2           1-1-1802
# 3           1-1-1803
# 4           1-1-1804
#              ...
# 146457    31-12-2196
# 146458    31-12-2197
# 146459    31-12-2198
# 146460    31-12-2199
# 146461    31-12-2200
# Name: date, Length: 146462, dtype: object

# %%
# # data['date'] = pd.date_range('3-12-2048', periods=10)
# # data['date'] = pd.date_range('12-3-1962', periods=10)

# # 1-1-1800 to 31-12-2200
# data['date'] = pd.date_range(start='1-1-1800',end='12-31-2200')


data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)

# # data.date = data.date.dt.strftime('%d-%m-%Y')
# # data.date = pd.to_datetime(data.date.dt.strftime('%d-%m-%Y'), format='%d-%m-%Y', infer_datetime_format=False)

# %%
data.dtypes
# Out:
# day                  object
# month                object
# leap_year            object
# decade               object
# date         datetime64[ns]
# dtype: object

# %%
data
# Out:
#           day  month leap_year decade       date
# 0       [WED]  [JAN]   [False]  [180] 1800-01-01
# 1       [THU]  [JAN]   [False]  [180] 1801-01-01
# 2       [FRI]  [JAN]   [False]  [180] 1802-01-01
# 3       [SAT]  [JAN]   [False]  [180] 1803-01-01
# 4       [SUN]  [JAN]    [True]  [180] 1804-01-01
# ...       ...    ...       ...    ...        ...
# 146457  [SAT]  [DEC]    [True]  [219] 2196-12-31
# 146458  [SUN]  [DEC]   [False]  [219] 2197-12-31
# 146459  [MON]  [DEC]   [False]  [219] 2198-12-31
# 146460  [TUE]  [DEC]   [False]  [219] 2199-12-31
# 146461  [WED]  [DEC]   [False]  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %%
map_leap_year = {'[False]': int(0), '[True]' : int(1)}

data.leap_year = data.leap_year.map(map_leap_year)

# data.leap_year = data.leap_year.astype(np.float64)

# %%
data
# Out:
#           day  month  leap_year decade       date
# 0       [WED]  [JAN]          0  [180] 1800-01-01
# 1       [THU]  [JAN]          0  [180] 1801-01-01
# 2       [FRI]  [JAN]          0  [180] 1802-01-01
# 3       [SAT]  [JAN]          0  [180] 1803-01-01
# 4       [SUN]  [JAN]          1  [180] 1804-01-01
# ...       ...    ...        ...    ...        ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31
# 146459  [MON]  [DEC]          0  [219] 2198-12-31
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31
# 146461  [WED]  [DEC]          0  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %% [markdown]
# date -> timestamp

# %%
data.date.iloc[0]
# Out:
# Timestamp('1800-01-01 00:00:00')

# %%
data['date_int'] = data['date'].dt.strftime("%Y%m%d").astype(np.int64)

# data['date_str'] = data['date'].dt.strftime("%Y%m%d")

# %%
# data['date_int'].map(str)
# data['date_int'].astype(str)

# %%
# date_max = data.date_int.max()
# data['date_normalized'] = data.date_int / date_max

# %%
data
# Out:
#           day  month  leap_year decade       date  date_int
# 0       [WED]  [JAN]          0  [180] 1800-01-01  18000101
# 1       [THU]  [JAN]          0  [180] 1801-01-01  18010101
# 2       [FRI]  [JAN]          0  [180] 1802-01-01  18020101
# 3       [SAT]  [JAN]          0  [180] 1803-01-01  18030101
# 4       [SUN]  [JAN]          1  [180] 1804-01-01  18040101
# ...       ...    ...        ...    ...        ...       ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31  21961231
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31  21971231
# 146459  [MON]  [DEC]          0  [219] 2198-12-31  21981231
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31  21991231
# 146461  [WED]  [DEC]          0  [220] 2200-12-31  22001231
#
# [146462 rows x 6 columns]

# %%
x = data.decade.iloc[0]
x
# Out:
# '[180]'

# %%
x.strip('[]')
# Out:
# '180'

# %%
data.decade = data.decade.apply(lambda x: x.strip('[]')).astype('int64')

# %%
# data.day = data.day.apply(lambda x: x.strip('[]'))
# data.month = data.month.apply(lambda x: x.strip('[]'))

# %%
map_day = {'[SAT]': int(0),
           '[SUN]': int(1),
           '[MON]': int(2),
           '[TUE]': int(3),
           '[WED]': int(4),
           '[THU]': int(5),
           '[FRI]': int(6)}

# %%
data['day_code'] = data.day.map(map_day)

# %%
scaler_day = RobustScaler()

x = data.day_code.values.reshape(-1, 1)

data['day_scaled'] = scaler_day.fit_transform(x).flatten()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled
# 0             0.25
# 1             0.50
# 2             0.75
# 3            -0.75
# 4            -0.50
# ...            ...
# 146457       -0.75
# 146458       -0.50
# 146459       -0.25
# 146460        0.00
# 146461        0.25
#
# [146462 rows x 8 columns]

# %%
data['day_sin'] = np.sin(data['day_code'] * (2 * np.pi / 7))
data['day_cos'] = np.cos(data['day_code'] * (2 * np.pi / 7))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos
# 0             0.25 -0.433884 -0.900969
# 1             0.50 -0.974928 -0.222521
# 2             0.75 -0.781831  0.623490
# 3            -0.75  0.000000  1.000000
# 4            -0.50  0.781831  0.623490
# ...            ...       ...       ...
# 146457       -0.75  0.000000  1.000000
# 146458       -0.50  0.781831  0.623490
# 146459       -0.25  0.974928 -0.222521
# 146460        0.00  0.433884 -0.900969
# 146461        0.25 -0.433884 -0.900969
#
# [146462 rows x 10 columns]

# %%
map_month = {'[JAN]' : 0,
             '[FEB]' : 1,
             '[MAR]' : 2,
             '[APR]' : 3,
             '[MAY]' : 4,
             '[JUN]' : 5,
             '[JUL]' : 6,
             '[AUG]' : 7,
             '[SEP]' : 8,
             '[OCT]' : 9,
             '[NOV]' : 10,
             '[DEC]' : 11}

# %%
data['month_code'] = data.month.map(map_month)

# %%
scaler_month = RobustScaler()

x = data.month_code.values.reshape(-1, 1)

data['month_scaled'] = scaler_month.fit_transform(x).flatten()

# %%
data['month_sin'] = np.sin(data['month_code'] * (2 * np.pi / 12))
data['month_cos'] = np.cos(data['month_code'] * (2 * np.pi / 12))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ...           ...
# 146457   0.866025
# 146458   0.866025
# 146459   0.866025
# 146460   0.866025
# 146461   0.866025
#
# [146462 rows x 14 columns]

# %%
scaler_decade = RobustScaler()

x = data.decade.values.reshape(-1, 1)

data['decade_scaled'] = scaler_decade.fit_transform(x).flatten()

# %%
# alpha = len(data.decade.unique())
alpha = (data.decade.iloc[-1] - data.decade.iloc[0]) + 1

data['decade_sin'] = np.sin(data['decade'] * (2 * np.pi / alpha))
data['decade_cos'] = np.cos(data['decade'] * (2 * np.pi / alpha))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %%
# data.date_normalized.min(), data.date_normalized.max()

# %%
# round(data.date_normalized.min()), round(data.date_normalized.max())

# %%
round(data.day_scaled.min()), round(data.day_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_sin.min()), round(data.day_sin.max())
# Out:
# (-1, 1)

# %%
round(data.day_cos.min()), round(data.day_cos.max())
# Out:
# (-1, 1)

# %%
round(data.month_scaled.min()), round(data.month_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.month_sin.min()), round(data.month_sin.max())
# Out:
# (-1, 1)

# %%
round(data.month_cos.min()), round(data.month_cos.max())
# Out:
# (-1, 1)

# %%
data.leap_year.min(), data.leap_year.max()
# Out:
# (0, 1)

# %%
round(data.decade_scaled.min()), round(data.decade_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.decade_sin.min()), round(data.decade_sin.max())
# Out:
# (-1, 1)

# %%
round(data.decade_cos.min()), round(data.decade_cos.max())
# Out:
# (-1, 1)

# %% [markdown]
# Boxplot

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.day.value_counts().plot(kind="bar")

# %%
data.month.value_counts().plot(kind="bar")

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
data.decade.value_counts().plot(kind="bar")

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %% [markdown]
# ['day_sin', 'day_cos', 'month_sin', 'month_cos', 'leap_year', 'decade_scaled']
# ['date_timestamp_scaled']

# %%
X = data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
          'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 0.25      , -0.43388374, -0.90096887, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.5       , -0.97492791, -0.22252093, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.75      , -0.78183148,  0.6234898 , ..., -1.        ,
#          0.63624244, -0.77148918],
#        ...,
#        [-0.25      ,  0.97492791, -0.22252093, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.        ,  0.43388374, -0.90096887, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.25      , -0.43388374, -0.90096887, ...,  1.        ,
#          0.74655322, -0.6653257 ]])

# %%
len(X)
# Out:
# 146462

# %%
X.shape
# Out:
# (146462, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()


ls = []

for s in data['date_int'].astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(data['date_int'])), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y = ll.values

Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 2, 0, ..., 2, 3, 1]])

# %%
len(Y)
# Out:
# 146462

# %%
Y.shape
# Out:
# (146462, 8)

# %%
# # leap = np.where(~X['leap_year'] == 1)[0]
# leap = np.where(X['leap_year'] == 1)[0]

# leap

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64


train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (146462, 10)
#
# Y: (146462, 8)
#
# Train data:   (102523, 10)
#
# Train labels: (102523, 8)
#
# Test data:    (43939, 10)
#
# Test labels:  (43939, 8)

# %%
102523 % 32, 102523 % 64
# Out:
# (27, 59)

# %%
class Model(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.input = nn.Linear(10, 32)

        self.fc1 = nn.Linear(32, 128)
        self.bnorm1 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 512)
        self.bnorm2 = nn.BatchNorm1d(512)

        self.fc3 = nn.Linear(512, 64)
        self.bnorm3 = nn.BatchNorm1d(64)

        self.fc4 = nn.Linear(64, 32)
        self.bnorm4 = nn.BatchNorm1d(32)


        self.output = nn.Linear(32, 8)



    def forward(self, x):


        # print(f'training={self.training}')

        x = F.relu( self.input(x) )

        x = F.relu(self.bnorm1(self.fc1(x)))
        # x = F.dropout(x, p=0.25, training=self.training)

        x = F.relu(self.bnorm2(self.fc2(x)))
        # x = F.dropout(x, p=0.4, training=self.training)

        x = F.relu(self.bnorm3(self.fc3(x)))
        # x = F.dropout(x, p=0.1, training=self.training)

        x = F.relu(self.bnorm4(self.fc4(x)))
        # x = F.dropout(x, p=0.05, training=self.training)


        x = F.relu(self.output(x))
        # x = self.output(x)
        


        return x

# %%
# test_x, test_y = next(iter(train_loader))

# print(f'test_x: {test_x.shape}\n')
# print(f'test_y: {test_y.shape}\n')

# %%
def train(model, numepochs):

    numepochs = numepochs

    model = model
    
    
    
    lossfun = nn.MSELoss()
    # lossfun = nn.L1Loss()


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0002, betas=(0.5, 0.999), weight_decay=1e-5)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.5, 0.999), weight_decay=1e-1)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=1e-9)


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
    
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    
    
    
    trainLoss = torch.zeros(numepochs)
    testLoss  = torch.zeros(numepochs)
    trainAcc  = torch.zeros(numepochs)
    # testAcc   = torch.zeros(numepochs)


    for epochi in range(numepochs):

        model.train() # switch to train mode

        batchLoss = []
        batchAcc  = []

        for X,y in train_loader:

            X = X.to(device)
            y = y.to(device)

            yHat = model(X)
            loss = lossfun(yHat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())
            # batchAcc.append( torch.mean(( yHat == y).float() ).item() )
            # batchAcc.append( torch.mean( (torch.abs(yHat - y) < 1).float() ).item() ) # <1 for rounding
            batchAcc.append( r2_score(y.detach().cpu().numpy(), yHat.detach().cpu().numpy()) )
            




        trainLoss[epochi] = np.mean(batchLoss)
        # trainAcc[epochi]  = 100*np.mean(batchAcc)
        trainAcc[epochi]  = np.mean(batchAcc)
        



        model.eval() # switch to test mode

        XX,yy = next(iter(test_loader))

        XX = XX.to(device)
        yy = yy.to(device)

        # forward pass and loss
        with torch.no_grad():
            yHat_test = model(XX)
            loss_test = lossfun(yHat_test, yy)


        testLoss[epochi] = loss_test.item()
        # testAcc[epochi]  = 100*torch.mean( (yHat_test == yy).float() ).item()
        # testAcc[epochi]  = 100*torch.mean( (torch.abs(yHat_test - yy) < 1).float() ).item()
        # testAcc[epochi]  = 100*r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
        


        # if (epochi + 1) % 5 == 0:
        print(f'Epoch {epochi+1}/{numepochs}, Train Loss: {loss.item():0.6f}, Test Loss: {loss_test.item():0.6f}')


        
    return trainLoss.cpu(), testLoss.cpu(), trainAcc.cpu(), yHat.cpu(), y.cpu(), yHat_test.cpu(), yy.cpu()

# %%
model = Model().to(device)

# test_hat = model(torch.randn(32,6))
# test_hat = model(test_x)

# print(test_hat.shape)


checkpoint = torch.load('checkpoint.pth.tar', map_location=torch.device('cpu'))
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
# for p in list(model.named_parameters()):
#     if 'weight' in p[0] and 'bnorm' not in p[0]:
#         nn.init.xavier_normal_(p[1].data)
#         print(p[0])
#         print(p[1].data.shape)

# %%
# numepochs = 120
numepochs = 300


trainLoss1, testLoss1, trainAcc1, yHat1, y1, yHat_test1, yy1 = train(model, numepochs)
# Out:
# Epoch 1/300, Train Loss: 2.302337, Test Loss: 1.999373
# Epoch 2/300, Train Loss: 2.303015, Test Loss: 1.981573
# Epoch 3/300, Train Loss: 2.296900, Test Loss: 1.970919
# Epoch 4/300, Train Loss: 2.301524, Test Loss: 1.978803
# Epoch 5/300, Train Loss: 2.293966, Test Loss: 1.961236
# Epoch 6/300, Train Loss: 2.289582, Test Loss: 1.977969
# Epoch 7/300, Train Loss: 2.289130, Test Loss: 1.966567
# Epoch 8/300, Train Loss: 2.287371, Test Loss: 1.967408
# Epoch 9/300, Train Loss: 2.295054, Test Loss: 1.966945
# Epoch 10/300, Train Loss: 2.288275, Test Loss: 1.962537
# Epoch 11/300, Train Loss: 2.285141, Test Loss: 1.971647
# Epoch 12/300, Train Loss: 2.285228, Test Loss: 1.966987
# Epoch 13/300, Train Loss: 2.284967, Test Loss: 1.968360
# Epoch 14/300, Train Loss: 2.287726, Test Loss: 1.973240
# Epoch 15/300, Train Loss: 2.288395, Test Loss: 1.977802
# Epoch 16/300, Train Loss: 2.285763, Test Loss: 1.978617
# Epoch 17/300, Train Loss: 2.284051, Test Loss: 1.974441
# Epoch 18/300, Train Loss: 2.284529, Test Loss: 1.983424
# Epoch 19/300, Train Loss: 2.283529, Test Loss: 1.986615
# Epoch 20/300, Train Loss: 2.280955, Test Loss: 1.981358
# Epoch 21/300, Train Loss: 2.280600, Test Loss: 1.983980
# Epoch 22/300, Train Loss: 2.279982, Test Loss: 1.991060
# Epoch 23/300, Train Loss: 2.283486, Test Loss: 1.998333
# Epoch 24/300, Train Loss: 2.276469, Test Loss: 2.017172
# Epoch 25/300, Train Loss: 2.278771, Test Loss: 2.012381
# Epoch 26/300, Train Loss: 2.281004, Test Loss: 2.006499
# Epoch 27/300, Train Loss: 2.273354, Test Loss: 2.001855
# Epoch 28/300, Train Loss: 2.302352, Test Loss: 1.991928
# Epoch 29/300, Train Loss: 2.279954, Test Loss: 2.000676
# Epoch 30/300, Train Loss: 2.283053, Test Loss: 2.004653
# Epoch 31/300, Train Loss: 2.279914, Test Loss: 2.014486
# Epoch 32/300, Train Loss: 2.277984, Test Loss: 2.012165
# Epoch 33/300, Train Loss: 2.274759, Test Loss: 2.006167
# Epoch 34/300, Train Loss: 2.275122, Test Loss: 1.990828
# Epoch 35/300, Train Loss: 2.281898, Test Loss: 1.981260
# Epoch 36/300, Train Loss: 2.279395, Test Loss: 1.975712
# Epoch 37/300, Train Loss: 2.281182, Test Loss: 1.991019
# Epoch 38/300, Train Loss: 2.283925, Test Loss: 1.987031
# Epoch 39/300, Train Loss: 2.284382, Test Loss: 1.973427
# Epoch 40/300, Train Loss: 2.286656, Test Loss: 1.974404
# Epoch 41/300, Train Loss: 2.279984, Test Loss: 1.980869
# Epoch 42/300, Train Loss: 2.286465, Test Loss: 1.970976
# Epoch 43/300, Train Loss: 2.289027, Test Loss: 1.964283
# Epoch 44/300, Train Loss: 2.286629, Test Loss: 1.981194
# Epoch 45/300, Train Loss: 2.290634, Test Loss: 1.984635
# Epoch 46/300, Train Loss: 2.294327, Test Loss: 1.971544
# Epoch 47/300, Train Loss: 2.284281, Test Loss: 1.978521
# Epoch 48/300, Train Loss: 2.299277, Test Loss: 1.986423
# Epoch 49/300, Train Loss: 2.294264, Test Loss: 1.964184
# Epoch 50/300, Train Loss: 2.294328, Test Loss: 1.994956
# Epoch 51/300, Train Loss: 2.295340, Test Loss: 1.976610
# Epoch 52/300, Train Loss: 2.291342, Test Loss: 1.978937
# Epoch 53/300, Train Loss: 2.290173, Test Loss: 1.990365
# Epoch 54/300, Train Loss: 2.286810, Test Loss: 1.977330
# Epoch 55/300, Train Loss: 2.293055, Test Loss: 1.977773
# Epoch 56/300, Train Loss: 2.284896, Test Loss: 1.969594
# Epoch 57/300, Train Loss: 2.288976, Test Loss: 1.992562
# Epoch 58/300, Train Loss: 2.289223, Test Loss: 1.972446
# Epoch 59/300, Train Loss: 2.285835, Test Loss: 1.977831
# Epoch 60/300, Train Loss: 2.294115, Test Loss: 1.978586
# Epoch 61/300, Train Loss: 2.292756, Test Loss: 1.984064
# Epoch 62/300, Train Loss: 2.291667, Test Loss: 1.993757
# Epoch 63/300, Train Loss: 2.298779, Test Loss: 1.988501
# Epoch 64/300, Train Loss: 2.291273, Test Loss: 1.992561
# Epoch 65/300, Train Loss: 2.292332, Test Loss: 2.003835
# Epoch 66/300, Train Loss: 2.290527, Test Loss: 2.008742
# Epoch 67/300, Train Loss: 2.286462, Test Loss: 1.961481
# Epoch 68/300, Train Loss: 2.290745, Test Loss: 1.975322
# Epoch 69/300, Train Loss: 2.293081, Test Loss: 1.976730
# Epoch 70/300, Train Loss: 2.279491, Test Loss: 1.976565
# Epoch 71/300, Train Loss: 2.290673, Test Loss: 1.998729
# Epoch 72/300, Train Loss: 2.289419, Test Loss: 1.979923
# Epoch 73/300, Train Loss: 2.288412, Test Loss: 1.990298
# Epoch 74/300, Train Loss: 2.304728, Test Loss: 1.994456
# Epoch 75/300, Train Loss: 2.282734, Test Loss: 2.000064
# Epoch 76/300, Train Loss: 2.280288, Test Loss: 1.986595
# Epoch 77/300, Train Loss: 2.286180, Test Loss: 1.980755
# Epoch 78/300, Train Loss: 2.289677, Test Loss: 1.989756
# Epoch 79/300, Train Loss: 2.289715, Test Loss: 1.975749
# Epoch 80/300, Train Loss: 2.285855, Test Loss: 1.977250
# Epoch 81/300, Train Loss: 2.284914, Test Loss: 1.982838
# Epoch 82/300, Train Loss: 2.288859, Test Loss: 1.988029
# Epoch 83/300, Train Loss: 2.289279, Test Loss: 1.960431
# Epoch 84/300, Train Loss: 2.287837, Test Loss: 1.970391
# Epoch 85/300, Train Loss: 2.292362, Test Loss: 1.992487
# Epoch 86/300, Train Loss: 2.286987, Test Loss: 1.979791
# Epoch 87/300, Train Loss: 2.283697, Test Loss: 1.972080
# Epoch 88/300, Train Loss: 2.289190, Test Loss: 1.979442
# Epoch 89/300, Train Loss: 2.287760, Test Loss: 1.964745
# Epoch 90/300, Train Loss: 2.285145, Test Loss: 1.977267
# Epoch 91/300, Train Loss: 2.422636, Test Loss: 1.973846
# Epoch 92/300, Train Loss: 2.292043, Test Loss: 1.978909
# Epoch 93/300, Train Loss: 2.290808, Test Loss: 1.985581
# Epoch 94/300, Train Loss: 2.287399, Test Loss: 1.984772
# Epoch 95/300, Train Loss: 2.291708, Test Loss: 1.989717
# Epoch 96/300, Train Loss: 2.290545, Test Loss: 1.992561
# Epoch 97/300, Train Loss: 2.289550, Test Loss: 2.001381
# Epoch 98/300, Train Loss: 2.287552, Test Loss: 1.987555
# Epoch 99/300, Train Loss: 2.288723, Test Loss: 1.981572
# Epoch 100/300, Train Loss: 2.293246, Test Loss: 1.975658
# Epoch 101/300, Train Loss: 2.298662, Test Loss: 1.988533
# Epoch 102/300, Train Loss: 2.286781, Test Loss: 1.961012
# Epoch 103/300, Train Loss: 2.295645, Test Loss: 1.974252
# Epoch 104/300, Train Loss: 2.295178, Test Loss: 1.980919
# Epoch 105/300, Train Loss: 2.290989, Test Loss: 1.987255
# Epoch 106/300, Train Loss: 2.295097, Test Loss: 1.965364
# Epoch 107/300, Train Loss: 2.297467, Test Loss: 1.964524
# Epoch 108/300, Train Loss: 2.294498, Test Loss: 1.965585
# Epoch 109/300, Train Loss: 2.305886, Test Loss: 1.985428
# Epoch 110/300, Train Loss: 2.296235, Test Loss: 1.971077
# Epoch 111/300, Train Loss: 2.289871, Test Loss: 1.965991
# Epoch 112/300, Train Loss: 2.300565, Test Loss: 1.968918
# Epoch 113/300, Train Loss: 2.295743, Test Loss: 1.977859
# Epoch 114/300, Train Loss: 2.297408, Test Loss: 1.972309
# Epoch 115/300, Train Loss: 2.299538, Test Loss: 1.962472
# Epoch 116/300, Train Loss: 2.290361, Test Loss: 1.974007
# Epoch 117/300, Train Loss: 2.287099, Test Loss: 1.969602
# Epoch 118/300, Train Loss: 2.294746, Test Loss: 1.972299
# Epoch 119/300, Train Loss: 2.296872, Test Loss: 1.975371
# Epoch 120/300, Train Loss: 2.291926, Test Loss: 1.964546
# Epoch 121/300, Train Loss: 2.287706, Test Loss: 1.967601
# Epoch 122/300, Train Loss: 2.287963, Test Loss: 1.965245
# Epoch 123/300, Train Loss: 2.295122, Test Loss: 1.976955
# Epoch 124/300, Train Loss: 2.291266, Test Loss: 1.951764
# Epoch 125/300, Train Loss: 2.295481, Test Loss: 1.967027
# Epoch 126/300, Train Loss: 2.292728, Test Loss: 1.953209
# Epoch 127/300, Train Loss: 2.295822, Test Loss: 1.939858
# Epoch 128/300, Train Loss: 2.275569, Test Loss: 1.961429
# Epoch 129/300, Train Loss: 2.296140, Test Loss: 1.961640
# Epoch 130/300, Train Loss: 2.295512, Test Loss: 1.952159
# Epoch 131/300, Train Loss: 2.297338, Test Loss: 1.935189
# Epoch 132/300, Train Loss: 2.291371, Test Loss: 1.948679
# Epoch 133/300, Train Loss: 2.287768, Test Loss: 1.961493
# Epoch 134/300, Train Loss: 2.290249, Test Loss: 1.960300
# Epoch 135/300, Train Loss: 2.287129, Test Loss: 1.946974
# Epoch 136/300, Train Loss: 2.287182, Test Loss: 1.950582
# Epoch 137/300, Train Loss: 2.293176, Test Loss: 1.942495
# Epoch 138/300, Train Loss: 2.286150, Test Loss: 1.960833
# Epoch 139/300, Train Loss: 2.281474, Test Loss: 1.940775
# Epoch 140/300, Train Loss: 2.289214, Test Loss: 1.945207
# Epoch 141/300, Train Loss: 2.293875, Test Loss: 1.953877
# Epoch 142/300, Train Loss: 2.286371, Test Loss: 1.948280
# Epoch 143/300, Train Loss: 2.284489, Test Loss: 1.938639
# Epoch 144/300, Train Loss: 2.285431, Test Loss: 1.942260
# Epoch 145/300, Train Loss: 2.295232, Test Loss: 1.933218
# Epoch 146/300, Train Loss: 2.293847, Test Loss: 1.953854
# Epoch 147/300, Train Loss: 2.285652, Test Loss: 1.940668
# Epoch 148/300, Train Loss: 2.295985, Test Loss: 1.941490
# Epoch 149/300, Train Loss: 2.288066, Test Loss: 1.950222
# Epoch 150/300, Train Loss: 2.282477, Test Loss: 1.933732
# Epoch 151/300, Train Loss: 2.294453, Test Loss: 1.953746
# Epoch 152/300, Train Loss: 2.281528, Test Loss: 1.928941
# Epoch 153/300, Train Loss: 2.289018, Test Loss: 1.939901
# Epoch 154/300, Train Loss: 2.290307, Test Loss: 1.954757
# Epoch 155/300, Train Loss: 2.282242, Test Loss: 1.933114
# Epoch 156/300, Train Loss: 2.285211, Test Loss: 1.937230
# Epoch 157/300, Train Loss: 2.286473, Test Loss: 1.930705
# Epoch 158/300, Train Loss: 2.291988, Test Loss: 1.943262
# Epoch 159/300, Train Loss: 2.292917, Test Loss: 1.944818
# Epoch 160/300, Train Loss: 2.288744, Test Loss: 1.958337
# Epoch 161/300, Train Loss: 2.285469, Test Loss: 1.936767
# Epoch 162/300, Train Loss: 2.289644, Test Loss: 1.932278
# Epoch 163/300, Train Loss: 2.320909, Test Loss: 1.954246
# Epoch 164/300, Train Loss: 2.283669, Test Loss: 1.941316
# Epoch 165/300, Train Loss: 2.341947, Test Loss: 1.947368
# Epoch 166/300, Train Loss: 2.291015, Test Loss: 1.955472
# Epoch 167/300, Train Loss: 2.288755, Test Loss: 1.946877
# Epoch 168/300, Train Loss: 2.287248, Test Loss: 1.949374
# Epoch 169/300, Train Loss: 2.331814, Test Loss: 1.950726
# Epoch 170/300, Train Loss: 2.291818, Test Loss: 1.945296
# Epoch 171/300, Train Loss: 2.385051, Test Loss: 1.968718
# Epoch 172/300, Train Loss: 2.313691, Test Loss: 1.945265
# Epoch 173/300, Train Loss: 2.285021, Test Loss: 1.972384
# Epoch 174/300, Train Loss: 2.293520, Test Loss: 1.941792
# Epoch 175/300, Train Loss: 2.295327, Test Loss: 1.939901
# Epoch 176/300, Train Loss: 2.287601, Test Loss: 1.942393
# Epoch 177/300, Train Loss: 2.285058, Test Loss: 1.927153
# Epoch 178/300, Train Loss: 2.289975, Test Loss: 1.930258
# Epoch 179/300, Train Loss: 2.292260, Test Loss: 1.946900
# Epoch 180/300, Train Loss: 2.293204, Test Loss: 1.935436
# Epoch 181/300, Train Loss: 2.293663, Test Loss: 1.926729
# Epoch 182/300, Train Loss: 2.301709, Test Loss: 1.945645
# Epoch 183/300, Train Loss: 2.300980, Test Loss: 1.931821
# Epoch 184/300, Train Loss: 2.291066, Test Loss: 1.926084
# Epoch 185/300, Train Loss: 2.287388, Test Loss: 1.926184
# Epoch 186/300, Train Loss: 2.290771, Test Loss: 1.935381
# Epoch 187/300, Train Loss: 2.313806, Test Loss: 1.941989
# Epoch 188/300, Train Loss: 2.289498, Test Loss: 1.936913
# Epoch 189/300, Train Loss: 2.306130, Test Loss: 1.939602
# Epoch 190/300, Train Loss: 2.293765, Test Loss: 1.970046
# Epoch 191/300, Train Loss: 2.289833, Test Loss: 1.935973
# Epoch 192/300, Train Loss: 2.291369, Test Loss: 1.929063
# Epoch 193/300, Train Loss: 2.299022, Test Loss: 1.946044
# Epoch 194/300, Train Loss: 2.291963, Test Loss: 1.937170
# Epoch 195/300, Train Loss: 2.301338, Test Loss: 1.950064
# Epoch 196/300, Train Loss: 2.230215, Test Loss: 1.943096
# Epoch 197/300, Train Loss: 2.272372, Test Loss: 1.935287
# Epoch 198/300, Train Loss: 2.288318, Test Loss: 1.928392
# Epoch 199/300, Train Loss: 2.244282, Test Loss: 1.923572
# Epoch 200/300, Train Loss: 2.287092, Test Loss: 1.923565
# Epoch 201/300, Train Loss: 2.293622, Test Loss: 1.936958
# Epoch 202/300, Train Loss: 2.274402, Test Loss: 1.929384
# Epoch 203/300, Train Loss: 2.259528, Test Loss: 1.931718
# Epoch 204/300, Train Loss: 2.292034, Test Loss: 1.923694
# Epoch 205/300, Train Loss: 2.288018, Test Loss: 1.928337
# Epoch 206/300, Train Loss: 2.259385, Test Loss: 1.924202
# Epoch 207/300, Train Loss: 2.242996, Test Loss: 1.936257
# Epoch 208/300, Train Loss: 2.238010, Test Loss: 1.931633
# Epoch 209/300, Train Loss: 2.237336, Test Loss: 1.911131
# Epoch 210/300, Train Loss: 2.239898, Test Loss: 1.904193
# Epoch 211/300, Train Loss: 2.289849, Test Loss: 1.924655
# Epoch 212/300, Train Loss: 2.256335, Test Loss: 1.928050
# Epoch 213/300, Train Loss: 2.281214, Test Loss: 1.949621
# Epoch 214/300, Train Loss: 2.216491, Test Loss: 1.923763
# Epoch 215/300, Train Loss: 2.282146, Test Loss: 1.926127
# Epoch 216/300, Train Loss: 2.235068, Test Loss: 1.904620
# Epoch 217/300, Train Loss: 2.256318, Test Loss: 1.926873
# Epoch 218/300, Train Loss: 2.232081, Test Loss: 1.934005
# Epoch 219/300, Train Loss: 2.211178, Test Loss: 1.931545
# Epoch 220/300, Train Loss: 2.242124, Test Loss: 1.939804
# Epoch 221/300, Train Loss: 2.193169, Test Loss: 1.937070
# Epoch 222/300, Train Loss: 2.226442, Test Loss: 1.937580
# Epoch 223/300, Train Loss: 2.196901, Test Loss: 1.934772
# Epoch 224/300, Train Loss: 2.196757, Test Loss: 1.931616
# Epoch 225/300, Train Loss: 2.184991, Test Loss: 1.951682
# Epoch 226/300, Train Loss: 2.234622, Test Loss: 1.935720
# Epoch 227/300, Train Loss: 2.210677, Test Loss: 1.921425
# Epoch 228/300, Train Loss: 2.188969, Test Loss: 1.951333
# Epoch 229/300, Train Loss: 2.224012, Test Loss: 1.938791
# Epoch 230/300, Train Loss: 2.181741, Test Loss: 1.934202
# Epoch 231/300, Train Loss: 2.196710, Test Loss: 1.944596
# Epoch 232/300, Train Loss: 2.184478, Test Loss: 1.904026
# Epoch 233/300, Train Loss: 2.176744, Test Loss: 1.912745
# Epoch 234/300, Train Loss: 2.185555, Test Loss: 1.919645
# Epoch 235/300, Train Loss: 2.199214, Test Loss: 1.926858
# Epoch 236/300, Train Loss: 2.322736, Test Loss: 1.927330
# Epoch 237/300, Train Loss: 2.276513, Test Loss: 1.907612
# Epoch 238/300, Train Loss: 2.183186, Test Loss: 1.923909
# Epoch 239/300, Train Loss: 2.206095, Test Loss: 1.898560
# Epoch 240/300, Train Loss: 2.221105, Test Loss: 1.919310
# Epoch 241/300, Train Loss: 2.188209, Test Loss: 1.916556
# Epoch 242/300, Train Loss: 2.181876, Test Loss: 1.915668
# Epoch 243/300, Train Loss: 2.180849, Test Loss: 1.924070
# Epoch 244/300, Train Loss: 2.175376, Test Loss: 1.919986
# Epoch 245/300, Train Loss: 2.258441, Test Loss: 1.896648
# Epoch 246/300, Train Loss: 2.209645, Test Loss: 1.936014
# Epoch 247/300, Train Loss: 2.195539, Test Loss: 1.920711
# Epoch 248/300, Train Loss: 2.214087, Test Loss: 1.913912
# Epoch 249/300, Train Loss: 2.242840, Test Loss: 1.896635
# Epoch 250/300, Train Loss: 2.208562, Test Loss: 1.938388
# Epoch 251/300, Train Loss: 2.175271, Test Loss: 1.892370
# Epoch 252/300, Train Loss: 2.188221, Test Loss: 1.931302
# Epoch 253/300, Train Loss: 2.188287, Test Loss: 1.942856
# Epoch 254/300, Train Loss: 2.169748, Test Loss: 1.916384
# Epoch 255/300, Train Loss: 2.217320, Test Loss: 1.913277
# Epoch 256/300, Train Loss: 2.195832, Test Loss: 1.917829
# Epoch 257/300, Train Loss: 2.178897, Test Loss: 1.912029
# Epoch 258/300, Train Loss: 2.215554, Test Loss: 1.921163
# Epoch 259/300, Train Loss: 2.214884, Test Loss: 1.923923
# Epoch 260/300, Train Loss: 2.204369, Test Loss: 1.904564
# Epoch 261/300, Train Loss: 2.200733, Test Loss: 1.933195
# Epoch 262/300, Train Loss: 2.192054, Test Loss: 1.921646
# Epoch 263/300, Train Loss: 2.242123, Test Loss: 1.915823
# Epoch 264/300, Train Loss: 2.194212, Test Loss: 1.905191
# Epoch 265/300, Train Loss: 2.182029, Test Loss: 1.931520
# Epoch 266/300, Train Loss: 2.206609, Test Loss: 1.953248
# Epoch 267/300, Train Loss: 2.223507, Test Loss: 1.938827
# Epoch 268/300, Train Loss: 2.194225, Test Loss: 1.931685
# Epoch 269/300, Train Loss: 2.196414, Test Loss: 1.952663
# Epoch 270/300, Train Loss: 2.190686, Test Loss: 1.928796
# Epoch 271/300, Train Loss: 2.235046, Test Loss: 1.922759
# Epoch 272/300, Train Loss: 2.197233, Test Loss: 1.913573
# Epoch 273/300, Train Loss: 2.205102, Test Loss: 1.909348
# Epoch 274/300, Train Loss: 2.177633, Test Loss: 1.923578
# Epoch 275/300, Train Loss: 2.178940, Test Loss: 1.904653
# Epoch 276/300, Train Loss: 2.196526, Test Loss: 1.928480
# Epoch 277/300, Train Loss: 2.165816, Test Loss: 1.959446
# Epoch 278/300, Train Loss: 2.171148, Test Loss: 1.918641
# Epoch 279/300, Train Loss: 2.218387, Test Loss: 1.947705
# Epoch 280/300, Train Loss: 2.192847, Test Loss: 1.924254
# Epoch 281/300, Train Loss: 2.186534, Test Loss: 1.935157
# Epoch 282/300, Train Loss: 2.211918, Test Loss: 1.954927
# Epoch 283/300, Train Loss: 2.204440, Test Loss: 1.918458
# Epoch 284/300, Train Loss: 2.195072, Test Loss: 1.939807
# Epoch 285/300, Train Loss: 2.186671, Test Loss: 1.936855
# Epoch 286/300, Train Loss: 2.205422, Test Loss: 1.958526
# Epoch 287/300, Train Loss: 2.172418, Test Loss: 1.943069
# Epoch 288/300, Train Loss: 2.201507, Test Loss: 1.951511
# Epoch 289/300, Train Loss: 2.210559, Test Loss: 1.941793
# Epoch 290/300, Train Loss: 2.209937, Test Loss: 1.936712
# Epoch 291/300, Train Loss: 2.222135, Test Loss: 1.947497
# Epoch 292/300, Train Loss: 2.209843, Test Loss: 1.917879
# Epoch 293/300, Train Loss: 2.242724, Test Loss: 1.965708
# Epoch 294/300, Train Loss: 2.208683, Test Loss: 1.923884
# Epoch 295/300, Train Loss: 2.223471, Test Loss: 1.972153
# Epoch 296/300, Train Loss: 2.203622, Test Loss: 1.968013
# Epoch 297/300, Train Loss: 2.257232, Test Loss: 1.899584
# Epoch 298/300, Train Loss: 2.235900, Test Loss: 1.911238
# Epoch 299/300, Train Loss: 2.199420, Test Loss: 1.912363
# Epoch 300/300, Train Loss: 2.224871, Test Loss: 1.910748

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              #'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              #'scaler_day_smote' : scaler_day_smote,
              #'scaler_month_smote' : scaler_month_smote,
              #'scaler_decade_smote' : scaler_decade_smote,
              
              'alpha': alpha,
              #'alpha_smote': alpha_smote
              }



torch.save(checkpoint, 'checkpoint_half.pth.tar')

# %%
# r2_score(y.detach().numpy(), yHat.detach().numpy())
# type(r2_score(y.detach(), yHat.detach()))

# %%
# torch.mean( r2_score(y.detach().numpy(), yHat.detach().numpy()) ).item()

# %%
trainLoss1, testLoss1, trainAcc1
# Out:
# (tensor([2.1906, 2.1862, 2.1831, 2.1807, 2.1795, 2.1789, 2.1778, 2.1763, 2.1764,
#          2.1753, 2.1744, 2.1749, 2.1736, 2.1737, 2.1746, 2.1729, 2.1729, 2.1730,
#          2.1726, 2.1725, 2.1725, 2.1731, 2.1720, 2.1725, 2.1721, 2.1719, 2.1714,
#          2.1714, 2.1724, 2.1711, 2.1721, 2.1711, 2.1714, 2.1710, 2.1711, 2.1709,
#          2.1716, 2.1707, 2.1706, 2.1710, 2.1705, 2.1717, 2.1702, 2.1708, 2.1703,
#          2.1714, 2.1701, 2.1701, 2.1708, 2.1696, 2.1696, 2.1705, 2.1694, 2.1689,
#          2.1690, 2.1689, 2.1682, 2.1676, 2.1684, 2.1679, 2.1674, 2.1676, 2.1706,
#          2.1675, 2.1671, 2.1671, 2.1682, 2.1666, 2.1661, 2.1658, 2.1676, 2.1652,
#          2.1658, 2.1658, 2.1653, 2.1715, 2.1650, 2.1645, 2.1657, 2.1647, 2.1638,
#          2.1642, 2.1629, 2.1637, 2.1629, 2.1629, 2.1636, 2.1629, 2.1625, 2.1621,
#          2.1623, 2.1605, 2.1615, 2.1616, 2.1613, 2.1611, 2.1610, 2.1612, 2.1609,
#          2.1604, 2.1599, 2.1618, 2.1589, 2.1598, 2.1593, 2.1593, 2.1588, 2.1602,
#          2.1588, 2.1578, 2.1584, 2.1581, 2.1571, 2.1577, 2.1564, 2.1566, 2.1579,
#          2.1559, 2.1564, 2.1559, 2.1560, 2.1552, 2.1548, 2.1549, 2.1541, 2.1541,
#          2.1539, 2.1543, 2.1544, 2.1545, 2.1538, 2.1528, 2.1521, 2.1527, 2.1518,
#          2.1522, 2.1521, 2.1513, 2.1516, 2.1513, 2.1513, 2.1521, 2.1507, 2.1508,
#          2.1501, 2.1499, 2.1511, 2.1509, 2.1489, 2.1494, 2.1490, 2.1491, 2.1479,
#          2.1488, 2.1487, 2.1479, 2.1478, 2.1485, 2.1471, 2.1476, 2.1474, 2.1476,
#          2.1471, 2.1459, 2.1467, 2.1465, 2.1453, 2.1458, 2.1453, 2.1452, 2.1446,
#          2.1443, 2.1445, 2.1439, 2.1431, 2.1439, 2.1438, 2.1443, 2.1434, 2.1425,
#          2.1431, 2.1426, 2.1429, 2.1418, 2.1420, 2.1415, 2.1412, 2.1416, 2.1406,
#          2.1410, 2.1405, 2.1396, 2.1402, 2.1403, 2.1399, 2.1393, 2.1388, 2.1401,
#          2.1400, 2.1383, 2.1388, 2.1386, 2.1378, 2.1378, 2.1387, 2.1372, 2.1372,
#          2.1375, 2.1383, 2.1369, 2.1370, 2.1367, 2.1361, 2.1363, 2.1354, 2.1356,
#          2.1341, 2.1352, 2.1356, 2.1338, 2.1340, 2.1341, 2.1334, 2.1339, 2.1327,
#          2.1328, 2.1332, 2.1322, 2.1338, 2.1323, 2.1332, 2.1315, 2.1344, 2.1321,
#          2.1319, 2.1315, 2.1314, 2.1304, 2.1306, 2.1313, 2.1300, 2.1302, 2.1306,
#          2.1296, 2.1296, 2.1299, 2.1300, 2.1296, 2.1303, 2.1293, 2.1298, 2.1298,
#          2.1287, 2.1284, 2.1277, 2.1287, 2.1275, 2.1274, 2.1280, 2.1268, 2.1274,
#          2.1285, 2.1267, 2.1279, 2.1270, 2.1266, 2.1264, 2.1261, 2.1244, 2.1258,
#          2.1253, 2.1258, 2.1241, 2.1252, 2.1237, 2.1253, 2.1246, 2.1253, 2.1238,
#          2.1243, 2.1240, 2.1229, 2.1228, 2.1223, 2.1225, 2.1231, 2.1232, 2.1232,
#          2.1219, 2.1246, 2.1214, 2.1215, 2.1209, 2.1211, 2.1207, 2.1198, 2.1214,
#          2.1216, 2.1201, 2.1198]),
#  tensor([1.9994, 1.9816, 1.9709, 1.9788, 1.9612, 1.9780, 1.9666, 1.9674, 1.9669,
#          1.9625, 1.9716, 1.9670, 1.9684, 1.9732, 1.9778, 1.9786, 1.9744, 1.9834,
#          1.9866, 1.9814, 1.9840, 1.9911, 1.9983, 2.0172, 2.0124, 2.0065, 2.0019,
#          1.9919, 2.0007, 2.0047, 2.0145, 2.0122, 2.0062, 1.9908, 1.9813, 1.9757,
#          1.9910, 1.9870, 1.9734, 1.9744, 1.9809, 1.9710, 1.9643, 1.9812, 1.9846,
#          1.9715, 1.9785, 1.9864, 1.9642, 1.9950, 1.9766, 1.9789, 1.9904, 1.9773,
#          1.9778, 1.9696, 1.9926, 1.9724, 1.9778, 1.9786, 1.9841, 1.9938, 1.9885,
#          1.9926, 2.0038, 2.0087, 1.9615, 1.9753, 1.9767, 1.9766, 1.9987, 1.9799,
#          1.9903, 1.9945, 2.0001, 1.9866, 1.9808, 1.9898, 1.9757, 1.9772, 1.9828,
#          1.9880, 1.9604, 1.9704, 1.9925, 1.9798, 1.9721, 1.9794, 1.9647, 1.9773,
#          1.9738, 1.9789, 1.9856, 1.9848, 1.9897, 1.9926, 2.0014, 1.9876, 1.9816,
#          1.9757, 1.9885, 1.9610, 1.9743, 1.9809, 1.9873, 1.9654, 1.9645, 1.9656,
#          1.9854, 1.9711, 1.9660, 1.9689, 1.9779, 1.9723, 1.9625, 1.9740, 1.9696,
#          1.9723, 1.9754, 1.9645, 1.9676, 1.9652, 1.9770, 1.9518, 1.9670, 1.9532,
#          1.9399, 1.9614, 1.9616, 1.9522, 1.9352, 1.9487, 1.9615, 1.9603, 1.9470,
#          1.9506, 1.9425, 1.9608, 1.9408, 1.9452, 1.9539, 1.9483, 1.9386, 1.9423,
#          1.9332, 1.9539, 1.9407, 1.9415, 1.9502, 1.9337, 1.9537, 1.9289, 1.9399,
#          1.9548, 1.9331, 1.9372, 1.9307, 1.9433, 1.9448, 1.9583, 1.9368, 1.9323,
#          1.9542, 1.9413, 1.9474, 1.9555, 1.9469, 1.9494, 1.9507, 1.9453, 1.9687,
#          1.9453, 1.9724, 1.9418, 1.9399, 1.9424, 1.9272, 1.9303, 1.9469, 1.9354,
#          1.9267, 1.9456, 1.9318, 1.9261, 1.9262, 1.9354, 1.9420, 1.9369, 1.9396,
#          1.9700, 1.9360, 1.9291, 1.9460, 1.9372, 1.9501, 1.9431, 1.9353, 1.9284,
#          1.9236, 1.9236, 1.9370, 1.9294, 1.9317, 1.9237, 1.9283, 1.9242, 1.9363,
#          1.9316, 1.9111, 1.9042, 1.9247, 1.9281, 1.9496, 1.9238, 1.9261, 1.9046,
#          1.9269, 1.9340, 1.9315, 1.9398, 1.9371, 1.9376, 1.9348, 1.9316, 1.9517,
#          1.9357, 1.9214, 1.9513, 1.9388, 1.9342, 1.9446, 1.9040, 1.9127, 1.9196,
#          1.9269, 1.9273, 1.9076, 1.9239, 1.8986, 1.9193, 1.9166, 1.9157, 1.9241,
#          1.9200, 1.8966, 1.9360, 1.9207, 1.9139, 1.8966, 1.9384, 1.8924, 1.9313,
#          1.9429, 1.9164, 1.9133, 1.9178, 1.9120, 1.9212, 1.9239, 1.9046, 1.9332,
#          1.9216, 1.9158, 1.9052, 1.9315, 1.9532, 1.9388, 1.9317, 1.9527, 1.9288,
#          1.9228, 1.9136, 1.9093, 1.9236, 1.9047, 1.9285, 1.9594, 1.9186, 1.9477,
#          1.9243, 1.9352, 1.9549, 1.9185, 1.9398, 1.9369, 1.9585, 1.9431, 1.9515,
#          1.9418, 1.9367, 1.9475, 1.9179, 1.9657, 1.9239, 1.9722, 1.9680, 1.8996,
#          1.9112, 1.9124, 1.9107]),
#  tensor([0.5646, 0.5798, 0.5861, 0.5906, 0.5933, 0.5950, 0.5969, 0.5991, 0.6004,
#          0.6036, 0.6054, 0.6060, 0.6065, 0.6069, 0.6067, 0.6076, 0.6075, 0.6075,
#          0.6077, 0.6080, 0.6082, 0.6077, 0.6082, 0.6078, 0.6081, 0.6080, 0.6081,
#          0.6079, 0.6080, 0.6079, 0.6080, 0.6079, 0.6076, 0.6079, 0.6078, 0.6077,
#          0.6077, 0.6077, 0.6079, 0.6070, 0.6073, 0.6074, 0.6079, 0.6073, 0.6073,
#          0.6069, 0.6074, 0.6069, 0.6066, 0.6072, 0.6072, 0.6072, 0.6081, 0.6076,
#          0.6077, 0.6075, 0.6076, 0.6076, 0.6073, 0.6079, 0.6073, 0.6080, 0.6078,
#          0.6076, 0.6077, 0.6080, 0.6078, 0.6078, 0.6081, 0.6079, 0.6076, 0.6082,
#          0.6084, 0.6080, 0.6082, 0.6072, 0.6083, 0.6081, 0.6081, 0.6082, 0.6085,
#          0.6082, 0.6087, 0.6083, 0.6087, 0.6085, 0.6084, 0.6084, 0.6083, 0.6089,
#          0.6084, 0.6092, 0.6088, 0.6087, 0.6086, 0.6089, 0.6087, 0.6086, 0.6086,
#          0.6090, 0.6090, 0.6087, 0.6091, 0.6089, 0.6087, 0.6088, 0.6090, 0.6089,
#          0.6090, 0.6091, 0.6091, 0.6090, 0.6092, 0.6092, 0.6094, 0.6093, 0.6090,
#          0.6095, 0.6095, 0.6094, 0.6094, 0.6094, 0.6094, 0.6093, 0.6093, 0.6093,
#          0.6095, 0.6092, 0.6095, 0.6090, 0.6097, 0.6092, 0.6094, 0.6095, 0.6096,
#          0.6096, 0.6096, 0.6094, 0.6097, 0.6095, 0.6100, 0.6094, 0.6099, 0.6098,
#          0.6099, 0.6101, 0.6097, 0.6101, 0.6101, 0.6098, 0.6101, 0.6100, 0.6101,
#          0.6097, 0.6099, 0.6102, 0.6103, 0.6100, 0.6101, 0.6100, 0.6102, 0.6101,
#          0.6099, 0.6104, 0.6098, 0.6102, 0.6103, 0.6101, 0.6102, 0.6099, 0.6101,
#          0.6102, 0.6103, 0.6105, 0.6105, 0.6102, 0.6104, 0.6101, 0.6100, 0.6106,
#          0.6104, 0.6105, 0.6102, 0.6102, 0.6106, 0.6104, 0.6108, 0.6103, 0.6105,
#          0.6108, 0.6104, 0.6107, 0.6105, 0.6107, 0.6108, 0.6106, 0.6106, 0.6106,
#          0.6104, 0.6106, 0.6105, 0.6105, 0.6108, 0.6109, 0.6104, 0.6109, 0.6109,
#          0.6101, 0.6105, 0.6105, 0.6107, 0.6107, 0.6106, 0.6106, 0.6107, 0.6108,
#          0.6113, 0.6110, 0.6110, 0.6104, 0.6110, 0.6110, 0.6109, 0.6106, 0.6111,
#          0.6113, 0.6110, 0.6114, 0.6112, 0.6108, 0.6109, 0.6110, 0.6107, 0.6109,
#          0.6110, 0.6110, 0.6109, 0.6114, 0.6113, 0.6107, 0.6112, 0.6111, 0.6108,
#          0.6109, 0.6113, 0.6112, 0.6112, 0.6114, 0.6112, 0.6106, 0.6106, 0.6108,
#          0.6114, 0.6112, 0.6113, 0.6111, 0.6116, 0.6113, 0.6114, 0.6112, 0.6108,
#          0.6108, 0.6109, 0.6104, 0.6110, 0.6109, 0.6105, 0.6113, 0.6114, 0.6113,
#          0.6107, 0.6110, 0.6112, 0.6110, 0.6111, 0.6113, 0.6113, 0.6109, 0.6108,
#          0.6103, 0.6110, 0.6110, 0.6108, 0.6108, 0.6115, 0.6110, 0.6107, 0.6110,
#          0.6106, 0.6106, 0.6110, 0.6108, 0.6114, 0.6108, 0.6107, 0.6115, 0.6106,
#          0.6103, 0.6108, 0.6111]))

# %%
# batchLoss

# %%
# batchAcc

# %%
# yHat.shape, y.shape

# %%
# yHat_test.shape, yy.shape

# %%
yHat1.flatten(), y1.flatten()
# Out:
# (tensor([2.0000, 1.0023, 7.8091, 4.4402, 0.0000, 3.2290, 1.1163, 4.4913, 2.0179,
#          0.0000, 7.9579, 4.5566, 0.0000, 2.1479, 1.0741, 4.8882, 1.9642, 0.0000,
#          4.8358, 7.1169, 0.0000, 3.4207, 0.9115, 8.7553, 2.0052, 0.9573, 3.7118,
#          4.5611, 0.0000, 6.8066, 1.1155, 4.5078, 2.0104, 1.0061, 8.9768, 4.3518,
#          0.0000, 7.8527, 1.1075, 4.3918, 1.0077, 8.9764, 4.6515, 4.7177, 0.0000,
#          1.2713, 1.0566, 4.9003, 1.0258, 7.9892, 0.0000, 4.6508, 0.0000, 2.9814,
#          1.0562, 4.7001, 2.0274, 0.0000, 8.8681, 4.4342, 0.9698, 1.3086, 1.0852,
#          4.6800, 1.0136, 9.0405, 5.9135, 4.5561, 0.9718, 2.2490, 1.0841, 4.6489,
#          1.0223, 8.9532, 0.0000, 4.4557, 0.0000, 6.7197, 1.0582, 4.5773, 2.0094,
#          0.9833, 5.8644, 4.4668, 0.0000, 7.8292, 1.1135, 4.4627, 1.9945, 1.0020,
#          7.7509, 4.5562, 0.0000, 2.3864, 1.0821, 4.7233, 1.9916, 0.0000, 7.9046,
#          4.2645, 0.0000, 4.2476, 1.1347, 4.7457, 1.9847, 0.0000, 7.9597, 4.4798,
#          0.0000, 1.1514, 1.0844, 4.8565, 1.0220, 8.9466, 0.0000, 4.4760, 0.0000,
#          6.6902, 1.0632, 4.5883, 1.0379, 7.9907, 0.0000, 4.5741, 0.0000, 8.7591,
#          0.9962, 4.7379, 1.0186, 9.0325, 2.4545, 4.4914, 0.0000, 5.9757, 1.1079,
#          4.4767, 1.9895, 0.9824, 4.6688, 4.7857, 0.0000, 1.2936, 1.0644, 4.9396,
#          2.0037, 0.9413, 5.7897, 4.6175, 1.0071, 0.0000, 1.0939, 4.7891, 2.0203,
#          0.0000, 8.7980, 4.4273, 0.9625, 2.2019, 1.0884, 4.6506, 1.0164, 9.0590,
#          7.0084, 4.4351, 0.9690, 1.1244, 1.0862, 4.5912, 1.0209, 8.9678, 0.1585,
#          4.4904, 0.0000, 6.7680, 1.0703, 4.5715, 1.0349, 7.9885, 0.0000, 4.5799,
#          0.0000, 7.6940, 1.0463, 4.6237, 1.0215, 7.9941, 0.0000, 4.7230, 0.0000,
#          2.0930, 1.0290, 4.8892, 1.0396, 7.9812, 8.8820, 4.4354, 0.0000, 6.0914,
#          1.1199, 4.3240, 1.0278, 8.0001, 8.8349, 4.6309, 0.0000, 2.1257, 1.0605,
#          4.7351, 2.0068, 0.9660, 1.4366, 4.4807, 0.0000, 6.8342, 1.1256, 4.3362,
#          1.0200, 8.9885, 3.4159, 4.5031, 0.0000, 5.0553, 1.1180, 4.4580, 2.0331,
#          0.0000, 0.0000, 6.6342, 0.0000, 7.9515, 0.8654, 8.2807, 2.0034, 0.9346,
#          1.2875, 4.6842, 1.0272, 0.0000, 1.0488, 4.8868, 1.0383, 7.9942, 4.8224,
#          4.5121, 0.0000, 7.8438, 1.1031, 4.3306, 1.9333, 0.0000, 3.8416, 4.5856,
#          0.0000, 4.8869, 1.1282, 4.6352], grad_fn=<ReshapeAliasBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
yHat_test1, yy1
# Out:
# (tensor([[1.0336, 7.9793, 1.0980, 4.5137, 0.0000, 5.5950, 1.0993, 4.4195]]),
#  tensor([[1., 8., 1., 6., 0., 6., 0., 1.]]))

# %%
yy1
# Out:
# tensor([[1., 8., 1., 6., 0., 6., 0., 1.]])

# %%
(yHat_test1).round()
# Out:
# tensor([[1., 8., 1., 5., 0., 6., 1., 4.]])

# %%
(yHat1.flatten()).round(), (y1.flatten()).round()
# Out:
# (tensor([2., 1., 8., 4., 0., 3., 1., 4., 2., 0., 8., 5., 0., 2., 1., 5., 2., 0.,
#          5., 7., 0., 3., 1., 9., 2., 1., 4., 5., 0., 7., 1., 5., 2., 1., 9., 4.,
#          0., 8., 1., 4., 1., 9., 5., 5., 0., 1., 1., 5., 1., 8., 0., 5., 0., 3.,
#          1., 5., 2., 0., 9., 4., 1., 1., 1., 5., 1., 9., 6., 5., 1., 2., 1., 5.,
#          1., 9., 0., 4., 0., 7., 1., 5., 2., 1., 6., 4., 0., 8., 1., 4., 2., 1.,
#          8., 5., 0., 2., 1., 5., 2., 0., 8., 4., 0., 4., 1., 5., 2., 0., 8., 4.,
#          0., 1., 1., 5., 1., 9., 0., 4., 0., 7., 1., 5., 1., 8., 0., 5., 0., 9.,
#          1., 5., 1., 9., 2., 4., 0., 6., 1., 4., 2., 1., 5., 5., 0., 1., 1., 5.,
#          2., 1., 6., 5., 1., 0., 1., 5., 2., 0., 9., 4., 1., 2., 1., 5., 1., 9.,
#          7., 4., 1., 1., 1., 5., 1., 9., 0., 4., 0., 7., 1., 5., 1., 8., 0., 5.,
#          0., 8., 1., 5., 1., 8., 0., 5., 0., 2., 1., 5., 1., 8., 9., 4., 0., 6.,
#          1., 4., 1., 8., 9., 5., 0., 2., 1., 5., 2., 1., 1., 4., 0., 7., 1., 4.,
#          1., 9., 3., 5., 0., 5., 1., 4., 2., 0., 0., 7., 0., 8., 1., 8., 2., 1.,
#          1., 5., 1., 0., 1., 5., 1., 8., 5., 5., 0., 8., 1., 4., 2., 0., 4., 5.,
#          0., 5., 1., 5.], grad_fn=<RoundBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
print_score(X.shape, yHat1, y1, yHat_test1, yy1)
# Out:
# Adjusted R-Squared(y, yHat): 0.6256
#
#
# mean_absolute_error(y, yHat): 0.7467
#
# mean_absolute_error(yy, yHat_test): 0.8203
#
#
# mean_squared_error(y, yHat): 2.2249
#
# mean_squared_error(yy, yHat_test): 1.9107
#
#
# mean_squared_log_error(y, yHat): 0.1763
#
# mean_squared_log_error(yy, yHat_test): 0.2009
#
#
# RMSE(y, yHat): 1.4916
#
# RMSE(yy, yHat_test): 1.3823

# %%
# create a 1D smoothing filter
def smooth(x, k=15):
    return np.convolve(x, np.ones(k)/k, mode='same')

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss1.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc1, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat1.detach().T, y1.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc1.jpg", bbox_inches='tight')


plt.show()

# %%
data.leap_year.value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
resampler = SMOTE(k_neighbors=20, random_state=0)

# %%
X_res, y_res = resampler.fit_resample(data[['day_code', 'month_code', 'decade', 'date_int']], data['leap_year'])

# %%
y_res.value_counts()
# Out:
# 0    110960
# 1    110960
# Name: leap_year, dtype: int64

# %%
data['leap_year'].value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 221915    1
# 221916    1
# 221917    1
# 221918    1
# 221919    1
# Name: leap_year, Length: 221920, dtype: int64

# %%
X_res
# Out:
#         day_code  month_code  decade  date_int
# 0              4           0     180  18000101
# 1              5           0     180  18010101
# 2              6           0     180  18020101
# 3              0           0     180  18030101
# 4              1           0     180  18040101
# ...          ...         ...     ...       ...
# 221915         0           5     188  18880618
# 221916         2           6     188  18840705
# 221917         5           2     218  21800323
# 221918         1           5     199  19960602
# 221919         1           4     219  21960520
#
# [221920 rows x 4 columns]

# %%
X_smote = X_res.assign(leap_year=y_res)

# %%
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221915         0           5     188  18880618          1
# 221916         2           6     188  18840705          1
# 221917         5           2     218  21800323          1
# 221918         1           5     199  19960602          1
# 221919         1           4     219  21960520          1
#
# [221920 rows x 5 columns]

# %% [markdown]
# Drop 220 decade

# %%
# data.decade.value_counts().plot(kind="bar")
X_smote.decade.value_counts().plot(kind="bar")

# %%
# data.decade.value_counts()[-5:]
X_smote.decade.value_counts()[-5:]
# Out:
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# 220     365
# Name: decade, dtype: int64

# %%
X_smote = X_smote.drop(X_smote.index[X_smote['decade'] == 220]).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221550         0           5     188  18880618          1
# 221551         2           6     188  18840705          1
# 221552         5           2     218  21800323          1
# 221553         1           5     199  19960602          1
# 221554         1           4     219  21960520          1
#
# [221555 rows x 5 columns]

# %%
X_smote.decade.value_counts().plot(kind="bar")

# %%
X_smote.decade.value_counts()[-5:]
# Out:
# 209    5174
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# Name: decade, dtype: int64

# %% [markdown]
# code is required to only work for dates in the range  [ 1-1-1800 to 31-12-2200 ]

# %%
X_smote.date_int.max()
# Out:
# 21991231

# %%
datetime.datetime.strptime(str(X_smote.date_int.max()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '31-12-2199'

# %%
X_smote.date_int.min()
# Out:
# 18000101

# %%
datetime.datetime.strptime(str(X_smote.date_int.min()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '01-01-1800'

# %%
Y_smote = X_smote['date_int']
Y_smote
# Out:
# 0         18000101
# 1         18010101
# 2         18020101
# 3         18030101
# 4         18040101
#             ...
# 221550    18880618
# 221551    18840705
# 221552    21800323
# 221553    19960602
# 221554    21960520
# Name: date_int, Length: 221555, dtype: int64

# %%
X_smote = X_smote.drop('date_int', axis=1).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  leap_year
# 0              4           0     180          0
# 1              5           0     180          0
# 2              6           0     180          0
# 3              0           0     180          0
# 4              1           0     180          1
# ...          ...         ...     ...        ...
# 221550         0           5     188          1
# 221551         2           6     188          1
# 221552         5           2     218          1
# 221553         1           5     199          1
# 221554         1           4     219          1
#
# [221555 rows x 4 columns]

# %%
Y_smote = Y_smote.reset_index(drop=True)

ls = []

for s in Y_smote.astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(Y_smote)), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y_smote = ll.values

Y_smote
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
# data.index[data['leap_year'] == 1].tolist()
# data.index[data['leap_year'] == 1]

# %%
# for i,idx in enumerate(data['leap_year'].tolist()):
#     print(i, idx)

# %% [markdown]
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1 <---
# 5 0
# 6 0
# 7 0
# 8 1 <---
# 9 0
# 10 0
# 11 0
# 12 1 <---
# 13 0
# 14 0
# 15 0
# 16 1 <---
# 17 0
# 18 0
# 19 0
# 20 1 <---
# 21 0
# 22 0
# 23 0
# 24 1 <---
# 25 0
# 26 0
# 27 0
# 28 1 <---
# 29 0
# 30 0

# %%
scaler_day_smote = RobustScaler()

x = X_smote.day_code.values.reshape(-1, 1)

X_smote['day_scaled'] = scaler_day_smote.fit_transform(x).flatten()

# %%
X_smote['day_sin'] = np.sin(X_smote['day_code'] * (2 * np.pi / 7))
X_smote['day_cos'] = np.cos(X_smote['day_code'] * (2 * np.pi / 7))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos
# 0      -0.900969
# 1      -0.222521
# 2       0.623490
# 3       1.000000
# 4       0.623490
# ...          ...
# 221550  1.000000
# 221551 -0.222521
# 221552 -0.222521
# 221553  0.623490
# 221554  0.623490
#
# [221555 rows x 7 columns]

# %%
scaler_month_smote = RobustScaler()

x = X_smote.month_code.values.reshape(-1, 1)

X_smote['month_scaled'] = scaler_month_smote.fit_transform(x).flatten()

# %%
X_smote['month_sin'] = np.sin(X_smote['month_code'] * (2 * np.pi / 12))
X_smote['month_cos'] = np.cos(X_smote['month_code'] * (2 * np.pi / 12))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos
# 0      -0.900969     -1.000000  0.000000e+00   1.000000
# 1      -0.222521     -1.000000  0.000000e+00   1.000000
# 2       0.623490     -1.000000  0.000000e+00   1.000000
# 3       1.000000     -1.000000  0.000000e+00   1.000000
# 4       0.623490     -1.000000  0.000000e+00   1.000000
# ...          ...           ...           ...        ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000
#
# [221555 rows x 10 columns]

# %%
scaler_decade_smote = RobustScaler()

x = X_smote.decade.values.reshape(-1, 1)

X_smote['decade_scaled'] = scaler_decade_smote.fit_transform(x).flatten()

# %%
# alpha_smote = len(X_smote.decade.unique())
alpha_smote = (X_smote.decade.iloc[-1] - X_smote.decade.iloc[0]) + 1

X_smote['decade_sin'] = np.sin(X_smote['decade'] * (2 * np.pi / alpha_smote))
X_smote['decade_cos'] = np.cos(X_smote['decade'] * (2 * np.pi / alpha_smote))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos  decade_scaled  \
# 0      -0.900969     -1.000000  0.000000e+00   1.000000      -1.052632
# 1      -0.222521     -1.000000  0.000000e+00   1.000000      -1.052632
# 2       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# 3       1.000000     -1.000000  0.000000e+00   1.000000      -1.052632
# 4       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# ...          ...           ...           ...        ...            ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025      -0.631579
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000      -0.631579
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000       0.947368
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025      -0.052632
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000       1.000000
#
#           decade_sin  decade_cos
# 0       1.102182e-15   -1.000000
# 1       1.102182e-15   -1.000000
# 2       1.102182e-15   -1.000000
# 3       1.102182e-15   -1.000000
# 4       1.102182e-15   -1.000000
# ...              ...         ...
# 221550 -9.510565e-01   -0.309017
# 221551 -9.510565e-01   -0.309017
# 221552  3.090170e-01   -0.951057
# 221553 -1.564345e-01    0.987688
# 221554  1.564345e-01   -0.987688
#
# [221555 rows x 13 columns]

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
X = X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 3.33333333e-01, -4.33883739e-01, -9.00968868e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 1.00000000e+00, -7.81831482e-01,  6.23489802e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        ...,
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#          9.47368421e-01,  3.09016994e-01, -9.51056516e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#         -5.26315789e-02, -1.56434465e-01,  9.87688341e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#          1.00000000e+00,  1.56434465e-01, -9.87688341e-01]])

# %%
X.shape
# Out:
# (221555, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()
# Y = data['date_normalized'].values.reshape(-1, 1)
Y = Y_smote


Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
Y.shape
# Out:
# (221555, 8)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64

train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (221555, 10)
#
# Y: (221555, 8)
#
# Train data:   (155088, 10)
#
# Train labels: (155088, 8)
#
# Test data:    (66467, 10)
#
# Test labels:  (66467, 8)

# %%
model_smote = Model().to(device)


checkpoint = torch.load('checkpoint.pth.tar')
model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
# Out:
# <All keys matched successfully>

# %%
# numepochs = 120
numepochs = 300


trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model_smote, numepochs)
# Out:
# Epoch 1/300, Train Loss: 1.891058, Test Loss: 3.991657
# Epoch 2/300, Train Loss: 1.876559, Test Loss: 3.962479
# Epoch 3/300, Train Loss: 1.873998, Test Loss: 3.949645
# Epoch 4/300, Train Loss: 1.874900, Test Loss: 3.925949
# Epoch 5/300, Train Loss: 1.874021, Test Loss: 3.933274
# Epoch 6/300, Train Loss: 1.884679, Test Loss: 4.178041
# Epoch 7/300, Train Loss: 1.880440, Test Loss: 4.122337
# Epoch 8/300, Train Loss: 1.865533, Test Loss: 4.144370
# Epoch 9/300, Train Loss: 1.854893, Test Loss: 4.244716
# Epoch 10/300, Train Loss: 1.849209, Test Loss: 4.248218
# Epoch 11/300, Train Loss: 1.854987, Test Loss: 4.289578
# Epoch 12/300, Train Loss: 1.856129, Test Loss: 4.289060
# Epoch 13/300, Train Loss: 1.848746, Test Loss: 4.346948
# Epoch 14/300, Train Loss: 1.846350, Test Loss: 4.328644
# Epoch 15/300, Train Loss: 1.839775, Test Loss: 4.377134
# Epoch 16/300, Train Loss: 1.845575, Test Loss: 4.332283
# Epoch 17/300, Train Loss: 1.849530, Test Loss: 4.318532
# Epoch 18/300, Train Loss: 1.851204, Test Loss: 4.352801
# Epoch 19/300, Train Loss: 1.857577, Test Loss: 4.338698
# Epoch 20/300, Train Loss: 1.846168, Test Loss: 4.344393
# Epoch 21/300, Train Loss: 1.852366, Test Loss: 4.366497
# Epoch 22/300, Train Loss: 1.848535, Test Loss: 4.358531
# Epoch 23/300, Train Loss: 1.855971, Test Loss: 4.354576
# Epoch 24/300, Train Loss: 1.863302, Test Loss: 4.356084
# Epoch 25/300, Train Loss: 1.857032, Test Loss: 4.341248
# Epoch 26/300, Train Loss: 1.854586, Test Loss: 4.359073
# Epoch 27/300, Train Loss: 1.855275, Test Loss: 4.386699
# Epoch 28/300, Train Loss: 1.864489, Test Loss: 4.381725
# Epoch 29/300, Train Loss: 1.854105, Test Loss: 4.382560
# Epoch 30/300, Train Loss: 1.855366, Test Loss: 4.395700
# Epoch 31/300, Train Loss: 1.853150, Test Loss: 4.395557
# Epoch 32/300, Train Loss: 1.859259, Test Loss: 4.378560
# Epoch 33/300, Train Loss: 1.848275, Test Loss: 4.392323
# Epoch 34/300, Train Loss: 1.862733, Test Loss: 4.393883
# Epoch 35/300, Train Loss: 1.850932, Test Loss: 4.409959
# Epoch 36/300, Train Loss: 1.865100, Test Loss: 4.422312
# Epoch 37/300, Train Loss: 1.871558, Test Loss: 4.435721
# Epoch 38/300, Train Loss: 1.868595, Test Loss: 4.409833
# Epoch 39/300, Train Loss: 1.863145, Test Loss: 4.447735
# Epoch 40/300, Train Loss: 1.871323, Test Loss: 4.464147
# Epoch 41/300, Train Loss: 1.852172, Test Loss: 4.453338
# Epoch 42/300, Train Loss: 1.863952, Test Loss: 4.457315
# Epoch 43/300, Train Loss: 1.867397, Test Loss: 4.469452
# Epoch 44/300, Train Loss: 1.865180, Test Loss: 4.459029
# Epoch 45/300, Train Loss: 1.872432, Test Loss: 4.455048
# Epoch 46/300, Train Loss: 1.858019, Test Loss: 4.437378
# Epoch 47/300, Train Loss: 1.879970, Test Loss: 4.392535
# Epoch 48/300, Train Loss: 1.878065, Test Loss: 4.432258
# Epoch 49/300, Train Loss: 1.878941, Test Loss: 4.454571
# Epoch 50/300, Train Loss: 1.890313, Test Loss: 4.450980
# Epoch 51/300, Train Loss: 1.880942, Test Loss: 4.348660
# Epoch 52/300, Train Loss: 1.870947, Test Loss: 4.484096
# Epoch 53/300, Train Loss: 1.870341, Test Loss: 4.438256
# Epoch 54/300, Train Loss: 1.881750, Test Loss: 4.467902
# Epoch 55/300, Train Loss: 1.866484, Test Loss: 4.451202
# Epoch 56/300, Train Loss: 1.861189, Test Loss: 4.464442
# Epoch 57/300, Train Loss: 1.859554, Test Loss: 4.302295
# Epoch 58/300, Train Loss: 1.878349, Test Loss: 4.481217
# Epoch 59/300, Train Loss: 1.878826, Test Loss: 4.306034
# Epoch 60/300, Train Loss: 1.877357, Test Loss: 4.423775
# Epoch 61/300, Train Loss: 1.857555, Test Loss: 4.402143
# Epoch 62/300, Train Loss: 1.875751, Test Loss: 4.303274
# Epoch 63/300, Train Loss: 1.881415, Test Loss: 4.266083
# Epoch 64/300, Train Loss: 1.863622, Test Loss: 4.288232
# Epoch 65/300, Train Loss: 1.848221, Test Loss: 4.392303
# Epoch 66/300, Train Loss: 1.858935, Test Loss: 4.360724
# Epoch 67/300, Train Loss: 1.850390, Test Loss: 4.335020
# Epoch 68/300, Train Loss: 1.866489, Test Loss: 4.225887
# Epoch 69/300, Train Loss: 1.852027, Test Loss: 4.278183
# Epoch 70/300, Train Loss: 1.850852, Test Loss: 4.330602
# Epoch 71/300, Train Loss: 1.858702, Test Loss: 4.192343
# Epoch 72/300, Train Loss: 1.858463, Test Loss: 4.235324
# Epoch 73/300, Train Loss: 1.840387, Test Loss: 4.278491
# Epoch 74/300, Train Loss: 1.867173, Test Loss: 4.262156
# Epoch 75/300, Train Loss: 1.856217, Test Loss: 4.176639
# Epoch 76/300, Train Loss: 1.847192, Test Loss: 4.351491
# Epoch 77/300, Train Loss: 1.838599, Test Loss: 4.235746
# Epoch 78/300, Train Loss: 1.844750, Test Loss: 4.260388
# Epoch 79/300, Train Loss: 1.802705, Test Loss: 4.252704
# Epoch 80/300, Train Loss: 1.823896, Test Loss: 4.252270
# Epoch 81/300, Train Loss: 1.799380, Test Loss: 4.272269
# Epoch 82/300, Train Loss: 1.805890, Test Loss: 4.256536
# Epoch 83/300, Train Loss: 1.781858, Test Loss: 4.315296
# Epoch 84/300, Train Loss: 1.831586, Test Loss: 4.288935
# Epoch 85/300, Train Loss: 1.795247, Test Loss: 4.314219
# Epoch 86/300, Train Loss: 1.784454, Test Loss: 4.346212
# Epoch 87/300, Train Loss: 1.785102, Test Loss: 4.244855
# Epoch 88/300, Train Loss: 1.777710, Test Loss: 4.244244
# Epoch 89/300, Train Loss: 1.770886, Test Loss: 4.370137
# Epoch 90/300, Train Loss: 1.777709, Test Loss: 4.385364
# Epoch 91/300, Train Loss: 1.779662, Test Loss: 4.277872
# Epoch 92/300, Train Loss: 1.764896, Test Loss: 4.170807
# Epoch 93/300, Train Loss: 1.769457, Test Loss: 4.296637
# Epoch 94/300, Train Loss: 1.768634, Test Loss: 4.184529
# Epoch 95/300, Train Loss: 1.771868, Test Loss: 4.405827
# Epoch 96/300, Train Loss: 1.774271, Test Loss: 4.203734
# Epoch 97/300, Train Loss: 1.775927, Test Loss: 4.201283
# Epoch 98/300, Train Loss: 1.769574, Test Loss: 4.220213
# Epoch 99/300, Train Loss: 1.796616, Test Loss: 4.234759
# Epoch 100/300, Train Loss: 1.826766, Test Loss: 4.146650
# Epoch 101/300, Train Loss: 1.817183, Test Loss: 4.129250
# Epoch 102/300, Train Loss: 1.813240, Test Loss: 4.211047
# Epoch 103/300, Train Loss: 1.818766, Test Loss: 4.197896
# Epoch 104/300, Train Loss: 1.821893, Test Loss: 4.138286
# Epoch 105/300, Train Loss: 1.846474, Test Loss: 4.236056
# Epoch 106/300, Train Loss: 1.821293, Test Loss: 4.294776
# Epoch 107/300, Train Loss: 1.827810, Test Loss: 4.114434
# Epoch 108/300, Train Loss: 1.800375, Test Loss: 4.167799
# Epoch 109/300, Train Loss: 1.812387, Test Loss: 4.185898
# Epoch 110/300, Train Loss: 1.769359, Test Loss: 4.073782
# Epoch 111/300, Train Loss: 1.804778, Test Loss: 4.182097
# Epoch 112/300, Train Loss: 1.829197, Test Loss: 4.142723
# Epoch 113/300, Train Loss: 1.842307, Test Loss: 4.056651
# Epoch 114/300, Train Loss: 1.823954, Test Loss: 4.199477
# Epoch 115/300, Train Loss: 1.822121, Test Loss: 4.059132
# Epoch 116/300, Train Loss: 1.829302, Test Loss: 4.218734
# Epoch 117/300, Train Loss: 1.807073, Test Loss: 4.132073
# Epoch 118/300, Train Loss: 1.826094, Test Loss: 4.139544
# Epoch 119/300, Train Loss: 1.811458, Test Loss: 4.153389
# Epoch 120/300, Train Loss: 1.819214, Test Loss: 4.176190
# Epoch 121/300, Train Loss: 1.832412, Test Loss: 4.188734
# Epoch 122/300, Train Loss: 1.830168, Test Loss: 4.272552
# Epoch 123/300, Train Loss: 1.836116, Test Loss: 4.096271
# Epoch 124/300, Train Loss: 1.833075, Test Loss: 4.119678
# Epoch 125/300, Train Loss: 1.846173, Test Loss: 4.034344
# Epoch 126/300, Train Loss: 1.796412, Test Loss: 4.138687
# Epoch 127/300, Train Loss: 1.827325, Test Loss: 4.149180
# Epoch 128/300, Train Loss: 1.811203, Test Loss: 4.229714
# Epoch 129/300, Train Loss: 1.834633, Test Loss: 4.242863
# Epoch 130/300, Train Loss: 1.838801, Test Loss: 4.182098
# Epoch 131/300, Train Loss: 1.800656, Test Loss: 4.107832
# Epoch 132/300, Train Loss: 1.818164, Test Loss: 4.065180
# Epoch 133/300, Train Loss: 1.812286, Test Loss: 4.063763
# Epoch 134/300, Train Loss: 1.803545, Test Loss: 4.080327
# Epoch 135/300, Train Loss: 1.811892, Test Loss: 4.175051
# Epoch 136/300, Train Loss: 1.817304, Test Loss: 3.941495
# Epoch 137/300, Train Loss: 1.823155, Test Loss: 4.261962
# Epoch 138/300, Train Loss: 1.816721, Test Loss: 4.176361
# Epoch 139/300, Train Loss: 1.811790, Test Loss: 4.139073
# Epoch 140/300, Train Loss: 1.796924, Test Loss: 4.089662
# Epoch 141/300, Train Loss: 1.804650, Test Loss: 4.096400
# Epoch 142/300, Train Loss: 1.810352, Test Loss: 4.109598
# Epoch 143/300, Train Loss: 1.812868, Test Loss: 4.270357
# Epoch 144/300, Train Loss: 1.818659, Test Loss: 4.268298
# Epoch 145/300, Train Loss: 1.791542, Test Loss: 4.256263
# Epoch 146/300, Train Loss: 1.813317, Test Loss: 4.303488
# Epoch 147/300, Train Loss: 1.804199, Test Loss: 4.232120
# Epoch 148/300, Train Loss: 1.831710, Test Loss: 4.216585
# Epoch 149/300, Train Loss: 1.803120, Test Loss: 4.304138
# Epoch 150/300, Train Loss: 1.825745, Test Loss: 4.331588
# Epoch 151/300, Train Loss: 1.815803, Test Loss: 4.282025
# Epoch 152/300, Train Loss: 1.835834, Test Loss: 4.339406
# Epoch 153/300, Train Loss: 1.831328, Test Loss: 4.283104
# Epoch 154/300, Train Loss: 1.813468, Test Loss: 4.240642
# Epoch 155/300, Train Loss: 1.825897, Test Loss: 4.426038
# Epoch 156/300, Train Loss: 1.823062, Test Loss: 4.523122
# Epoch 157/300, Train Loss: 1.784978, Test Loss: 4.204871
# Epoch 158/300, Train Loss: 1.805908, Test Loss: 4.292865
# Epoch 159/300, Train Loss: 1.811464, Test Loss: 4.387446
# Epoch 160/300, Train Loss: 1.809301, Test Loss: 4.204630
# Epoch 161/300, Train Loss: 1.810577, Test Loss: 4.297944
# Epoch 162/300, Train Loss: 1.812100, Test Loss: 4.511053
# Epoch 163/300, Train Loss: 1.812163, Test Loss: 4.315875
# Epoch 164/300, Train Loss: 1.821479, Test Loss: 4.447817
# Epoch 165/300, Train Loss: 1.797488, Test Loss: 4.602652
# Epoch 166/300, Train Loss: 1.803348, Test Loss: 4.312351
# Epoch 167/300, Train Loss: 1.804990, Test Loss: 4.232472
# Epoch 168/300, Train Loss: 1.804034, Test Loss: 4.304654
# Epoch 169/300, Train Loss: 1.795942, Test Loss: 4.212676
# Epoch 170/300, Train Loss: 1.806630, Test Loss: 4.378263
# Epoch 171/300, Train Loss: 1.823120, Test Loss: 4.356945
# Epoch 172/300, Train Loss: 1.797623, Test Loss: 4.411020
# Epoch 173/300, Train Loss: 1.808684, Test Loss: 4.295554
# Epoch 174/300, Train Loss: 1.807585, Test Loss: 4.434975
# Epoch 175/300, Train Loss: 1.794263, Test Loss: 4.492904
# Epoch 176/300, Train Loss: 1.768706, Test Loss: 4.390582
# Epoch 177/300, Train Loss: 1.803960, Test Loss: 4.514884
# Epoch 178/300, Train Loss: 1.790421, Test Loss: 4.441154
# Epoch 179/300, Train Loss: 1.790615, Test Loss: 4.208691
# Epoch 180/300, Train Loss: 1.805312, Test Loss: 4.182240
# Epoch 181/300, Train Loss: 1.791426, Test Loss: 4.295302
# Epoch 182/300, Train Loss: 1.786419, Test Loss: 4.162882
# Epoch 183/300, Train Loss: 1.785939, Test Loss: 4.228318
# Epoch 184/300, Train Loss: 1.788409, Test Loss: 4.273732
# Epoch 185/300, Train Loss: 1.787068, Test Loss: 4.360338
# Epoch 186/300, Train Loss: 1.790632, Test Loss: 4.289630
# Epoch 187/300, Train Loss: 1.778067, Test Loss: 4.294255
# Epoch 188/300, Train Loss: 1.809497, Test Loss: 4.240004
# Epoch 189/300, Train Loss: 1.820203, Test Loss: 4.163816
# Epoch 190/300, Train Loss: 1.799674, Test Loss: 4.397926
# Epoch 191/300, Train Loss: 1.806973, Test Loss: 4.377435
# Epoch 192/300, Train Loss: 1.815795, Test Loss: 4.406314
# Epoch 193/300, Train Loss: 1.795010, Test Loss: 4.253017
# Epoch 194/300, Train Loss: 1.809599, Test Loss: 4.530625
# Epoch 195/300, Train Loss: 1.810922, Test Loss: 4.621760
# Epoch 196/300, Train Loss: 1.799215, Test Loss: 4.537719
# Epoch 197/300, Train Loss: 1.784096, Test Loss: 4.550245
# Epoch 198/300, Train Loss: 1.783840, Test Loss: 4.639310
# Epoch 199/300, Train Loss: 1.821810, Test Loss: 4.638986
# Epoch 200/300, Train Loss: 1.795030, Test Loss: 4.459844
# Epoch 201/300, Train Loss: 1.794524, Test Loss: 4.449364
# Epoch 202/300, Train Loss: 1.796943, Test Loss: 4.720154
# Epoch 203/300, Train Loss: 1.797694, Test Loss: 4.631278
# Epoch 204/300, Train Loss: 1.801550, Test Loss: 4.560152
# Epoch 205/300, Train Loss: 1.831790, Test Loss: 4.502764
# Epoch 206/300, Train Loss: 1.783292, Test Loss: 4.597147
# Epoch 207/300, Train Loss: 1.804770, Test Loss: 4.606348
# Epoch 208/300, Train Loss: 1.811000, Test Loss: 4.638537
# Epoch 209/300, Train Loss: 1.812169, Test Loss: 4.843267
# Epoch 210/300, Train Loss: 1.835559, Test Loss: 4.837368
# Epoch 211/300, Train Loss: 1.803620, Test Loss: 4.747665
# Epoch 212/300, Train Loss: 1.832525, Test Loss: 4.828835
# Epoch 213/300, Train Loss: 1.824332, Test Loss: 4.673504
# Epoch 214/300, Train Loss: 1.834897, Test Loss: 4.568028
# Epoch 215/300, Train Loss: 1.832503, Test Loss: 4.709715
# Epoch 216/300, Train Loss: 1.822279, Test Loss: 4.832973
# Epoch 217/300, Train Loss: 1.809910, Test Loss: 4.805409
# Epoch 218/300, Train Loss: 1.820915, Test Loss: 4.693833
# Epoch 219/300, Train Loss: 1.802717, Test Loss: 4.624312
# Epoch 220/300, Train Loss: 1.820869, Test Loss: 4.677810
# Epoch 221/300, Train Loss: 1.803393, Test Loss: 4.667892
# Epoch 222/300, Train Loss: 1.792156, Test Loss: 4.750181
# Epoch 223/300, Train Loss: 1.807136, Test Loss: 4.688416
# Epoch 224/300, Train Loss: 1.798415, Test Loss: 4.576026
# Epoch 225/300, Train Loss: 1.816426, Test Loss: 4.753857
# Epoch 226/300, Train Loss: 1.816443, Test Loss: 4.650919
# Epoch 227/300, Train Loss: 1.827458, Test Loss: 4.631045
# Epoch 228/300, Train Loss: 1.843893, Test Loss: 4.818117
# Epoch 229/300, Train Loss: 1.813113, Test Loss: 4.947996
# Epoch 230/300, Train Loss: 1.821153, Test Loss: 4.963799
# Epoch 231/300, Train Loss: 1.823486, Test Loss: 4.799323
# Epoch 232/300, Train Loss: 1.809283, Test Loss: 4.911666
# Epoch 233/300, Train Loss: 1.814835, Test Loss: 4.839464
# Epoch 234/300, Train Loss: 1.813493, Test Loss: 4.801258
# Epoch 235/300, Train Loss: 1.841557, Test Loss: 4.895892
# Epoch 236/300, Train Loss: 1.806674, Test Loss: 4.834060
# Epoch 237/300, Train Loss: 1.816091, Test Loss: 4.787202
# Epoch 238/300, Train Loss: 1.803021, Test Loss: 4.853595
# Epoch 239/300, Train Loss: 1.818016, Test Loss: 4.755698
# Epoch 240/300, Train Loss: 1.802856, Test Loss: 4.915642
# Epoch 241/300, Train Loss: 1.830987, Test Loss: 4.941824
# Epoch 242/300, Train Loss: 1.826509, Test Loss: 4.928372
# Epoch 243/300, Train Loss: 1.834387, Test Loss: 4.935907
# Epoch 244/300, Train Loss: 1.798833, Test Loss: 4.823327
# Epoch 245/300, Train Loss: 1.815174, Test Loss: 4.801736
# Epoch 246/300, Train Loss: 1.816896, Test Loss: 4.838730
# Epoch 247/300, Train Loss: 1.805335, Test Loss: 5.091054
# Epoch 248/300, Train Loss: 1.803453, Test Loss: 4.895169
# Epoch 249/300, Train Loss: 1.827706, Test Loss: 4.855972
# Epoch 250/300, Train Loss: 1.813737, Test Loss: 4.791905
# Epoch 251/300, Train Loss: 1.819273, Test Loss: 4.825255
# Epoch 252/300, Train Loss: 1.807423, Test Loss: 4.813106
# Epoch 253/300, Train Loss: 1.809968, Test Loss: 4.684299
# Epoch 254/300, Train Loss: 1.800766, Test Loss: 4.906288
# Epoch 255/300, Train Loss: 1.783762, Test Loss: 5.001313
# Epoch 256/300, Train Loss: 1.799870, Test Loss: 4.993204
# Epoch 257/300, Train Loss: 1.783421, Test Loss: 4.823828
# Epoch 258/300, Train Loss: 1.786091, Test Loss: 4.917300
# Epoch 259/300, Train Loss: 1.774494, Test Loss: 4.740053
# Epoch 260/300, Train Loss: 1.805185, Test Loss: 4.745292
# Epoch 261/300, Train Loss: 1.778162, Test Loss: 4.696262
# Epoch 262/300, Train Loss: 1.819820, Test Loss: 4.594911
# Epoch 263/300, Train Loss: 1.806346, Test Loss: 4.773574
# Epoch 264/300, Train Loss: 1.782909, Test Loss: 4.746552
# Epoch 265/300, Train Loss: 1.763746, Test Loss: 4.920999
# Epoch 266/300, Train Loss: 1.787264, Test Loss: 4.779327
# Epoch 267/300, Train Loss: 1.795426, Test Loss: 4.883398
# Epoch 268/300, Train Loss: 1.782071, Test Loss: 4.839663
# Epoch 269/300, Train Loss: 1.784477, Test Loss: 4.956944
# Epoch 270/300, Train Loss: 1.827061, Test Loss: 4.709054
# Epoch 271/300, Train Loss: 1.791254, Test Loss: 4.737944
# Epoch 272/300, Train Loss: 1.785904, Test Loss: 4.926442
# Epoch 273/300, Train Loss: 1.790297, Test Loss: 4.973730
# Epoch 274/300, Train Loss: 1.780458, Test Loss: 4.863534
# Epoch 275/300, Train Loss: 1.789471, Test Loss: 4.867095
# Epoch 276/300, Train Loss: 1.758226, Test Loss: 4.905912
# Epoch 277/300, Train Loss: 1.770280, Test Loss: 4.885542
# Epoch 278/300, Train Loss: 1.757832, Test Loss: 4.989645
# Epoch 279/300, Train Loss: 1.766771, Test Loss: 4.834283
# Epoch 280/300, Train Loss: 1.766174, Test Loss: 5.073662
# Epoch 281/300, Train Loss: 1.769018, Test Loss: 4.906496
# Epoch 282/300, Train Loss: 1.800217, Test Loss: 4.816387
# Epoch 283/300, Train Loss: 1.775436, Test Loss: 4.991803
# Epoch 284/300, Train Loss: 1.784912, Test Loss: 4.909843
# Epoch 285/300, Train Loss: 1.770896, Test Loss: 4.963771
# Epoch 286/300, Train Loss: 1.789127, Test Loss: 5.021572
# Epoch 287/300, Train Loss: 1.783457, Test Loss: 4.955151
# Epoch 288/300, Train Loss: 1.788806, Test Loss: 4.814892
# Epoch 289/300, Train Loss: 1.766466, Test Loss: 4.874675
# Epoch 290/300, Train Loss: 1.748179, Test Loss: 4.840088
# Epoch 291/300, Train Loss: 1.754165, Test Loss: 5.025871
# Epoch 292/300, Train Loss: 1.761162, Test Loss: 4.950294
# Epoch 293/300, Train Loss: 1.809782, Test Loss: 4.931100
# Epoch 294/300, Train Loss: 1.775012, Test Loss: 4.935364
# Epoch 295/300, Train Loss: 1.777424, Test Loss: 4.862103
# Epoch 296/300, Train Loss: 1.785835, Test Loss: 4.876566
# Epoch 297/300, Train Loss: 1.808151, Test Loss: 4.885339
# Epoch 298/300, Train Loss: 1.799939, Test Loss: 4.934729
# Epoch 299/300, Train Loss: 1.767771, Test Loss: 4.946218
# Epoch 300/300, Train Loss: 1.774870, Test Loss: 4.832374

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([2.1429, 2.1359, 2.1349, 2.1334, 2.1314, 2.1300, 2.1254, 2.1234, 2.1210,
#          2.1193, 2.1184, 2.1179, 2.1173, 2.1166, 2.1175, 2.1174, 2.1154, 2.1156,
#          2.1148, 2.1160, 2.1141, 2.1153, 2.1136, 2.1138, 2.1130, 2.1128, 2.1123,
#          2.1119, 2.1118, 2.1114, 2.1113, 2.1108, 2.1104, 2.1100, 2.1100, 2.1094,
#          2.1119, 2.1088, 2.1085, 2.1113, 2.1116, 2.1086, 2.1072, 2.1084, 2.1066,
#          2.1075, 2.1059, 2.1052, 2.1053, 2.1062, 2.1067, 2.1043, 2.1049, 2.1088,
#          2.1032, 2.1030, 2.1027, 2.1022, 2.1017, 2.1016, 2.1011, 2.1006, 2.1011,
#          2.1004, 2.1002, 2.0995, 2.0988, 2.0987, 2.0984, 2.0979, 2.0975, 2.0969,
#          2.0967, 2.0966, 2.0964, 2.0955, 2.0950, 2.0946, 2.0940, 2.0943, 2.0936,
#          2.0931, 2.0925, 2.0921, 2.0917, 2.0909, 2.0907, 2.0900, 2.0899, 2.0895,
#          2.0893, 2.0887, 2.0885, 2.0876, 2.0871, 2.0871, 2.0864, 2.0865, 2.0862,
#          2.0855, 2.0847, 2.0846, 2.0842, 2.0836, 2.0830, 2.0828, 2.0827, 2.0822,
#          2.0817, 2.0818, 2.0811, 2.0806, 2.0799, 2.0802, 2.0792, 2.0792, 2.0787,
#          2.0783, 2.0785, 2.0778, 2.0773, 2.0770, 2.0771, 2.0761, 2.0760, 2.0758,
#          2.0753, 2.0750, 2.0749, 2.0744, 2.0737, 2.0732, 2.0726, 2.0728, 2.0723,
#          2.0718, 2.0713, 2.0711, 2.0706, 2.0703, 2.0701, 2.0698, 2.0692, 2.0694,
#          2.0686, 2.0682, 2.0681, 2.0680, 2.0675, 2.0676, 2.0672, 2.0669, 2.0666,
#          2.0657, 2.0659, 2.0651, 2.0649, 2.0642, 2.0642, 2.0637, 2.0629, 2.0627,
#          2.0625, 2.0620, 2.0623, 2.0621, 2.0614, 2.0608, 2.0611, 2.0604, 2.0601,
#          2.0604, 2.0600, 2.0601, 2.0590, 2.0592, 2.0590, 2.0586, 2.0586, 2.0581,
#          2.0573, 2.0572, 2.0575, 2.0569, 2.0565, 2.0563, 2.0557, 2.0557, 2.0557,
#          2.0554, 2.0555, 2.0549, 2.0553, 2.0544, 2.0539, 2.0539, 2.0537, 2.0535,
#          2.0541, 2.0533, 2.0527, 2.0522, 2.0525, 2.0517, 2.0517, 2.0517, 2.0507,
#          2.0506, 2.0500, 2.0503, 2.0501, 2.0501, 2.0494, 2.0498, 2.0493, 2.0494,
#          2.0491, 2.0485, 2.0480, 2.0479, 2.0479, 2.0473, 2.0474, 2.0471, 2.0459,
#          2.0462, 2.0464, 2.0460, 2.0468, 2.0459, 2.0453, 2.0451, 2.0449, 2.0442,
#          2.0446, 2.0441, 2.0432, 2.0432, 2.0430, 2.0426, 2.0426, 2.0431, 2.0426,
#          2.0416, 2.0422, 2.0416, 2.0417, 2.0411, 2.0413, 2.0409, 2.0407, 2.0402,
#          2.0399, 2.0396, 2.0393, 2.0390, 2.0393, 2.0394, 2.0392, 2.0401, 2.0389,
#          2.0386, 2.0383, 2.0379, 2.0380, 2.0373, 2.0378, 2.0373, 2.0370, 2.0364,
#          2.0368, 2.0364, 2.0359, 2.0357, 2.0354, 2.0354, 2.0351, 2.0349, 2.0353,
#          2.0345, 2.0345, 2.0345, 2.0337, 2.0343, 2.0338, 2.0332, 2.0327, 2.0338,
#          2.0330, 2.0335, 2.0327, 2.0321, 2.0322, 2.0318, 2.0319, 2.0315, 2.0316,
#          2.0310, 2.0315, 2.0311]),
#  tensor([3.9917, 3.9625, 3.9496, 3.9259, 3.9333, 4.1780, 4.1223, 4.1444, 4.2447,
#          4.2482, 4.2896, 4.2891, 4.3469, 4.3286, 4.3771, 4.3323, 4.3185, 4.3528,
#          4.3387, 4.3444, 4.3665, 4.3585, 4.3546, 4.3561, 4.3412, 4.3591, 4.3867,
#          4.3817, 4.3826, 4.3957, 4.3956, 4.3786, 4.3923, 4.3939, 4.4100, 4.4223,
#          4.4357, 4.4098, 4.4477, 4.4641, 4.4533, 4.4573, 4.4695, 4.4590, 4.4550,
#          4.4374, 4.3925, 4.4323, 4.4546, 4.4510, 4.3487, 4.4841, 4.4383, 4.4679,
#          4.4512, 4.4644, 4.3023, 4.4812, 4.3060, 4.4238, 4.4021, 4.3033, 4.2661,
#          4.2882, 4.3923, 4.3607, 4.3350, 4.2259, 4.2782, 4.3306, 4.1923, 4.2353,
#          4.2785, 4.2622, 4.1766, 4.3515, 4.2357, 4.2604, 4.2527, 4.2523, 4.2723,
#          4.2565, 4.3153, 4.2889, 4.3142, 4.3462, 4.2449, 4.2442, 4.3701, 4.3854,
#          4.2779, 4.1708, 4.2966, 4.1845, 4.4058, 4.2037, 4.2013, 4.2202, 4.2348,
#          4.1467, 4.1292, 4.2110, 4.1979, 4.1383, 4.2361, 4.2948, 4.1144, 4.1678,
#          4.1859, 4.0738, 4.1821, 4.1427, 4.0567, 4.1995, 4.0591, 4.2187, 4.1321,
#          4.1395, 4.1534, 4.1762, 4.1887, 4.2726, 4.0963, 4.1197, 4.0343, 4.1387,
#          4.1492, 4.2297, 4.2429, 4.1821, 4.1078, 4.0652, 4.0638, 4.0803, 4.1751,
#          3.9415, 4.2620, 4.1764, 4.1391, 4.0897, 4.0964, 4.1096, 4.2704, 4.2683,
#          4.2563, 4.3035, 4.2321, 4.2166, 4.3041, 4.3316, 4.2820, 4.3394, 4.2831,
#          4.2406, 4.4260, 4.5231, 4.2049, 4.2929, 4.3874, 4.2046, 4.2979, 4.5111,
#          4.3159, 4.4478, 4.6027, 4.3124, 4.2325, 4.3047, 4.2127, 4.3783, 4.3569,
#          4.4110, 4.2956, 4.4350, 4.4929, 4.3906, 4.5149, 4.4412, 4.2087, 4.1822,
#          4.2953, 4.1629, 4.2283, 4.2737, 4.3603, 4.2896, 4.2943, 4.2400, 4.1638,
#          4.3979, 4.3774, 4.4063, 4.2530, 4.5306, 4.6218, 4.5377, 4.5502, 4.6393,
#          4.6390, 4.4598, 4.4494, 4.7202, 4.6313, 4.5602, 4.5028, 4.5971, 4.6063,
#          4.6385, 4.8433, 4.8374, 4.7477, 4.8288, 4.6735, 4.5680, 4.7097, 4.8330,
#          4.8054, 4.6938, 4.6243, 4.6778, 4.6679, 4.7502, 4.6884, 4.5760, 4.7539,
#          4.6509, 4.6310, 4.8181, 4.9480, 4.9638, 4.7993, 4.9117, 4.8395, 4.8013,
#          4.8959, 4.8341, 4.7872, 4.8536, 4.7557, 4.9156, 4.9418, 4.9284, 4.9359,
#          4.8233, 4.8017, 4.8387, 5.0911, 4.8952, 4.8560, 4.7919, 4.8253, 4.8131,
#          4.6843, 4.9063, 5.0013, 4.9932, 4.8238, 4.9173, 4.7401, 4.7453, 4.6963,
#          4.5949, 4.7736, 4.7466, 4.9210, 4.7793, 4.8834, 4.8397, 4.9569, 4.7091,
#          4.7379, 4.9264, 4.9737, 4.8635, 4.8671, 4.9059, 4.8855, 4.9896, 4.8343,
#          5.0737, 4.9065, 4.8164, 4.9918, 4.9098, 4.9638, 5.0216, 4.9552, 4.8149,
#          4.8747, 4.8401, 5.0259, 4.9503, 4.9311, 4.9354, 4.8621, 4.8766, 4.8853,
#          4.9347, 4.9462, 4.8324]),
#  tensor([0.5786, 0.5977, 0.6001, 0.6013, 0.6021, 0.6039, 0.6048, 0.6052, 0.6057,
#          0.6061, 0.6063, 0.6062, 0.6067, 0.6067, 0.6069, 0.6068, 0.6071, 0.6070,
#          0.6072, 0.6072, 0.6076, 0.6074, 0.6072, 0.6074, 0.6075, 0.6076, 0.6078,
#          0.6076, 0.6077, 0.6078, 0.6073, 0.6077, 0.6079, 0.6079, 0.6077, 0.6077,
#          0.6076, 0.6078, 0.6081, 0.6075, 0.6075, 0.6078, 0.6082, 0.6078, 0.6081,
#          0.6079, 0.6080, 0.6081, 0.6081, 0.6080, 0.6079, 0.6082, 0.6082, 0.6076,
#          0.6084, 0.6078, 0.6082, 0.6083, 0.6083, 0.6080, 0.6084, 0.6084, 0.6084,
#          0.6081, 0.6083, 0.6084, 0.6084, 0.6083, 0.6083, 0.6084, 0.6086, 0.6085,
#          0.6083, 0.6087, 0.6085, 0.6084, 0.6088, 0.6083, 0.6087, 0.6084, 0.6086,
#          0.6088, 0.6087, 0.6089, 0.6093, 0.6090, 0.6091, 0.6097, 0.6097, 0.6098,
#          0.6105, 0.6107, 0.6109, 0.6112, 0.6114, 0.6114, 0.6116, 0.6112, 0.6118,
#          0.6119, 0.6121, 0.6122, 0.6120, 0.6122, 0.6124, 0.6123, 0.6124, 0.6125,
#          0.6123, 0.6125, 0.6123, 0.6125, 0.6127, 0.6127, 0.6127, 0.6129, 0.6129,
#          0.6131, 0.6129, 0.6129, 0.6131, 0.6132, 0.6129, 0.6134, 0.6132, 0.6135,
#          0.6132, 0.6134, 0.6134, 0.6138, 0.6136, 0.6136, 0.6136, 0.6137, 0.6139,
#          0.6138, 0.6140, 0.6142, 0.6142, 0.6141, 0.6141, 0.6143, 0.6142, 0.6139,
#          0.6143, 0.6144, 0.6147, 0.6146, 0.6145, 0.6147, 0.6147, 0.6147, 0.6148,
#          0.6148, 0.6148, 0.6150, 0.6150, 0.6150, 0.6149, 0.6150, 0.6152, 0.6151,
#          0.6153, 0.6152, 0.6152, 0.6153, 0.6154, 0.6154, 0.6154, 0.6154, 0.6155,
#          0.6152, 0.6156, 0.6152, 0.6154, 0.6156, 0.6153, 0.6155, 0.6154, 0.6156,
#          0.6155, 0.6157, 0.6157, 0.6158, 0.6158, 0.6157, 0.6159, 0.6157, 0.6158,
#          0.6160, 0.6159, 0.6159, 0.6160, 0.6161, 0.6161, 0.6162, 0.6163, 0.6160,
#          0.6162, 0.6162, 0.6164, 0.6163, 0.6161, 0.6163, 0.6163, 0.6164, 0.6165,
#          0.6165, 0.6166, 0.6165, 0.6167, 0.6165, 0.6166, 0.6167, 0.6166, 0.6167,
#          0.6167, 0.6168, 0.6166, 0.6167, 0.6168, 0.6167, 0.6168, 0.6168, 0.6171,
#          0.6170, 0.6167, 0.6168, 0.6170, 0.6169, 0.6170, 0.6171, 0.6170, 0.6171,
#          0.6168, 0.6173, 0.6173, 0.6171, 0.6173, 0.6171, 0.6173, 0.6171, 0.6173,
#          0.6173, 0.6173, 0.6174, 0.6173, 0.6174, 0.6174, 0.6174, 0.6174, 0.6176,
#          0.6176, 0.6176, 0.6176, 0.6175, 0.6176, 0.6174, 0.6177, 0.6174, 0.6175,
#          0.6176, 0.6176, 0.6179, 0.6178, 0.6179, 0.6179, 0.6179, 0.6179, 0.6179,
#          0.6180, 0.6180, 0.6179, 0.6179, 0.6180, 0.6181, 0.6181, 0.6181, 0.6180,
#          0.6180, 0.6182, 0.6181, 0.6183, 0.6182, 0.6182, 0.6183, 0.6183, 0.6184,
#          0.6183, 0.6181, 0.6183, 0.6185, 0.6184, 0.6186, 0.6185, 0.6184, 0.6184,
#          0.6184, 0.6185, 0.6185]))

# %%
# (yy * data['date_int'].max()).round()

# %%
# (yHat_test * data['date_int'].max()).round()

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.6194
#
#
# mean_absolute_error(y, yHat): 0.6839
#
# mean_absolute_error(yy, yHat_test): 1.2577
#
#
# mean_squared_error(y, yHat): 1.7749
#
# mean_squared_error(yy, yHat_test): 4.8324
#
#
# mean_squared_log_error(y, yHat): 0.0961
#
# mean_squared_log_error(yy, yHat_test): 0.4586
#
#
# RMSE(y, yHat): 1.3322
#
# RMSE(yy, yHat_test): 2.1983

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss2.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.detach().T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc2.jpg", bbox_inches='tight')


plt.show()

# %%
['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']
# Out:
# ['day_scaled',
#  'day_sin',
#  'day_cos',
#  'month_scaled',
#  'month_sin',
#  'month_cos',
#  'leap_year',
#  'decade_scaled',
#  'decade_sin',
#  'decade_cos']

# %%
def result_to_date(result):
    
    result = str(result)
    
    day   = int(result[6:]) - 1
    month = int(result[4:6]) - 1

    ss = str(f'{result[:4]}0101')
    
    ds = datetime.datetime.strptime(ss, '%Y%m%d')
    
    ds = ds + relativedelta(months=month, days=day)

    result = ds.strftime('%d-%m-%Y')
    
    
    return result

# %%
# (16830739, 17848869)
result_to_date(16830739), result_to_date(17848869)
# Out:
# ('08-08-1683', '08-06-1791')

# %%
def test_model(input_list):
    

    X       = np.zeros((1, 10))
    X_smote = np.zeros((1, 10))



    day       = np.array(map_day[input_list[0]])
    month     = np.array(map_month[input_list[1]])
    leap_year = map_leap_year[input_list[2]]
    decade    = np.array(input_list[3].strip('[]')).astype('int64')


    X[0, 0] = scaler_day.transform(day.reshape(-1, 1)).flatten()
    X[0, 1] = np.sin(day * (2 * np.pi / 7))
    X[0, 2] = np.cos(day * (2 * np.pi / 7))

    X[0, 3] = scaler_month.transform(month.reshape(-1, 1)).flatten()
    X[0, 4] = np.sin(month * (2 * np.pi / 12))
    X[0, 5] = np.cos(month * (2 * np.pi / 12))

    X[0, 6] = leap_year

    X[0, 7] = scaler_decade.transform(decade.reshape(-1, 1)).flatten()
    X[0, 8] = np.sin(decade * (2 * np.pi / alpha))
    X[0, 9] = np.cos(decade * (2 * np.pi / alpha))

    # ---

    X_smote[0, 0] = scaler_day_smote.transform(day.reshape(-1, 1)).flatten()
    X_smote[0, 1] = X[0, 1]
    X_smote[0, 2] = X[0, 2]

    X_smote[0, 3] = scaler_month_smote.transform(month.reshape(-1, 1)).flatten()
    X_smote[0, 4] = X[0, 4]
    X_smote[0, 5] = X[0, 5]

    X_smote[0, 6] = leap_year

    X_smote[0, 7] = scaler_decade_smote.transform(decade.reshape(-1, 1)).flatten()
    X_smote[0, 8] = np.sin(decade * (2 * np.pi / alpha_smote))
    X_smote[0, 9] = np.cos(decade * (2 * np.pi / alpha_smote))


    # ---

    result       = model(torch.tensor(X).to(device).float())
    result_smote = model_smote(torch.tensor(X_smote).to(device).float())


    # ---


    result       = ''.join(result.detach().cpu().numpy().round().astype(int).astype(str).flatten())
    result_smote = ''.join(result_smote.detach().cpu().numpy().round().astype(int).astype(str).flatten())


    
    return result_to_date(result), result_to_date(result_smote)

# %%
input_test1 = ['[MON]', '[DEC]', '[False]', '[196]']
output_test1 = '3-12-1962'

input_test2 = ['[THU]', '[DEC]', '[True]', '[204]']
output_test2 = '3-12-2048'

input_test3 = ['[WED]', '[JAN]', '[False]', '[181]']
output_test3 = '10-1-1810'


input_test4 = ['[WED]', '[JUN]', '[False]', '[209]']

# %%
test_model(input_test1), test_model(input_test2), test_model(input_test3), test_model(input_test4)
# Out:
# (('15-12-1965', '15-12-1965'),
#  ('15-12-2045', '15-12-2045'),
#  ('12-01-1813', '15-01-1814'),
#  ('15-06-2094', '14-06-2095'))

# %%
output_test1, output_test2, output_test3
# Out:
# ('3-12-1962', '3-12-2048', '10-1-1810')

# %%
# example_input = pd.read_csv('./data/example_input.txt', sep=' ', header=None)
example_input = pd.read_csv('example_input.txt', sep=' ', header=None)


example_input.columns = ['day', 'month', 'leap_year', 'decade']

# %%
example_input
# Out:
#         day  month leap_year decade
# 0     [WED]  [JAN]   [False]  [180]
# 1     [MON]  [JAN]   [False]  [190]
# 2     [SAT]  [JAN]    [True]  [200]
# 3     [FRI]  [JAN]   [False]  [210]
# 4     [WED]  [JAN]   [False]  [220]
# ...     ...    ...       ...    ...
# 1460  [MON]  [OCT]    [True]  [214]
# 1461  [TUE]  [DEC]   [False]  [183]
# 1462  [SUN]  [DEC]   [False]  [193]
# 1463  [SAT]  [DEC]   [False]  [203]
# 1464  [THU]  [DEC]   [False]  [213]
#
# [1465 rows x 4 columns]

# %%
R       = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result'])
R_smote = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result_smote'])

# %%
example_input.iloc[0].tolist()
# Out:
# ['[WED]', '[JAN]', '[False]', '[180]']

# %%
for i in range(len(example_input)):
    R.iloc[i], R_smote.iloc[i] = test_model(example_input.iloc[i].tolist())

# %%
R
# Out:
#           result
# 0     14-01-1804
# 1     12-01-1903
# 2     15-01-2005
# 3     15-01-2105
# 4     15-02-2200
# ...          ...
# 1460  15-10-2145
# 1461  15-12-1835
# 1462  15-12-1935
# 1463  15-12-2035
# 1464  15-12-2135
#
# [1465 rows x 1 columns]

# %%
final = pd.concat([example_input, R], axis=1)
final
# Out:
#         day  month leap_year decade      result
# 0     [WED]  [JAN]   [False]  [180]  14-01-1804
# 1     [MON]  [JAN]   [False]  [190]  12-01-1903
# 2     [SAT]  [JAN]    [True]  [200]  15-01-2005
# 3     [FRI]  [JAN]   [False]  [210]  15-01-2105
# 4     [WED]  [JAN]   [False]  [220]  15-02-2200
# ...     ...    ...       ...    ...         ...
# 1460  [MON]  [OCT]    [True]  [214]  15-10-2145
# 1461  [TUE]  [DEC]   [False]  [183]  15-12-1835
# 1462  [SUN]  [DEC]   [False]  [193]  15-12-1935
# 1463  [SAT]  [DEC]   [False]  [203]  15-12-2035
# 1464  [THU]  [DEC]   [False]  [213]  15-12-2135
#
# [1465 rows x 5 columns]

# %%
final_smote = pd.concat([example_input, R_smote], axis=1)
final_smote
# Out:
#         day  month leap_year decade result_smote
# 0     [WED]  [JAN]   [False]  [180]   15-01-1804
# 1     [MON]  [JAN]   [False]  [190]   15-01-1904
# 2     [SAT]  [JAN]    [True]  [200]   15-01-2002
# 3     [FRI]  [JAN]   [False]  [210]   15-01-2104
# 4     [WED]  [JAN]   [False]  [220]   14-01-2184
# ...     ...    ...       ...    ...          ...
# 1460  [MON]  [OCT]    [True]  [214]   15-10-2145
# 1461  [TUE]  [DEC]   [False]  [183]   15-12-1834
# 1462  [SUN]  [DEC]   [False]  [193]   15-12-1935
# 1463  [SAT]  [DEC]   [False]  [203]   15-12-2035
# 1464  [THU]  [DEC]   [False]  [213]   15-12-2134
#
# [1465 rows x 5 columns]

# %%
final.to_csv('output_file.txt', sep=' ', header=None, index=False)

# %%
final_smote.to_csv('output_file_smote.txt', sep=' ', header=None, index=False)

# %% [markdown]
# Out-liers

# %% [markdown]
# Saving

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              'scaler_day_smote' : scaler_day_smote,
              'scaler_month_smote' : scaler_month_smote,
              'scaler_decade_smote' : scaler_decade_smote,
              
              'alpha': alpha,
              'alpha_smote': alpha_smote}



torch.save(checkpoint, 'checkpoint.pth.tar')

# %%
# checkpoint = torch.load('checkpoint.pth.tar')

# %%
# model       = Model()
# model_smote = Model()


# model.load_state_dict(checkpoint['model_state_dict'])
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
