# %%
import datetime

import copy

import random


from dateutil.relativedelta import relativedelta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('seaborn')
# plt.style.use(['dark_background', 'ggplot'])

import seaborn as sns
# sns.set()

# import scipy
# import scipy.stats as stats


# # sympy = symbolic math in Python
# import sympy as sym
# import sympy.plotting.plot as symplot


# make the equations look nicer

# from IPython.display import display
# display.set_matplotlib_formats('svg') # Deprecated since version 7.23

# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


# %config InlineBackend.set_matplotlib_formats = ["svg"]
# %config InlineBackend.figure_formats = ["svg"]

# %%
import sklearn


from sklearn.model_selection import train_test_split


# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler     # <------------ (-1.0, 1.0)
# from sklearn.preprocessing import MinMaxScaler


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from imblearn.over_sampling import SMOTE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset, DataLoader





torch.__version__
# Out:
# '1.12.1+cu113'

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def print_score(shape, yHat, y, yHat_test, yy):
    
    
    n, p = shape
    
    R2 = r2_score(y.detach().numpy(), yHat.detach().numpy())
    
    Adj_r2 = 1 - (1 - R2)  *  (n - 1) / (n - p - 1)
    
    print(f'Adjusted R-Squared(y, yHat): {Adj_r2:0.4f}\n\n')
    # r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
    #  R^2 score is not well-defined with less than two samples
    
    
    print(f'mean_absolute_error(y, yHat):',
          f'{mean_absolute_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_absolute_error(yy, yHat_test):',
          f'{mean_absolute_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_error(y, yHat):',
          f'{mean_squared_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_error(yy, yHat_test):',
          f'{mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_log_error(y, yHat):',
          f'{mean_squared_log_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_log_error(yy, yHat_test):',
          f'{mean_squared_log_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    
    print(f'RMSE(y, yHat):',
          f'{np.sqrt( mean_squared_error(y.detach().numpy(), yHat.detach().numpy()) ):0.4f}\n')
    print(f'RMSE(yy, yHat_test):',
          f'{np.sqrt( mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()) ):0.4f}\n\n')

# %%
# date = np.datetime64("2000-01-01")
# date_strings = date.astype(str).split('-'). 
# # >> ['2000', '01', '01']

# year_int = int(date_strings[0])

# %%
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Out:
# --2022-08-18 13:54:18--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5230713 (5.0M) [text/plain]
# Saving to: ‘data.txt’
#
# data.txt            100%[===================>]   4.99M  --.-KB/s    in 0.04s
#
# 2022-08-18 13:54:20 (122 MB/s) - ‘data.txt’ saved [5230713/5230713]
#
# --2022-08-18 13:54:21--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37732 (37K) [text/plain]
# Saving to: ‘example_input.txt’
#
# example_input.txt   100%[===================>]  36.85K  --.-KB/s    in 0.001s
#
# 2022-08-18 13:54:21 (25.3 MB/s) - ‘example_input.txt’ saved [37732/37732]

# %%
# !ls
# Out:
# data.txt  example_input.txt  sample_data

# %% [markdown]
# 'text.txt'

# %% [markdown]
# [ 1-1-1800 to 31-12-2200 ]

# %% [markdown]
# [day condition] [month condition] [leap year condition] [decade condition] date

# %% [markdown]
# [MON] [DEC] [False] [196] 3-12-1962
# [THU] [DEC] [True] [204] 3-12-2048
# [WED] [JAN] [False] [181] 10-1-1810

# %%
# data = np.loadtxt(open('text.txt','r'),delimiter=' ')
# ori = pd.read_csv('./data/data.txt', sep=' ', header=None)

ori = pd.read_csv('data.txt', sep=' ', header=None)

# %%
ori.columns = ['day', 'month', 'leap_year', 'decade', 'date']

# %%
ori
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
# data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)
# # pd.to_datetime(data.date, infer_datetime_format=False)

# %%
ori.dtypes
# Out:
# day          object
# month        object
# leap_year    object
# decade       object
# date         object
# dtype: object

# %%
# data_backup = copy.deepcopy(ori)
data = copy.deepcopy(ori)

# %%
data
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
data.date
# Out:
# 0           1-1-1800
# 1           1-1-1801
# 2           1-1-1802
# 3           1-1-1803
# 4           1-1-1804
#              ...
# 146457    31-12-2196
# 146458    31-12-2197
# 146459    31-12-2198
# 146460    31-12-2199
# 146461    31-12-2200
# Name: date, Length: 146462, dtype: object

# %%
# # data['date'] = pd.date_range('3-12-2048', periods=10)
# # data['date'] = pd.date_range('12-3-1962', periods=10)

# # 1-1-1800 to 31-12-2200
# data['date'] = pd.date_range(start='1-1-1800',end='12-31-2200')


data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)

# # data.date = data.date.dt.strftime('%d-%m-%Y')
# # data.date = pd.to_datetime(data.date.dt.strftime('%d-%m-%Y'), format='%d-%m-%Y', infer_datetime_format=False)

# %%
data.dtypes
# Out:
# day                  object
# month                object
# leap_year            object
# decade               object
# date         datetime64[ns]
# dtype: object

# %%
data
# Out:
#           day  month leap_year decade       date
# 0       [WED]  [JAN]   [False]  [180] 1800-01-01
# 1       [THU]  [JAN]   [False]  [180] 1801-01-01
# 2       [FRI]  [JAN]   [False]  [180] 1802-01-01
# 3       [SAT]  [JAN]   [False]  [180] 1803-01-01
# 4       [SUN]  [JAN]    [True]  [180] 1804-01-01
# ...       ...    ...       ...    ...        ...
# 146457  [SAT]  [DEC]    [True]  [219] 2196-12-31
# 146458  [SUN]  [DEC]   [False]  [219] 2197-12-31
# 146459  [MON]  [DEC]   [False]  [219] 2198-12-31
# 146460  [TUE]  [DEC]   [False]  [219] 2199-12-31
# 146461  [WED]  [DEC]   [False]  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %%
map_leap_year = {'[False]': int(0), '[True]' : int(1)}

data.leap_year = data.leap_year.map(map_leap_year)

# data.leap_year = data.leap_year.astype(np.float64)

# %%
data
# Out:
#           day  month  leap_year decade       date
# 0       [WED]  [JAN]          0  [180] 1800-01-01
# 1       [THU]  [JAN]          0  [180] 1801-01-01
# 2       [FRI]  [JAN]          0  [180] 1802-01-01
# 3       [SAT]  [JAN]          0  [180] 1803-01-01
# 4       [SUN]  [JAN]          1  [180] 1804-01-01
# ...       ...    ...        ...    ...        ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31
# 146459  [MON]  [DEC]          0  [219] 2198-12-31
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31
# 146461  [WED]  [DEC]          0  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %% [markdown]
# date -> timestamp

# %%
data.date.iloc[0]
# Out:
# Timestamp('1800-01-01 00:00:00')

# %%
data['date_int'] = data['date'].dt.strftime("%Y%m%d").astype(np.int64)

# data['date_str'] = data['date'].dt.strftime("%Y%m%d")

# %%
# data['date_int'].map(str)
# data['date_int'].astype(str)

# %%
# date_max = data.date_int.max()
# data['date_normalized'] = data.date_int / date_max

# %%
data
# Out:
#           day  month  leap_year decade       date  date_int
# 0       [WED]  [JAN]          0  [180] 1800-01-01  18000101
# 1       [THU]  [JAN]          0  [180] 1801-01-01  18010101
# 2       [FRI]  [JAN]          0  [180] 1802-01-01  18020101
# 3       [SAT]  [JAN]          0  [180] 1803-01-01  18030101
# 4       [SUN]  [JAN]          1  [180] 1804-01-01  18040101
# ...       ...    ...        ...    ...        ...       ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31  21961231
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31  21971231
# 146459  [MON]  [DEC]          0  [219] 2198-12-31  21981231
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31  21991231
# 146461  [WED]  [DEC]          0  [220] 2200-12-31  22001231
#
# [146462 rows x 6 columns]

# %%
x = data.decade.iloc[0]
x
# Out:
# '[180]'

# %%
x.strip('[]')
# Out:
# '180'

# %%
data.decade = data.decade.apply(lambda x: x.strip('[]')).astype('int64')

# %%
# data.day = data.day.apply(lambda x: x.strip('[]'))
# data.month = data.month.apply(lambda x: x.strip('[]'))

# %%
map_day = {'[SAT]': int(0),
           '[SUN]': int(1),
           '[MON]': int(2),
           '[TUE]': int(3),
           '[WED]': int(4),
           '[THU]': int(5),
           '[FRI]': int(6)}

# %%
data['day_code'] = data.day.map(map_day)

# %%
scaler_day = RobustScaler()

x = data.day_code.values.reshape(-1, 1)

data['day_scaled'] = scaler_day.fit_transform(x).flatten()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled
# 0             0.25
# 1             0.50
# 2             0.75
# 3            -0.75
# 4            -0.50
# ...            ...
# 146457       -0.75
# 146458       -0.50
# 146459       -0.25
# 146460        0.00
# 146461        0.25
#
# [146462 rows x 8 columns]

# %%
data['day_sin'] = np.sin(data['day_code'] * (2 * np.pi / 7))
data['day_cos'] = np.cos(data['day_code'] * (2 * np.pi / 7))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos
# 0             0.25 -0.433884 -0.900969
# 1             0.50 -0.974928 -0.222521
# 2             0.75 -0.781831  0.623490
# 3            -0.75  0.000000  1.000000
# 4            -0.50  0.781831  0.623490
# ...            ...       ...       ...
# 146457       -0.75  0.000000  1.000000
# 146458       -0.50  0.781831  0.623490
# 146459       -0.25  0.974928 -0.222521
# 146460        0.00  0.433884 -0.900969
# 146461        0.25 -0.433884 -0.900969
#
# [146462 rows x 10 columns]

# %%
map_month = {'[JAN]': int(0),
             '[FEB]': int(1),
             '[MAR]': int(2),
             '[APR]': int(3),
             '[MAY]': int(4),
             '[JUN]': int(5),
             '[JUL]': int(6),
             '[AUG]': int(7),
             '[SEP]': int(8),
             '[OCT]': int(9),
             '[NOV]': int(10),
             '[DEC]': int(11)}

# %%
data['month_code'] = data.month.map(map_month)

# %%
scaler_month = RobustScaler()

x = data.month_code.values.reshape(-1, 1)

data['month_scaled'] = scaler_month.fit_transform(x).flatten()

# %%
data['month_sin'] = np.sin(data['month_code'] * (2 * np.pi / 12))
data['month_cos'] = np.cos(data['month_code'] * (2 * np.pi / 12))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ...           ...
# 146457   0.866025
# 146458   0.866025
# 146459   0.866025
# 146460   0.866025
# 146461   0.866025
#
# [146462 rows x 14 columns]

# %%
scaler_decade = RobustScaler()

x = data.decade.values.reshape(-1, 1)

data['decade_scaled'] = scaler_decade.fit_transform(x).flatten()

# %%
# alpha = len(data.decade.unique())
alpha = (data.decade.iloc[-1] - data.decade.iloc[0]) + 1

data['decade_sin'] = np.sin(data['decade'] * (2 * np.pi / alpha))
data['decade_cos'] = np.cos(data['decade'] * (2 * np.pi / alpha))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %%
# data.date_normalized.min(), data.date_normalized.max()

# %%
# round(data.date_normalized.min()), round(data.date_normalized.max())

# %%
round(data.day_scaled.min()), round(data.day_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_sin.min()), round(data.day_sin.max())
# Out:
# (-1, 1)

# %%
round(data.day_cos.min()), round(data.day_cos.max())
# Out:
# (-1, 1)

# %%
round(data.month_scaled.min()), round(data.month_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.month_sin.min()), round(data.month_sin.max())
# Out:
# (-1, 1)

# %%
round(data.month_cos.min()), round(data.month_cos.max())
# Out:
# (-1, 1)

# %%
data.leap_year.min(), data.leap_year.max()
# Out:
# (0, 1)

# %%
round(data.decade_scaled.min()), round(data.decade_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.decade_sin.min()), round(data.decade_sin.max())
# Out:
# (-1, 1)

# %%
round(data.decade_cos.min()), round(data.decade_cos.max())
# Out:
# (-1, 1)

# %% [markdown]
# Boxplot

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.day.value_counts().plot(kind="bar")

# %%
data.month.value_counts().plot(kind="bar")

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
data.decade.value_counts().plot(kind="bar")

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %% [markdown]
# ['day_sin', 'day_cos', 'month_sin', 'month_cos', 'leap_year', 'decade_scaled']
# ['date_timestamp_scaled']

# %%
X = data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
          'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 0.25      , -0.43388374, -0.90096887, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.5       , -0.97492791, -0.22252093, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.75      , -0.78183148,  0.6234898 , ..., -1.        ,
#          0.63624244, -0.77148918],
#        ...,
#        [-0.25      ,  0.97492791, -0.22252093, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.        ,  0.43388374, -0.90096887, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.25      , -0.43388374, -0.90096887, ...,  1.        ,
#          0.74655322, -0.6653257 ]])

# %%
len(X)
# Out:
# 146462

# %%
X.shape
# Out:
# (146462, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()


ls = []

for s in data['date_int'].astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(data['date_int'])), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y = ll.values

Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 2, 0, ..., 2, 3, 1]])

# %%
len(Y)
# Out:
# 146462

# %%
Y.shape
# Out:
# (146462, 8)

# %%
# # leap = np.where(~X['leap_year'] == 1)[0]
# leap = np.where(X['leap_year'] == 1)[0]

# leap

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64


train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (146462, 10)
#
# Y: (146462, 8)
#
# Train data:   (102523, 10)
#
# Train labels: (102523, 8)
#
# Test data:    (43939, 10)
#
# Test labels:  (43939, 8)

# %%
102523 % 32, 102523 % 64
# Out:
# (27, 59)

# %%
class Model(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.input = nn.Linear(10, 64)

        self.fc1 = nn.Linear(64, 128)
        self.bnorm1 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 512)
        self.bnorm2 = nn.BatchNorm1d(512)

        self.fc3 = nn.Linear(512, 1024)
        self.bnorm3 = nn.BatchNorm1d(1024)

        self.fc4 = nn.Linear(1024, 512)
        self.bnorm4 = nn.BatchNorm1d(512)

        self.fc5 = nn.Linear(512, 128)
        self.bnorm5 = nn.BatchNorm1d(128)

        self.fc6 = nn.Linear(128, 64)
        self.bnorm6 = nn.BatchNorm1d(64)


        self.output = nn.Linear(64, 8)



    def forward(self, x):


        # print(f'training={self.training}')

        x = F.relu( self.input(x) ) # 64

        x = F.relu(self.bnorm1(self.fc1(x))) # 128
        # x = F.dropout(x, p=0.07, training=self.training)

        x = F.relu(self.bnorm2(self.fc2(x))) # 512
        # x = F.dropout(x, p=0.12, training=self.training)

        x = F.relu(self.bnorm3(self.fc3(x))) # 1024
        # x = F.dropout(x, p=0.25, training=self.training)

        x = F.relu(self.bnorm4(self.fc4(x))) # 512
        # x = F.dropout(x, p=0.12, training=self.training)

        x = F.relu(self.bnorm5(self.fc5(x))) # 128
        # x = F.dropout(x, p=0.07, training=self.training)

        x = F.relu(self.bnorm6(self.fc6(x))) # 64
        # x = F.dropout(x, p=0.05, training=self.training)

        x = F.relu(self.output(x)) # 8
        # x = self.output(x)
        


        return x

# %%
# test_x, test_y = next(iter(train_loader))

# print(f'test_x: {test_x.shape}\n')
# print(f'test_y: {test_y.shape}\n')

# %%
def train(model, numepochs):

    numepochs = numepochs

    model = model
    
    
    
    lossfun = nn.MSELoss()
    # lossfun = nn.L1Loss()


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0002, betas=(0.5, 0.999), weight_decay=1e-5)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.5, 0.999), weight_decay=1e-1)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=1e-9)


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
    
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    
    
    
    trainLoss = torch.zeros(numepochs)
    testLoss  = torch.zeros(numepochs)
    trainAcc  = torch.zeros(numepochs)
    # testAcc   = torch.zeros(numepochs)


    for epochi in range(numepochs):

        model.train() # switch to train mode

        batchLoss = []
        batchAcc  = []

        for X,y in train_loader:

            X = X.to(device)
            y = y.to(device)

            yHat = model(X)
            loss = lossfun(yHat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())
            # batchAcc.append( torch.mean(( yHat == y).float() ).item() )
            # batchAcc.append( torch.mean( (torch.abs(yHat - y) < 1).float() ).item() ) # <1 for rounding
            batchAcc.append( r2_score(y.detach().cpu().numpy(), yHat.detach().cpu().numpy()) )
            




        trainLoss[epochi] = np.mean(batchLoss)
        # trainAcc[epochi]  = 100*np.mean(batchAcc)
        trainAcc[epochi]  = np.mean(batchAcc)
        



        model.eval() # switch to test mode

        XX,yy = next(iter(test_loader))

        XX = XX.to(device)
        yy = yy.to(device)

        # forward pass and loss
        with torch.no_grad():
            yHat_test = model(XX)
            loss_test = lossfun(yHat_test, yy)


        testLoss[epochi] = loss_test.item()
        # testAcc[epochi]  = 100*torch.mean( (yHat_test == yy).float() ).item()
        # testAcc[epochi]  = 100*torch.mean( (torch.abs(yHat_test - yy) < 1).float() ).item()
        # testAcc[epochi]  = 100*r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
        


        # if (epochi + 1) % 5 == 0:
        print(f'Epoch {epochi+1}/{numepochs}, Train Loss: {loss.item():0.6f}, Test Loss: {loss_test.item():0.6f}')


        
    return trainLoss.cpu(), testLoss.cpu(), trainAcc.cpu(), yHat.cpu(), y.cpu(), yHat_test.cpu(), yy.cpu()

# %%
model = Model().to(device)

# test_hat = model(torch.randn(32,6))
# test_hat = model(test_x)

# print(test_hat.shape)


# # checkpoint = torch.load('checkpoint.pth.tar', map_location=torch.device('cpu'))
# checkpoint = torch.load('checkpoint_half.pth.tar', map_location=torch.device('cpu'))

# model.load_state_dict(checkpoint['model_state_dict'])

# %%
# for p in list(model.named_parameters()):
#     if 'weight' in p[0] and 'bnorm' not in p[0]:
#         nn.init.xavier_normal_(p[1].data)
#         print(p[0])
#         print(p[1].data.shape)

# %%
numepochs = 120
# numepochs = 300
# numepochs = 500



trainLoss1, testLoss1, trainAcc1, yHat1, y1, yHat_test1, yy1 = train(model, numepochs)
# Out:
# Epoch 1/120, Train Loss: 2.507965, Test Loss: 2.357785
# Epoch 2/120, Train Loss: 2.445185, Test Loss: 2.205106
# Epoch 3/120, Train Loss: 2.408722, Test Loss: 2.089826
# Epoch 4/120, Train Loss: 2.360607, Test Loss: 2.125216
# Epoch 5/120, Train Loss: 2.367944, Test Loss: 2.008972
# Epoch 6/120, Train Loss: 2.353453, Test Loss: 1.966699
# Epoch 7/120, Train Loss: 2.327424, Test Loss: 1.988318
# Epoch 8/120, Train Loss: 2.319540, Test Loss: 1.973851
# Epoch 9/120, Train Loss: 2.307599, Test Loss: 1.989388
# Epoch 10/120, Train Loss: 2.310573, Test Loss: 1.965093
# Epoch 11/120, Train Loss: 2.306724, Test Loss: 1.966587
# Epoch 12/120, Train Loss: 2.318141, Test Loss: 1.973196
# Epoch 13/120, Train Loss: 2.302895, Test Loss: 1.978483
# Epoch 14/120, Train Loss: 2.294433, Test Loss: 1.982434
# Epoch 15/120, Train Loss: 2.288211, Test Loss: 1.965482
# Epoch 16/120, Train Loss: 2.291320, Test Loss: 1.968217
# Epoch 17/120, Train Loss: 2.304884, Test Loss: 1.950907
# Epoch 18/120, Train Loss: 2.296584, Test Loss: 1.952195
# Epoch 19/120, Train Loss: 2.307058, Test Loss: 1.915408
# Epoch 20/120, Train Loss: 2.304927, Test Loss: 1.969079
# Epoch 21/120, Train Loss: 2.319221, Test Loss: 1.943584
# Epoch 22/120, Train Loss: 2.290039, Test Loss: 1.955684
# Epoch 23/120, Train Loss: 2.282159, Test Loss: 1.966097
# Epoch 24/120, Train Loss: 2.339452, Test Loss: 1.936145
# Epoch 25/120, Train Loss: 2.283663, Test Loss: 1.957914
# Epoch 26/120, Train Loss: 2.276217, Test Loss: 1.900140
# Epoch 27/120, Train Loss: 2.287220, Test Loss: 1.930577
# Epoch 28/120, Train Loss: 2.283775, Test Loss: 1.935981
# Epoch 29/120, Train Loss: 2.294147, Test Loss: 1.907266
# Epoch 30/120, Train Loss: 2.260273, Test Loss: 1.936505
# Epoch 31/120, Train Loss: 2.281572, Test Loss: 1.948707
# Epoch 32/120, Train Loss: 2.265878, Test Loss: 1.910078
# Epoch 33/120, Train Loss: 2.274910, Test Loss: 1.876874
# Epoch 34/120, Train Loss: 2.279462, Test Loss: 1.954820
# Epoch 35/120, Train Loss: 2.247025, Test Loss: 2.000998
# Epoch 36/120, Train Loss: 2.286341, Test Loss: 1.988623
# Epoch 37/120, Train Loss: 2.226430, Test Loss: 2.021874
# Epoch 38/120, Train Loss: 2.255948, Test Loss: 2.079727
# Epoch 39/120, Train Loss: 2.239904, Test Loss: 2.151937
# Epoch 40/120, Train Loss: 2.244294, Test Loss: 2.175706
# Epoch 41/120, Train Loss: 2.245576, Test Loss: 2.093144
# Epoch 42/120, Train Loss: 2.275948, Test Loss: 2.031969
# Epoch 43/120, Train Loss: 2.286358, Test Loss: 2.033139
# Epoch 44/120, Train Loss: 2.316388, Test Loss: 2.241500
# Epoch 45/120, Train Loss: 2.268147, Test Loss: 2.328970
# Epoch 46/120, Train Loss: 2.306208, Test Loss: 2.276396
# Epoch 47/120, Train Loss: 2.288103, Test Loss: 2.727621
# Epoch 48/120, Train Loss: 2.281016, Test Loss: 2.046196
# Epoch 49/120, Train Loss: 2.200162, Test Loss: 2.100565
# Epoch 50/120, Train Loss: 2.256575, Test Loss: 1.938015
# Epoch 51/120, Train Loss: 2.240515, Test Loss: 2.023652
# Epoch 52/120, Train Loss: 2.226217, Test Loss: 2.081835
# Epoch 53/120, Train Loss: 2.211861, Test Loss: 1.929795
# Epoch 54/120, Train Loss: 2.221392, Test Loss: 1.697142
# Epoch 55/120, Train Loss: 2.196527, Test Loss: 2.059521
# Epoch 56/120, Train Loss: 2.080255, Test Loss: 1.926442
# Epoch 57/120, Train Loss: 2.200242, Test Loss: 2.025656
# Epoch 58/120, Train Loss: 2.179714, Test Loss: 2.200909
# Epoch 59/120, Train Loss: 2.259542, Test Loss: 1.836905
# Epoch 60/120, Train Loss: 2.179910, Test Loss: 2.011362
# Epoch 61/120, Train Loss: 2.056638, Test Loss: 1.687714
# Epoch 62/120, Train Loss: 1.969977, Test Loss: 1.915210
# Epoch 63/120, Train Loss: 2.039770, Test Loss: 1.969580
# Epoch 64/120, Train Loss: 2.002504, Test Loss: 2.382574
# Epoch 65/120, Train Loss: 1.945085, Test Loss: 1.768120
# Epoch 66/120, Train Loss: 1.997343, Test Loss: 2.019805
# Epoch 67/120, Train Loss: 1.853467, Test Loss: 1.739754
# Epoch 68/120, Train Loss: 2.023209, Test Loss: 1.747250
# Epoch 69/120, Train Loss: 1.851447, Test Loss: 1.705491
# Epoch 70/120, Train Loss: 1.871789, Test Loss: 1.933209
# Epoch 71/120, Train Loss: 1.893675, Test Loss: 1.724033
# Epoch 72/120, Train Loss: 1.830681, Test Loss: 1.797704
# Epoch 73/120, Train Loss: 1.859560, Test Loss: 1.930994
# Epoch 74/120, Train Loss: 1.890920, Test Loss: 1.841797
# Epoch 75/120, Train Loss: 1.799411, Test Loss: 1.801078
# Epoch 76/120, Train Loss: 1.785531, Test Loss: 1.838536
# Epoch 77/120, Train Loss: 1.886203, Test Loss: 1.730002
# Epoch 78/120, Train Loss: 1.789643, Test Loss: 1.760380
# Epoch 79/120, Train Loss: 1.800983, Test Loss: 1.834359
# Epoch 80/120, Train Loss: 1.805188, Test Loss: 2.272597
# Epoch 81/120, Train Loss: 1.661131, Test Loss: 2.634801
# Epoch 82/120, Train Loss: 1.706332, Test Loss: 2.606196
# Epoch 83/120, Train Loss: 1.685968, Test Loss: 2.456262
# Epoch 84/120, Train Loss: 1.736870, Test Loss: 2.286849
# Epoch 85/120, Train Loss: 1.821115, Test Loss: 2.716396
# Epoch 86/120, Train Loss: 1.773809, Test Loss: 3.154440
# Epoch 87/120, Train Loss: 1.790698, Test Loss: 2.728362
# Epoch 88/120, Train Loss: 1.778870, Test Loss: 2.505318
# Epoch 89/120, Train Loss: 1.691476, Test Loss: 2.807901
# Epoch 90/120, Train Loss: 1.618728, Test Loss: 3.120511
# Epoch 91/120, Train Loss: 1.608551, Test Loss: 2.579909
# Epoch 92/120, Train Loss: 1.672694, Test Loss: 2.853560
# Epoch 93/120, Train Loss: 1.666373, Test Loss: 2.774854
# Epoch 94/120, Train Loss: 1.915318, Test Loss: 2.509797
# Epoch 95/120, Train Loss: 1.569452, Test Loss: 2.470083
# Epoch 96/120, Train Loss: 1.647559, Test Loss: 3.001322
# Epoch 97/120, Train Loss: 1.735872, Test Loss: 2.818213
# Epoch 98/120, Train Loss: 1.641267, Test Loss: 2.777108
# Epoch 99/120, Train Loss: 1.597718, Test Loss: 2.806522
# Epoch 100/120, Train Loss: 1.683326, Test Loss: 1.993775
# Epoch 101/120, Train Loss: 1.549082, Test Loss: 2.357558
# Epoch 102/120, Train Loss: 1.672933, Test Loss: 1.764041
# Epoch 103/120, Train Loss: 1.759782, Test Loss: 2.140402
# Epoch 104/120, Train Loss: 1.894642, Test Loss: 2.232877
# Epoch 105/120, Train Loss: 1.584620, Test Loss: 2.040229
# Epoch 106/120, Train Loss: 1.585223, Test Loss: 2.355032
# Epoch 107/120, Train Loss: 1.793460, Test Loss: 2.344296
# Epoch 108/120, Train Loss: 1.552628, Test Loss: 2.539670
# Epoch 109/120, Train Loss: 1.433830, Test Loss: 3.328621
# Epoch 110/120, Train Loss: 1.376726, Test Loss: 2.255721
# Epoch 111/120, Train Loss: 1.483985, Test Loss: 2.948095
# Epoch 112/120, Train Loss: 1.425929, Test Loss: 3.054225
# Epoch 113/120, Train Loss: 1.392558, Test Loss: 2.148605
# Epoch 114/120, Train Loss: 1.458041, Test Loss: 2.465429
# Epoch 115/120, Train Loss: 1.473785, Test Loss: 3.331551
# Epoch 116/120, Train Loss: 1.398281, Test Loss: 2.998180
# Epoch 117/120, Train Loss: 1.498096, Test Loss: 3.015238
# Epoch 118/120, Train Loss: 1.492132, Test Loss: 2.712122
# Epoch 119/120, Train Loss: 1.488601, Test Loss: 2.397108
# Epoch 120/120, Train Loss: 1.466299, Test Loss: 2.931779

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              #'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              #'scaler_day_smote' : scaler_day_smote,
              #'scaler_month_smote' : scaler_month_smote,
              #'scaler_decade_smote' : scaler_decade_smote,
              
              'alpha': alpha,
              #'alpha_smote': alpha_smote
              }



torch.save(checkpoint, 'checkpoint_half.pth.tar')

# %%
# r2_score(y.detach().numpy(), yHat.detach().numpy())
# type(r2_score(y.detach(), yHat.detach()))

# %%
# torch.mean( r2_score(y.detach().numpy(), yHat.detach().numpy()) ).item()

# %%
trainLoss1, testLoss1, trainAcc1
# Out:
# (tensor([2.7478, 2.3583, 2.2881, 2.2528, 2.2643, 2.2235, 2.2152, 2.2030, 2.1989,
#          2.2083, 2.1944, 2.1862, 2.1919, 2.1879, 2.1956, 2.1873, 2.2052, 2.1812,
#          2.1963, 2.1839, 2.1823, 2.1885, 2.1945, 2.1876, 2.1948, 2.1873, 2.1906,
#          2.1832, 2.1804, 2.1839, 2.1742, 2.1876, 2.1758, 2.1759, 2.1701, 2.1718,
#          2.1756, 2.1654, 2.1617, 2.1609, 2.1636, 2.1545, 2.1600, 2.1503, 2.1454,
#          2.1479, 2.1413, 2.1392, 2.1275, 2.1224, 2.1157, 2.1102, 2.1003, 2.0940,
#          2.0871, 2.0753, 2.0675, 2.0578, 2.0456, 2.0354, 2.0219, 2.0173, 2.0023,
#          1.9905, 1.9794, 1.9668, 1.9564, 1.9414, 1.9326, 1.9174, 1.9069, 1.8945,
#          1.8861, 1.8708, 1.8597, 1.8480, 1.8370, 1.8267, 1.8110, 1.8005, 1.7873,
#          1.7771, 1.7671, 1.7565, 1.7439, 1.7338, 1.7237, 1.7111, 1.7011, 1.6862,
#          1.6787, 1.6708, 1.6577, 1.6483, 1.6357, 1.6302, 1.6145, 1.6071, 1.5935,
#          1.5892, 1.5764, 1.5703, 1.5555, 1.5503, 1.5429, 1.5273, 1.5191, 1.5089,
#          1.4999, 1.4914, 1.4828, 1.4746, 1.4687, 1.4600, 1.4502, 1.4425, 1.4314,
#          1.4241, 1.4161, 1.4134]),
#  tensor([2.3578, 2.2051, 2.0898, 2.1252, 2.0090, 1.9667, 1.9883, 1.9739, 1.9894,
#          1.9651, 1.9666, 1.9732, 1.9785, 1.9824, 1.9655, 1.9682, 1.9509, 1.9522,
#          1.9154, 1.9691, 1.9436, 1.9557, 1.9661, 1.9361, 1.9579, 1.9001, 1.9306,
#          1.9360, 1.9073, 1.9365, 1.9487, 1.9101, 1.8769, 1.9548, 2.0010, 1.9886,
#          2.0219, 2.0797, 2.1519, 2.1757, 2.0931, 2.0320, 2.0331, 2.2415, 2.3290,
#          2.2764, 2.7276, 2.0462, 2.1006, 1.9380, 2.0237, 2.0818, 1.9298, 1.6971,
#          2.0595, 1.9264, 2.0257, 2.2009, 1.8369, 2.0114, 1.6877, 1.9152, 1.9696,
#          2.3826, 1.7681, 2.0198, 1.7398, 1.7473, 1.7055, 1.9332, 1.7240, 1.7977,
#          1.9310, 1.8418, 1.8011, 1.8385, 1.7300, 1.7604, 1.8344, 2.2726, 2.6348,
#          2.6062, 2.4563, 2.2868, 2.7164, 3.1544, 2.7284, 2.5053, 2.8079, 3.1205,
#          2.5799, 2.8536, 2.7749, 2.5098, 2.4701, 3.0013, 2.8182, 2.7771, 2.8065,
#          1.9938, 2.3576, 1.7640, 2.1404, 2.2329, 2.0402, 2.3550, 2.3443, 2.5397,
#          3.3286, 2.2557, 2.9481, 3.0542, 2.1486, 2.4654, 3.3316, 2.9982, 3.0152,
#          2.7121, 2.3971, 2.9318]),
#  tensor([0.4597, 0.5227, 0.5391, 0.5495, 0.5761, 0.5921, 0.5965, 0.5987, 0.5999,
#          0.6006, 0.6037, 0.6045, 0.6038, 0.6054, 0.6040, 0.6056, 0.6012, 0.6060,
#          0.6040, 0.6066, 0.6064, 0.6052, 0.6047, 0.6065, 0.6050, 0.6056, 0.6061,
#          0.6066, 0.6061, 0.6062, 0.6084, 0.6065, 0.6082, 0.6074, 0.6082, 0.6082,
#          0.6080, 0.6090, 0.6089, 0.6095, 0.6085, 0.6101, 0.6092, 0.6098, 0.6111,
#          0.6104, 0.6113, 0.6108, 0.6127, 0.6131, 0.6133, 0.6142, 0.6153, 0.6155,
#          0.6165, 0.6176, 0.6185, 0.6196, 0.6209, 0.6220, 0.6237, 0.6237, 0.6253,
#          0.6268, 0.6275, 0.6286, 0.6302, 0.6320, 0.6332, 0.6339, 0.6348, 0.6368,
#          0.6371, 0.6394, 0.6401, 0.6412, 0.6423, 0.6441, 0.6446, 0.6459, 0.6470,
#          0.6484, 0.6498, 0.6501, 0.6512, 0.6522, 0.6531, 0.6551, 0.6555, 0.6576,
#          0.6587, 0.6587, 0.6603, 0.6601, 0.6611, 0.6615, 0.6629, 0.6637, 0.6646,
#          0.6665, 0.6666, 0.6665, 0.6689, 0.6691, 0.6691, 0.6695, 0.6713, 0.6715,
#          0.6729, 0.6729, 0.6733, 0.6742, 0.6755, 0.6759, 0.6770, 0.6789, 0.6780,
#          0.6798, 0.6789, 0.6802]))

# %%
# batchLoss

# %%
# batchAcc

# %%
# yHat.shape, y.shape

# %%
# yHat_test.shape, yy.shape

# %%
yHat1.flatten(), y1.flatten()
# Out:
# (tensor([1.9491, 1.2696, 7.6612, 5.6534, 0.0000, 2.9458, 1.0181, 5.7866, 2.0448,
#          0.0000, 7.5972, 8.7025, 0.0000, 1.7185, 1.2178, 4.1327, 2.0760, 0.0000,
#          5.3692, 9.1426, 0.0000, 2.9018, 0.9650, 8.0718, 1.9968, 1.4793, 3.7473,
#          4.9053, 0.0000, 6.5641, 1.1126, 4.4923, 1.9513, 1.4219, 8.7418, 5.8385,
#          0.0000, 8.1740, 1.1437, 4.2228, 1.0489, 9.0950, 4.3233, 5.7755, 0.9947,
#          1.0319, 1.1742, 4.4922, 1.0371, 8.0780, 0.0000, 2.1870, 0.0000, 2.9463,
#          1.0043, 5.5635, 2.0290, 0.0000, 8.2169, 2.1519, 1.0005, 0.7434, 1.1792,
#          3.7343, 1.0367, 8.9772, 5.9515, 4.4517, 0.9763, 1.4819, 1.1534, 4.4883,
#          1.1052, 8.8088, 0.0000, 4.6106, 0.0000, 6.8512, 1.2237, 2.9956, 2.0389,
#          1.3120, 5.9533, 2.7267, 0.0000, 7.9396, 1.0897, 4.5180, 1.9741, 1.2961,
#          7.6921, 4.4201, 0.0000, 1.9843, 1.1483, 3.2956, 2.0451, 0.0000, 7.7168,
#          7.6961, 0.0000, 3.9867, 1.0441, 7.0972, 2.0469, 0.0000, 8.2346, 5.1213,
#          0.0000, 0.9523, 1.1139, 6.0269, 1.0611, 8.7598, 0.0000, 2.8716, 0.0000,
#          6.7831, 1.0409, 4.8292, 1.0522, 8.0944, 0.0000, 2.8829, 0.0000, 8.6035,
#          1.2964, 1.9740, 1.0493, 9.0181, 2.3692, 4.4110, 0.0000, 5.8432, 1.1777,
#          3.7581, 2.0205, 0.8833, 4.8418, 4.6511, 0.0000, 1.0727, 1.1505, 4.0497,
#          1.9451, 1.3579, 5.8258, 2.7538, 1.1542, 0.0000, 1.2029, 3.1031, 2.0777,
#          0.0000, 8.6765, 7.3547, 0.9765, 1.9933, 1.2494, 3.2461, 1.0602, 8.9863,
#          6.4096, 7.7940, 0.9917, 0.8642, 1.1996, 4.5076, 1.0847, 9.1174, 0.7531,
#          8.1857, 0.0000, 6.6526, 1.2234, 4.2432, 1.0735, 8.0282, 0.0000, 4.5404,
#          0.0000, 8.1691, 1.0451, 5.0487, 1.0385, 8.0839, 0.0000, 1.9501, 0.0000,
#          2.1918, 0.9663, 6.1871, 1.0398, 8.0726, 8.8079, 3.6778, 0.0000, 5.8705,
#          1.1346, 3.2918, 1.0299, 8.1050, 8.9148, 2.6596, 0.0000, 2.0904, 1.0726,
#          4.2052, 2.0619, 1.1791, 1.7817, 4.0650, 0.0000, 6.7156, 1.0531, 5.3684,
#          1.0262, 9.0119, 3.7445, 1.8102, 0.0000, 5.1477, 1.1497, 3.8525, 1.8588,
#          0.0000, 0.0000, 1.8540, 0.0000, 7.4796, 0.9219, 8.0868, 1.9397, 1.5446,
#          1.7559, 6.5842, 1.1114, 0.0000, 1.1453, 4.4964, 1.0295, 8.1135, 5.0197,
#          2.8695, 0.0000, 7.8861, 1.0756, 4.7074, 2.0347, 0.0000, 4.0624, 1.2037,
#          0.0000, 4.8473, 1.1743, 4.0278], grad_fn=<ReshapeAliasBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
yHat_test1, yy1
# Out:
# (tensor([[1.0646, 8.0822, 0.8038, 4.1707, 0.0000, 5.5140, 1.0445, 5.3280]]),
#  tensor([[1., 8., 1., 6., 0., 6., 0., 1.]]))

# %%
yy1
# Out:
# tensor([[1., 8., 1., 6., 0., 6., 0., 1.]])

# %%
(yHat_test1).round()
# Out:
# tensor([[1., 8., 1., 4., 0., 6., 1., 5.]])

# %%
(yHat1.flatten()).round(), (y1.flatten()).round()
# Out:
# (tensor([2., 1., 8., 6., 0., 3., 1., 6., 2., 0., 8., 9., 0., 2., 1., 4., 2., 0.,
#          5., 9., 0., 3., 1., 8., 2., 1., 4., 5., 0., 7., 1., 4., 2., 1., 9., 6.,
#          0., 8., 1., 4., 1., 9., 4., 6., 1., 1., 1., 4., 1., 8., 0., 2., 0., 3.,
#          1., 6., 2., 0., 8., 2., 1., 1., 1., 4., 1., 9., 6., 4., 1., 1., 1., 4.,
#          1., 9., 0., 5., 0., 7., 1., 3., 2., 1., 6., 3., 0., 8., 1., 5., 2., 1.,
#          8., 4., 0., 2., 1., 3., 2., 0., 8., 8., 0., 4., 1., 7., 2., 0., 8., 5.,
#          0., 1., 1., 6., 1., 9., 0., 3., 0., 7., 1., 5., 1., 8., 0., 3., 0., 9.,
#          1., 2., 1., 9., 2., 4., 0., 6., 1., 4., 2., 1., 5., 5., 0., 1., 1., 4.,
#          2., 1., 6., 3., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 1., 3., 1., 9.,
#          6., 8., 1., 1., 1., 5., 1., 9., 1., 8., 0., 7., 1., 4., 1., 8., 0., 5.,
#          0., 8., 1., 5., 1., 8., 0., 2., 0., 2., 1., 6., 1., 8., 9., 4., 0., 6.,
#          1., 3., 1., 8., 9., 3., 0., 2., 1., 4., 2., 1., 2., 4., 0., 7., 1., 5.,
#          1., 9., 4., 2., 0., 5., 1., 4., 2., 0., 0., 2., 0., 7., 1., 8., 2., 2.,
#          2., 7., 1., 0., 1., 4., 1., 8., 5., 3., 0., 8., 1., 5., 2., 0., 4., 1.,
#          0., 5., 1., 4.], grad_fn=<RoundBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
print_score(X.shape, yHat1, y1, yHat_test1, yy1)
# Out:
# Adjusted R-Squared(y, yHat): 0.6852
#
#
# mean_absolute_error(y, yHat): 0.6238
#
# mean_absolute_error(yy, yHat_test): 1.0038
#
#
# mean_squared_error(y, yHat): 1.4663
#
# mean_squared_error(yy, yHat_test): 2.9318
#
#
# mean_squared_log_error(y, yHat): 0.1290
#
# mean_squared_log_error(yy, yHat_test): 0.2434
#
#
# RMSE(y, yHat): 1.2109
#
# RMSE(yy, yHat_test): 1.7122

# %%
# create a 1D smoothing filter
def smooth(x, k=15):
    return np.convolve(x, np.ones(k)/k, mode='same')

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Train loss')
ax[0].legend()



ax[1].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Test loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss1.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc1, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat1.detach().T, y1.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc1.jpg", bbox_inches='tight')


plt.show()

# %%
data.leap_year.value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
resampler = SMOTE(k_neighbors=20, random_state=0)

# %%
X_res, y_res = resampler.fit_resample(data[['day_code', 'month_code', 'decade', 'date_int']], data['leap_year'])

# %%
y_res.value_counts()
# Out:
# 0    110960
# 1    110960
# Name: leap_year, dtype: int64

# %%
data['leap_year'].value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 221915    1
# 221916    1
# 221917    1
# 221918    1
# 221919    1
# Name: leap_year, Length: 221920, dtype: int64

# %%
X_res
# Out:
#         day_code  month_code  decade  date_int
# 0              4           0     180  18000101
# 1              5           0     180  18010101
# 2              6           0     180  18020101
# 3              0           0     180  18030101
# 4              1           0     180  18040101
# ...          ...         ...     ...       ...
# 221915         0           5     188  18880618
# 221916         2           6     188  18840705
# 221917         5           2     218  21800323
# 221918         1           5     199  19960602
# 221919         1           4     219  21960520
#
# [221920 rows x 4 columns]

# %%
X_smote = X_res.assign(leap_year=y_res)

# %%
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221915         0           5     188  18880618          1
# 221916         2           6     188  18840705          1
# 221917         5           2     218  21800323          1
# 221918         1           5     199  19960602          1
# 221919         1           4     219  21960520          1
#
# [221920 rows x 5 columns]

# %% [markdown]
# Drop 220 decade

# %%
# data.decade.value_counts().plot(kind="bar")
X_smote.decade.value_counts().plot(kind="bar")

# %%
# data.decade.value_counts()[-5:]
X_smote.decade.value_counts()[-5:]
# Out:
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# 220     365
# Name: decade, dtype: int64

# %%
X_smote = X_smote.drop(X_smote.index[X_smote['decade'] == 220]).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221550         0           5     188  18880618          1
# 221551         2           6     188  18840705          1
# 221552         5           2     218  21800323          1
# 221553         1           5     199  19960602          1
# 221554         1           4     219  21960520          1
#
# [221555 rows x 5 columns]

# %%
X_smote.decade.value_counts().plot(kind="bar")

# %%
X_smote.decade.value_counts()[-5:]
# Out:
# 209    5174
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# Name: decade, dtype: int64

# %% [markdown]
# code is required to only work for dates in the range  [ 1-1-1800 to 31-12-2200 ]

# %%
X_smote.date_int.max()
# Out:
# 21991231

# %%
datetime.datetime.strptime(str(X_smote.date_int.max()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '31-12-2199'

# %%
X_smote.date_int.min()
# Out:
# 18000101

# %%
datetime.datetime.strptime(str(X_smote.date_int.min()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '01-01-1800'

# %%
Y_smote = X_smote['date_int']
Y_smote
# Out:
# 0         18000101
# 1         18010101
# 2         18020101
# 3         18030101
# 4         18040101
#             ...
# 221550    18880618
# 221551    18840705
# 221552    21800323
# 221553    19960602
# 221554    21960520
# Name: date_int, Length: 221555, dtype: int64

# %%
X_smote = X_smote.drop('date_int', axis=1).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  leap_year
# 0              4           0     180          0
# 1              5           0     180          0
# 2              6           0     180          0
# 3              0           0     180          0
# 4              1           0     180          1
# ...          ...         ...     ...        ...
# 221550         0           5     188          1
# 221551         2           6     188          1
# 221552         5           2     218          1
# 221553         1           5     199          1
# 221554         1           4     219          1
#
# [221555 rows x 4 columns]

# %%
Y_smote = Y_smote.reset_index(drop=True)

ls = []

for s in Y_smote.astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(Y_smote)), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y_smote = ll.values

Y_smote
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
# data.index[data['leap_year'] == 1].tolist()
# data.index[data['leap_year'] == 1]

# %%
# for i,idx in enumerate(data['leap_year'].tolist()):
#     print(i, idx)

# %% [markdown]
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1 <---
# 5 0
# 6 0
# 7 0
# 8 1 <---
# 9 0
# 10 0
# 11 0
# 12 1 <---
# 13 0
# 14 0
# 15 0
# 16 1 <---
# 17 0
# 18 0
# 19 0
# 20 1 <---
# 21 0
# 22 0
# 23 0
# 24 1 <---
# 25 0
# 26 0
# 27 0
# 28 1 <---
# 29 0
# 30 0

# %%
scaler_day_smote = RobustScaler()

x = X_smote.day_code.values.reshape(-1, 1)

X_smote['day_scaled'] = scaler_day_smote.fit_transform(x).flatten()

# %%
X_smote['day_sin'] = np.sin(X_smote['day_code'] * (2 * np.pi / 7))
X_smote['day_cos'] = np.cos(X_smote['day_code'] * (2 * np.pi / 7))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos
# 0      -0.900969
# 1      -0.222521
# 2       0.623490
# 3       1.000000
# 4       0.623490
# ...          ...
# 221550  1.000000
# 221551 -0.222521
# 221552 -0.222521
# 221553  0.623490
# 221554  0.623490
#
# [221555 rows x 7 columns]

# %%
scaler_month_smote = RobustScaler()

x = X_smote.month_code.values.reshape(-1, 1)

X_smote['month_scaled'] = scaler_month_smote.fit_transform(x).flatten()

# %%
X_smote['month_sin'] = np.sin(X_smote['month_code'] * (2 * np.pi / 12))
X_smote['month_cos'] = np.cos(X_smote['month_code'] * (2 * np.pi / 12))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos
# 0      -0.900969     -1.000000  0.000000e+00   1.000000
# 1      -0.222521     -1.000000  0.000000e+00   1.000000
# 2       0.623490     -1.000000  0.000000e+00   1.000000
# 3       1.000000     -1.000000  0.000000e+00   1.000000
# 4       0.623490     -1.000000  0.000000e+00   1.000000
# ...          ...           ...           ...        ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000
#
# [221555 rows x 10 columns]

# %%
scaler_decade_smote = RobustScaler()

x = X_smote.decade.values.reshape(-1, 1)

X_smote['decade_scaled'] = scaler_decade_smote.fit_transform(x).flatten()

# %%
# alpha_smote = len(X_smote.decade.unique())
alpha_smote = (X_smote.decade.iloc[-1] - X_smote.decade.iloc[0]) + 1

X_smote['decade_sin'] = np.sin(X_smote['decade'] * (2 * np.pi / alpha_smote))
X_smote['decade_cos'] = np.cos(X_smote['decade'] * (2 * np.pi / alpha_smote))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos  decade_scaled  \
# 0      -0.900969     -1.000000  0.000000e+00   1.000000      -1.052632
# 1      -0.222521     -1.000000  0.000000e+00   1.000000      -1.052632
# 2       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# 3       1.000000     -1.000000  0.000000e+00   1.000000      -1.052632
# 4       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# ...          ...           ...           ...        ...            ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025      -0.631579
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000      -0.631579
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000       0.947368
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025      -0.052632
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000       1.000000
#
#           decade_sin  decade_cos
# 0       1.102182e-15   -1.000000
# 1       1.102182e-15   -1.000000
# 2       1.102182e-15   -1.000000
# 3       1.102182e-15   -1.000000
# 4       1.102182e-15   -1.000000
# ...              ...         ...
# 221550 -9.510565e-01   -0.309017
# 221551 -9.510565e-01   -0.309017
# 221552  3.090170e-01   -0.951057
# 221553 -1.564345e-01    0.987688
# 221554  1.564345e-01   -0.987688
#
# [221555 rows x 13 columns]

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
X = X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 3.33333333e-01, -4.33883739e-01, -9.00968868e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 1.00000000e+00, -7.81831482e-01,  6.23489802e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        ...,
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#          9.47368421e-01,  3.09016994e-01, -9.51056516e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#         -5.26315789e-02, -1.56434465e-01,  9.87688341e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#          1.00000000e+00,  1.56434465e-01, -9.87688341e-01]])

# %%
X.shape
# Out:
# (221555, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()
# Y = data['date_normalized'].values.reshape(-1, 1)
Y = Y_smote


Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
Y.shape
# Out:
# (221555, 8)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64

train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (221555, 10)
#
# Y: (221555, 8)
#
# Train data:   (155088, 10)
#
# Train labels: (155088, 8)
#
# Test data:    (66467, 10)
#
# Test labels:  (66467, 8)

# %%
model_smote = Model().to(device)


# checkpoint = torch.load('checkpoint.pth.tar', map_location=torch.device('cpu'))
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])

# %%
numepochs = 120
# numepochs = 300
# numepochs = 500



trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model_smote, numepochs)
# Out:
# Epoch 1/120, Train Loss: 2.030803, Test Loss: 4.566076
# Epoch 2/120, Train Loss: 1.928650, Test Loss: 4.132753
# Epoch 3/120, Train Loss: 1.920810, Test Loss: 4.104535
# Epoch 4/120, Train Loss: 1.899002, Test Loss: 4.035106
# Epoch 5/120, Train Loss: 1.915750, Test Loss: 4.001500
# Epoch 6/120, Train Loss: 1.912858, Test Loss: 3.962472
# Epoch 7/120, Train Loss: 1.919810, Test Loss: 4.001203
# Epoch 8/120, Train Loss: 1.895635, Test Loss: 4.063961
# Epoch 9/120, Train Loss: 1.913962, Test Loss: 4.096409
# Epoch 10/120, Train Loss: 1.910111, Test Loss: 4.244309
# Epoch 11/120, Train Loss: 1.900544, Test Loss: 4.249809
# Epoch 12/120, Train Loss: 1.904951, Test Loss: 4.275436
# Epoch 13/120, Train Loss: 1.893090, Test Loss: 4.284489
# Epoch 14/120, Train Loss: 1.914473, Test Loss: 4.297169
# Epoch 15/120, Train Loss: 1.918617, Test Loss: 4.313251
# Epoch 16/120, Train Loss: 1.933944, Test Loss: 4.307733
# Epoch 17/120, Train Loss: 2.615611, Test Loss: 4.288871
# Epoch 18/120, Train Loss: 1.909159, Test Loss: 4.235250
# Epoch 19/120, Train Loss: 1.922262, Test Loss: 4.408545
# Epoch 20/120, Train Loss: 1.925303, Test Loss: 4.283201
# Epoch 21/120, Train Loss: 1.941775, Test Loss: 4.333419
# Epoch 22/120, Train Loss: 1.945390, Test Loss: 4.368124
# Epoch 23/120, Train Loss: 1.920535, Test Loss: 4.274348
# Epoch 24/120, Train Loss: 1.925263, Test Loss: 4.116759
# Epoch 25/120, Train Loss: 1.931932, Test Loss: 4.424178
# Epoch 26/120, Train Loss: 1.933099, Test Loss: 4.250548
# Epoch 27/120, Train Loss: 1.945976, Test Loss: 4.225284
# Epoch 28/120, Train Loss: 1.943356, Test Loss: 4.287263
# Epoch 29/120, Train Loss: 1.969199, Test Loss: 4.340405
# Epoch 30/120, Train Loss: 1.959137, Test Loss: 4.478589
# Epoch 31/120, Train Loss: 1.985093, Test Loss: 4.027175
# Epoch 32/120, Train Loss: 1.932861, Test Loss: 3.969628
# Epoch 33/120, Train Loss: 1.965210, Test Loss: 4.187287
# Epoch 34/120, Train Loss: 1.974522, Test Loss: 4.249546
# Epoch 35/120, Train Loss: 2.003179, Test Loss: 4.117933
# Epoch 36/120, Train Loss: 1.974198, Test Loss: 4.373898
# Epoch 37/120, Train Loss: 2.025450, Test Loss: 4.372254
# Epoch 38/120, Train Loss: 2.020318, Test Loss: 4.884431
# Epoch 39/120, Train Loss: 1.988653, Test Loss: 4.968543
# Epoch 40/120, Train Loss: 1.976842, Test Loss: 4.313875
# Epoch 41/120, Train Loss: 1.976306, Test Loss: 4.787267
# Epoch 42/120, Train Loss: 1.995016, Test Loss: 5.084841
# Epoch 43/120, Train Loss: 2.007817, Test Loss: 5.248707
# Epoch 44/120, Train Loss: 2.024817, Test Loss: 5.237102
# Epoch 45/120, Train Loss: 1.979899, Test Loss: 4.762539
# Epoch 46/120, Train Loss: 2.037577, Test Loss: 4.951068
# Epoch 47/120, Train Loss: 2.036714, Test Loss: 4.610165
# Epoch 48/120, Train Loss: 1.883097, Test Loss: 4.737435
# Epoch 49/120, Train Loss: 1.965662, Test Loss: 5.295527
# Epoch 50/120, Train Loss: 1.920418, Test Loss: 4.723083
# Epoch 51/120, Train Loss: 1.884652, Test Loss: 5.071997
# Epoch 52/120, Train Loss: 1.824604, Test Loss: 5.555348
# Epoch 53/120, Train Loss: 1.883903, Test Loss: 5.884837
# Epoch 54/120, Train Loss: 1.834742, Test Loss: 5.214683
# Epoch 55/120, Train Loss: 1.755274, Test Loss: 5.485937
# Epoch 56/120, Train Loss: 1.812046, Test Loss: 5.417087
# Epoch 57/120, Train Loss: 1.831627, Test Loss: 6.419384
# Epoch 58/120, Train Loss: 1.697676, Test Loss: 5.882163
# Epoch 59/120, Train Loss: 1.849409, Test Loss: 6.152116
# Epoch 60/120, Train Loss: 1.746203, Test Loss: 6.071597
# Epoch 61/120, Train Loss: 1.798153, Test Loss: 4.839522
# Epoch 62/120, Train Loss: 1.775203, Test Loss: 6.953559
# Epoch 63/120, Train Loss: 1.731414, Test Loss: 6.686386
# Epoch 64/120, Train Loss: 1.756522, Test Loss: 6.714366
# Epoch 65/120, Train Loss: 1.791052, Test Loss: 5.414378
# Epoch 66/120, Train Loss: 1.845752, Test Loss: 7.068822
# Epoch 67/120, Train Loss: 1.789367, Test Loss: 7.513842
# Epoch 68/120, Train Loss: 1.740305, Test Loss: 6.957029
# Epoch 69/120, Train Loss: 1.750197, Test Loss: 6.613882
# Epoch 70/120, Train Loss: 1.750291, Test Loss: 4.854052
# Epoch 71/120, Train Loss: 1.828418, Test Loss: 5.721222
# Epoch 72/120, Train Loss: 1.698950, Test Loss: 4.740686
# Epoch 73/120, Train Loss: 1.722588, Test Loss: 5.285481
# Epoch 74/120, Train Loss: 1.777459, Test Loss: 4.189988
# Epoch 75/120, Train Loss: 1.706037, Test Loss: 5.048309
# Epoch 76/120, Train Loss: 1.782876, Test Loss: 5.259654
# Epoch 77/120, Train Loss: 1.827242, Test Loss: 4.528431
# Epoch 78/120, Train Loss: 1.889350, Test Loss: 5.120080
# Epoch 79/120, Train Loss: 1.716401, Test Loss: 4.597986
# Epoch 80/120, Train Loss: 1.683116, Test Loss: 5.883557
# Epoch 81/120, Train Loss: 1.768304, Test Loss: 6.394103
# Epoch 82/120, Train Loss: 1.743860, Test Loss: 6.249434
# Epoch 83/120, Train Loss: 1.644678, Test Loss: 6.268561
# Epoch 84/120, Train Loss: 1.706616, Test Loss: 5.006701
# Epoch 85/120, Train Loss: 1.669802, Test Loss: 4.792871
# Epoch 86/120, Train Loss: 1.555588, Test Loss: 4.051834
# Epoch 87/120, Train Loss: 1.616448, Test Loss: 4.899072
# Epoch 88/120, Train Loss: 1.607296, Test Loss: 5.558705
# Epoch 89/120, Train Loss: 1.631531, Test Loss: 4.223793
# Epoch 90/120, Train Loss: 1.587049, Test Loss: 5.349042
# Epoch 91/120, Train Loss: 1.495594, Test Loss: 5.038499
# Epoch 92/120, Train Loss: 1.445027, Test Loss: 5.222453
# Epoch 93/120, Train Loss: 1.515417, Test Loss: 5.060293
# Epoch 94/120, Train Loss: 1.688120, Test Loss: 5.508802
# Epoch 95/120, Train Loss: 1.402205, Test Loss: 5.305499
# Epoch 96/120, Train Loss: 1.423640, Test Loss: 6.493389
# Epoch 97/120, Train Loss: 1.495316, Test Loss: 5.827761
# Epoch 98/120, Train Loss: 1.465951, Test Loss: 4.942009
# Epoch 99/120, Train Loss: 1.503040, Test Loss: 4.533199
# Epoch 100/120, Train Loss: 1.406941, Test Loss: 5.647174
# Epoch 101/120, Train Loss: 1.490355, Test Loss: 5.619536
# Epoch 102/120, Train Loss: 1.437386, Test Loss: 6.785905
# Epoch 103/120, Train Loss: 1.572276, Test Loss: 3.798803
# Epoch 104/120, Train Loss: 1.497547, Test Loss: 4.770673
# Epoch 105/120, Train Loss: 1.300773, Test Loss: 5.074470
# Epoch 106/120, Train Loss: 1.330353, Test Loss: 5.524089
# Epoch 107/120, Train Loss: 1.562838, Test Loss: 5.869600
# Epoch 108/120, Train Loss: 1.379889, Test Loss: 4.640996
# Epoch 109/120, Train Loss: 1.347551, Test Loss: 6.389854
# Epoch 110/120, Train Loss: 1.396670, Test Loss: 5.767307
# Epoch 111/120, Train Loss: 1.491402, Test Loss: 7.041358
# Epoch 112/120, Train Loss: 1.470969, Test Loss: 4.581773
# Epoch 113/120, Train Loss: 1.376022, Test Loss: 4.107967
# Epoch 114/120, Train Loss: 1.445522, Test Loss: 4.853033
# Epoch 115/120, Train Loss: 1.365836, Test Loss: 4.610156
# Epoch 116/120, Train Loss: 1.292179, Test Loss: 5.013975
# Epoch 117/120, Train Loss: 1.269512, Test Loss: 4.471116
# Epoch 118/120, Train Loss: 1.373164, Test Loss: 4.965464
# Epoch 119/120, Train Loss: 1.276848, Test Loss: 4.188401
# Epoch 120/120, Train Loss: 1.334535, Test Loss: 4.781596

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([2.5021, 2.2340, 2.2151, 2.1880, 2.1824, 2.1802, 2.1726, 2.1709, 2.1663,
#          2.1612, 2.1593, 2.1532, 2.1528, 2.1490, 2.1485, 2.1504, 2.1457, 2.1470,
#          2.1423, 2.1423, 2.1417, 2.1416, 2.1401, 2.1413, 2.1393, 2.1374, 2.1369,
#          2.1352, 2.1345, 2.1337, 2.1316, 2.1308, 2.1274, 2.1268, 2.1228, 2.1201,
#          2.1179, 2.1151, 2.1110, 2.1071, 2.1028, 2.0984, 2.0935, 2.0871, 2.0823,
#          2.0770, 2.0704, 2.0651, 2.0589, 2.0535, 2.0469, 2.0391, 2.0318, 2.0274,
#          2.0191, 2.0118, 2.0073, 1.9986, 1.9921, 1.9861, 1.9773, 1.9702, 1.9623,
#          1.9547, 1.9462, 1.9396, 1.9314, 1.9238, 1.9195, 1.9108, 1.9016, 1.8968,
#          1.8877, 1.8812, 1.8734, 1.8655, 1.8574, 1.8499, 1.8465, 1.8357, 1.8312,
#          1.8243, 1.8153, 1.8095, 1.8023, 1.7964, 1.7906, 1.7847, 1.7775, 1.7716,
#          1.7650, 1.7592, 1.7528, 1.7453, 1.7392, 1.7349, 1.7280, 1.7224, 1.7162,
#          1.7114, 1.7038, 1.6983, 1.6925, 1.6880, 1.6820, 1.6745, 1.6710, 1.6632,
#          1.6587, 1.6535, 1.6460, 1.6433, 1.6358, 1.6333, 1.6276, 1.6234, 1.6185,
#          1.6120, 1.6069, 1.6042]),
#  tensor([4.5661, 4.1328, 4.1045, 4.0351, 4.0015, 3.9625, 4.0012, 4.0640, 4.0964,
#          4.2443, 4.2498, 4.2754, 4.2845, 4.2972, 4.3133, 4.3077, 4.2889, 4.2352,
#          4.4085, 4.2832, 4.3334, 4.3681, 4.2743, 4.1168, 4.4242, 4.2505, 4.2253,
#          4.2873, 4.3404, 4.4786, 4.0272, 3.9696, 4.1873, 4.2495, 4.1179, 4.3739,
#          4.3723, 4.8844, 4.9685, 4.3139, 4.7873, 5.0848, 5.2487, 5.2371, 4.7625,
#          4.9511, 4.6102, 4.7374, 5.2955, 4.7231, 5.0720, 5.5553, 5.8848, 5.2147,
#          5.4859, 5.4171, 6.4194, 5.8822, 6.1521, 6.0716, 4.8395, 6.9536, 6.6864,
#          6.7144, 5.4144, 7.0688, 7.5138, 6.9570, 6.6139, 4.8541, 5.7212, 4.7407,
#          5.2855, 4.1900, 5.0483, 5.2597, 4.5284, 5.1201, 4.5980, 5.8836, 6.3941,
#          6.2494, 6.2686, 5.0067, 4.7929, 4.0518, 4.8991, 5.5587, 4.2238, 5.3490,
#          5.0385, 5.2225, 5.0603, 5.5088, 5.3055, 6.4934, 5.8278, 4.9420, 4.5332,
#          5.6472, 5.6195, 6.7859, 3.7988, 4.7707, 5.0745, 5.5241, 5.8696, 4.6410,
#          6.3899, 5.7673, 7.0414, 4.5818, 4.1080, 4.8530, 4.6102, 5.0140, 4.4711,
#          4.9655, 4.1884, 4.7816]),
#  tensor([0.3891, 0.4297, 0.4326, 0.4366, 0.4376, 0.4382, 0.4392, 0.4392, 0.4398,
#          0.4403, 0.4405, 0.4413, 0.4413, 0.4419, 0.4420, 0.4403, 0.4415, 0.4419,
#          0.4426, 0.4425, 0.4425, 0.4425, 0.4428, 0.4426, 0.4428, 0.4430, 0.4430,
#          0.4431, 0.4432, 0.4432, 0.4436, 0.4436, 0.4439, 0.4440, 0.4445, 0.4447,
#          0.4449, 0.4452, 0.4457, 0.4462, 0.4466, 0.4470, 0.4475, 0.4481, 0.4486,
#          0.4491, 0.4498, 0.4504, 0.4510, 0.4514, 0.4522, 0.4529, 0.4537, 0.4542,
#          0.4552, 0.4560, 0.4566, 0.4577, 0.4584, 0.4592, 0.4603, 0.4612, 0.4623,
#          0.4632, 0.4643, 0.4652, 0.4663, 0.4672, 0.4678, 0.4689, 0.4700, 0.4707,
#          0.4720, 0.4728, 0.4739, 0.4748, 0.4760, 0.4769, 0.4773, 0.4787, 0.4793,
#          0.4801, 0.4813, 0.4820, 0.4830, 0.4837, 0.4845, 0.4853, 0.4862, 0.4870,
#          0.4879, 0.4886, 0.4895, 0.4904, 0.4912, 0.4918, 0.4927, 0.4934, 0.4942,
#          0.4948, 0.4958, 0.4966, 0.4974, 0.4979, 0.4988, 0.4997, 0.5002, 0.5011,
#          0.5018, 0.5024, 0.5034, 0.5038, 0.5048, 0.5051, 0.5058, 0.5063, 0.5069,
#          0.5078, 0.5084, 0.5088]))

# %%
# (yy * data['date_int'].max()).round()

# %%
# (yHat_test * data['date_int'].max()).round()

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.5342
#
#
# mean_absolute_error(y, yHat): 0.5938
#
# mean_absolute_error(yy, yHat_test): 1.2024
#
#
# mean_squared_error(y, yHat): 1.3345
#
# mean_squared_error(yy, yHat_test): 4.7816
#
#
# mean_squared_log_error(y, yHat): 0.0883
#
# mean_squared_log_error(yy, yHat_test): 0.4565
#
#
# RMSE(y, yHat): 1.1552
#
# RMSE(yy, yHat_test): 2.1867

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Train loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Test loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss2.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.detach().T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc2.jpg", bbox_inches='tight')


plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2691: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.7/dist-packages/numpy/lib/function_base.py:2692: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']
# Out:
# ['day_scaled',
#  'day_sin',
#  'day_cos',
#  'month_scaled',
#  'month_sin',
#  'month_cos',
#  'leap_year',
#  'decade_scaled',
#  'decade_sin',
#  'decade_cos']

# %%
def result_to_date(result):
    
    result = str(result)
    
    day   = int(result[6:]) - 1
    month = int(result[4:6]) - 1

    ss = str(f'{result[:4]}0101')
    
    ds = datetime.datetime.strptime(ss, '%Y%m%d')
    
    ds = ds + relativedelta(months=month, days=day)

    result = ds.strftime('%d-%m-%Y')
    
    
    return result

# %%
# (16830739, 17848869)
result_to_date(16830739), result_to_date(17848869)
# Out:
# ('08-08-1683', '08-06-1791')

# %%
def test_model(input_list):
    

    X       = np.zeros((1, 10))
    X_smote = np.zeros((1, 10))



    day       = np.array(map_day[input_list[0]])
    month     = np.array(map_month[input_list[1]])
    leap_year = map_leap_year[input_list[2]]
    decade    = np.array(input_list[3].strip('[]')).astype('int64')


    X[0, 0] = scaler_day.transform(day.reshape(-1, 1)).flatten()
    X[0, 1] = np.sin(day * (2 * np.pi / 7))
    X[0, 2] = np.cos(day * (2 * np.pi / 7))

    X[0, 3] = scaler_month.transform(month.reshape(-1, 1)).flatten()
    X[0, 4] = np.sin(month * (2 * np.pi / 12))
    X[0, 5] = np.cos(month * (2 * np.pi / 12))

    X[0, 6] = leap_year

    X[0, 7] = scaler_decade.transform(decade.reshape(-1, 1)).flatten()
    X[0, 8] = np.sin(decade * (2 * np.pi / alpha))
    X[0, 9] = np.cos(decade * (2 * np.pi / alpha))

    # ---

    X_smote[0, 0] = scaler_day_smote.transform(day.reshape(-1, 1)).flatten()
    X_smote[0, 1] = X[0, 1]
    X_smote[0, 2] = X[0, 2]

    X_smote[0, 3] = scaler_month_smote.transform(month.reshape(-1, 1)).flatten()
    X_smote[0, 4] = X[0, 4]
    X_smote[0, 5] = X[0, 5]

    X_smote[0, 6] = leap_year

    X_smote[0, 7] = scaler_decade_smote.transform(decade.reshape(-1, 1)).flatten()
    X_smote[0, 8] = np.sin(decade * (2 * np.pi / alpha_smote))
    X_smote[0, 9] = np.cos(decade * (2 * np.pi / alpha_smote))



    flag = [model.training, model_smote.training]

    # ---

    model.eval()
    model_smote.eval()


    result       = model(torch.tensor(X).to(device).float())
    result_smote = model_smote(torch.tensor(X_smote).to(device).float())



    # if all(flag):
    #   model.train()
    #   model_smote.train()


    if flag[0]:
      model.train()

    if flag[1]:
      model_smote.train()


    # ---


    result       = ''.join(result.detach().cpu().numpy().round().astype(int).astype(str).flatten())
    result_smote = ''.join(result_smote.detach().cpu().numpy().round().astype(int).astype(str).flatten())

    
    
    return result_to_date(result), result_to_date(result_smote)

# %%
input_test1 = ['[MON]', '[DEC]', '[False]', '[196]']
output_test1 = '3-12-1962'

input_test2 = ['[THU]', '[DEC]', '[True]', '[204]']
output_test2 = '3-12-2048'

input_test3 = ['[WED]', '[JAN]', '[False]', '[181]']
output_test3 = '10-1-1810'


input_test4 = ['[WED]', '[JUN]', '[False]', '[209]']

# %%
test_model(input_test1), test_model(input_test2), test_model(input_test3), test_model(input_test4)
# Out:
# (('15-12-1965', '14-02-1964'),
#  ('15-12-2047', '15-02-2046'),
#  ('14-01-1816', '14-01-1813'),
#  ('15-06-2087', '13-06-2095'))

# %%
output_test1, output_test2, output_test3
# Out:
# ('3-12-1962', '3-12-2048', '10-1-1810')

# %%
# example_input = pd.read_csv('./data/example_input.txt', sep=' ', header=None)
example_input = pd.read_csv('example_input.txt', sep=' ', header=None)


example_input.columns = ['day', 'month', 'leap_year', 'decade']

# %%
example_input
# Out:
#         day  month leap_year decade
# 0     [WED]  [JAN]   [False]  [180]
# 1     [MON]  [JAN]   [False]  [190]
# 2     [SAT]  [JAN]    [True]  [200]
# 3     [FRI]  [JAN]   [False]  [210]
# 4     [WED]  [JAN]   [False]  [220]
# ...     ...    ...       ...    ...
# 1460  [MON]  [OCT]    [True]  [214]
# 1461  [TUE]  [DEC]   [False]  [183]
# 1462  [SUN]  [DEC]   [False]  [193]
# 1463  [SAT]  [DEC]   [False]  [203]
# 1464  [THU]  [DEC]   [False]  [213]
#
# [1465 rows x 4 columns]

# %%
R       = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result'])
R_smote = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result_smote'])

# %%
example_input.iloc[0].tolist()
# Out:
# ['[WED]', '[JAN]', '[False]', '[180]']

# %%
for i in range(len(example_input)):
    R.iloc[i], R_smote.iloc[i] = test_model(example_input.iloc[i].tolist())

# %%
R
# Out:
#           result
# 0     14-01-1806
# 1     15-01-1904
# 2     15-01-2008
# 3     15-01-2102
# 4     14-01-2400
# ...          ...
# 1460  14-10-2143
# 1461  15-12-1836
# 1462  15-12-1934
# 1463  15-12-2035
# 1464  15-12-2136
#
# [1465 rows x 1 columns]

# %%
final = pd.concat([example_input, R], axis=1)
final
# Out:
#         day  month leap_year decade      result
# 0     [WED]  [JAN]   [False]  [180]  14-01-1806
# 1     [MON]  [JAN]   [False]  [190]  15-01-1904
# 2     [SAT]  [JAN]    [True]  [200]  15-01-2008
# 3     [FRI]  [JAN]   [False]  [210]  15-01-2102
# 4     [WED]  [JAN]   [False]  [220]  14-01-2400
# ...     ...    ...       ...    ...         ...
# 1460  [MON]  [OCT]    [True]  [214]  14-10-2143
# 1461  [TUE]  [DEC]   [False]  [183]  15-12-1836
# 1462  [SUN]  [DEC]   [False]  [193]  15-12-1934
# 1463  [SAT]  [DEC]   [False]  [203]  15-12-2035
# 1464  [THU]  [DEC]   [False]  [213]  15-12-2136
#
# [1465 rows x 5 columns]

# %%
final_smote = pd.concat([example_input, R_smote], axis=1)
final_smote
# Out:
#         day  month leap_year decade result_smote
# 0     [WED]  [JAN]   [False]  [180]   15-01-1805
# 1     [MON]  [JAN]   [False]  [190]   15-01-1903
# 2     [SAT]  [JAN]    [True]  [200]   13-01-2003
# 3     [FRI]  [JAN]   [False]  [210]   16-01-2103
# 4     [WED]  [JAN]   [False]  [220]   15-01-2196
# ...     ...    ...       ...    ...          ...
# 1460  [MON]  [OCT]    [True]  [214]   15-12-2144
# 1461  [TUE]  [DEC]   [False]  [183]   15-02-1834
# 1462  [SUN]  [DEC]   [False]  [193]   15-02-1933
# 1463  [SAT]  [DEC]   [False]  [203]   14-02-2036
# 1464  [THU]  [DEC]   [False]  [213]   15-02-2134
#
# [1465 rows x 5 columns]

# %%
final.to_csv('output_file.txt', sep=' ', header=None, index=False)

# %%
final_smote.to_csv('output_file_smote.txt', sep=' ', header=None, index=False)

# %% [markdown]
# Out-liers

# %% [markdown]
# Saving

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              'scaler_day_smote' : scaler_day_smote,
              'scaler_month_smote' : scaler_month_smote,
              'scaler_decade_smote' : scaler_decade_smote,
              
              'alpha': alpha,
              'alpha_smote': alpha_smote}



torch.save(checkpoint, 'checkpoint.pth.tar')

# %%
# checkpoint = torch.load('checkpoint.pth.tar')

# %%
# model       = Model()
# model_smote = Model()


# model.load_state_dict(checkpoint['model_state_dict'])
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
