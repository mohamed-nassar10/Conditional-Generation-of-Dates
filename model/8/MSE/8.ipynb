# %%
import datetime

import copy

import random


from dateutil.relativedelta import relativedelta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('seaborn')
# plt.style.use(['dark_background', 'ggplot'])

import seaborn as sns
# sns.set()

# import scipy
# import scipy.stats as stats


# # sympy = symbolic math in Python
# import sympy as sym
# import sympy.plotting.plot as symplot


# make the equations look nicer

# from IPython.display import display
# display.set_matplotlib_formats('svg') # Deprecated since version 7.23

# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


# %config InlineBackend.set_matplotlib_formats = ["svg"]
# %config InlineBackend.figure_formats = ["svg"]

# %%
import sklearn


from sklearn.model_selection import train_test_split


# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler     # <------------ (-1.0, 1.0)
# from sklearn.preprocessing import MinMaxScaler


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from imblearn.over_sampling import SMOTE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset, DataLoader





torch.__version__
# Out:
# '1.12.0+cu113'

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def print_score(shape, yHat, y, yHat_test, yy):
    
    
    n, p = shape
    
    R2 = r2_score(y.detach().numpy(), yHat.detach().numpy())
    
    Adj_r2 = 1 - (1 - R2)  *  (n - 1) / (n - p - 1)
    
    print(f'Adjusted R-Squared(y, yHat): {Adj_r2:0.4f}\n\n')
    # r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
    #  R^2 score is not well-defined with less than two samples
    
    
    print(f'mean_absolute_error(y, yHat):',
          f'{mean_absolute_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_absolute_error(yy, yHat_test):',
          f'{mean_absolute_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_error(y, yHat):',
          f'{mean_squared_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_error(yy, yHat_test):',
          f'{mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_log_error(y, yHat):',
          f'{mean_squared_log_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_log_error(yy, yHat_test):',
          f'{mean_squared_log_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    
    print(f'RMSE(y, yHat):',
          f'{np.sqrt( mean_squared_error(y.detach().numpy(), yHat.detach().numpy()) ):0.4f}\n')
    print(f'RMSE(yy, yHat_test):',
          f'{np.sqrt( mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()) ):0.4f}\n\n')

# %%
# date = np.datetime64("2000-01-01")
# date_strings = date.astype(str).split('-'). 
# # >> ['2000', '01', '01']

# year_int = int(date_strings[0])

# %%
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Out:
# --2022-08-05 15:56:09--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5230713 (5.0M) [text/plain]
# Saving to: ‘data.txt’
#
# data.txt            100%[===================>]   4.99M  --.-KB/s    in 0.02s
#
# 2022-08-05 15:56:12 (300 MB/s) - ‘data.txt’ saved [5230713/5230713]
#
# --2022-08-05 15:56:12--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37732 (37K) [text/plain]
# Saving to: ‘example_input.txt’
#
# example_input.txt   100%[===================>]  36.85K  --.-KB/s    in 0s
#
# 2022-08-05 15:56:13 (125 MB/s) - ‘example_input.txt’ saved [37732/37732]

# %%
# !ls
# Out:
# data.txt  example_input.txt  sample_data

# %% [markdown]
# 'text.txt'

# %% [markdown]
# [ 1-1-1800 to 31-12-2200 ]

# %% [markdown]
# [day condition] [month condition] [leap year condition] [decade condition] date

# %% [markdown]
# [MON] [DEC] [False] [196] 3-12-1962
# [THU] [DEC] [True] [204] 3-12-2048
# [WED] [JAN] [False] [181] 10-1-1810

# %%
# data = np.loadtxt(open('text.txt','r'),delimiter=' ')
# ori = pd.read_csv('./data/data.txt', sep=' ', header=None)

ori = pd.read_csv('data.txt', sep=' ', header=None)

# %%
ori.columns = ['day', 'month', 'leap_year', 'decade', 'date']

# %%
ori
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
# data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)
# # pd.to_datetime(data.date, infer_datetime_format=False)

# %%
ori.dtypes
# Out:
# day          object
# month        object
# leap_year    object
# decade       object
# date         object
# dtype: object

# %%
# data_backup = copy.deepcopy(ori)
data = copy.deepcopy(ori)

# %%
data
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
data.date
# Out:
# 0           1-1-1800
# 1           1-1-1801
# 2           1-1-1802
# 3           1-1-1803
# 4           1-1-1804
#              ...
# 146457    31-12-2196
# 146458    31-12-2197
# 146459    31-12-2198
# 146460    31-12-2199
# 146461    31-12-2200
# Name: date, Length: 146462, dtype: object

# %%
# # data['date'] = pd.date_range('3-12-2048', periods=10)
# # data['date'] = pd.date_range('12-3-1962', periods=10)

# # 1-1-1800 to 31-12-2200
# data['date'] = pd.date_range(start='1-1-1800',end='12-31-2200')


data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)

# # data.date = data.date.dt.strftime('%d-%m-%Y')
# # data.date = pd.to_datetime(data.date.dt.strftime('%d-%m-%Y'), format='%d-%m-%Y', infer_datetime_format=False)

# %%
data.dtypes
# Out:
# day                  object
# month                object
# leap_year            object
# decade               object
# date         datetime64[ns]
# dtype: object

# %%
data
# Out:
#           day  month leap_year decade       date
# 0       [WED]  [JAN]   [False]  [180] 1800-01-01
# 1       [THU]  [JAN]   [False]  [180] 1801-01-01
# 2       [FRI]  [JAN]   [False]  [180] 1802-01-01
# 3       [SAT]  [JAN]   [False]  [180] 1803-01-01
# 4       [SUN]  [JAN]    [True]  [180] 1804-01-01
# ...       ...    ...       ...    ...        ...
# 146457  [SAT]  [DEC]    [True]  [219] 2196-12-31
# 146458  [SUN]  [DEC]   [False]  [219] 2197-12-31
# 146459  [MON]  [DEC]   [False]  [219] 2198-12-31
# 146460  [TUE]  [DEC]   [False]  [219] 2199-12-31
# 146461  [WED]  [DEC]   [False]  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %%
map_leap_year = {'[False]': int(0), '[True]' : int(1)}

data.leap_year = data.leap_year.map(map_leap_year)

# data.leap_year = data.leap_year.astype(np.float64)

# %%
data
# Out:
#           day  month  leap_year decade       date
# 0       [WED]  [JAN]          0  [180] 1800-01-01
# 1       [THU]  [JAN]          0  [180] 1801-01-01
# 2       [FRI]  [JAN]          0  [180] 1802-01-01
# 3       [SAT]  [JAN]          0  [180] 1803-01-01
# 4       [SUN]  [JAN]          1  [180] 1804-01-01
# ...       ...    ...        ...    ...        ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31
# 146459  [MON]  [DEC]          0  [219] 2198-12-31
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31
# 146461  [WED]  [DEC]          0  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %% [markdown]
# date -> timestamp

# %%
data.date.iloc[0]
# Out:
# Timestamp('1800-01-01 00:00:00')

# %%
data['date_int'] = data['date'].dt.strftime("%Y%m%d").astype(np.int64)

# data['date_str'] = data['date'].dt.strftime("%Y%m%d")

# %%
# data['date_int'].map(str)
# data['date_int'].astype(str)

# %%
# date_max = data.date_int.max()
# data['date_normalized'] = data.date_int / date_max

# %%
data
# Out:
#           day  month  leap_year decade       date  date_int
# 0       [WED]  [JAN]          0  [180] 1800-01-01  18000101
# 1       [THU]  [JAN]          0  [180] 1801-01-01  18010101
# 2       [FRI]  [JAN]          0  [180] 1802-01-01  18020101
# 3       [SAT]  [JAN]          0  [180] 1803-01-01  18030101
# 4       [SUN]  [JAN]          1  [180] 1804-01-01  18040101
# ...       ...    ...        ...    ...        ...       ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31  21961231
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31  21971231
# 146459  [MON]  [DEC]          0  [219] 2198-12-31  21981231
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31  21991231
# 146461  [WED]  [DEC]          0  [220] 2200-12-31  22001231
#
# [146462 rows x 6 columns]

# %%
x = data.decade.iloc[0]
x
# Out:
# '[180]'

# %%
x.strip('[]')
# Out:
# '180'

# %%
data.decade = data.decade.apply(lambda x: x.strip('[]')).astype('int64')

# %%
# data.day = data.day.apply(lambda x: x.strip('[]'))
# data.month = data.month.apply(lambda x: x.strip('[]'))

# %%
map_day = {'[SAT]': int(0),
           '[SUN]': int(1),
           '[MON]': int(2),
           '[TUE]': int(3),
           '[WED]': int(4),
           '[THU]': int(5),
           '[FRI]': int(6)}

# %%
data['day_code'] = data.day.map(map_day)

# %%
scaler_day = RobustScaler()

x = data.day_code.values.reshape(-1, 1)

data['day_scaled'] = scaler_day.fit_transform(x).flatten()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled
# 0             0.25
# 1             0.50
# 2             0.75
# 3            -0.75
# 4            -0.50
# ...            ...
# 146457       -0.75
# 146458       -0.50
# 146459       -0.25
# 146460        0.00
# 146461        0.25
#
# [146462 rows x 8 columns]

# %%
data['day_sin'] = np.sin(data['day_code'] * (2 * np.pi / 7))
data['day_cos'] = np.cos(data['day_code'] * (2 * np.pi / 7))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos
# 0             0.25 -0.433884 -0.900969
# 1             0.50 -0.974928 -0.222521
# 2             0.75 -0.781831  0.623490
# 3            -0.75  0.000000  1.000000
# 4            -0.50  0.781831  0.623490
# ...            ...       ...       ...
# 146457       -0.75  0.000000  1.000000
# 146458       -0.50  0.781831  0.623490
# 146459       -0.25  0.974928 -0.222521
# 146460        0.00  0.433884 -0.900969
# 146461        0.25 -0.433884 -0.900969
#
# [146462 rows x 10 columns]

# %%
map_month = {'[JAN]' : 0,
             '[FEB]' : 1,
             '[MAR]' : 2,
             '[APR]' : 3,
             '[MAY]' : 4,
             '[JUN]' : 5,
             '[JUL]' : 6,
             '[AUG]' : 7,
             '[SEP]' : 8,
             '[OCT]' : 9,
             '[NOV]' : 10,
             '[DEC]' : 11}

# %%
data['month_code'] = data.month.map(map_month)

# %%
scaler_month = RobustScaler()

x = data.month_code.values.reshape(-1, 1)

data['month_scaled'] = scaler_month.fit_transform(x).flatten()

# %%
data['month_sin'] = np.sin(data['month_code'] * (2 * np.pi / 12))
data['month_cos'] = np.cos(data['month_code'] * (2 * np.pi / 12))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ...           ...
# 146457   0.866025
# 146458   0.866025
# 146459   0.866025
# 146460   0.866025
# 146461   0.866025
#
# [146462 rows x 14 columns]

# %%
scaler_decade = RobustScaler()

x = data.decade.values.reshape(-1, 1)

data['decade_scaled'] = scaler_decade.fit_transform(x).flatten()

# %%
# alpha = len(data.decade.unique())
alpha = (data.decade.iloc[-1] - data.decade.iloc[0]) + 1

data['decade_sin'] = np.sin(data['decade'] * (2 * np.pi / alpha))
data['decade_cos'] = np.cos(data['decade'] * (2 * np.pi / alpha))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %%
# data.date_normalized.min(), data.date_normalized.max()

# %%
# round(data.date_normalized.min()), round(data.date_normalized.max())

# %%
round(data.day_scaled.min()), round(data.day_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_sin.min()), round(data.day_sin.max())
# Out:
# (-1, 1)

# %%
round(data.day_cos.min()), round(data.day_cos.max())
# Out:
# (-1, 1)

# %%
round(data.month_scaled.min()), round(data.month_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.month_sin.min()), round(data.month_sin.max())
# Out:
# (-1, 1)

# %%
round(data.month_cos.min()), round(data.month_cos.max())
# Out:
# (-1, 1)

# %%
data.leap_year.min(), data.leap_year.max()
# Out:
# (0, 1)

# %%
round(data.decade_scaled.min()), round(data.decade_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.decade_sin.min()), round(data.decade_sin.max())
# Out:
# (-1, 1)

# %%
round(data.decade_cos.min()), round(data.decade_cos.max())
# Out:
# (-1, 1)

# %% [markdown]
# Boxplot

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.day.value_counts().plot(kind="bar")

# %%
data.month.value_counts().plot(kind="bar")

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
data.decade.value_counts().plot(kind="bar")

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %% [markdown]
# ['day_sin', 'day_cos', 'month_sin', 'month_cos', 'leap_year', 'decade_scaled']
# ['date_timestamp_scaled']

# %%
X = data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
          'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 0.25      , -0.43388374, -0.90096887, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.5       , -0.97492791, -0.22252093, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.75      , -0.78183148,  0.6234898 , ..., -1.        ,
#          0.63624244, -0.77148918],
#        ...,
#        [-0.25      ,  0.97492791, -0.22252093, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.        ,  0.43388374, -0.90096887, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.25      , -0.43388374, -0.90096887, ...,  1.        ,
#          0.74655322, -0.6653257 ]])

# %%
len(X)
# Out:
# 146462

# %%
X.shape
# Out:
# (146462, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()


ls = []

for s in data['date_int'].astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(data['date_int'])), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y = ll.values

Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 2, 0, ..., 2, 3, 1]])

# %%
len(Y)
# Out:
# 146462

# %%
Y.shape
# Out:
# (146462, 8)

# %%
# # leap = np.where(~X['leap_year'] == 1)[0]
# leap = np.where(X['leap_year'] == 1)[0]

# leap

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64


train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (146462, 10)
#
# Y: (146462, 8)
#
# Train data:   (102523, 10)
#
# Train labels: (102523, 8)
#
# Test data:    (43939, 10)
#
# Test labels:  (43939, 8)

# %%
102523 % 32, 102523 % 64
# Out:
# (27, 59)

# %%
class Model(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.input = nn.Linear(10, 32)

        self.fc1 = nn.Linear(32, 128)
        self.bnorm1 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 512)
        self.bnorm2 = nn.BatchNorm1d(512)

        self.fc3 = nn.Linear(512, 64)
        self.bnorm3 = nn.BatchNorm1d(64)

        self.fc4 = nn.Linear(64, 32)
        self.bnorm4 = nn.BatchNorm1d(32)


        self.output = nn.Linear(32, 8)



    def forward(self, x):


        # print(f'training={self.training}')

        x = F.relu( self.input(x) )

        x = F.relu(self.bnorm1(self.fc1(x)))
        x = F.dropout(x, p=0.25, training=self.training)

        x = F.relu(self.bnorm2(self.fc2(x)))
        x = F.dropout(x, p=0.4, training=self.training)

        x = F.relu(self.bnorm3(self.fc3(x)))
        x = F.dropout(x, p=0.1, training=self.training)

        x = F.relu(self.bnorm4(self.fc4(x)))
        x = F.dropout(x, p=0.05, training=self.training)


        x = F.relu(self.output(x))
        # x = self.output(x)
        


        return x

# %%
# test_x, test_y = next(iter(train_loader))

# print(f'X: {X.shape}\n')
# print(f'Y: {Y.shape}\n')

# %%
def train(model, numepochs):

    numepochs = numepochs

    model = model
    
    
    
    lossfun = nn.MSELoss()
    # lossfun = nn.L1Loss()


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0002, betas=(0.5, 0.999), weight_decay=1e-5)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.5, 0.999), weight_decay=1e-1)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=1e-9)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
    
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    
    
    
    trainLoss = torch.zeros(numepochs)
    testLoss  = torch.zeros(numepochs)
    trainAcc  = torch.zeros(numepochs)
    # testAcc   = torch.zeros(numepochs)


    for epochi in range(numepochs):

        model.train() # switch to train mode

        batchLoss = []
        batchAcc  = []

        for X,y in train_loader:

            X = X.to(device)
            y = y.to(device)

            yHat = model(X)
            loss = lossfun(yHat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())
            # batchAcc.append( torch.mean(( yHat == y).float() ).item() )
            # batchAcc.append( torch.mean( (torch.abs(yHat - y) < 1).float() ).item() ) # <1 for rounding
            batchAcc.append( r2_score(y.detach().cpu().numpy(), yHat.detach().cpu().numpy()) )
            




        trainLoss[epochi] = np.mean(batchLoss)
        # trainAcc[epochi]  = 100*np.mean(batchAcc)
        trainAcc[epochi]  = np.mean(batchAcc)
        



        model.eval() # switch to test mode

        XX,yy = next(iter(test_loader))

        XX = XX.to(device)
        yy = yy.to(device)

        # forward pass and loss
        with torch.no_grad():
            yHat_test = model(XX)
            loss = lossfun(yHat_test, yy)


        testLoss[epochi] = loss.item()
        # testAcc[epochi]  = 100*torch.mean( (yHat_test == yy).float() ).item()
        # testAcc[epochi]  = 100*torch.mean( (torch.abs(yHat_test - yy) < 1).float() ).item()
        # testAcc[epochi]  = 100*r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
        


        # if (epochi + 1) % 5 == 0:
        print(f'Epoch {epochi+1}/{numepochs}, Train Loss: {loss.item():0.6f}, Test Loss: {loss.item():0.6f}')


        
    return trainLoss.cpu(), testLoss.cpu(), trainAcc.cpu(), yHat.cpu(), y.cpu(), yHat_test.cpu(), yy.cpu()

# %%
model = Model().to(device)

# test_hat = model(torch.randn(32,6))
# test_hat = model(test_x)

# print(test_hat.shape)

# %%
# for p in list(model.named_parameters()):
#     if 'weight' in p[0] and 'bnorm' not in p[0]:
#         nn.init.xavier_normal_(p[1].data)
#         print(p[0])
#         print(p[1].data.shape)

# %%
numepochs = 120

trainLoss1, testLoss1, trainAcc1, yHat1, y1, yHat_test1, yy1 = train(model, numepochs)
# Out:
# Epoch 1/120, Train Loss: 2.042668, Test Loss: 2.042668
# Epoch 2/120, Train Loss: 2.016958, Test Loss: 2.016958
# Epoch 3/120, Train Loss: 2.019478, Test Loss: 2.019478
# Epoch 4/120, Train Loss: 2.019245, Test Loss: 2.019245
# Epoch 5/120, Train Loss: 1.963256, Test Loss: 1.963256
# Epoch 6/120, Train Loss: 1.989552, Test Loss: 1.989552
# Epoch 7/120, Train Loss: 1.945126, Test Loss: 1.945126
# Epoch 8/120, Train Loss: 2.013913, Test Loss: 2.013913
# Epoch 9/120, Train Loss: 1.997414, Test Loss: 1.997414
# Epoch 10/120, Train Loss: 2.132531, Test Loss: 2.132531
# Epoch 11/120, Train Loss: 1.994427, Test Loss: 1.994427
# Epoch 12/120, Train Loss: 2.020075, Test Loss: 2.020075
# Epoch 13/120, Train Loss: 2.347518, Test Loss: 2.347518
# Epoch 14/120, Train Loss: 2.020745, Test Loss: 2.020745
# Epoch 15/120, Train Loss: 2.098979, Test Loss: 2.098979
# Epoch 16/120, Train Loss: 1.987931, Test Loss: 1.987931
# Epoch 17/120, Train Loss: 1.983331, Test Loss: 1.983331
# Epoch 18/120, Train Loss: 2.123682, Test Loss: 2.123682
# Epoch 19/120, Train Loss: 1.983381, Test Loss: 1.983381
# Epoch 20/120, Train Loss: 2.024052, Test Loss: 2.024052
# Epoch 21/120, Train Loss: 2.029120, Test Loss: 2.029120
# Epoch 22/120, Train Loss: 2.057898, Test Loss: 2.057898
# Epoch 23/120, Train Loss: 2.101235, Test Loss: 2.101235
# Epoch 24/120, Train Loss: 2.041797, Test Loss: 2.041797
# Epoch 25/120, Train Loss: 2.054961, Test Loss: 2.054961
# Epoch 26/120, Train Loss: 2.093894, Test Loss: 2.093894
# Epoch 27/120, Train Loss: 2.057049, Test Loss: 2.057049
# Epoch 28/120, Train Loss: 2.081978, Test Loss: 2.081978
# Epoch 29/120, Train Loss: 2.017264, Test Loss: 2.017264
# Epoch 30/120, Train Loss: 2.018874, Test Loss: 2.018874
# Epoch 31/120, Train Loss: 2.019937, Test Loss: 2.019937
# Epoch 32/120, Train Loss: 2.045637, Test Loss: 2.045637
# Epoch 33/120, Train Loss: 2.069529, Test Loss: 2.069529
# Epoch 34/120, Train Loss: 1.994545, Test Loss: 1.994545
# Epoch 35/120, Train Loss: 2.010246, Test Loss: 2.010246
# Epoch 36/120, Train Loss: 2.005898, Test Loss: 2.005898
# Epoch 37/120, Train Loss: 2.058799, Test Loss: 2.058799
# Epoch 38/120, Train Loss: 1.979127, Test Loss: 1.979127
# Epoch 39/120, Train Loss: 2.093657, Test Loss: 2.093657
# Epoch 40/120, Train Loss: 1.980825, Test Loss: 1.980825
# Epoch 41/120, Train Loss: 2.008500, Test Loss: 2.008500
# Epoch 42/120, Train Loss: 2.057710, Test Loss: 2.057710
# Epoch 43/120, Train Loss: 1.982119, Test Loss: 1.982119
# Epoch 44/120, Train Loss: 2.028748, Test Loss: 2.028748
# Epoch 45/120, Train Loss: 1.985793, Test Loss: 1.985793
# Epoch 46/120, Train Loss: 2.036031, Test Loss: 2.036031
# Epoch 47/120, Train Loss: 2.074105, Test Loss: 2.074105
# Epoch 48/120, Train Loss: 2.077296, Test Loss: 2.077296
# Epoch 49/120, Train Loss: 1.945198, Test Loss: 1.945198
# Epoch 50/120, Train Loss: 1.918006, Test Loss: 1.918006
# Epoch 51/120, Train Loss: 2.040954, Test Loss: 2.040954
# Epoch 52/120, Train Loss: 2.008180, Test Loss: 2.008180
# Epoch 53/120, Train Loss: 2.012939, Test Loss: 2.012939
# Epoch 54/120, Train Loss: 2.030434, Test Loss: 2.030434
# Epoch 55/120, Train Loss: 2.020755, Test Loss: 2.020755
# Epoch 56/120, Train Loss: 2.100501, Test Loss: 2.100501
# Epoch 57/120, Train Loss: 1.983057, Test Loss: 1.983057
# Epoch 58/120, Train Loss: 2.043545, Test Loss: 2.043545
# Epoch 59/120, Train Loss: 1.961170, Test Loss: 1.961170
# Epoch 60/120, Train Loss: 2.032961, Test Loss: 2.032961
# Epoch 61/120, Train Loss: 2.015627, Test Loss: 2.015627
# Epoch 62/120, Train Loss: 1.972035, Test Loss: 1.972035
# Epoch 63/120, Train Loss: 2.006785, Test Loss: 2.006785
# Epoch 64/120, Train Loss: 2.115840, Test Loss: 2.115840
# Epoch 65/120, Train Loss: 2.092712, Test Loss: 2.092712
# Epoch 66/120, Train Loss: 2.028861, Test Loss: 2.028861
# Epoch 67/120, Train Loss: 2.027539, Test Loss: 2.027539
# Epoch 68/120, Train Loss: 1.960234, Test Loss: 1.960234
# Epoch 69/120, Train Loss: 2.175325, Test Loss: 2.175325
# Epoch 70/120, Train Loss: 1.955987, Test Loss: 1.955987
# Epoch 71/120, Train Loss: 2.022951, Test Loss: 2.022951
# Epoch 72/120, Train Loss: 2.044869, Test Loss: 2.044869
# Epoch 73/120, Train Loss: 2.124146, Test Loss: 2.124146
# Epoch 74/120, Train Loss: 2.005840, Test Loss: 2.005840
# Epoch 75/120, Train Loss: 1.972284, Test Loss: 1.972284
# Epoch 76/120, Train Loss: 1.993938, Test Loss: 1.993938
# Epoch 77/120, Train Loss: 1.988635, Test Loss: 1.988635
# Epoch 78/120, Train Loss: 2.041731, Test Loss: 2.041731
# Epoch 79/120, Train Loss: 1.939747, Test Loss: 1.939747
# Epoch 80/120, Train Loss: 1.963219, Test Loss: 1.963219
# Epoch 81/120, Train Loss: 1.977586, Test Loss: 1.977586
# Epoch 82/120, Train Loss: 2.049830, Test Loss: 2.049830
# Epoch 83/120, Train Loss: 1.961018, Test Loss: 1.961018
# Epoch 84/120, Train Loss: 2.027951, Test Loss: 2.027951
# Epoch 85/120, Train Loss: 1.960573, Test Loss: 1.960573
# Epoch 86/120, Train Loss: 1.959933, Test Loss: 1.959933
# Epoch 87/120, Train Loss: 1.990267, Test Loss: 1.990267
# Epoch 88/120, Train Loss: 1.973633, Test Loss: 1.973633
# Epoch 89/120, Train Loss: 2.020439, Test Loss: 2.020439
# Epoch 90/120, Train Loss: 2.029128, Test Loss: 2.029128
# Epoch 91/120, Train Loss: 2.025216, Test Loss: 2.025216
# Epoch 92/120, Train Loss: 2.021727, Test Loss: 2.021727
# Epoch 93/120, Train Loss: 2.050921, Test Loss: 2.050921
# Epoch 94/120, Train Loss: 1.932032, Test Loss: 1.932032
# Epoch 95/120, Train Loss: 2.042921, Test Loss: 2.042921
# Epoch 96/120, Train Loss: 1.997014, Test Loss: 1.997014
# Epoch 97/120, Train Loss: 1.921683, Test Loss: 1.921683
# Epoch 98/120, Train Loss: 1.992406, Test Loss: 1.992406
# Epoch 99/120, Train Loss: 2.121594, Test Loss: 2.121594
# Epoch 100/120, Train Loss: 1.952064, Test Loss: 1.952064
# Epoch 101/120, Train Loss: 1.977968, Test Loss: 1.977968
# Epoch 102/120, Train Loss: 2.009427, Test Loss: 2.009427
# Epoch 103/120, Train Loss: 1.985625, Test Loss: 1.985625
# Epoch 104/120, Train Loss: 2.081489, Test Loss: 2.081489
# Epoch 105/120, Train Loss: 1.982289, Test Loss: 1.982289
# Epoch 106/120, Train Loss: 2.029583, Test Loss: 2.029583
# Epoch 107/120, Train Loss: 2.005249, Test Loss: 2.005249
# Epoch 108/120, Train Loss: 2.025806, Test Loss: 2.025806
# Epoch 109/120, Train Loss: 2.081832, Test Loss: 2.081832
# Epoch 110/120, Train Loss: 2.017101, Test Loss: 2.017101
# Epoch 111/120, Train Loss: 2.089045, Test Loss: 2.089045
# Epoch 112/120, Train Loss: 2.020034, Test Loss: 2.020034
# Epoch 113/120, Train Loss: 1.994172, Test Loss: 1.994172
# Epoch 114/120, Train Loss: 2.120450, Test Loss: 2.120450
# Epoch 115/120, Train Loss: 1.997190, Test Loss: 1.997190
# Epoch 116/120, Train Loss: 1.983999, Test Loss: 1.983999
# Epoch 117/120, Train Loss: 1.930001, Test Loss: 1.930001
# Epoch 118/120, Train Loss: 2.024082, Test Loss: 2.024082
# Epoch 119/120, Train Loss: 2.000272, Test Loss: 2.000272
# Epoch 120/120, Train Loss: 2.006048, Test Loss: 2.006048

# %%
# r2_score(y.detach().numpy(), yHat.detach().numpy())
# type(r2_score(y.detach(), yHat.detach()))

# %%
# torch.mean( r2_score(y.detach().numpy(), yHat.detach().numpy()) ).item()

# %%
trainLoss1, testLoss1, trainAcc1
# Out:
# (tensor([3.4802, 2.5872, 2.5083, 2.4915, 2.4807, 2.4709, 2.4750, 2.4695, 2.4659,
#          2.4708, 2.4648, 2.4663, 2.4602, 2.4696, 2.4622, 2.4637, 2.4645, 2.4623,
#          2.4627, 2.4630, 2.4619, 2.4625, 2.4651, 2.4595, 2.4644, 2.4642, 2.4617,
#          2.4646, 2.4621, 2.4632, 2.4603, 2.4652, 2.4638, 2.4598, 2.4622, 2.4617,
#          2.4598, 2.4639, 2.4603, 2.4621, 2.4628, 2.4623, 2.4614, 2.4625, 2.4619,
#          2.4629, 2.4616, 2.4660, 2.4613, 2.4620, 2.4629, 2.4608, 2.4628, 2.4617,
#          2.4639, 2.4616, 2.4599, 2.4562, 2.4625, 2.4602, 2.4637, 2.4594, 2.4602,
#          2.4624, 2.4623, 2.4606, 2.4580, 2.4637, 2.4630, 2.4652, 2.4596, 2.4635,
#          2.4638, 2.4628, 2.4641, 2.4600, 2.4611, 2.4678, 2.4623, 2.4574, 2.4576,
#          2.4612, 2.4616, 2.4653, 2.4599, 2.4634, 2.4610, 2.4626, 2.4614, 2.4549,
#          2.4574, 2.4626, 2.4609, 2.4645, 2.4620, 2.4610, 2.4593, 2.4573, 2.4603,
#          2.4624, 2.4616, 2.4592, 2.4616, 2.4601, 2.4575, 2.4570, 2.4608, 2.4668,
#          2.4549, 2.4647, 2.4618, 2.4608, 2.4632, 2.4654, 2.4555, 2.4627, 2.4577,
#          2.4598, 2.4601, 2.4606]),
#  tensor([2.0427, 2.0170, 2.0195, 2.0192, 1.9633, 1.9896, 1.9451, 2.0139, 1.9974,
#          2.1325, 1.9944, 2.0201, 2.3475, 2.0207, 2.0990, 1.9879, 1.9833, 2.1237,
#          1.9834, 2.0241, 2.0291, 2.0579, 2.1012, 2.0418, 2.0550, 2.0939, 2.0570,
#          2.0820, 2.0173, 2.0189, 2.0199, 2.0456, 2.0695, 1.9945, 2.0102, 2.0059,
#          2.0588, 1.9791, 2.0937, 1.9808, 2.0085, 2.0577, 1.9821, 2.0287, 1.9858,
#          2.0360, 2.0741, 2.0773, 1.9452, 1.9180, 2.0410, 2.0082, 2.0129, 2.0304,
#          2.0208, 2.1005, 1.9831, 2.0435, 1.9612, 2.0330, 2.0156, 1.9720, 2.0068,
#          2.1158, 2.0927, 2.0289, 2.0275, 1.9602, 2.1753, 1.9560, 2.0230, 2.0449,
#          2.1241, 2.0058, 1.9723, 1.9939, 1.9886, 2.0417, 1.9397, 1.9632, 1.9776,
#          2.0498, 1.9610, 2.0280, 1.9606, 1.9599, 1.9903, 1.9736, 2.0204, 2.0291,
#          2.0252, 2.0217, 2.0509, 1.9320, 2.0429, 1.9970, 1.9217, 1.9924, 2.1216,
#          1.9521, 1.9780, 2.0094, 1.9856, 2.0815, 1.9823, 2.0296, 2.0052, 2.0258,
#          2.0818, 2.0171, 2.0890, 2.0200, 1.9942, 2.1204, 1.9972, 1.9840, 1.9300,
#          2.0241, 2.0003, 2.0060]),
#  tensor([0.3462, 0.4798, 0.4894, 0.4921, 0.4941, 0.4947, 0.4943, 0.4955, 0.4961,
#          0.4945, 0.4955, 0.4961, 0.4967, 0.4956, 0.4969, 0.4969, 0.4970, 0.4964,
#          0.4970, 0.4974, 0.4975, 0.4970, 0.4966, 0.4982, 0.4972, 0.4972, 0.4974,
#          0.4972, 0.4977, 0.4970, 0.4986, 0.4970, 0.4975, 0.4976, 0.4976, 0.4975,
#          0.4977, 0.4969, 0.4978, 0.4978, 0.4973, 0.4975, 0.4975, 0.4978, 0.4977,
#          0.4973, 0.4973, 0.4969, 0.4974, 0.4978, 0.4972, 0.4973, 0.4970, 0.4976,
#          0.4973, 0.4977, 0.4976, 0.4982, 0.4977, 0.4980, 0.4971, 0.4977, 0.4972,
#          0.4976, 0.4973, 0.4975, 0.4980, 0.4973, 0.4977, 0.4973, 0.4986, 0.4975,
#          0.4980, 0.4972, 0.4973, 0.4974, 0.4976, 0.4968, 0.4979, 0.4983, 0.4984,
#          0.4978, 0.4975, 0.4968, 0.4979, 0.4974, 0.4978, 0.4979, 0.4986, 0.4988,
#          0.4982, 0.4976, 0.4980, 0.4973, 0.4979, 0.4979, 0.4979, 0.4984, 0.4984,
#          0.4984, 0.4978, 0.4978, 0.4977, 0.4977, 0.4979, 0.4985, 0.4976, 0.4972,
#          0.4989, 0.4975, 0.4975, 0.4982, 0.4975, 0.4974, 0.4986, 0.4975, 0.4983,
#          0.4984, 0.4980, 0.4981]))

# %%
# batchLoss

# %%
# batchAcc

# %%
# yHat.shape, y.shape

# %%
# yHat_test.shape, yy.shape

# %%
yHat1.flatten(), y1.flatten()
# Out:
# (tensor([1.5587, 2.1915, 7.5152, 3.8249, 0.1586, 2.6132, 0.9515, 3.9026, 1.9988,
#          0.0000, 7.6418, 4.5496, 0.3436, 2.4621, 1.1057, 4.6091, 1.7478, 0.0000,
#          3.5151, 3.9062, 0.0767, 3.0592, 0.9433, 3.9846, 1.8518, 0.5205, 3.7401,
#          4.3024, 0.0000, 6.6384, 1.0346, 4.3369, 1.7590, 0.3951, 7.0739, 4.0173,
#          0.0000, 5.9280, 1.0092, 4.1101, 0.8953, 9.4651, 4.5445, 4.6553, 0.8622,
#          0.4124, 1.1234, 4.6276, 1.0852, 8.7081, 0.6373, 4.6229, 0.3229, 2.4830,
#          1.1184, 4.6439, 1.9906, 0.0000, 7.7126, 4.4481, 0.6564, 1.0938, 1.0818,
#          4.5258, 0.8567, 9.2793, 4.7138, 4.4855, 0.3341, 2.3537, 1.0762, 4.4206,
#          1.0879, 8.6738, 0.2260, 4.5873, 0.0000, 6.5862, 1.1357, 4.6651, 1.8960,
#          0.8808, 5.9156, 4.4101, 0.0000, 8.3359, 1.0818, 4.4687, 1.7912, 0.9909,
#          7.4184, 4.2301, 0.3784, 2.0467, 1.0302, 4.2858, 2.0271, 0.0000, 6.9736,
#          4.4508, 0.1153, 3.2684, 1.0731, 4.4954, 2.1123, 0.0000, 8.1106, 4.7525,
#          0.7814, 0.8794, 1.1582, 4.8441, 0.9364, 9.0289, 5.1156, 4.4967, 0.0000,
#          6.7071, 1.1096, 4.4827, 1.0900, 8.5958, 0.9683, 4.5884, 0.0000, 8.4227,
#          1.1354, 4.6327, 0.9717, 9.9190, 2.6933, 4.8109, 0.0220, 5.2332, 1.1627,
#          4.7831, 1.9099, 0.0000, 4.7042, 4.3556, 0.6538, 0.9354, 1.0558, 4.4546,
#          1.7747, 0.9710, 5.1371, 4.2666, 1.0656, 0.0000, 1.0234, 4.3396, 1.7113,
#          1.7696, 7.4120, 4.1300, 0.5149, 1.3449, 1.0103, 4.2141, 0.9048, 8.1279,
#          5.2333, 4.1914, 0.4711, 1.5434, 1.0124, 4.1458, 0.9873, 9.7025, 0.9411,
#          4.7581, 0.0000, 6.8052, 1.1676, 4.7726, 1.0924, 8.6866, 0.5619, 4.6192,
#          0.0000, 7.3611, 1.1366, 4.6554, 1.0734, 8.7561, 1.1649, 4.6405, 0.5299,
#          1.6421, 1.1226, 4.6624, 1.0074, 8.2202, 8.2306, 4.3736, 0.0000, 5.9714,
#          1.0751, 4.3388, 0.7665, 9.0899, 6.1941, 4.2434, 0.4040, 1.8727, 1.0292,
#          4.2098, 1.9116, 1.1664, 2.1940, 4.4729, 0.0000, 7.2915, 1.0881, 4.5541,
#          0.8834, 9.1786, 3.3588, 4.4949, 0.1057, 4.9430, 1.0877, 4.4353, 1.9276,
#          0.2395, 0.6209, 4.3602, 0.0000, 8.4242, 1.0707, 4.4912, 1.9336, 1.2535,
#          2.1396, 4.6139, 0.9343, 0.0000, 1.1088, 4.7235, 1.0342, 8.1784, 4.9281,
#          4.4391, 0.0000, 7.7967, 1.0879, 4.4137, 2.0841, 0.0000, 4.2835, 4.5590,
#          0.0106, 4.6858, 1.0882, 4.6038], grad_fn=<ReshapeAliasBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
yHat_test1, yy1
# Out:
# (tensor([[1.1217, 8.1884, 0.9109, 4.5179, 0.0000, 5.8909, 1.1044, 4.5443]]),
#  tensor([[1., 8., 1., 6., 0., 6., 0., 1.]]))

# %%
yy1
# Out:
# tensor([[1., 8., 1., 6., 0., 6., 0., 1.]])

# %%
(yHat_test1).round()
# Out:
# tensor([[1., 8., 1., 5., 0., 6., 1., 5.]])

# %%
(yHat1.flatten()).round(), (y1.flatten()).round()
# Out:
# (tensor([ 2.,  2.,  8.,  4.,  0.,  3.,  1.,  4.,  2.,  0.,  8.,  5.,  0.,  2.,
#           1.,  5.,  2.,  0.,  4.,  4.,  0.,  3.,  1.,  4.,  2.,  1.,  4.,  4.,
#           0.,  7.,  1.,  4.,  2.,  0.,  7.,  4.,  0.,  6.,  1.,  4.,  1.,  9.,
#           5.,  5.,  1.,  0.,  1.,  5.,  1.,  9.,  1.,  5.,  0.,  2.,  1.,  5.,
#           2.,  0.,  8.,  4.,  1.,  1.,  1.,  5.,  1.,  9.,  5.,  4.,  0.,  2.,
#           1.,  4.,  1.,  9.,  0.,  5.,  0.,  7.,  1.,  5.,  2.,  1.,  6.,  4.,
#           0.,  8.,  1.,  4.,  2.,  1.,  7.,  4.,  0.,  2.,  1.,  4.,  2.,  0.,
#           7.,  4.,  0.,  3.,  1.,  4.,  2.,  0.,  8.,  5.,  1.,  1.,  1.,  5.,
#           1.,  9.,  5.,  4.,  0.,  7.,  1.,  4.,  1.,  9.,  1.,  5.,  0.,  8.,
#           1.,  5.,  1., 10.,  3.,  5.,  0.,  5.,  1.,  5.,  2.,  0.,  5.,  4.,
#           1.,  1.,  1.,  4.,  2.,  1.,  5.,  4.,  1.,  0.,  1.,  4.,  2.,  2.,
#           7.,  4.,  1.,  1.,  1.,  4.,  1.,  8.,  5.,  4.,  0.,  2.,  1.,  4.,
#           1., 10.,  1.,  5.,  0.,  7.,  1.,  5.,  1.,  9.,  1.,  5.,  0.,  7.,
#           1.,  5.,  1.,  9.,  1.,  5.,  1.,  2.,  1.,  5.,  1.,  8.,  8.,  4.,
#           0.,  6.,  1.,  4.,  1.,  9.,  6.,  4.,  0.,  2.,  1.,  4.,  2.,  1.,
#           2.,  4.,  0.,  7.,  1.,  5.,  1.,  9.,  3.,  4.,  0.,  5.,  1.,  4.,
#           2.,  0.,  1.,  4.,  0.,  8.,  1.,  4.,  2.,  1.,  2.,  5.,  1.,  0.,
#           1.,  5.,  1.,  8.,  5.,  4.,  0.,  8.,  1.,  4.,  2.,  0.,  4.,  5.,
#           0.,  5.,  1.,  5.], grad_fn=<RoundBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
print_score(X.shape, yHat1, y1, yHat_test1, yy1)
# Out:
# Adjusted R-Squared(y, yHat): 0.4779
#
#
# mean_absolute_error(y, yHat): 0.9825
#
# mean_absolute_error(yy, yHat_test): 0.8299
#
#
# mean_squared_error(y, yHat): 2.6459
#
# mean_squared_error(yy, yHat_test): 2.0060
#
#
# mean_squared_log_error(y, yHat): 0.2112
#
# mean_squared_log_error(yy, yHat_test): 0.2070
#
#
# RMSE(y, yHat): 1.6266
#
# RMSE(yy, yHat_test): 1.4164

# %%
# create a 1D smoothing filter
def smooth(x, k=15):
    return np.convolve(x, np.ones(k)/k, mode='same')

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss1.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc1, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat1.detach().T, y1.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc1.jpg", bbox_inches='tight')


plt.show()

# %%
data.leap_year.value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
resampler = SMOTE(k_neighbors=20, random_state=0)

# %%
X_res, y_res = resampler.fit_resample(data[['day_code', 'month_code', 'decade', 'date_int']], data['leap_year'])

# %%
y_res.value_counts()
# Out:
# 0    110960
# 1    110960
# Name: leap_year, dtype: int64

# %%
data['leap_year'].value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 221915    1
# 221916    1
# 221917    1
# 221918    1
# 221919    1
# Name: leap_year, Length: 221920, dtype: int64

# %%
X_res
# Out:
#         day_code  month_code  decade  date_int
# 0              4           0     180  18000101
# 1              5           0     180  18010101
# 2              6           0     180  18020101
# 3              0           0     180  18030101
# 4              1           0     180  18040101
# ...          ...         ...     ...       ...
# 221915         0           5     188  18880618
# 221916         2           6     188  18840705
# 221917         5           2     218  21800323
# 221918         1           5     199  19960602
# 221919         1           4     219  21960520
#
# [221920 rows x 4 columns]

# %%
X_smote = X_res.assign(leap_year=y_res)

# %%
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221915         0           5     188  18880618          1
# 221916         2           6     188  18840705          1
# 221917         5           2     218  21800323          1
# 221918         1           5     199  19960602          1
# 221919         1           4     219  21960520          1
#
# [221920 rows x 5 columns]

# %% [markdown]
# Drop 220 decade

# %%
# data.decade.value_counts().plot(kind="bar")
X_smote.decade.value_counts().plot(kind="bar")

# %%
# data.decade.value_counts()[-5:]
X_smote.decade.value_counts()[-5:]
# Out:
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# 220     365
# Name: decade, dtype: int64

# %%
X_smote = X_smote.drop(X_smote.index[X_smote['decade'] == 220]).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221550         0           5     188  18880618          1
# 221551         2           6     188  18840705          1
# 221552         5           2     218  21800323          1
# 221553         1           5     199  19960602          1
# 221554         1           4     219  21960520          1
#
# [221555 rows x 5 columns]

# %%
X_smote.decade.value_counts().plot(kind="bar")

# %%
X_smote.decade.value_counts()[-5:]
# Out:
# 209    5174
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# Name: decade, dtype: int64

# %% [markdown]
# code is required to only work for dates in the range  [ 1-1-1800 to 31-12-2200 ]

# %%
X_smote.date_int.max()
# Out:
# 21991231

# %%
datetime.datetime.strptime(str(X_smote.date_int.max()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '31-12-2199'

# %%
X_smote.date_int.min()
# Out:
# 18000101

# %%
datetime.datetime.strptime(str(X_smote.date_int.min()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '01-01-1800'

# %%
Y_smote = X_smote['date_int']
Y_smote
# Out:
# 0         18000101
# 1         18010101
# 2         18020101
# 3         18030101
# 4         18040101
#             ...
# 221550    18880618
# 221551    18840705
# 221552    21800323
# 221553    19960602
# 221554    21960520
# Name: date_int, Length: 221555, dtype: int64

# %%
X_smote = X_smote.drop('date_int', axis=1).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  leap_year
# 0              4           0     180          0
# 1              5           0     180          0
# 2              6           0     180          0
# 3              0           0     180          0
# 4              1           0     180          1
# ...          ...         ...     ...        ...
# 221550         0           5     188          1
# 221551         2           6     188          1
# 221552         5           2     218          1
# 221553         1           5     199          1
# 221554         1           4     219          1
#
# [221555 rows x 4 columns]

# %%
Y_smote = Y_smote.reset_index(drop=True)

ls = []

for s in Y_smote.astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(Y_smote)), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y_smote = ll.values

Y_smote
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
# data.index[data['leap_year'] == 1].tolist()
# data.index[data['leap_year'] == 1]

# %%
# for i,idx in enumerate(data['leap_year'].tolist()):
#     print(i, idx)

# %% [markdown]
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1 <---
# 5 0
# 6 0
# 7 0
# 8 1 <---
# 9 0
# 10 0
# 11 0
# 12 1 <---
# 13 0
# 14 0
# 15 0
# 16 1 <---
# 17 0
# 18 0
# 19 0
# 20 1 <---
# 21 0
# 22 0
# 23 0
# 24 1 <---
# 25 0
# 26 0
# 27 0
# 28 1 <---
# 29 0
# 30 0

# %%
scaler_day_smote = RobustScaler()

x = X_smote.day_code.values.reshape(-1, 1)

X_smote['day_scaled'] = scaler_day_smote.fit_transform(x).flatten()

# %%
X_smote['day_sin'] = np.sin(X_smote['day_code'] * (2 * np.pi / 7))
X_smote['day_cos'] = np.cos(X_smote['day_code'] * (2 * np.pi / 7))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos
# 0      -0.900969
# 1      -0.222521
# 2       0.623490
# 3       1.000000
# 4       0.623490
# ...          ...
# 221550  1.000000
# 221551 -0.222521
# 221552 -0.222521
# 221553  0.623490
# 221554  0.623490
#
# [221555 rows x 7 columns]

# %%
scaler_month_smote = RobustScaler()

x = X_smote.month_code.values.reshape(-1, 1)

X_smote['month_scaled'] = scaler_month_smote.fit_transform(x).flatten()

# %%
X_smote['month_sin'] = np.sin(X_smote['month_code'] * (2 * np.pi / 12))
X_smote['month_cos'] = np.cos(X_smote['month_code'] * (2 * np.pi / 12))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos
# 0      -0.900969     -1.000000  0.000000e+00   1.000000
# 1      -0.222521     -1.000000  0.000000e+00   1.000000
# 2       0.623490     -1.000000  0.000000e+00   1.000000
# 3       1.000000     -1.000000  0.000000e+00   1.000000
# 4       0.623490     -1.000000  0.000000e+00   1.000000
# ...          ...           ...           ...        ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000
#
# [221555 rows x 10 columns]

# %%
scaler_decade_smote = RobustScaler()

x = X_smote.decade.values.reshape(-1, 1)

X_smote['decade_scaled'] = scaler_decade_smote.fit_transform(x).flatten()

# %%
# alpha_smote = len(X_smote.decade.unique())
alpha_smote = (X_smote.decade.iloc[-1] - X_smote.decade.iloc[0]) + 1

X_smote['decade_sin'] = np.sin(X_smote['decade'] * (2 * np.pi / alpha_smote))
X_smote['decade_cos'] = np.cos(X_smote['decade'] * (2 * np.pi / alpha_smote))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos  decade_scaled  \
# 0      -0.900969     -1.000000  0.000000e+00   1.000000      -1.052632
# 1      -0.222521     -1.000000  0.000000e+00   1.000000      -1.052632
# 2       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# 3       1.000000     -1.000000  0.000000e+00   1.000000      -1.052632
# 4       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# ...          ...           ...           ...        ...            ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025      -0.631579
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000      -0.631579
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000       0.947368
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025      -0.052632
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000       1.000000
#
#           decade_sin  decade_cos
# 0       1.102182e-15   -1.000000
# 1       1.102182e-15   -1.000000
# 2       1.102182e-15   -1.000000
# 3       1.102182e-15   -1.000000
# 4       1.102182e-15   -1.000000
# ...              ...         ...
# 221550 -9.510565e-01   -0.309017
# 221551 -9.510565e-01   -0.309017
# 221552  3.090170e-01   -0.951057
# 221553 -1.564345e-01    0.987688
# 221554  1.564345e-01   -0.987688
#
# [221555 rows x 13 columns]

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
X = X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 3.33333333e-01, -4.33883739e-01, -9.00968868e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 1.00000000e+00, -7.81831482e-01,  6.23489802e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        ...,
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#          9.47368421e-01,  3.09016994e-01, -9.51056516e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#         -5.26315789e-02, -1.56434465e-01,  9.87688341e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#          1.00000000e+00,  1.56434465e-01, -9.87688341e-01]])

# %%
X.shape
# Out:
# (221555, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()
# Y = data['date_normalized'].values.reshape(-1, 1)
Y = Y_smote


Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
Y.shape
# Out:
# (221555, 8)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64

train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (221555, 10)
#
# Y: (221555, 8)
#
# Train data:   (155088, 10)
#
# Train labels: (155088, 8)
#
# Test data:    (66467, 10)
#
# Test labels:  (66467, 8)

# %%
model_smote = Model().to(device)

# %%
numepochs = 120

trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model_smote, numepochs)
# Out:
# Epoch 1/120, Train Loss: 4.143764, Test Loss: 4.143764
# Epoch 2/120, Train Loss: 4.182227, Test Loss: 4.182227
# Epoch 3/120, Train Loss: 4.227010, Test Loss: 4.227010
# Epoch 4/120, Train Loss: 4.112676, Test Loss: 4.112676
# Epoch 5/120, Train Loss: 4.358381, Test Loss: 4.358381
# Epoch 6/120, Train Loss: 4.195965, Test Loss: 4.195965
# Epoch 7/120, Train Loss: 4.147899, Test Loss: 4.147899
# Epoch 8/120, Train Loss: 4.057199, Test Loss: 4.057199
# Epoch 9/120, Train Loss: 4.239831, Test Loss: 4.239831
# Epoch 10/120, Train Loss: 4.194536, Test Loss: 4.194536
# Epoch 11/120, Train Loss: 4.332522, Test Loss: 4.332522
# Epoch 12/120, Train Loss: 4.063351, Test Loss: 4.063351
# Epoch 13/120, Train Loss: 4.393960, Test Loss: 4.393960
# Epoch 14/120, Train Loss: 4.086084, Test Loss: 4.086084
# Epoch 15/120, Train Loss: 4.136766, Test Loss: 4.136766
# Epoch 16/120, Train Loss: 4.155253, Test Loss: 4.155253
# Epoch 17/120, Train Loss: 4.090245, Test Loss: 4.090245
# Epoch 18/120, Train Loss: 4.135665, Test Loss: 4.135665
# Epoch 19/120, Train Loss: 4.283618, Test Loss: 4.283618
# Epoch 20/120, Train Loss: 4.197245, Test Loss: 4.197245
# Epoch 21/120, Train Loss: 4.172227, Test Loss: 4.172227
# Epoch 22/120, Train Loss: 4.332545, Test Loss: 4.332545
# Epoch 23/120, Train Loss: 4.150939, Test Loss: 4.150939
# Epoch 24/120, Train Loss: 4.362115, Test Loss: 4.362115
# Epoch 25/120, Train Loss: 4.131450, Test Loss: 4.131450
# Epoch 26/120, Train Loss: 4.052880, Test Loss: 4.052880
# Epoch 27/120, Train Loss: 4.186070, Test Loss: 4.186070
# Epoch 28/120, Train Loss: 4.106553, Test Loss: 4.106553
# Epoch 29/120, Train Loss: 4.096805, Test Loss: 4.096805
# Epoch 30/120, Train Loss: 4.162368, Test Loss: 4.162368
# Epoch 31/120, Train Loss: 4.183040, Test Loss: 4.183040
# Epoch 32/120, Train Loss: 4.062280, Test Loss: 4.062280
# Epoch 33/120, Train Loss: 4.296004, Test Loss: 4.296004
# Epoch 34/120, Train Loss: 4.172103, Test Loss: 4.172103
# Epoch 35/120, Train Loss: 4.192657, Test Loss: 4.192657
# Epoch 36/120, Train Loss: 4.097289, Test Loss: 4.097289
# Epoch 37/120, Train Loss: 4.088638, Test Loss: 4.088638
# Epoch 38/120, Train Loss: 4.223679, Test Loss: 4.223679
# Epoch 39/120, Train Loss: 4.132513, Test Loss: 4.132513
# Epoch 40/120, Train Loss: 4.177443, Test Loss: 4.177443
# Epoch 41/120, Train Loss: 4.135444, Test Loss: 4.135444
# Epoch 42/120, Train Loss: 4.247720, Test Loss: 4.247720
# Epoch 43/120, Train Loss: 4.342825, Test Loss: 4.342825
# Epoch 44/120, Train Loss: 4.215411, Test Loss: 4.215411
# Epoch 45/120, Train Loss: 4.023419, Test Loss: 4.023419
# Epoch 46/120, Train Loss: 4.294668, Test Loss: 4.294668
# Epoch 47/120, Train Loss: 4.074379, Test Loss: 4.074379
# Epoch 48/120, Train Loss: 4.233991, Test Loss: 4.233991
# Epoch 49/120, Train Loss: 4.065957, Test Loss: 4.065957
# Epoch 50/120, Train Loss: 4.073976, Test Loss: 4.073976
# Epoch 51/120, Train Loss: 4.231202, Test Loss: 4.231202
# Epoch 52/120, Train Loss: 4.394158, Test Loss: 4.394158
# Epoch 53/120, Train Loss: 4.104895, Test Loss: 4.104895
# Epoch 54/120, Train Loss: 4.202364, Test Loss: 4.202364
# Epoch 55/120, Train Loss: 4.157475, Test Loss: 4.157475
# Epoch 56/120, Train Loss: 4.134994, Test Loss: 4.134994
# Epoch 57/120, Train Loss: 4.112209, Test Loss: 4.112209
# Epoch 58/120, Train Loss: 4.198477, Test Loss: 4.198477
# Epoch 59/120, Train Loss: 4.096962, Test Loss: 4.096962
# Epoch 60/120, Train Loss: 4.087592, Test Loss: 4.087592
# Epoch 61/120, Train Loss: 4.062770, Test Loss: 4.062770
# Epoch 62/120, Train Loss: 4.058463, Test Loss: 4.058463
# Epoch 63/120, Train Loss: 4.083261, Test Loss: 4.083261
# Epoch 64/120, Train Loss: 4.121212, Test Loss: 4.121212
# Epoch 65/120, Train Loss: 4.126503, Test Loss: 4.126503
# Epoch 66/120, Train Loss: 4.307493, Test Loss: 4.307493
# Epoch 67/120, Train Loss: 4.166913, Test Loss: 4.166913
# Epoch 68/120, Train Loss: 4.049231, Test Loss: 4.049231
# Epoch 69/120, Train Loss: 4.138862, Test Loss: 4.138862
# Epoch 70/120, Train Loss: 4.241808, Test Loss: 4.241808
# Epoch 71/120, Train Loss: 4.060496, Test Loss: 4.060496
# Epoch 72/120, Train Loss: 4.046460, Test Loss: 4.046460
# Epoch 73/120, Train Loss: 4.151943, Test Loss: 4.151943
# Epoch 74/120, Train Loss: 4.131744, Test Loss: 4.131744
# Epoch 75/120, Train Loss: 4.290222, Test Loss: 4.290222
# Epoch 76/120, Train Loss: 4.216043, Test Loss: 4.216043
# Epoch 77/120, Train Loss: 4.089171, Test Loss: 4.089171
# Epoch 78/120, Train Loss: 4.093639, Test Loss: 4.093639
# Epoch 79/120, Train Loss: 4.044613, Test Loss: 4.044613
# Epoch 80/120, Train Loss: 4.124676, Test Loss: 4.124676
# Epoch 81/120, Train Loss: 4.237965, Test Loss: 4.237965
# Epoch 82/120, Train Loss: 4.104631, Test Loss: 4.104631
# Epoch 83/120, Train Loss: 4.198055, Test Loss: 4.198055
# Epoch 84/120, Train Loss: 4.092422, Test Loss: 4.092422
# Epoch 85/120, Train Loss: 4.173012, Test Loss: 4.173012
# Epoch 86/120, Train Loss: 4.124086, Test Loss: 4.124086
# Epoch 87/120, Train Loss: 4.135064, Test Loss: 4.135064
# Epoch 88/120, Train Loss: 4.247502, Test Loss: 4.247502
# Epoch 89/120, Train Loss: 4.115364, Test Loss: 4.115364
# Epoch 90/120, Train Loss: 4.160461, Test Loss: 4.160461
# Epoch 91/120, Train Loss: 4.099010, Test Loss: 4.099010
# Epoch 92/120, Train Loss: 4.151491, Test Loss: 4.151491
# Epoch 93/120, Train Loss: 4.152715, Test Loss: 4.152715
# Epoch 94/120, Train Loss: 4.156896, Test Loss: 4.156896
# Epoch 95/120, Train Loss: 4.178414, Test Loss: 4.178414
# Epoch 96/120, Train Loss: 4.107327, Test Loss: 4.107327
# Epoch 97/120, Train Loss: 4.113338, Test Loss: 4.113338
# Epoch 98/120, Train Loss: 4.174442, Test Loss: 4.174442
# Epoch 99/120, Train Loss: 4.019378, Test Loss: 4.019378
# Epoch 100/120, Train Loss: 4.120811, Test Loss: 4.120811
# Epoch 101/120, Train Loss: 4.113431, Test Loss: 4.113431
# Epoch 102/120, Train Loss: 4.262599, Test Loss: 4.262599
# Epoch 103/120, Train Loss: 4.024617, Test Loss: 4.024617
# Epoch 104/120, Train Loss: 4.140732, Test Loss: 4.140732
# Epoch 105/120, Train Loss: 4.030547, Test Loss: 4.030547
# Epoch 106/120, Train Loss: 4.090391, Test Loss: 4.090391
# Epoch 107/120, Train Loss: 4.116089, Test Loss: 4.116089
# Epoch 108/120, Train Loss: 4.045319, Test Loss: 4.045319
# Epoch 109/120, Train Loss: 4.189080, Test Loss: 4.189080
# Epoch 110/120, Train Loss: 4.027981, Test Loss: 4.027981
# Epoch 111/120, Train Loss: 4.186657, Test Loss: 4.186657
# Epoch 112/120, Train Loss: 4.137014, Test Loss: 4.137014
# Epoch 113/120, Train Loss: 4.133032, Test Loss: 4.133032
# Epoch 114/120, Train Loss: 4.180607, Test Loss: 4.180607
# Epoch 115/120, Train Loss: 4.106621, Test Loss: 4.106621
# Epoch 116/120, Train Loss: 4.011579, Test Loss: 4.011579
# Epoch 117/120, Train Loss: 4.209220, Test Loss: 4.209220
# Epoch 118/120, Train Loss: 4.144854, Test Loss: 4.144854
# Epoch 119/120, Train Loss: 4.206750, Test Loss: 4.206750
# Epoch 120/120, Train Loss: 4.231387, Test Loss: 4.231387

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([3.1272, 2.4558, 2.4320, 2.4243, 2.4152, 2.4203, 2.4170, 2.4152, 2.4198,
#          2.4132, 2.4131, 2.4139, 2.4123, 2.4139, 2.4160, 2.4133, 2.4093, 2.4106,
#          2.4115, 2.4135, 2.4105, 2.4089, 2.4097, 2.4097, 2.4070, 2.4092, 2.4060,
#          2.4061, 2.4081, 2.4061, 2.4085, 2.4064, 2.4042, 2.4089, 2.4037, 2.4065,
#          2.4072, 2.4060, 2.4036, 2.4080, 2.4047, 2.4062, 2.4038, 2.4060, 2.4064,
#          2.4028, 2.4037, 2.4031, 2.4029, 2.4036, 2.4043, 2.4053, 2.4026, 2.4036,
#          2.4026, 2.3996, 2.4017, 2.4012, 2.4024, 2.4035, 2.4026, 2.4025, 2.4027,
#          2.4005, 2.3997, 2.3998, 2.4012, 2.4019, 2.4001, 2.3983, 2.4018, 2.4013,
#          2.4009, 2.4027, 2.4001, 2.4024, 2.4021, 2.4003, 2.3997, 2.4004, 2.4006,
#          2.4002, 2.3981, 2.4000, 2.3989, 2.4012, 2.3988, 2.3978, 2.4025, 2.4000,
#          2.4023, 2.4001, 2.3983, 2.4024, 2.3994, 2.4009, 2.3964, 2.4003, 2.3994,
#          2.3990, 2.4019, 2.3968, 2.3989, 2.3994, 2.4017, 2.4016, 2.3996, 2.4030,
#          2.3990, 2.4010, 2.3981, 2.3992, 2.4029, 2.3989, 2.4022, 2.3998, 2.4017,
#          2.4009, 2.4014, 2.4009]),
#  tensor([4.1438, 4.1822, 4.2270, 4.1127, 4.3584, 4.1960, 4.1479, 4.0572, 4.2398,
#          4.1945, 4.3325, 4.0634, 4.3940, 4.0861, 4.1368, 4.1553, 4.0902, 4.1357,
#          4.2836, 4.1972, 4.1722, 4.3325, 4.1509, 4.3621, 4.1315, 4.0529, 4.1861,
#          4.1066, 4.0968, 4.1624, 4.1830, 4.0623, 4.2960, 4.1721, 4.1927, 4.0973,
#          4.0886, 4.2237, 4.1325, 4.1774, 4.1354, 4.2477, 4.3428, 4.2154, 4.0234,
#          4.2947, 4.0744, 4.2340, 4.0660, 4.0740, 4.2312, 4.3942, 4.1049, 4.2024,
#          4.1575, 4.1350, 4.1122, 4.1985, 4.0970, 4.0876, 4.0628, 4.0585, 4.0833,
#          4.1212, 4.1265, 4.3075, 4.1669, 4.0492, 4.1389, 4.2418, 4.0605, 4.0465,
#          4.1519, 4.1317, 4.2902, 4.2160, 4.0892, 4.0936, 4.0446, 4.1247, 4.2380,
#          4.1046, 4.1981, 4.0924, 4.1730, 4.1241, 4.1351, 4.2475, 4.1154, 4.1605,
#          4.0990, 4.1515, 4.1527, 4.1569, 4.1784, 4.1073, 4.1133, 4.1744, 4.0194,
#          4.1208, 4.1134, 4.2626, 4.0246, 4.1407, 4.0305, 4.0904, 4.1161, 4.0453,
#          4.1891, 4.0280, 4.1867, 4.1370, 4.1330, 4.1806, 4.1066, 4.0116, 4.2092,
#          4.1449, 4.2067, 4.2314]),
#  tensor([0.3803, 0.4902, 0.4937, 0.4953, 0.4969, 0.4963, 0.4965, 0.4964, 0.4960,
#          0.4967, 0.4965, 0.4968, 0.4970, 0.4966, 0.4959, 0.4963, 0.4966, 0.4963,
#          0.4959, 0.4959, 0.4964, 0.4970, 0.4961, 0.4963, 0.4966, 0.4966, 0.4974,
#          0.4968, 0.4968, 0.4971, 0.4967, 0.4974, 0.4976, 0.4968, 0.4975, 0.4969,
#          0.4969, 0.4970, 0.4973, 0.4971, 0.4976, 0.4973, 0.4975, 0.4973, 0.4971,
#          0.4976, 0.4979, 0.4977, 0.4979, 0.4979, 0.4978, 0.4975, 0.4981, 0.4977,
#          0.4977, 0.4985, 0.4982, 0.4983, 0.4980, 0.4976, 0.4981, 0.4980, 0.4980,
#          0.4983, 0.4983, 0.4983, 0.4984, 0.4982, 0.4981, 0.4990, 0.4980, 0.4981,
#          0.4979, 0.4979, 0.4981, 0.4980, 0.4981, 0.4986, 0.4983, 0.4983, 0.4986,
#          0.4979, 0.4983, 0.4980, 0.4984, 0.4982, 0.4984, 0.4986, 0.4982, 0.4982,
#          0.4979, 0.4982, 0.4986, 0.4978, 0.4988, 0.4988, 0.4991, 0.4984, 0.4985,
#          0.4986, 0.4980, 0.4986, 0.4985, 0.4983, 0.4977, 0.4981, 0.4982, 0.4979,
#          0.4989, 0.4981, 0.4987, 0.4989, 0.4978, 0.4982, 0.4980, 0.4983, 0.4983,
#          0.4981, 0.4984, 0.4980]))

# %%
# (yy * data['date_int'].max()).round()

# %%
# (yHat_test * data['date_int'].max()).round()

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.5169
#
#
# mean_absolute_error(y, yHat): 0.9356
#
# mean_absolute_error(yy, yHat_test): 1.3379
#
#
# mean_squared_error(y, yHat): 2.2307
#
# mean_squared_error(yy, yHat_test): 4.2314
#
#
# mean_squared_log_error(y, yHat): 0.1267
#
# mean_squared_log_error(yy, yHat_test): 0.4240
#
#
# RMSE(y, yHat): 1.4936
#
# RMSE(yy, yHat_test): 2.0570

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss2.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.detach().T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc2.jpg", bbox_inches='tight')


plt.show()

# %%
['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']
# Out:
# ['day_scaled',
#  'day_sin',
#  'day_cos',
#  'month_scaled',
#  'month_sin',
#  'month_cos',
#  'leap_year',
#  'decade_scaled',
#  'decade_sin',
#  'decade_cos']

# %%
def result_to_date(result):
    
    result = str(result)
    
    day   = int(result[6:]) - 1
    month = int(result[4:6]) - 1

    ss = str(f'{result[:4]}0101')
    
    ds = datetime.datetime.strptime(ss, '%Y%m%d')
    
    ds = ds + relativedelta(months=month, days=day)

    result = ds.strftime('%d-%m-%Y')
    
    
    return result

# %%
# (16830739, 17848869)
result_to_date(16830739), result_to_date(17848869)
# Out:
# ('08-08-1683', '08-06-1791')

# %%
def test_model(input_list):
    

    X       = np.zeros((1, 10))
    X_smote = np.zeros((1, 10))



    day       = np.array(map_day[input_list[0]])
    month     = np.array(map_month[input_list[1]])
    leap_year = map_leap_year[input_list[2]]
    decade    = np.array(input_list[3].strip('[]')).astype('int64')


    X[0, 0] = scaler_day.transform(day.reshape(-1, 1)).flatten()
    X[0, 1] = np.sin(day * (2 * np.pi / 7))
    X[0, 2] = np.cos(day * (2 * np.pi / 7))

    X[0, 3] = scaler_month.transform(month.reshape(-1, 1)).flatten()
    X[0, 4] = np.sin(month * (2 * np.pi / 12))
    X[0, 5] = np.cos(month * (2 * np.pi / 12))

    X[0, 6] = leap_year

    X[0, 7] = scaler_decade.transform(decade.reshape(-1, 1)).flatten()
    X[0, 8] = np.sin(decade * (2 * np.pi / alpha))
    X[0, 9] = np.cos(decade * (2 * np.pi / alpha))

    # ---

    X_smote[0, 0] = scaler_day_smote.transform(day.reshape(-1, 1)).flatten()
    X_smote[0, 1] = X[0, 1]
    X_smote[0, 2] = X[0, 2]

    X_smote[0, 3] = scaler_month_smote.transform(month.reshape(-1, 1)).flatten()
    X_smote[0, 4] = X[0, 4]
    X_smote[0, 5] = X[0, 5]

    X_smote[0, 6] = leap_year

    X_smote[0, 7] = scaler_decade_smote.transform(decade.reshape(-1, 1)).flatten()
    X_smote[0, 8] = np.sin(decade * (2 * np.pi / alpha_smote))
    X_smote[0, 9] = np.cos(decade * (2 * np.pi / alpha_smote))


    # ---

    result       = model(torch.tensor(X).to(device).float())
    result_smote = model_smote(torch.tensor(X_smote).to(device).float())


    # ---


    result       = ''.join(result.detach().cpu().numpy().round().astype(int).astype(str).flatten())
    result_smote = ''.join(result_smote.detach().cpu().numpy().round().astype(int).astype(str).flatten())


    
    return result_to_date(result), result_to_date(result_smote)

# %%
input_test1 = ['[MON]', '[DEC]', '[False]', '[196]']
output_test1 = '3-12-1962'

input_test2 = ['[THU]', '[DEC]', '[True]', '[204]']
output_test2 = '3-12-2048'

input_test3 = ['[WED]', '[JAN]', '[False]', '[181]']
output_test3 = '10-1-1810'


input_test4 = ['[WED]', '[JUN]', '[False]', '[209]']

# %%
test_model(input_test1), test_model(input_test2), test_model(input_test3), test_model(input_test4)
# Out:
# (('14-02-1964', '14-02-1964'),
#  ('14-02-2044', '14-02-2044'),
#  ('14-11-1814', '15-11-1814'),
#  ('14-06-2084', '14-06-2084'))

# %%
output_test1, output_test2, output_test3
# Out:
# ('3-12-1962', '3-12-2048', '10-1-1810')

# %%
# example_input = pd.read_csv('./data/example_input.txt', sep=' ', header=None)
example_input = pd.read_csv('example_input.txt', sep=' ', header=None)


example_input.columns = ['day', 'month', 'leap_year', 'decade']

# %%
example_input
# Out:
#         day  month leap_year decade
# 0     [WED]  [JAN]   [False]  [180]
# 1     [MON]  [JAN]   [False]  [190]
# 2     [SAT]  [JAN]    [True]  [200]
# 3     [FRI]  [JAN]   [False]  [210]
# 4     [WED]  [JAN]   [False]  [220]
# ...     ...    ...       ...    ...
# 1460  [MON]  [OCT]    [True]  [214]
# 1461  [TUE]  [DEC]   [False]  [183]
# 1462  [SUN]  [DEC]   [False]  [193]
# 1463  [SAT]  [DEC]   [False]  [203]
# 1464  [THU]  [DEC]   [False]  [213]
#
# [1465 rows x 4 columns]

# %%
R       = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result'])
R_smote = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result_smote'])

# %%
example_input.iloc[0].tolist()
# Out:
# ['[WED]', '[JAN]', '[False]', '[180]']

# %%
for i in range(len(example_input)):
    R.iloc[i], R_smote.iloc[i] = test_model(example_input.iloc[i].tolist())

# %%
R
# Out:
#           result
# 0     14-11-1814
# 1     15-11-1914
# 2     14-11-2004
# 3     14-11-2114
# 4     14-11-2114
# ...          ...
# 1460  14-10-2154
# 1461  14-02-1834
# 1462  14-02-1934
# 1463  14-02-2034
# 1464  14-02-2134
#
# [1465 rows x 1 columns]

# %%
final = pd.concat([example_input, R], axis=1)
final
# Out:
#         day  month leap_year decade      result
# 0     [WED]  [JAN]   [False]  [180]  14-11-1814
# 1     [MON]  [JAN]   [False]  [190]  15-11-1914
# 2     [SAT]  [JAN]    [True]  [200]  14-11-2004
# 3     [FRI]  [JAN]   [False]  [210]  14-11-2114
# 4     [WED]  [JAN]   [False]  [220]  14-11-2114
# ...     ...    ...       ...    ...         ...
# 1460  [MON]  [OCT]    [True]  [214]  14-10-2154
# 1461  [TUE]  [DEC]   [False]  [183]  14-02-1834
# 1462  [SUN]  [DEC]   [False]  [193]  14-02-1934
# 1463  [SAT]  [DEC]   [False]  [203]  14-02-2034
# 1464  [THU]  [DEC]   [False]  [213]  14-02-2134
#
# [1465 rows x 5 columns]

# %%
final_smote = pd.concat([example_input, R_smote], axis=1)
final_smote
# Out:
#         day  month leap_year decade result_smote
# 0     [WED]  [JAN]   [False]  [180]   15-11-1805
# 1     [MON]  [JAN]   [False]  [190]   15-11-1905
# 2     [SAT]  [JAN]    [True]  [200]   14-11-2004
# 3     [FRI]  [JAN]   [False]  [210]   14-11-2114
# 4     [WED]  [JAN]   [False]  [220]   14-11-2184
# ...     ...    ...       ...    ...          ...
# 1460  [MON]  [OCT]    [True]  [214]   15-11-2134
# 1461  [TUE]  [DEC]   [False]  [183]   14-02-1824
# 1462  [SUN]  [DEC]   [False]  [193]   14-02-1934
# 1463  [SAT]  [DEC]   [False]  [203]   14-12-2034
# 1464  [THU]  [DEC]   [False]  [213]   14-02-2124
#
# [1465 rows x 5 columns]

# %%
final.to_csv('output_file.txt', sep=' ', header=None, index=False)

# %%
final_smote.to_csv('output_file_smote.txt', sep=' ', header=None, index=False)

# %% [markdown]
# Out-liers

# %% [markdown]
# Saving

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              'scaler_day_smote' : scaler_day_smote,
              'scaler_month_smote' : scaler_month_smote,
              'scaler_decade_smote' : scaler_decade_smote}



torch.save(checkpoint, 'checkpoint.pth.tar')

# %%
# checkpoint = torch.load('checkpoint.pth.tar')

# %%
# model       = Model()
# model_smote = Model()


# model.load_state_dict(checkpoint['model_state_dict'])
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
