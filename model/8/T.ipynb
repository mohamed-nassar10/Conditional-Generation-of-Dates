# %%
import datetime

import copy

import random


from dateutil.relativedelta import relativedelta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('seaborn')
# plt.style.use(['dark_background', 'ggplot'])

import seaborn as sns
# sns.set()

# import scipy
# import scipy.stats as stats


# # sympy = symbolic math in Python
# import sympy as sym
# import sympy.plotting.plot as symplot


# make the equations look nicer

# from IPython.display import display
# display.set_matplotlib_formats('svg') # Deprecated since version 7.23

# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


# %config InlineBackend.set_matplotlib_formats = ["svg"]
# %config InlineBackend.figure_formats = ["svg"]

# %%
import sklearn


from sklearn.model_selection import train_test_split


# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler     # <------------ (-1.0, 1.0)
# from sklearn.preprocessing import MinMaxScaler


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from imblearn.over_sampling import SMOTE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset, DataLoader





torch.__version__
# Out:
# '1.12.0+cu113'

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def print_score(shape, yHat, y, yHat_test, yy):
    
    
    n, p = shape
    
    R2 = r2_score(y.detach().numpy(), yHat.detach().numpy())
    
    Adj_r2 = 1 - (1 - R2)  *  (n - 1) / (n - p - 1)
    
    print(f'Adjusted R-Squared(y, yHat): {Adj_r2:0.4f}\n\n')
    # r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
    #  R^2 score is not well-defined with less than two samples
    
    
    print(f'mean_absolute_error(y, yHat):',
          f'{mean_absolute_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_absolute_error(yy, yHat_test):',
          f'{mean_absolute_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_error(y, yHat):',
          f'{mean_squared_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_error(yy, yHat_test):',
          f'{mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_log_error(y, yHat):',
          f'{mean_squared_log_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_log_error(yy, yHat_test):',
          f'{mean_squared_log_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    
    print(f'RMSE(y, yHat):',
          f'{np.sqrt( mean_squared_error(y.detach().numpy(), yHat.detach().numpy()) ):0.4f}\n')
    print(f'RMSE(yy, yHat_test):',
          f'{np.sqrt( mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()) ):0.4f}\n\n')

# %%
# date = np.datetime64("2000-01-01")
# date_strings = date.astype(str).split('-'). 
# # >> ['2000', '01', '01']

# year_int = int(date_strings[0])

# %%
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Out:
# --2022-08-05 17:53:50--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5230713 (5.0M) [text/plain]
# Saving to: ‘data.txt’
#
# data.txt            100%[===================>]   4.99M  --.-KB/s    in 0.01s
#
# 2022-08-05 17:53:50 (337 MB/s) - ‘data.txt’ saved [5230713/5230713]
#
# --2022-08-05 17:53:51--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37732 (37K) [text/plain]
# Saving to: ‘example_input.txt’
#
# example_input.txt   100%[===================>]  36.85K  --.-KB/s    in 0s
#
# 2022-08-05 17:53:52 (145 MB/s) - ‘example_input.txt’ saved [37732/37732]

# %%
# !ls
# Out:
# checkpoint.pth.tar  data.txt  example_input.txt  sample_data

# %% [markdown]
# 'text.txt'

# %% [markdown]
# [ 1-1-1800 to 31-12-2200 ]

# %% [markdown]
# [day condition] [month condition] [leap year condition] [decade condition] date

# %% [markdown]
# [MON] [DEC] [False] [196] 3-12-1962
# [THU] [DEC] [True] [204] 3-12-2048
# [WED] [JAN] [False] [181] 10-1-1810

# %%
# data = np.loadtxt(open('text.txt','r'),delimiter=' ')
# ori = pd.read_csv('./data/data.txt', sep=' ', header=None)

ori = pd.read_csv('data.txt', sep=' ', header=None)

# %%
ori.columns = ['day', 'month', 'leap_year', 'decade', 'date']

# %%
ori
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
# data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)
# # pd.to_datetime(data.date, infer_datetime_format=False)

# %%
ori.dtypes
# Out:
# day          object
# month        object
# leap_year    object
# decade       object
# date         object
# dtype: object

# %%
# data_backup = copy.deepcopy(ori)
data = copy.deepcopy(ori)

# %%
data
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
data.date
# Out:
# 0           1-1-1800
# 1           1-1-1801
# 2           1-1-1802
# 3           1-1-1803
# 4           1-1-1804
#              ...
# 146457    31-12-2196
# 146458    31-12-2197
# 146459    31-12-2198
# 146460    31-12-2199
# 146461    31-12-2200
# Name: date, Length: 146462, dtype: object

# %%
# # data['date'] = pd.date_range('3-12-2048', periods=10)
# # data['date'] = pd.date_range('12-3-1962', periods=10)

# # 1-1-1800 to 31-12-2200
# data['date'] = pd.date_range(start='1-1-1800',end='12-31-2200')


data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)

# # data.date = data.date.dt.strftime('%d-%m-%Y')
# # data.date = pd.to_datetime(data.date.dt.strftime('%d-%m-%Y'), format='%d-%m-%Y', infer_datetime_format=False)

# %%
data.dtypes
# Out:
# day                  object
# month                object
# leap_year            object
# decade               object
# date         datetime64[ns]
# dtype: object

# %%
data
# Out:
#           day  month leap_year decade       date
# 0       [WED]  [JAN]   [False]  [180] 1800-01-01
# 1       [THU]  [JAN]   [False]  [180] 1801-01-01
# 2       [FRI]  [JAN]   [False]  [180] 1802-01-01
# 3       [SAT]  [JAN]   [False]  [180] 1803-01-01
# 4       [SUN]  [JAN]    [True]  [180] 1804-01-01
# ...       ...    ...       ...    ...        ...
# 146457  [SAT]  [DEC]    [True]  [219] 2196-12-31
# 146458  [SUN]  [DEC]   [False]  [219] 2197-12-31
# 146459  [MON]  [DEC]   [False]  [219] 2198-12-31
# 146460  [TUE]  [DEC]   [False]  [219] 2199-12-31
# 146461  [WED]  [DEC]   [False]  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %%
map_leap_year = {'[False]': int(0), '[True]' : int(1)}

data.leap_year = data.leap_year.map(map_leap_year)

# data.leap_year = data.leap_year.astype(np.float64)

# %%
data
# Out:
#           day  month  leap_year decade       date
# 0       [WED]  [JAN]          0  [180] 1800-01-01
# 1       [THU]  [JAN]          0  [180] 1801-01-01
# 2       [FRI]  [JAN]          0  [180] 1802-01-01
# 3       [SAT]  [JAN]          0  [180] 1803-01-01
# 4       [SUN]  [JAN]          1  [180] 1804-01-01
# ...       ...    ...        ...    ...        ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31
# 146459  [MON]  [DEC]          0  [219] 2198-12-31
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31
# 146461  [WED]  [DEC]          0  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %% [markdown]
# date -> timestamp

# %%
data.date.iloc[0]
# Out:
# Timestamp('1800-01-01 00:00:00')

# %%
data['date_int'] = data['date'].dt.strftime("%Y%m%d").astype(np.int64)

# data['date_str'] = data['date'].dt.strftime("%Y%m%d")

# %%
# data['date_int'].map(str)
# data['date_int'].astype(str)

# %%
# date_max = data.date_int.max()
# data['date_normalized'] = data.date_int / date_max

# %%
data
# Out:
#           day  month  leap_year decade       date  date_int
# 0       [WED]  [JAN]          0  [180] 1800-01-01  18000101
# 1       [THU]  [JAN]          0  [180] 1801-01-01  18010101
# 2       [FRI]  [JAN]          0  [180] 1802-01-01  18020101
# 3       [SAT]  [JAN]          0  [180] 1803-01-01  18030101
# 4       [SUN]  [JAN]          1  [180] 1804-01-01  18040101
# ...       ...    ...        ...    ...        ...       ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31  21961231
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31  21971231
# 146459  [MON]  [DEC]          0  [219] 2198-12-31  21981231
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31  21991231
# 146461  [WED]  [DEC]          0  [220] 2200-12-31  22001231
#
# [146462 rows x 6 columns]

# %%
x = data.decade.iloc[0]
x
# Out:
# '[180]'

# %%
x.strip('[]')
# Out:
# '180'

# %%
data.decade = data.decade.apply(lambda x: x.strip('[]')).astype('int64')

# %%
# data.day = data.day.apply(lambda x: x.strip('[]'))
# data.month = data.month.apply(lambda x: x.strip('[]'))

# %%
map_day = {'[SAT]': int(0),
           '[SUN]': int(1),
           '[MON]': int(2),
           '[TUE]': int(3),
           '[WED]': int(4),
           '[THU]': int(5),
           '[FRI]': int(6)}

# %%
data['day_code'] = data.day.map(map_day)

# %%
scaler_day = RobustScaler()

x = data.day_code.values.reshape(-1, 1)

data['day_scaled'] = scaler_day.fit_transform(x).flatten()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled
# 0             0.25
# 1             0.50
# 2             0.75
# 3            -0.75
# 4            -0.50
# ...            ...
# 146457       -0.75
# 146458       -0.50
# 146459       -0.25
# 146460        0.00
# 146461        0.25
#
# [146462 rows x 8 columns]

# %%
data['day_sin'] = np.sin(data['day_code'] * (2 * np.pi / 7))
data['day_cos'] = np.cos(data['day_code'] * (2 * np.pi / 7))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos
# 0             0.25 -0.433884 -0.900969
# 1             0.50 -0.974928 -0.222521
# 2             0.75 -0.781831  0.623490
# 3            -0.75  0.000000  1.000000
# 4            -0.50  0.781831  0.623490
# ...            ...       ...       ...
# 146457       -0.75  0.000000  1.000000
# 146458       -0.50  0.781831  0.623490
# 146459       -0.25  0.974928 -0.222521
# 146460        0.00  0.433884 -0.900969
# 146461        0.25 -0.433884 -0.900969
#
# [146462 rows x 10 columns]

# %%
map_month = {'[JAN]' : 0,
             '[FEB]' : 1,
             '[MAR]' : 2,
             '[APR]' : 3,
             '[MAY]' : 4,
             '[JUN]' : 5,
             '[JUL]' : 6,
             '[AUG]' : 7,
             '[SEP]' : 8,
             '[OCT]' : 9,
             '[NOV]' : 10,
             '[DEC]' : 11}

# %%
data['month_code'] = data.month.map(map_month)

# %%
scaler_month = RobustScaler()

x = data.month_code.values.reshape(-1, 1)

data['month_scaled'] = scaler_month.fit_transform(x).flatten()

# %%
data['month_sin'] = np.sin(data['month_code'] * (2 * np.pi / 12))
data['month_cos'] = np.cos(data['month_code'] * (2 * np.pi / 12))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ...           ...
# 146457   0.866025
# 146458   0.866025
# 146459   0.866025
# 146460   0.866025
# 146461   0.866025
#
# [146462 rows x 14 columns]

# %%
scaler_decade = RobustScaler()

x = data.decade.values.reshape(-1, 1)

data['decade_scaled'] = scaler_decade.fit_transform(x).flatten()

# %%
# alpha = len(data.decade.unique())
alpha = (data.decade.iloc[-1] - data.decade.iloc[0]) + 1

data['decade_sin'] = np.sin(data['decade'] * (2 * np.pi / alpha))
data['decade_cos'] = np.cos(data['decade'] * (2 * np.pi / alpha))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %%
# data.date_normalized.min(), data.date_normalized.max()

# %%
# round(data.date_normalized.min()), round(data.date_normalized.max())

# %%
round(data.day_scaled.min()), round(data.day_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_sin.min()), round(data.day_sin.max())
# Out:
# (-1, 1)

# %%
round(data.day_cos.min()), round(data.day_cos.max())
# Out:
# (-1, 1)

# %%
round(data.month_scaled.min()), round(data.month_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.month_sin.min()), round(data.month_sin.max())
# Out:
# (-1, 1)

# %%
round(data.month_cos.min()), round(data.month_cos.max())
# Out:
# (-1, 1)

# %%
data.leap_year.min(), data.leap_year.max()
# Out:
# (0, 1)

# %%
round(data.decade_scaled.min()), round(data.decade_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.decade_sin.min()), round(data.decade_sin.max())
# Out:
# (-1, 1)

# %%
round(data.decade_cos.min()), round(data.decade_cos.max())
# Out:
# (-1, 1)

# %% [markdown]
# Boxplot

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.day.value_counts().plot(kind="bar")

# %%
data.month.value_counts().plot(kind="bar")

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
data.decade.value_counts().plot(kind="bar")

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %% [markdown]
# ['day_sin', 'day_cos', 'month_sin', 'month_cos', 'leap_year', 'decade_scaled']
# ['date_timestamp_scaled']

# %%
X = data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
          'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 0.25      , -0.43388374, -0.90096887, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.5       , -0.97492791, -0.22252093, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.75      , -0.78183148,  0.6234898 , ..., -1.        ,
#          0.63624244, -0.77148918],
#        ...,
#        [-0.25      ,  0.97492791, -0.22252093, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.        ,  0.43388374, -0.90096887, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.25      , -0.43388374, -0.90096887, ...,  1.        ,
#          0.74655322, -0.6653257 ]])

# %%
len(X)
# Out:
# 146462

# %%
X.shape
# Out:
# (146462, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()


ls = []

for s in data['date_int'].astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(data['date_int'])), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y = ll.values

Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 2, 0, ..., 2, 3, 1]])

# %%
len(Y)
# Out:
# 146462

# %%
Y.shape
# Out:
# (146462, 8)

# %%
# # leap = np.where(~X['leap_year'] == 1)[0]
# leap = np.where(X['leap_year'] == 1)[0]

# leap

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64


train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (146462, 10)
#
# Y: (146462, 8)
#
# Train data:   (102523, 10)
#
# Train labels: (102523, 8)
#
# Test data:    (43939, 10)
#
# Test labels:  (43939, 8)

# %%
102523 % 32, 102523 % 64
# Out:
# (27, 59)

# %%
class Model(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.input = nn.Linear(10, 32)

        self.fc1 = nn.Linear(32, 128)
        self.bnorm1 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 512)
        self.bnorm2 = nn.BatchNorm1d(512)

        self.fc3 = nn.Linear(512, 64)
        self.bnorm3 = nn.BatchNorm1d(64)

        self.fc4 = nn.Linear(64, 32)
        self.bnorm4 = nn.BatchNorm1d(32)


        self.output = nn.Linear(32, 8)



    def forward(self, x):


        # print(f'training={self.training}')

        x = F.relu( self.input(x) )

        x = F.relu(self.bnorm1(self.fc1(x)))
        x = F.dropout(x, p=0.25, training=self.training)

        x = F.relu(self.bnorm2(self.fc2(x)))
        x = F.dropout(x, p=0.4, training=self.training)

        x = F.relu(self.bnorm3(self.fc3(x)))
        x = F.dropout(x, p=0.1, training=self.training)

        x = F.relu(self.bnorm4(self.fc4(x)))
        x = F.dropout(x, p=0.05, training=self.training)


        x = F.relu(self.output(x))
        # x = self.output(x)
        


        return x

# %%
# test_x, test_y = next(iter(train_loader))

# print(f'X: {X.shape}\n')
# print(f'Y: {Y.shape}\n')

# %%
def train(model, numepochs):

    numepochs = numepochs

    model = model
    
    
    
    lossfun = nn.MSELoss()
    # lossfun = nn.L1Loss()


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0002, betas=(0.5, 0.999), weight_decay=1e-5)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.5, 0.999), weight_decay=1e-1)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-5)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=1e-9)


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
    
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    
    
    
    trainLoss = torch.zeros(numepochs)
    testLoss  = torch.zeros(numepochs)
    trainAcc  = torch.zeros(numepochs)
    # testAcc   = torch.zeros(numepochs)


    for epochi in range(numepochs):

        model.train() # switch to train mode

        batchLoss = []
        batchAcc  = []

        for X,y in train_loader:

            X = X.to(device)
            y = y.to(device)

            yHat = model(X)
            loss = lossfun(yHat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())
            # batchAcc.append( torch.mean(( yHat == y).float() ).item() )
            # batchAcc.append( torch.mean( (torch.abs(yHat - y) < 1).float() ).item() ) # <1 for rounding
            batchAcc.append( r2_score(y.detach().cpu().numpy(), yHat.detach().cpu().numpy()) )
            




        trainLoss[epochi] = np.mean(batchLoss)
        # trainAcc[epochi]  = 100*np.mean(batchAcc)
        trainAcc[epochi]  = np.mean(batchAcc)
        



        model.eval() # switch to test mode

        XX,yy = next(iter(test_loader))

        XX = XX.to(device)
        yy = yy.to(device)

        # forward pass and loss
        with torch.no_grad():
            yHat_test = model(XX)
            loss = lossfun(yHat_test, yy)


        testLoss[epochi] = loss.item()
        # testAcc[epochi]  = 100*torch.mean( (yHat_test == yy).float() ).item()
        # testAcc[epochi]  = 100*torch.mean( (torch.abs(yHat_test - yy) < 1).float() ).item()
        # testAcc[epochi]  = 100*r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
        


        # if (epochi + 1) % 5 == 0:
        print(f'Epoch {epochi+1}/{numepochs}, Train Loss: {loss.item():0.6f}, Test Loss: {loss.item():0.6f}')


        
    return trainLoss.cpu(), testLoss.cpu(), trainAcc.cpu(), yHat.cpu(), y.cpu(), yHat_test.cpu(), yy.cpu()

# %%
model = Model().to(device)

# test_hat = model(torch.randn(32,6))
# test_hat = model(test_x)

# print(test_hat.shape)


checkpoint = torch.load('checkpoint.pth.tar')
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
# for p in list(model.named_parameters()):
#     if 'weight' in p[0] and 'bnorm' not in p[0]:
#         nn.init.xavier_normal_(p[1].data)
#         print(p[0])
#         print(p[1].data.shape)

# %%
numepochs = 120

trainLoss1, testLoss1, trainAcc1, yHat1, y1, yHat_test1, yy1 = train(model, numepochs)
# Out:
# Epoch 1/120, Train Loss: 2.234396, Test Loss: 2.234396
# Epoch 2/120, Train Loss: 2.106644, Test Loss: 2.106644
# Epoch 3/120, Train Loss: 2.053349, Test Loss: 2.053349
# Epoch 4/120, Train Loss: 2.058144, Test Loss: 2.058144
# Epoch 5/120, Train Loss: 2.214136, Test Loss: 2.214136
# Epoch 6/120, Train Loss: 2.056202, Test Loss: 2.056202
# Epoch 7/120, Train Loss: 2.084572, Test Loss: 2.084572
# Epoch 8/120, Train Loss: 2.083748, Test Loss: 2.083748
# Epoch 9/120, Train Loss: 2.067258, Test Loss: 2.067258
# Epoch 10/120, Train Loss: 2.037630, Test Loss: 2.037630
# Epoch 11/120, Train Loss: 2.077608, Test Loss: 2.077608
# Epoch 12/120, Train Loss: 2.085200, Test Loss: 2.085200
# Epoch 13/120, Train Loss: 2.028764, Test Loss: 2.028764
# Epoch 14/120, Train Loss: 2.087657, Test Loss: 2.087657
# Epoch 15/120, Train Loss: 2.001023, Test Loss: 2.001023
# Epoch 16/120, Train Loss: 2.077268, Test Loss: 2.077268
# Epoch 17/120, Train Loss: 2.062173, Test Loss: 2.062173
# Epoch 18/120, Train Loss: 1.989697, Test Loss: 1.989697
# Epoch 19/120, Train Loss: 2.078393, Test Loss: 2.078393
# Epoch 20/120, Train Loss: 2.008702, Test Loss: 2.008702
# Epoch 21/120, Train Loss: 2.211963, Test Loss: 2.211963
# Epoch 22/120, Train Loss: 2.175495, Test Loss: 2.175495
# Epoch 23/120, Train Loss: 2.040176, Test Loss: 2.040176
# Epoch 24/120, Train Loss: 2.276028, Test Loss: 2.276028
# Epoch 25/120, Train Loss: 2.171516, Test Loss: 2.171516
# Epoch 26/120, Train Loss: 2.059583, Test Loss: 2.059583
# Epoch 27/120, Train Loss: 2.073066, Test Loss: 2.073066
# Epoch 28/120, Train Loss: 1.991670, Test Loss: 1.991670
# Epoch 29/120, Train Loss: 2.040567, Test Loss: 2.040567
# Epoch 30/120, Train Loss: 2.099703, Test Loss: 2.099703
# Epoch 31/120, Train Loss: 1.994857, Test Loss: 1.994857
# Epoch 32/120, Train Loss: 2.258945, Test Loss: 2.258945
# Epoch 33/120, Train Loss: 2.061164, Test Loss: 2.061164
# Epoch 34/120, Train Loss: 2.147632, Test Loss: 2.147632
# Epoch 35/120, Train Loss: 2.189554, Test Loss: 2.189554
# Epoch 36/120, Train Loss: 2.049666, Test Loss: 2.049666
# Epoch 37/120, Train Loss: 2.022875, Test Loss: 2.022875
# Epoch 38/120, Train Loss: 1.991756, Test Loss: 1.991756
# Epoch 39/120, Train Loss: 2.038104, Test Loss: 2.038104
# Epoch 40/120, Train Loss: 2.053190, Test Loss: 2.053190
# Epoch 41/120, Train Loss: 2.245347, Test Loss: 2.245347
# Epoch 42/120, Train Loss: 2.050615, Test Loss: 2.050615
# Epoch 43/120, Train Loss: 2.089363, Test Loss: 2.089363
# Epoch 44/120, Train Loss: 2.015184, Test Loss: 2.015184
# Epoch 45/120, Train Loss: 2.061433, Test Loss: 2.061433
# Epoch 46/120, Train Loss: 2.030354, Test Loss: 2.030354
# Epoch 47/120, Train Loss: 2.132598, Test Loss: 2.132598
# Epoch 48/120, Train Loss: 1.999988, Test Loss: 1.999988
# Epoch 49/120, Train Loss: 2.191709, Test Loss: 2.191709
# Epoch 50/120, Train Loss: 2.040962, Test Loss: 2.040962
# Epoch 51/120, Train Loss: 2.001029, Test Loss: 2.001029
# Epoch 52/120, Train Loss: 2.008677, Test Loss: 2.008677
# Epoch 53/120, Train Loss: 2.007746, Test Loss: 2.007746
# Epoch 54/120, Train Loss: 2.079984, Test Loss: 2.079984
# Epoch 55/120, Train Loss: 2.054629, Test Loss: 2.054629
# Epoch 56/120, Train Loss: 2.054048, Test Loss: 2.054048
# Epoch 57/120, Train Loss: 2.004961, Test Loss: 2.004961
# Epoch 58/120, Train Loss: 2.153211, Test Loss: 2.153211
# Epoch 59/120, Train Loss: 1.994236, Test Loss: 1.994236
# Epoch 60/120, Train Loss: 2.026425, Test Loss: 2.026425
# Epoch 61/120, Train Loss: 2.011499, Test Loss: 2.011499
# Epoch 62/120, Train Loss: 2.108923, Test Loss: 2.108923
# Epoch 63/120, Train Loss: 2.223170, Test Loss: 2.223170
# Epoch 64/120, Train Loss: 2.127941, Test Loss: 2.127941
# Epoch 65/120, Train Loss: 2.024180, Test Loss: 2.024180
# Epoch 66/120, Train Loss: 2.021220, Test Loss: 2.021220
# Epoch 67/120, Train Loss: 2.163466, Test Loss: 2.163466
# Epoch 68/120, Train Loss: 2.131739, Test Loss: 2.131739
# Epoch 69/120, Train Loss: 2.020598, Test Loss: 2.020598
# Epoch 70/120, Train Loss: 2.013045, Test Loss: 2.013045
# Epoch 71/120, Train Loss: 2.023223, Test Loss: 2.023223
# Epoch 72/120, Train Loss: 1.993894, Test Loss: 1.993894
# Epoch 73/120, Train Loss: 2.087888, Test Loss: 2.087888
# Epoch 74/120, Train Loss: 2.011164, Test Loss: 2.011164
# Epoch 75/120, Train Loss: 2.047258, Test Loss: 2.047258
# Epoch 76/120, Train Loss: 2.016854, Test Loss: 2.016854
# Epoch 77/120, Train Loss: 1.991497, Test Loss: 1.991497
# Epoch 78/120, Train Loss: 2.021873, Test Loss: 2.021873
# Epoch 79/120, Train Loss: 1.958360, Test Loss: 1.958360
# Epoch 80/120, Train Loss: 2.001355, Test Loss: 2.001355
# Epoch 81/120, Train Loss: 2.196610, Test Loss: 2.196610
# Epoch 82/120, Train Loss: 2.033759, Test Loss: 2.033759
# Epoch 83/120, Train Loss: 1.984419, Test Loss: 1.984419
# Epoch 84/120, Train Loss: 1.977565, Test Loss: 1.977565
# Epoch 85/120, Train Loss: 1.969059, Test Loss: 1.969059
# Epoch 86/120, Train Loss: 2.017557, Test Loss: 2.017557
# Epoch 87/120, Train Loss: 1.977969, Test Loss: 1.977969
# Epoch 88/120, Train Loss: 2.195691, Test Loss: 2.195691
# Epoch 89/120, Train Loss: 1.987916, Test Loss: 1.987916
# Epoch 90/120, Train Loss: 2.001559, Test Loss: 2.001559
# Epoch 91/120, Train Loss: 2.007612, Test Loss: 2.007612
# Epoch 92/120, Train Loss: 2.026206, Test Loss: 2.026206
# Epoch 93/120, Train Loss: 1.996505, Test Loss: 1.996505
# Epoch 94/120, Train Loss: 1.969999, Test Loss: 1.969999
# Epoch 95/120, Train Loss: 2.172014, Test Loss: 2.172014
# Epoch 96/120, Train Loss: 2.006161, Test Loss: 2.006161
# Epoch 97/120, Train Loss: 2.009773, Test Loss: 2.009773
# Epoch 98/120, Train Loss: 1.987216, Test Loss: 1.987216
# Epoch 99/120, Train Loss: 1.977953, Test Loss: 1.977953
# Epoch 100/120, Train Loss: 1.979140, Test Loss: 1.979140
# Epoch 101/120, Train Loss: 2.000974, Test Loss: 2.000974
# Epoch 102/120, Train Loss: 1.994897, Test Loss: 1.994897
# Epoch 103/120, Train Loss: 2.015068, Test Loss: 2.015068
# Epoch 104/120, Train Loss: 2.009727, Test Loss: 2.009727
# Epoch 105/120, Train Loss: 2.003209, Test Loss: 2.003209
# Epoch 106/120, Train Loss: 2.188856, Test Loss: 2.188856
# Epoch 107/120, Train Loss: 2.046120, Test Loss: 2.046120
# Epoch 108/120, Train Loss: 2.019987, Test Loss: 2.019987
# Epoch 109/120, Train Loss: 2.035720, Test Loss: 2.035720
# Epoch 110/120, Train Loss: 2.004719, Test Loss: 2.004719
# Epoch 111/120, Train Loss: 2.012132, Test Loss: 2.012132
# Epoch 112/120, Train Loss: 2.041040, Test Loss: 2.041040
# Epoch 113/120, Train Loss: 2.038321, Test Loss: 2.038321
# Epoch 114/120, Train Loss: 2.048751, Test Loss: 2.048751
# Epoch 115/120, Train Loss: 2.034434, Test Loss: 2.034434
# Epoch 116/120, Train Loss: 1.980485, Test Loss: 1.980485
# Epoch 117/120, Train Loss: 1.991175, Test Loss: 1.991175
# Epoch 118/120, Train Loss: 2.035033, Test Loss: 2.035033
# Epoch 119/120, Train Loss: 2.158657, Test Loss: 2.158657
# Epoch 120/120, Train Loss: 2.048449, Test Loss: 2.048449

# %%
# r2_score(y.detach().numpy(), yHat.detach().numpy())
# type(r2_score(y.detach(), yHat.detach()))

# %%
# torch.mean( r2_score(y.detach().numpy(), yHat.detach().numpy()) ).item()

# %%
trainLoss1, testLoss1, trainAcc1
# Out:
# (tensor([2.7585, 2.5364, 2.4795, 2.4446, 2.4011, 2.3919, 2.3770, 2.3718, 2.3703,
#          2.3577, 2.3583, 2.3534, 2.3462, 2.3424, 2.3412, 2.3355, 2.3356, 2.3373,
#          2.3323, 2.3281, 2.3266, 2.3297, 2.3314, 2.3263, 2.3257, 2.3245, 2.3232,
#          2.3225, 2.3224, 2.3219, 2.3183, 2.3208, 2.3175, 2.3182, 2.3168, 2.3182,
#          2.3139, 2.3143, 2.3168, 2.3124, 2.3134, 2.3138, 2.3114, 2.3142, 2.3074,
#          2.3124, 2.3099, 2.3085, 2.3105, 2.3135, 2.3074, 2.3090, 2.3073, 2.3066,
#          2.3087, 2.3048, 2.3085, 2.3056, 2.3096, 2.3059, 2.3048, 2.3052, 2.3059,
#          2.3053, 2.3047, 2.3043, 2.3058, 2.3018, 2.3036, 2.3015, 2.3017, 2.3029,
#          2.3009, 2.3022, 2.2993, 2.2993, 2.3012, 2.2985, 2.2991, 2.2998, 2.2976,
#          2.2979, 2.2991, 2.2977, 2.2975, 2.2979, 2.2984, 2.2985, 2.2984, 2.2981,
#          2.2975, 2.2965, 2.2977, 2.2974, 2.2974, 2.2971, 2.2958, 2.2971, 2.2956,
#          2.2944, 2.2966, 2.2959, 2.2964, 2.2946, 2.2946, 2.2962, 2.2929, 2.2958,
#          2.2947, 2.2962, 2.2936, 2.2941, 2.2952, 2.2954, 2.2967, 2.2964, 2.2922,
#          2.2943, 2.2940, 2.2949]),
#  tensor([2.2344, 2.1066, 2.0533, 2.0581, 2.2141, 2.0562, 2.0846, 2.0837, 2.0673,
#          2.0376, 2.0776, 2.0852, 2.0288, 2.0877, 2.0010, 2.0773, 2.0622, 1.9897,
#          2.0784, 2.0087, 2.2120, 2.1755, 2.0402, 2.2760, 2.1715, 2.0596, 2.0731,
#          1.9917, 2.0406, 2.0997, 1.9949, 2.2589, 2.0612, 2.1476, 2.1896, 2.0497,
#          2.0229, 1.9918, 2.0381, 2.0532, 2.2453, 2.0506, 2.0894, 2.0152, 2.0614,
#          2.0304, 2.1326, 2.0000, 2.1917, 2.0410, 2.0010, 2.0087, 2.0077, 2.0800,
#          2.0546, 2.0540, 2.0050, 2.1532, 1.9942, 2.0264, 2.0115, 2.1089, 2.2232,
#          2.1279, 2.0242, 2.0212, 2.1635, 2.1317, 2.0206, 2.0130, 2.0232, 1.9939,
#          2.0879, 2.0112, 2.0473, 2.0169, 1.9915, 2.0219, 1.9584, 2.0014, 2.1966,
#          2.0338, 1.9844, 1.9776, 1.9691, 2.0176, 1.9780, 2.1957, 1.9879, 2.0016,
#          2.0076, 2.0262, 1.9965, 1.9700, 2.1720, 2.0062, 2.0098, 1.9872, 1.9780,
#          1.9791, 2.0010, 1.9949, 2.0151, 2.0097, 2.0032, 2.1889, 2.0461, 2.0200,
#          2.0357, 2.0047, 2.0121, 2.0410, 2.0383, 2.0488, 2.0344, 1.9805, 1.9912,
#          2.0350, 2.1587, 2.0484]),
#  tensor([0.4532, 0.4867, 0.4951, 0.4997, 0.5074, 0.5092, 0.5119, 0.5133, 0.5131,
#          0.5157, 0.5159, 0.5173, 0.5171, 0.5174, 0.5177, 0.5187, 0.5191, 0.5183,
#          0.5198, 0.5207, 0.5208, 0.5196, 0.5203, 0.5208, 0.5209, 0.5210, 0.5216,
#          0.5218, 0.5223, 0.5217, 0.5225, 0.5221, 0.5222, 0.5219, 0.5227, 0.5224,
#          0.5233, 0.5235, 0.5229, 0.5239, 0.5227, 0.5227, 0.5234, 0.5230, 0.5243,
#          0.5231, 0.5238, 0.5240, 0.5236, 0.5232, 0.5241, 0.5240, 0.5247, 0.5247,
#          0.5246, 0.5248, 0.5239, 0.5243, 0.5238, 0.5241, 0.5248, 0.5247, 0.5244,
#          0.5249, 0.5243, 0.5242, 0.5249, 0.5251, 0.5250, 0.5252, 0.5254, 0.5249,
#          0.5254, 0.5251, 0.5255, 0.5254, 0.5251, 0.5251, 0.5255, 0.5262, 0.5263,
#          0.5264, 0.5257, 0.5261, 0.5255, 0.5261, 0.5260, 0.5261, 0.5258, 0.5258,
#          0.5259, 0.5262, 0.5261, 0.5264, 0.5251, 0.5257, 0.5265, 0.5254, 0.5267,
#          0.5261, 0.5258, 0.5262, 0.5265, 0.5267, 0.5268, 0.5261, 0.5274, 0.5266,
#          0.5269, 0.5262, 0.5264, 0.5256, 0.5257, 0.5254, 0.5260, 0.5258, 0.5262,
#          0.5262, 0.5257, 0.5262]))

# %%
# batchLoss

# %%
# batchAcc

# %%
# yHat.shape, y.shape

# %%
# yHat_test.shape, yy.shape

# %%
yHat1.flatten(), y1.flatten()
# Out:
# (tensor([1.6515, 3.1241, 8.7459, 4.3874, 0.0000, 2.5671, 1.1244, 4.4676, 1.8480,
#          0.0000, 7.6113, 4.4602, 0.3300, 1.9973, 1.1378, 4.5340, 1.9011, 0.0000,
#          3.8149, 4.5388, 0.0000, 3.1278, 1.0943, 4.5827, 1.9835, 0.1406, 4.7544,
#          4.5812, 0.0000, 6.8582, 1.0430, 4.4930, 1.8653, 0.8829, 7.9250, 4.5183,
#          0.0000, 6.1259, 1.1956, 4.3978, 0.9203, 9.0784, 5.1475, 4.4683, 0.7411,
#          0.0000, 1.0983, 4.4917, 0.9808, 8.2512, 0.0000, 4.4203, 0.0138, 2.6328,
#          1.1001, 4.6433, 2.0154, 0.0000, 7.9509, 4.4708, 0.7274, 0.0000, 1.1424,
#          4.6667, 0.9520, 9.0969, 6.6398, 4.3841, 0.4750, 2.0747, 1.0991, 4.4030,
#          1.0886, 8.6784, 0.0347, 4.4187, 0.0000, 6.1591, 1.1353, 4.5423, 1.9850,
#          0.4625, 6.1710, 4.4890, 0.0000, 8.1586, 0.9942, 4.5155, 1.9700, 0.6556,
#          8.5739, 4.4321, 0.5344, 1.5569, 1.0982, 4.4669, 1.8926, 0.0000, 6.5701,
#          4.4830, 0.0000, 3.9995, 1.1493, 4.5338, 1.9947, 0.0000, 8.2426, 4.4908,
#          0.5915, 0.4127, 1.1648, 4.5326, 0.9473, 9.1519, 0.0000, 4.3824, 0.0000,
#          6.8286, 1.0789, 4.5905, 0.9743, 8.1714, 0.0000, 4.3142, 0.0000, 9.6256,
#          0.9810, 4.7875, 0.9421, 9.0913, 2.8885, 4.4196, 0.0000, 5.3001, 1.1025,
#          4.4724, 1.9774, 0.4054, 4.2656, 4.5776, 0.6591, 0.5449, 1.0639, 4.5634,
#          2.0012, 1.0152, 5.7032, 4.5944, 1.0299, 0.0000, 1.0604, 4.6498, 1.8383,
#          0.0000, 8.3881, 4.4099, 0.5120, 1.3077, 1.1368, 4.4834, 1.0844, 8.7597,
#          6.8255, 4.4135, 0.6136, 0.1697, 1.1358, 4.3946, 0.9395, 9.1446, 0.2637,
#          4.3843, 0.0000, 7.7116, 1.0316, 4.5531, 1.0081, 8.1986, 0.0000, 4.3512,
#          0.0000, 8.5057, 1.0125, 4.6836, 0.9946, 8.1501, 0.0000, 4.4173, 0.5717,
#          1.3792, 1.1186, 4.6898, 0.9696, 7.9407, 9.0466, 4.3533, 0.0000, 5.1296,
#          1.1306, 4.3531, 0.9786, 7.9034, 7.2510, 4.4526, 0.5037, 1.4796, 1.1172,
#          4.3615, 1.9173, 0.8093, 1.1296, 4.5726, 0.0000, 6.5980, 1.0903, 4.5603,
#          0.9631, 8.4734, 4.1707, 4.4646, 0.0000, 4.2837, 1.0938, 4.4284, 1.9963,
#          0.0000, 0.0000, 4.5161, 0.0000, 8.5620, 1.0336, 4.7289, 1.9344, 0.7805,
#          1.9750, 4.5740, 0.8205, 0.0000, 1.0845, 4.6780, 0.9921, 7.8912, 4.2272,
#          4.4711, 0.0000, 8.4495, 0.9998, 4.4701, 2.0528, 0.0000, 4.1241, 4.5970,
#          0.0000, 4.4500, 1.0995, 4.5992], grad_fn=<ReshapeAliasBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
yHat_test1, yy1
# Out:
# (tensor([[1.1053, 7.7933, 0.9414, 4.4494, 0.0000, 5.6383, 1.1199, 4.5413]]),
#  tensor([[1., 8., 1., 6., 0., 6., 0., 1.]]))

# %%
yy1
# Out:
# tensor([[1., 8., 1., 6., 0., 6., 0., 1.]])

# %%
(yHat_test1).round()
# Out:
# tensor([[1., 8., 1., 4., 0., 6., 1., 5.]])

# %%
(yHat1.flatten()).round(), (y1.flatten()).round()
# Out:
# (tensor([ 2.,  3.,  9.,  4.,  0.,  3.,  1.,  4.,  2.,  0.,  8.,  4.,  0.,  2.,
#           1.,  5.,  2.,  0.,  4.,  5.,  0.,  3.,  1.,  5.,  2.,  0.,  5.,  5.,
#           0.,  7.,  1.,  4.,  2.,  1.,  8.,  5.,  0.,  6.,  1.,  4.,  1.,  9.,
#           5.,  4.,  1.,  0.,  1.,  4.,  1.,  8.,  0.,  4.,  0.,  3.,  1.,  5.,
#           2.,  0.,  8.,  4.,  1.,  0.,  1.,  5.,  1.,  9.,  7.,  4.,  0.,  2.,
#           1.,  4.,  1.,  9.,  0.,  4.,  0.,  6.,  1.,  5.,  2.,  0.,  6.,  4.,
#           0.,  8.,  1.,  5.,  2.,  1.,  9.,  4.,  1.,  2.,  1.,  4.,  2.,  0.,
#           7.,  4.,  0.,  4.,  1.,  5.,  2.,  0.,  8.,  4.,  1.,  0.,  1.,  5.,
#           1.,  9.,  0.,  4.,  0.,  7.,  1.,  5.,  1.,  8.,  0.,  4.,  0., 10.,
#           1.,  5.,  1.,  9.,  3.,  4.,  0.,  5.,  1.,  4.,  2.,  0.,  4.,  5.,
#           1.,  1.,  1.,  5.,  2.,  1.,  6.,  5.,  1.,  0.,  1.,  5.,  2.,  0.,
#           8.,  4.,  1.,  1.,  1.,  4.,  1.,  9.,  7.,  4.,  1.,  0.,  1.,  4.,
#           1.,  9.,  0.,  4.,  0.,  8.,  1.,  5.,  1.,  8.,  0.,  4.,  0.,  9.,
#           1.,  5.,  1.,  8.,  0.,  4.,  1.,  1.,  1.,  5.,  1.,  8.,  9.,  4.,
#           0.,  5.,  1.,  4.,  1.,  8.,  7.,  4.,  1.,  1.,  1.,  4.,  2.,  1.,
#           1.,  5.,  0.,  7.,  1.,  5.,  1.,  8.,  4.,  4.,  0.,  4.,  1.,  4.,
#           2.,  0.,  0.,  5.,  0.,  9.,  1.,  5.,  2.,  1.,  2.,  5.,  1.,  0.,
#           1.,  5.,  1.,  8.,  4.,  4.,  0.,  8.,  1.,  4.,  2.,  0.,  4.,  5.,
#           0.,  4.,  1.,  5.], grad_fn=<RoundBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
print_score(X.shape, yHat1, y1, yHat_test1, yy1)
# Out:
# Adjusted R-Squared(y, yHat): 0.5215
#
#
# mean_absolute_error(y, yHat): 0.9021
#
# mean_absolute_error(yy, yHat_test): 0.8680
#
#
# mean_squared_error(y, yHat): 2.4311
#
# mean_squared_error(yy, yHat_test): 2.0484
#
#
# mean_squared_log_error(y, yHat): 0.1923
#
# mean_squared_log_error(yy, yHat_test): 0.2091
#
#
# RMSE(y, yHat): 1.5592
#
# RMSE(yy, yHat_test): 1.4312

# %%
# create a 1D smoothing filter
def smooth(x, k=15):
    return np.convolve(x, np.ones(k)/k, mode='same')

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss1.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc1, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat1.detach().T, y1.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc1.jpg", bbox_inches='tight')


plt.show()

# %%
data.leap_year.value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
resampler = SMOTE(k_neighbors=20, random_state=0)

# %%
X_res, y_res = resampler.fit_resample(data[['day_code', 'month_code', 'decade', 'date_int']], data['leap_year'])

# %%
y_res.value_counts()
# Out:
# 0    110960
# 1    110960
# Name: leap_year, dtype: int64

# %%
data['leap_year'].value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 221915    1
# 221916    1
# 221917    1
# 221918    1
# 221919    1
# Name: leap_year, Length: 221920, dtype: int64

# %%
X_res
# Out:
#         day_code  month_code  decade  date_int
# 0              4           0     180  18000101
# 1              5           0     180  18010101
# 2              6           0     180  18020101
# 3              0           0     180  18030101
# 4              1           0     180  18040101
# ...          ...         ...     ...       ...
# 221915         0           5     188  18880618
# 221916         2           6     188  18840705
# 221917         5           2     218  21800323
# 221918         1           5     199  19960602
# 221919         1           4     219  21960520
#
# [221920 rows x 4 columns]

# %%
X_smote = X_res.assign(leap_year=y_res)

# %%
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221915         0           5     188  18880618          1
# 221916         2           6     188  18840705          1
# 221917         5           2     218  21800323          1
# 221918         1           5     199  19960602          1
# 221919         1           4     219  21960520          1
#
# [221920 rows x 5 columns]

# %% [markdown]
# Drop 220 decade

# %%
# data.decade.value_counts().plot(kind="bar")
X_smote.decade.value_counts().plot(kind="bar")

# %%
# data.decade.value_counts()[-5:]
X_smote.decade.value_counts()[-5:]
# Out:
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# 220     365
# Name: decade, dtype: int64

# %%
X_smote = X_smote.drop(X_smote.index[X_smote['decade'] == 220]).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221550         0           5     188  18880618          1
# 221551         2           6     188  18840705          1
# 221552         5           2     218  21800323          1
# 221553         1           5     199  19960602          1
# 221554         1           4     219  21960520          1
#
# [221555 rows x 5 columns]

# %%
X_smote.decade.value_counts().plot(kind="bar")

# %%
X_smote.decade.value_counts()[-5:]
# Out:
# 209    5174
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# Name: decade, dtype: int64

# %% [markdown]
# code is required to only work for dates in the range  [ 1-1-1800 to 31-12-2200 ]

# %%
X_smote.date_int.max()
# Out:
# 21991231

# %%
datetime.datetime.strptime(str(X_smote.date_int.max()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '31-12-2199'

# %%
X_smote.date_int.min()
# Out:
# 18000101

# %%
datetime.datetime.strptime(str(X_smote.date_int.min()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '01-01-1800'

# %%
Y_smote = X_smote['date_int']
Y_smote
# Out:
# 0         18000101
# 1         18010101
# 2         18020101
# 3         18030101
# 4         18040101
#             ...
# 221550    18880618
# 221551    18840705
# 221552    21800323
# 221553    19960602
# 221554    21960520
# Name: date_int, Length: 221555, dtype: int64

# %%
X_smote = X_smote.drop('date_int', axis=1).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  leap_year
# 0              4           0     180          0
# 1              5           0     180          0
# 2              6           0     180          0
# 3              0           0     180          0
# 4              1           0     180          1
# ...          ...         ...     ...        ...
# 221550         0           5     188          1
# 221551         2           6     188          1
# 221552         5           2     218          1
# 221553         1           5     199          1
# 221554         1           4     219          1
#
# [221555 rows x 4 columns]

# %%
Y_smote = Y_smote.reset_index(drop=True)

ls = []

for s in Y_smote.astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(Y_smote)), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y_smote = ll.values

Y_smote
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
# data.index[data['leap_year'] == 1].tolist()
# data.index[data['leap_year'] == 1]

# %%
# for i,idx in enumerate(data['leap_year'].tolist()):
#     print(i, idx)

# %% [markdown]
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1 <---
# 5 0
# 6 0
# 7 0
# 8 1 <---
# 9 0
# 10 0
# 11 0
# 12 1 <---
# 13 0
# 14 0
# 15 0
# 16 1 <---
# 17 0
# 18 0
# 19 0
# 20 1 <---
# 21 0
# 22 0
# 23 0
# 24 1 <---
# 25 0
# 26 0
# 27 0
# 28 1 <---
# 29 0
# 30 0

# %%
scaler_day_smote = RobustScaler()

x = X_smote.day_code.values.reshape(-1, 1)

X_smote['day_scaled'] = scaler_day_smote.fit_transform(x).flatten()

# %%
X_smote['day_sin'] = np.sin(X_smote['day_code'] * (2 * np.pi / 7))
X_smote['day_cos'] = np.cos(X_smote['day_code'] * (2 * np.pi / 7))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos
# 0      -0.900969
# 1      -0.222521
# 2       0.623490
# 3       1.000000
# 4       0.623490
# ...          ...
# 221550  1.000000
# 221551 -0.222521
# 221552 -0.222521
# 221553  0.623490
# 221554  0.623490
#
# [221555 rows x 7 columns]

# %%
scaler_month_smote = RobustScaler()

x = X_smote.month_code.values.reshape(-1, 1)

X_smote['month_scaled'] = scaler_month_smote.fit_transform(x).flatten()

# %%
X_smote['month_sin'] = np.sin(X_smote['month_code'] * (2 * np.pi / 12))
X_smote['month_cos'] = np.cos(X_smote['month_code'] * (2 * np.pi / 12))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos
# 0      -0.900969     -1.000000  0.000000e+00   1.000000
# 1      -0.222521     -1.000000  0.000000e+00   1.000000
# 2       0.623490     -1.000000  0.000000e+00   1.000000
# 3       1.000000     -1.000000  0.000000e+00   1.000000
# 4       0.623490     -1.000000  0.000000e+00   1.000000
# ...          ...           ...           ...        ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000
#
# [221555 rows x 10 columns]

# %%
scaler_decade_smote = RobustScaler()

x = X_smote.decade.values.reshape(-1, 1)

X_smote['decade_scaled'] = scaler_decade_smote.fit_transform(x).flatten()

# %%
# alpha_smote = len(X_smote.decade.unique())
alpha_smote = (X_smote.decade.iloc[-1] - X_smote.decade.iloc[0]) + 1

X_smote['decade_sin'] = np.sin(X_smote['decade'] * (2 * np.pi / alpha_smote))
X_smote['decade_cos'] = np.cos(X_smote['decade'] * (2 * np.pi / alpha_smote))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos  decade_scaled  \
# 0      -0.900969     -1.000000  0.000000e+00   1.000000      -1.052632
# 1      -0.222521     -1.000000  0.000000e+00   1.000000      -1.052632
# 2       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# 3       1.000000     -1.000000  0.000000e+00   1.000000      -1.052632
# 4       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# ...          ...           ...           ...        ...            ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025      -0.631579
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000      -0.631579
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000       0.947368
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025      -0.052632
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000       1.000000
#
#           decade_sin  decade_cos
# 0       1.102182e-15   -1.000000
# 1       1.102182e-15   -1.000000
# 2       1.102182e-15   -1.000000
# 3       1.102182e-15   -1.000000
# 4       1.102182e-15   -1.000000
# ...              ...         ...
# 221550 -9.510565e-01   -0.309017
# 221551 -9.510565e-01   -0.309017
# 221552  3.090170e-01   -0.951057
# 221553 -1.564345e-01    0.987688
# 221554  1.564345e-01   -0.987688
#
# [221555 rows x 13 columns]

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
X = X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 3.33333333e-01, -4.33883739e-01, -9.00968868e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 1.00000000e+00, -7.81831482e-01,  6.23489802e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        ...,
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#          9.47368421e-01,  3.09016994e-01, -9.51056516e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#         -5.26315789e-02, -1.56434465e-01,  9.87688341e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#          1.00000000e+00,  1.56434465e-01, -9.87688341e-01]])

# %%
X.shape
# Out:
# (221555, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()
# Y = data['date_normalized'].values.reshape(-1, 1)
Y = Y_smote


Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
Y.shape
# Out:
# (221555, 8)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64

train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (221555, 10)
#
# Y: (221555, 8)
#
# Train data:   (155088, 10)
#
# Train labels: (155088, 8)
#
# Test data:    (66467, 10)
#
# Test labels:  (66467, 8)

# %%
model_smote = Model().to(device)


# checkpoint = torch.load('checkpoint.pth.tar')
model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
# Out:
# <All keys matched successfully>

# %%
numepochs = 120

trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model_smote, numepochs)
# Out:
# Epoch 1/120, Train Loss: 4.095503, Test Loss: 4.095503
# Epoch 2/120, Train Loss: 4.182442, Test Loss: 4.182442
# Epoch 3/120, Train Loss: 4.181900, Test Loss: 4.181900
# Epoch 4/120, Train Loss: 4.034262, Test Loss: 4.034262
# Epoch 5/120, Train Loss: 3.933705, Test Loss: 3.933705
# Epoch 6/120, Train Loss: 3.943250, Test Loss: 3.943250
# Epoch 7/120, Train Loss: 3.945699, Test Loss: 3.945699
# Epoch 8/120, Train Loss: 3.924235, Test Loss: 3.924235
# Epoch 9/120, Train Loss: 3.983541, Test Loss: 3.983541
# Epoch 10/120, Train Loss: 4.056945, Test Loss: 4.056945
# Epoch 11/120, Train Loss: 4.056983, Test Loss: 4.056983
# Epoch 12/120, Train Loss: 4.003517, Test Loss: 4.003517
# Epoch 13/120, Train Loss: 4.070236, Test Loss: 4.070236
# Epoch 14/120, Train Loss: 3.989597, Test Loss: 3.989597
# Epoch 15/120, Train Loss: 3.977016, Test Loss: 3.977016
# Epoch 16/120, Train Loss: 3.937398, Test Loss: 3.937398
# Epoch 17/120, Train Loss: 3.930883, Test Loss: 3.930883
# Epoch 18/120, Train Loss: 3.891062, Test Loss: 3.891062
# Epoch 19/120, Train Loss: 3.914633, Test Loss: 3.914633
# Epoch 20/120, Train Loss: 4.012462, Test Loss: 4.012462
# Epoch 21/120, Train Loss: 4.009582, Test Loss: 4.009582
# Epoch 22/120, Train Loss: 3.998351, Test Loss: 3.998351
# Epoch 23/120, Train Loss: 3.967939, Test Loss: 3.967939
# Epoch 24/120, Train Loss: 3.958943, Test Loss: 3.958943
# Epoch 25/120, Train Loss: 4.028003, Test Loss: 4.028003
# Epoch 26/120, Train Loss: 4.039221, Test Loss: 4.039221
# Epoch 27/120, Train Loss: 4.037125, Test Loss: 4.037125
# Epoch 28/120, Train Loss: 4.084659, Test Loss: 4.084659
# Epoch 29/120, Train Loss: 4.053150, Test Loss: 4.053150
# Epoch 30/120, Train Loss: 4.163548, Test Loss: 4.163548
# Epoch 31/120, Train Loss: 4.032524, Test Loss: 4.032524
# Epoch 32/120, Train Loss: 4.050380, Test Loss: 4.050380
# Epoch 33/120, Train Loss: 3.996570, Test Loss: 3.996570
# Epoch 34/120, Train Loss: 4.020191, Test Loss: 4.020191
# Epoch 35/120, Train Loss: 4.054465, Test Loss: 4.054465
# Epoch 36/120, Train Loss: 3.980033, Test Loss: 3.980033
# Epoch 37/120, Train Loss: 4.067998, Test Loss: 4.067998
# Epoch 38/120, Train Loss: 3.969487, Test Loss: 3.969487
# Epoch 39/120, Train Loss: 4.039256, Test Loss: 4.039256
# Epoch 40/120, Train Loss: 3.977055, Test Loss: 3.977055
# Epoch 41/120, Train Loss: 4.013880, Test Loss: 4.013880
# Epoch 42/120, Train Loss: 4.001421, Test Loss: 4.001421
# Epoch 43/120, Train Loss: 4.057238, Test Loss: 4.057238
# Epoch 44/120, Train Loss: 4.008458, Test Loss: 4.008458
# Epoch 45/120, Train Loss: 3.989875, Test Loss: 3.989875
# Epoch 46/120, Train Loss: 4.060482, Test Loss: 4.060482
# Epoch 47/120, Train Loss: 3.941628, Test Loss: 3.941628
# Epoch 48/120, Train Loss: 4.023123, Test Loss: 4.023123
# Epoch 49/120, Train Loss: 3.987972, Test Loss: 3.987972
# Epoch 50/120, Train Loss: 4.011283, Test Loss: 4.011283
# Epoch 51/120, Train Loss: 3.955932, Test Loss: 3.955932
# Epoch 52/120, Train Loss: 4.098703, Test Loss: 4.098703
# Epoch 53/120, Train Loss: 4.016921, Test Loss: 4.016921
# Epoch 54/120, Train Loss: 4.021540, Test Loss: 4.021540
# Epoch 55/120, Train Loss: 4.022509, Test Loss: 4.022509
# Epoch 56/120, Train Loss: 4.005706, Test Loss: 4.005706
# Epoch 57/120, Train Loss: 4.056046, Test Loss: 4.056046
# Epoch 58/120, Train Loss: 4.010540, Test Loss: 4.010540
# Epoch 59/120, Train Loss: 3.979706, Test Loss: 3.979706
# Epoch 60/120, Train Loss: 4.081203, Test Loss: 4.081203
# Epoch 61/120, Train Loss: 4.037796, Test Loss: 4.037796
# Epoch 62/120, Train Loss: 4.037741, Test Loss: 4.037741
# Epoch 63/120, Train Loss: 4.010230, Test Loss: 4.010230
# Epoch 64/120, Train Loss: 3.995456, Test Loss: 3.995456
# Epoch 65/120, Train Loss: 4.060350, Test Loss: 4.060350
# Epoch 66/120, Train Loss: 4.045238, Test Loss: 4.045238
# Epoch 67/120, Train Loss: 4.068020, Test Loss: 4.068020
# Epoch 68/120, Train Loss: 4.010851, Test Loss: 4.010851
# Epoch 69/120, Train Loss: 4.076034, Test Loss: 4.076034
# Epoch 70/120, Train Loss: 4.173297, Test Loss: 4.173297
# Epoch 71/120, Train Loss: 3.991866, Test Loss: 3.991866
# Epoch 72/120, Train Loss: 4.005185, Test Loss: 4.005185
# Epoch 73/120, Train Loss: 3.946746, Test Loss: 3.946746
# Epoch 74/120, Train Loss: 4.076230, Test Loss: 4.076230
# Epoch 75/120, Train Loss: 4.097547, Test Loss: 4.097547
# Epoch 76/120, Train Loss: 4.031172, Test Loss: 4.031172
# Epoch 77/120, Train Loss: 4.044182, Test Loss: 4.044182
# Epoch 78/120, Train Loss: 3.976418, Test Loss: 3.976418
# Epoch 79/120, Train Loss: 4.014413, Test Loss: 4.014413
# Epoch 80/120, Train Loss: 4.006976, Test Loss: 4.006976
# Epoch 81/120, Train Loss: 4.052997, Test Loss: 4.052997
# Epoch 82/120, Train Loss: 4.091324, Test Loss: 4.091324
# Epoch 83/120, Train Loss: 4.065464, Test Loss: 4.065464
# Epoch 84/120, Train Loss: 4.037008, Test Loss: 4.037008
# Epoch 85/120, Train Loss: 4.006569, Test Loss: 4.006569
# Epoch 86/120, Train Loss: 4.056823, Test Loss: 4.056823
# Epoch 87/120, Train Loss: 4.033119, Test Loss: 4.033119
# Epoch 88/120, Train Loss: 4.118224, Test Loss: 4.118224
# Epoch 89/120, Train Loss: 4.009638, Test Loss: 4.009638
# Epoch 90/120, Train Loss: 4.030313, Test Loss: 4.030313
# Epoch 91/120, Train Loss: 4.023218, Test Loss: 4.023218
# Epoch 92/120, Train Loss: 3.959924, Test Loss: 3.959924
# Epoch 93/120, Train Loss: 4.064027, Test Loss: 4.064027
# Epoch 94/120, Train Loss: 4.055312, Test Loss: 4.055312
# Epoch 95/120, Train Loss: 4.047516, Test Loss: 4.047516
# Epoch 96/120, Train Loss: 4.039223, Test Loss: 4.039223
# Epoch 97/120, Train Loss: 4.000919, Test Loss: 4.000919
# Epoch 98/120, Train Loss: 4.059627, Test Loss: 4.059627
# Epoch 99/120, Train Loss: 4.021137, Test Loss: 4.021137
# Epoch 100/120, Train Loss: 4.027654, Test Loss: 4.027654
# Epoch 101/120, Train Loss: 4.025127, Test Loss: 4.025127
# Epoch 102/120, Train Loss: 3.980152, Test Loss: 3.980152
# Epoch 103/120, Train Loss: 4.011333, Test Loss: 4.011333
# Epoch 104/120, Train Loss: 3.972458, Test Loss: 3.972458
# Epoch 105/120, Train Loss: 4.035112, Test Loss: 4.035112
# Epoch 106/120, Train Loss: 4.049787, Test Loss: 4.049787
# Epoch 107/120, Train Loss: 4.032399, Test Loss: 4.032399
# Epoch 108/120, Train Loss: 4.038075, Test Loss: 4.038075
# Epoch 109/120, Train Loss: 4.030605, Test Loss: 4.030605
# Epoch 110/120, Train Loss: 4.046901, Test Loss: 4.046901
# Epoch 111/120, Train Loss: 4.007471, Test Loss: 4.007471
# Epoch 112/120, Train Loss: 4.004374, Test Loss: 4.004374
# Epoch 113/120, Train Loss: 4.027245, Test Loss: 4.027245
# Epoch 114/120, Train Loss: 4.051104, Test Loss: 4.051104
# Epoch 115/120, Train Loss: 4.017148, Test Loss: 4.017148
# Epoch 116/120, Train Loss: 3.973609, Test Loss: 3.973609
# Epoch 117/120, Train Loss: 4.071127, Test Loss: 4.071127
# Epoch 118/120, Train Loss: 4.103238, Test Loss: 4.103238
# Epoch 119/120, Train Loss: 3.969781, Test Loss: 3.969781
# Epoch 120/120, Train Loss: 4.040879, Test Loss: 4.040879

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([2.5996, 2.4259, 2.3769, 2.3359, 2.3305, 2.3071, 2.3047, 2.2952, 2.2833,
#          2.2802, 2.2768, 2.2703, 2.2682, 2.2698, 2.2667, 2.2614, 2.2638, 2.2623,
#          2.2579, 2.2572, 2.2572, 2.2554, 2.2533, 2.2546, 2.2535, 2.2524, 2.2488,
#          2.2514, 2.2482, 2.2496, 2.2506, 2.2500, 2.2489, 2.2484, 2.2474, 2.2466,
#          2.2479, 2.2459, 2.2473, 2.2469, 2.2461, 2.2475, 2.2446, 2.2461, 2.2466,
#          2.2435, 2.2460, 2.2436, 2.2445, 2.2431, 2.2436, 2.2432, 2.2425, 2.2440,
#          2.2413, 2.2432, 2.2422, 2.2405, 2.2436, 2.2425, 2.2430, 2.2416, 2.2426,
#          2.2405, 2.2414, 2.2406, 2.2403, 2.2417, 2.2400, 2.2407, 2.2404, 2.2401,
#          2.2394, 2.2403, 2.2403, 2.2401, 2.2392, 2.2393, 2.2402, 2.2388, 2.2384,
#          2.2396, 2.2384, 2.2385, 2.2388, 2.2379, 2.2395, 2.2366, 2.2393, 2.2378,
#          2.2370, 2.2377, 2.2370, 2.2372, 2.2374, 2.2368, 2.2370, 2.2378, 2.2366,
#          2.2363, 2.2358, 2.2367, 2.2363, 2.2358, 2.2365, 2.2360, 2.2360, 2.2356,
#          2.2364, 2.2362, 2.2373, 2.2359, 2.2347, 2.2350, 2.2357, 2.2354, 2.2348,
#          2.2345, 2.2353, 2.2348]),
#  tensor([4.0955, 4.1824, 4.1819, 4.0343, 3.9337, 3.9433, 3.9457, 3.9242, 3.9835,
#          4.0569, 4.0570, 4.0035, 4.0702, 3.9896, 3.9770, 3.9374, 3.9309, 3.8911,
#          3.9146, 4.0125, 4.0096, 3.9984, 3.9679, 3.9589, 4.0280, 4.0392, 4.0371,
#          4.0847, 4.0532, 4.1635, 4.0325, 4.0504, 3.9966, 4.0202, 4.0545, 3.9800,
#          4.0680, 3.9695, 4.0393, 3.9771, 4.0139, 4.0014, 4.0572, 4.0085, 3.9899,
#          4.0605, 3.9416, 4.0231, 3.9880, 4.0113, 3.9559, 4.0987, 4.0169, 4.0215,
#          4.0225, 4.0057, 4.0560, 4.0105, 3.9797, 4.0812, 4.0378, 4.0377, 4.0102,
#          3.9955, 4.0603, 4.0452, 4.0680, 4.0109, 4.0760, 4.1733, 3.9919, 4.0052,
#          3.9467, 4.0762, 4.0975, 4.0312, 4.0442, 3.9764, 4.0144, 4.0070, 4.0530,
#          4.0913, 4.0655, 4.0370, 4.0066, 4.0568, 4.0331, 4.1182, 4.0096, 4.0303,
#          4.0232, 3.9599, 4.0640, 4.0553, 4.0475, 4.0392, 4.0009, 4.0596, 4.0211,
#          4.0277, 4.0251, 3.9802, 4.0113, 3.9725, 4.0351, 4.0498, 4.0324, 4.0381,
#          4.0306, 4.0469, 4.0075, 4.0044, 4.0272, 4.0511, 4.0171, 3.9736, 4.0711,
#          4.1032, 3.9698, 4.0409]),
#  tensor([0.4707, 0.4964, 0.5052, 0.5126, 0.5141, 0.5186, 0.5179, 0.5185, 0.5203,
#          0.5213, 0.5219, 0.5230, 0.5232, 0.5230, 0.5235, 0.5244, 0.5237, 0.5252,
#          0.5252, 0.5255, 0.5254, 0.5259, 0.5260, 0.5260, 0.5256, 0.5264, 0.5268,
#          0.5262, 0.5264, 0.5274, 0.5267, 0.5266, 0.5271, 0.5271, 0.5276, 0.5274,
#          0.5261, 0.5273, 0.5272, 0.5274, 0.5274, 0.5272, 0.5273, 0.5270, 0.5273,
#          0.5277, 0.5270, 0.5277, 0.5280, 0.5279, 0.5273, 0.5275, 0.5278, 0.5274,
#          0.5280, 0.5278, 0.5281, 0.5286, 0.5278, 0.5284, 0.5278, 0.5281, 0.5277,
#          0.5281, 0.5282, 0.5285, 0.5283, 0.5278, 0.5284, 0.5283, 0.5282, 0.5284,
#          0.5288, 0.5282, 0.5285, 0.5281, 0.5282, 0.5285, 0.5286, 0.5288, 0.5288,
#          0.5283, 0.5283, 0.5287, 0.5282, 0.5288, 0.5285, 0.5291, 0.5285, 0.5287,
#          0.5286, 0.5288, 0.5289, 0.5286, 0.5291, 0.5286, 0.5289, 0.5287, 0.5289,
#          0.5283, 0.5289, 0.5287, 0.5290, 0.5290, 0.5291, 0.5289, 0.5293, 0.5291,
#          0.5293, 0.5291, 0.5289, 0.5285, 0.5289, 0.5292, 0.5288, 0.5286, 0.5289,
#          0.5287, 0.5288, 0.5286]))

# %%
# (yy * data['date_int'].max()).round()

# %%
# (yHat_test * data['date_int'].max()).round()

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.5543
#
#
# mean_absolute_error(y, yHat): 0.8185
#
# mean_absolute_error(yy, yHat_test): 1.2576
#
#
# mean_squared_error(y, yHat): 1.9998
#
# mean_squared_error(yy, yHat_test): 4.0409
#
#
# mean_squared_log_error(y, yHat): 0.1121
#
# mean_squared_log_error(yy, yHat_test): 0.4059
#
#
# RMSE(y, yHat): 1.4141
#
# RMSE(yy, yHat_test): 2.0102

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss2.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.detach().T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc2.jpg", bbox_inches='tight')


plt.show()

# %%
['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']
# Out:
# ['day_scaled',
#  'day_sin',
#  'day_cos',
#  'month_scaled',
#  'month_sin',
#  'month_cos',
#  'leap_year',
#  'decade_scaled',
#  'decade_sin',
#  'decade_cos']

# %%
def result_to_date(result):
    
    result = str(result)
    
    day   = int(result[6:]) - 1
    month = int(result[4:6]) - 1

    ss = str(f'{result[:4]}0101')
    
    ds = datetime.datetime.strptime(ss, '%Y%m%d')
    
    ds = ds + relativedelta(months=month, days=day)

    result = ds.strftime('%d-%m-%Y')
    
    
    return result

# %%
# (16830739, 17848869)
result_to_date(16830739), result_to_date(17848869)
# Out:
# ('08-08-1683', '08-06-1791')

# %%
def test_model(input_list):
    

    X       = np.zeros((1, 10))
    X_smote = np.zeros((1, 10))



    day       = np.array(map_day[input_list[0]])
    month     = np.array(map_month[input_list[1]])
    leap_year = map_leap_year[input_list[2]]
    decade    = np.array(input_list[3].strip('[]')).astype('int64')


    X[0, 0] = scaler_day.transform(day.reshape(-1, 1)).flatten()
    X[0, 1] = np.sin(day * (2 * np.pi / 7))
    X[0, 2] = np.cos(day * (2 * np.pi / 7))

    X[0, 3] = scaler_month.transform(month.reshape(-1, 1)).flatten()
    X[0, 4] = np.sin(month * (2 * np.pi / 12))
    X[0, 5] = np.cos(month * (2 * np.pi / 12))

    X[0, 6] = leap_year

    X[0, 7] = scaler_decade.transform(decade.reshape(-1, 1)).flatten()
    X[0, 8] = np.sin(decade * (2 * np.pi / alpha))
    X[0, 9] = np.cos(decade * (2 * np.pi / alpha))

    # ---

    X_smote[0, 0] = scaler_day_smote.transform(day.reshape(-1, 1)).flatten()
    X_smote[0, 1] = X[0, 1]
    X_smote[0, 2] = X[0, 2]

    X_smote[0, 3] = scaler_month_smote.transform(month.reshape(-1, 1)).flatten()
    X_smote[0, 4] = X[0, 4]
    X_smote[0, 5] = X[0, 5]

    X_smote[0, 6] = leap_year

    X_smote[0, 7] = scaler_decade_smote.transform(decade.reshape(-1, 1)).flatten()
    X_smote[0, 8] = np.sin(decade * (2 * np.pi / alpha_smote))
    X_smote[0, 9] = np.cos(decade * (2 * np.pi / alpha_smote))


    # ---

    result       = model(torch.tensor(X).to(device).float())
    result_smote = model_smote(torch.tensor(X_smote).to(device).float())


    # ---


    result       = ''.join(result.detach().cpu().numpy().round().astype(int).astype(str).flatten())
    result_smote = ''.join(result_smote.detach().cpu().numpy().round().astype(int).astype(str).flatten())


    
    return result_to_date(result), result_to_date(result_smote)

# %%
input_test1 = ['[MON]', '[DEC]', '[False]', '[196]']
output_test1 = '3-12-1962'

input_test2 = ['[THU]', '[DEC]', '[True]', '[204]']
output_test2 = '3-12-2048'

input_test3 = ['[WED]', '[JAN]', '[False]', '[181]']
output_test3 = '10-1-1810'


input_test4 = ['[WED]', '[JUN]', '[False]', '[209]']

# %%
test_model(input_test1), test_model(input_test2), test_model(input_test3), test_model(input_test4)
# Out:
# (('14-12-1964', '15-02-1964'),
#  ('15-02-2045', '15-12-2044'),
#  ('15-11-1814', '15-11-1814'),
#  ('14-06-2084', '14-06-2084'))

# %%
output_test1, output_test2, output_test3
# Out:
# ('3-12-1962', '3-12-2048', '10-1-1810')

# %%
# example_input = pd.read_csv('./data/example_input.txt', sep=' ', header=None)
example_input = pd.read_csv('example_input.txt', sep=' ', header=None)


example_input.columns = ['day', 'month', 'leap_year', 'decade']

# %%
example_input
# Out:
#         day  month leap_year decade
# 0     [WED]  [JAN]   [False]  [180]
# 1     [MON]  [JAN]   [False]  [190]
# 2     [SAT]  [JAN]    [True]  [200]
# 3     [FRI]  [JAN]   [False]  [210]
# 4     [WED]  [JAN]   [False]  [220]
# ...     ...    ...       ...    ...
# 1460  [MON]  [OCT]    [True]  [214]
# 1461  [TUE]  [DEC]   [False]  [183]
# 1462  [SUN]  [DEC]   [False]  [193]
# 1463  [SAT]  [DEC]   [False]  [203]
# 1464  [THU]  [DEC]   [False]  [213]
#
# [1465 rows x 4 columns]

# %%
R       = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result'])
R_smote = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result_smote'])

# %%
example_input.iloc[0].tolist()
# Out:
# ['[WED]', '[JAN]', '[False]', '[180]']

# %%
for i in range(len(example_input)):
    R.iloc[i], R_smote.iloc[i] = test_model(example_input.iloc[i].tolist())

# %%
R
# Out:
#           result
# 0     15-11-1804
# 1     15-11-1904
# 2     15-11-2005
# 3     15-11-2105
# 4     15-11-2200
# ...          ...
# 1460  15-10-2145
# 1461  15-12-1834
# 1462  15-12-1934
# 1463  15-02-2035
# 1464  15-12-2135
#
# [1465 rows x 1 columns]

# %%
final = pd.concat([example_input, R], axis=1)
final
# Out:
#         day  month leap_year decade      result
# 0     [WED]  [JAN]   [False]  [180]  15-11-1804
# 1     [MON]  [JAN]   [False]  [190]  15-11-1904
# 2     [SAT]  [JAN]    [True]  [200]  15-11-2005
# 3     [FRI]  [JAN]   [False]  [210]  15-11-2105
# 4     [WED]  [JAN]   [False]  [220]  15-11-2200
# ...     ...    ...       ...    ...         ...
# 1460  [MON]  [OCT]    [True]  [214]  15-10-2145
# 1461  [TUE]  [DEC]   [False]  [183]  15-12-1834
# 1462  [SUN]  [DEC]   [False]  [193]  15-12-1934
# 1463  [SAT]  [DEC]   [False]  [203]  15-02-2035
# 1464  [THU]  [DEC]   [False]  [213]  15-12-2135
#
# [1465 rows x 5 columns]

# %%
final_smote = pd.concat([example_input, R_smote], axis=1)
final_smote
# Out:
#         day  month leap_year decade result_smote
# 0     [WED]  [JAN]   [False]  [180]   15-11-1805
# 1     [MON]  [JAN]   [False]  [190]   15-11-1905
# 2     [SAT]  [JAN]    [True]  [200]   15-11-2005
# 3     [FRI]  [JAN]   [False]  [210]   15-11-2305
# 4     [WED]  [JAN]   [False]  [220]   15-11-2394
# ...     ...    ...       ...    ...          ...
# 1460  [MON]  [OCT]    [True]  [214]   15-10-2344
# 1461  [TUE]  [DEC]   [False]  [183]   15-02-1834
# 1462  [SUN]  [DEC]   [False]  [193]   15-02-1934
# 1463  [SAT]  [DEC]   [False]  [203]   15-12-2034
# 1464  [THU]  [DEC]   [False]  [213]   15-12-2334
#
# [1465 rows x 5 columns]

# %%
final.to_csv('output_file.txt', sep=' ', header=None, index=False)

# %%
final_smote.to_csv('output_file_smote.txt', sep=' ', header=None, index=False)

# %% [markdown]
# Out-liers

# %% [markdown]
# Saving

# %%
checkpoint = {'model_class'      : Model,
              
              'model_state_dict'      : model.state_dict(),
              'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              'scaler_day_smote' : scaler_day_smote,
              'scaler_month_smote' : scaler_month_smote,
              'scaler_decade_smote' : scaler_decade_smote}



torch.save(checkpoint, 'checkpoint.pth.tar')

# %%
# checkpoint = torch.load('checkpoint.pth.tar')

# %%
# model       = Model()
# model_smote = Model()


# model.load_state_dict(checkpoint['model_state_dict'])
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
