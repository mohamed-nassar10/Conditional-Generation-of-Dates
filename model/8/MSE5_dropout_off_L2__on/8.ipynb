# %%
import datetime

import copy

import random


from dateutil.relativedelta import relativedelta

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('seaborn')
# plt.style.use(['dark_background', 'ggplot'])

import seaborn as sns
# sns.set()

# import scipy
# import scipy.stats as stats


# # sympy = symbolic math in Python
# import sympy as sym
# import sympy.plotting.plot as symplot


# make the equations look nicer

# from IPython.display import display
# display.set_matplotlib_formats('svg') # Deprecated since version 7.23

# import matplotlib_inline
# matplotlib_inline.backend_inline.set_matplotlib_formats('svg')


# %config InlineBackend.set_matplotlib_formats = ["svg"]
# %config InlineBackend.figure_formats = ["svg"]

# %%
import sklearn


from sklearn.model_selection import train_test_split


# from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler     # <------------ (-1.0, 1.0)
# from sklearn.preprocessing import MinMaxScaler


from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error


from imblearn.over_sampling import SMOTE

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset, DataLoader





torch.__version__
# Out:
# '1.12.1+cu113'

# %%
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def print_score(shape, yHat, y, yHat_test, yy):
    
    
    n, p = shape
    
    R2 = r2_score(y.detach().numpy(), yHat.detach().numpy())
    
    Adj_r2 = 1 - (1 - R2)  *  (n - 1) / (n - p - 1)
    
    print(f'Adjusted R-Squared(y, yHat): {Adj_r2:0.4f}\n\n')
    # r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
    #  R^2 score is not well-defined with less than two samples
    
    
    print(f'mean_absolute_error(y, yHat):',
          f'{mean_absolute_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_absolute_error(yy, yHat_test):',
          f'{mean_absolute_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_error(y, yHat):',
          f'{mean_squared_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_error(yy, yHat_test):',
          f'{mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    print(f'mean_squared_log_error(y, yHat):',
          f'{mean_squared_log_error(y.detach().numpy(), yHat.detach().numpy()):0.4f}\n')
    print(f'mean_squared_log_error(yy, yHat_test):',
          f'{mean_squared_log_error(yy.detach().numpy(), yHat_test.detach().numpy()):0.4f}\n\n')
    
    
    
    print(f'RMSE(y, yHat):',
          f'{np.sqrt( mean_squared_error(y.detach().numpy(), yHat.detach().numpy()) ):0.4f}\n')
    print(f'RMSE(yy, yHat_test):',
          f'{np.sqrt( mean_squared_error(yy.detach().numpy(), yHat_test.detach().numpy()) ):0.4f}\n\n')

# %%
# date = np.datetime64("2000-01-01")
# date_strings = date.astype(str).split('-'). 
# # >> ['2000', '01', '01']

# year_int = int(date_strings[0])

# %%
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# !wget -nc https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Out:
# --2022-08-14 17:50:58--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/data.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5230713 (5.0M) [text/plain]
# Saving to: ‘data.txt’
#
# data.txt            100%[===================>]   4.99M  --.-KB/s    in 0.08s
#
# 2022-08-14 17:50:58 (65.8 MB/s) - ‘data.txt’ saved [5230713/5230713]
#
# --2022-08-14 17:50:58--  https://raw.githubusercontent.com/Proteinea/dl-challenge-2/main/data/example_input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37732 (37K) [text/plain]
# Saving to: ‘example_input.txt’
#
# example_input.txt   100%[===================>]  36.85K  --.-KB/s    in 0.003s
#
# 2022-08-14 17:50:58 (10.3 MB/s) - ‘example_input.txt’ saved [37732/37732]

# %%
# !ls
# Out:
# checkpoint.pth.tar  data.txt  example_input.txt  sample_data

# %% [markdown]
# 'text.txt'

# %% [markdown]
# [ 1-1-1800 to 31-12-2200 ]

# %% [markdown]
# [day condition] [month condition] [leap year condition] [decade condition] date

# %% [markdown]
# [MON] [DEC] [False] [196] 3-12-1962
# [THU] [DEC] [True] [204] 3-12-2048
# [WED] [JAN] [False] [181] 10-1-1810

# %%
# data = np.loadtxt(open('text.txt','r'),delimiter=' ')
# ori = pd.read_csv('./data/data.txt', sep=' ', header=None)

ori = pd.read_csv('data.txt', sep=' ', header=None)

# %%
ori.columns = ['day', 'month', 'leap_year', 'decade', 'date']

# %%
ori
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
# data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)
# # pd.to_datetime(data.date, infer_datetime_format=False)

# %%
ori.dtypes
# Out:
# day          object
# month        object
# leap_year    object
# decade       object
# date         object
# dtype: object

# %%
# data_backup = copy.deepcopy(ori)
data = copy.deepcopy(ori)

# %%
data
# Out:
#           day  month leap_year decade        date
# 0       [WED]  [JAN]   [False]  [180]    1-1-1800
# 1       [THU]  [JAN]   [False]  [180]    1-1-1801
# 2       [FRI]  [JAN]   [False]  [180]    1-1-1802
# 3       [SAT]  [JAN]   [False]  [180]    1-1-1803
# 4       [SUN]  [JAN]    [True]  [180]    1-1-1804
# ...       ...    ...       ...    ...         ...
# 146457  [SAT]  [DEC]    [True]  [219]  31-12-2196
# 146458  [SUN]  [DEC]   [False]  [219]  31-12-2197
# 146459  [MON]  [DEC]   [False]  [219]  31-12-2198
# 146460  [TUE]  [DEC]   [False]  [219]  31-12-2199
# 146461  [WED]  [DEC]   [False]  [220]  31-12-2200
#
# [146462 rows x 5 columns]

# %%
data.date
# Out:
# 0           1-1-1800
# 1           1-1-1801
# 2           1-1-1802
# 3           1-1-1803
# 4           1-1-1804
#              ...
# 146457    31-12-2196
# 146458    31-12-2197
# 146459    31-12-2198
# 146460    31-12-2199
# 146461    31-12-2200
# Name: date, Length: 146462, dtype: object

# %%
# # data['date'] = pd.date_range('3-12-2048', periods=10)
# # data['date'] = pd.date_range('12-3-1962', periods=10)

# # 1-1-1800 to 31-12-2200
# data['date'] = pd.date_range(start='1-1-1800',end='12-31-2200')


data.date = pd.to_datetime(data.date, format='%d-%m-%Y', infer_datetime_format=False)

# # data.date = data.date.dt.strftime('%d-%m-%Y')
# # data.date = pd.to_datetime(data.date.dt.strftime('%d-%m-%Y'), format='%d-%m-%Y', infer_datetime_format=False)

# %%
data.dtypes
# Out:
# day                  object
# month                object
# leap_year            object
# decade               object
# date         datetime64[ns]
# dtype: object

# %%
data
# Out:
#           day  month leap_year decade       date
# 0       [WED]  [JAN]   [False]  [180] 1800-01-01
# 1       [THU]  [JAN]   [False]  [180] 1801-01-01
# 2       [FRI]  [JAN]   [False]  [180] 1802-01-01
# 3       [SAT]  [JAN]   [False]  [180] 1803-01-01
# 4       [SUN]  [JAN]    [True]  [180] 1804-01-01
# ...       ...    ...       ...    ...        ...
# 146457  [SAT]  [DEC]    [True]  [219] 2196-12-31
# 146458  [SUN]  [DEC]   [False]  [219] 2197-12-31
# 146459  [MON]  [DEC]   [False]  [219] 2198-12-31
# 146460  [TUE]  [DEC]   [False]  [219] 2199-12-31
# 146461  [WED]  [DEC]   [False]  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %%
map_leap_year = {'[False]': int(0), '[True]' : int(1)}

data.leap_year = data.leap_year.map(map_leap_year)

# data.leap_year = data.leap_year.astype(np.float64)

# %%
data
# Out:
#           day  month  leap_year decade       date
# 0       [WED]  [JAN]          0  [180] 1800-01-01
# 1       [THU]  [JAN]          0  [180] 1801-01-01
# 2       [FRI]  [JAN]          0  [180] 1802-01-01
# 3       [SAT]  [JAN]          0  [180] 1803-01-01
# 4       [SUN]  [JAN]          1  [180] 1804-01-01
# ...       ...    ...        ...    ...        ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31
# 146459  [MON]  [DEC]          0  [219] 2198-12-31
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31
# 146461  [WED]  [DEC]          0  [220] 2200-12-31
#
# [146462 rows x 5 columns]

# %% [markdown]
# date -> timestamp

# %%
data.date.iloc[0]
# Out:
# Timestamp('1800-01-01 00:00:00')

# %%
data['date_int'] = data['date'].dt.strftime("%Y%m%d").astype(np.int64)

# data['date_str'] = data['date'].dt.strftime("%Y%m%d")

# %%
# data['date_int'].map(str)
# data['date_int'].astype(str)

# %%
# date_max = data.date_int.max()
# data['date_normalized'] = data.date_int / date_max

# %%
data
# Out:
#           day  month  leap_year decade       date  date_int
# 0       [WED]  [JAN]          0  [180] 1800-01-01  18000101
# 1       [THU]  [JAN]          0  [180] 1801-01-01  18010101
# 2       [FRI]  [JAN]          0  [180] 1802-01-01  18020101
# 3       [SAT]  [JAN]          0  [180] 1803-01-01  18030101
# 4       [SUN]  [JAN]          1  [180] 1804-01-01  18040101
# ...       ...    ...        ...    ...        ...       ...
# 146457  [SAT]  [DEC]          1  [219] 2196-12-31  21961231
# 146458  [SUN]  [DEC]          0  [219] 2197-12-31  21971231
# 146459  [MON]  [DEC]          0  [219] 2198-12-31  21981231
# 146460  [TUE]  [DEC]          0  [219] 2199-12-31  21991231
# 146461  [WED]  [DEC]          0  [220] 2200-12-31  22001231
#
# [146462 rows x 6 columns]

# %%
x = data.decade.iloc[0]
x
# Out:
# '[180]'

# %%
x.strip('[]')
# Out:
# '180'

# %%
data.decade = data.decade.apply(lambda x: x.strip('[]')).astype('int64')

# %%
# data.day = data.day.apply(lambda x: x.strip('[]'))
# data.month = data.month.apply(lambda x: x.strip('[]'))

# %%
map_day = {'[SAT]': int(0),
           '[SUN]': int(1),
           '[MON]': int(2),
           '[TUE]': int(3),
           '[WED]': int(4),
           '[THU]': int(5),
           '[FRI]': int(6)}

# %%
data['day_code'] = data.day.map(map_day)

# %%
scaler_day = RobustScaler()

x = data.day_code.values.reshape(-1, 1)

data['day_scaled'] = scaler_day.fit_transform(x).flatten()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled
# 0             0.25
# 1             0.50
# 2             0.75
# 3            -0.75
# 4            -0.50
# ...            ...
# 146457       -0.75
# 146458       -0.50
# 146459       -0.25
# 146460        0.00
# 146461        0.25
#
# [146462 rows x 8 columns]

# %%
data['day_sin'] = np.sin(data['day_code'] * (2 * np.pi / 7))
data['day_cos'] = np.cos(data['day_code'] * (2 * np.pi / 7))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos
# 0             0.25 -0.433884 -0.900969
# 1             0.50 -0.974928 -0.222521
# 2             0.75 -0.781831  0.623490
# 3            -0.75  0.000000  1.000000
# 4            -0.50  0.781831  0.623490
# ...            ...       ...       ...
# 146457       -0.75  0.000000  1.000000
# 146458       -0.50  0.781831  0.623490
# 146459       -0.25  0.974928 -0.222521
# 146460        0.00  0.433884 -0.900969
# 146461        0.25 -0.433884 -0.900969
#
# [146462 rows x 10 columns]

# %%
map_month = {'[JAN]' : 0,
             '[FEB]' : 1,
             '[MAR]' : 2,
             '[APR]' : 3,
             '[MAY]' : 4,
             '[JUN]' : 5,
             '[JUL]' : 6,
             '[AUG]' : 7,
             '[SEP]' : 8,
             '[OCT]' : 9,
             '[NOV]' : 10,
             '[DEC]' : 11}

# %%
data['month_code'] = data.month.map(map_month)

# %%
scaler_month = RobustScaler()

x = data.month_code.values.reshape(-1, 1)

data['month_scaled'] = scaler_month.fit_transform(x).flatten()

# %%
data['month_sin'] = np.sin(data['month_code'] * (2 * np.pi / 12))
data['month_cos'] = np.cos(data['month_code'] * (2 * np.pi / 12))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos
# 0        1.000000
# 1        1.000000
# 2        1.000000
# 3        1.000000
# 4        1.000000
# ...           ...
# 146457   0.866025
# 146458   0.866025
# 146459   0.866025
# 146460   0.866025
# 146461   0.866025
#
# [146462 rows x 14 columns]

# %%
scaler_decade = RobustScaler()

x = data.decade.values.reshape(-1, 1)

data['decade_scaled'] = scaler_decade.fit_transform(x).flatten()

# %%
# alpha = len(data.decade.unique())
alpha = (data.decade.iloc[-1] - data.decade.iloc[0]) + 1

data['decade_sin'] = np.sin(data['decade'] * (2 * np.pi / alpha))
data['decade_cos'] = np.cos(data['decade'] * (2 * np.pi / alpha))

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %%
# data.date_normalized.min(), data.date_normalized.max()

# %%
# round(data.date_normalized.min()), round(data.date_normalized.max())

# %%
round(data.day_scaled.min()), round(data.day_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.day_sin.min()), round(data.day_sin.max())
# Out:
# (-1, 1)

# %%
round(data.day_cos.min()), round(data.day_cos.max())
# Out:
# (-1, 1)

# %%
round(data.month_scaled.min()), round(data.month_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.month_sin.min()), round(data.month_sin.max())
# Out:
# (-1, 1)

# %%
round(data.month_cos.min()), round(data.month_cos.max())
# Out:
# (-1, 1)

# %%
data.leap_year.min(), data.leap_year.max()
# Out:
# (0, 1)

# %%
round(data.decade_scaled.min()), round(data.decade_scaled.max())
# Out:
# (-1, 1)

# %%
round(data.decade_sin.min()), round(data.decade_sin.max())
# Out:
# (-1, 1)

# %%
round(data.decade_cos.min()), round(data.decade_cos.max())
# Out:
# (-1, 1)

# %% [markdown]
# Boxplot

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.day.value_counts().plot(kind="bar")

# %%
data.month.value_counts().plot(kind="bar")

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
data.decade.value_counts().plot(kind="bar")

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
data.dtypes
# Out:
# day                      object
# month                    object
# leap_year                 int64
# decade                    int64
# date             datetime64[ns]
# date_int                  int64
# day_code                  int64
# day_scaled              float64
# day_sin                 float64
# day_cos                 float64
# month_code                int64
# month_scaled            float64
# month_sin               float64
# month_cos               float64
# decade_scaled           float64
# decade_sin              float64
# decade_cos              float64
# dtype: object

# %% [markdown]
# ['day_sin', 'day_cos', 'month_sin', 'month_cos', 'leap_year', 'decade_scaled']
# ['date_timestamp_scaled']

# %%
X = data[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
          'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 0.25      , -0.43388374, -0.90096887, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.5       , -0.97492791, -0.22252093, ..., -1.        ,
#          0.63624244, -0.77148918],
#        [ 0.75      , -0.78183148,  0.6234898 , ..., -1.        ,
#          0.63624244, -0.77148918],
#        ...,
#        [-0.25      ,  0.97492791, -0.22252093, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.        ,  0.43388374, -0.90096887, ...,  0.95      ,
#          0.83936543, -0.54356755],
#        [ 0.25      , -0.43388374, -0.90096887, ...,  1.        ,
#          0.74655322, -0.6653257 ]])

# %%
len(X)
# Out:
# 146462

# %%
X.shape
# Out:
# (146462, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()


ls = []

for s in data['date_int'].astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(data['date_int'])), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y = ll.values

Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 1, 9, ..., 2, 3, 1],
#        [2, 2, 0, ..., 2, 3, 1]])

# %%
len(Y)
# Out:
# 146462

# %%
Y.shape
# Out:
# (146462, 8)

# %%
# # leap = np.where(~X['leap_year'] == 1)[0]
# leap = np.where(X['leap_year'] == 1)[0]

# leap

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64


train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (146462, 10)
#
# Y: (146462, 8)
#
# Train data:   (102523, 10)
#
# Train labels: (102523, 8)
#
# Test data:    (43939, 10)
#
# Test labels:  (43939, 8)

# %%
102523 % 32, 102523 % 64
# Out:
# (27, 59)

# %%
class Model(nn.Module):
    
    def __init__(self):
        super().__init__()

        self.input = nn.Linear(10, 32)

        self.fc1 = nn.Linear(32, 128)
        self.bnorm1 = nn.BatchNorm1d(128)

        self.fc2 = nn.Linear(128, 512)
        self.bnorm2 = nn.BatchNorm1d(512)

        self.fc3 = nn.Linear(512, 64)
        self.bnorm3 = nn.BatchNorm1d(64)

        self.fc4 = nn.Linear(64, 32)
        self.bnorm4 = nn.BatchNorm1d(32)


        self.output = nn.Linear(32, 8)



    def forward(self, x):


        # print(f'training={self.training}')

        x = F.relu( self.input(x) )

        x = F.relu(self.bnorm1(self.fc1(x)))
        # x = F.dropout(x, p=0.25, training=self.training)

        x = F.relu(self.bnorm2(self.fc2(x)))
        # x = F.dropout(x, p=0.4, training=self.training)

        x = F.relu(self.bnorm3(self.fc3(x)))
        # x = F.dropout(x, p=0.1, training=self.training)

        x = F.relu(self.bnorm4(self.fc4(x)))
        # x = F.dropout(x, p=0.05, training=self.training)


        x = F.relu(self.output(x))
        # x = self.output(x)
        


        return x

# %%
# test_x, test_y = next(iter(train_loader))

# print(f'test_x: {test_x.shape}\n')
# print(f'test_y: {test_y.shape}\n')

# %%
def train(model, numepochs):

    numepochs = numepochs

    model = model
    
    
    
    lossfun = nn.MSELoss()
    # lossfun = nn.L1Loss()


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0002, betas=(0.5, 0.999), weight_decay=1e-5)
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.5, 0.999), weight_decay=1e-1)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=1e-3)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), weight_decay=1e-9)


    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999), weight_decay=0.01)
    
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    
    
    
    trainLoss = torch.zeros(numepochs)
    testLoss  = torch.zeros(numepochs)
    trainAcc  = torch.zeros(numepochs)
    # testAcc   = torch.zeros(numepochs)


    for epochi in range(numepochs):

        model.train() # switch to train mode

        batchLoss = []
        batchAcc  = []

        for X,y in train_loader:

            X = X.to(device)
            y = y.to(device)

            yHat = model(X)
            loss = lossfun(yHat, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            batchLoss.append(loss.item())
            # batchAcc.append( torch.mean(( yHat == y).float() ).item() )
            # batchAcc.append( torch.mean( (torch.abs(yHat - y) < 1).float() ).item() ) # <1 for rounding
            batchAcc.append( r2_score(y.detach().cpu().numpy(), yHat.detach().cpu().numpy()) )
            




        trainLoss[epochi] = np.mean(batchLoss)
        # trainAcc[epochi]  = 100*np.mean(batchAcc)
        trainAcc[epochi]  = np.mean(batchAcc)
        



        model.eval() # switch to test mode

        XX,yy = next(iter(test_loader))

        XX = XX.to(device)
        yy = yy.to(device)

        # forward pass and loss
        with torch.no_grad():
            yHat_test = model(XX)
            loss_test = lossfun(yHat_test, yy)


        testLoss[epochi] = loss_test.item()
        # testAcc[epochi]  = 100*torch.mean( (yHat_test == yy).float() ).item()
        # testAcc[epochi]  = 100*torch.mean( (torch.abs(yHat_test - yy) < 1).float() ).item()
        # testAcc[epochi]  = 100*r2_score(yy.detach().numpy(), yHat_test.detach().numpy())
        


        # if (epochi + 1) % 5 == 0:
        print(f'Epoch {epochi+1}/{numepochs}, Train Loss: {loss.item():0.6f}, Test Loss: {loss_test.item():0.6f}')


        
    return trainLoss.cpu(), testLoss.cpu(), trainAcc.cpu(), yHat.cpu(), y.cpu(), yHat_test.cpu(), yy.cpu()

# %%
model = Model().to(device)

# test_hat = model(torch.randn(32,6))
# test_hat = model(test_x)

# print(test_hat.shape)


checkpoint = torch.load('checkpoint.pth.tar', map_location=torch.device('cpu'))
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
# for p in list(model.named_parameters()):
#     if 'weight' in p[0] and 'bnorm' not in p[0]:
#         nn.init.xavier_normal_(p[1].data)
#         print(p[0])
#         print(p[1].data.shape)

# %%
numepochs = 120
# numepochs = 300


trainLoss1, testLoss1, trainAcc1, yHat1, y1, yHat_test1, yy1 = train(model, numepochs)
# Out:
# Epoch 1/120, Train Loss: 2.364265, Test Loss: 1.961634
# Epoch 2/120, Train Loss: 2.352750, Test Loss: 2.031554
# Epoch 3/120, Train Loss: 2.407808, Test Loss: 2.262245
# Epoch 4/120, Train Loss: 2.350814, Test Loss: 2.082468
# Epoch 5/120, Train Loss: 2.434305, Test Loss: 2.124529
# Epoch 6/120, Train Loss: 2.462451, Test Loss: 2.126883
# Epoch 7/120, Train Loss: 2.474916, Test Loss: 2.202505
# Epoch 8/120, Train Loss: 2.352995, Test Loss: 2.070889
# Epoch 9/120, Train Loss: 2.356397, Test Loss: 2.121875
# Epoch 10/120, Train Loss: 2.359031, Test Loss: 2.221628
# Epoch 11/120, Train Loss: 2.354285, Test Loss: 2.069683
# Epoch 12/120, Train Loss: 2.353535, Test Loss: 2.072946
# Epoch 13/120, Train Loss: 2.359394, Test Loss: 2.105313
# Epoch 14/120, Train Loss: 2.360985, Test Loss: 2.086538
# Epoch 15/120, Train Loss: 2.351129, Test Loss: 2.028417
# Epoch 16/120, Train Loss: 2.435209, Test Loss: 2.209531
# Epoch 17/120, Train Loss: 2.342547, Test Loss: 2.088416
# Epoch 18/120, Train Loss: 2.348498, Test Loss: 2.074283
# Epoch 19/120, Train Loss: 2.372921, Test Loss: 2.132572
# Epoch 20/120, Train Loss: 2.492147, Test Loss: 2.897904
# Epoch 21/120, Train Loss: 2.359517, Test Loss: 2.242002
# Epoch 22/120, Train Loss: 2.360937, Test Loss: 2.027410
# Epoch 23/120, Train Loss: 2.363640, Test Loss: 2.093372
# Epoch 24/120, Train Loss: 2.356582, Test Loss: 2.044764
# Epoch 25/120, Train Loss: 2.368342, Test Loss: 2.071768
# Epoch 26/120, Train Loss: 2.352513, Test Loss: 2.046062
# Epoch 27/120, Train Loss: 2.366168, Test Loss: 2.069552
# Epoch 28/120, Train Loss: 2.393262, Test Loss: 2.017565
# Epoch 29/120, Train Loss: 2.367029, Test Loss: 2.025747
# Epoch 30/120, Train Loss: 2.373282, Test Loss: 2.175958
# Epoch 31/120, Train Loss: 2.438265, Test Loss: 2.120691
# Epoch 32/120, Train Loss: 2.388205, Test Loss: 2.764710
# Epoch 33/120, Train Loss: 2.389987, Test Loss: 2.165425
# Epoch 34/120, Train Loss: 2.356897, Test Loss: 2.297394
# Epoch 35/120, Train Loss: 2.416088, Test Loss: 2.286144
# Epoch 36/120, Train Loss: 2.499327, Test Loss: 2.454789
# Epoch 37/120, Train Loss: 2.400984, Test Loss: 2.244614
# Epoch 38/120, Train Loss: 2.516951, Test Loss: 2.197360
# Epoch 39/120, Train Loss: 2.413106, Test Loss: 2.097393
# Epoch 40/120, Train Loss: 2.618447, Test Loss: 2.469428
# Epoch 41/120, Train Loss: 2.376076, Test Loss: 2.049794
# Epoch 42/120, Train Loss: 2.373007, Test Loss: 2.069993
# Epoch 43/120, Train Loss: 2.384517, Test Loss: 2.082824
# Epoch 44/120, Train Loss: 2.387274, Test Loss: 2.056515
# Epoch 45/120, Train Loss: 2.364312, Test Loss: 2.055911
# Epoch 46/120, Train Loss: 2.386321, Test Loss: 2.059618
# Epoch 47/120, Train Loss: 2.399222, Test Loss: 2.053130
# Epoch 48/120, Train Loss: 2.386441, Test Loss: 2.102939
# Epoch 49/120, Train Loss: 2.417895, Test Loss: 2.132443
# Epoch 50/120, Train Loss: 2.362834, Test Loss: 2.637491
# Epoch 51/120, Train Loss: 2.378745, Test Loss: 2.063073
# Epoch 52/120, Train Loss: 2.377214, Test Loss: 2.241906
# Epoch 53/120, Train Loss: 2.367210, Test Loss: 2.062221
# Epoch 54/120, Train Loss: 2.392892, Test Loss: 2.042337
# Epoch 55/120, Train Loss: 2.370939, Test Loss: 2.153527
# Epoch 56/120, Train Loss: 2.359823, Test Loss: 2.126845
# Epoch 57/120, Train Loss: 2.409120, Test Loss: 2.243308
# Epoch 58/120, Train Loss: 2.438716, Test Loss: 2.098234
# Epoch 59/120, Train Loss: 2.348456, Test Loss: 2.172834
# Epoch 60/120, Train Loss: 2.368795, Test Loss: 2.127064
# Epoch 61/120, Train Loss: 2.374128, Test Loss: 2.313782
# Epoch 62/120, Train Loss: 2.390575, Test Loss: 2.151078
# Epoch 63/120, Train Loss: 2.402700, Test Loss: 2.155776
# Epoch 64/120, Train Loss: 2.424347, Test Loss: 2.058805
# Epoch 65/120, Train Loss: 2.405040, Test Loss: 2.152060
# Epoch 66/120, Train Loss: 2.359430, Test Loss: 2.050311
# Epoch 67/120, Train Loss: 2.418767, Test Loss: 2.147672
# Epoch 68/120, Train Loss: 2.460486, Test Loss: 2.378329
# Epoch 69/120, Train Loss: 2.386777, Test Loss: 2.169122
# Epoch 70/120, Train Loss: 2.384398, Test Loss: 2.042476
# Epoch 71/120, Train Loss: 2.393456, Test Loss: 2.063761
# Epoch 72/120, Train Loss: 2.457313, Test Loss: 2.037592
# Epoch 73/120, Train Loss: 2.359518, Test Loss: 2.044271
# Epoch 74/120, Train Loss: 2.549786, Test Loss: 2.163790
# Epoch 75/120, Train Loss: 2.376872, Test Loss: 2.098625
# Epoch 76/120, Train Loss: 2.435475, Test Loss: 2.069932
# Epoch 77/120, Train Loss: 2.626711, Test Loss: 2.058132
# Epoch 78/120, Train Loss: 2.608718, Test Loss: 2.025229
# Epoch 79/120, Train Loss: 2.369074, Test Loss: 2.075726
# Epoch 80/120, Train Loss: 2.416195, Test Loss: 2.262958
# Epoch 81/120, Train Loss: 2.468001, Test Loss: 2.153188
# Epoch 82/120, Train Loss: 2.384689, Test Loss: 2.074671
# Epoch 83/120, Train Loss: 2.392879, Test Loss: 2.232577
# Epoch 84/120, Train Loss: 2.386187, Test Loss: 2.108786
# Epoch 85/120, Train Loss: 2.354851, Test Loss: 2.140000
# Epoch 86/120, Train Loss: 2.449581, Test Loss: 2.281709
# Epoch 87/120, Train Loss: 2.461364, Test Loss: 2.224653
# Epoch 88/120, Train Loss: 2.377327, Test Loss: 2.066542
# Epoch 89/120, Train Loss: 2.398340, Test Loss: 2.115670
# Epoch 90/120, Train Loss: 2.392484, Test Loss: 2.467342
# Epoch 91/120, Train Loss: 2.378959, Test Loss: 2.071225
# Epoch 92/120, Train Loss: 2.421023, Test Loss: 2.368063
# Epoch 93/120, Train Loss: 2.506241, Test Loss: 2.362834
# Epoch 94/120, Train Loss: 2.366285, Test Loss: 2.202600
# Epoch 95/120, Train Loss: 2.356657, Test Loss: 2.242654
# Epoch 96/120, Train Loss: 2.408847, Test Loss: 2.695983
# Epoch 97/120, Train Loss: 2.366991, Test Loss: 2.115843
# Epoch 98/120, Train Loss: 2.369972, Test Loss: 2.343053
# Epoch 99/120, Train Loss: 2.383379, Test Loss: 2.150320
# Epoch 100/120, Train Loss: 2.361182, Test Loss: 2.202819
# Epoch 101/120, Train Loss: 2.387516, Test Loss: 2.123107
# Epoch 102/120, Train Loss: 2.364211, Test Loss: 2.249447
# Epoch 103/120, Train Loss: 2.372609, Test Loss: 2.130981
# Epoch 104/120, Train Loss: 2.378748, Test Loss: 2.073268
# Epoch 105/120, Train Loss: 2.361029, Test Loss: 2.423051
# Epoch 106/120, Train Loss: 2.359887, Test Loss: 2.280026
# Epoch 107/120, Train Loss: 2.422940, Test Loss: 2.084112
# Epoch 108/120, Train Loss: 2.548219, Test Loss: 2.359582
# Epoch 109/120, Train Loss: 2.348296, Test Loss: 2.103678
# Epoch 110/120, Train Loss: 2.371229, Test Loss: 2.064910
# Epoch 111/120, Train Loss: 2.422108, Test Loss: 2.435862
# Epoch 112/120, Train Loss: 2.398870, Test Loss: 2.261918
# Epoch 113/120, Train Loss: 2.396780, Test Loss: 2.073439
# Epoch 114/120, Train Loss: 2.374317, Test Loss: 2.247336
# Epoch 115/120, Train Loss: 2.376687, Test Loss: 2.072835
# Epoch 116/120, Train Loss: 2.373500, Test Loss: 2.117688
# Epoch 117/120, Train Loss: 2.383178, Test Loss: 2.244972
# Epoch 118/120, Train Loss: 2.387592, Test Loss: 2.047291
# Epoch 119/120, Train Loss: 2.370402, Test Loss: 2.119019
# Epoch 120/120, Train Loss: 2.425613, Test Loss: 2.159813

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              #'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              #'scaler_day_smote' : scaler_day_smote,
              #'scaler_month_smote' : scaler_month_smote,
              #'scaler_decade_smote' : scaler_decade_smote,
              
              'alpha': alpha,
              #'alpha_smote': alpha_smote
              }



torch.save(checkpoint, 'checkpoint_half.pth.tar')

# %%
# r2_score(y.detach().numpy(), yHat.detach().numpy())
# type(r2_score(y.detach(), yHat.detach()))

# %%
# torch.mean( r2_score(y.detach().numpy(), yHat.detach().numpy()) ).item()

# %%
trainLoss1, testLoss1, trainAcc1
# Out:
# (tensor([2.2666, 2.2801, 2.2982, 2.2963, 2.3094, 2.3031, 2.3091, 2.3023, 2.3068,
#          2.3028, 2.3044, 2.3062, 2.3067, 2.3091, 2.3014, 2.3015, 2.3078, 2.3074,
#          2.3068, 2.3031, 2.3154, 2.3079, 2.3117, 2.3014, 2.3092, 2.3110, 2.3116,
#          2.2985, 2.3330, 2.3085, 2.2946, 2.3076, 2.2996, 2.3163, 2.2966, 2.3086,
#          2.3105, 2.3308, 2.3185, 2.3252, 2.3279, 2.3309, 2.3194, 2.3275, 2.3236,
#          2.3286, 2.3306, 2.3263, 2.3216, 2.3340, 2.3219, 2.3244, 2.3249, 2.3190,
#          2.3264, 2.3217, 2.3197, 2.3247, 2.3196, 2.3333, 2.3195, 2.3317, 2.3165,
#          2.3260, 2.3292, 2.3123, 2.3255, 2.3179, 2.3254, 2.3350, 2.3239, 2.3431,
#          2.3416, 2.3298, 2.3296, 2.3313, 2.3339, 2.3290, 2.3323, 2.3269, 2.3243,
#          2.3341, 2.3293, 2.3269, 2.3265, 2.3263, 2.3303, 2.3266, 2.3295, 2.3298,
#          2.3260, 2.3288, 2.3331, 2.3255, 2.3222, 2.3261, 2.3220, 2.3306, 2.3222,
#          2.3290, 2.3223, 2.3243, 2.3232, 2.3313, 2.3235, 2.3279, 2.3233, 2.3248,
#          2.3337, 2.3216, 2.3252, 2.3270, 2.3197, 2.3264, 2.3230, 2.3354, 2.3175,
#          2.3283, 2.3258, 2.3252]),
#  tensor([1.9616, 2.0316, 2.2622, 2.0825, 2.1245, 2.1269, 2.2025, 2.0709, 2.1219,
#          2.2216, 2.0697, 2.0729, 2.1053, 2.0865, 2.0284, 2.2095, 2.0884, 2.0743,
#          2.1326, 2.8979, 2.2420, 2.0274, 2.0934, 2.0448, 2.0718, 2.0461, 2.0696,
#          2.0176, 2.0257, 2.1760, 2.1207, 2.7647, 2.1654, 2.2974, 2.2861, 2.4548,
#          2.2446, 2.1974, 2.0974, 2.4694, 2.0498, 2.0700, 2.0828, 2.0565, 2.0559,
#          2.0596, 2.0531, 2.1029, 2.1324, 2.6375, 2.0631, 2.2419, 2.0622, 2.0423,
#          2.1535, 2.1268, 2.2433, 2.0982, 2.1728, 2.1271, 2.3138, 2.1511, 2.1558,
#          2.0588, 2.1521, 2.0503, 2.1477, 2.3783, 2.1691, 2.0425, 2.0638, 2.0376,
#          2.0443, 2.1638, 2.0986, 2.0699, 2.0581, 2.0252, 2.0757, 2.2630, 2.1532,
#          2.0747, 2.2326, 2.1088, 2.1400, 2.2817, 2.2247, 2.0665, 2.1157, 2.4673,
#          2.0712, 2.3681, 2.3628, 2.2026, 2.2427, 2.6960, 2.1158, 2.3431, 2.1503,
#          2.2028, 2.1231, 2.2494, 2.1310, 2.0733, 2.4231, 2.2800, 2.0841, 2.3596,
#          2.1037, 2.0649, 2.4359, 2.2619, 2.0734, 2.2473, 2.0728, 2.1177, 2.2450,
#          2.0473, 2.1190, 2.1598]),
#  tensor([0.5822, 0.5719, 0.5304, 0.5272, 0.5272, 0.5278, 0.5264, 0.5268, 0.5269,
#          0.5275, 0.5272, 0.5273, 0.5270, 0.5272, 0.5279, 0.5282, 0.5275, 0.5275,
#          0.5276, 0.5281, 0.5265, 0.5275, 0.5266, 0.5284, 0.5273, 0.5268, 0.5268,
#          0.5286, 0.5243, 0.5276, 0.5295, 0.5274, 0.5286, 0.5267, 0.5287, 0.5275,
#          0.5274, 0.5247, 0.5265, 0.5255, 0.5251, 0.5240, 0.5253, 0.5246, 0.5251,
#          0.5247, 0.5238, 0.5247, 0.5255, 0.5237, 0.5250, 0.5251, 0.5249, 0.5256,
#          0.5246, 0.5253, 0.5253, 0.5247, 0.5255, 0.5235, 0.5258, 0.5240, 0.5260,
#          0.5244, 0.5242, 0.5266, 0.5248, 0.5259, 0.5249, 0.5234, 0.5251, 0.5225,
#          0.5228, 0.5241, 0.5244, 0.5243, 0.5237, 0.5245, 0.5237, 0.5244, 0.5255,
#          0.5240, 0.5247, 0.5251, 0.5253, 0.5249, 0.5249, 0.5249, 0.5250, 0.5245,
#          0.5255, 0.5251, 0.5244, 0.5252, 0.5256, 0.5254, 0.5257, 0.5245, 0.5256,
#          0.5247, 0.5255, 0.5253, 0.5257, 0.5248, 0.5256, 0.5245, 0.5259, 0.5256,
#          0.5242, 0.5253, 0.5251, 0.5252, 0.5257, 0.5248, 0.5255, 0.5238, 0.5262,
#          0.5247, 0.5254, 0.5255]))

# %%
# batchLoss

# %%
# batchAcc

# %%
# yHat.shape, y.shape

# %%
# yHat_test.shape, yy.shape

# %%
yHat1.flatten(), y1.flatten()
# Out:
# (tensor([1.8981, 1.0633, 8.0774, 4.3941, 0.0103, 3.0620, 1.1958, 4.5450, 1.9588,
#          0.0000, 7.4462, 4.5743, 0.3980, 1.7753, 1.1846, 4.6050, 1.9904, 0.0000,
#          4.4576, 4.8247, 0.0619, 2.9984, 1.1985, 4.6833, 1.9395, 0.9798, 4.1536,
#          4.7472, 0.0000, 6.9024, 1.1652, 4.6621, 1.8428, 1.2069, 8.2484, 4.3411,
#          0.0000, 7.9292, 1.2015, 4.5646, 0.9684, 9.3342, 4.5799, 4.6462, 0.6247,
#          1.2078, 1.1532, 4.5578, 1.0889, 8.3273, 0.9384, 4.6661, 0.0000, 3.3413,
#          1.1877, 4.6316, 1.9453, 0.5942, 7.8805, 4.4247, 0.9517, 0.0000, 1.1731,
#          4.6091, 0.9758, 9.2837, 6.8176, 4.6405, 0.4217, 1.8875, 1.1369, 4.4929,
#          0.9733, 9.0537, 0.2607, 4.6890, 0.0000, 6.8917, 1.1958, 4.6587, 1.9159,
#          1.0040, 6.5172, 4.6374, 0.0000, 7.8288, 1.1507, 4.5889, 1.9080, 1.1135,
#          7.9965, 4.3943, 0.2664, 2.2141, 1.1863, 4.5551, 1.9817, 0.0000, 7.4692,
#          4.6595, 0.0000, 3.9291, 1.2084, 4.6225, 1.9902, 0.0000, 6.0520, 4.6527,
#          0.8010, 0.4795, 1.1522, 4.6407, 0.9515, 9.1876, 2.1935, 4.6856, 0.0000,
#          6.8774, 1.1852, 4.6122, 1.0389, 8.4132, 0.0323, 4.6582, 0.0000, 8.9801,
#          1.1952, 4.6735, 0.9562, 9.2126, 2.7584, 4.6943, 0.0000, 5.5134, 1.1852,
#          4.6000, 2.0129, 1.0444, 5.2543, 4.7094, 0.6853, 0.8895, 1.1345, 4.6464,
#          2.0048, 1.1256, 6.4795, 4.6255, 1.0367, 0.0000, 1.1220, 4.6213, 1.9416,
#          0.0000, 7.8940, 4.4830, 0.5645, 1.2301, 1.1931, 4.6054, 0.9718, 9.2966,
#          6.8311, 4.5957, 0.8078, 0.6090, 1.1218, 4.4826, 0.9803, 8.9991, 0.0000,
#          4.6902, 0.0000, 6.8650, 1.1993, 4.6706, 1.0453, 8.4294, 0.4253, 4.6630,
#          0.0000, 7.9842, 1.1934, 4.6641, 1.0867, 8.3348, 0.6080, 4.6542, 0.1153,
#          2.7706, 1.1861, 4.6365, 0.9731, 8.8913, 8.5485, 4.3393, 0.0000, 5.5673,
#          1.1984, 4.4684, 0.9892, 8.9054, 7.7119, 4.4451, 0.2529, 2.3893, 1.1646,
#          4.4537, 1.9168, 1.0804, 1.5158, 4.7705, 0.0000, 7.0215, 1.1879, 4.7258,
#          0.9627, 9.2244, 2.7019, 4.7001, 0.0000, 4.6637, 1.1859, 4.6011, 1.9013,
#          0.0000, 1.3737, 4.8012, 0.0000, 8.4195, 1.2087, 4.7513, 1.9731, 1.2698,
#          1.0082, 4.7304, 1.0492, 0.0000, 1.1687, 4.7669, 1.0353, 8.5693, 5.0497,
#          4.6344, 0.0000, 7.7207, 1.1529, 4.5421, 2.0589, 0.0000, 3.8316, 4.8945,
#          0.0000, 4.8538, 1.2328, 4.7424], grad_fn=<ReshapeAliasBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
yHat_test1, yy1
# Out:
# (tensor([[1.0888, 8.4557, 1.8581, 4.6593, 0.0000, 5.9038, 1.1789, 4.6236]]),
#  tensor([[1., 8., 1., 6., 0., 6., 0., 1.]]))

# %%
yy1
# Out:
# tensor([[1., 8., 1., 6., 0., 6., 0., 1.]])

# %%
(yHat_test1).round()
# Out:
# tensor([[1., 8., 2., 5., 0., 6., 1., 5.]])

# %%
(yHat1.flatten()).round(), (y1.flatten()).round()
# Out:
# (tensor([2., 1., 8., 4., 0., 3., 1., 5., 2., 0., 7., 5., 0., 2., 1., 5., 2., 0.,
#          4., 5., 0., 3., 1., 5., 2., 1., 4., 5., 0., 7., 1., 5., 2., 1., 8., 4.,
#          0., 8., 1., 5., 1., 9., 5., 5., 1., 1., 1., 5., 1., 8., 1., 5., 0., 3.,
#          1., 5., 2., 1., 8., 4., 1., 0., 1., 5., 1., 9., 7., 5., 0., 2., 1., 4.,
#          1., 9., 0., 5., 0., 7., 1., 5., 2., 1., 7., 5., 0., 8., 1., 5., 2., 1.,
#          8., 4., 0., 2., 1., 5., 2., 0., 7., 5., 0., 4., 1., 5., 2., 0., 6., 5.,
#          1., 0., 1., 5., 1., 9., 2., 5., 0., 7., 1., 5., 1., 8., 0., 5., 0., 9.,
#          1., 5., 1., 9., 3., 5., 0., 6., 1., 5., 2., 1., 5., 5., 1., 1., 1., 5.,
#          2., 1., 6., 5., 1., 0., 1., 5., 2., 0., 8., 4., 1., 1., 1., 5., 1., 9.,
#          7., 5., 1., 1., 1., 4., 1., 9., 0., 5., 0., 7., 1., 5., 1., 8., 0., 5.,
#          0., 8., 1., 5., 1., 8., 1., 5., 0., 3., 1., 5., 1., 9., 9., 4., 0., 6.,
#          1., 4., 1., 9., 8., 4., 0., 2., 1., 4., 2., 1., 2., 5., 0., 7., 1., 5.,
#          1., 9., 3., 5., 0., 5., 1., 5., 2., 0., 1., 5., 0., 8., 1., 5., 2., 1.,
#          1., 5., 1., 0., 1., 5., 1., 9., 5., 5., 0., 8., 1., 5., 2., 0., 4., 5.,
#          0., 5., 1., 5.], grad_fn=<RoundBackward0>),
#  tensor([2., 1., 8., 5., 0., 3., 1., 8., 2., 0., 8., 9., 0., 2., 2., 4., 2., 0.,
#          5., 8., 0., 3., 2., 9., 2., 1., 4., 2., 0., 7., 0., 3., 2., 1., 9., 0.,
#          0., 8., 0., 6., 1., 9., 5., 7., 0., 1., 0., 3., 1., 8., 0., 2., 0., 3.,
#          1., 4., 2., 0., 9., 3., 1., 1., 1., 8., 1., 9., 6., 4., 1., 2., 1., 0.,
#          1., 9., 0., 4., 0., 7., 0., 3., 2., 1., 6., 4., 0., 8., 1., 7., 2., 1.,
#          8., 8., 0., 2., 2., 0., 2., 0., 8., 6., 0., 4., 0., 5., 2., 0., 8., 8.,
#          0., 1., 1., 9., 1., 9., 0., 1., 0., 7., 2., 4., 1., 8., 0., 6., 0., 9.,
#          1., 0., 1., 9., 3., 1., 0., 6., 1., 0., 2., 1., 5., 1., 0., 1., 2., 1.,
#          2., 1., 6., 0., 1., 0., 1., 3., 2., 0., 9., 7., 1., 2., 2., 8., 1., 9.,
#          7., 9., 1., 1., 1., 5., 1., 9., 1., 9., 0., 7., 1., 9., 1., 8., 0., 1.,
#          0., 8., 2., 3., 1., 8., 0., 1., 0., 2., 1., 3., 1., 8., 9., 4., 0., 6.,
#          0., 3., 1., 8., 9., 0., 0., 2., 2., 7., 2., 1., 2., 5., 0., 7., 2., 6.,
#          1., 9., 4., 2., 0., 5., 1., 1., 2., 0., 0., 1., 0., 8., 0., 9., 2., 1.,
#          2., 6., 1., 0., 2., 5., 1., 8., 5., 4., 0., 8., 1., 8., 2., 0., 4., 0.,
#          0., 5., 2., 6.]))

# %%
print_score(X.shape, yHat1, y1, yHat_test1, yy1)
# Out:
# Adjusted R-Squared(y, yHat): 0.5442
#
#
# mean_absolute_error(y, yHat): 0.8893
#
# mean_absolute_error(yy, yHat_test): 0.9552
#
#
# mean_squared_error(y, yHat): 2.4256
#
# mean_squared_error(yy, yHat_test): 2.1598
#
#
# mean_squared_log_error(y, yHat): 0.1994
#
# mean_squared_log_error(yy, yHat_test): 0.2316
#
#
# RMSE(y, yHat): 1.5574
#
# RMSE(yy, yHat_test): 1.4696

# %%
# create a 1D smoothing filter
def smooth(x, k=15):
    return np.convolve(x, np.ones(k)/k, mode='same')

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss1, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss1, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss1) - 1, testLoss1[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss1.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc1, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat1.detach().T, y1.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc1.jpg", bbox_inches='tight')


plt.show()

# %%
data.leap_year.value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data.leap_year.value_counts().plot(kind="bar")

# %%
resampler = SMOTE(k_neighbors=20, random_state=0)

# %%
X_res, y_res = resampler.fit_resample(data[['day_code', 'month_code', 'decade', 'date_int']], data['leap_year'])

# %%
y_res.value_counts()
# Out:
# 0    110960
# 1    110960
# Name: leap_year, dtype: int64

# %%
data['leap_year'].value_counts()
# Out:
# 0    110960
# 1     35502
# Name: leap_year, dtype: int64

# %%
data
# Out:
#           day  month  leap_year  decade       date  date_int  day_code  \
# 0       [WED]  [JAN]          0     180 1800-01-01  18000101         4
# 1       [THU]  [JAN]          0     180 1801-01-01  18010101         5
# 2       [FRI]  [JAN]          0     180 1802-01-01  18020101         6
# 3       [SAT]  [JAN]          0     180 1803-01-01  18030101         0
# 4       [SUN]  [JAN]          1     180 1804-01-01  18040101         1
# ...       ...    ...        ...     ...        ...       ...       ...
# 146457  [SAT]  [DEC]          1     219 2196-12-31  21961231         0
# 146458  [SUN]  [DEC]          0     219 2197-12-31  21971231         1
# 146459  [MON]  [DEC]          0     219 2198-12-31  21981231         2
# 146460  [TUE]  [DEC]          0     219 2199-12-31  21991231         3
# 146461  [WED]  [DEC]          0     220 2200-12-31  22001231         4
#
#         day_scaled   day_sin   day_cos  month_code  month_scaled  month_sin  \
# 0             0.25 -0.433884 -0.900969           0     -1.000000        0.0
# 1             0.50 -0.974928 -0.222521           0     -1.000000        0.0
# 2             0.75 -0.781831  0.623490           0     -1.000000        0.0
# 3            -0.75  0.000000  1.000000           0     -1.000000        0.0
# 4            -0.50  0.781831  0.623490           0     -1.000000        0.0
# ...            ...       ...       ...         ...           ...        ...
# 146457       -0.75  0.000000  1.000000          11      0.833333       -0.5
# 146458       -0.50  0.781831  0.623490          11      0.833333       -0.5
# 146459       -0.25  0.974928 -0.222521          11      0.833333       -0.5
# 146460        0.00  0.433884 -0.900969          11      0.833333       -0.5
# 146461        0.25 -0.433884 -0.900969          11      0.833333       -0.5
#
#         month_cos  decade_scaled  decade_sin  decade_cos
# 0        1.000000          -1.00    0.636242   -0.771489
# 1        1.000000          -1.00    0.636242   -0.771489
# 2        1.000000          -1.00    0.636242   -0.771489
# 3        1.000000          -1.00    0.636242   -0.771489
# 4        1.000000          -1.00    0.636242   -0.771489
# ...           ...            ...         ...         ...
# 146457   0.866025           0.95    0.839365   -0.543568
# 146458   0.866025           0.95    0.839365   -0.543568
# 146459   0.866025           0.95    0.839365   -0.543568
# 146460   0.866025           0.95    0.839365   -0.543568
# 146461   0.866025           1.00    0.746553   -0.665326
#
# [146462 rows x 17 columns]

# %%
y_res
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         1
#          ..
# 221915    1
# 221916    1
# 221917    1
# 221918    1
# 221919    1
# Name: leap_year, Length: 221920, dtype: int64

# %%
X_res
# Out:
#         day_code  month_code  decade  date_int
# 0              4           0     180  18000101
# 1              5           0     180  18010101
# 2              6           0     180  18020101
# 3              0           0     180  18030101
# 4              1           0     180  18040101
# ...          ...         ...     ...       ...
# 221915         0           5     188  18880618
# 221916         2           6     188  18840705
# 221917         5           2     218  21800323
# 221918         1           5     199  19960602
# 221919         1           4     219  21960520
#
# [221920 rows x 4 columns]

# %%
X_smote = X_res.assign(leap_year=y_res)

# %%
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221915         0           5     188  18880618          1
# 221916         2           6     188  18840705          1
# 221917         5           2     218  21800323          1
# 221918         1           5     199  19960602          1
# 221919         1           4     219  21960520          1
#
# [221920 rows x 5 columns]

# %% [markdown]
# Drop 220 decade

# %%
# data.decade.value_counts().plot(kind="bar")
X_smote.decade.value_counts().plot(kind="bar")

# %%
# data.decade.value_counts()[-5:]
X_smote.decade.value_counts()[-5:]
# Out:
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# 220     365
# Name: decade, dtype: int64

# %%
X_smote = X_smote.drop(X_smote.index[X_smote['decade'] == 220]).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  date_int  leap_year
# 0              4           0     180  18000101          0
# 1              5           0     180  18010101          0
# 2              6           0     180  18020101          0
# 3              0           0     180  18030101          0
# 4              1           0     180  18040101          1
# ...          ...         ...     ...       ...        ...
# 221550         0           5     188  18880618          1
# 221551         2           6     188  18840705          1
# 221552         5           2     218  21800323          1
# 221553         1           5     199  19960602          1
# 221554         1           4     219  21960520          1
#
# [221555 rows x 5 columns]

# %%
X_smote.decade.value_counts().plot(kind="bar")

# %%
X_smote.decade.value_counts()[-5:]
# Out:
# 209    5174
# 219    5139
# 207    5134
# 189    5133
# 187    5098
# Name: decade, dtype: int64

# %% [markdown]
# code is required to only work for dates in the range  [ 1-1-1800 to 31-12-2200 ]

# %%
X_smote.date_int.max()
# Out:
# 21991231

# %%
datetime.datetime.strptime(str(X_smote.date_int.max()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '31-12-2199'

# %%
X_smote.date_int.min()
# Out:
# 18000101

# %%
datetime.datetime.strptime(str(X_smote.date_int.min()), '%Y%m%d').strftime('%d-%m-%Y')
# Out:
# '01-01-1800'

# %%
Y_smote = X_smote['date_int']
Y_smote
# Out:
# 0         18000101
# 1         18010101
# 2         18020101
# 3         18030101
# 4         18040101
#             ...
# 221550    18880618
# 221551    18840705
# 221552    21800323
# 221553    19960602
# 221554    21960520
# Name: date_int, Length: 221555, dtype: int64

# %%
X_smote = X_smote.drop('date_int', axis=1).reset_index(drop=True)
X_smote
# Out:
#         day_code  month_code  decade  leap_year
# 0              4           0     180          0
# 1              5           0     180          0
# 2              6           0     180          0
# 3              0           0     180          0
# 4              1           0     180          1
# ...          ...         ...     ...        ...
# 221550         0           5     188          1
# 221551         2           6     188          1
# 221552         5           2     218          1
# 221553         1           5     199          1
# 221554         1           4     219          1
#
# [221555 rows x 4 columns]

# %%
Y_smote = Y_smote.reset_index(drop=True)

ls = []

for s in Y_smote.astype(str).to_list():

  l = list(s)

  ls.append(l)



arr = np.array(ls).astype(int)

ll = pd.DataFrame(arr, index=np.arange(len(Y_smote)), columns=['y1', 'y2', 'y3', 'y4', 'm1', 'm2', 'd1', 'd2'])


Y_smote = ll.values

Y_smote
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
# data.index[data['leap_year'] == 1].tolist()
# data.index[data['leap_year'] == 1]

# %%
# for i,idx in enumerate(data['leap_year'].tolist()):
#     print(i, idx)

# %% [markdown]
# 0 0
# 1 0
# 2 0
# 3 0
# 4 1 <---
# 5 0
# 6 0
# 7 0
# 8 1 <---
# 9 0
# 10 0
# 11 0
# 12 1 <---
# 13 0
# 14 0
# 15 0
# 16 1 <---
# 17 0
# 18 0
# 19 0
# 20 1 <---
# 21 0
# 22 0
# 23 0
# 24 1 <---
# 25 0
# 26 0
# 27 0
# 28 1 <---
# 29 0
# 30 0

# %%
scaler_day_smote = RobustScaler()

x = X_smote.day_code.values.reshape(-1, 1)

X_smote['day_scaled'] = scaler_day_smote.fit_transform(x).flatten()

# %%
X_smote['day_sin'] = np.sin(X_smote['day_code'] * (2 * np.pi / 7))
X_smote['day_cos'] = np.cos(X_smote['day_code'] * (2 * np.pi / 7))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos
# 0      -0.900969
# 1      -0.222521
# 2       0.623490
# 3       1.000000
# 4       0.623490
# ...          ...
# 221550  1.000000
# 221551 -0.222521
# 221552 -0.222521
# 221553  0.623490
# 221554  0.623490
#
# [221555 rows x 7 columns]

# %%
scaler_month_smote = RobustScaler()

x = X_smote.month_code.values.reshape(-1, 1)

X_smote['month_scaled'] = scaler_month_smote.fit_transform(x).flatten()

# %%
X_smote['month_sin'] = np.sin(X_smote['month_code'] * (2 * np.pi / 12))
X_smote['month_cos'] = np.cos(X_smote['month_code'] * (2 * np.pi / 12))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos
# 0      -0.900969     -1.000000  0.000000e+00   1.000000
# 1      -0.222521     -1.000000  0.000000e+00   1.000000
# 2       0.623490     -1.000000  0.000000e+00   1.000000
# 3       1.000000     -1.000000  0.000000e+00   1.000000
# 4       0.623490     -1.000000  0.000000e+00   1.000000
# ...          ...           ...           ...        ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000
#
# [221555 rows x 10 columns]

# %%
scaler_decade_smote = RobustScaler()

x = X_smote.decade.values.reshape(-1, 1)

X_smote['decade_scaled'] = scaler_decade_smote.fit_transform(x).flatten()

# %%
# alpha_smote = len(X_smote.decade.unique())
alpha_smote = (X_smote.decade.iloc[-1] - X_smote.decade.iloc[0]) + 1

X_smote['decade_sin'] = np.sin(X_smote['decade'] * (2 * np.pi / alpha_smote))
X_smote['decade_cos'] = np.cos(X_smote['decade'] * (2 * np.pi / alpha_smote))

# %%
X_smote
# Out:
#         day_code  month_code  decade  leap_year  day_scaled   day_sin  \
# 0              4           0     180          0    0.333333 -0.433884
# 1              5           0     180          0    0.666667 -0.974928
# 2              6           0     180          0    1.000000 -0.781831
# 3              0           0     180          0   -1.000000  0.000000
# 4              1           0     180          1   -0.666667  0.781831
# ...          ...         ...     ...        ...         ...       ...
# 221550         0           5     188          1   -1.000000  0.000000
# 221551         2           6     188          1   -0.333333  0.974928
# 221552         5           2     218          1    0.666667 -0.974928
# 221553         1           5     199          1   -0.666667  0.781831
# 221554         1           4     219          1   -0.666667  0.781831
#
#          day_cos  month_scaled     month_sin  month_cos  decade_scaled  \
# 0      -0.900969     -1.000000  0.000000e+00   1.000000      -1.052632
# 1      -0.222521     -1.000000  0.000000e+00   1.000000      -1.052632
# 2       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# 3       1.000000     -1.000000  0.000000e+00   1.000000      -1.052632
# 4       0.623490     -1.000000  0.000000e+00   1.000000      -1.052632
# ...          ...           ...           ...        ...            ...
# 221550  1.000000     -0.166667  5.000000e-01  -0.866025      -0.631579
# 221551 -0.222521      0.000000  1.224647e-16  -1.000000      -0.631579
# 221552 -0.222521     -0.666667  8.660254e-01   0.500000       0.947368
# 221553  0.623490     -0.166667  5.000000e-01  -0.866025      -0.052632
# 221554  0.623490     -0.333333  8.660254e-01  -0.500000       1.000000
#
#           decade_sin  decade_cos
# 0       1.102182e-15   -1.000000
# 1       1.102182e-15   -1.000000
# 2       1.102182e-15   -1.000000
# 3       1.102182e-15   -1.000000
# 4       1.102182e-15   -1.000000
# ...              ...         ...
# 221550 -9.510565e-01   -0.309017
# 221551 -9.510565e-01   -0.309017
# 221552  3.090170e-01   -0.951057
# 221553 -1.564345e-01    0.987688
# 221554  1.564345e-01   -0.987688
#
# [221555 rows x 13 columns]

# %%
# fig,ax = plt.subplots(1,figsize=(17,4))

# ax = sns.boxplot(data=X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
#           'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']])

# ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
# plt.show()

# %%
X = X_smote[['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']].values
X
# Out:
# array([[ 3.33333333e-01, -4.33883739e-01, -9.00968868e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        [ 1.00000000e+00, -7.81831482e-01,  6.23489802e-01, ...,
#         -1.05263158e+00,  1.10218212e-15, -1.00000000e+00],
#        ...,
#        [ 6.66666667e-01, -9.74927912e-01, -2.22520934e-01, ...,
#          9.47368421e-01,  3.09016994e-01, -9.51056516e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#         -5.26315789e-02, -1.56434465e-01,  9.87688341e-01],
#        [-6.66666667e-01,  7.81831482e-01,  6.23489802e-01, ...,
#          1.00000000e+00,  1.56434465e-01, -9.87688341e-01]])

# %%
X.shape
# Out:
# (221555, 10)

# %%
# Y = data['date_int'].values.reshape(-1, 1)
# Y = np.log(data['date_int'].values.reshape(-1, 1))
# Y = data['date_int'].values.reshape(-1, 1) / data['date_int'].max()
# Y = data['date_normalized'].values.reshape(-1, 1)
Y = Y_smote


Y
# Out:
# array([[1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        [1, 8, 0, ..., 1, 0, 1],
#        ...,
#        [2, 1, 8, ..., 3, 2, 3],
#        [1, 9, 9, ..., 6, 0, 2],
#        [2, 1, 9, ..., 5, 2, 0]])

# %%
Y.shape
# Out:
# (221555, 8)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(X, Y, test_size=0.3, shuffle=True,
                                                                    random_state=0)

# %%
train_dataT = TensorDataset( torch.tensor(train_data).float(), torch.tensor(train_labels).float() )

test_dataT  = TensorDataset( torch.tensor(test_data).float(), torch.tensor(test_labels).float() )



batchsize = 32
# batchsize = 64

train_loader = DataLoader(train_dataT, batch_size=batchsize, drop_last=True)

test_loader  = DataLoader(test_dataT)

# %%
print(f'X: {X.shape}\n')
print(f'Y: {Y.shape}\n')

print(f'Train data:   {train_data.shape}\n')
print(f'Train labels: {train_labels.shape}\n')
print(f'Test data:    {test_data.shape}\n')
print(f'Test labels:  {test_labels.shape}')
# Out:
# X: (221555, 10)
#
# Y: (221555, 8)
#
# Train data:   (155088, 10)
#
# Train labels: (155088, 8)
#
# Test data:    (66467, 10)
#
# Test labels:  (66467, 8)

# %%
model_smote = Model().to(device)


checkpoint = torch.load('checkpoint.pth.tar', map_location=torch.device('cpu'))

model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
# Out:
# <All keys matched successfully>

# %%
numepochs = 120
# numepochs = 300


trainLoss, testLoss, trainAcc, yHat, y, yHat_test, yy = train(model_smote, numepochs)
# Out:
# Epoch 1/120, Train Loss: 1.937989, Test Loss: 4.141801
# Epoch 2/120, Train Loss: 1.986688, Test Loss: 4.078907
# Epoch 3/120, Train Loss: 1.937682, Test Loss: 4.188260
# Epoch 4/120, Train Loss: 1.980826, Test Loss: 4.211207
# Epoch 5/120, Train Loss: 1.927072, Test Loss: 4.186737
# Epoch 6/120, Train Loss: 1.954143, Test Loss: 4.165364
# Epoch 7/120, Train Loss: 1.949481, Test Loss: 4.175392
# Epoch 8/120, Train Loss: 1.930158, Test Loss: 4.225994
# Epoch 9/120, Train Loss: 1.955565, Test Loss: 4.157386
# Epoch 10/120, Train Loss: 1.921955, Test Loss: 4.170353
# Epoch 11/120, Train Loss: 1.999009, Test Loss: 4.183068
# Epoch 12/120, Train Loss: 1.930656, Test Loss: 4.151003
# Epoch 13/120, Train Loss: 1.964342, Test Loss: 4.517305
# Epoch 14/120, Train Loss: 1.931331, Test Loss: 4.175156
# Epoch 15/120, Train Loss: 1.933382, Test Loss: 4.148662
# Epoch 16/120, Train Loss: 1.935975, Test Loss: 4.173666
# Epoch 17/120, Train Loss: 2.000582, Test Loss: 4.202804
# Epoch 18/120, Train Loss: 1.946556, Test Loss: 4.320993
# Epoch 19/120, Train Loss: 2.064839, Test Loss: 4.851540
# Epoch 20/120, Train Loss: 1.945124, Test Loss: 4.422825
# Epoch 21/120, Train Loss: 1.949979, Test Loss: 4.228343
# Epoch 22/120, Train Loss: 1.959349, Test Loss: 4.159293
# Epoch 23/120, Train Loss: 1.953281, Test Loss: 4.349324
# Epoch 24/120, Train Loss: 1.945350, Test Loss: 4.145196
# Epoch 25/120, Train Loss: 1.947511, Test Loss: 4.163527
# Epoch 26/120, Train Loss: 1.940083, Test Loss: 4.427698
# Epoch 27/120, Train Loss: 1.950203, Test Loss: 4.213315
# Epoch 28/120, Train Loss: 1.983120, Test Loss: 4.186719
# Epoch 29/120, Train Loss: 1.928749, Test Loss: 4.123460
# Epoch 30/120, Train Loss: 1.985414, Test Loss: 4.529026
# Epoch 31/120, Train Loss: 1.969585, Test Loss: 4.361983
# Epoch 32/120, Train Loss: 1.937457, Test Loss: 4.132937
# Epoch 33/120, Train Loss: 2.017650, Test Loss: 4.498752
# Epoch 34/120, Train Loss: 1.957969, Test Loss: 4.261934
# Epoch 35/120, Train Loss: 1.940141, Test Loss: 4.375855
# Epoch 36/120, Train Loss: 1.926856, Test Loss: 4.300781
# Epoch 37/120, Train Loss: 1.938277, Test Loss: 4.159804
# Epoch 38/120, Train Loss: 1.929076, Test Loss: 4.213324
# Epoch 39/120, Train Loss: 1.930223, Test Loss: 4.582912
# Epoch 40/120, Train Loss: 1.943378, Test Loss: 4.200146
# Epoch 41/120, Train Loss: 1.939834, Test Loss: 4.416699
# Epoch 42/120, Train Loss: 2.004309, Test Loss: 4.707143
# Epoch 43/120, Train Loss: 1.939241, Test Loss: 4.137959
# Epoch 44/120, Train Loss: 2.018580, Test Loss: 4.174334
# Epoch 45/120, Train Loss: 1.931541, Test Loss: 4.182216
# Epoch 46/120, Train Loss: 1.926626, Test Loss: 4.113650
# Epoch 47/120, Train Loss: 2.086767, Test Loss: 4.874802
# Epoch 48/120, Train Loss: 1.967638, Test Loss: 4.191481
# Epoch 49/120, Train Loss: 1.932278, Test Loss: 4.179706
# Epoch 50/120, Train Loss: 1.949964, Test Loss: 4.418232
# Epoch 51/120, Train Loss: 1.947531, Test Loss: 4.212003
# Epoch 52/120, Train Loss: 1.952199, Test Loss: 4.440719
# Epoch 53/120, Train Loss: 1.947643, Test Loss: 4.190854
# Epoch 54/120, Train Loss: 1.952231, Test Loss: 4.200483
# Epoch 55/120, Train Loss: 1.937688, Test Loss: 4.401163
# Epoch 56/120, Train Loss: 1.962864, Test Loss: 4.342893
# Epoch 57/120, Train Loss: 1.965573, Test Loss: 4.294973
# Epoch 58/120, Train Loss: 1.940958, Test Loss: 4.210580
# Epoch 59/120, Train Loss: 1.934721, Test Loss: 4.229321
# Epoch 60/120, Train Loss: 1.944200, Test Loss: 4.155208
# Epoch 61/120, Train Loss: 1.941182, Test Loss: 4.234491
# Epoch 62/120, Train Loss: 2.061249, Test Loss: 4.276865
# Epoch 63/120, Train Loss: 2.029840, Test Loss: 4.245207
# Epoch 64/120, Train Loss: 1.938978, Test Loss: 4.166636
# Epoch 65/120, Train Loss: 1.956472, Test Loss: 4.402693
# Epoch 66/120, Train Loss: 1.967840, Test Loss: 4.213250
# Epoch 67/120, Train Loss: 1.924680, Test Loss: 4.188428
# Epoch 68/120, Train Loss: 1.963935, Test Loss: 4.158981
# Epoch 69/120, Train Loss: 1.933343, Test Loss: 4.191685
# Epoch 70/120, Train Loss: 1.957835, Test Loss: 4.515310
# Epoch 71/120, Train Loss: 1.955065, Test Loss: 4.479611
# Epoch 72/120, Train Loss: 1.964135, Test Loss: 4.184636
# Epoch 73/120, Train Loss: 1.978604, Test Loss: 4.400066
# Epoch 74/120, Train Loss: 1.939177, Test Loss: 4.525070
# Epoch 75/120, Train Loss: 1.931809, Test Loss: 4.214164
# Epoch 76/120, Train Loss: 1.928748, Test Loss: 4.143199
# Epoch 77/120, Train Loss: 1.958958, Test Loss: 4.498445
# Epoch 78/120, Train Loss: 1.932379, Test Loss: 4.165842
# Epoch 79/120, Train Loss: 1.941670, Test Loss: 4.472466
# Epoch 80/120, Train Loss: 1.948758, Test Loss: 4.462685
# Epoch 81/120, Train Loss: 2.099368, Test Loss: 4.302142
# Epoch 82/120, Train Loss: 1.931623, Test Loss: 4.106411
# Epoch 83/120, Train Loss: 2.032166, Test Loss: 4.121009
# Epoch 84/120, Train Loss: 1.943255, Test Loss: 4.446184
# Epoch 85/120, Train Loss: 1.955280, Test Loss: 4.175347
# Epoch 86/120, Train Loss: 1.961133, Test Loss: 4.259062
# Epoch 87/120, Train Loss: 1.939476, Test Loss: 4.447721
# Epoch 88/120, Train Loss: 1.963405, Test Loss: 4.289800
# Epoch 89/120, Train Loss: 1.941938, Test Loss: 4.367987
# Epoch 90/120, Train Loss: 1.963631, Test Loss: 4.141673
# Epoch 91/120, Train Loss: 1.933829, Test Loss: 4.149011
# Epoch 92/120, Train Loss: 1.962624, Test Loss: 4.172035
# Epoch 93/120, Train Loss: 1.954927, Test Loss: 4.086720
# Epoch 94/120, Train Loss: 1.964876, Test Loss: 4.234595
# Epoch 95/120, Train Loss: 1.941531, Test Loss: 4.172134
# Epoch 96/120, Train Loss: 1.937116, Test Loss: 4.384094
# Epoch 97/120, Train Loss: 1.936668, Test Loss: 4.218894
# Epoch 98/120, Train Loss: 1.942155, Test Loss: 4.218482
# Epoch 99/120, Train Loss: 1.926296, Test Loss: 4.144855
# Epoch 100/120, Train Loss: 1.952007, Test Loss: 4.556839
# Epoch 101/120, Train Loss: 1.934368, Test Loss: 4.196105
# Epoch 102/120, Train Loss: 1.938489, Test Loss: 4.351282
# Epoch 103/120, Train Loss: 1.950631, Test Loss: 4.338377
# Epoch 104/120, Train Loss: 1.928750, Test Loss: 4.179529
# Epoch 105/120, Train Loss: 1.966528, Test Loss: 4.272964
# Epoch 106/120, Train Loss: 2.079927, Test Loss: 4.201634
# Epoch 107/120, Train Loss: 1.962686, Test Loss: 4.366065
# Epoch 108/120, Train Loss: 1.954383, Test Loss: 4.189713
# Epoch 109/120, Train Loss: 1.945736, Test Loss: 4.176228
# Epoch 110/120, Train Loss: 1.953542, Test Loss: 4.171356
# Epoch 111/120, Train Loss: 1.936111, Test Loss: 4.424748
# Epoch 112/120, Train Loss: 1.936897, Test Loss: 4.456960
# Epoch 113/120, Train Loss: 1.937808, Test Loss: 4.356861
# Epoch 114/120, Train Loss: 1.945441, Test Loss: 4.120450
# Epoch 115/120, Train Loss: 1.938820, Test Loss: 4.229444
# Epoch 116/120, Train Loss: 1.958321, Test Loss: 4.500818
# Epoch 117/120, Train Loss: 1.913274, Test Loss: 4.422910
# Epoch 118/120, Train Loss: 1.943829, Test Loss: 4.280051
# Epoch 119/120, Train Loss: 1.984073, Test Loss: 4.276299
# Epoch 120/120, Train Loss: 1.926017, Test Loss: 4.260186

# %%
trainLoss, testLoss, trainAcc
# Out:
# (tensor([2.2238, 2.2395, 2.2281, 2.2338, 2.2354, 2.2463, 2.2444, 2.2429, 2.2441,
#          2.2408, 2.2459, 2.2516, 2.2466, 2.2473, 2.2455, 2.2574, 2.2511, 2.2452,
#          2.2476, 2.2519, 2.2443, 2.2497, 2.2520, 2.2667, 2.2496, 2.2615, 2.2485,
#          2.2605, 2.2546, 2.2630, 2.2559, 2.2557, 2.2617, 2.2498, 2.2527, 2.2510,
#          2.2567, 2.2556, 2.2595, 2.2566, 2.2537, 2.2558, 2.2531, 2.2613, 2.2578,
#          2.2580, 2.2576, 2.2555, 2.2533, 2.2639, 2.2549, 2.2595, 2.2551, 2.2586,
#          2.2554, 2.2542, 2.2631, 2.2515, 2.2606, 2.2564, 2.2571, 2.2575, 2.2519,
#          2.2722, 2.2616, 2.2653, 2.2592, 2.2637, 2.2629, 2.2578, 2.2584, 2.2660,
#          2.2586, 2.2608, 2.2612, 2.2617, 2.2575, 2.2641, 2.2610, 2.2652, 2.2602,
#          2.2656, 2.2522, 2.2533, 2.2504, 2.2620, 2.2577, 2.2567, 2.2573, 2.2557,
#          2.2533, 2.2570, 2.2521, 2.2570, 2.2648, 2.2577, 2.2570, 2.2593, 2.2633,
#          2.2646, 2.2603, 2.2617, 2.2574, 2.2618, 2.2604, 2.2616, 2.2663, 2.2583,
#          2.2602, 2.2590, 2.2652, 2.2601, 2.2597, 2.2604, 2.2615, 2.2620, 2.2585,
#          2.2590, 2.2624, 2.2554]),
#  tensor([4.1418, 4.0789, 4.1883, 4.2112, 4.1867, 4.1654, 4.1754, 4.2260, 4.1574,
#          4.1704, 4.1831, 4.1510, 4.5173, 4.1752, 4.1487, 4.1737, 4.2028, 4.3210,
#          4.8515, 4.4228, 4.2283, 4.1593, 4.3493, 4.1452, 4.1635, 4.4277, 4.2133,
#          4.1867, 4.1235, 4.5290, 4.3620, 4.1329, 4.4988, 4.2619, 4.3759, 4.3008,
#          4.1598, 4.2133, 4.5829, 4.2001, 4.4167, 4.7071, 4.1380, 4.1743, 4.1822,
#          4.1137, 4.8748, 4.1915, 4.1797, 4.4182, 4.2120, 4.4407, 4.1909, 4.2005,
#          4.4012, 4.3429, 4.2950, 4.2106, 4.2293, 4.1552, 4.2345, 4.2769, 4.2452,
#          4.1666, 4.4027, 4.2133, 4.1884, 4.1590, 4.1917, 4.5153, 4.4796, 4.1846,
#          4.4001, 4.5251, 4.2142, 4.1432, 4.4984, 4.1658, 4.4725, 4.4627, 4.3021,
#          4.1064, 4.1210, 4.4462, 4.1753, 4.2591, 4.4477, 4.2898, 4.3680, 4.1417,
#          4.1490, 4.1720, 4.0867, 4.2346, 4.1721, 4.3841, 4.2189, 4.2185, 4.1449,
#          4.5568, 4.1961, 4.3513, 4.3384, 4.1795, 4.2730, 4.2016, 4.3661, 4.1897,
#          4.1762, 4.1714, 4.4247, 4.4570, 4.3569, 4.1205, 4.2294, 4.5008, 4.4229,
#          4.2801, 4.2763, 4.2602]),
#  tensor([0.5700, 0.5475, 0.5807, 0.5848, 0.5842, 0.5604, 0.5289, 0.5262, 0.5270,
#          0.5276, 0.5272, 0.5272, 0.5279, 0.5280, 0.5282, 0.5265, 0.5278, 0.5283,
#          0.5281, 0.5275, 0.5283, 0.5281, 0.5279, 0.5260, 0.5191, 0.5192, 0.5188,
#          0.5176, 0.5191, 0.5222, 0.5234, 0.5229, 0.5223, 0.5241, 0.5234, 0.5243,
#          0.5227, 0.5236, 0.5218, 0.5216, 0.5222, 0.5214, 0.5217, 0.5206, 0.5212,
#          0.5206, 0.5206, 0.5216, 0.5219, 0.5206, 0.5221, 0.5209, 0.5223, 0.5217,
#          0.5221, 0.5220, 0.5212, 0.5223, 0.5214, 0.5222, 0.5218, 0.5216, 0.5227,
#          0.5220, 0.5222, 0.5220, 0.5225, 0.5224, 0.5217, 0.5225, 0.5216, 0.5204,
#          0.5221, 0.5216, 0.5209, 0.5217, 0.5221, 0.5215, 0.5221, 0.5210, 0.5213,
#          0.5200, 0.5217, 0.5215, 0.5221, 0.5204, 0.5215, 0.5218, 0.5216, 0.5218,
#          0.5220, 0.5219, 0.5218, 0.5218, 0.5233, 0.5236, 0.5237, 0.5227, 0.5227,
#          0.5225, 0.5227, 0.5228, 0.5232, 0.5227, 0.5229, 0.5229, 0.5220, 0.5233,
#          0.5228, 0.5231, 0.5222, 0.5230, 0.5231, 0.5228, 0.5228, 0.5230, 0.5231,
#          0.5229, 0.5224, 0.5233]))

# %%
# (yy * data['date_int'].max()).round()

# %%
# (yHat_test * data['date_int'].max()).round()

# %%
print_score(X.shape, yHat, y, yHat_test, yy)
# Out:
# Adjusted R-Squared(y, yHat): 0.5560
#
#
# mean_absolute_error(y, yHat): 0.7903
#
# mean_absolute_error(yy, yHat_test): 1.2342
#
#
# mean_squared_error(y, yHat): 1.9260
#
# mean_squared_error(yy, yHat_test): 4.2602
#
#
# mean_squared_log_error(y, yHat): 0.1073
#
# mean_squared_log_error(yy, yHat_test): 0.4288
#
#
# RMSE(y, yHat): 1.3878
#
# RMSE(yy, yHat_test): 2.0640

# %%
fig,ax = plt.subplots(1, 3, figsize=(16, 5))

# ax[0].plot(smooth(trainLoss))
# ax[0].plot(smooth(testLoss))
ax[0].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')

ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Model loss')
ax[0].legend()



ax[1].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[1].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_title('Model loss')
# ax[1].set_ylim([0, 0.5])
ax[1].legend()



ax[2].plot(trainLoss, 'sb-', markerfacecolor='w', markersize=10, label='Train')
ax[2].plot(testLoss, 'ko-', markerfacecolor='w', markersize=10, label='Test')
ax[2].plot(len(testLoss) - 1, testLoss[-1], 'r*', markersize=15, label='Test')

ax[2].set_xlabel('Epochs')
ax[2].set_ylabel('Loss')
ax[2].set_title('Model loss')
ax[2].legend()




# plt.ylim([0,1])
# plt.xlim([-10,10]) # note: this actually clips two data points


plt.savefig("loss2.jpg", bbox_inches='tight')


plt.show()

# %%
plt.plot(trainAcc, 'ms-', markerfacecolor='w', markersize=10, label='Train')

plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')

# correlations between predictions and outputs
corrTrain = np.corrcoef(yHat.detach().T, y.T) [1,0]

plt.legend([ f'Train r={corrTrain:0.3f}'])


plt.savefig("acc2.jpg", bbox_inches='tight')


plt.show()

# %%
['day_scaled', 'day_sin', 'day_cos', 'month_scaled', 'month_sin', 'month_cos', 
             'leap_year', 'decade_scaled', 'decade_sin', 'decade_cos']
# Out:
# ['day_scaled',
#  'day_sin',
#  'day_cos',
#  'month_scaled',
#  'month_sin',
#  'month_cos',
#  'leap_year',
#  'decade_scaled',
#  'decade_sin',
#  'decade_cos']

# %%
def result_to_date(result):
    
    result = str(result)
    
    day   = int(result[6:]) - 1
    month = int(result[4:6]) - 1

    ss = str(f'{result[:4]}0101')
    
    ds = datetime.datetime.strptime(ss, '%Y%m%d')
    
    ds = ds + relativedelta(months=month, days=day)

    result = ds.strftime('%d-%m-%Y')
    
    
    return result

# %%
# (16830739, 17848869)
result_to_date(16830739), result_to_date(17848869)
# Out:
# ('08-08-1683', '08-06-1791')

# %%
def test_model(input_list):
    

    X       = np.zeros((1, 10))
    X_smote = np.zeros((1, 10))



    day       = np.array(map_day[input_list[0]])
    month     = np.array(map_month[input_list[1]])
    leap_year = map_leap_year[input_list[2]]
    decade    = np.array(input_list[3].strip('[]')).astype('int64')


    X[0, 0] = scaler_day.transform(day.reshape(-1, 1)).flatten()
    X[0, 1] = np.sin(day * (2 * np.pi / 7))
    X[0, 2] = np.cos(day * (2 * np.pi / 7))

    X[0, 3] = scaler_month.transform(month.reshape(-1, 1)).flatten()
    X[0, 4] = np.sin(month * (2 * np.pi / 12))
    X[0, 5] = np.cos(month * (2 * np.pi / 12))

    X[0, 6] = leap_year

    X[0, 7] = scaler_decade.transform(decade.reshape(-1, 1)).flatten()
    X[0, 8] = np.sin(decade * (2 * np.pi / alpha))
    X[0, 9] = np.cos(decade * (2 * np.pi / alpha))

    # ---

    X_smote[0, 0] = scaler_day_smote.transform(day.reshape(-1, 1)).flatten()
    X_smote[0, 1] = X[0, 1]
    X_smote[0, 2] = X[0, 2]

    X_smote[0, 3] = scaler_month_smote.transform(month.reshape(-1, 1)).flatten()
    X_smote[0, 4] = X[0, 4]
    X_smote[0, 5] = X[0, 5]

    X_smote[0, 6] = leap_year

    X_smote[0, 7] = scaler_decade_smote.transform(decade.reshape(-1, 1)).flatten()
    X_smote[0, 8] = np.sin(decade * (2 * np.pi / alpha_smote))
    X_smote[0, 9] = np.cos(decade * (2 * np.pi / alpha_smote))


    # ---

    result       = model(torch.tensor(X).to(device).float())
    result_smote = model_smote(torch.tensor(X_smote).to(device).float())


    # ---


    result       = ''.join(result.detach().cpu().numpy().round().astype(int).astype(str).flatten())
    result_smote = ''.join(result_smote.detach().cpu().numpy().round().astype(int).astype(str).flatten())


    
    return result_to_date(result), result_to_date(result_smote)

# %%
input_test1 = ['[MON]', '[DEC]', '[False]', '[196]']
output_test1 = '3-12-1962'

input_test2 = ['[THU]', '[DEC]', '[True]', '[204]']
output_test2 = '3-12-2048'

input_test3 = ['[WED]', '[JAN]', '[False]', '[181]']
output_test3 = '10-1-1810'


input_test4 = ['[WED]', '[JUN]', '[False]', '[209]']

# %%
test_model(input_test1), test_model(input_test2), test_model(input_test3), test_model(input_test4)
# Out:
# (('14-02-1965', '15-02-1964'),
#  ('15-11-2045', '15-02-2045'),
#  ('15-11-1825', '15-11-1815'),
#  ('15-07-2084', '15-06-2084'))

# %%
output_test1, output_test2, output_test3
# Out:
# ('3-12-1962', '3-12-2048', '10-1-1810')

# %%
# example_input = pd.read_csv('./data/example_input.txt', sep=' ', header=None)
example_input = pd.read_csv('example_input.txt', sep=' ', header=None)


example_input.columns = ['day', 'month', 'leap_year', 'decade']

# %%
example_input
# Out:
#         day  month leap_year decade
# 0     [WED]  [JAN]   [False]  [180]
# 1     [MON]  [JAN]   [False]  [190]
# 2     [SAT]  [JAN]    [True]  [200]
# 3     [FRI]  [JAN]   [False]  [210]
# 4     [WED]  [JAN]   [False]  [220]
# ...     ...    ...       ...    ...
# 1460  [MON]  [OCT]    [True]  [214]
# 1461  [TUE]  [DEC]   [False]  [183]
# 1462  [SUN]  [DEC]   [False]  [193]
# 1463  [SAT]  [DEC]   [False]  [203]
# 1464  [THU]  [DEC]   [False]  [213]
#
# [1465 rows x 4 columns]

# %%
R       = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result'])
R_smote = pd.DataFrame(np.nan, index=np.arange(len(example_input)), columns=['result_smote'])

# %%
example_input.iloc[0].tolist()
# Out:
# ['[WED]', '[JAN]', '[False]', '[180]']

# %%
for i in range(len(example_input)):
    R.iloc[i], R_smote.iloc[i] = test_model(example_input.iloc[i].tolist())

# %%
R
# Out:
#           result
# 0     15-11-1815
# 1     15-11-1915
# 2     15-11-2015
# 3     15-11-2115
# 4     15-11-2294
# ...          ...
# 1460  15-10-2145
# 1461  15-02-1845
# 1462  15-02-1925
# 1463  15-11-2035
# 1464  15-11-2135
#
# [1465 rows x 1 columns]

# %%
final = pd.concat([example_input, R], axis=1)
final
# Out:
#         day  month leap_year decade      result
# 0     [WED]  [JAN]   [False]  [180]  15-11-1815
# 1     [MON]  [JAN]   [False]  [190]  15-11-1915
# 2     [SAT]  [JAN]    [True]  [200]  15-11-2015
# 3     [FRI]  [JAN]   [False]  [210]  15-11-2115
# 4     [WED]  [JAN]   [False]  [220]  15-11-2294
# ...     ...    ...       ...    ...         ...
# 1460  [MON]  [OCT]    [True]  [214]  15-10-2145
# 1461  [TUE]  [DEC]   [False]  [183]  15-02-1845
# 1462  [SUN]  [DEC]   [False]  [193]  15-02-1925
# 1463  [SAT]  [DEC]   [False]  [203]  15-11-2035
# 1464  [THU]  [DEC]   [False]  [213]  15-11-2135
#
# [1465 rows x 5 columns]

# %%
final_smote = pd.concat([example_input, R_smote], axis=1)
final_smote
# Out:
#         day  month leap_year decade result_smote
# 0     [WED]  [JAN]   [False]  [180]   15-11-1805
# 1     [MON]  [JAN]   [False]  [190]   15-11-1905
# 2     [SAT]  [JAN]    [True]  [200]   15-11-2005
# 3     [FRI]  [JAN]   [False]  [210]   15-11-2115
# 4     [WED]  [JAN]   [False]  [220]   14-11-2195
# ...     ...    ...       ...    ...          ...
# 1460  [MON]  [OCT]    [True]  [214]   15-10-2145
# 1461  [TUE]  [DEC]   [False]  [183]   15-02-1834
# 1462  [SUN]  [DEC]   [False]  [193]   15-02-1934
# 1463  [SAT]  [DEC]   [False]  [203]   15-02-2045
# 1464  [THU]  [DEC]   [False]  [213]   15-02-2135
#
# [1465 rows x 5 columns]

# %%
final.to_csv('output_file.txt', sep=' ', header=None, index=False)

# %%
final_smote.to_csv('output_file_smote.txt', sep=' ', header=None, index=False)

# %% [markdown]
# Out-liers

# %% [markdown]
# Saving

# %%
checkpoint = {'model_state_dict'      : model.state_dict(),
              'model_smote_state_dict': model_smote.state_dict(),

              'scaler_day' : scaler_day,
              'scaler_month' : scaler_month,
              'scaler_decade' : scaler_decade,

              'scaler_day_smote' : scaler_day_smote,
              'scaler_month_smote' : scaler_month_smote,
              'scaler_decade_smote' : scaler_decade_smote,
              
              'alpha': alpha,
              'alpha_smote': alpha_smote}



torch.save(checkpoint, 'checkpoint.pth.tar')

# %%
# checkpoint = torch.load('checkpoint.pth.tar')

# %%
# model       = Model()
# model_smote = Model()


# model.load_state_dict(checkpoint['model_state_dict'])
# model_smote.load_state_dict(checkpoint['model_smote_state_dict'])
